# %% [markdown]
# **Soil-air interface.**
#
# Using the functionality of COMETS, one can design simulations which go beyond in silico corollaries of lab experiments to make predictions for environments mimicking natural ecosystems, which is a necessary step for understanding natural ecology from first principles. In this example, we consider a simulation of a soil environment. We use source-and-sink functions to model how a root provides organic acids to the environment while removing ammonia (Huang et al 2014 Botany). While we restrict the root functionality to a source/sink, one could use functionality demonstrated above, for example extracellular enzymes, to generate feedback loops between microbe-produced metabolites and root exudation. We use fixed metabolite concentrations to mimic the largely unchanging air interface above a root, which generates an oxygen gradient. Additionally, since soil is characterized by strong spatial structure with many impenetrable barriers that localized interactions (Nunan 2017), we place “rock” barriers throughout the simulation area. A more complex simulation could use varying diffusion constants for metabolites, as described in a previous protocol (Virtual Petri Dish). Similarly, we use standard diffusion of biomass, but this could be changed to use pushing force or non-linear diffusion for a potentially increased realism.

# %%
import cobra 
import sys 
import copy 
import numpy as np 
from matplotlib import pyplot as plt 
import cometspy as c

# %% [markdown]
# Para nuestro proyecto, utilizaremos Escherichia coli (modelo iAF1260), Pseudomonas putida (modelo iJN1463) y Saccharomyces Cerevisiae (modelo iMM904), recuperados de la base de datos BIGG.
#
# Cambiamos los bounds de las funciones objetivo de los modelos:

# %%
model_dir = "./modelos" # model location
iAF = cobra.io.read_sbml_model(model_dir + '/iAF1260.xml')
iJN = cobra.io.read_sbml_model(model_dir + '/iJN1463.xml')

iAF.reactions.get_by_id('BIOMASS_Ec_iAF1260_core_59p81M').lower_bound = 0
iAF.reactions.get_by_id('BIOMASS_Ec_iAF1260_core_59p81M').upper_bound = 1000

iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').lower_bound = 0
iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').upper_bound = 1000

# %% [markdown]
# Luego se convierten estos modelos al formato de COMETS. Se utilizan funciones helper para dos cosas: a) Asegurar que el modelo en COMETS no confunda las reacciones de "sink" con las de exchange, ya que en COBRA están desbalanceadas y por tanto se parecen a las de exchange, y b) abrir todos los bounds de las reacciones de exchange, para que COMETS controle la composición del medio.

# %%
iAF_comets = c.model(iAF)
iAF_comets.ensure_sinks_are_not_exchanges()
iAF_comets.open_exchanges()

iJN_comets = c.model(iJN)
iJN_comets.ensure_sinks_are_not_exchanges()
iJN_comets.open_exchanges()

# %% [markdown]
# El mundo que se simulará tendrá dimensiones de 30x30. El eje de la izquierda (x = 0) corresponde a la raíz, y el eje superior (y = 0) corresponde al aire. La biomasa y las rocas se distribuyen en el resto del grid. Donde hayan rocas no puede haber ni biomasa ni metabolitos, así que seleccionamos esos lugares primero. Para esta simulación, se generarán 3 rocas con un un tamaño medio de 1 cuadraditos. Para generar las piedras se utiliza la función helper grow_rocks.

# %%
from cometspy.utils import grow_rocks, pick_random_locations

grid_size = 15 # 100
n_rocks = 27 # 70
rock_locs = grow_rocks(n = n_rocks, xrange = [1,grid_size-1],yrange = [1,grid_size-1],mean_size = 1)

# %% [markdown]
# Cada especie será plantada en 20 lugares sin sobreponerse. Para esto se utiliza la función helper pick_random_locations, la cual toma como argumento una tupla generada anteriormente que marca lugares "prohibidos", como los cuadrados donde se encuentran las rocas.
#
# Generamos una copia de rock_locs para no cambiarla accidentalmente, y la llamamos forbbiden_locs:

# %%
import copy
forbidden_locs = copy.deepcopy(rock_locs)

# %% [markdown]
# Ahora elegimos al azar los lugares para cada especie, y los vamos añadiendo a la lista forbidden locs para que no se sobrepongan:

# %%
founders_per_species = 15 # 60
iAF_locs = pick_random_locations(n = founders_per_species, 
                                   xrange = [1,grid_size], yrange = [1,grid_size], 
                                   forbidden_locs = forbidden_locs)
forbidden_locs.extend(iAF_locs)
iJN_locs = pick_random_locations(founders_per_species, [1,grid_size],[1,grid_size], forbidden_locs)

# %% [markdown]
# Para graficar los lugares utilizamos matplotlib:

# %%
from matplotlib import pyplot as plt
initial_image = np.zeros((grid_size,grid_size,3))
for rock in rock_locs:
    initial_image[rock[0],rock[1],0:3] = 0.5 
for loc in iAF_locs:
    initial_image[loc[0],loc[1],1] = 1
for loc in iJN_locs:
    initial_image[loc[0],loc[1],2] = 1
plt.imshow(initial_image)

# %% [markdown]
# Generamos el layout y agregamos las rocas:

# %%
# iAF
iAF_initial_pop = [] 
for loc in iJN_locs: 
    iAF_initial_pop.append([loc[0], loc[1], 1.e-8]) 
iAF_comets.initial_pop = iAF_initial_pop 
# iJN
iJN_initial_pop = [] 
for loc in iJN_locs: 
    iJN_initial_pop.append([loc[0], loc[1], 1.e-7]) 
iJN_comets.initial_pop = iJN_initial_pop

# %% [markdown]
# Setteamos las poblaciones iniciales para cada especie, con esto los modelos están listos y los añadimos al layout:

# %%
layout = c.layout([iAF_comets, iJN_comets])
layout.grid = [grid_size,grid_size]
layout.add_barriers(rock_locs)

# %% [markdown]
# Añadimos los metabolitos que estarán inicialmente disponibles en el ambiente. Usamos la función helper add_typical_trace_metabolites() para las trazas típicas. Bajamos el valor del oxígeno dado que la idea es que el que esté disponible difunda desde la atmósfera. Añadimos algunos metabolitos que no se añadieron con la función helper:

# %%
layout.add_typical_trace_metabolites()
layout.set_specific_metabolite('o2_e',0.000001)
layout.set_specific_metabolite('hco3_e',1000)
layout.set_specific_metabolite('co2_e',1000)
layout.set_specific_metabolite('h2_e',1000)
layout.set_specific_metabolite('so3_e',1000)
layout.set_specific_metabolite('nh4_e',0.0000001)

layout.set_specific_metabolite('glc__D_e',0.0000001)
layout.set_specific_metabolite('meoh_e',0.00000001)
layout.set_specific_metabolite('cys__L_e',0.0000001)
layout.set_specific_metabolite('catechol_e',0.0000001)

# %% [markdown]
# Para la capa de aire, dejamos el oxígeno en un valor constante. Al fondo también dejamos al oxígeno en un valor fijo e igual a 0, para simular el efecto de difusión. De manera similar, hacemos lo mismo con el amoniaco y la raíz en la parte izquierda:

# %%
# set static media of O2 and CO2 at the top and bottom-- the "air" and continuous loss of O2 downwards
for x in range(grid_size):
    layout.set_specific_static_at_location('o2_e', (x,0), .0001) # top
    layout.set_specific_static_at_location('o2_e', (x,grid_size-1), 0.) # bottom
    layout.set_specific_static_at_location('co2_e', (x,0), .0001)
    
for x in range(grid_size):
    layout.set_specific_static_at_location('nh4_e', (0,x), 0.0)

# %% [markdown]
# La raíz consume todo el amoniaco, pero es una fuente de acidos orgánicos y metanol para el ambiente. Asumiendo una tasa fija:

# %%
for x in range(grid_size):
    layout.set_specific_refresh_at_location('cit_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('meoh_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('succ_e', (0,x), .000001)

# %% [markdown]
# El layout y los modelos están listos, ahora setteamos los parámetros de la simulación:

# %%
params = c.params()
params.set_param('timeStep', 0.1)
params.set_param('maxCycles', 1000)
params.set_param('maxSpaceBiomass', 10)
params.set_param('deathRate', 0.0001) # die at rate of 1/10000 per hour
params.set_param('writeBiomassLog', True)
params.set_param('BiomassLogRate', 500)
params.set_param('writeMediaLog', True)
params.set_param('MediaLogRate', 500)
params.set_param("writeFluxLog", True)
params.set_param("FluxLogRate", 500)
params.set_param('numRunThreads', 3)
params.set_param('defaultKm', 0.000001)

# %% [markdown]
# Ahora creamos el objeto de la simulación y la corremos. Ojito que se demora y el pc empieza a despegar.

# %%
sim = c.comets(layout, params)
sim.run(False)
# Out:
# Running COMETS simulation ...
# C:\Users\pabli\AppData\Local\Temp/ipykernel_3344/1491467366.py:2: DtypeWarning: Columns (5,8,10,11,12,14,18,23,25,26,27,28,31,35,39,43,44,46,62,63,64,68,69,70,72,73,74,75,79,81,83,95,96,102,104,105,107,108,114,116,118,121,122,124,129,130,132,133,134,136,137,142,144,145,146,147,148,149,150,151,152,153,155,162,163,165,166,167,169,173,175,176,177,182,189,193,200,203,206,213,214,228,229,238,243,254,255,256,257,258,265,266,274,275,286,292,294,297,299,301,303,304,327,331,346,362,369,396,402,406,407,408,410,411,412,413,414,415,417,419,420,421,440,443,444,445,450,453,458,459,489,491,506,507,514,517,518,523,527,535,538,545,547,548,549,557,559,560,569,590,591,607,619,624,631,633,639,656,657,665,667,669,670,674,676,693,696,705,708,710,714,716,718,719,720,722,723,725,727,728,729,731,732,734,736,742,746,749,753,758,760,766,768,769,781,783,785,786,798,807,810,811,813,818,821,831,833,842,846,847,863,866,868,870,871,872,873,878,879,882,883,885,887,891,909,910,911,912,920,928,935,938,941,945,950,953,954,955,959,964,966,967,969,971,974,975,976,977,978,979,981,982,983,988,991,1016,1017,1018,1021,1035,1039,1050,1053,1061,1062,1063,1064,1070,1073,1088,1091,1098,1107,1113,1114,1126,1134,1141,1149,1150,1154,1156,1159,1180,1184,1185,1188,1197,1200,1201,1203,1204,1213,1214,1216,1217,1220,1221,1224,1225,1227,1228,1229,1230,1243,1244,1246,1248,1254,1261,1262,1263,1264,1265,1266,1267,1268,1269,1275,1276,1279,1281,1282,1288,1294,1301,1302,1303,1308,1310,1316,1318,1328,1329,1336,1340,1344,1346,1348,1358,1360,1364,1370,1371,1376,1418,1424,1428,1448,1467,1468,1469,1470,1474,1476,1478,1491,1499,1500,1501,1502,1504,1505,1506,1507,1508,1509,1511,1515,1516,1517,1518,1519,1520,1521,1524,1526,1527,1528,1529,1530,1531,1532,1533,1534,1535,1536,1537,1540,1541,1542,1544,1546,1548,1552,1553,1554,1555,1556,1557,1558,1567,1573,1600,1618,1620,1621,1622,1624,1625,1629,1641,1660,1665,1678,1690,1692,1693,1697,1698,1700,1721,1726,1727,1734,1741,1747,1755,1760,1765,1766,1767,1769,1770,1771,1772,1773,1774,1775,1777,1778,1784,1785,1790,1796,1799,1810,1811,1812,1816,1830,1831,1836,1855,1868,1873,1874,1875,1886,1887,1891,1895,1896,1902,1906,1908,1910,1911,1914,1917,1918,1919,1920,1921,1923,1925,1927,1928,1930,1931,1932,1933,1934,1935,1937,1938,1940,1941,1943,1944,1949,1961,1963,1964,1968,1969,1970,1974,1975,1977,1978,1984,1985,1986,1987,1988,1989,1990,1991,1992,1994,1998,1999,2001,2002,2004,2049,2055,2056,2060,2062,2063,2075,2093,2094,2096,2098,2099,2103,2106,2107,2113,2125,2135,2140,2160,2167,2173,2200,2206,2207,2219,2225,2227,2231,2249,2253,2254,2257,2259,2263,2264,2267,2268,2269,2274,2285,2293,2316,2326,2331,2371,2376,2387,2391,2398,2399,2401,2402,2410,2420,2423,2424,2426,2431,2440,2453,2474,2477,2479,2480,2529,2533,2558,2559,2594,2595,2673,2698,2712,2715,2719,2720,2727,2729,2731,2733,2762,2763,2764,2765,2766,2769,2781,2783,2790,2833,2837,2838,2840,2842,2852,2855,2857,2877,2911,2917) have mixed types.Specify dtype option on import or set low_memory=False.
#   sim.run(False)
# Done!

# %%
print(sim.run_output)
print(sim.run_errors)
# Out:
# -script
# running script file: C:\Users\pabli\OneDrive\Escritorio\COMETS\ODRM\simulaciones\2_modelos\Coli_putida_15x15_0.0000001_catechol_cambio_putida\Coli_putida_15x15_0.0000001_catechol_cambio_putida_1e7/.current_script_0x19f70965c40
# Current Java version: 17.0.1
# Parameters file .current_global_0x19f70965c40 loaded.
# Parameters file .current_package_0x19f70965c40 loaded.
# Loading layout file '.current_layout_0x19f70965c40'...
# null\COMETS_manifest.txt (El sistema no puede encontrar la ruta especificada)
# Unable to initialize manifest file.
# Continuing without writing manifest file.
# Found 2 model files!
# Loading '.\iAF1260.cmd' ...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution = 395.73529219628256
# Loading '.\iJN1463.cmd' ...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution = 237.06607191111308
# Constructing world...
# Done!
# medialist	12dgr160_e	12dgr180_e	12ppd__R_e	12ppd__S_e	13dampp_e	14glucan_e	15dap_e	1ag160_e	1ag180_e	1ag181d9_e	1ag182d9d12_e	23camp_e	23ccmp_e	23cgmp_e	23cump_e	23dappa_e	25dkglcn_e	26dap__M_e	2ameph_e	2ddglcn_e	2dhglcn_e	2m35mdntha_e	34dhbz_e	34dhcinm_e	34dhpac_e	34dhphe_e	35dnta_e	3amp_e	3cmp_e	3gmp_e	3h4atb_e	3hcinnm_e	3hpppn_e	3mb_e	3oxoadp_e	3ump_e	4abut_e	4hbz_e	4hoxpacd_e	4hpro_DC_e	4hpro_LT_e	4hptn_e	4oxptn_e	5aptn_e	5dglcn_e	5g2oxpt_e	5mcsn_e	5oxpro_e	6atha_e	6hnac_e	LalaDgluMdapDala_e	LalaDgluMdap_e	LalaLglu_e	Ncbmpts_e	R3hdec4e_e	R_3h4atba_e	R_3h6atha_e	R_3hcmrs7e_e	R_3hdcaa_e	R_3hdd5ea
# Cycle 5
# Total biomass:
# Model iAF1260.cmd: 1.9855291419237198E-7
# Model iJN1463.cmd: 1.8545440557995646E-6
# Cycle 6
# Total biomass:
# Model iAF1260.cmd: 2.1125023034298156E-7
# Model iJN1463.cmd: 1.9377893092018725E-6
# Cycle 7
# Total biomass:
# Model iAF1260.cmd: 2.2481615521530032E-7
# Model iJN1463.cmd: 2.025246666761892E-6
# Cycle 8
# Total biomass:
# Model iAF1260.cmd: 2.393054279215946E-7
# Model iJN1463.cmd: 2.117188907381088E-6
# Cycle 9
# Total biomass:
# Model iAF1260.cmd: 2.5474445052146335E-7
# Model iJN1463.cmd: 2.213506066645162E-6
# Cycle 10
# Total biomass:
# Model iAF1260.cmd: 2.711111033445097E-7
# Model iJN1463.cmd: 2.3143869372232937E-6
# Cycle 11
# Total biomass:
# Model iAF1260.cmd: 2.8842713479321324E-7
# Model iJN1463.cmd: 2.4199782020469947E-6
# Cycle 12
# Total biomass:
# Model iAF1260.cmd: 3.067188204772262E-7
# Model iJN1463.cmd: 2.530923845180995E-6
# Cycle 13
# Total biomass:
# Model iAF1260.cmd: 3.260201718707163E-7
# Model iJN1463.cmd: 2.6470675515897405E-6
# Cycle 14
# Total biomass:
# Model iAF1260.cmd: 3.46344494956996E-7
# Model iJN1463.cmd: 2.7685054189754916E-6
# Cycle 15
# Total biomass:
# Model iAF1260.cmd: 3.676849919780275E-7
# Model iJN1463.cmd: 2.895249338128665E-6
# Cycle 16
# Total biomass:
# Model iAF1260.cmd: 3.90008251352599E-7
# Model iJN1463.cmd: 3.0274861067173277E-6
# Cycle 17
# Total biomass:
# Model iAF1260.cmd: 4.1319565729509145E-7
# Model iJN1463.cmd: 3.1652676828207333E-6
# Cycle 18
# Total biomass:
# Model iAF1260.cmd: 4.371056209962982E-7
# Model iJN1463.cmd: 3.309897318042377E-6
# Cycle 19
# Total biomass:
# Model iAF1260.cmd: 4.6164170329238633E-7
# Model iJN1463.cmd: 3.4610038852746534E-6
# Cycle 20
# Total biomass:
# Model iAF1260.cmd: 4.865550277104959E-7
# Model iJN1463.cmd: 3.6186642187382843E-6
# Cycle 21
# Total biomass:
# Model iAF1260.cmd: 5.116500995334655E-7
# Model iJN1463.cmd: 3.782891573824543E-6
# Cycle 22
# Total biomass:
# Model iAF1260.cmd: 5.369417415438794E-7
# Model iJN1463.cmd: 3.953509397358462E-6
# Cycle 23
# Total biomass:
# Model iAF1260.cmd: 5.626329841499423E-7
# Model iJN1463.cmd: 4.1306261624694355E-6
# Cycle 24
# Total biomass:
# Model iAF1260.cmd: 5.888039962972723E-7
# Model iJN1463.cmd: 4.314455234720688E-6
# Cycle 25
# Total biomass:
# Model iAF1260.cmd: 6.153648842840288E-7
# Model iJN1463.cmd: 4.505115084169577E-6
# Cycle 26
# Total biomass:
# Model iAF1260.cmd: 6.423701496937646E-7
# Model iJN1463.cmd: 4.702910961115008E-6
# Cycle 27
# Total biomass:
# Model iAF1260.cmd: 6.69491292324259E-7
# Model iJN1463.cmd: 1.177679377210381E-5
# Cycle 51
# Total biomass:
# Model iAF1260.cmd: 1.494768367771362E-6
# Model iJN1463.cmd: 1.2123182928078315E-5
# Cycle 52
# Total biomass:
# Model iAF1260.cmd: 1.5380031208470927E-6
# Model iJN1463.cmd: 1.2467274375596519E-5
# Cycle 53
# Total biomass:
# Model iAF1260.cmd: 1.5815713087465288E-6
# Model iJN1463.cmd: 1.281257807597281E-5
# Cycle 54
# Total biomass:
# Model iAF1260.cmd: 1.6258210906105E-6
# Model iJN1463.cmd: 1.3155537259394319E-5
# Cycle 55
# Total biomass:
# Model iAF1260.cmd: 1.670611446962455E-6
# Model iJN1463.cmd: 1.3495301987743521E-5
# Cycle 56
# Total biomass:
# Model iAF1260.cmd: 1.7163296830080335E-6
# Model iJN1463.cmd: 1.382912746952955E-5
# Cycle 57
# Total biomass:
# Model iAF1260.cmd: 1.7626409710968643E-6
# Model iJN1463.cmd: 1.4160150449870395E-5
# Cycle 58
# Total biomass:
# Model iAF1260.cmd: 1.8098531252254087E-6
# Model iJN1463.cmd: 1.4488053833178213E-5
# Cycle 59
# Total biomass:
# Model iAF1260.cmd: 1.857345880243417E-6
# Model iJN1463.cmd: 1.4817252720168215E-5
# Cycle 60
# Total biomass:
# Model iAF1260.cmd: 1.9062152587931097E-6
# Model iJN1463.cmd: 1.5136776848368056E-5
# Cycle 61
# Total biomass:
# Model iAF1260.cmd: 1.9549114057299216E-6
# Model iJN1463.cmd: 1.545137553862024E-5
# Cycle 62
# Total biomass:
# Model iAF1260.cmd: 2.0042234600805674E-6
# Model iJN1463.cmd: 1.5760708175209468E-5
# Cycle 63
# Total biomass:
# Model iAF1260.cmd: 2.0542191001056864E-6
# Model iJN1463.cmd: 1.606101087164336E-5
# Cycle 64
# Total biomass:
# Model iAF1260.cmd: 2.103486086704985E-6
# Model iJN1463.cmd: 1.6351510124944226E-5
# Cycle 65
# Total biomass:
# Model iAF1260.cmd: 2.1530579955320476E-6
# Model iJN1463.cmd: 1.6632430666242542E-5
# Cycle 66
# Total biomass:
# Model iAF1260.cmd: 2.2033758603057844E-6
# Model iJN1463.cmd: 1.6896649620755547E-5
# Cycle 67
# Total biomass:
# Model iAF1260.cmd: 2.2539858170814397E-6
# Model iJN1463.cmd: 1.7148003424211566E-5
# Cycle 68
# Total biomass:
# Model iAF1260.cmd: 2.305290686818443E-6
# Model iJN1463.cmd: 1.738488274072327E-5
# Cycle 69
# Total biomass:
# Model iAF1260.cmd: 2.356051460496704E-6
# Model iJN1463.cmd: 1.761055002597084E-5
# Cycle 70
# Total biomass:
# Model iAF1260.cmd: 2.406897737443049E-6
# Model iJN1463.cmd: 1.782739018329194E-5
# Cycle 71
# Total biomass:
# Model iAF1260.cmd: 2.4581043472053987E-6
# Model iJN1463.cmd: 1.803765367986285E-5
# Cycle 72
# Total biomass:
# Model iAF1260.cmd: 2.509451057900189E-6
# Model iJN1463.cmd: 1.824919115704985E-5
# Cycle 73
# Total biomass:
# Model iAF1260.cmd: 2.561275123825619E-6
# Model iJN1463.cmd: 1.8448771355117275E-5
# Cycle 74
# Total biomass:
# Model iAF1260.cmd: 2.613210381420121E-6
# Model iJN1463.cmd: 1.8643513623445883E-5
# Cycle 75
# Total biomass:
# Model iAF1260.cmd: 2.6660054583043365E-6
# Model iJN1463.cmd: 1.883514514605459E-5
# Cycle 76
# Total biomass:
# Model iAF1260.cmd: 2.719059906518968E-6
# Model iJN1463.cmd: 1.901752911840729E-5
# Cycle 77
# Total biomass:
# Model iAF1260.cmd: 2.7723990357642096E-6
# Model iJN1463.cmd: 1.9196046062292415E-5
# Cycle 78
# Total biomass:
# Model iAF1260.cmd: 2.826407328975197E-6
# Model iJN1463.cmd: 1.938256155769207E-5
# Cycle 79
# Total biomass:
# Model iAF1260.cmd: 2.880828766018124E-6
# Model iJN1463.cmd: 1.956088475719999E-5
# Cycle 80
# Total biomass:
# Model iAF1260.cmd: 2.9350697059153197E-6
# Model iJN1463.cmd: 1.973812821124993E-5
# Cycle 81
# Total biomass:
# Model iAF1260.cmd: 2.989209574835024E-6
# Model iJN1463.cmd: 1.991625353629543E-5
# Cycle 82
# Total biomass:
# Model iAF1260.cmd: 3.0445711899803234E-6
# Model iJN1463.cmd: 2.008622699058315E-5
# Cycle 83
# Total biomass:
# Model iAF1260.cmd: 3.0998405675766336E-6
# Model iJN1463.cmd: 2.0263644077547436E-5
# Cycle 84
# Total biomass:
# Model iAF1260.cmd: 3.154378709045395E-6
# Model iJN1463.cmd: 2.043929477797268E-5
# Cycle 85
# Total biomass:
# Model iAF1260.cmd: 3.208931083530239E-6
# Model iJN1463.cmd: 2.0617370554217115E-5
# Cycle 86
# Total biomass:
# Model iAF1260.cmd: 3.264023800905154E-6
# Model iJN1463.cmd: 2.0780754806459693E-5
# Cycle 87
# Total biomass:
# Model iAF1260.cmd: 3.318946383439577E-6
# Model iJN1463.cmd: 2.0949572882664842E-5
# Cycle 88
# Total biomass:
# Model iAF1260.cmd: 3.373671737770368E-6
# Model iJN1463.cmd: 2.1117105111421274E-5
# Cycle 89
# Total biomass:
# Model iAF1260.cmd: 3.4289904339177217E-6
# Model iJN1463.cmd: 2.1283046924525534E-5
# Cycle 90
# Total biomass:
# Model iAF1260.cmd: 3.4835530955935615E-6
# Model iJN1463.cmd: 2.145157546880296E-5
# Cycle 91
# Total biomass:
# Model iAF1260.cmd: 3.539672680327853E-6
# Model iJN1463.cmd: 2.1613386290492315E-5
# Cycle 92
# Total biomass:
# Model iAF1260.cmd: 3.5947418335531092E-6
# Model iJN1463.cmd: 2.178070235628483E-5
# Cycle 93
# Total biomass:
# Model iAF1260.cmd: 3.649575221993594E-6
# Model iJN1463.cmd: 2.1943918312657114E-5
# Cycle 94
# Total biomass:
# Model iAF1260.cmd: 3.7047543167013403E-6
# Model iJN1463.cmd: 2.2108053654026232E-5
# Cycle 95
# Total biomass:
# Model iAF1260.cmd: 3.76035984050651E-6
# Model iJN1463.cmd: 2.226734013005707E-5
# Model iJN1463.cmd: 2.5782768482200308E-5
# Cycle 119
# Total biomass:
# Model iAF1260.cmd: 5.215036144524914E-6
# Model iJN1463.cmd: 2.5927702230117796E-5
# Cycle 120
# Total biomass:
# Model iAF1260.cmd: 5.2801267993367955E-6
# Model iJN1463.cmd: 2.6069599457419197E-5
# Cycle 121
# Total biomass:
# Model iAF1260.cmd: 5.346307282077581E-6
# Model iJN1463.cmd: 2.62150459259053E-5
# Cycle 122
# Total biomass:
# Model iAF1260.cmd: 5.412145883469116E-6
# Model iJN1463.cmd: 2.6360644299785014E-5
# Cycle 123
# Total biomass:
# Model iAF1260.cmd: 5.477089685674891E-6
# Model iJN1463.cmd: 2.6498097259398387E-5
# Cycle 124
# Total biomass:
# Model iAF1260.cmd: 5.541241875994471E-6
# Model iJN1463.cmd: 2.6639249694175655E-5
# Cycle 125
# Total biomass:
# Model iAF1260.cmd: 5.605266493947018E-6
# Model iJN1463.cmd: 2.6784694396516605E-5
# Cycle 126
# Total biomass:
# Model iAF1260.cmd: 5.6704299397480515E-6
# Model iJN1463.cmd: 2.6928704063454158E-5
# Cycle 127
# Total biomass:
# Model iAF1260.cmd: 5.736924365335185E-6
# Model iJN1463.cmd: 2.7070253586435054E-5
# Cycle 128
# Total biomass:
# Model iAF1260.cmd: 5.803121403647241E-6
# Model iJN1463.cmd: 2.7210147835722226E-5
# Cycle 129
# Total biomass:
# Model iAF1260.cmd: 5.8692312521901664E-6
# Model iJN1463.cmd: 2.7350891675283974E-5
# Cycle 130
# Total biomass:
# Model iAF1260.cmd: 5.936433552068958E-6
# Model iJN1463.cmd: 2.748688301171886E-5
# Cycle 131
# Total biomass:
# Model iAF1260.cmd: 6.003530982019006E-6
# Model iJN1463.cmd: 2.7624743753684158E-5
# Cycle 132
# Total biomass:
# Model iAF1260.cmd: 6.071291411927676E-6
# Model iJN1463.cmd: 2.7761060486338273E-5
# Cycle 133
# Total biomass:
# Model iAF1260.cmd: 6.137285628869662E-6
# Model iJN1463.cmd: 2.7903877190199726E-5
# Cycle 134
# Total biomass:
# Model iAF1260.cmd: 6.20156049971794E-6
# Model iJN1463.cmd: 2.8044766473199025E-5
# Cycle 135
# Total biomass:
# Model iAF1260.cmd: 6.267857991983285E-6
# Model iJN1463.cmd: 2.8184983255864705E-5
# Cycle 136
# Total biomass:
# Model iAF1260.cmd: 6.335590262357789E-6
# Model iJN1463.cmd: 2.8322268612742537E-5
# Cycle 137
# Total biomass:
# Model iAF1260.cmd: 6.403304479760464E-6
# Model iJN1463.cmd: 2.845822015591351E-5
# Cycle 138
# Total biomass:
# Model iAF1260.cmd: 6.470037762087728E-6
# Model iJN1463.cmd: 2.8596960060010595E-5
# Cycle 139
# Total biomass:
# Model iAF1260.cmd: 6.538063510641772E-6
# Model iJN1463.cmd: 2.8733242581458797E-5
# Cycle 140
# Total biomass:
# Model iAF1260.cmd: 6.60687081817816E-6
# Model iJN1463.cmd: 2.8864561966436696E-5
# Cycle 141
# Total biomass:
# Model iAF1260.cmd: 6.676503313598401E-6
# Model iJN1463.cmd: 3.462210793489667E-5
# Cycle 188
# Total biomass:
# Model iAF1260.cmd: 1.0228800235760118E-5
# Model iJN1463.cmd: 3.473297759212319E-5
# Cycle 189
# Total biomass:
# Model iAF1260.cmd: 1.0306362833314654E-5
# Model iJN1463.cmd: 3.4847675080863586E-5
# Cycle 190
# Total biomass:
# Model iAF1260.cmd: 1.0386438972638092E-5
# Model iJN1463.cmd: 3.4959154605993794E-5
# Cycle 191
# Total biomass:
# Model iAF1260.cmd: 1.0464351911540922E-5
# Model iJN1463.cmd: 3.507312709346499E-5
# Cycle 192
# Total biomass:
# Model iAF1260.cmd: 1.0542286590539215E-5
# Model iJN1463.cmd: 3.518656730381105E-5
# Cycle 193
# Total biomass:
# Model iAF1260.cmd: 1.0621002358119273E-5
# Model iJN1463.cmd: 3.529910156973348E-5
# Cycle 194
# Total biomass:
# Model iAF1260.cmd: 1.0697065982045527E-5
# Model iJN1463.cmd: 3.5413149071069495E-5
# Cycle 195
# Total biomass:
# Model iAF1260.cmd: 1.0774834224961965E-5
# Model iJN1463.cmd: 3.5524800755345604E-5
# Cycle 196
# Total biomass:
# Model iAF1260.cmd: 1.085250520948292E-5
# Model iJN1463.cmd: 3.563620134052244E-5
# Cycle 197
# Total biomass:
# Model iAF1260.cmd: 1.0931116981525375E-5
# Model iJN1463.cmd: 3.574645795682866E-5
# Cycle 198
# Total biomass:
# Model iAF1260.cmd: 1.1009798441978934E-5
# Model iJN1463.cmd: 3.585612796147788E-5
# Cycle 199
# Total biomass:
# Model iAF1260.cmd: 1.108920785287726E-5
# Model iJN1463.cmd: 3.5965195063249386E-5
# Cycle 200
# Total biomass:
# Model iAF1260.cmd: 1.1168608306579593E-5
# Model iJN1463.cmd: 3.607373943558339E-5
# Cycle 201
# Total biomass:
# Model iAF1260.cmd: 1.124851711075167E-5
# Model iJN1463.cmd: 3.618165130624499E-5
# Cycle 202
# Total biomass:
# Model iAF1260.cmd: 1.1327576048181886E-5
# Model iJN1463.cmd: 3.6289350744208374E-5
# Cycle 203
# Total biomass:
# Model iAF1260.cmd: 1.1408013083763463E-5
# Model iJN1463.cmd: 3.6396938101169494E-5
# Cycle 204
# Total biomass:
# Model iAF1260.cmd: 1.1487738530084381E-5
# Model iJN1463.cmd: 3.650456292260573E-5
# Cycle 205
# Total biomass:
# Model iAF1260.cmd: 1.1567264327392436E-5
# Model iJN1463.cmd: 3.661208280935705E-5
# Cycle 206
# Total biomass:
# Model iAF1260.cmd: 1.1647585817381884E-5
# Model iJN1463.cmd: 3.671895438365338E-5
# Cycle 207
# Total biomass:
# Model iAF1260.cmd: 1.1726921973395715E-5
# Model iJN1463.cmd: 3.682618030100175E-5
# Cycle 208
# Total biomass:
# Model iAF1260.cmd: 1.1806595318214962E-5
# Model iJN1463.cmd: 3.693276567465865E-5
# Cycle 209
# Total biomass:
# Model iAF1260.cmd: 1.1885412584365978E-5
# Model iJN1463.cmd: 3.704033815824459E-5
# Cycle 210
# Total biomass:
# Model iAF1260.cmd: 1.1965989632221984E-5
# Model iJN1463.cmd: 3.714571375304554E-5
# Cycle 211
# Total biomass:
# Model iAF1260.cmd: 1.2048744281063967E-5
# Model iJN1463.cmd: 3.724831764454371E-5
# Cycle 212
# Total biomass:
# Model iAF1260.cmd: 1.213140184189345E-5
# Model iJN1463.cmd: 3.73519656959207E-5
# Cycle 213
# Total biomass:
# Model iAF1260.cmd: 1.2213114445702908E-5
# Model iJN1463.cmd: 3.745633783373885E-5
# Cycle 214
# Total biomass:
# Model iAF1260.cmd: 1.2295205442355468E-5
# Model iJN1463.cmd: 3.755984081059268E-5
# Cycle 215
# Total biomass:
# Model iAF1260.cmd: 1.2376905498479837E-5
# Model iJN1463.cmd: 3.766339479565877E-5
# Cycle 216
# Total biomass:
# Model iAF1260.cmd: 1.2458738423045539E-5
# Model iJN1463.cmd: 3.776638343816947E-5
# Cycle 217
# Total biomass:
# Model iAF1260.cmd: 1.2540917682293273E-5
# Model iJN1463.cmd: 3.786874755685558E-5
# Cycle 218
# Total biomass:
# Model iAF1260.cmd: 1.2623427966425186E-5
# Model iJN1463.cmd: 3.797067429977687E-5
# Cycle 219
# Total biomass:
# Model iAF1260.cmd: 1.2705903787850668E-5
# Model iJN1463.cmd: 3.8072192230569906E-5
# Cycle 220
# Total biomass:
# Model iAF1260.cmd: 1.2788651049065287E-5
# Model iJN1463.cmd: 3.817321542336888E-5
# Cycle 221
# Total biomass:
# Model iAF1260.cmd: 1.2871690691740705E-5
# Model iJN1463.cmd: 3.8273813474580805E-5
# Cycle 222
# Total biomass:
# Model iAF1260.cmd: 1.2954986241955467E-5
# Model iJN1463.cmd: 3.837400952171011E-5
# Cycle 223
# Total biomass:
# Model iAF1260.cmd: 1.3038447923946757E-5
# Model iJN1463.cmd: 3.847379718679908E-5
# Cycle 224
# Total biomass:
# Model iAF1260.cmd: 1.312177531070381E-5
# Model iJN1463.cmd: 3.857363696471077E-5
# Cycle 225
# Total biomass:
# Model iAF1260.cmd: 1.3205172007731099E-5
# Model iJN1463.cmd: 3.8672635859687364E-5
# Cycle 226
# Total biomass:
# Model iAF1260.cmd: 1.3287846280103371E-5
# Model iJN1463.cmd: 3.877197713903785E-5
# Cycle 227
# Total biomass:
# Model iAF1260.cmd: 1.336954317677638E-5
# Model iJN1463.cmd: 3.887179283244094E-5
# Cycle 228
# Total biomass:
# Model iAF1260.cmd: 1.345069417784697E-5
# Model iJN1463.cmd: 3.897183138032238E-5
# Cycle 229
# Total biomass:
# Model iAF1260.cmd: 1.3531332542205118E-5
# Model iJN1463.cmd: 3.907167817569669E-5
# Cycle 230
# Total biomass:
# Model iAF1260.cmd: 1.36118475323675E-5
# Model iJN1463.cmd: 3.9171152371743086E-5
# Cycle 231
# Total biomass:
# Model iAF1260.cmd: 1.3692488250613083E-5
# Model iJN1463.cmd: 3.9270234050934085E-5
# Cycle 232
# Total biomass:
# Model iAF1260.cmd: 1.377314246963105E-5
# Model iJN1463.cmd: 3.9368837966351507E-5
# Model iJN1463.cmd: 4.1483998808440025E-5
# Cycle 256
# Total biomass:
# Model iAF1260.cmd: 1.5801384708571328E-5
# Model iJN1463.cmd: 4.157213753016759E-5
# Cycle 257
# Total biomass:
# Model iAF1260.cmd: 1.58858745766897E-5
# Model iJN1463.cmd: 4.16600390030058E-5
# Cycle 258
# Total biomass:
# Model iAF1260.cmd: 1.5970419129364565E-5
# Model iJN1463.cmd: 4.17477075534829E-5
# Cycle 259
# Total biomass:
# Model iAF1260.cmd: 1.6055067943981216E-5
# Model iJN1463.cmd: 4.183509439965198E-5
# Cycle 260
# Total biomass:
# Model iAF1260.cmd: 1.6139872304217265E-5
# Model iJN1463.cmd: 4.192214846486799E-5
# Cycle 261
# Total biomass:
# Model iAF1260.cmd: 1.62248163603647E-5
# Model iJN1463.cmd: 4.200885310360764E-5
# Cycle 262
# Total biomass:
# Model iAF1260.cmd: 1.6309931584186622E-5
# Model iJN1463.cmd: 4.209520068561184E-5
# Cycle 263
# Total biomass:
# Model iAF1260.cmd: 1.6394825536328092E-5
# Model iJN1463.cmd: 4.2181146502952126E-5
# Cycle 264
# Total biomass:
# Model iAF1260.cmd: 1.6479928379958026E-5
# Model iJN1463.cmd: 4.2266684051105444E-5
# Cycle 265
# Total biomass:
# Model iAF1260.cmd: 1.656517522376381E-5
# Model iJN1463.cmd: 4.235181984455519E-5
# Cycle 266
# Total biomass:
# Model iAF1260.cmd: 1.665047531029014E-5
# Model iJN1463.cmd: 4.2436554769483314E-5
# Cycle 267
# Total biomass:
# Model iAF1260.cmd: 1.673593149932974E-5
# Model iJN1463.cmd: 4.252087765835151E-5
# Cycle 268
# Total biomass:
# Model iAF1260.cmd: 1.6821361124543982E-5
# Model iJN1463.cmd: 4.260477455989844E-5
# Cycle 269
# Total biomass:
# Model iAF1260.cmd: 1.690695298744263E-5
# Model iJN1463.cmd: 4.268823581466273E-5
# Cycle 270
# Total biomass:
# Model iAF1260.cmd: 1.6992574386124366E-5
# Model iJN1463.cmd: 4.277128600162528E-5
# Cycle 271
# Total biomass:
# Model iAF1260.cmd: 1.7078325018219432E-5
# Model iJN1463.cmd: 4.2853924915240145E-5
# Cycle 272
# Total biomass:
# Model iAF1260.cmd: 1.716416184625153E-5
# Model iJN1463.cmd: 4.293614963455794E-5
# Cycle 273
# Total biomass:
# Model iAF1260.cmd: 1.725012851251779E-5
# Model iJN1463.cmd: 4.3017957548154644E-5
# Cycle 274
# Total biomass:
# Model iAF1260.cmd: 1.7336248184317778E-5
# Model iJN1463.cmd: 4.309933508453144E-5
# Cycle 275
# Total biomass:
# Model iAF1260.cmd: 1.7422497517821473E-5
# Model iJN1463.cmd: 4.3180283338567333E-5
# Cycle 276
# Total biomass:
# Model iAF1260.cmd: 1.750885891971631E-5
# Model iJN1463.cmd: 4.326081389472627E-5
# Cycle 277
# Total biomass:
# Model iAF1260.cmd: 1.7595325310203353E-5
# Model iJN1463.cmd: 4.334093032730325E-5
# Cycle 278
# Total biomass:
# Model iAF1260.cmd: 1.76818949041331E-5
# Model iJN1463.cmd: 4.342063597376408E-5
# Cycle 279
# Total biomass:
# Model iAF1260.cmd: 1.7768556111379E-5
# Model iJN1463.cmd: 4.349993988001642E-5
# Cycle 280
# Total biomass:
# Model iAF1260.cmd: 1.785528844433712E-5
# Model iJN1463.cmd: 4.3578859585524744E-5
# Cycle 281
# Total biomass:
# Model iAF1260.cmd: 1.7942090839250346E-5
# Model iJN1463.cmd: 4.3657403003174606E-5
# Cycle 282
# Total biomass:
# Model iAF1260.cmd: 1.8028939159042118E-5
# Model iJN1463.cmd: 4.373556725359666E-5
# Cycle 283
# Total biomass:
# Model iAF1260.cmd: 1.8115839925051933E-5
# Model iJN1463.cmd: 4.381336881048735E-5
# Cycle 284
# Total biomass:
# Model iAF1260.cmd: 1.8202694192585786E-5
# Model iJN1463.cmd: 4.3890826311227736E-5
# Cycle 285
# Total biomass:
# Model iAF1260.cmd: 1.82895709304313E-5
# Model iJN1463.cmd: 4.3967955928107024E-5
# Cycle 286
# Total biomass:
# Model iAF1260.cmd: 1.8376420036677798E-5
# Model iJN1463.cmd: 4.4044760077203495E-5
# Cycle 287
# Total biomass:
# Model iAF1260.cmd: 1.846327808242978E-5
# Model iJN1463.cmd: 4.412124900872522E-5
# Cycle 288
# Total biomass:
# Model iAF1260.cmd: 1.855014218721198E-5
# Model iJN1463.cmd: 4.419742508913634E-5
# Cycle 289
# Total biomass:
# Model iAF1260.cmd: 1.8637010673494184E-5
# Model iJN1463.cmd: 4.427328968998213E-5
# Cycle 290
# Total biomass:
# Model iAF1260.cmd: 1.8723848566040253E-5
# Model iJN1463.cmd: 4.4348835596470756E-5
# Cycle 291
# Total biomass:
# Model iAF1260.cmd: 1.881072895464785E-5
# Model iJN1463.cmd: 4.442406636157811E-5
# Cycle 292
# Total biomass:
# Model iAF1260.cmd: 1.8897462211705774E-5
# Model iJN1463.cmd: 4.449899287290359E-5
# Cycle 293
# Total biomass:
# Model iAF1260.cmd: 1.898418451222542E-5
# Model iJN1463.cmd: 4.4573610399614814E-5
# Cycle 294
# Total biomass:
# Model iAF1260.cmd: 1.9070791685598184E-5
# Model iJN1463.cmd: 4.464791916022989E-5
# Cycle 295
# Total biomass:
# Model iAF1260.cmd: 1.9157351616961204E-5
# Model iJN1463.cmd: 4.472193152602045E-5
# Cycle 296
# Total biomass:
# Model iAF1260.cmd: 1.924384817771758E-5
# Model iJN1463.cmd: 4.47956612783283E-5
# Cycle 297
# Total biomass:
# Model iAF1260.cmd: 1.9330275815278294E-5
# Model iJN1463.cmd: 4.486911252270491E-5
# Cycle 298
# Total biomass:
# Model iAF1260.cmd: 1.9416611345553853E-5
# Model iJN1463.cmd: 4.494230636890872E-5
# Cycle 299
# Total biomass:
# Model iAF1260.cmd: 1.950285077268079E-5
# Model iJN1463.cmd: 4.5015247171406045E-5
# Cycle 300
# Total biomass:
# Model iAF1260.cmd: 1.9588990127412205E-5
# Model iJN1463.cmd: 4.50879353832168E-5
# Cycle 301
# Total biomass:
# Cycle 324
# Total biomass:
# Model iAF1260.cmd: 2.1635201839960688E-5
# Model iJN1463.cmd: 4.6749043874662146E-5
# Cycle 325
# Total biomass:
# Model iAF1260.cmd: 2.1719746695780246E-5
# Model iJN1463.cmd: 4.681491027632482E-5
# Cycle 326
# Total biomass:
# Model iAF1260.cmd: 2.180423190397937E-5
# Model iJN1463.cmd: 4.68805712105741E-5
# Cycle 327
# Total biomass:
# Model iAF1260.cmd: 2.1888673696522E-5
# Model iJN1463.cmd: 4.694599062364653E-5
# Cycle 328
# Total biomass:
# Model iAF1260.cmd: 2.197379208744944E-5
# Model iJN1463.cmd: 4.701061708870046E-5
# Cycle 329
# Total biomass:
# Model iAF1260.cmd: 2.205901997835349E-5
# Model iJN1463.cmd: 4.707492606944775E-5
# Cycle 330
# Total biomass:
# Model iAF1260.cmd: 2.214426936590846E-5
# Model iJN1463.cmd: 4.713895406827592E-5
# Cycle 331
# Total biomass:
# Model iAF1260.cmd: 2.2229503630313743E-5
# Model iJN1463.cmd: 4.7202719416187965E-5
# Cycle 332
# Total biomass:
# Model iAF1260.cmd: 2.2314693828979927E-5
# Model iJN1463.cmd: 4.726624340348218E-5
# Cycle 333
# Total biomass:
# Model iAF1260.cmd: 2.239982334851931E-5
# Model iJN1463.cmd: 4.7329537660281464E-5
# Cycle 334
# Total biomass:
# Model iAF1260.cmd: 2.24848935610807E-5
# Model iJN1463.cmd: 4.739261285723185E-5
# Cycle 335
# Total biomass:
# Model iAF1260.cmd: 2.2569904791770264E-5
# Model iJN1463.cmd: 4.74554740348965E-5
# Cycle 336
# Total biomass:
# Model iAF1260.cmd: 2.26548573873242E-5
# Model iJN1463.cmd: 4.751812323779757E-5
# Cycle 337
# Total biomass:
# Model iAF1260.cmd: 2.2739750259463104E-5
# Model iJN1463.cmd: 4.758056222285958E-5
# Cycle 338
# Total biomass:
# Model iAF1260.cmd: 2.2824581290491097E-5
# Model iJN1463.cmd: 4.7642793571802654E-5
# Cycle 339
# Total biomass:
# Model iAF1260.cmd: 2.2909329382412682E-5
# Model iJN1463.cmd: 4.770482162581589E-5
# Cycle 340
# Total biomass:
# Model iAF1260.cmd: 2.299401511697613E-5
# Model iJN1463.cmd: 4.776665086391012E-5
# Cycle 341
# Total biomass:
# Model iAF1260.cmd: 2.3078639757620454E-5
# Model iJN1463.cmd: 4.782827913295419E-5
# Cycle 342
# Total biomass:
# Model iAF1260.cmd: 2.3163211628455206E-5
# Model iJN1463.cmd: 4.788968967274768E-5
# Cycle 343
# Total biomass:
# Model iAF1260.cmd: 2.3247731580357806E-5
# Model iJN1463.cmd: 4.7950903507479845E-5
# Cycle 344
# Total biomass:
# Model iAF1260.cmd: 2.3332198722363725E-5
# Model iJN1463.cmd: 4.80118955460717E-5
# Cycle 345
# Total biomass:
# Model iAF1260.cmd: 2.3416612656875797E-5
# Model iJN1463.cmd: 4.8072664317475056E-5
# Cycle 346
# Total biomass:
# Model iAF1260.cmd: 2.3500973877679416E-5
# Model iJN1463.cmd: 4.813323252772752E-5
# Cycle 347
# Total biomass:
# Model iAF1260.cmd: 2.3585304363005873E-5
# Model iJN1463.cmd: 4.8193596417661126E-5
# Cycle 348
# Total biomass:
# Model iAF1260.cmd: 2.3669610375044263E-5
# Model iJN1463.cmd: 4.82537606271996E-5
# Cycle 349
# Total biomass:
# Model iAF1260.cmd: 2.375389358494028E-5
# Model iJN1463.cmd: 4.831372656414321E-5
# Cycle 350
# Total biomass:
# Model iAF1260.cmd: 2.3838153544230435E-5
# Model iJN1463.cmd: 4.837349489333377E-5
# Cycle 351
# Total biomass:
# Model iAF1260.cmd: 2.3922409186478746E-5
# Model iJN1463.cmd: 4.843308329655327E-5
# Cycle 352
# Total biomass:
# Model iAF1260.cmd: 2.400666727107096E-5
# Model iJN1463.cmd: 4.8492497704384503E-5
# Cycle 353
# Total biomass:
# Model iAF1260.cmd: 2.4090929011577842E-5
# Model iJN1463.cmd: 4.8551739212351334E-5
# Cycle 354
# Total biomass:
# Model iAF1260.cmd: 2.417519487601012E-5
# Model iJN1463.cmd: 4.861080867868158E-5
# Cycle 355
# Total biomass:
# Model iAF1260.cmd: 2.4259462914508544E-5
# Model iJN1463.cmd: 4.866970616161422E-5
# Cycle 356
# Total biomass:
# Model iAF1260.cmd: 2.4343732857598856E-5
# Model iJN1463.cmd: 4.872843258013774E-5
# Cycle 357
# Total biomass:
# Model iAF1260.cmd: 2.442800578644192E-5
# Model iJN1463.cmd: 4.8786992082737125E-5
# Cycle 358
# Total biomass:
# Model iAF1260.cmd: 2.451227990540693E-5
# Model iJN1463.cmd: 4.884538963397851E-5
# Cycle 359
# Total biomass:
# Model iAF1260.cmd: 2.4596538254886635E-5
# Model iJN1463.cmd: 4.8903615623941143E-5
# Cycle 360
# Total biomass:
# Model iAF1260.cmd: 2.468077860785057E-5
# Model iJN1463.cmd: 4.896165944759617E-5
# Cycle 361
# Total biomass:
# Model iAF1260.cmd: 2.4765001430206594E-5
# Model iJN1463.cmd: 4.9019515292087245E-5
# Cycle 362
# Total biomass:
# Model iAF1260.cmd: 2.4849206497178395E-5
# Model iJN1463.cmd: 4.9077181164888095E-5
# Cycle 363
# Total biomass:
# Model iAF1260.cmd: 2.493339230764013E-5
# Model iJN1463.cmd: 4.913468184371313E-5
# Cycle 364
# Total biomass:
# Model iAF1260.cmd: 2.5017554668939954E-5
# Model iJN1463.cmd: 4.919199633275934E-5
# Cycle 365
# Total biomass:
# Model iAF1260.cmd: 2.510169080674366E-5
# Model iJN1463.cmd: 4.924912563798272E-5
# Cycle 366
# Total biomass:
# Model iAF1260.cmd: 2.518578684677171E-5
# Model iJN1463.cmd: 4.9306081424465666E-5
# Cycle 367
# Total biomass:
# Model iAF1260.cmd: 2.5269849278529286E-5
# Model iJN1463.cmd: 4.936288562320384E-5
# Cycle 368
# Total biomass:
# Model iAF1260.cmd: 2.5353881330750624E-5
# Model iJN1463.cmd: 4.941954367933156E-5
# Cycle 369
# Total biomass:
# Model iAF1260.cmd: 2.5437878631268108E-5
# Model iJN1463.cmd: 4.947606225620077E-5
# Cycle 370
# Total biomass:
# Model iAF1260.cmd: 2.552182322487905E-5
# Model iJN1463.cmd: 4.953245691510714E-5
# Cycle 371
# Total biomass:
# Model iAF1260.cmd: 2.5605724142793614E-5
# Model iJN1463.cmd: 4.958873834885887E-5
# Cycle 372
# Total biomass:
# Model iAF1260.cmd: 2.5689594310177965E-5
# Model iJN1463.cmd: 4.9644917701794765E-5
# Cycle 373
# Total biomass:
# Model iAF1260.cmd: 2.5773436884198837E-5
# Model iJN1463.cmd: 4.970099755111199E-5
# Cycle 374
# Total biomass:
# Model iAF1260.cmd: 2.5857252764199236E-5
# Model iJN1463.cmd: 4.975697878693639E-5
# Cycle 375
# Total biomass:
# Model iAF1260.cmd: 2.5941043807362E-5
# Model iJN1463.cmd: 4.981286404888657E-5
# Cycle 376
# Total biomass:
# Model iAF1260.cmd: 2.602481803337586E-5
# Model iJN1463.cmd: 4.986862911766732E-5
# Cycle 377
# Total biomass:
# Model iAF1260.cmd: 2.6108587292944143E-5
# Model iJN1463.cmd: 4.9924245872508224E-5
# Cycle 378
# Total biomass:
# Model iAF1260.cmd: 2.619235087561263E-5
# Model iJN1463.cmd: 4.9979711872454976E-5
# Cycle 379
# Total biomass:
# Model iAF1260.cmd: 2.627610777678988E-5
# Model iJN1463.cmd: 5.003502721154356E-5
# Cycle 380
# Total biomass:
# Model iAF1260.cmd: 2.635983895598716E-5
# Model iJN1463.cmd: 5.00901861493009E-5
# Cycle 381
# Total biomass:
# Model iAF1260.cmd: 2.6443527024361683E-5
# Model iJN1463.cmd: 5.014518857702575E-5
# Cycle 382
# Total biomass:
# Model iAF1260.cmd: 2.6527168445754383E-5
# Model iJN1463.cmd: 5.0200032733687926E-5
# Cycle 383
# Total biomass:
# Model iAF1260.cmd: 2.661076183655185E-5
# Model iJN1463.cmd: 5.025471818832125E-5
# Cycle 384
# Total biomass:
# Model iAF1260.cmd: 2.6694307114948184E-5
# Model iJN1463.cmd: 5.030924588139578E-5
# Cycle 385
# Total biomass:
# Model iAF1260.cmd: 2.677780628153551E-5
# Model iJN1463.cmd: 5.036362042615556E-5
# Cycle 386
# Total biomass:
# Model iAF1260.cmd: 2.686128158312645E-5
# Model iJN1463.cmd: 5.041784370934977E-5
# Cycle 387
# Total biomass:
# Model iAF1260.cmd: 2.6944707785683946E-5
# Model iJN1463.cmd: 5.047191496249494E-5
# Cycle 388
# Total biomass:
# Model iAF1260.cmd: 2.702808364050983E-5
# Model iJN1463.cmd: 5.052583588380765E-5
# Cycle 389
# Total biomass:
# Model iAF1260.cmd: 2.7111408255299557E-5
# Model iJN1463.cmd: 5.057960759221992E-5
# Cycle 390
# Total biomass:
# Model iAF1260.cmd: 2.7194681351637397E-5
# Model iJN1463.cmd: 5.06332301739573E-5
# Cycle 391
# Total biomass:
# Model iAF1260.cmd: 2.727790284539499E-5
# Model iJN1463.cmd: 5.068670398388384E-5
# Cycle 392
# Total biomass:
# Model iAF1260.cmd: 2.7361072704045456E-5
# Model iJN1463.cmd: 5.0740029442503704E-5
# Cycle 393
# Total biomass:
# Model iAF1260.cmd: 2.744419056635978E-5
# Model iJN1463.cmd: 5.0793206932488085E-5
# Cycle 394
# Total biomass:
# Model iAF1260.cmd: 2.752725672245811E-5
# ...
# Model iJN1463.cmd: 6.581071870170157E-5
# Cycle 850
# Total biomass:
# Model iAF1260.cmd: 5.096413847620383E-5
# Model iJN1463.cmd: 6.582737502187959E-5
# Cycle 851
# Total biomass:
# Model iAF1260.cmd: 5.099613719563902E-5
# Model iJN1463.cmd: 6.584402312198342E-5
# Cycle 852
# Total biomass:
# Model iAF1260.cmd: 5.102809925613769E-5
# Model iJN1463.cmd: 6.586063107360586E-5
# Cycle 853
# Total biomass:
# Model iAF1260.cmd: 5.1059994918907995E-5
# Model iJN1463.cmd: 6.587720187203281E-5
# Cycle 854
# Total biomass:
# Model iAF1260.cmd: 5.1091817927584524E-5
# Model iJN1463.cmd: 6.589372721212585E-5
# Cycle 855
# Total biomass:
# Model iAF1260.cmd: 5.1122842251418995E-5
# Model iJN1463.cmd: 6.590987333360726E-5
# Cycle 856
# Total biomass:
# Model iAF1260.cmd: 5.1152039483286196E-5
# Model iJN1463.cmd: 6.592293838488534E-5
# Cycle 857
# Total biomass:
# Model iAF1260.cmd: 5.117937752842852E-5
# Model iJN1463.cmd: 6.593379762478966E-5
# Cycle 858
# Total biomass:
# Model iAF1260.cmd: 5.120618767692627E-5
# Model iJN1463.cmd: 6.594384769700061E-5
# Cycle 859
# Total biomass:
# Model iAF1260.cmd: 5.1232794636873826E-5
# Model iJN1463.cmd: 6.595361324462415E-5
# Cycle 860
# Total biomass:
# Model iAF1260.cmd: 5.1259358293371885E-5
# Model iJN1463.cmd: 6.596315768462991E-5
# Cycle 861
# Total biomass:
# Model iAF1260.cmd: 5.128589013865031E-5
# Model iJN1463.cmd: 6.597289858213047E-5
# Cycle 862
# Total biomass:
# Model iAF1260.cmd: 5.131465611136947E-5
# Model iJN1463.cmd: 6.598358590221065E-5
# Cycle 863
# Total biomass:
# Model iAF1260.cmd: 5.13455854132711E-5
# Model iJN1463.cmd: 6.59954734709328E-5
# Cycle 864
# Total biomass:
# Model iAF1260.cmd: 5.137625408783662E-5
# Model iJN1463.cmd: 6.600725686841828E-5
# Cycle 865
# Total biomass:
# Model iAF1260.cmd: 5.140837463893804E-5
# Model iJN1463.cmd: 6.602059236821604E-5
# Cycle 866
# Total biomass:
# Model iAF1260.cmd: 5.1439696981099314E-5
# Model iJN1463.cmd: 6.603358091427016E-5
# Cycle 867
# Total biomass:
# Model iAF1260.cmd: 5.147004173841942E-5
# Model iJN1463.cmd: 6.604793224832725E-5
# Cycle 868
# Total biomass:
# Model iAF1260.cmd: 5.149823271966867E-5
# Model iJN1463.cmd: 6.605864164180907E-5
# Cycle 869
# Total biomass:
# Model iAF1260.cmd: 5.152479091295018E-5
# Model iJN1463.cmd: 6.606839208190616E-5
# Cycle 870
# Total biomass:
# Model iAF1260.cmd: 5.155117420800586E-5
# Model iJN1463.cmd: 6.607785082810203E-5
# Cycle 871
# Total biomass:
# Model iAF1260.cmd: 5.1577222332951445E-5
# Model iJN1463.cmd: 6.608721286230476E-5
# Cycle 872
# Total biomass:
# Model iAF1260.cmd: 5.1603019855686865E-5
# Model iJN1463.cmd: 6.609634794073089E-5
# Cycle 873
# Total biomass:
# Model iAF1260.cmd: 5.162875402315455E-5
# Model iJN1463.cmd: 6.610581905973746E-5
# Cycle 874
# Total biomass:
# Model iAF1260.cmd: 5.165682535479904E-5
# Model iJN1463.cmd: 6.61161336624018E-5
# Cycle 875
# Total biomass:
# Model iAF1260.cmd: 5.168708310537223E-5
# Model iJN1463.cmd: 6.61276313748462E-5
# Cycle 876
# Total biomass:
# Model iAF1260.cmd: 5.171709268078393E-5
# Model iJN1463.cmd: 6.613901752250553E-5
# Cycle 877
# Total biomass:
# Model iAF1260.cmd: 5.174849459922491E-5
# Model iJN1463.cmd: 6.615191030256836E-5
# Cycle 878
# Total biomass:
# Model iAF1260.cmd: 5.17791084089275E-5
# Model iJN1463.cmd: 6.616445281819318E-5
# Cycle 879
# Total biomass:
# Model iAF1260.cmd: 5.1806569592568815E-5
# Model iJN1463.cmd: 6.617430721510696E-5
# Cycle 880
# Total biomass:
# Model iAF1260.cmd: 5.183292771145042E-5
# Model iJN1463.cmd: 6.618355061378258E-5
# Cycle 881
# Total biomass:
# Model iAF1260.cmd: 5.1858656727819984E-5
# Model iJN1463.cmd: 6.61926766815232E-5
# Cycle 882
# Total biomass:
# Model iAF1260.cmd: 5.188407969374124E-5
# Model iJN1463.cmd: 6.620164898533123E-5
# Cycle 883
# Total biomass:
# Model iAF1260.cmd: 5.190941167080404E-5
# Model iJN1463.cmd: 6.621084066973665E-5
# Cycle 884
# Total biomass:
# Model iAF1260.cmd: 5.193870437928217E-5
# Model iJN1463.cmd: 6.622177793557666E-5
# Cycle 885
# Total biomass:
# Model iAF1260.cmd: 5.196878554782364E-5
# Model iJN1463.cmd: 6.623311277279178E-5
# Cycle 886
# Total biomass:
# Model iAF1260.cmd: 5.199839104122166E-5
# Model iJN1463.cmd: 6.624423144667174E-5
# Cycle 887
# Total biomass:
# Model iAF1260.cmd: 5.2029335560116504E-5
# Model iJN1463.cmd: 6.625680242627618E-5
# Cycle 888
# Total biomass:
# Model iAF1260.cmd: 5.2058629086967965E-5
# Model iJN1463.cmd: 6.626877657743113E-5
# Cycle 889
# Total biomass:
# Model iAF1260.cmd: 5.208542532668759E-5
# Model iJN1463.cmd: 6.627822426379057E-5
# Cycle 890
# Total biomass:
# Model iAF1260.cmd: 5.211134965895495E-5
# Model iJN1463.cmd: 6.628720558203581E-5
# Cycle 891
# Total biomass:
# Model iAF1260.cmd: 5.2136772289305596E-5
# Model iJN1463.cmd: 6.629609014016026E-5
# Cycle 892
# Total biomass:
# Model iAF1260.cmd: 5.216181928918265E-5
# Model iJN1463.cmd: 6.6304837525677E-5
# Cycle 893
# Total biomass:
# Model iAF1260.cmd: 5.2186229717052344E-5
# Model iJN1463.cmd: 6.631353902468357E-5
# Cycle 894
# Total biomass:
# Model iAF1260.cmd: 5.2213242364855984E-5
# Model iJN1463.cmd: 6.632354378375749E-5
# Cycle 895
# Total biomass:
# Model iAF1260.cmd: 5.2241707900002536E-5
# Model iJN1463.cmd: 6.633391872454086E-5
# Cycle 896
# Total biomass:
# Model iAF1260.cmd: 5.227059245224945E-5
# Model iJN1463.cmd: 6.634463623959867E-5
# Cycle 897
# Total biomass:
# Model iAF1260.cmd: 5.2299198192470724E-5
# Model iJN1463.cmd: 6.63553529882439E-5
# Cycle 898
# Total biomass:
# Model iAF1260.cmd: 5.232873463808127E-5
# Model iJN1463.cmd: 6.636712437695205E-5
# Cycle 899
# Total biomass:
# Model iAF1260.cmd: 5.236124190206564E-5
# Model iJN1463.cmd: 6.638167150377583E-5
# Cycle 900
# Total biomass:
# Model iAF1260.cmd: 5.239160995236454E-5
# Model iJN1463.cmd: 6.639599075269782E-5
# Cycle 901
# Total biomass:
# Model iAF1260.cmd: 5.2420907808412504E-5
# Model iJN1463.cmd: 6.641035442619547E-5
# Cycle 902
# Total biomass:
# Model iAF1260.cmd: 5.24498538417015E-5
# Model iJN1463.cmd: 6.642480278464867E-5
# Cycle 903
# Total biomass:
# Model iAF1260.cmd: 5.2478646918605634E-5
# Model iJN1463.cmd: 6.643925427918798E-5
# Cycle 904
# Total biomass:
# Model iAF1260.cmd: 5.250734890985892E-5
# Model iJN1463.cmd: 6.645368548714451E-5
# Cycle 905
# Total biomass:
# Model iAF1260.cmd: 5.2535980002133986E-5
# Model iJN1463.cmd: 6.64680842626351E-5
# Cycle 906
# Total biomass:
# Model iAF1260.cmd: 5.256454816526805E-5
# Model iJN1463.cmd: 6.648244675358196E-5
# Cycle 907
# Total biomass:
# Model iAF1260.cmd: 5.2593056615206836E-5
# Model iJN1463.cmd: 6.649677147578052E-5
# Cycle 908
# Total biomass:
# Model iAF1260.cmd: 5.2621506581867325E-5
# Model iJN1463.cmd: 6.651105785282617E-5
# Cycle 909
# Total biomass:
# Model iAF1260.cmd: 5.264989849275747E-5
# Model iJN1463.cmd: 6.652530575110199E-5
# Cycle 910
# Total biomass:
# Model iAF1260.cmd: 5.267823227958217E-5
# Model iJN1463.cmd: 6.653951532023709E-5
# Cycle 911
# Total biomass:
# Model iAF1260.cmd: 5.2706508241504024E-5
# Model iJN1463.cmd: 6.655368630138256E-5
# Cycle 912
# Total biomass:
# Model iAF1260.cmd: 5.2734725438057526E-5
# Model iJN1463.cmd: 6.656781890565596E-5
# Cycle 913
# Total biomass:
# Model iAF1260.cmd: 5.276412369028358E-5
# Model iJN1463.cmd: 6.658330967624086E-5
# Cycle 914
# Total biomass:
# Model iAF1260.cmd: 5.279015497032496E-5
# Model iJN1463.cmd: 6.659332343885455E-5
# Cycle 915
# Total biomass:
# Model iAF1260.cmd: 5.281530911384012E-5
# Model iJN1463.cmd: 6.660207520621297E-5
# Cycle 916
# Total biomass:
# Model iAF1260.cmd: 5.2839735966965546E-5
# Model iJN1463.cmd: 6.661050606090729E-5
# Cycle 917
# Total biomass:
# Model iAF1260.cmd: 5.2863909645841126E-5
# Model iJN1463.cmd: 6.661872193538931E-5
# Cycle 918
# Total biomass:
# Model iAF1260.cmd: 5.2887826429693183E-5
# Model iJN1463.cmd: 6.662709005966797E-5
# Cycle 919
# Total biomass:
# Model iAF1260.cmd: 5.2913695242617884E-5
# Model iJN1463.cmd: 6.663613190877332E-5
# Cycle 920
# Total biomass:
# Model iAF1260.cmd: 5.294019414108536E-5
# Model iJN1463.cmd: 6.664532809201913E-5
# Cycle 921
# Total biomass:
# Model iAF1260.cmd: 5.296973817101847E-5
# Model iJN1463.cmd: 6.665700971165541E-5
# Cycle 922
# Total biomass:
# Model iAF1260.cmd: 5.3000811844889635E-5
# Model iJN1463.cmd: 6.667366786586522E-5
# Cycle 923
# Total biomass:
# Model iAF1260.cmd: 5.3033399761233955E-5
# Model iJN1463.cmd: 6.668939876770227E-5
# Cycle 924
# Total biomass:
# Model iAF1260.cmd: 5.3065643986400184E-5
# Model iJN1463.cmd: 6.670578774990245E-5
# Cycle 925
# Total biomass:
# Model iAF1260.cmd: 5.309712420568184E-5
# Model iJN1463.cmd: 6.672303907001601E-5
# Cycle 926
# Total biomass:
# Model iAF1260.cmd: 5.3126126873485424E-5
# Model iJN1463.cmd: 6.67372332787486E-5
# Cycle 927
# Total biomass:
# Model iAF1260.cmd: 5.315391050651874E-5
# Model iJN1463.cmd: 6.67509001315691E-5
# Cycle 928
# Total biomass:
# Model iAF1260.cmd: 5.3180895210315906E-5
# Model iJN1463.cmd: 6.676728657734949E-5
# Cycle 929
# Total biomass:
# Model iAF1260.cmd: 5.320845455017193E-5
# Model iJN1463.cmd: 6.678290257657035E-5
# Cycle 930
# Total biomass:
# Model iAF1260.cmd: 5.3238212407826084E-5
# Model iJN1463.cmd: 6.680295172755839E-5
# Cycle 931
# Total biomass:
# Model iAF1260.cmd: 5.326673735694866E-5
# Model iJN1463.cmd: 6.68174872501807E-5
# Cycle 932
# Total biomass:
# Model iAF1260.cmd: 5.3294166004069386E-5
# Model iJN1463.cmd: 6.683112692992585E-5
# Cycle 933
# Total biomass:
# Model iAF1260.cmd: 5.332326703747981E-5
# Model iJN1463.cmd: 6.685181705999818E-5
# Cycle 934
# Total biomass:
# Model iAF1260.cmd: 5.335239343573828E-5
# Model iJN1463.cmd: 6.687555192721491E-5
# Cycle 935
# Total biomass:
# Model iAF1260.cmd: 5.338360533839437E-5
# Model iJN1463.cmd: 6.689548384436673E-5
# Cycle 936
# Total biomass:
# Model iAF1260.cmd: 5.3413929611653496E-5
# Model iJN1463.cmd: 6.691633280320517E-5
# Cycle 937
# Total biomass:
# Model iAF1260.cmd: 5.34436587205937E-5
# Model iJN1463.cmd: 6.693855678976938E-5
# Cycle 938
# Total biomass:
# Model iAF1260.cmd: 5.3472216046797706E-5
# Model iJN1463.cmd: 6.695336642493206E-5
# Cycle 939
# Total biomass:
# Model iAF1260.cmd: 5.349940369667945E-5
# Model iJN1463.cmd: 6.696690556288676E-5
# Cycle 940
# Total biomass:
# Model iAF1260.cmd: 5.352590900156195E-5
# Model iJN1463.cmd: 6.698292199203878E-5
# Cycle 941
# Total biomass:
# Model iAF1260.cmd: 5.355277928433752E-5
# Model iJN1463.cmd: 6.699659390021004E-5
# Cycle 942
# Total biomass:
# Model iAF1260.cmd: 5.3579456193509526E-5
# Model iJN1463.cmd: 6.700982673026036E-5
# Cycle 943
# Total biomass:
# Model iAF1260.cmd: 5.360605725358632E-5
# Model iJN1463.cmd: 6.702291435013445E-5
# Cycle 944
# Total biomass:
# Model iAF1260.cmd: 5.363379026424046E-5
# Model iJN1463.cmd: 6.704559498356511E-5
# Cycle 945
# Total biomass:
# Model iAF1260.cmd: 5.366153451209206E-5
# Model iJN1463.cmd: 6.7060116022182E-5
# Cycle 946
# Total biomass:
# Model iAF1260.cmd: 5.36882242303881E-5
# Model iJN1463.cmd: 6.707339924474725E-5
# Cycle 947
# Total biomass:
# Model iAF1260.cmd: 5.371471242542402E-5
# Model iJN1463.cmd: 6.708641956953531E-5
# Cycle 948
# Total biomass:
# Model iAF1260.cmd: 5.3741093226019656E-5
# Model iJN1463.cmd: 6.709932843597113E-5
# Cycle 949
# Total biomass:
# Model iAF1260.cmd: 5.376745827308565E-5
# Model iJN1463.cmd: 6.711217986737535E-5
# Cycle 950
# Total biomass:
# Model iAF1260.cmd: 5.3795104813645816E-5
# Model iJN1463.cmd: 6.713454828569293E-5
# Cycle 951
# Total biomass:
# Model iAF1260.cmd: 5.3821522173347895E-5
# Model iJN1463.cmd: 6.715312856787363E-5
# Cycle 952
# Total biomass:
# Model iAF1260.cmd: 5.384942059378778E-5
# Model iJN1463.cmd: 6.717720551299102E-5
# Cycle 953
# Total biomass:
# Model iAF1260.cmd: 5.3875934118138955E-5
# Model iJN1463.cmd: 6.719626958920438E-5
# Cycle 954
# Total biomass:
# Model iAF1260.cmd: 5.390425277395044E-5
# Model iJN1463.cmd: 6.721899374418168E-5
# Cycle 955
# Total biomass:
# Model iAF1260.cmd: 5.3931028493469034E-5
# Model iJN1463.cmd: 6.723493170271468E-5
# Cycle 956
# Total biomass:
# Model iAF1260.cmd: 5.395724525252381E-5
# Model iJN1463.cmd: 6.724832494698541E-5
# Cycle 957
# Total biomass:
# Model iAF1260.cmd: 5.398511360539368E-5
# Model iJN1463.cmd: 6.726925528256944E-5
# Cycle 958
# Total biomass:
# Model iAF1260.cmd: 5.4011501881041576E-5
# Model iJN1463.cmd: 6.728459249501806E-5
# Cycle 959
# Total biomass:
# Model iAF1260.cmd: 5.403758505596601E-5
# Model iJN1463.cmd: 6.7297738409216E-5
# Cycle 960
# Total biomass:
# Model iAF1260.cmd: 5.4063197754971714E-5
# Model iJN1463.cmd: 6.731300943486155E-5
# Cycle 961
# Total biomass:
# Model iAF1260.cmd: 5.408913499109365E-5
# Model iJN1463.cmd: 6.732609698828444E-5
# Cycle 962
# Total biomass:
# Model iAF1260.cmd: 5.411478738542928E-5
# Model iJN1463.cmd: 6.734444723571583E-5
# Cycle 963
# Total biomass:
# Model iAF1260.cmd: 5.4142414442676444E-5
# Model iJN1463.cmd: 6.736794086821595E-5
# Cycle 964
# Total biomass:
# Model iAF1260.cmd: 5.4171054779222344E-5
# Model iJN1463.cmd: 6.739109320410914E-5
# Cycle 965
# Total biomass:
# Model iAF1260.cmd: 5.419985101673752E-5
# Model iJN1463.cmd: 6.74141384405744E-5
# Cycle 966
# Total biomass:
# Model iAF1260.cmd: 5.42286782061128E-5
# Model iJN1463.cmd: 6.743710925215138E-5
# Cycle 967
# Total biomass:
# Model iAF1260.cmd: 5.425750792712809E-5
# Model iJN1463.cmd: 6.746001410070973E-5
# Cycle 968
# Total biomass:
# Model iAF1260.cmd: 5.428632629862661E-5
# Model iJN1463.cmd: 6.748285545831493E-5
# Cycle 969
# Total biomass:
# Model iAF1260.cmd: 5.43151307077598E-5
# Model iJN1463.cmd: 6.750563039470056E-5
# Cycle 970
# Total biomass:
# Model iAF1260.cmd: 5.434391883643002E-5
# Model iJN1463.cmd: 6.752833887039101E-5
# Cycle 971
# Total biomass:
# Model iAF1260.cmd: 5.4372691083410164E-5
# Model iJN1463.cmd: 6.755098061680284E-5
# Cycle 972
# Total biomass:
# Model iAF1260.cmd: 5.440144644212636E-5
# Model iJN1463.cmd: 6.757355561423105E-5
# Cycle 973
# Total biomass:
# Model iAF1260.cmd: 5.4430184862121995E-5
# Model iJN1463.cmd: 6.759606389618879E-5
# Cycle 974
# Total biomass:
# Model iAF1260.cmd: 5.445841250245442E-5
# Model iJN1463.cmd: 6.761991032486737E-5
# Cycle 975
# Total biomass:
# Model iAF1260.cmd: 5.4486697327816116E-5
# Model iJN1463.cmd: 6.764400997566548E-5
# Cycle 976
# Total biomass:
# Model iAF1260.cmd: 5.45149877717311E-5
# Model iJN1463.cmd: 6.766812707906437E-5
# Cycle 977
# Total biomass:
# Model iAF1260.cmd: 5.4543274202506874E-5
# Model iJN1463.cmd: 6.769220293000809E-5
# Cycle 978
# Total biomass:
# Model iAF1260.cmd: 5.45715604336873E-5
# Model iJN1463.cmd: 6.771622418786657E-5
# Cycle 979
# Total biomass:
# Model iAF1260.cmd: 5.459981675123682E-5
# Model iJN1463.cmd: 6.774019166538601E-5
# Cycle 980
# Total biomass:
# Model iAF1260.cmd: 5.46280689861311E-5
# Model iJN1463.cmd: 6.776409721297303E-5
# Cycle 981
# Total biomass:
# Model iAF1260.cmd: 5.465628858090468E-5
# Model iJN1463.cmd: 6.778794771277677E-5
# Cycle 982
# Total biomass:
# Model iAF1260.cmd: 5.4684503887291715E-5
# Model iJN1463.cmd: 6.781173587221308E-5
# Cycle 983
# Total biomass:
# Model iAF1260.cmd: 5.471269892185181E-5
# Model iJN1463.cmd: 6.783546930143768E-5
# Cycle 984
# Total biomass:
# Model iAF1260.cmd: 5.4739328296079394E-5
# Model iJN1463.cmd: 6.784924720966774E-5
# Cycle 985
# Total biomass:
# Model iAF1260.cmd: 5.476452762670194E-5
# Model iJN1463.cmd: 6.786141707800545E-5
# Cycle 986
# Total biomass:
# Model iAF1260.cmd: 5.4791528504827044E-5
# Model iJN1463.cmd: 6.788215498456663E-5
# Cycle 987
# Total biomass:
# Model iAF1260.cmd: 5.481693758714261E-5
# Model iJN1463.cmd: 6.789934155252619E-5
# Cycle 988
# Total biomass:
# Model iAF1260.cmd: 5.484153163752358E-5
# Model iJN1463.cmd: 6.791352306622347E-5
# Cycle 989
# Total biomass:
# Model iAF1260.cmd: 5.4866221470152655E-5
# Model iJN1463.cmd: 6.79257678547844E-5
# Cycle 990
# Total biomass:
# Model iAF1260.cmd: 5.489306519962245E-5
# Model iJN1463.cmd: 6.794639037328444E-5
# Cycle 991
# Total biomass:
# Model iAF1260.cmd: 5.491880740303619E-5
# Model iJN1463.cmd: 6.795934441440543E-5
# Cycle 992
# Total biomass:
# Model iAF1260.cmd: 5.494351623606129E-5
# Model iJN1463.cmd: 6.797114384695192E-5
# Cycle 993
# Total biomass:
# Model iAF1260.cmd: 5.496801082444034E-5
# Model iJN1463.cmd: 6.798269929777476E-5
# Cycle 994
# Total biomass:
# Model iAF1260.cmd: 5.4992394788414977E-5
# Model iJN1463.cmd: 6.799414774676888E-5
# Cycle 995
# Total biomass:
# Model iAF1260.cmd: 5.5016856296126186E-5
# Model iJN1463.cmd: 6.800786834135233E-5
# Cycle 996
# Total biomass:
# Model iAF1260.cmd: 5.504364934536319E-5
# Model iJN1463.cmd: 6.802866270344058E-5
# Cycle 997
# Total biomass:
# Model iAF1260.cmd: 5.50700654544144E-5
# Model iJN1463.cmd: 6.804820767488465E-5
# Cycle 998
# Total biomass:
# Model iAF1260.cmd: 5.50975125404875E-5
# Model iJN1463.cmd: 6.807047557052882E-5
# Cycle 999
# Total biomass:
# Model iAF1260.cmd: 5.512514700009587E-5
# Model iJN1463.cmd: 6.809325571999942E-5
# Cycle 1000
# Total biomass:
# Model iAF1260.cmd: 5.515295652299451E-5
# Model iJN1463.cmd: 6.81160516838314E-5
# Cycle 1001
# End of simulation
# Total time = 11523.525s
#
# STDERR empty.

# %% [markdown]
# Para revisar la biomasa total

# %%
sim.total_biomass.plot(x = "cycle")
# Out:
# <AxesSubplot:xlabel='cycle'>

# %% [markdown]
# Graficamos los resultados de biomasa y demás metabolitos interesantes en el grid:

# %%
im = sim.get_biomass_image('iAF1260', params.all_params['maxCycles'])
im2 = sim.get_biomass_image('iJN1463',params.all_params['maxCycles'])

final = np.zeros((grid_size,grid_size,3))
final[:,:,0] = im / np.max(im)
final[:,:,1] = im2 / np.max(im2)
for rock in rock_locs:
    final[rock[0],rock[1],0:3] = 0.4 
from matplotlib import pyplot as plt
ﬁg, ax = plt.subplots(ﬁgsize = (3.1, 3.1))
ax.imshow(ﬁnal)
plt.imshow(final)

# %%
plt.imshow(sim.get_metabolite_image("succ_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("ac_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("nh4_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("o2_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("catechol_e",params.all_params['maxCycles']))
