# %% [markdown]
# **Soil-air interface.**
#
# Using the functionality of COMETS, one can design simulations which go beyond in silico corollaries of lab experiments to make predictions for environments mimicking natural ecosystems, which is a necessary step for understanding natural ecology from first principles. In this example, we consider a simulation of a soil environment. We use source-and-sink functions to model how a root provides organic acids to the environment while removing ammonia (Huang et al 2014 Botany). While we restrict the root functionality to a source/sink, one could use functionality demonstrated above, for example extracellular enzymes, to generate feedback loops between microbe-produced metabolites and root exudation. We use fixed metabolite concentrations to mimic the largely unchanging air interface above a root, which generates an oxygen gradient. Additionally, since soil is characterized by strong spatial structure with many impenetrable barriers that localized interactions (Nunan 2017), we place “rock” barriers throughout the simulation area. A more complex simulation could use varying diffusion constants for metabolites, as described in a previous protocol (Virtual Petri Dish). Similarly, we use standard diffusion of biomass, but this could be changed to use pushing force or non-linear diffusion for a potentially increased realism.

# %%
import cobra 
import sys 
import copy 
import numpy as np 
from matplotlib import pyplot as plt 
import cometspy as c

# %% [markdown]
# Para nuestro proyecto, utilizaremos Escherichia coli (modelo iAF1260), Pseudomonas putida (modelo iJN1463) y Saccharomyces Cerevisiae (modelo iMM904), recuperados de la base de datos BIGG.
#
# Cambiamos los bounds de las funciones objetivo de los modelos:

# %%
model_dir = "./modelos" # model location
iAF = cobra.io.read_sbml_model(model_dir + '/iAF1260.xml')
iJN = cobra.io.read_sbml_model(model_dir + '/iJN1463.xml')

iAF.reactions.get_by_id('BIOMASS_Ec_iAF1260_core_59p81M').lower_bound = 0
iAF.reactions.get_by_id('BIOMASS_Ec_iAF1260_core_59p81M').upper_bound = 1000

iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').lower_bound = 0
iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').upper_bound = 1000

# %% [markdown]
# Luego se convierten estos modelos al formato de COMETS. Se utilizan funciones helper para dos cosas: a) Asegurar que el modelo en COMETS no confunda las reacciones de "sink" con las de exchange, ya que en COBRA están desbalanceadas y por tanto se parecen a las de exchange, y b) abrir todos los bounds de las reacciones de exchange, para que COMETS controle la composición del medio.

# %%
iAF_comets = c.model(iAF)
iAF_comets.ensure_sinks_are_not_exchanges()
iAF_comets.open_exchanges()

iJN_comets = c.model(iJN)
iJN_comets.ensure_sinks_are_not_exchanges()
iJN_comets.open_exchanges()

# %% [markdown]
# El mundo que se simulará tendrá dimensiones de 30x30. El eje de la izquierda (x = 0) corresponde a la raíz, y el eje superior (y = 0) corresponde al aire. La biomasa y las rocas se distribuyen en el resto del grid. Donde hayan rocas no puede haber ni biomasa ni metabolitos, así que seleccionamos esos lugares primero. Para esta simulación, se generarán 3 rocas con un un tamaño medio de 1 cuadraditos. Para generar las piedras se utiliza la función helper grow_rocks.

# %%
from cometspy.utils import grow_rocks, pick_random_locations

grid_size = 15 # 100
n_rocks = 27 # 70
rock_locs = grow_rocks(n = n_rocks, xrange = [1,grid_size-1],yrange = [1,grid_size-1],mean_size = 1)

# %% [markdown]
# Cada especie será plantada en 20 lugares sin sobreponerse. Para esto se utiliza la función helper pick_random_locations, la cual toma como argumento una tupla generada anteriormente que marca lugares "prohibidos", como los cuadrados donde se encuentran las rocas.
#
# Generamos una copia de rock_locs para no cambiarla accidentalmente, y la llamamos forbbiden_locs:

# %%
import copy
forbidden_locs = copy.deepcopy(rock_locs)

# %% [markdown]
# Ahora elegimos al azar los lugares para cada especie, y los vamos añadiendo a la lista forbidden locs para que no se sobrepongan:

# %%
founders_per_species = 15 # 60
iAF_locs = pick_random_locations(n = founders_per_species, 
                                   xrange = [1,grid_size], yrange = [1,grid_size], 
                                   forbidden_locs = forbidden_locs)
forbidden_locs.extend(iAF_locs)
iJN_locs = pick_random_locations(founders_per_species, [1,grid_size],[1,grid_size], forbidden_locs)

# %% [markdown]
# Para graficar los lugares utilizamos matplotlib:

# %%
from matplotlib import pyplot as plt
initial_image = np.zeros((grid_size,grid_size,3))
for rock in rock_locs:
    initial_image[rock[0],rock[1],0:3] = 0.5 
for loc in iAF_locs:
    initial_image[loc[0],loc[1],1] = 1
for loc in iJN_locs:
    initial_image[loc[0],loc[1],2] = 1
plt.imshow(initial_image)

# %% [markdown]
# Generamos el layout y agregamos las rocas:

# %%
# iAF
iAF_initial_pop = [] 
for loc in iJN_locs: 
    iAF_initial_pop.append([loc[0], loc[1], 1.e-8]) 
iAF_comets.initial_pop = iAF_initial_pop 
# iJN
iJN_initial_pop = [] 
for loc in iJN_locs: 
    iJN_initial_pop.append([loc[0], loc[1], 1.e-10]) 
iJN_comets.initial_pop = iJN_initial_pop

# %% [markdown]
# Setteamos las poblaciones iniciales para cada especie, con esto los modelos están listos y los añadimos al layout:

# %%
layout = c.layout([iAF_comets, iJN_comets])
layout.grid = [grid_size,grid_size]
layout.add_barriers(rock_locs)

# %% [markdown]
# Añadimos los metabolitos que estarán inicialmente disponibles en el ambiente. Usamos la función helper add_typical_trace_metabolites() para las trazas típicas. Bajamos el valor del oxígeno dado que la idea es que el que esté disponible difunda desde la atmósfera. Añadimos algunos metabolitos que no se añadieron con la función helper:

# %%
layout.add_typical_trace_metabolites()
layout.set_specific_metabolite('o2_e',0.000001)
layout.set_specific_metabolite('hco3_e',1000)
layout.set_specific_metabolite('co2_e',1000)
layout.set_specific_metabolite('h2_e',1000)
layout.set_specific_metabolite('so3_e',1000)
layout.set_specific_metabolite('nh4_e',0.0000001)

layout.set_specific_metabolite('glc__D_e',0.0000001)
layout.set_specific_metabolite('meoh_e',0.00000001)
layout.set_specific_metabolite('cys__L_e',0.0000001)
layout.set_specific_metabolite('catechol_e',0.0000001)

# %% [markdown]
# Para la capa de aire, dejamos el oxígeno en un valor constante. Al fondo también dejamos al oxígeno en un valor fijo e igual a 0, para simular el efecto de difusión. De manera similar, hacemos lo mismo con el amoniaco y la raíz en la parte izquierda:

# %%
# set static media of O2 and CO2 at the top and bottom-- the "air" and continuous loss of O2 downwards
for x in range(grid_size):
    layout.set_specific_static_at_location('o2_e', (x,0), .0001) # top
    layout.set_specific_static_at_location('o2_e', (x,grid_size-1), 0.) # bottom
    layout.set_specific_static_at_location('co2_e', (x,0), .0001)
    
for x in range(grid_size):
    layout.set_specific_static_at_location('nh4_e', (0,x), 0.0)

# %% [markdown]
# La raíz consume todo el amoniaco, pero es una fuente de acidos orgánicos y metanol para el ambiente. Asumiendo una tasa fija:

# %%
for x in range(grid_size):
    layout.set_specific_refresh_at_location('cit_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('meoh_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('succ_e', (0,x), .000001)

# %% [markdown]
# El layout y los modelos están listos, ahora setteamos los parámetros de la simulación:

# %%
params = c.params()
params.set_param('timeStep', 0.1)
params.set_param('maxCycles', 1000)
params.set_param('maxSpaceBiomass', 10)
params.set_param('deathRate', 0.0001) # die at rate of 1/10000 per hour
params.set_param('writeBiomassLog', True)
params.set_param('BiomassLogRate', 500)
params.set_param('writeMediaLog', True)
params.set_param('MediaLogRate', 500)
params.set_param("writeFluxLog", True)
params.set_param("FluxLogRate", 500)
params.set_param('numRunThreads', 3)
params.set_param('defaultKm', 0.000001)

# %% [markdown]
# Ahora creamos el objeto de la simulación y la corremos. Ojito que se demora y el pc empieza a despegar.

# %%
sim = c.comets(layout, params)
sim.run(False)
# Out:
# Running COMETS simulation ...
# C:\Users\pabli\AppData\Local\Temp/ipykernel_6360/1491467366.py:2: DtypeWarning: Columns (7,8,12,14,18,32,35,42,43,47,48,51,52,62,63,69,72,74,75,81,82,100,101,102,103,104,116,121,122,124,129,132,135,137,142,146,147,148,149,151,155,161,162,163,165,166,167,169,174,176,181,189,200,217,233,238,254,255,256,257,258,282,286,292,294,298,299,338,369,402,406,407,408,411,412,414,415,419,420,421,440,443,453,481,495,514,516,517,522,523,527,530,537,538,539,542,574,591,600,605,607,633,639,640,644,645,653,665,668,669,670,674,691,696,698,718,725,727,728,729,730,732,742,744,746,750,762,768,781,791,798,818,821,833,846,847,866,868,873,878,881,884,885,908,915,938,941,944,945,961,964,967,968,971,976,977,978,981,983,996,1017,1025,1050,1051,1083,1086,1087,1088,1098,1107,1113,1114,1124,1125,1126,1134,1151,1164,1165,1183,1184,1185,1203,1204,1206,1220,1221,1225,1227,1229,1230,1233,1243,1244,1246,1248,1254,1255,1276,1281,1282,1288,1297,1298,1303,1316,1317,1318,1320,1336,1346,1354,1355,1363,1364,1365,1369,1370,1371,1376,1377,1412,1419,1421,1428,1431,1481,1503,1505,1508,1510,1511,1515,1516,1517,1518,1521,1524,1527,1530,1535,1540,1541,1542,1567,1568,1569,1573,1587,1601,1618,1621,1622,1629,1630,1642,1645,1646,1660,1663,1665,1696,1717,1726,1727,1736,1747,1760,1764,1766,1767,1768,1769,1770,1771,1796,1810,1830,1836,1855,1858,1864,1878,1886,1887,1890,1891,1901,1902,1908,1914,1915,1918,1924,1926,1928,1930,1932,1933,1936,1938,1940,1941,1942,1943,1944,1946,1949,1951,1961,1964,1968,1969,1970,1974,1975,1977,1984,1987,1988,1990,1991,1992,1994,1998,2002,2016,2017,2049,2055,2056,2063,2072,2080,2085,2086,2093,2094,2096,2098,2099,2100,2101,2103,2106,2107,2113,2120,2133,2134,2148,2150,2182,2204,2231,2254,2257,2267,2268,2274,2282,2284,2362,2376,2382,2388,2389,2390,2392,2410,2420,2423,2424,2426,2440,2453,2471,2474,2477,2479,2480,2482,2531,2534,2535,2575,2595,2610,2639,2670,2680,2694,2719,2729,2731,2781,2795,2826,2877,2888,2900,2908) have mixed types.Specify dtype option on import or set low_memory=False.
#   sim.run(False)
# Done!

# %%
print(sim.run_output)
print(sim.run_errors)
# Out:
# -script
# running script file: C:\Users\pabli\OneDrive\Escritorio\COMETS\ODRM\simulaciones\2_modelos\Coli_putida_15x15_0.0000001_catechol_cambio_putida\Coli_putida_15x15_0.0000001_catechol_cambio_putida_1e10/.current_script_0x18c89f9b160
# Current Java version: 17.0.1
# Parameters file .current_global_0x18c89f9b160 loaded.
# Parameters file .current_package_0x18c89f9b160 loaded.
# Loading layout file '.current_layout_0x18c89f9b160'...
# null\COMETS_manifest.txt (El sistema no puede encontrar la ruta especificada)
# Unable to initialize manifest file.
# Continuing without writing manifest file.
# Found 2 model files!
# Loading '.\iAF1260.cmd' ...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution = 395.73529219628256
# Loading '.\iJN1463.cmd' ...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution = 237.06607191111308
# Constructing world...
# Done!
# medialist	12dgr160_e	12dgr180_e	12ppd__R_e	12ppd__S_e	13dampp_e	14glucan_e	15dap_e	1ag160_e	1ag180_e	1ag181d9_e	1ag182d9d12_e	23camp_e	23ccmp_e	23cgmp_e	23cump_e	23dappa_e	25dkglcn_e	26dap__M_e	2ameph_e	2ddglcn_e	2dhglcn_e	2m35mdntha_e	34dhbz_e	34dhcinm_e	34dhpac_e	34dhphe_e	35dnta_e	3amp_e	3cmp_e	3gmp_e	3h4atb_e	3hcinnm_e	3hpppn_e	3mb_e	3oxoadp_e	3ump_e	4abut_e	4hbz_e	4hoxpacd_e	4hpro_DC_e	4hpro_LT_e	4hptn_e	4oxptn_e	5aptn_e	5dglcn_e	5g2oxpt_e	5mcsn_e	5oxpro_e	6atha_e	6hnac_e	LalaDgluMdapDala_e	LalaDgluMdap_e	LalaLglu_e	Ncbmpts_e	R3hdec4e_e	R_3h4atba_e	R_3h6atha_e	R_3hcmrs7e_e	R_3hdcaa_e	R_3hdd5ea_e	R_3hdd6e_e	R_3hdda_e	R_3hhdca_e	R_3hhpa_e	R_3hhxa_e	R_3hnonaa_e	R_3hocta_e	R_3hpba_e	R_3hpdeca_e	R_3hphpa_e	R_3hphxa_e	R_3hpnona_e	R_3hpocta_e	R_3hppta_e	R_3hpt_e	R_3htd58e_e	R_3htd5e_e	R_3httdca_e	T4hcinnm_e	ac_e	acac_e	acald_e	acgal1p_e	acgal_e	acgam1p_e	acgam_e	acmana_e	acmtsoxin_e	acmum_e	acnam_e	acolipa_e	acon_C_e	acpptrn_e	acser_e	actn__R_e	ade_e	adn_e	adocbl_e	ag_e	agm_e	akg_e	ala_B_e	ala__D_e	ala__L_e	alaala_e	alahis_e	alaleu_e	alathr_e	alatrp_e	algac_MG_14_e	algac_MG_23_e	algac_MG_32_e	algac_MG_41_e	algac__M_e	all__D_e	alltn_e	amp_e	anhgm_e	apc_e	arab__L_e	arbtn_e	arbtn_fe3_e	arg__D_e	arg__L_e	ascb__L_e	asn__D_e	asn__L_e	aso3_e	aso4_e	asp__L_e	balaala_e	balabala_e	balagly_e	balaleu_e	balamd_e	bhb_e	biliverd_e	btd_RR_e	btn_e	but_e	butso3_e	bz_e	ca2_e	carn_e	catechol_e	cbi_e	cbl1_e	cd2_e	cell4_e	cgly_e	chol_e	chols_e	chor_e	cinnm_e	cit_e	cl_e	cm_e	cmcbtt_e	cmp_e	co2_e	co_e	cobalt2_e	colipa_e	confrl_e	cpgn_e	cpgn_un_e	creat_e	crn_e	cro2_e	cro4_e	crtn_e	csn_e	cu2_e	cu_e	cyan_e	cynt_e	cys__D_e	cys__L_e	cytd_e	d2one_e	d3one_e	d4one_e	dad_2_e	dag181d9_e	dag182d9d12_e	damp_e	dca_e	dcmp_e	dcyt_e	ddca_e	dgmp_e	dgsn_e	dgudbutn_e	dha_e	dimp_e	din_e	dmanur_e	dmgly_e	dms_e	dmso2_e	dmso_e	dopa_e	dtmp_e	dump_e	duri_e	eca4colipa_e	ecto__L_e	enlipa_e	enter_e	etha_e	ethso3_e	etoh_e	f6p_e	fald_e	fcmcbtt_e	fe2_e	fe3_e	fe3dcit_e	fe3dhbzs_e	fe3hox_e	fe3hox_un_e	fe3mcbtt_e	fe3pyovd_e	fe3pyovd_kt_e	fecrm_e	fecrm_un_e	feenter_e	feoxam_e	feoxam_un_e	fer_e	for_e	fru_e	frulys_e	fruur_e	fuc__L_e	fum_e	g1p_e	g3pc_e	g3pe_e	g3pg_e	g3pi_e	g3ps_e	g6p_e	ga_e	gal1p_e	gal_bD_e	gal_e	galct__D_e	galctn__D_e	galctn__L_e	galt_e	galur_e	gam6p_e	gam_e	gbbtn_e	gdp_e	glc__D_e	glcn_e	glcr_e	glcur1p_e	glcur_e	gln__L_e	glu__L_e	glutar_e	gly_e	glyald_e	glyb_e	glyc2p_e	glyc3p_e	glyc__R_e	glyc_e	glyclt_e	glycol_e	glygln_e	glyglu_e	glygly_e	glymet_e	glyphe_e	glyser_e	gmp_e	gsn_e	gthox_e	gthrd_e	gtp_e	gua_e	gudac_e	gudptn_e	h2_e	h2o2_e	h2o_e	h2s_e	h_e	hacolipa_e	halipa_e	hco3_e	hcys__L_e	hdca_e	hdcea_e	hg2_e	hgentis_e	his__L_e	hisgly_e	hishis_e	hom__L_e	hpta_e	hxa_e	hxan_e	icit_e	idon__L_e	ile__L_e	imp_e	ind3ac_e	indole_e	inost_e	ins_e	isetac_e	k_e	kdo2lipid4_e	lac__D_e	lac__L_e	lcts_e	leu__D_e	leu__L_e	leuleu_e	lipa_cold_e	lipa_e	lnlc_e	lpspput_e	lys__D_e	lys__L_e	lyx__L_e	m_xyl_e	mal__D_e	mal__L_e	malt_e	malthx_e	maltpt_e	malttr_e	maltttr_e	man6p_e	man_e	manglyc_e	manur_e	mcbtt_e	melib_e	meoh_e	met__D_e	met__L_e	metsox_R__L_e	metsox_S__L_e	mg2_e	minohp_e	mmet_e	mn2_e	mnl_e	mobd_e	mso3_e	mtsoxin_e	n2o_e	n2one_e	na1_e	nac_e	nh4_e	ni2_e	nmn_e	no2_e	no3_e	no_e	nona_e	o16a4colipa_e	o2_e	o2s_e	o_xyl_e	oaa_e	ocdca_e	ocdcea_e	octa_e	orn__D_e	orn_e	orot_e	oxa_e	p_xyl_e	pac_e	pacald_e	pb2_e	pea_e	peamn_e	pentso3_e	phe__D_e	phe__L_e	phedca_e	phehpa_e	phehxa_e	pheme_e	phenona_e	pheocta_e	phept_e	phpyr_e	pi_e	pnto__R_e	ppa_e	ppal_e	ppi_e	pppn_e	ppt_e	pptrn_e	prealg_MG_14_e	prealg_MG_23_e	prealg_MG_32_e	prealg_MG_41_e	prealginate_G_e	pro__D_e	pro__L_e	progly_e	psclys_e	pser__L_e	pta_e	ptrc_e	ptsla_e	pydam_e	pyovd_e	pyovd_kt_e	pyr_e	quin_e	r5p_e	rib__D_e	rmn_e	sbo3_e	sbt__D_e	sel_e	ser__D_e	ser__L_e	sheme_e	skm_e	so2_e	so3_e	so4_e	spmd_e	succ_e	sucr_e	sulfac_e	tag160_e	tag180_e	tag181d9_e	tag182d9d12_e	tartr__L_e	taur_e	tcynt_e	thm_e	thr__L_e	thrp_e	thym_e	thymd_e	tma_e	tmanur_e	tmao_e	tnt_e	tol_e	tre_e	trp__L_e	tsul_e	ttdca_e	ttdcea_e	ttrcyc_e	tungs_e	tym_e	tyr__D_e	tyr__L_e	tyrp_e	uacg ...
# Cycle 1
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# FBARunThread-0 starting up.
# FBARunThread-1 starting up.
# FBARunThread-2 starting up.
# Total biomass:
# Model iAF1260.cmd: 1.5910604705455136E-7
# Model iJN1463.cmd: 1.5657256924274454E-9
# Cycle 2
# Total biomass:
# Model iAF1260.cmd: 1.687605093150302E-7
# Model iJN1463.cmd: 1.6343339537724464E-9
# Cycle 3
# Total biomass:
# Model iAF1260.cmd: 1.798392578739299E-7
# Model iJN1463.cmd: 1.717985107615731E-9
# Cycle 4
# Total biomass:
# Model iAF1260.cmd: 1.9223204814334332E-7
# Model iJN1463.cmd: 1.8082188910612781E-9
# Cycle 5
# Total biomass:
# Model iAF1260.cmd: 2.059836164416933E-7
# Model iJN1463.cmd: 1.9034533006289032E-9
# Cycle 6
# Total biomass:
# Model iAF1260.cmd: 2.2117471961821807E-7
# Model iJN1463.cmd: 2.0037849136381877E-9
# Cycle 7
# Total biomass:
# Model iAF1260.cmd: 2.3782492823317055E-7
# Model iJN1463.cmd: 2.1094512946848682E-9
# Cycle 8
# Total biomass:
# Model iAF1260.cmd: 2.559611726793595E-7
# Model iJN1463.cmd: 2.220721372293119E-9
# Cycle 9
# Total biomass:
# Model iAF1260.cmd: 2.7560932453209286E-7
# Model iJN1463.cmd: 2.337870676866336E-9
# Cycle 10
# Total biomass:
# Model iAF1260.cmd: 2.968477478456439E-7
# Model iJN1463.cmd: 2.4612176613208426E-9
# Cycle 11
# Total biomass:
# Model iAF1260.cmd: 3.1973736603186766E-7
# Model iJN1463.cmd: 2.591083228016799E-9
# Cycle 12
# Total biomass:
# Model iAF1260.cmd: 3.443799622585751E-7
# Model iJN1463.cmd: 2.727805773050629E-9
# Cycle 13
# Total biomass:
# Model iAF1260.cmd: 3.7090893969840047E-7
# Model iJN1463.cmd: 2.8717475178811267E-9
# Cycle 14
# Total biomass:
# Model iAF1260.cmd: 3.9946784102084746E-7
# Model iJN1463.cmd: 3.023289846366291E-9
# Cycle 15
# Total biomass:
# Model iAF1260.cmd: 4.302111051411239E-7
# Model iJN1463.cmd: 3.18283431389822E-9
# Cycle 16
# Total biomass:
# Model iAF1260.cmd: 4.633048853085919E-7
# Model iJN1463.cmd: 3.350803711231749E-9
# Cycle 17
# Total biomass:
# Model iAF1260.cmd: 4.989279304193797E-7
# Model iJN1463.cmd: 3.527643185569254E-9
# Cycle 18
# Total biomass:
# Model iAF1260.cmd: 5.372725335087697E-7
# Model iJN1463.cmd: 3.7138214215451105E-9
# Cycle 19
# Total biomass:
# Model iAF1260.cmd: 5.785455520399373E-7
# Model iJN1463.cmd: 3.9098318849833525E-9
# Cycle 20
# Total biomass:
# Model iAF1260.cmd: 6.229695050536619E-7
# Model iJN1463.cmd: 4.1161941325236995E-9
# Cycle 21
# Total biomass:
# Model iAF1260.cmd: 6.70783752620154E-7
# Model iJN1463.cmd: 4.3334551903829635E-9
# Cycle 22
# Total biomass:
# Model iAF1260.cmd: 7.222730318668831E-7
# Model iJN1463.cmd: 4.562191005591108E-9
# Cycle 23
# Total biomass:
# Model iAF1260.cmd: 7.777178711270516E-7
# Model iJN1463.cmd: 4.80300797319109E-9
# Cycle 24
# Total biomass:
# Model iAF1260.cmd: 8.374789107349102E-7
# Model iJN1463.cmd: 5.056544542604102E-9
# Cycle 25
# Total biomass:
# Model iAF1260.cmd: 9.013701818597085E-7
# Model iJN1463.cmd: 5.32340530343063E-9
# Cycle 26
# Total biomass:
# Model iAF1260.cmd: 9.683338786633998E-7
# Model iJN1463.cmd: 5.604334157039196E-9
# Cycle 27
# Total biomass:
# Model iAF1260.cmd: 1.0376714005605546E-6
# Model iJN1463.cmd: 5.900008461180467E-9
# Cycle 28
# Total biomass:
# Model iAF1260.cmd: 1.1090095226311263E-6
# Model iJN1463.cmd: 6.21125789879485E-9
# Cycle 29
# Total biomass:
# Model iAF1260.cmd: 1.1826043811840834E-6
# Model iJN1463.cmd: 6.538894288938167E-9
# Cycle 30
# Total biomass:
# Model iAF1260.cmd: 1.2591283453108992E-6
# Model iJN1463.cmd: 6.8837682812233256E-9
# Cycle 31
# Total biomass:
# Model iAF1260.cmd: 1.3383381235761917E-6
# Model iJN1463.cmd: 7.246769380000535E-9
# Cycle 32
# Total biomass:
# Model iAF1260.cmd: 1.4203478735291693E-6
# Model iJN1463.cmd: 7.6288243549764E-9
# Cycle 33
# Total biomass:
# Model iAF1260.cmd: 1.5051641254719928E-6
# Model iJN1463.cmd: 8.030892409504254E-9
# Cycle 34
# Total biomass:
# Model iAF1260.cmd: 1.5924721370159393E-6
# Model iJN1463.cmd: 8.453952544625644E-9
# Cycle 35
# Total biomass:
# Model iAF1260.cmd: 1.6819631577461929E-6
# Model iJN1463.cmd: 8.898982066487787E-9
# Cycle 36
# Total biomass:
# Model iAF1260.cmd: 1.7730892701741047E-6
# Model iJN1463.cmd: 9.36690987963835E-9
# Cycle 37
# Total biomass:
# Model iAF1260.cmd: 1.8655663084260463E-6
# Model iJN1463.cmd: 9.858687074203296E-9
# Cycle 38
# Total biomass:
# Model iAF1260.cmd: 1.9598396496539823E-6
# Model iJN1463.cmd: 1.0375231034231637E-8
# Cycle 39
# Total biomass:
# Model iAF1260.cmd: 2.0540693400898047E-6
# Model iJN1463.cmd: 1.0917329467123515E-8
# Cycle 40
# Total biomass:
# Model iAF1260.cmd: 2.148761089504454E-6
# Model iJN1463.cmd: 1.148566452003687E-8
# Cycle 41
# Total biomass:
# Model iAF1260.cmd: 2.244333203640289E-6
# Model iJN1463.cmd: 1.2080767733082054E-8
# Cycle 42
# Total biomass:
# Model iAF1260.cmd: 2.3410784212269357E-6
# Model iJN1463.cmd: 1.2701833956757633E-8
# Cycle 43
# Total biomass:
# Model iAF1260.cmd: 2.439251408584627E-6
# Model iJN1463.cmd: 1.3345048274260327E-8
# Cycle 44
# Total biomass:
# Model iAF1260.cmd: 2.5391028593343737E-6
# Model iJN1463.cmd: 1.400761590362142E-8
# Cycle 45
# Total biomass:
# Model iAF1260.cmd: 2.6408619156010813E-6
# Model iJN1463.cmd: 1.4686357076760595E-8
# Cycle 46
# Total biomass:
# Model iAF1260.cmd: 2.744836843233511E-6
# Model iJN1463.cmd: 1.5374893541357675E-8
# Cycle 47
# Total biomass:
# Model iAF1260.cmd: 2.8510937733041592E-6
# Model iJN1463.cmd: 1.6074772531305638E-8
# Cycle 48
# Total biomass:
# Model iAF1260.cmd: 2.959861071553053E-6
# Model iJN1463.cmd: 1.6787133719506065E-8
# Cycle 49
# Total biomass:
# Model iAF1260.cmd: 3.071415363550129E-6
# Model iJN1463.cmd: 1.7516198939833652E-8
# Cycle 50
# Total biomass:
# Model iAF1260.cmd: 3.1859271141860217E-6
# Model iJN1463.cmd: 1.826613425415357E-8
# Cycle 51
# Total biomass:
# Model iAF1260.cmd: 3.3034652327716206E-6
# Model iJN1463.cmd: 1.9040825597951036E-8
# Cycle 52
# Total biomass:
# Model iAF1260.cmd: 3.424115809098974E-6
# Model iJN1463.cmd: 1.9843751770867757E-8
# Cycle 53
# Total biomass:
# Model iAF1260.cmd: 3.5479229939116567E-6
# Model iJN1463.cmd: 2.067757467602326E-8
# Cycle 54
# Total biomass:
# Model iAF1260.cmd: 3.674623107583686E-6
# Model iJN1463.cmd: 2.1544375934839825E-8
# Cycle 55
# Total biomass:
# Model iAF1260.cmd: 3.8043140913731774E-6
# Model iJN1463.cmd: 2.2446053097145913E-8
# Cycle 56
# Total biomass:
# Model iAF1260.cmd: 3.9371984372802564E-6
# Model iJN1463.cmd: 2.33842977384607E-8
# Cycle 57
# Total biomass:
# Model iAF1260.cmd: 4.073448049799481E-6
# Model iJN1463.cmd: 2.436072057615225E-8
# Cycle 58
# Total biomass:
# Model iAF1260.cmd: 4.21321760897195E-6
# Model iJN1463.cmd: 2.537682824007619E-8
# Cycle 59
# Total biomass:
# Model iAF1260.cmd: 4.3566004876851934E-6
# Model iJN1463.cmd: 2.6433940246396188E-8
# Cycle 60
# Total biomass:
# Model iAF1260.cmd: 4.5036474693132875E-6
# Model iJN1463.cmd: 2.7533499645303017E-8
# Cycle 61
# Total biomass:
# Model iAF1260.cmd: 4.6543535928809855E-6
# Model iJN1463.cmd: 2.8677135060264236E-8
# Cycle 62
# Total biomass:
# Model iAF1260.cmd: 4.808496233417066E-6
# Model iJN1463.cmd: 2.986644302607347E-8
# Cycle 63
# Total biomass:
# Model iAF1260.cmd: 4.965847044891458E-6
# Model iJN1463.cmd: 3.1103019450108014E-8
# Cycle 64
# Total biomass:
# Model iAF1260.cmd: 5.12631553752528E-6
# Model iJN1463.cmd: 3.238872697102854E-8
# Cycle 65
# Total biomass:
# Model iAF1260.cmd: 5.289993475827935E-6
# Model iJN1463.cmd: 3.372547490704366E-8
# Cycle 66
# Total biomass:
# Model iAF1260.cmd: 5.456837770884299E-6
# Model iJN1463.cmd: 3.511508267214862E-8
# Cycle 67
# Total biomass:
# Model iAF1260.cmd: 5.626879280057602E-6
# Model iJN1463.cmd: 3.655939758150362E-8
# Cycle 68
# Total biomass:
# Model iAF1260.cmd: 5.7998706156569545E-6
# Model iJN1463.cmd: 3.806022265455402E-8
# Cycle 69
# Total biomass:
# Model iAF1260.cmd: 5.975365291437086E-6
# Model iJN1463.cmd: 3.962619186926231E-8
# Cycle 70
# Total biomass:
# Model iAF1260.cmd: 6.153231428774132E-6
# Model iJN1463.cmd: 4.125807751988402E-8
# Cycle 71
# Total biomass:
# Model iAF1260.cmd: 6.333367812164118E-6
# Model iJN1463.cmd: 4.2971496030084136E-8
# Cycle 72
# Total biomass:
# Model iAF1260.cmd: 6.516000862774035E-6
# Model iJN1463.cmd: 4.4753034685206967E-8
# Cycle 73
# Total biomass:
# Model iAF1260.cmd: 6.7008236748990615E-6
# Model iJN1463.cmd: 4.6612249522550134E-8
# Cycle 74
# Total biomass:
# Model iAF1260.cmd: 6.888036500330451E-6
# Model iJN1463.cmd: 4.854511737673257E-8
# Cycle 75
# Total biomass:
# Model iAF1260.cmd: 7.077547458032699E-6
# Model iJN1463.cmd: 5.0551297235505824E-8
# Cycle 76
# Total biomass:
# Model iAF1260.cmd: 7.269370294209034E-6
# Model iJN1463.cmd: 5.263917992961738E-8
# Cycle 77
# Total biomass:
# Model iAF1260.cmd: 7.463738464298227E-6
# Model iJN1463.cmd: 5.4811148670453585E-8
# Cycle 78
# Total biomass:
# Model iAF1260.cmd: 7.660895730953202E-6
# Model iJN1463.cmd: 5.707053918085601E-8
# Cycle 79
# Total biomass:
# Model iAF1260.cmd: 7.861048974102478E-6
# Model iJN1463.cmd: 5.942119193220242E-8
# Cycle 80
# Total biomass:
# Model iAF1260.cmd: 8.064417025546526E-6
# Model iJN1463.cmd: 6.186612033299151E-8
# Cycle 81
# Total biomass:
# Model iAF1260.cmd: 8.271285615222551E-6
# Model iJN1463.cmd: 6.440384144718913E-8
# Cycle 82
# Total biomass:
# Model iAF1260.cmd: 8.481854542239412E-6
# Model iJN1463.cmd: 6.70644658095872E-8
# Cycle 83
# Total biomass:
# Model iAF1260.cmd: 8.69639288872465E-6
# Model iJN1463.cmd: 6.982886129903506E-8
# Cycle 84
# Total biomass:
# Model iAF1260.cmd: 8.91509099890938E-6
# Model iJN1463.cmd: 7.272553283438967E-8
# Cycle 85
# Total biomass:
# Model iAF1260.cmd: 9.138113956618355E-6
# Model iJN1463.cmd: 7.581046417183974E-8
# Cycle 86
# Total biomass:
# Model iAF1260.cmd: 9.365663918329848E-6
# Model iJN1463.cmd: 7.901763946367327E-8
# Cycle 87
# Total biomass:
# Model iAF1260.cmd: 9.597779677287362E-6
# Model iJN1463.cmd: 8.237750102297025E-8
# Cycle 88
# Total biomass:
# Model iAF1260.cmd: 9.834583442230126E-6
# Model iJN1463.cmd: 8.589717224165692E-8
# Cycle 89
# Total biomass:
# Model iAF1260.cmd: 1.0076241247890161E-5
# Model iJN1463.cmd: 8.955386406970824E-8
# Cycle 90
# Total biomass:
# Model iAF1260.cmd: 1.0322825679456673E-5
# Model iJN1463.cmd: 9.33560102571405E-8
# Cycle 91
# Total biomass:
# Model iAF1260.cmd: 1.0574438939647188E-5
# Model iJN1463.cmd: 9.730155740143062E-8
# Cycle 92
# Total biomass:
# Model iAF1260.cmd: 1.08311886995339E-5
# Model iJN1463.cmd: 1.014022884381293E-7
# Cycle 93
# Total biomass:
# Model iAF1260.cmd: 1.1093184935613055E-5
# Model iJN1463.cmd: 1.0565990050032384E-7
# Cycle 94
# Total biomass:
# Model iAF1260.cmd: 1.1360534150755346E-5
# Model iJN1463.cmd: 1.1007916946788699E-7
# Cycle 95
# Total biomass:
# Model iAF1260.cmd: 1.1633322323581496E-5
# Model iJN1463.cmd: 1.1467339573515842E-7
# Cycle 96
# Total biomass:
# Model iAF1260.cmd: 1.1911635283681402E-5
# Model iJN1463.cmd: 1.1944958529612092E-7
# Cycle 97
# Total biomass:
# Model iAF1260.cmd: 1.2195540434752858E-5
# Model iJN1463.cmd: 1.2446479875642277E-7
# Cycle 98
# Total biomass:
# Model iAF1260.cmd: 1.2485159751882622E-5
# Model iJN1463.cmd: 1.2973257252187936E-7
# Cycle 99
# Total biomass:
# Model iAF1260.cmd: 1.278062423718175E-5
# Model iJN1463.cmd: 1.352918353947812E-7
# Cycle 100
# Total biomass:
# Model iAF1260.cmd: 1.3082020161482482E-5
# Model iJN1463.cmd: 1.411982371717412E-7
# Cycle 101
# Total biomass:
# Model iAF1260.cmd: 1.3389460158806523E-5
# Model iJN1463.cmd: 1.4734213489843253E-7
# Cycle 102
# Total biomass:
# Model iAF1260.cmd: 1.370307366296375E-5
# Model iJN1463.cmd: 1.5374140951087742E-7
# Cycle 103
# Total biomass:
# Model iAF1260.cmd: 1.4022958228080056E-5
# Model iJN1463.cmd: 1.60406767699608E-7
# Cycle 104
# Total biomass:
# Model iAF1260.cmd: 1.4349272770577802E-5
# Model iJN1463.cmd: 1.678581908892496E-7
# Cycle 105
# Total biomass:
# Model iAF1260.cmd: 1.4682079005597975E-5
# Model iJN1463.cmd: 1.757448015986368E-7
# Cycle 106
# Total biomass:
# Model iAF1260.cmd: 1.502150729397702E-5
# Model iJN1463.cmd: 1.8398596056501452E-7
# Cycle 107
# Total biomass:
# Model iAF1260.cmd: 1.536757261660663E-5
# Model iJN1463.cmd: 1.9259662089967164E-7
# Cycle 108
# Total biomass:
# Model iAF1260.cmd: 1.571974719857761E-5
# Model iJN1463.cmd: 2.0159221439071682E-7
# Cycle 109
# Total biomass:
# Model iAF1260.cmd: 1.6077485801773282E-5
# Model iJN1463.cmd: 2.1101440908986995E-7
# Cycle 110
# Total biomass:
# Model iAF1260.cmd: 1.6439635512134433E-5
# Model iJN1463.cmd: 2.2090841735215547E-7
# Cycle 111
# Total biomass:
# Model iAF1260.cmd: 1.6802317255092937E-5
# Model iJN1463.cmd: 2.3124643286446587E-7
# Cycle 112
# Total biomass:
# Model iAF1260.cmd: 1.7161963529594606E-5
# Model iJN1463.cmd: 2.420490885253107E-7
# Cycle 113
# Total biomass:
# Model iAF1260.cmd: 1.751550806624176E-5
# Model iJN1463.cmd: 2.53326104955147E-7
# Cycle 114
# Total biomass:
# Model iAF1260.cmd: 1.7860129570051047E-5
# Model iJN1463.cmd: 2.651102761314283E-7
# Cycle 115
# Total biomass:
# Model iAF1260.cmd: 1.819455850710078E-5
# Model iJN1463.cmd: 2.7742387748670766E-7
# Cycle 116
# Total biomass:
# Model iAF1260.cmd: 1.851630382192601E-5
# Model iJN1463.cmd: 2.9028382652419056E-7
# Cycle 117
# Total biomass:
# Model iAF1260.cmd: 1.8823505644840105E-5
# Model iJN1463.cmd: 3.037108711570318E-7
# Cycle 118
# Total biomass:
# Model iAF1260.cmd: 1.9114853533136344E-5
# Model iJN1463.cmd: 3.1772013610254735E-7
# Cycle 119
# Total biomass:
# Model iAF1260.cmd: 1.9391287976433025E-5
# Model iJN1463.cmd: 3.323332186246103E-7
# Cycle 120
# Total biomass:
# Model iAF1260.cmd: 1.9654356405819928E-5
# Model iJN1463.cmd: 3.4755615649918325E-7
# Cycle 121
# Total biomass:
# Model iAF1260.cmd: 1.9905965556286824E-5
# Model iJN1463.cmd: 3.634238160721042E-7
# Cycle 122
# Total biomass:
# Model iAF1260.cmd: 2.0148237428942627E-5
# Model iJN1463.cmd: 3.7995783636698116E-7
# Cycle 123
# Total biomass:
# Model iAF1260.cmd: 2.038357253439538E-5
# Model iJN1463.cmd: 3.972091315374231E-7
# Cycle 124
# Total biomass:
# Model iAF1260.cmd: 2.061301917665459E-5
# Model iJN1463.cmd: 4.1516829443947705E-7
# Cycle 125
# Total biomass:
# Model iAF1260.cmd: 2.0836729890793247E-5
# Model iJN1463.cmd: 4.3388446532003956E-7
# Cycle 126
# Total biomass:
# Model iAF1260.cmd: 2.1055055987519993E-5
# Model iJN1463.cmd: 4.53383600237636E-7
# Cycle 127
# Total biomass:
# Model iAF1260.cmd: 2.1268765715823813E-5
# Model iJN1463.cmd: 4.736825058259049E-7
# Cycle 128
# Total biomass:
# Model iAF1260.cmd: 2.147866532905171E-5
# Model iJN1463.cmd: 4.948038033893349E-7
# Cycle 129
# Total biomass:
# Model iAF1260.cmd: 2.1685563382726555E-5
# Model iJN1463.cmd: 5.167784716797746E-7
# Cycle 130
# Total biomass:
# Model iAF1260.cmd: 2.1890280832221588E-5
# Model iJN1463.cmd: 5.396997454667475E-7
# Cycle 131
# Total biomass:
# Model iAF1260.cmd: 2.2093494011021164E-5
# Model iJN1463.cmd: 5.635833262188486E-7
# Cycle 132
# Total biomass:
# Model iAF1260.cmd: 2.2295690356163148E-5
# Model iJN1463.cmd: 5.884147385969666E-7
# Cycle 133
# Total biomass:
# Model iAF1260.cmd: 2.2497154756700186E-5
# Model iJN1463.cmd: 6.142544729442052E-7
# Cycle 134
# Total biomass:
# Model iAF1260.cmd: 2.269816263971937E-5
# Model iJN1463.cmd: 6.411443098374577E-7
# Cycle 135
# Total biomass:
# Model iAF1260.cmd: 2.2898877518811447E-5
# Model iJN1463.cmd: 6.691247702054151E-7
# Cycle 136
# Total biomass:
# Model iAF1260.cmd: 2.3099381477045357E-5
# Model iJN1463.cmd: 6.982339190527534E-7
# Cycle 137
# Total biomass:
# Model iAF1260.cmd: 2.3299713261893316E-5
# Model iJN1463.cmd: 7.285183377809339E-7
# Cycle 138
# Total biomass:
# Model iAF1260.cmd: 2.3499854585841443E-5
# Model iJN1463.cmd: 7.600497995112718E-7
# Cycle 139
# Total biomass:
# Model iAF1260.cmd: 2.369936217517776E-5
# Model iJN1463.cmd: 7.928562629597447E-7
# Cycle 140
# Total biomass:
# Model iAF1260.cmd: 2.3898557973555727E-5
# Model iJN1463.cmd: 8.269928567894115E-7
# Cycle 141
# Total biomass:
# Model iAF1260.cmd: 2.409754146409334E-5
# Model iJN1463.cmd: 8.625856671421776E-7
# Cycle 142
# Total biomass:
# Model iAF1260.cmd: 2.4296406001207117E-5
# Model iJN1463.cmd: 8.996028376051189E-7
# Cycle 143
# Total biomass:
# Model iAF1260.cmd: 2.4494966205699392E-5
# Model iJN1463.cmd: 9.381101436098016E-7
# Cycle 144
# Total biomass:
# Model iAF1260.cmd: 2.469294359436075E-5
# Model iJN1463.cmd: 9.783650186883263E-7
# Cycle 145
# Total biomass:
# Model iAF1260.cmd: 2.489054436341663E-5
# Model iJN1463.cmd: 1.0204248370422555E-6
# Cycle 146
# Total biomass:
# Model iAF1260.cmd: 2.508806574804841E-5
# Model iJN1463.cmd: 1.0641971200042462E-6
# Cycle 147
# Total biomass:
# Model iAF1260.cmd: 2.5285393114582305E-5
# Model iJN1463.cmd: 1.109759180649964E-6
# Cycle 148
# Total biomass:
# Model iAF1260.cmd: 2.548263073071418E-5
# Model iJN1463.cmd: 1.157157869195183E-6
# Cycle 149
# Total biomass:
# Model iAF1260.cmd: 2.567993952420126E-5
# Model iJN1463.cmd: 1.2064850662791074E-6
# Cycle 150
# Total biomass:
# Model iAF1260.cmd: 2.5877249785405965E-5
# Model iJN1463.cmd: 1.2578188126120155E-6
# Cycle 151
# Total biomass:
# Model iAF1260.cmd: 2.6074377818777296E-5
# Model iJN1463.cmd: 1.3112947163652151E-6
# Cycle 152
# Total biomass:
# Model iAF1260.cmd: 2.6271574626589153E-5
# Model iJN1463.cmd: 1.3668999269946767E-6
# Cycle 153
# Total biomass:
# Model iAF1260.cmd: 2.6468533486992505E-5
# Model iJN1463.cmd: 1.4247963219017619E-6
# Cycle 154
# Total biomass:
# Model iAF1260.cmd: 2.666554817723982E-5
# Model iJN1463.cmd: 1.4851222053379113E-6
# Cycle 155
# Total biomass:
# Model iAF1260.cmd: 2.686256159948071E-5
# Model iJN1463.cmd: 1.5480121995023544E-6
# Cycle 156
# Total biomass:
# Model iAF1260.cmd: 2.7059397713339983E-5
# Model iJN1463.cmd: 1.6133793412053432E-6
# Cycle 157
# Total biomass:
# Model iAF1260.cmd: 2.7255246809698163E-5
# Model iJN1463.cmd: 1.6813909538212838E-6
# Cycle 158
# Total biomass:
# Model iAF1260.cmd: 2.7450415995080305E-5
# Model iJN1463.cmd: 1.7521390624332044E-6
# Cycle 159
# Total biomass:
# Model iAF1260.cmd: 2.764509553219605E-5
# Model iJN1463.cmd: 1.8257188230226513E-6
# Cycle 160
# Total biomass:
# Model iAF1260.cmd: 2.7839432231168926E-5
# Model iJN1463.cmd: 1.9022348138640862E-6
# Cycle 161
# Total biomass:
# Model iAF1260.cmd: 2.803347554680082E-5
# Model iJN1463.cmd: 1.9817755376982706E-6
# Cycle 162
# Total biomass:
# Model iAF1260.cmd: 2.8227140090936047E-5
# Model iJN1463.cmd: 2.0644648849159357E-6
# Cycle 163
# Total biomass:
# Model iAF1260.cmd: 2.8420589877230604E-5
# Model iJN1463.cmd: 2.1504501586256493E-6
# Cycle 164
# Total biomass:
# Model iAF1260.cmd: 2.8613786608247494E-5
# Model iJN1463.cmd: 2.2398371658069426E-6
# Cycle 165
# Total biomass:
# Model iAF1260.cmd: 2.8806851408218252E-5
# Model iJN1463.cmd: 2.3327347285411506E-6
# Cycle 166
# Total biomass:
# Model iAF1260.cmd: 2.899946802452665E-5
# Model iJN1463.cmd: 2.429243895427745E-6
# Cycle 167
# Total biomass:
# Model iAF1260.cmd: 2.9191337142490197E-5
# Model iJN1463.cmd: 2.5295721353671207E-6
# Cycle 168
# Total biomass:
# Model iAF1260.cmd: 2.9382811460795487E-5
# Model iJN1463.cmd: 2.6338233627817736E-6
# Cycle 169
# Total biomass:
# Model iAF1260.cmd: 2.9573996112154776E-5
# Model iJN1463.cmd: 2.7421403117075764E-6
# Cycle 170
# Total biomass:
# Model iAF1260.cmd: 2.9769418302045592E-5
# Model iJN1463.cmd: 2.8543634470238522E-6
# Cycle 171
# Total biomass:
# Model iAF1260.cmd: 2.9961486967824626E-5
# Model iJN1463.cmd: 2.970869772836091E-6
# Cycle 172
# Total biomass:
# Model iAF1260.cmd: 3.0152191726247016E-5
# Model iJN1463.cmd: 3.0917440297099317E-6
# Cycle 173
# Total biomass:
# Model iAF1260.cmd: 3.0341525770132526E-5
# Model iJN1463.cmd: 3.2172085358180683E-6
# Cycle 174
# Total biomass:
# Model iAF1260.cmd: 3.0529179426796214E-5
# Model iJN1463.cmd: 3.3475737597860433E-6
# Cycle 175
# Total biomass:
# Model iAF1260.cmd: 3.071623520191825E-5
# Model iJN1463.cmd: 3.483026905446779E-6
# Cycle 176
# Total biomass:
# Model iAF1260.cmd: 3.090253093203377E-5
# Model iJN1463.cmd: 3.6237328557512394E-6
# Cycle 177
# Total biomass:
# Model iAF1260.cmd: 3.108863763424845E-5
# Model iJN1463.cmd: 3.7698350368240046E-6
# Cycle 178
# Total biomass:
# Model iAF1260.cmd: 3.127405714893789E-5
# Model iJN1463.cmd: 3.921605158294233E-6
# Cycle 179
# Total biomass:
# Model iAF1260.cmd: 3.14592027345075E-5
# Model iJN1463.cmd: 4.079217754813588E-6
# Cycle 180
# Total biomass:
# Model iAF1260.cmd: 3.164415367588241E-5
# Model iJN1463.cmd: 4.242853090457133E-6
# Cycle 181
# Total biomass:
# Model iAF1260.cmd: 3.182880992524496E-5
# Model iJN1463.cmd: 4.412702566887646E-6
# Cycle 182
# Total biomass:
# Model iAF1260.cmd: 3.2012990565118664E-5
# Model iJN1463.cmd: 4.58903042175349E-6
# Cycle 183
# Total biomass:
# Model iAF1260.cmd: 3.219672203150231E-5
# Model iJN1463.cmd: 4.772123714071807E-6
# Cycle 184
# Total biomass:
# Model iAF1260.cmd: 3.238006138578812E-5
# Model iJN1463.cmd: 4.962185107152124E-6
# Cycle 185
# Total biomass:
# Model iAF1260.cmd: 3.256220474320083E-5
# Model iJN1463.cmd: 5.15941216828238E-6
# Cycle 186
# Total biomass:
# Model iAF1260.cmd: 3.2743491954665984E-5
# Model iJN1463.cmd: 5.364058644607321E-6
# Cycle 187
# Total biomass:
# Model iAF1260.cmd: 3.2923831671404626E-5
# Model iJN1463.cmd: 5.5764708314411225E-6
# Cycle 188
# Total biomass:
# Model iAF1260.cmd: 3.310294056293777E-5
# Model iJN1463.cmd: 5.796886395218211E-6
# Cycle 189
# Total biomass:
# Model iAF1260.cmd: 3.3281463399200084E-5
# Model iJN1463.cmd: 6.0255745912437255E-6
# Cycle 190
# Total biomass:
# Model iAF1260.cmd: 3.3459134728451525E-5
# Model iJN1463.cmd: 6.2627838882237476E-6
# Cycle 191
# Total biomass:
# Model iAF1260.cmd: 3.363689465959536E-5
# Model iJN1463.cmd: 6.50740985305046E-6
# Cycle 192
# Total biomass:
# Model iAF1260.cmd: 3.3812452068878236E-5
# Model iJN1463.cmd: 6.7586620679182175E-6
# Cycle 193
# Total biomass:
# Model iAF1260.cmd: 3.3986765422942553E-5
# Model iJN1463.cmd: 7.016207516396164E-6
# Cycle 194
# Total biomass:
# Model iAF1260.cmd: 3.416106663098355E-5
# Model iJN1463.cmd: 7.279172412290843E-6
# Cycle 195
# Total biomass:
# Model iAF1260.cmd: 3.433434160976728E-5
# Model iJN1463.cmd: 7.545105563487355E-6
# Cycle 196
# Total biomass:
# Model iAF1260.cmd: 3.4504174621615237E-5
# Model iJN1463.cmd: 7.814310480596333E-6
# Cycle 197
# Total biomass:
# Model iAF1260.cmd: 3.4673048401435466E-5
# Model iJN1463.cmd: 8.085251847559596E-6
# Cycle 198
# Total biomass:
# Model iAF1260.cmd: 3.4840759284861505E-5
# Model iJN1463.cmd: 8.35770560004433E-6
# Cycle 199
# Total biomass:
# Model iAF1260.cmd: 3.5007388320814244E-5
# Model iJN1463.cmd: 8.631848700102676E-6
# Cycle 200
# Total biomass:
# Model iAF1260.cmd: 3.517323106290716E-5
# Model iJN1463.cmd: 8.908222519488536E-6
# Cycle 201
# Total biomass:
# Model iAF1260.cmd: 3.533830038434256E-5
# Model iJN1463.cmd: 9.185550700217269E-6
# Cycle 202
# Total biomass:
# Model iAF1260.cmd: 3.5502914457732065E-5
# Model iJN1463.cmd: 9.46178677395268E-6
# Cycle 203
# Total biomass:
# Model iAF1260.cmd: 3.566723401501338E-5
# Model iJN1463.cmd: 9.734580154796959E-6
# Cycle 204
# Total biomass:
# Model iAF1260.cmd: 3.583161816779835E-5
# Model iJN1463.cmd: 1.0000108195132486E-5
# Cycle 205
# Total biomass:
# Model iAF1260.cmd: 3.5995874091113173E-5
# Model iJN1463.cmd: 1.0254133477172829E-5
# Cycle 206
# Total biomass:
# Model iAF1260.cmd: 3.615862734452241E-5
# Model iJN1463.cmd: 1.0493570826802702E-5
# Cycle 207
# Total biomass:
# Model iAF1260.cmd: 3.632060400635376E-5
# Model iJN1463.cmd: 1.0716641518352351E-5
# Cycle 208
# Total biomass:
# Model iAF1260.cmd: 3.64818493311151E-5
# Model iJN1463.cmd: 1.0919984090459588E-5
# Cycle 209
# Total biomass:
# Model iAF1260.cmd: 3.664220499921148E-5
# Model iJN1463.cmd: 1.1105713455228501E-5
# Cycle 210
# Total biomass:
# Model iAF1260.cmd: 3.6801645069682365E-5
# Model iJN1463.cmd: 1.1269198184831681E-5
# Cycle 211
# Total biomass:
# Model iAF1260.cmd: 3.696027229069613E-5
# Model iJN1463.cmd: 1.1412640771062953E-5
# Cycle 212
# Total biomass:
# Model iAF1260.cmd: 3.711822261103623E-5
# Model iJN1463.cmd: 1.1541298397058622E-5
# Cycle 213
# Total biomass:
# Model iAF1260.cmd: 3.7275316870761405E-5
# Model iJN1463.cmd: 1.1658458679572835E-5
# Cycle 214
# Total biomass:
# Model iAF1260.cmd: 3.743170217703803E-5
# Model iJN1463.cmd: 1.176713136763441E-5
# Cycle 215
# Total biomass:
# Model iAF1260.cmd: 3.758785821508768E-5
# Model iJN1463.cmd: 1.186951555586442E-5
# Cycle 216
# Total biomass:
# Model iAF1260.cmd: 3.77431869820147E-5
# Model iJN1463.cmd: 1.1967666757501988E-5
# Cycle 217
# Total biomass:
# Model iAF1260.cmd: 3.7897847006634847E-5
# Model iJN1463.cmd: 1.206295675662586E-5
# Cycle 218
# Total biomass:
# Model iAF1260.cmd: 3.805184658581909E-5
# Model iJN1463.cmd: 1.2156130262443847E-5
# Cycle 219
# Total biomass:
# Model iAF1260.cmd: 3.820514159636414E-5
# Model iJN1463.cmd: 1.2248377269508116E-5
# Cycle 220
# Total biomass:
# Model iAF1260.cmd: 3.835804633579184E-5
# Model iJN1463.cmd: 1.233973452123104E-5
# Cycle 221
# Total biomass:
# Model iAF1260.cmd: 3.851005561876936E-5
# Model iJN1463.cmd: 1.2430127114483318E-5
# Cycle 222
# Total biomass:
# Model iAF1260.cmd: 3.8661197328644854E-5
# Model iJN1463.cmd: 1.2520512357921247E-5
# Cycle 223
# Total biomass:
# Model iAF1260.cmd: 3.881205344280431E-5
# Model iJN1463.cmd: 1.2610966349005927E-5
# Cycle 224
# Total biomass:
# Model iAF1260.cmd: 3.8962833343311835E-5
# Model iJN1463.cmd: 1.2701324738779232E-5
# Cycle 225
# Total biomass:
# Model iAF1260.cmd: 3.911319599778939E-5
# Model iJN1463.cmd: 1.2790917611359872E-5
# Cycle 226
# Total biomass:
# Model iAF1260.cmd: 3.926296166835392E-5
# Model iJN1463.cmd: 1.2880698580555018E-5
# Cycle 227
# Total biomass:
# Model iAF1260.cmd: 3.941203365082177E-5
# Model iJN1463.cmd: 1.2969322401085084E-5
# Cycle 228
# Total biomass:
# Model iAF1260.cmd: 3.9560563055627826E-5
# Model iJN1463.cmd: 1.3057686903910475E-5
# Cycle 229
# Total biomass:
# Model iAF1260.cmd: 3.97085224413296E-5
# Model iJN1463.cmd: 1.3146211494083784E-5
# Cycle 230
# Total biomass:
# Model iAF1260.cmd: 3.985618153709727E-5
# Model iJN1463.cmd: 1.3234422199046588E-5
# Cycle 231
# Total biomass:
# Model iAF1260.cmd: 4.00034143322235E-5
# Model iJN1463.cmd: 1.3322384056038185E-5
# Cycle 232
# Total biomass:
# Model iAF1260.cmd: 4.0150477148979026E-5
# Model iJN1463.cmd: 1.3410391426215556E-5
# Cycle 233
# Total biomass:
# Model iAF1260.cmd: 4.029736286232548E-5
# Model iJN1463.cmd: 1.3498626879266555E-5
# Cycle 234
# Total biomass:
# Model iAF1260.cmd: 4.044406046737793E-5
# Model iJN1463.cmd: 1.358644246327405E-5
# Cycle 235
# Total biomass:
# Model iAF1260.cmd: 4.059050903348786E-5
# Model iJN1463.cmd: 1.3674338535908125E-5
# Cycle 236
# Total biomass:
# Model iAF1260.cmd: 4.0736887221914776E-5
# Model iJN1463.cmd: 1.376227735280303E-5
# Cycle 237
# Total biomass:
# Model iAF1260.cmd: 4.088312921053775E-5
# Model iJN1463.cmd: 1.3850280064824047E-5
# Cycle 238
# Total biomass:
# Model iAF1260.cmd: 4.102925872272989E-5
# Model iJN1463.cmd: 1.39383633427005E-5
# Cycle 239
# Total biomass:
# Model iAF1260.cmd: 4.1175277092477786E-5
# Model iJN1463.cmd: 1.4026371340241364E-5
# Cycle 240
# Total biomass:
# Model iAF1260.cmd: 4.1320996317801865E-5
# Model iJN1463.cmd: 1.4114432423894778E-5
# Cycle 241
# Total biomass:
# Model iAF1260.cmd: 4.1466265989631083E-5
# Model iJN1463.cmd: 1.4202510416614831E-5
# Cycle 242
# Total biomass:
# Model iAF1260.cmd: 4.1610842092601436E-5
# Model iJN1463.cmd: 1.429077178143032E-5
# Cycle 243
# Total biomass:
# Model iAF1260.cmd: 4.1754834265193996E-5
# Model iJN1463.cmd: 1.4379242243169772E-5
# Cycle 244
# Total biomass:
# Model iAF1260.cmd: 4.189849245318427E-5
# Model iJN1463.cmd: 1.44678041452391E-5
# Cycle 245
# Total biomass:
# Model iAF1260.cmd: 4.2041822478824033E-5
# Model iJN1463.cmd: 1.4556430300077668E-5
# Cycle 246
# Total biomass:
# Model iAF1260.cmd: 4.2184867460412896E-5
# Model iJN1463.cmd: 1.4645018406955039E-5
# Cycle 247
# Total biomass:
# Model iAF1260.cmd: 4.232763235634906E-5
# Model iJN1463.cmd: 1.4733546746339906E-5
# Cycle 248
# Total biomass:
# Model iAF1260.cmd: 4.247028198267965E-5
# Model iJN1463.cmd: 1.4822098437809161E-5
# Cycle 249
# Total biomass:
# Model iAF1260.cmd: 4.26133423621813E-5
# Model iJN1463.cmd: 1.4910718956454605E-5
# Cycle 250
# Total biomass:
# Model iAF1260.cmd: 4.275639958183577E-5
# Model iJN1463.cmd: 1.4999211954325895E-5
# Cycle 251
# Total biomass:
# Model iAF1260.cmd: 4.289902201372456E-5
# Model iJN1463.cmd: 1.5088089896012745E-5
# Cycle 252
# Total biomass:
# Model iAF1260.cmd: 4.304241700802389E-5
# Model iJN1463.cmd: 1.5176734144863284E-5
# Cycle 253
# Total biomass:
# Model iAF1260.cmd: 4.3186231127587124E-5
# Model iJN1463.cmd: 1.526556261612142E-5
# Cycle 254
# Total biomass:
# Model iAF1260.cmd: 4.3329709871006085E-5
# Model iJN1463.cmd: 1.5354979933741274E-5
# Cycle 255
# Total biomass:
# Model iAF1260.cmd: 4.347318498207996E-5
# Model iJN1463.cmd: 1.544457732821707E-5
# Cycle 256
# Total biomass:
# Model iAF1260.cmd: 4.361722374460369E-5
# Model iJN1463.cmd: 1.5534316484866906E-5
# Cycle 257
# Total biomass:
# Model iAF1260.cmd: 4.3761430900958425E-5
# Model iJN1463.cmd: 1.562350845509375E-5
# Cycle 258
# Total biomass:
# Model iAF1260.cmd: 4.390439983409567E-5
# Model iJN1463.cmd: 1.5712217090225162E-5
# Cycle 259
# Total biomass:
# Model iAF1260.cmd: 4.4047526182065116E-5
# Model iJN1463.cmd: 1.580116278060205E-5
# Cycle 260
# Total biomass:
# Model iAF1260.cmd: 4.4190140823091756E-5
# Model iJN1463.cmd: 1.589039650097534E-5
# Cycle 261
# Total biomass:
# Model iAF1260.cmd: 4.433258341941134E-5
# Model iJN1463.cmd: 1.597985759300537E-5
# Cycle 262
# Total biomass:
# Model iAF1260.cmd: 4.44746694988213E-5
# Model iJN1463.cmd: 1.6069145827874774E-5
# Cycle 263
# Total biomass:
# Model iAF1260.cmd: 4.461621207286346E-5
# Model iJN1463.cmd: 1.6158443977044992E-5
# Cycle 264
# Total biomass:
# Model iAF1260.cmd: 4.475669604012471E-5
# Model iJN1463.cmd: 1.6247967709075543E-5
# Cycle 265
# Total biomass:
# Model iAF1260.cmd: 4.4896601757751286E-5
# Model iJN1463.cmd: 1.633794360287154E-5
# Cycle 266
# Total biomass:
# Model iAF1260.cmd: 4.5036053619852774E-5
# Model iJN1463.cmd: 1.6428375524165592E-5
# Cycle 267
# Total biomass:
# Model iAF1260.cmd: 4.5175484922935045E-5
# Model iJN1463.cmd: 1.6519218532098734E-5
# Cycle 268
# Total biomass:
# Model iAF1260.cmd: 4.5314536745869505E-5
# Model iJN1463.cmd: 1.6610038918487013E-5
# Cycle 269
# Total biomass:
# Model iAF1260.cmd: 4.545306415142209E-5
# Model iJN1463.cmd: 1.6701089386098585E-5
# Cycle 270
# Total biomass:
# Model iAF1260.cmd: 4.559104164328237E-5
# Model iJN1463.cmd: 1.6791770223049107E-5
# Cycle 271
# Total biomass:
# Model iAF1260.cmd: 4.572855553128513E-5
# Model iJN1463.cmd: 1.688286336370587E-5
# Cycle 272
# Total biomass:
# Model iAF1260.cmd: 4.5866257790664017E-5
# Model iJN1463.cmd: 1.697409991931889E-5
# Cycle 273
# Total biomass:
# Model iAF1260.cmd: 4.600531730772051E-5
# Model iJN1463.cmd: 1.706657606141664E-5
# Cycle 274
# Total biomass:
# Model iAF1260.cmd: 4.614451321725007E-5
# Model iJN1463.cmd: 1.715879133088575E-5
# Cycle 275
# Total biomass:
# Model iAF1260.cmd: 4.6284625182471594E-5
# Model iJN1463.cmd: 1.7248448254741758E-5
# Cycle 276
# Total biomass:
# Model iAF1260.cmd: 4.64249173134716E-5
# Model iJN1463.cmd: 1.7337027343542927E-5
# Cycle 277
# Total biomass:
# Model iAF1260.cmd: 4.656442464303929E-5
# Model iJN1463.cmd: 1.7426687443587653E-5
# Cycle 278
# Total biomass:
# Model iAF1260.cmd: 4.6703253298794615E-5
# Model iJN1463.cmd: 1.7516731303273522E-5
# Cycle 279
# Total biomass:
# Model iAF1260.cmd: 4.684080713899639E-5
# Model iJN1463.cmd: 1.7606927859207507E-5
# Cycle 280
# Total biomass:
# Model iAF1260.cmd: 4.697776768659381E-5
# Model iJN1463.cmd: 1.7697570428058802E-5
# Cycle 281
# Total biomass:
# Model iAF1260.cmd: 4.711422136028265E-5
# Model iJN1463.cmd: 1.7788289540938158E-5
# Cycle 282
# Total biomass:
# Model iAF1260.cmd: 4.725021630008848E-5
# Model iJN1463.cmd: 1.787947425463284E-5
# Cycle 283
# Total biomass:
# Model iAF1260.cmd: 4.738596118353919E-5
# Model iJN1463.cmd: 1.797107127145217E-5
# Cycle 284
# Total biomass:
# Model iAF1260.cmd: 4.75214865910019E-5
# Model iJN1463.cmd: 1.8063025263552165E-5
# Cycle 285
# Total biomass:
# Model iAF1260.cmd: 4.7656827309594E-5
# Model iJN1463.cmd: 1.8155275916527237E-5
# Cycle 286
# Total biomass:
# Model iAF1260.cmd: 4.779297500743759E-5
# Model iJN1463.cmd: 1.824770805935459E-5
# Cycle 287
# Total biomass:
# Model iAF1260.cmd: 4.792842366759279E-5
# Model iJN1463.cmd: 1.8340052128505275E-5
# Cycle 288
# Total biomass:
# Model iAF1260.cmd: 4.806363570884527E-5
# Model iJN1463.cmd: 1.8432723083519187E-5
# Cycle 289
# Total biomass:
# Model iAF1260.cmd: 4.8198578051875194E-5
# Model iJN1463.cmd: 1.8525466525047736E-5
# Cycle 290
# Total biomass:
# Model iAF1260.cmd: 4.83364740190016E-5
# Model iJN1463.cmd: 1.8616310782022403E-5
# Cycle 291
# Total biomass:
# Model iAF1260.cmd: 4.847208082412602E-5
# Model iJN1463.cmd: 1.8707095702567242E-5
# Cycle 292
# Total biomass:
# Model iAF1260.cmd: 4.860828143517567E-5
# Model iJN1463.cmd: 1.8797714573163346E-5
# Cycle 293
# Total biomass:
# Model iAF1260.cmd: 4.874331993462209E-5
# Model iJN1463.cmd: 1.888917716566661E-5
# Cycle 294
# Total biomass:
# Model iAF1260.cmd: 4.887795990707154E-5
# Model iJN1463.cmd: 1.898116093601238E-5
# Cycle 295
# Total biomass:
# Model iAF1260.cmd: 4.9011942797073845E-5
# Model iJN1463.cmd: 1.9073683283995253E-5
# Cycle 296
# Total biomass:
# Model iAF1260.cmd: 4.9145113495710596E-5
# Model iJN1463.cmd: 1.9166581271869724E-5
# Cycle 297
# Total biomass:
# Model iAF1260.cmd: 4.9280196041190716E-5
# Model iJN1463.cmd: 1.925898037437946E-5
# Cycle 298
# Total biomass:
# Model iAF1260.cmd: 4.94160875557982E-5
# Model iJN1463.cmd: 1.9352220178120928E-5
# Cycle 299
# Total biomass:
# Model iAF1260.cmd: 4.9550980331615045E-5
# Model iJN1463.cmd: 1.944598793521416E-5
# Cycle 300
# Total biomass:
# Model iAF1260.cmd: 4.9685631646085537E-5
# Model iJN1463.cmd: 1.9540349852773412E-5
# Cycle 301
# Total biomass:
# Model iAF1260.cmd: 4.9819615508498856E-5
# Model iJN1463.cmd: 1.963449252018715E-5
# Cycle 302
# Total biomass:
# Model iAF1260.cmd: 4.9952879187285554E-5
# Model iJN1463.cmd: 1.972915941189113E-5
# Cycle 303
# Total biomass:
# Model iAF1260.cmd: 5.0085186616511116E-5
# Model iJN1463.cmd: 1.982434998508122E-5
# Cycle 304
# Total biomass:
# Model iAF1260.cmd: 5.0215806251103545E-5
# Model iJN1463.cmd: 1.9920089223509334E-5
# Cycle 305
# Total biomass:
# Model iAF1260.cmd: 5.0344631844495E-5
# Model iJN1463.cmd: 2.0016907831443137E-5
# Cycle 306
# Total biomass:
# Model iAF1260.cmd: 5.047404776102432E-5
# Model iJN1463.cmd: 2.011228207595761E-5
# Cycle 307
# Total biomass:
# Model iAF1260.cmd: 5.0602972754890074E-5
# Model iJN1463.cmd: 2.020757621214858E-5
# Cycle 308
# Total biomass:
# Model iAF1260.cmd: 5.0731821692125006E-5
# Model iJN1463.cmd: 2.0303093854017133E-5
# Cycle 309
# Total biomass:
# Model iAF1260.cmd: 5.0859789972354054E-5
# Model iJN1463.cmd: 2.0398773721235627E-5
# Cycle 310
# Total biomass:
# Model iAF1260.cmd: 5.0987345499223176E-5
# Model iJN1463.cmd: 2.049495427479262E-5
# Cycle 311
# Total biomass:
# Model iAF1260.cmd: 5.111646895066756E-5
# Model iJN1463.cmd: 2.059067804239941E-5
# Cycle 312
# Total biomass:
# Model iAF1260.cmd: 5.124590485156146E-5
# Model iJN1463.cmd: 2.0685349960412272E-5
# Cycle 313
# Total biomass:
# Model iAF1260.cmd: 5.137333969822677E-5
# Model iJN1463.cmd: 2.0780808049125056E-5
# Cycle 314
# Total biomass:
# Model iAF1260.cmd: 5.1499939758582824E-5
# Model iJN1463.cmd: 2.0876306285775298E-5
# Cycle 315
# Total biomass:
# Model iAF1260.cmd: 5.162582248486453E-5
# Model iJN1463.cmd: 2.0972355162815738E-5
# Cycle 316
# Total biomass:
# Model iAF1260.cmd: 5.1750872845239144E-5
# Model iJN1463.cmd: 2.106853631807958E-5
# Cycle 317
# Total biomass:
# Model iAF1260.cmd: 5.187579213198912E-5
# Model iJN1463.cmd: 2.1164776584601637E-5
# Cycle 318
# Total biomass:
# Model iAF1260.cmd: 5.200136230673738E-5
# Model iJN1463.cmd: 2.1261316688546997E-5
# Cycle 319
# Total biomass:
# Model iAF1260.cmd: 5.2129031212601875E-5
# Model iJN1463.cmd: 2.1355846914859004E-5
# Cycle 320
# Total biomass:
# Model iAF1260.cmd: 5.2254602551953995E-5
# Model iJN1463.cmd: 2.145246483051799E-5
# Cycle 321
# Total biomass:
# Model iAF1260.cmd: 5.23791616781815E-5
# Model iJN1463.cmd: 2.1548630318114642E-5
# Cycle 322
# Total biomass:
# Model iAF1260.cmd: 5.2503222444575436E-5
# Model iJN1463.cmd: 2.1645125752951343E-5
# Cycle 323
# Total biomass:
# Model iAF1260.cmd: 5.2626957205330285E-5
# Model iJN1463.cmd: 2.1741699359686252E-5
# Cycle 324
# Total biomass:
# Model iAF1260.cmd: 5.274990591014991E-5
# Model iJN1463.cmd: 2.1838594369985816E-5
# Cycle 325
# Total biomass:
# Model iAF1260.cmd: 5.2871778696492496E-5
# Model iJN1463.cmd: 2.1936028790087113E-5
# Cycle 326
# Total biomass:
# Model iAF1260.cmd: 5.299419081812807E-5
# Model iJN1463.cmd: 2.2032762414006584E-5
# Cycle 327
# Total biomass:
# Model iAF1260.cmd: 5.311662263792022E-5
# Model iJN1463.cmd: 2.2129510503077404E-5
# Cycle 328
# Total biomass:
# Model iAF1260.cmd: 5.323855924079432E-5
# Model iJN1463.cmd: 2.2226005378219788E-5
# Cycle 329
# Total biomass:
# Model iAF1260.cmd: 5.3359899597157904E-5
# Model iJN1463.cmd: 2.2322970280759273E-5
# Cycle 330
# Total biomass:
# Model iAF1260.cmd: 5.348096205838297E-5
# Model iJN1463.cmd: 2.2420175882949703E-5
# Cycle 331
# Total biomass:
# Model iAF1260.cmd: 5.3601576689588184E-5
# Model iJN1463.cmd: 2.2517560788702406E-5
# Cycle 332
# Total biomass:
# Model iAF1260.cmd: 5.372190852587901E-5
# Model iJN1463.cmd: 2.261521109479714E-5
# Cycle 333
# Total biomass:
# Model iAF1260.cmd: 5.384194224685866E-5
# Model iJN1463.cmd: 2.2713061493789042E-5
# Cycle 334
# Total biomass:
# Model iAF1260.cmd: 5.396131568001139E-5
# Model iJN1463.cmd: 2.2810949566963766E-5
# Cycle 335
# Total biomass:
# Model iAF1260.cmd: 5.408036632271193E-5
# Model iJN1463.cmd: 2.2908319074566513E-5
# Cycle 336
# Total biomass:
# Model iAF1260.cmd: 5.419900035988604E-5
# Model iJN1463.cmd: 2.3005898556596436E-5
# Cycle 337
# Total biomass:
# Model iAF1260.cmd: 5.431714704461468E-5
# Model iJN1463.cmd: 2.310358343986344E-5
# Cycle 338
# Total biomass:
# Model iAF1260.cmd: 5.44349694180893E-5
# Model iJN1463.cmd: 2.320146150828873E-5
# Cycle 339
# Total biomass:
# Model iAF1260.cmd: 5.455248944215476E-5
# Model iJN1463.cmd: 2.3299544676015687E-5
# Cycle 340
# Total biomass:
# Model iAF1260.cmd: 5.466971986577279E-5
# Model iJN1463.cmd: 2.339780447641685E-5
# Cycle 341
# Total biomass:
# Model iAF1260.cmd: 5.47866951976057E-5
# Model iJN1463.cmd: 2.3496312395501218E-5
# Cycle 342
# Total biomass:
# Model iAF1260.cmd: 5.4903433284249306E-5
# Model iJN1463.cmd: 2.359506878942121E-5
# Cycle 343
# Total biomass:
# Model iAF1260.cmd: 5.501996017918838E-5
# Model iJN1463.cmd: 2.369345311941135E-5
# Cycle 344
# Total biomass:
# Model iAF1260.cmd: 5.513622015696898E-5
# Model iJN1463.cmd: 2.3791553554237533E-5
# Cycle 345
# Total biomass:
# Model iAF1260.cmd: 5.5252167303517054E-5
# Model iJN1463.cmd: 2.3889241257161805E-5
# Cycle 346
# Total biomass:
# Model iAF1260.cmd: 5.536765601126118E-5
# Model iJN1463.cmd: 2.398689740737907E-5
# Cycle 347
# Total biomass:
# Model iAF1260.cmd: 5.548275755220956E-5
# Model iJN1463.cmd: 2.408414704612103E-5
# Cycle 348
# Total biomass:
# Model iAF1260.cmd: 5.5597448330283275E-5
# Model iJN1463.cmd: 2.418145758517812E-5
# Cycle 349
# Total biomass:
# Model iAF1260.cmd: 5.571178812374315E-5
# Model iJN1463.cmd: 2.427877875374641E-5
# Cycle 350
# Total biomass:
# Model iAF1260.cmd: 5.582576112120142E-5
# Model iJN1463.cmd: 2.4376184803222186E-5
# Cycle 351
# Total biomass:
# Model iAF1260.cmd: 5.593969224911791E-5
# Model iJN1463.cmd: 2.4473655666535633E-5
# Cycle 352
# Total biomass:
# Model iAF1260.cmd: 5.60533233448191E-5
# Model iJN1463.cmd: 2.4570678316207128E-5
# Cycle 353
# Total biomass:
# Model iAF1260.cmd: 5.616680082409491E-5
# Model iJN1463.cmd: 2.466762043503376E-5
# Cycle 354
# Total biomass:
# Model iAF1260.cmd: 5.628133689102109E-5
# Model iJN1463.cmd: 2.4763849154899418E-5
# Cycle 355
# Total biomass:
# Model iAF1260.cmd: 5.639517461056155E-5
# Model iJN1463.cmd: 2.4859971277881227E-5
# Cycle 356
# Total biomass:
# Model iAF1260.cmd: 5.651049509208512E-5
# Model iJN1463.cmd: 2.4954577125245575E-5
# Cycle 357
# Total biomass:
# Model iAF1260.cmd: 5.662605700086363E-5
# Model iJN1463.cmd: 2.5048724287499366E-5
# Cycle 358
# Total biomass:
# Model iAF1260.cmd: 5.6741892939706644E-5
# Model iJN1463.cmd: 2.514194751452746E-5
# Cycle 359
# Total biomass:
# Model iAF1260.cmd: 5.685772717134937E-5
# Model iJN1463.cmd: 2.5234902897056087E-5
# Cycle 360
# Total biomass:
# Model iAF1260.cmd: 5.697348610093276E-5
# Model iJN1463.cmd: 2.5327636331737045E-5
# Cycle 361
# Total biomass:
# Model iAF1260.cmd: 5.7087037531807215E-5
# Model iJN1463.cmd: 2.5422383529936334E-5
# Cycle 362
# Total biomass:
# Model iAF1260.cmd: 5.7198968667448876E-5
# Model iJN1463.cmd: 2.5517833385719077E-5
# Cycle 363
# Total biomass:
# Model iAF1260.cmd: 5.7309903647422674E-5
# Model iJN1463.cmd: 2.561372881352719E-5
# Cycle 364
# Total biomass:
# Model iAF1260.cmd: 5.74204712918789E-5
# Model iJN1463.cmd: 2.570982922988753E-5
# Cycle 365
# Total biomass:
# Model iAF1260.cmd: 5.753352422605066E-5
# Model iJN1463.cmd: 2.5803530112160925E-5
# Cycle 366
# Total biomass:
# Model iAF1260.cmd: 5.7647807156265734E-5
# Model iJN1463.cmd: 2.5896385315790577E-5
# Cycle 367
# Total biomass:
# Model iAF1260.cmd: 5.776227802471758E-5
# Model iJN1463.cmd: 2.5987559209257494E-5
# Cycle 368
# Total biomass:
# Model iAF1260.cmd: 5.7876829580128645E-5
# Model iJN1463.cmd: 2.607822515544776E-5
# Cycle 369
# Total biomass:
# Model iAF1260.cmd: 5.799008965757657E-5
# Model iJN1463.cmd: 2.6170335564699585E-5
# Cycle 370
# Total biomass:
# Model iAF1260.cmd: 5.810229559735967E-5
# Model iJN1463.cmd: 2.6262297971828066E-5
# Cycle 371
# Total biomass:
# Model iAF1260.cmd: 5.821524880192943E-5
# Model iJN1463.cmd: 2.635345596959657E-5
# Cycle 372
# Total biomass:
# Model iAF1260.cmd: 5.832477771576756E-5
# Model iJN1463.cmd: 2.6446821135884603E-5
# Cycle 373
# Total biomass:
# Model iAF1260.cmd: 5.843339408095949E-5
# Model iJN1463.cmd: 2.65407603071035E-5
# Cycle 374
# Total biomass:
# Model iAF1260.cmd: 5.8540008589069585E-5
# Model iJN1463.cmd: 2.6636961260612105E-5
# Cycle 375
# Total biomass:
# Model iAF1260.cmd: 5.864774654623166E-5
# Model iJN1463.cmd: 2.673231107720517E-5
# Cycle 376
# Total biomass:
# Model iAF1260.cmd: 5.875485050507314E-5
# Model iJN1463.cmd: 2.682675510054151E-5
# Cycle 377
# Total biomass:
# Model iAF1260.cmd: 5.886197891163366E-5
# Model iJN1463.cmd: 2.6920899893563048E-5
# Cycle 378
# Total biomass:
# Model iAF1260.cmd: 5.8969170217436335E-5
# Model iJN1463.cmd: 2.7014914596871503E-5
# Cycle 379
# Total biomass:
# Model iAF1260.cmd: 5.907899575995E-5
# Model iJN1463.cmd: 2.7106658025277612E-5
# Cycle 380
# Total biomass:
# Model iAF1260.cmd: 5.9190797273943636E-5
# Model iJN1463.cmd: 2.719696834968696E-5
# Cycle 381
# Total biomass:
# Model iAF1260.cmd: 5.930351390899021E-5
# Model iJN1463.cmd: 2.728622167296593E-5
# Cycle 382
# Total biomass:
# Model iAF1260.cmd: 5.9413445331456155E-5
# Model iJN1463.cmd: 2.7377639905552465E-5
# Cycle 383
# Total biomass:
# Model iAF1260.cmd: 5.952136833110819E-5
# Model iJN1463.cmd: 2.7470642227767934E-5
# Cycle 384
# Total biomass:
# Model iAF1260.cmd: 5.962879989239476E-5
# Model iJN1463.cmd: 2.756338885592876E-5
# Cycle 385
# Total biomass:
# Model iAF1260.cmd: 5.973545275464496E-5
# Model iJN1463.cmd: 2.7656920940536095E-5
# Cycle 386
# Total biomass:
# Model iAF1260.cmd: 5.98417254975145E-5
# Model iJN1463.cmd: 2.775049341278362E-5
# Cycle 387
# Total biomass:
# Model iAF1260.cmd: 5.994751696717267E-5
# Model iJN1463.cmd: 2.784358244151139E-5
# Cycle 388
# Total biomass:
# Model iAF1260.cmd: 6.005311987116861E-5
# Model iJN1463.cmd: 2.7936601619952832E-5
# Cycle 389
# Total biomass:
# Model iAF1260.cmd: 6.015855342267299E-5
# Model iJN1463.cmd: 2.8029527857474594E-5
# Cycle 390
# Total biomass:
# Model iAF1260.cmd: 6.026379633003349E-5
# Model iJN1463.cmd: 2.8122346937340723E-5
# Cycle 391
# Total biomass:
# Model iAF1260.cmd: 6.036879310572214E-5
# Model iJN1463.cmd: 2.821507701184273E-5
# Cycle 392
# Total biomass:
# Model iAF1260.cmd: 6.047364217501634E-5
# Model iJN1463.cmd: 2.8307764813937054E-5
# Cycle 393
# Total biomass:
# Model iAF1260.cmd: 6.0578196532006986E-5
# Model iJN1463.cmd: 2.8400467987270124E-5
# Cycle 394
# Total biomass:
# ...
# Model iJN1463.cmd: 5.291258266171123E-5
# Cycle 850
# Total biomass:
# Model iAF1260.cmd: 9.022607838938864E-5
# Model iJN1463.cmd: 5.293471384733077E-5
# Cycle 851
# Total biomass:
# Model iAF1260.cmd: 9.026141038905249E-5
# Model iJN1463.cmd: 5.295678662801781E-5
# Cycle 852
# Total biomass:
# Model iAF1260.cmd: 9.029667979442993E-5
# Model iJN1463.cmd: 5.297877982164362E-5
# Cycle 853
# Total biomass:
# Model iAF1260.cmd: 9.033185993327826E-5
# Model iJN1463.cmd: 5.300056452464137E-5
# Cycle 854
# Total biomass:
# Model iAF1260.cmd: 9.03670098655599E-5
# Model iJN1463.cmd: 5.302229449673009E-5
# Cycle 855
# Total biomass:
# Model iAF1260.cmd: 9.040210819008676E-5
# Model iJN1463.cmd: 5.3043947784705814E-5
# Cycle 856
# Total biomass:
# Model iAF1260.cmd: 9.043712325453745E-5
# Model iJN1463.cmd: 5.306539711432913E-5
# Cycle 857
# Total biomass:
# Model iAF1260.cmd: 9.047211185205888E-5
# Model iJN1463.cmd: 5.308680191613943E-5
# Cycle 858
# Total biomass:
# Model iAF1260.cmd: 9.050705062681737E-5
# Model iJN1463.cmd: 5.3108127601238956E-5
# Cycle 859
# Total biomass:
# Model iAF1260.cmd: 9.05419101271153E-5
# Model iJN1463.cmd: 5.3129250778320384E-5
# Cycle 860
# Total biomass:
# Model iAF1260.cmd: 9.057675112521312E-5
# Model iJN1463.cmd: 5.3150340889682575E-5
# Cycle 861
# Total biomass:
# Model iAF1260.cmd: 9.061155637168893E-5
# Model iJN1463.cmd: 5.317134334383949E-5
# Cycle 862
# Total biomass:
# Model iAF1260.cmd: 9.064628421603363E-5
# Model iJN1463.cmd: 5.319212468762578E-5
# Cycle 863
# Total biomass:
# Model iAF1260.cmd: 9.068102371997472E-5
# Model iJN1463.cmd: 5.3212860772851934E-5
# Cycle 864
# Total biomass:
# Model iAF1260.cmd: 9.071572430662893E-5
# Model iJN1463.cmd: 5.323350659555445E-5
# Cycle 865
# Total biomass:
# Model iAF1260.cmd: 9.07503442522072E-5
# Model iJN1463.cmd: 5.3253925070156436E-5
# Cycle 866
# Total biomass:
# Model iAF1260.cmd: 9.078497860598835E-5
# Model iJN1463.cmd: 5.3274302389777435E-5
# Cycle 867
# Total biomass:
# Model iAF1260.cmd: 9.081958578214379E-5
# Model iJN1463.cmd: 5.329458707230169E-5
# Cycle 868
# Total biomass:
# Model iAF1260.cmd: 9.085414436832974E-5
# Model iJN1463.cmd: 5.331477423923136E-5
# Cycle 869
# Total biomass:
# Model iAF1260.cmd: 9.088858956343223E-5
# Model iJN1463.cmd: 5.3334738371926977E-5
# Cycle 870
# Total biomass:
# Model iAF1260.cmd: 9.092308310709911E-5
# Model iJN1463.cmd: 5.3354674542236274E-5
# Cycle 871
# Total biomass:
# Model iAF1260.cmd: 9.095752502235598E-5
# Model iJN1463.cmd: 5.337453653079513E-5
# Cycle 872
# Total biomass:
# Model iAF1260.cmd: 9.099191580774704E-5
# Model iJN1463.cmd: 5.3394308561430744E-5
# Cycle 873
# Total biomass:
# Model iAF1260.cmd: 9.102625763334527E-5
# Model iJN1463.cmd: 5.341398348592597E-5
# Cycle 874
# Total biomass:
# Model iAF1260.cmd: 9.106057517303877E-5
# Model iJN1463.cmd: 5.34335580429752E-5
# Cycle 875
# Total biomass:
# Model iAF1260.cmd: 9.109482826540978E-5
# Model iJN1463.cmd: 5.345303617665319E-5
# Cycle 876
# Total biomass:
# Model iAF1260.cmd: 9.11290597428986E-5
# Model iJN1463.cmd: 5.3472409294761026E-5
# Cycle 877
# Total biomass:
# Model iAF1260.cmd: 9.116324909661614E-5
# Model iJN1463.cmd: 5.34916849183936E-5
# Cycle 878
# Total biomass:
# Model iAF1260.cmd: 9.119885817174476E-5
# Model iJN1463.cmd: 5.3512095797336845E-5
# Cycle 879
# Total biomass:
# Model iAF1260.cmd: 9.123973218425683E-5
# Model iJN1463.cmd: 5.352775420798002E-5
# Cycle 880
# Total biomass:
# Model iAF1260.cmd: 9.127639881103095E-5
# Model iJN1463.cmd: 5.353952908652868E-5
# Cycle 881
# Total biomass:
# Model iAF1260.cmd: 9.130849254520733E-5
# Model iJN1463.cmd: 5.3553161737183786E-5
# Cycle 882
# Total biomass:
# Model iAF1260.cmd: 9.134057837596008E-5
# Model iJN1463.cmd: 5.356814528730907E-5
# Cycle 883
# Total biomass:
# Model iAF1260.cmd: 9.137502600803086E-5
# Model iJN1463.cmd: 5.358515309181877E-5
# Cycle 884
# Total biomass:
# Model iAF1260.cmd: 9.14090004195278E-5
# Model iJN1463.cmd: 5.360309659092334E-5
# Cycle 885
# Total biomass:
# Model iAF1260.cmd: 9.144288788934658E-5
# Model iJN1463.cmd: 5.362130406412913E-5
# Cycle 886
# Total biomass:
# Model iAF1260.cmd: 9.147672317112486E-5
# Model iJN1463.cmd: 5.36395846822811E-5
# Cycle 887
# Total biomass:
# Model iAF1260.cmd: 9.151051004027002E-5
# Model iJN1463.cmd: 5.3657837082042596E-5
# Cycle 888
# Total biomass:
# Model iAF1260.cmd: 9.154425593578021E-5
# Model iJN1463.cmd: 5.367602118279963E-5
# Cycle 889
# Total biomass:
# Model iAF1260.cmd: 9.157796270761073E-5
# Model iJN1463.cmd: 5.369412198221394E-5
# Cycle 890
# Total biomass:
# Model iAF1260.cmd: 9.16116342367128E-5
# Model iJN1463.cmd: 5.371212808127238E-5
# Cycle 891
# Total biomass:
# Model iAF1260.cmd: 9.1648189056211E-5
# Model iJN1463.cmd: 5.3732462047011417E-5
# Cycle 892
# Total biomass:
# Model iAF1260.cmd: 9.169130249909014E-5
# Model iJN1463.cmd: 5.3749781724798815E-5
# Cycle 893
# Total biomass:
# Model iAF1260.cmd: 9.172744330894355E-5
# Model iJN1463.cmd: 5.3761088886425193E-5
# Cycle 894
# Total biomass:
# Model iAF1260.cmd: 9.176008954551232E-5
# Model iJN1463.cmd: 5.3772649355261395E-5
# Cycle 895
# Total biomass:
# Model iAF1260.cmd: 9.179101914155682E-5
# Model iJN1463.cmd: 5.3785048420700935E-5
# Cycle 896
# Total biomass:
# Model iAF1260.cmd: 9.182321985863181E-5
# Model iJN1463.cmd: 5.379928051169496E-5
# Cycle 897
# Total biomass:
# Model iAF1260.cmd: 9.185716029813296E-5
# Model iJN1463.cmd: 5.3814886993764004E-5
# Cycle 898
# Total biomass:
# Model iAF1260.cmd: 9.189080489479223E-5
# Model iJN1463.cmd: 5.383140258248691E-5
# Cycle 899
# Total biomass:
# Model iAF1260.cmd: 9.192432254477612E-5
# Model iJN1463.cmd: 5.3848233942175267E-5
# Cycle 900
# Total biomass:
# Model iAF1260.cmd: 9.195765175458231E-5
# Model iJN1463.cmd: 5.386514545379652E-5
# Cycle 901
# Total biomass:
# Model iAF1260.cmd: 9.199097561460374E-5
# Model iJN1463.cmd: 5.388195294597135E-5
# Cycle 902
# Total biomass:
# Model iAF1260.cmd: 9.202424738931316E-5
# Model iJN1463.cmd: 5.389875447642614E-5
# Cycle 903
# Total biomass:
# Model iAF1260.cmd: 9.205744413029941E-5
# Model iJN1463.cmd: 5.391551419518741E-5
# Cycle 904
# Total biomass:
# Model iAF1260.cmd: 9.209056989751693E-5
# Model iJN1463.cmd: 5.393221232470741E-5
# Cycle 905
# Total biomass:
# Model iAF1260.cmd: 9.212362958345605E-5
# Model iJN1463.cmd: 5.394883878479202E-5
# Cycle 906
# Total biomass:
# Model iAF1260.cmd: 9.215662600474312E-5
# Model iJN1463.cmd: 5.39653897421738E-5
# Cycle 907
# Total biomass:
# Model iAF1260.cmd: 9.218956041266332E-5
# Model iJN1463.cmd: 5.398186334442403E-5
# Cycle 908
# Total biomass:
# Model iAF1260.cmd: 9.222243332328134E-5
# Model iJN1463.cmd: 5.3998259130207906E-5
# Cycle 909
# Total biomass:
# Model iAF1260.cmd: 9.225672724448485E-5
# Model iJN1463.cmd: 5.401582681429382E-5
# Cycle 910
# Total biomass:
# Model iAF1260.cmd: 9.229336851170294E-5
# Model iJN1463.cmd: 5.402833631706827E-5
# Cycle 911
# Total biomass:
# Model iAF1260.cmd: 9.232694031365268E-5
# Model iJN1463.cmd: 5.403794732514378E-5
# Cycle 912
# Total biomass:
# Model iAF1260.cmd: 9.235781252903259E-5
# Model iJN1463.cmd: 5.4049569623171226E-5
# Cycle 913
# Total biomass:
# Model iAF1260.cmd: 9.239091137717765E-5
# Model iJN1463.cmd: 5.406310500353975E-5
# Cycle 914
# Total biomass:
# Model iAF1260.cmd: 9.242390577503243E-5
# Model iJN1463.cmd: 5.407773224906413E-5
# Cycle 915
# Total biomass:
# Model iAF1260.cmd: 9.245818869777052E-5
# Model iJN1463.cmd: 5.4094208166786096E-5
# Cycle 916
# Total biomass:
# Model iAF1260.cmd: 9.24944338362213E-5
# Model iJN1463.cmd: 5.410619988564528E-5
# Cycle 917
# Total biomass:
# Model iAF1260.cmd: 9.252762436617071E-5
# Model iJN1463.cmd: 5.4115510849021673E-5
# Cycle 918
# Total biomass:
# Model iAF1260.cmd: 9.255769833819576E-5
# Model iJN1463.cmd: 5.412680361197339E-5
# Cycle 919
# Total biomass:
# Model iAF1260.cmd: 9.259051857534257E-5
# Model iJN1463.cmd: 5.413982478619645E-5
# Cycle 920
# Total biomass:
# Model iAF1260.cmd: 9.262420709735927E-5
# Model iJN1463.cmd: 5.415326474732681E-5
# Cycle 921
# Total biomass:
# Model iAF1260.cmd: 9.266008425356622E-5
# Model iJN1463.cmd: 5.416768758325389E-5
# Cycle 922
# Total biomass:
# Model iAF1260.cmd: 9.269799770924376E-5
# Model iJN1463.cmd: 5.418019112177457E-5
# Cycle 923
# Total biomass:
# Model iAF1260.cmd: 9.273820994797288E-5
# Model iJN1463.cmd: 5.419970383158137E-5
# Cycle 924
# Total biomass:
# Model iAF1260.cmd: 9.276975794752146E-5
# Model iJN1463.cmd: 5.42125129502125E-5
# Cycle 925
# Total biomass:
# Model iAF1260.cmd: 9.28035933218244E-5
# Model iJN1463.cmd: 5.4222943692488686E-5
# Cycle 926
# Total biomass:
# Model iAF1260.cmd: 9.283880486023656E-5
# Model iJN1463.cmd: 5.423226357812226E-5
# Cycle 927
# Total biomass:
# Model iAF1260.cmd: 9.287409782690519E-5
# Model iJN1463.cmd: 5.424148240464347E-5
# Cycle 928
# Total biomass:
# Model iAF1260.cmd: 9.290729471598554E-5
# Model iJN1463.cmd: 5.425164986959491E-5
# Cycle 929
# Total biomass:
# Model iAF1260.cmd: 9.293928527715228E-5
# Model iJN1463.cmd: 5.426233547467136E-5
# Cycle 930
# Total biomass:
# Model iAF1260.cmd: 9.297213947499881E-5
# Model iJN1463.cmd: 5.427404115195896E-5
# Cycle 931
# Total biomass:
# Model iAF1260.cmd: 9.300743865159027E-5
# Model iJN1463.cmd: 5.4287280405121564E-5
# Cycle 932
# Total biomass:
# Model iAF1260.cmd: 9.304360883000144E-5
# Model iJN1463.cmd: 5.430116024758646E-5
# Cycle 933
# Total biomass:
# Model iAF1260.cmd: 9.307819981658649E-5
# Model iJN1463.cmd: 5.431625238917881E-5
# Cycle 934
# Total biomass:
# Model iAF1260.cmd: 9.311252013040318E-5
# Model iJN1463.cmd: 5.433208214960362E-5
# Cycle 935
# Total biomass:
# Model iAF1260.cmd: 9.314960467479621E-5
# Model iJN1463.cmd: 5.434348604369067E-5
# Cycle 936
# Total biomass:
# Model iAF1260.cmd: 9.31843416444999E-5
# Model iJN1463.cmd: 5.435260357897279E-5
# Cycle 937
# Total biomass:
# Model iAF1260.cmd: 9.321587830174258E-5
# Model iJN1463.cmd: 5.43634629652495E-5
# Cycle 938
# Total biomass:
# Model iAF1260.cmd: 9.325065270935807E-5
# Model iJN1463.cmd: 5.437614401604206E-5
# Cycle 939
# Total biomass:
# Model iAF1260.cmd: 9.328641208407814E-5
# Model iJN1463.cmd: 5.43893627604745E-5
# Cycle 940
# Total biomass:
# Model iAF1260.cmd: 9.332083071175551E-5
# Model iJN1463.cmd: 5.440388172367791E-5
# Cycle 941
# Total biomass:
# Model iAF1260.cmd: 9.335498742484557E-5
# Model iJN1463.cmd: 5.4419260330855053E-5
# Cycle 942
# Total biomass:
# Model iAF1260.cmd: 9.339165383010684E-5
# Model iJN1463.cmd: 5.4430358889301055E-5
# Cycle 943
# Total biomass:
# Model iAF1260.cmd: 9.34258696481283E-5
# Model iJN1463.cmd: 5.4439124530911006E-5
# Cycle 944
# Total biomass:
# Model iAF1260.cmd: 9.345982683869135E-5
# Model iJN1463.cmd: 5.4447664285132586E-5
# Cycle 945
# Total biomass:
# Model iAF1260.cmd: 9.349397746549657E-5
# Model iJN1463.cmd: 5.445975729197379E-5
# Cycle 946
# Total biomass:
# Model iAF1260.cmd: 9.352941334028932E-5
# Model iJN1463.cmd: 5.447257956074459E-5
# Cycle 947
# Total biomass:
# Model iAF1260.cmd: 9.356354767388851E-5
# Model iJN1463.cmd: 5.448670035381954E-5
# Cycle 948
# Total biomass:
# Model iAF1260.cmd: 9.359741418312145E-5
# Model iJN1463.cmd: 5.450155673451762E-5
# Cycle 949
# Total biomass:
# Model iAF1260.cmd: 9.363380001907295E-5
# Model iJN1463.cmd: 5.4512576020060666E-5
# Cycle 950
# Total biomass:
# Model iAF1260.cmd: 9.366754563749662E-5
# Model iJN1463.cmd: 5.452116672352253E-5
# Cycle 951
# Total biomass:
# Model iAF1260.cmd: 9.36987861061609E-5
# Model iJN1463.cmd: 5.453131192073922E-5
# Cycle 952
# Total biomass:
# Model iAF1260.cmd: 9.373300779735314E-5
# Model iJN1463.cmd: 5.4543110276016606E-5
# Cycle 953
# Total biomass:
# Model iAF1260.cmd: 9.376843218242052E-5
# Model iJN1463.cmd: 5.455570679117234E-5
# Cycle 954
# Total biomass:
# Model iAF1260.cmd: 9.380228958222565E-5
# Model iJN1463.cmd: 5.45694418976233E-5
# Cycle 955
# Total biomass:
# Model iAF1260.cmd: 9.383592172408189E-5
# Model iJN1463.cmd: 5.4583897266417784E-5
# Cycle 956
# Total biomass:
# Model iAF1260.cmd: 9.387183222917923E-5
# Model iJN1463.cmd: 5.4594617730983166E-5
# Cycle 957
# Total biomass:
# Model iAF1260.cmd: 9.390514390529469E-5
# Model iJN1463.cmd: 5.460294929951249E-5
# Cycle 958
# Total biomass:
# Model iAF1260.cmd: 9.39361571531617E-5
# Model iJN1463.cmd: 5.4612661778756935E-5
# Cycle 959
# Total biomass:
# Model iAF1260.cmd: 9.397030460464448E-5
# Model iJN1463.cmd: 5.462411473244982E-5
# Cycle 960
# Total biomass:
# Model iAF1260.cmd: 9.400554633253944E-5
# Model iJN1463.cmd: 5.463629106906871E-5
# Cycle 961
# Total biomass:
# Model iAF1260.cmd: 9.403920372997337E-5
# Model iJN1463.cmd: 5.4649681695813376E-5
# Cycle 962
# Total biomass:
# Model iAF1260.cmd: 9.407268822705207E-5
# Model iJN1463.cmd: 5.4664071573463983E-5
# Cycle 963
# Total biomass:
# Model iAF1260.cmd: 9.410662647630606E-5
# Model iJN1463.cmd: 5.4673525619638454E-5
# Cycle 964
# Total biomass:
# Model iAF1260.cmd: 9.413916590009371E-5
# Model iJN1463.cmd: 5.468149115902676E-5
# Cycle 965
# Total biomass:
# Model iAF1260.cmd: 9.417114280310685E-5
# Model iJN1463.cmd: 5.469160488482643E-5
# Cycle 966
# Total biomass:
# Model iAF1260.cmd: 9.420449737099882E-5
# Model iJN1463.cmd: 5.470258046721755E-5
# Cycle 967
# Total biomass:
# Model iAF1260.cmd: 9.423791618724186E-5
# Model iJN1463.cmd: 5.471473271983604E-5
# Cycle 968
# Total biomass:
# Model iAF1260.cmd: 9.426951605006333E-5
# Model iJN1463.cmd: 5.472718317092724E-5
# Cycle 969
# Total biomass:
# Model iAF1260.cmd: 9.430177593853579E-5
# Model iJN1463.cmd: 5.474085008103031E-5
# Cycle 970
# Total biomass:
# Model iAF1260.cmd: 9.433638606451811E-5
# Model iJN1463.cmd: 5.4750940350983254E-5
# Cycle 971
# Total biomass:
# Model iAF1260.cmd: 9.436860521589638E-5
# Model iJN1463.cmd: 5.475875282784205E-5
# Cycle 972
# Total biomass:
# Model iAF1260.cmd: 9.439777510670503E-5
# Model iJN1463.cmd: 5.476703831546737E-5
# Cycle 973
# Total biomass:
# Model iAF1260.cmd: 9.443059665050324E-5
# Model iJN1463.cmd: 5.4777528260211684E-5
# Cycle 974
# Total biomass:
# Model iAF1260.cmd: 9.446205389478258E-5
# Model iJN1463.cmd: 5.4788311925239054E-5
# Cycle 975
# Total biomass:
# Model iAF1260.cmd: 9.449256547667859E-5
# Model iJN1463.cmd: 5.480003170033964E-5
# Cycle 976
# Total biomass:
# Model iAF1260.cmd: 9.452251543274836E-5
# Model iJN1463.cmd: 5.481200244487723E-5
# Cycle 977
# Total biomass:
# Model iAF1260.cmd: 9.455541622920044E-5
# Model iJN1463.cmd: 5.4826442597841074E-5
# Cycle 978
# Total biomass:
# Model iAF1260.cmd: 9.458962671008141E-5
# Model iJN1463.cmd: 5.483636599450505E-5
# Cycle 979
# Total biomass:
# Model iAF1260.cmd: 9.461988029691492E-5
# Model iJN1463.cmd: 5.484315284465043E-5
# Cycle 980
# Total biomass:
# Model iAF1260.cmd: 9.464789138991589E-5
# Model iJN1463.cmd: 5.485071945552156E-5
# Cycle 981
# Total biomass:
# Model iAF1260.cmd: 9.467802549014152E-5
# Model iJN1463.cmd: 5.485947623220552E-5
# Cycle 982
# Total biomass:
# Model iAF1260.cmd: 9.470809526363795E-5
# Model iJN1463.cmd: 5.486936236830852E-5
# Cycle 983
# Total biomass:
# Model iAF1260.cmd: 9.473711235646067E-5
# Model iJN1463.cmd: 5.488004208108671E-5
# Cycle 984
# Total biomass:
# Model iAF1260.cmd: 9.476567607023212E-5
# Model iJN1463.cmd: 5.489102115174037E-5
# Cycle 985
# Total biomass:
# Model iAF1260.cmd: 9.479563401671477E-5
# Model iJN1463.cmd: 5.4903233798245486E-5
# Cycle 986
# Total biomass:
# Model iAF1260.cmd: 9.482866359173458E-5
# Model iJN1463.cmd: 5.4912510391804774E-5
# Cycle 987
# Total biomass:
# Model iAF1260.cmd: 9.485817124284863E-5
# Model iJN1463.cmd: 5.491895060836876E-5
# Cycle 988
# Total biomass:
# Model iAF1260.cmd: 9.488497435370715E-5
# Model iJN1463.cmd: 5.492573847953668E-5
# Cycle 989
# Total biomass:
# Model iAF1260.cmd: 9.491367843704819E-5
# Model iJN1463.cmd: 5.493361686191199E-5
# Cycle 990
# Total biomass:
# Model iAF1260.cmd: 9.494405626643294E-5
# Model iJN1463.cmd: 5.494246410890429E-5
# Cycle 991
# Total biomass:
# Model iAF1260.cmd: 9.4973726847558E-5
# Model iJN1463.cmd: 5.4952028770044925E-5
# Cycle 992
# Total biomass:
# Model iAF1260.cmd: 9.500228696373695E-5
# Model iJN1463.cmd: 5.4962330776284855E-5
# Cycle 993
# Total biomass:
# Model iAF1260.cmd: 9.503193734641974E-5
# Model iJN1463.cmd: 5.4974037199819105E-5
# Cycle 994
# Total biomass:
# Model iAF1260.cmd: 9.506441954318667E-5
# Model iJN1463.cmd: 5.498297851097727E-5
# Cycle 995
# Total biomass:
# Model iAF1260.cmd: 9.509336432984602E-5
# Model iJN1463.cmd: 5.4989102317724726E-5
# Cycle 996
# Total biomass:
# Model iAF1260.cmd: 9.51203720839386E-5
# Model iJN1463.cmd: 5.499603512141652E-5
# Cycle 997
# Total biomass:
# Model iAF1260.cmd: 9.514955625906387E-5
# Model iJN1463.cmd: 5.500410651136756E-5
# Cycle 998
# Total biomass:
# Model iAF1260.cmd: 9.517973359014321E-5
# Model iJN1463.cmd: 5.501274646428693E-5
# Cycle 999
# Total biomass:
# Model iAF1260.cmd: 9.520816809192456E-5
# Model iJN1463.cmd: 5.5022479189584215E-5
# Cycle 1000
# Total biomass:
# Model iAF1260.cmd: 9.523598111994818E-5
# Model iJN1463.cmd: 5.503266133075621E-5
# Cycle 1001
# End of simulation
# Total time = 9392.766s
#
# STDERR empty.

# %% [markdown]
# Para revisar la biomasa total

# %%
sim.total_biomass.plot(x = "cycle")
# Out:
# <AxesSubplot:xlabel='cycle'>

# %% [markdown]
# Graficamos los resultados de biomasa y demás metabolitos interesantes en el grid:

# %%
im = sim.get_biomass_image('iAF1260', params.all_params['maxCycles'])
im2 = sim.get_biomass_image('iJN1463',params.all_params['maxCycles'])

final = np.zeros((grid_size,grid_size,3))
final[:,:,0] = im / np.max(im)
final[:,:,1] = im2 / np.max(im2)
for rock in rock_locs:
    final[rock[0],rock[1],0:3] = 0.4 
from matplotlib import pyplot as plt
ﬁg, ax = plt.subplots(ﬁgsize = (3.1, 3.1))
ax.imshow(ﬁnal)
plt.imshow(final)

# %%
plt.imshow(sim.get_metabolite_image("succ_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("ac_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("nh4_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("o2_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("catechol_e",params.all_params['maxCycles']))
