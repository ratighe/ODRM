# %% [markdown]
# **Soil-air interface.**
#
# Using the functionality of COMETS, one can design simulations which go beyond in silico corollaries of lab experiments to make predictions for environments mimicking natural ecosystems, which is a necessary step for understanding natural ecology from first principles. In this example, we consider a simulation of a soil environment. We use source-and-sink functions to model how a root provides organic acids to the environment while removing ammonia (Huang et al 2014 Botany). While we restrict the root functionality to a source/sink, one could use functionality demonstrated above, for example extracellular enzymes, to generate feedback loops between microbe-produced metabolites and root exudation. We use fixed metabolite concentrations to mimic the largely unchanging air interface above a root, which generates an oxygen gradient. Additionally, since soil is characterized by strong spatial structure with many impenetrable barriers that localized interactions (Nunan 2017), we place “rock” barriers throughout the simulation area. A more complex simulation could use varying diffusion constants for metabolites, as described in a previous protocol (Virtual Petri Dish). Similarly, we use standard diffusion of biomass, but this could be changed to use pushing force or non-linear diffusion for a potentially increased realism.

# %%
import cobra 
import sys 
import copy 
import numpy as np 
from matplotlib import pyplot as plt 
import cometspy as c

# %% [markdown]
# Para nuestro proyecto, utilizaremos Escherichia coli (modelo iAF1260), Pseudomonas putida (modelo iJN1463) y Saccharomyces Cerevisiae (modelo iMM904), recuperados de la base de datos BIGG.
#
# Cambiamos los bounds de las funciones objetivo de los modelos:

# %%
model_dir = "./modelos" # model location
iAF = cobra.io.read_sbml_model(model_dir + '/iAF1260.xml')
iJN = cobra.io.read_sbml_model(model_dir + '/iJN1463.xml')

iAF.reactions.get_by_id('BIOMASS_Ec_iAF1260_core_59p81M').lower_bound = 0
iAF.reactions.get_by_id('BIOMASS_Ec_iAF1260_core_59p81M').upper_bound = 1000

iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').lower_bound = 0
iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').upper_bound = 1000

# %% [markdown]
# Luego se convierten estos modelos al formato de COMETS. Se utilizan funciones helper para dos cosas: a) Asegurar que el modelo en COMETS no confunda las reacciones de "sink" con las de exchange, ya que en COBRA están desbalanceadas y por tanto se parecen a las de exchange, y b) abrir todos los bounds de las reacciones de exchange, para que COMETS controle la composición del medio.

# %%
iAF_comets = c.model(iAF)
iAF_comets.ensure_sinks_are_not_exchanges()
iAF_comets.open_exchanges()

iJN_comets = c.model(iJN)
iJN_comets.ensure_sinks_are_not_exchanges()
iJN_comets.open_exchanges()

# %% [markdown]
# El mundo que se simulará tendrá dimensiones de 30x30. El eje de la izquierda (x = 0) corresponde a la raíz, y el eje superior (y = 0) corresponde al aire. La biomasa y las rocas se distribuyen en el resto del grid. Donde hayan rocas no puede haber ni biomasa ni metabolitos, así que seleccionamos esos lugares primero. Para esta simulación, se generarán 3 rocas con un un tamaño medio de 1 cuadraditos. Para generar las piedras se utiliza la función helper grow_rocks.

# %%
from cometspy.utils import grow_rocks, pick_random_locations

grid_size = 15 # 100
n_rocks = 27 # 70
rock_locs = grow_rocks(n = n_rocks, xrange = [1,grid_size-1],yrange = [1,grid_size-1],mean_size = 1)

# %% [markdown]
# Cada especie será plantada en 20 lugares sin sobreponerse. Para esto se utiliza la función helper pick_random_locations, la cual toma como argumento una tupla generada anteriormente que marca lugares "prohibidos", como los cuadrados donde se encuentran las rocas.
#
# Generamos una copia de rock_locs para no cambiarla accidentalmente, y la llamamos forbbiden_locs:

# %%
import copy
forbidden_locs = copy.deepcopy(rock_locs)

# %% [markdown]
# Ahora elegimos al azar los lugares para cada especie, y los vamos añadiendo a la lista forbidden locs para que no se sobrepongan:

# %%
founders_per_species = 15 # 60
iAF_locs = pick_random_locations(n = founders_per_species, 
                                   xrange = [1,grid_size], yrange = [1,grid_size], 
                                   forbidden_locs = forbidden_locs)
forbidden_locs.extend(iAF_locs)
iJN_locs = pick_random_locations(founders_per_species, [1,grid_size],[1,grid_size], forbidden_locs)

# %% [markdown]
# Para graficar los lugares utilizamos matplotlib:

# %%
from matplotlib import pyplot as plt
initial_image = np.zeros((grid_size,grid_size,3))
for rock in rock_locs:
    initial_image[rock[0],rock[1],0:3] = 0.5 
for loc in iAF_locs:
    initial_image[loc[0],loc[1],1] = 1
for loc in iJN_locs:
    initial_image[loc[0],loc[1],2] = 1
plt.imshow(initial_image)

# %% [markdown]
# Generamos el layout y agregamos las rocas:

# %%
# iAF
iAF_initial_pop = [] 
for loc in iJN_locs: 
    iAF_initial_pop.append([loc[0], loc[1], 1.e-8]) 
iAF_comets.initial_pop = iAF_initial_pop 
# iJN
iJN_initial_pop = [] 
for loc in iJN_locs: 
    iJN_initial_pop.append([loc[0], loc[1], 1.e-6]) 
iJN_comets.initial_pop = iJN_initial_pop

# %% [markdown]
# Setteamos las poblaciones iniciales para cada especie, con esto los modelos están listos y los añadimos al layout:

# %%
layout = c.layout([iAF_comets, iJN_comets])
layout.grid = [grid_size,grid_size]
layout.add_barriers(rock_locs)

# %% [markdown]
# Añadimos los metabolitos que estarán inicialmente disponibles en el ambiente. Usamos la función helper add_typical_trace_metabolites() para las trazas típicas. Bajamos el valor del oxígeno dado que la idea es que el que esté disponible difunda desde la atmósfera. Añadimos algunos metabolitos que no se añadieron con la función helper:

# %%
layout.add_typical_trace_metabolites()
layout.set_specific_metabolite('o2_e',0.000001)
layout.set_specific_metabolite('hco3_e',1000)
layout.set_specific_metabolite('co2_e',1000)
layout.set_specific_metabolite('h2_e',1000)
layout.set_specific_metabolite('so3_e',1000)
layout.set_specific_metabolite('nh4_e',0.0000001)

layout.set_specific_metabolite('glc__D_e',0.0000001)
layout.set_specific_metabolite('meoh_e',0.00000001)
layout.set_specific_metabolite('cys__L_e',0.0000001)
layout.set_specific_metabolite('catechol_e',0.0000001)

# %% [markdown]
# Para la capa de aire, dejamos el oxígeno en un valor constante. Al fondo también dejamos al oxígeno en un valor fijo e igual a 0, para simular el efecto de difusión. De manera similar, hacemos lo mismo con el amoniaco y la raíz en la parte izquierda:

# %%
# set static media of O2 and CO2 at the top and bottom-- the "air" and continuous loss of O2 downwards
for x in range(grid_size):
    layout.set_specific_static_at_location('o2_e', (x,0), .0001) # top
    layout.set_specific_static_at_location('o2_e', (x,grid_size-1), 0.) # bottom
    layout.set_specific_static_at_location('co2_e', (x,0), .0001)
    
for x in range(grid_size):
    layout.set_specific_static_at_location('nh4_e', (0,x), 0.0)

# %% [markdown]
# La raíz consume todo el amoniaco, pero es una fuente de acidos orgánicos y metanol para el ambiente. Asumiendo una tasa fija:

# %%
for x in range(grid_size):
    layout.set_specific_refresh_at_location('cit_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('meoh_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('succ_e', (0,x), .000001)

# %% [markdown]
# El layout y los modelos están listos, ahora setteamos los parámetros de la simulación:

# %%
params = c.params()
params.set_param('timeStep', 0.1)
params.set_param('maxCycles', 1000)
params.set_param('maxSpaceBiomass', 10)
params.set_param('deathRate', 0.0001) # die at rate of 1/10000 per hour
params.set_param('writeBiomassLog', True)
params.set_param('BiomassLogRate', 500)
params.set_param('writeMediaLog', True)
params.set_param('MediaLogRate', 500)
params.set_param("writeFluxLog", True)
params.set_param("FluxLogRate", 500)
params.set_param('numRunThreads', 3)
params.set_param('defaultKm', 0.000001)

# %% [markdown]
# Ahora creamos el objeto de la simulación y la corremos. Ojito que se demora y el pc empieza a despegar.

# %%
sim = c.comets(layout, params)
sim.run(False)
# Out:
# Running COMETS simulation ...
# C:\Users\pabli\AppData\Local\Temp/ipykernel_32672/1491467366.py:2: DtypeWarning: Columns (5,7,8,11,12,14,18,26,31,35,39,42,43,51,52,62,63,64,67,69,72,73,74,75,81,102,103,104,114,116,118,121,122,124,135,136,137,142,146,147,148,149,150,151,155,161,162,165,166,167,175,176,177,181,187,189,192,200,213,217,228,238,254,255,256,274,338,360,363,364,369,370,371,396,402,406,407,408,411,412,413,414,417,420,433,435,440,443,450,453,481,491,495,514,517,518,523,530,544,545,547,554,557,559,560,574,590,594,631,639,640,656,657,670,678,690,691,693,696,698,701,710,718,727,728,729,734,742,744,746,751,758,762,768,769,785,786,788,798,807,811,813,818,821,842,870,871,873,878,883,885,900,909,910,925,944,945,953,954,958,960,967,968,969,974,975,976,977,978,979,981,983,988,1017,1021,1026,1028,1043,1050,1073,1084,1087,1098,1099,1107,1113,1114,1124,1126,1127,1134,1151,1156,1159,1164,1165,1183,1184,1185,1203,1206,1220,1221,1225,1230,1232,1233,1243,1244,1246,1248,1262,1264,1266,1268,1275,1276,1285,1288,1294,1297,1303,1308,1310,1316,1317,1318,1328,1329,1334,1336,1346,1354,1355,1365,1369,1376,1377,1387,1412,1419,1420,1421,1425,1431,1447,1470,1478,1499,1500,1501,1503,1504,1505,1506,1507,1508,1509,1510,1511,1514,1515,1516,1517,1518,1519,1520,1521,1524,1526,1527,1528,1530,1531,1532,1533,1535,1536,1538,1540,1542,1548,1552,1554,1555,1556,1557,1568,1569,1573,1587,1618,1624,1625,1641,1642,1647,1660,1663,1696,1717,1727,1736,1747,1760,1764,1766,1767,1769,1770,1771,1772,1774,1778,1784,1785,1786,1788,1790,1796,1799,1805,1808,1810,1811,1812,1815,1816,1830,1831,1864,1873,1874,1875,1878,1886,1890,1898,1899,1901,1902,1908,1911,1923,1924,1925,1926,1927,1928,1932,1933,1934,1935,1938,1940,1941,1942,1943,1944,1948,1949,1951,1961,1963,1964,1969,1970,1974,1975,1977,1978,1985,1987,1988,1989,1990,1991,1992,1998,1999,2001,2002,2008,2009,2016,2017,2049,2055,2056,2060,2063,2072,2075,2085,2096,2101,2103,2106,2113,2131,2135,2140,2182,2204,2207,2257,2259,2264,2267,2268,2269,2274,2286,2376,2382,2401,2402,2420,2423,2431,2441,2444,2489,2528,2534,2594,2610,2673,2680,2694,2704,2711,2712,2719,2720,2733,2734,2736,2742,2745,2757,2762,2763,2764,2765,2766,2781,2819,2828,2833,2837,2838,2840,2842,2855,2877,2908,2911,2917) have mixed types.Specify dtype option on import or set low_memory=False.
#   sim.run(False)
# Done!

# %%
print(sim.run_output)
print(sim.run_errors)
# Out:
# -script
# running script file: C:\Users\pabli\OneDrive\Escritorio\COMETS\ODRM\simulaciones\2_modelos\Coli_putida_15x15_0.0000001_catechol_cambio_putida\Coli_putida_15x15_0.0000001_catechol_cambio_putida_1e6/.current_script_0x1dc9e4ce820
# Current Java version: 17.0.1
# Parameters file .current_global_0x1dc9e4ce820 loaded.
# Parameters file .current_package_0x1dc9e4ce820 loaded.
# Loading layout file '.current_layout_0x1dc9e4ce820'...
# null\COMETS_manifest.txt (El sistema no puede encontrar la ruta especificada)
# Unable to initialize manifest file.
# Continuing without writing manifest file.
# Found 2 model files!
# Loading '.\iAF1260.cmd' ...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution = 395.73529219628256
# Loading '.\iJN1463.cmd' ...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution = 237.06607191111308
# Constructing world...
# Done!
# medialist	12dgr160_e	12dgr180_e	12ppd__R_e	12ppd__S_e	13dampp_e	14glucan_e	15dap_e	1ag160_e	1ag180_e	1ag181d9_e	1ag182d9d12_e	23camp_e	23ccmp_e	23cgmp_e	23cump_e	23dappa_e	25dkglcn_e	26dap__M_e	2ameph_e	2ddglcn_e	2dhglcn_e	2m35mdntha_e	34dhbz_e	34dhcinm_e	34dhpac_e	34dhphe_e	35dnta_e	3amp_e	3cmp_e	3gmp_e	3h4atb_e	3hcinnm_e	3hpppn_e	3mb_e	3oxoadp_e	3ump_e	4abut_e	4hbz_e	4hoxpacd_e	4hpro_DC_e	4hpro_LT_e	4hptn_e	4oxptn_e	5aptn_e	5dglcn_e	5g2oxpt_e	5mcsn_e	5oxpro_e	6atha_e	6hnac_e	LalaDgluMdapDala_e	LalaDgluMdap_e	LalaLglu_e	Ncbmpts_e	R3hdec4e_e	R_3h4atba_e	R_3h6atha_e	R_3hcmrs7e_e	R_3hdcaa_e	R_3hdd5ea_e	R_3hdd6e_e	R_3hdda_e	R_3hhdca_e	R_3hhpa_e	R_3hhxa_e	R_3hnonaa_e	R_3hocta_e	R_3hpba_e	R_3hpdeca_e	R_3hphpa_e	R_3hphxa_e	R_3hpnona_e	R_3hpocta_e	R_3hppta_e	R_3hpt_e	R_3htd58e_e	R_3htd5e_e	R_3httdca_e	T4hcinnm_e	ac_e	acac_e	acald_e	acgal1p_e	acgal_e	acgam1p_e	acgam_e	acmana_e	acmtsoxin_e	acmum_e	acnam_e	acolipa_e	acon_C_e	acpptrn_e	acser_e	actn__R_e	ade_e	adn_e	adocbl_e	ag_e	agm_e	akg_e	ala_B_e	ala__D_e	ala__L_e	alaala_e	alahis_e	alaleu_e	alathr_e	alatrp_e	algac_MG_14_e	algac_MG_23_e	algac_MG_32_e	algac_MG_41_e	algac__M_e	all__D_e	alltn_e	amp_e	anhgm_e	apc_e	arab__L_e	arbtn_e	arbtn_fe3_e	arg__D_e	arg__L_e	ascb__L_e	asn__D_e	asn__L_e	aso3_e	aso4_e	asp__L_e	balaala_e	balabala_e	balagly_e	balaleu_e	balamd_e	bhb_e	biliverd_e	btd_RR_e	btn_e	but_e	butso3_e	bz_e	ca2_e	carn_e	catechol_e	cbi_e	cbl1_e	cd2_e	cell4_e	cgly_e	chol_e	chols_e	chor_e	cinnm_e	cit_e	cl_e	cm_e	cmcbtt_e	cmp_e	co2_e	co_e	cobalt2_e	colipa_e	confrl_e	cpgn_e	cpgn_un_e	creat_e	crn_e	cro2_e	cro4_e	crtn_e	csn_e	cu2_e	cu_e	cyan_e	cynt_e	cys__D_e	cys__L_e	cytd_e	d2one_e	d3one_e	d4one_e	dad_2_e	dag181d9_e	dag182d9d12_e	damp_e	dca_e	dcmp_e	dcyt_e	ddca_e	dgmp_e	dgsn_e	dgudbutn_e	dha_e	dimp_e	din_e	dmanur_e	dmgly_e	dms_e	dmso2_e	dmso_e	dopa_e	dtmp_e	dump_e	duri_e	eca4colipa_e	ecto__L_e	enlipa_e	enter_e	etha_e	ethso3_e	etoh_e	f6p_e	fald_e	fcmcbtt_e	fe2_e	fe3_e	fe3dcit_e	fe3dhbzs_e	fe3hox_e	fe3hox_un_e	fe3mcbtt_e	fe3pyovd_e	fe3pyovd_kt_e	fecrm_e	fecrm_un_e	feenter_e	feoxam_e	feoxam_un_e	fer_e	for_e	fru_e	frulys_e	fruur_e	fuc__L_e	fum_e	g1p_e	g3pc_e	g3pe_e	g3pg_e	g3pi_e	g3ps_e	g6p_e	ga_e	gal1p_e	gal_bD_e	gal_e	galct__D_e	galctn__D_e	galctn__L_e	galt_e	galur_e	gam6p_e	gam_e	gbbtn_e	gdp_e	glc__D_e	glcn_e	glcr_e	glcur1p_e	glcur_e	gln__L_e	glu__L_e	glutar_e	gly_e	glyald_e	glyb_e	glyc2p_e	glyc3p_e	glyc__R_e	glyc_e	glyclt_e	glycol_e	glygln_e	glyglu_e	glygly_e	glymet_e	glyphe_e	glyser_e	gmp_e	gsn_e	gthox_e	gthrd_e	gtp_e	gua_e	gudac_e	gudptn_e	h2_e	h2o2_e	h2o_e	h2s_e	h_e	hacolipa_e	halipa_e	hco3_e	hcys__L_e	hdca_e	hdcea_e	hg2_e	hgentis_e	his__L_e	hisgly_e	hishis_e	hom__L_e	hpta_e	hxa_e	hxan_e	icit_e	idon__L_e	ile__L_e	imp_e	ind3ac_e	indole_e	inost_e	ins_e	isetac_e	k_e	kdo2lipid4_e	lac__D_e	lac__L_e	lcts_e	leu__D_e	leu__L_e	leuleu_e	lipa_cold_e	lipa_e	lnlc_e	lpspput_e	lys__D_e	lys__L_e	lyx__L_e	m_xyl_e	mal__D_e	mal__L_e	malt_e	malthx_e	maltpt_e	malttr_e	maltttr_e	man6p_e	man_e	manglyc_e	manur_e	mcbtt_e	melib_e	meoh_e	met__D_e	met__L_e	metsox_R__L_e	metsox_S__L_e	mg2_e	minohp_e	mmet_e	mn2_e	mnl_e	mobd_e	mso3_e	mtsoxin_e	n2o_e	n2one_e	na1_e	nac_e	nh4_e	ni2_e	nmn_e	no2_e	no3_e	no_e	nona_e	o16a4colipa_e	o2_e	o2s_e	o_xyl_e	oaa_e	ocdca_e	ocdcea_e	octa_e	orn__D_e	orn_e	orot_e	oxa_e	p_xyl_e	pac_e	pacald_e	pb2_e	pea_e	peamn_e	pentso3_e	phe__D_e	phe__L_e	phedca_e	phehpa_e	phehxa_e	pheme_e	phenona_e	pheocta_e	phept_e	phpyr_e	pi_e	pnto__R_e	ppa_e	ppal_e	ppi_e	pppn_e	ppt_e	pptrn_e	prealg_MG_14_e	prealg_MG_23_e	prealg_MG_32_e	prealg_MG_41_e	prealginate_G_e	pro__D_e	pro__L_e	progly_e	psclys_e	pser__L_e	pta_e	ptrc_e	ptsla_e	pydam_e	pyovd_e	pyovd_kt_e	pyr_e	quin_e	r5p_e	rib__D_e	rmn_e	sbo3_e	sbt__D_e	sel_e	ser__D_e	ser__L_e	sheme_e	skm_e	so2_e	so3_e	so4_e	spmd_e	succ_e	sucr_e	sulfac_e	tag160_e	tag180_e	tag181d9_e	tag182d9d12_e	tartr__L_e	taur_e	tcynt_e	thm_e	thr__L_e	thrp_e	thym_e	thymd_e	tma_e	tmanur_e	tmao_e	tnt_e	tol_e	tre_e	trp__L_e	tsul_e	ttdca_e	ttdcea_e	ttrcyc_e	tungs_e	tym_e	tyr__D_e	tyr__L_e	tyrp_e	uacg ...
# Cycle 1
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# FBARunThread-0 starting up.
# FBARunThread-1 starting up.
# FBARunThread-2 starting up.
# Total biomass:
# Model iAF1260.cmd: 1.5792461044289926E-7
# Model iJN1463.cmd: 1.5280718991267883E-5
# Cycle 2
# Total biomass:
# Model iAF1260.cmd: 1.662474233396917E-7
# Model iJN1463.cmd: 1.554300728320561E-5
# Cycle 3
# Total biomass:
# Model iAF1260.cmd: 1.7576623364090008E-7
# Model iJN1463.cmd: 1.5800335707732065E-5
# Cycle 4
# Total biomass:
# Model iAF1260.cmd: 1.862557473937782E-7
# Model iJN1463.cmd: 1.6056819723810308E-5
# Cycle 5
# Total biomass:
# Model iAF1260.cmd: 1.976930469100223E-7
# Model iJN1463.cmd: 1.631402557628655E-5
# Cycle 6
# Total biomass:
# Model iAF1260.cmd: 2.1009181400154754E-7
# Model iJN1463.cmd: 1.6572719378641207E-5
# Cycle 7
# Total biomass:
# Model iAF1260.cmd: 2.2345834870404966E-7
# Model iJN1463.cmd: 1.6833700047390685E-5
# Cycle 8
# Total biomass:
# Model iAF1260.cmd: 2.3770189583178605E-7
# Model iJN1463.cmd: 1.709817733748325E-5
# Cycle 9
# Total biomass:
# Model iAF1260.cmd: 2.52734661837542E-7
# Model iJN1463.cmd: 1.7366836330649312E-5
# Cycle 10
# Total biomass:
# Model iAF1260.cmd: 2.684353475353167E-7
# Model iJN1463.cmd: 1.7640178759867227E-5
# Cycle 11
# Total biomass:
# Model iAF1260.cmd: 2.8464352593640214E-7
# Model iJN1463.cmd: 1.7918135164154E-5
# Cycle 12
# Total biomass:
# Model iAF1260.cmd: 3.0113041296794935E-7
# Model iJN1463.cmd: 1.8201655885946927E-5
# Cycle 13
# Total biomass:
# Model iAF1260.cmd: 3.1771454028748045E-7
# Model iJN1463.cmd: 1.8491559381112407E-5
# Cycle 14
# Total biomass:
# Model iAF1260.cmd: 3.3431043170201795E-7
# Model iJN1463.cmd: 1.878800493684492E-5
# Cycle 15
# Total biomass:
# Model iAF1260.cmd: 3.5085572457485443E-7
# Model iJN1463.cmd: 1.9089680694188952E-5
# Cycle 16
# Total biomass:
# Model iAF1260.cmd: 3.673703157309314E-7
# Model iJN1463.cmd: 1.9396356146139776E-5
# Cycle 17
# Total biomass:
# Model iAF1260.cmd: 3.838572025679507E-7
# Model iJN1463.cmd: 1.970738026566807E-5
# Cycle 18
# Total biomass:
# Model iAF1260.cmd: 4.002961828203386E-7
# Model iJN1463.cmd: 2.0021381270759583E-5
# Cycle 19
# Total biomass:
# Model iAF1260.cmd: 4.167331906728314E-7
# Model iJN1463.cmd: 2.0336791896255746E-5
# Cycle 20
# Total biomass:
# Model iAF1260.cmd: 4.3313996349620206E-7
# Model iJN1463.cmd: 2.0654944001979914E-5
# Cycle 21
# Total biomass:
# Model iAF1260.cmd: 4.4947775649234874E-7
# Model iJN1463.cmd: 2.0976737494860168E-5
# Cycle 22
# Total biomass:
# Model iAF1260.cmd: 4.6585887932320276E-7
# Model iJN1463.cmd: 2.1300121890511735E-5
# Cycle 23
# Total biomass:
# Model iAF1260.cmd: 4.823444770863573E-7
# Model iJN1463.cmd: 2.1625816615551504E-5
# Cycle 24
# Total biomass:
# Model iAF1260.cmd: 4.990054911224481E-7
# Model iJN1463.cmd: 2.1953584520740378E-5
# Cycle 25
# Total biomass:
# Model iAF1260.cmd: 5.158411189685022E-7
# Model iJN1463.cmd: 2.228151971075512E-5
# Cycle 26
# Total biomass:
# Model iAF1260.cmd: 5.328553602934533E-7
# Model iJN1463.cmd: 2.2607201906940507E-5
# Cycle 27
# Total biomass:
# Model iAF1260.cmd: 5.501057258055403E-7
# Model iJN1463.cmd: 2.2925892136506666E-5
# Cycle 28
# Total biomass:
# Model iAF1260.cmd: 5.676038601731524E-7
# Model iJN1463.cmd: 2.323664769681957E-5
# Cycle 29
# Total biomass:
# Model iAF1260.cmd: 5.854044057567763E-7
# Model iJN1463.cmd: 2.353860060180936E-5
# Cycle 30
# Total biomass:
# Model iAF1260.cmd: 6.03600766780449E-7
# Model iJN1463.cmd: 2.3831983396551866E-5
# Cycle 31
# Total biomass:
# Model iAF1260.cmd: 6.222102517527703E-7
# Model iJN1463.cmd: 2.4117158121736915E-5
# Cycle 32
# Total biomass:
# Model iAF1260.cmd: 6.412385750080845E-7
# Model iJN1463.cmd: 2.4394611554210973E-5
# Cycle 33
# Total biomass:
# Model iAF1260.cmd: 6.606943986363081E-7
# Model iJN1463.cmd: 2.4665239547135568E-5
# Cycle 34
# Total biomass:
# Model iAF1260.cmd: 6.805895148438776E-7
# Model iJN1463.cmd: 2.492861842868155E-5
# Cycle 35
# Total biomass:
# Model iAF1260.cmd: 7.007580910097104E-7
# Model iJN1463.cmd: 2.5184803868600196E-5
# Cycle 36
# Total biomass:
# Model iAF1260.cmd: 7.212038939625553E-7
# Model iJN1463.cmd: 2.543281360380344E-5
# Cycle 37
# Total biomass:
# Model iAF1260.cmd: 7.42005958516491E-7
# Model iJN1463.cmd: 2.5672804490462936E-5
# Cycle 38
# Total biomass:
# Model iAF1260.cmd: 7.632759729495082E-7
# Model iJN1463.cmd: 2.590565076453805E-5
# Cycle 39
# Total biomass:
# Model iAF1260.cmd: 7.847776760839691E-7
# Model iJN1463.cmd: 2.6132629388332813E-5
# Cycle 40
# Total biomass:
# Model iAF1260.cmd: 8.066088099941852E-7
# Model iJN1463.cmd: 2.6355080495060623E-5
# Cycle 41
# Total biomass:
# Model iAF1260.cmd: 8.286535482026706E-7
# Model iJN1463.cmd: 2.6573866830081575E-5
# Cycle 42
# Total biomass:
# Model iAF1260.cmd: 8.510411049161989E-7
# Model iJN1463.cmd: 2.6789674237712588E-5
# Cycle 43
# Total biomass:
# Model iAF1260.cmd: 8.73797807752085E-7
# Model iJN1463.cmd: 2.7003133556552284E-5
# Cycle 44
# Total biomass:
# Model iAF1260.cmd: 8.968566549058142E-7
# Model iJN1463.cmd: 2.7214647349935237E-5
# Cycle 45
# Total biomass:
# Model iAF1260.cmd: 9.202661548516614E-7
# Model iJN1463.cmd: 2.7424283089885603E-5
# Cycle 46
# Total biomass:
# Model iAF1260.cmd: 9.440782262825706E-7
# Model iJN1463.cmd: 2.7635355947277216E-5
# Cycle 47
# Total biomass:
# Model iAF1260.cmd: 9.682106740344167E-7
# Model iJN1463.cmd: 2.7845478186763747E-5
# Cycle 48
# Total biomass:
# Model iAF1260.cmd: 9.92453537480497E-7
# Model iJN1463.cmd: 2.805414942097247E-5
# Cycle 49
# Total biomass:
# Model iAF1260.cmd: 1.0174043796966201E-6
# Model iJN1463.cmd: 2.8258627684076854E-5
# Cycle 50
# Total biomass:
# Model iAF1260.cmd: 1.0429005683182588E-6
# Model iJN1463.cmd: 2.8462668597502378E-5
# Cycle 51
# Total biomass:
# Model iAF1260.cmd: 1.0688617918159246E-6
# Model iJN1463.cmd: 2.866369216583705E-5
# Cycle 52
# Total biomass:
# Model iAF1260.cmd: 1.095380163285038E-6
# Model iJN1463.cmd: 2.8863803974954073E-5
# Cycle 53
# Total biomass:
# Model iAF1260.cmd: 1.1223831309533829E-6
# Model iJN1463.cmd: 2.906359017665808E-5
# Cycle 54
# Total biomass:
# Model iAF1260.cmd: 1.1499140796711033E-6
# Model iJN1463.cmd: 2.9267943579199258E-5
# Cycle 55
# Total biomass:
# Model iAF1260.cmd: 1.1780982343398018E-6
# Model iJN1463.cmd: 2.946509896645335E-5
# Cycle 56
# Total biomass:
# Model iAF1260.cmd: 1.2066823314335525E-6
# Model iJN1463.cmd: 2.966215513473777E-5
# Cycle 57
# Total biomass:
# Model iAF1260.cmd: 1.2354769858231618E-6
# Model iJN1463.cmd: 2.9859061479039057E-5
# Cycle 58
# Total biomass:
# Model iAF1260.cmd: 1.2647218341980847E-6
# Model iJN1463.cmd: 3.0055722137231122E-5
# Cycle 59
# Total biomass:
# Model iAF1260.cmd: 1.2942325635606122E-6
# Model iJN1463.cmd: 3.025197785407417E-5
# Cycle 60
# Total biomass:
# Model iAF1260.cmd: 1.3242807288748871E-6
# Model iJN1463.cmd: 3.0447391457004746E-5
# Cycle 61
# Total biomass:
# Model iAF1260.cmd: 1.3548387848067076E-6
# Model iJN1463.cmd: 3.064178627173769E-5
# Cycle 62
# Total biomass:
# Model iAF1260.cmd: 1.3860153062885454E-6
# Model iJN1463.cmd: 3.0834912535612256E-5
# Cycle 63
# Total biomass:
# Model iAF1260.cmd: 1.417523751930254E-6
# Model iJN1463.cmd: 3.1027003708679054E-5
# Cycle 64
# Total biomass:
# Model iAF1260.cmd: 1.4492709293643929E-6
# Model iJN1463.cmd: 3.121789776281653E-5
# Cycle 65
# Total biomass:
# Model iAF1260.cmd: 1.4815160054700845E-6
# Model iJN1463.cmd: 3.1407775457633984E-5
# Cycle 66
# Total biomass:
# Model iAF1260.cmd: 1.5142915219728261E-6
# Model iJN1463.cmd: 3.15965733354972E-5
# Cycle 67
# Total biomass:
# Model iAF1260.cmd: 1.5474613072107851E-6
# Model iJN1463.cmd: 3.17872026817019E-5
# Cycle 68
# Total biomass:
# Model iAF1260.cmd: 1.58082125098542E-6
# Model iJN1463.cmd: 3.19761775784801E-5
# Cycle 69
# Total biomass:
# Model iAF1260.cmd: 1.6145742609877749E-6
# Model iJN1463.cmd: 3.216300716286582E-5
# Cycle 70
# Total biomass:
# Model iAF1260.cmd: 1.6488783557491523E-6
# Model iJN1463.cmd: 3.2351316506783174E-5
# Cycle 71
# Total biomass:
# Model iAF1260.cmd: 1.6838280843117718E-6
# Model iJN1463.cmd: 3.2539103995970026E-5
# Cycle 72
# Total biomass:
# Model iAF1260.cmd: 1.7193892894710886E-6
# Model iJN1463.cmd: 3.272523551154976E-5
# Cycle 73
# Total biomass:
# Model iAF1260.cmd: 1.7553457587930038E-6
# Model iJN1463.cmd: 3.291093999983245E-5
# Cycle 74
# Total biomass:
# Model iAF1260.cmd: 1.791610534123885E-6
# Model iJN1463.cmd: 3.3095578977264644E-5
# Cycle 75
# Total biomass:
# Model iAF1260.cmd: 1.8277184950845654E-6
# Model iJN1463.cmd: 3.3280445431154966E-5
# Cycle 76
# Total biomass:
# Model iAF1260.cmd: 1.8638373064631945E-6
# Model iJN1463.cmd: 3.346480974579294E-5
# Cycle 77
# Total biomass:
# Model iAF1260.cmd: 1.9002607156309065E-6
# Model iJN1463.cmd: 3.364743262468259E-5
# Cycle 78
# Total biomass:
# Model iAF1260.cmd: 1.9365866749460557E-6
# Model iJN1463.cmd: 3.3830029049891236E-5
# Cycle 79
# Total biomass:
# Model iAF1260.cmd: 1.9741986331015564E-6
# Model iJN1463.cmd: 3.4012150619106284E-5
# Cycle 80
# Total biomass:
# Model iAF1260.cmd: 2.012429264408216E-6
# Model iJN1463.cmd: 3.4191243835084074E-5
# Cycle 81
# Total biomass:
# Model iAF1260.cmd: 2.0509326823726427E-6
# Model iJN1463.cmd: 3.4372470062631996E-5
# Cycle 82
# Total biomass:
# Model iAF1260.cmd: 2.0901954324289615E-6
# Model iJN1463.cmd: 3.455073582462357E-5
# Cycle 83
# Total biomass:
# Model iAF1260.cmd: 2.1299536341802402E-6
# Model iJN1463.cmd: 3.4728120685607175E-5
# Cycle 84
# Total biomass:
# Model iAF1260.cmd: 2.170450321660148E-6
# Model iJN1463.cmd: 3.490340180416356E-5
# Cycle 85
# Total biomass:
# Model iAF1260.cmd: 2.2115569243527597E-6
# Model iJN1463.cmd: 3.507950127772843E-5
# Cycle 86
# Total biomass:
# Model iAF1260.cmd: 2.2530956542365168E-6
# Model iJN1463.cmd: 3.525569655764268E-5
# Cycle 87
# Total biomass:
# Model iAF1260.cmd: 2.2948767363601365E-6
# Model iJN1463.cmd: 3.543207520128667E-5
# Cycle 88
# Total biomass:
# Model iAF1260.cmd: 2.33707370768237E-6
# Model iJN1463.cmd: 3.560842219744054E-5
# Cycle 89
# Total biomass:
# Model iAF1260.cmd: 2.3798943015964593E-6
# Model iJN1463.cmd: 3.578389970232859E-5
# Cycle 90
# Total biomass:
# Model iAF1260.cmd: 2.423183848446488E-6
# Model iJN1463.cmd: 3.5959171405360384E-5
# Cycle 91
# Total biomass:
# Model iAF1260.cmd: 2.466962988806664E-6
# Model iJN1463.cmd: 3.6133601414872494E-5
# Cycle 92
# Total biomass:
# Model iAF1260.cmd: 2.511213353932596E-6
# Model iJN1463.cmd: 3.630775318452534E-5
# Cycle 93
# Total biomass:
# Model iAF1260.cmd: 2.5556253079079254E-6
# Model iJN1463.cmd: 3.6481300919957035E-5
# Cycle 94
# Total biomass:
# Model iAF1260.cmd: 2.6004857765260257E-6
# Model iJN1463.cmd: 3.66544040720668E-5
# Cycle 95
# Total biomass:
# Model iAF1260.cmd: 2.645663331470179E-6
# Model iJN1463.cmd: 3.682709630713579E-5
# Cycle 96
# Total biomass:
# Model iAF1260.cmd: 2.691122612656548E-6
# Model iJN1463.cmd: 3.699973027840587E-5
# Cycle 97
# Total biomass:
# Model iAF1260.cmd: 2.73653955750066E-6
# Model iJN1463.cmd: 3.717260805051303E-5
# Cycle 98
# Total biomass:
# Model iAF1260.cmd: 2.7829703424880215E-6
# Model iJN1463.cmd: 3.734379510253851E-5
# Cycle 99
# Total biomass:
# Model iAF1260.cmd: 2.8297781242334273E-6
# Model iJN1463.cmd: 3.751454041400279E-5
# Cycle 100
# Total biomass:
# Model iAF1260.cmd: 2.8770227359837205E-6
# Model iJN1463.cmd: 3.7689094354448E-5
# Cycle 101
# Total biomass:
# Model iAF1260.cmd: 2.9244882982935103E-6
# Model iJN1463.cmd: 3.7857533602889786E-5
# Cycle 102
# Total biomass:
# Model iAF1260.cmd: 2.9721616775328815E-6
# Model iJN1463.cmd: 3.802746882700546E-5
# Cycle 103
# Total biomass:
# Model iAF1260.cmd: 3.020665435213503E-6
# Model iJN1463.cmd: 3.819598717389125E-5
# Cycle 104
# Total biomass:
# Model iAF1260.cmd: 3.0692959496963293E-6
# Model iJN1463.cmd: 3.83645978435903E-5
# Cycle 105
# Total biomass:
# Model iAF1260.cmd: 3.1177837498025055E-6
# Model iJN1463.cmd: 3.8533599986551536E-5
# Cycle 106
# Total biomass:
# Model iAF1260.cmd: 3.165888818511657E-6
# Model iJN1463.cmd: 3.870313279067966E-5
# Cycle 107
# Total biomass:
# Model iAF1260.cmd: 3.2143921282289195E-6
# Model iJN1463.cmd: 3.887232334231424E-5
# Cycle 108
# Total biomass:
# Model iAF1260.cmd: 3.2632283739640013E-6
# Model iJN1463.cmd: 3.904361958550783E-5
# Cycle 109
# Total biomass:
# Model iAF1260.cmd: 3.3124361668521913E-6
# Model iJN1463.cmd: 3.92123354821658E-5
# Cycle 110
# Total biomass:
# Model iAF1260.cmd: 3.3613199949829574E-6
# Model iJN1463.cmd: 3.9379731985372316E-5
# Cycle 111
# Total biomass:
# Model iAF1260.cmd: 3.410708902140728E-6
# Model iJN1463.cmd: 3.954658216416775E-5
# Cycle 112
# Total biomass:
# Model iAF1260.cmd: 3.460736050631677E-6
# Model iJN1463.cmd: 3.971258201155256E-5
# Cycle 113
# Total biomass:
# Model iAF1260.cmd: 3.5112693798841746E-6
# Model iJN1463.cmd: 3.988319875826443E-5
# Cycle 114
# Total biomass:
# Model iAF1260.cmd: 3.561974997152175E-6
# Model iJN1463.cmd: 4.0048154348049485E-5
# Cycle 115
# Total biomass:
# Model iAF1260.cmd: 3.612658446957841E-6
# Model iJN1463.cmd: 4.021137531499495E-5
# Cycle 116
# Total biomass:
# Model iAF1260.cmd: 3.664010241891876E-6
# Model iJN1463.cmd: 4.037803169324332E-5
# Cycle 117
# Total biomass:
# Model iAF1260.cmd: 3.7154351480405323E-6
# Model iJN1463.cmd: 4.0539957416589435E-5
# Cycle 118
# Total biomass:
# Model iAF1260.cmd: 3.767473575044325E-6
# Model iJN1463.cmd: 4.070240862116572E-5
# Cycle 119
# Total biomass:
# Model iAF1260.cmd: 3.81895378237685E-6
# Model iJN1463.cmd: 4.0870086182925136E-5
# Cycle 120
# Total biomass:
# Model iAF1260.cmd: 3.8701252478144444E-6
# Model iJN1463.cmd: 4.103582676340057E-5
# Cycle 121
# Total biomass:
# Model iAF1260.cmd: 3.922212880337556E-6
# Model iJN1463.cmd: 4.1197193471326185E-5
# Cycle 122
# Total biomass:
# Model iAF1260.cmd: 3.974080402725662E-6
# Model iJN1463.cmd: 4.135981851623188E-5
# Cycle 123
# Total biomass:
# Model iAF1260.cmd: 4.026031671142703E-6
# Model iJN1463.cmd: 4.152137416824476E-5
# Cycle 124
# Total biomass:
# Model iAF1260.cmd: 4.0779271207708445E-6
# Model iJN1463.cmd: 4.168714097948489E-5
# Cycle 125
# Total biomass:
# Model iAF1260.cmd: 4.130730240524748E-6
# Model iJN1463.cmd: 4.1847923512552375E-5
# Cycle 126
# Total biomass:
# Model iAF1260.cmd: 4.184396006231857E-6
# Model iJN1463.cmd: 4.200896291118761E-5
# Cycle 127
# Total biomass:
# Model iAF1260.cmd: 4.2374852128814985E-6
# Model iJN1463.cmd: 4.217046973426399E-5
# Cycle 128
# Total biomass:
# Model iAF1260.cmd: 4.29171953920914E-6
# Model iJN1463.cmd: 4.232988718708528E-5
# Cycle 129
# Total biomass:
# Model iAF1260.cmd: 4.345371208310924E-6
# Model iJN1463.cmd: 4.2490876035376586E-5
# Cycle 130
# Total biomass:
# Model iAF1260.cmd: 4.399072067459611E-6
# Model iJN1463.cmd: 4.2652320009487575E-5
# Cycle 131
# Total biomass:
# Model iAF1260.cmd: 4.454122616070851E-6
# Model iJN1463.cmd: 4.281223136239551E-5
# Cycle 132
# Total biomass:
# Model iAF1260.cmd: 4.508926116878007E-6
# Model iJN1463.cmd: 4.297129971598712E-5
# Cycle 133
# Total biomass:
# Model iAF1260.cmd: 4.564625991235458E-6
# Model iJN1463.cmd: 4.313002833443346E-5
# Cycle 134
# Total biomass:
# Model iAF1260.cmd: 4.620393464060879E-6
# Model iJN1463.cmd: 4.328754254639855E-5
# Cycle 135
# Total biomass:
# Model iAF1260.cmd: 4.676572140664517E-6
# Model iJN1463.cmd: 4.3447131036292635E-5
# Cycle 136
# Total biomass:
# Model iAF1260.cmd: 4.732484127669212E-6
# Model iJN1463.cmd: 4.360609727926667E-5
# Cycle 137
# Total biomass:
# Model iAF1260.cmd: 4.788790644212052E-6
# Model iJN1463.cmd: 4.376375901253803E-5
# Cycle 138
# Total biomass:
# Model iAF1260.cmd: 4.8453609280098255E-6
# Model iJN1463.cmd: 4.3921399391235025E-5
# Cycle 139
# Total biomass:
# Model iAF1260.cmd: 4.90341394888493E-6
# Model iJN1463.cmd: 4.4077837406147204E-5
# Cycle 140
# Total biomass:
# Model iAF1260.cmd: 4.962637463612219E-6
# Model iJN1463.cmd: 4.4232389023052256E-5
# Cycle 141
# Total biomass:
# Model iAF1260.cmd: 5.0236339767367874E-6
# Model iJN1463.cmd: 4.4384132598584863E-5
# Cycle 142
# Total biomass:
# Model iAF1260.cmd: 5.0856084702384445E-6
# Model iJN1463.cmd: 4.453555246714691E-5
# Cycle 143
# Total biomass:
# Model iAF1260.cmd: 5.148051766863738E-6
# Model iJN1463.cmd: 4.468975620807962E-5
# Cycle 144
# Total biomass:
# Model iAF1260.cmd: 5.210703342898275E-6
# Model iJN1463.cmd: 4.4841992519929375E-5
# Cycle 145
# Total biomass:
# Model iAF1260.cmd: 5.272650416683321E-6
# Model iJN1463.cmd: 4.4991641662443045E-5
# Cycle 146
# Total biomass:
# Model iAF1260.cmd: 5.333553439179518E-6
# Model iJN1463.cmd: 4.514380480179055E-5
# Cycle 147
# Total biomass:
# Model iAF1260.cmd: 5.396405791841613E-6
# Model iJN1463.cmd: 4.529483229497342E-5
# Cycle 148
# Total biomass:
# Model iAF1260.cmd: 5.458948913222911E-6
# Model iJN1463.cmd: 4.5445431217712494E-5
# Cycle 149
# Total biomass:
# Model iAF1260.cmd: 5.5184450907924496E-6
# Model iJN1463.cmd: 4.559883803806887E-5
# Cycle 150
# Total biomass:
# Model iAF1260.cmd: 5.581695947692531E-6
# Model iJN1463.cmd: 4.574733497939636E-5
# Cycle 151
# Total biomass:
# Model iAF1260.cmd: 5.643312801385983E-6
# Model iJN1463.cmd: 4.5899256553642455E-5
# Cycle 152
# Total biomass:
# Model iAF1260.cmd: 5.705274280793091E-6
# Model iJN1463.cmd: 4.605026116002252E-5
# Cycle 153
# Total biomass:
# Model iAF1260.cmd: 5.768875043654524E-6
# Model iJN1463.cmd: 4.619939920593671E-5
# Cycle 154
# Total biomass:
# Model iAF1260.cmd: 5.833091507634549E-6
# Model iJN1463.cmd: 4.634953126472322E-5
# Cycle 155
# Total biomass:
# Model iAF1260.cmd: 5.897071983395524E-6
# Model iJN1463.cmd: 4.649886461009459E-5
# Cycle 156
# Total biomass:
# Model iAF1260.cmd: 5.961141600375772E-6
# Model iJN1463.cmd: 4.6646783961434304E-5
# Cycle 157
# Total biomass:
# Model iAF1260.cmd: 6.025290917986106E-6
# Model iJN1463.cmd: 4.6792551159385135E-5
# Cycle 158
# Total biomass:
# Model iAF1260.cmd: 6.087080613859386E-6
# Model iJN1463.cmd: 4.6942815636723755E-5
# Cycle 159
# Total biomass:
# Model iAF1260.cmd: 6.1486374353277E-6
# Model iJN1463.cmd: 4.709616211149688E-5
# Cycle 160
# Total biomass:
# Model iAF1260.cmd: 6.212772191357892E-6
# Model iJN1463.cmd: 4.72448691216415E-5
# Cycle 161
# Total biomass:
# Model iAF1260.cmd: 6.276403810218073E-6
# Model iJN1463.cmd: 4.7391160301414626E-5
# Cycle 162
# Total biomass:
# Model iAF1260.cmd: 6.338414862942712E-6
# Model iJN1463.cmd: 4.754018239570514E-5
# Cycle 163
# Total biomass:
# Model iAF1260.cmd: 6.4054038492394575E-6
# Model iJN1463.cmd: 4.7682106094219376E-5
# Cycle 164
# Total biomass:
# Model iAF1260.cmd: 6.469676759001444E-6
# Model iJN1463.cmd: 4.7829366358543375E-5
# Cycle 165
# Total biomass:
# Model iAF1260.cmd: 6.532697419080222E-6
# Model iJN1463.cmd: 4.797737481861269E-5
# Cycle 166
# Total biomass:
# Model iAF1260.cmd: 6.595672442473109E-6
# Model iJN1463.cmd: 4.812486237263241E-5
# Cycle 167
# Total biomass:
# Model iAF1260.cmd: 6.65994766286915E-6
# Model iJN1463.cmd: 4.827054853382494E-5
# Cycle 168
# Total biomass:
# Model iAF1260.cmd: 6.7237314582227265E-6
# Model iJN1463.cmd: 4.841677869142445E-5
# Cycle 169
# Total biomass:
# Model iAF1260.cmd: 6.787566603577471E-6
# Model iJN1463.cmd: 4.8562856130954304E-5
# Cycle 170
# Total biomass:
# Model iAF1260.cmd: 6.8517167168967335E-6
# Model iJN1463.cmd: 4.870857737608233E-5
# Cycle 171
# Total biomass:
# Model iAF1260.cmd: 6.916274657848297E-6
# Model iJN1463.cmd: 4.885374991458836E-5
# Cycle 172
# Total biomass:
# Model iAF1260.cmd: 6.981156232812122E-6
# Model iJN1463.cmd: 4.899822583873634E-5
# Cycle 173
# Total biomass:
# Model iAF1260.cmd: 7.044974817649854E-6
# Model iJN1463.cmd: 4.9143481651486395E-5
# Cycle 174
# Total biomass:
# Model iAF1260.cmd: 7.108882029462941E-6
# Model iJN1463.cmd: 4.929242806040095E-5
# Cycle 175
# Total biomass:
# Model iAF1260.cmd: 7.172758190804912E-6
# Model iJN1463.cmd: 4.943520839250044E-5
# Cycle 176
# Total biomass:
# Model iAF1260.cmd: 7.238800865355465E-6
# Model iJN1463.cmd: 4.9577562154084774E-5
# Cycle 177
# Total biomass:
# Model iAF1260.cmd: 7.306651614038606E-6
# Model iJN1463.cmd: 4.9718219504103425E-5
# Cycle 178
# Total biomass:
# Model iAF1260.cmd: 7.3746598083796594E-6
# Model iJN1463.cmd: 4.985905401168718E-5
# Cycle 179
# Total biomass:
# Model iAF1260.cmd: 7.442454851076653E-6
# Model iJN1463.cmd: 5.000015281442026E-5
# Cycle 180
# Total biomass:
# Model iAF1260.cmd: 7.515376947955534E-6
# Model iJN1463.cmd: 5.013422757292148E-5
# Cycle 181
# Total biomass:
# Model iAF1260.cmd: 7.5843256316837986E-6
# Model iJN1463.cmd: 5.0274834867060447E-5
# Cycle 182
# Total biomass:
# Model iAF1260.cmd: 7.654041188411653E-6
# Model iJN1463.cmd: 5.041602194656503E-5
# Cycle 183
# Total biomass:
# Model iAF1260.cmd: 7.72602388576022E-6
# Model iJN1463.cmd: 5.054950454526959E-5
# Cycle 184
# Total biomass:
# Model iAF1260.cmd: 7.795549379894627E-6
# Model iJN1463.cmd: 5.068764544829037E-5
# Cycle 185
# Total biomass:
# Model iAF1260.cmd: 7.863438819625897E-6
# Model iJN1463.cmd: 5.082704338353579E-5
# Cycle 186
# Total biomass:
# Model iAF1260.cmd: 7.933768268242962E-6
# Model iJN1463.cmd: 5.096291997764467E-5
# Cycle 187
# Total biomass:
# Model iAF1260.cmd: 8.004097267966273E-6
# Model iJN1463.cmd: 5.109918821039556E-5
# Cycle 188
# Total biomass:
# Model iAF1260.cmd: 8.075021325125412E-6
# Model iJN1463.cmd: 5.123496051782188E-5
# Cycle 189
# Total biomass:
# Model iAF1260.cmd: 8.14528459536301E-6
# Model iJN1463.cmd: 5.1371728928704086E-5
# Cycle 190
# Total biomass:
# Model iAF1260.cmd: 8.215214336957886E-6
# Model iJN1463.cmd: 5.1508754765497066E-5
# Cycle 191
# Total biomass:
# Model iAF1260.cmd: 8.28846985054455E-6
# Model iJN1463.cmd: 5.1641924360466665E-5
# Cycle 192
# Total biomass:
# Model iAF1260.cmd: 8.365066813505678E-6
# Model iJN1463.cmd: 5.1774713736333574E-5
# Cycle 193
# Total biomass:
# Model iAF1260.cmd: 8.441936161295403E-6
# Model iJN1463.cmd: 5.1903402446120985E-5
# Cycle 194
# Total biomass:
# Model iAF1260.cmd: 8.518914365363414E-6
# Model iJN1463.cmd: 5.203100561179173E-5
# Cycle 195
# Total biomass:
# Model iAF1260.cmd: 8.597111393647557E-6
# Model iJN1463.cmd: 5.2157901907612866E-5
# Cycle 196
# Total biomass:
# Model iAF1260.cmd: 8.67448745907822E-6
# Model iJN1463.cmd: 5.228645274321575E-5
# Cycle 197
# Total biomass:
# Model iAF1260.cmd: 8.74802475608711E-6
# Model iJN1463.cmd: 5.2418623609711184E-5
# Cycle 198
# Total biomass:
# Model iAF1260.cmd: 8.82592534868019E-6
# Model iJN1463.cmd: 5.2546027856929486E-5
# Cycle 199
# Total biomass:
# Model iAF1260.cmd: 8.905746607744806E-6
# Model iJN1463.cmd: 5.267075522218261E-5
# Cycle 200
# Total biomass:
# Model iAF1260.cmd: 8.983607776505575E-6
# Model iJN1463.cmd: 5.2798396286328044E-5
# Cycle 201
# Total biomass:
# Model iAF1260.cmd: 9.057778124883681E-6
# Model iJN1463.cmd: 5.292944052943453E-5
# Cycle 202
# Total biomass:
# Model iAF1260.cmd: 9.131090339618439E-6
# Model iJN1463.cmd: 5.306073913757566E-5
# Cycle 203
# Total biomass:
# Model iAF1260.cmd: 9.204342519277278E-6
# Model iJN1463.cmd: 5.319181832808545E-5
# Cycle 204
# Total biomass:
# Model iAF1260.cmd: 9.277630377646078E-6
# Model iJN1463.cmd: 5.332249204660133E-5
# Cycle 205
# Total biomass:
# Model iAF1260.cmd: 9.351178665678154E-6
# Model iJN1463.cmd: 5.345271996530996E-5
# Cycle 206
# Total biomass:
# Model iAF1260.cmd: 9.424997412285364E-6
# Model iJN1463.cmd: 5.358252281041965E-5
# Cycle 207
# Total biomass:
# Model iAF1260.cmd: 9.499149311029242E-6
# Model iJN1463.cmd: 5.371191298299485E-5
# Cycle 208
# Total biomass:
# Model iAF1260.cmd: 9.573458822867234E-6
# Model iJN1463.cmd: 5.384084481835572E-5
# Cycle 209
# Total biomass:
# Model iAF1260.cmd: 9.64808500238447E-6
# Model iJN1463.cmd: 5.396933803822859E-5
# Cycle 210
# Total biomass:
# Model iAF1260.cmd: 9.72300020273198E-6
# Model iJN1463.cmd: 5.409744127925725E-5
# Cycle 211
# Total biomass:
# Model iAF1260.cmd: 9.79812449157671E-6
# Model iJN1463.cmd: 5.4225046254132255E-5
# Cycle 212
# Total biomass:
# Model iAF1260.cmd: 9.873460682048229E-6
# Model iJN1463.cmd: 5.435217322696976E-5
# Cycle 213
# Total biomass:
# Model iAF1260.cmd: 9.94913146385295E-6
# Model iJN1463.cmd: 5.4478829477856284E-5
# Cycle 214
# Total biomass:
# Model iAF1260.cmd: 1.0025114784666782E-5
# Model iJN1463.cmd: 5.460501869814166E-5
# Cycle 215
# Total biomass:
# Model iAF1260.cmd: 1.0101404243973306E-5
# Model iJN1463.cmd: 5.4730738865429065E-5
# Cycle 216
# Total biomass:
# Model iAF1260.cmd: 1.017798476388909E-5
# Model iJN1463.cmd: 5.485598929372979E-5
# Cycle 217
# Total biomass:
# Model iAF1260.cmd: 1.0254793490298763E-5
# Model iJN1463.cmd: 5.498072284572752E-5
# Cycle 218
# Total biomass:
# Model iAF1260.cmd: 1.0331810469315063E-5
# Model iJN1463.cmd: 5.510499744101866E-5
# Cycle 219
# Total biomass:
# Model iAF1260.cmd: 1.0409047645423622E-5
# Model iJN1463.cmd: 5.522877562559204E-5
# Cycle 220
# Total biomass:
# Model iAF1260.cmd: 1.0486761656761916E-5
# Model iJN1463.cmd: 5.535205310707244E-5
# Cycle 221
# Total biomass:
# Model iAF1260.cmd: 1.0564779617810324E-5
# Model iJN1463.cmd: 5.547478063181383E-5
# Cycle 222
# Total biomass:
# Model iAF1260.cmd: 1.0642937236269877E-5
# Model iJN1463.cmd: 5.559701004593896E-5
# Cycle 223
# Total biomass:
# Model iAF1260.cmd: 1.0721365307781728E-5
# Model iJN1463.cmd: 5.571873996211416E-5
# Cycle 224
# Total biomass:
# Model iAF1260.cmd: 1.0800116166989651E-5
# Model iJN1463.cmd: 5.583993195509084E-5
# Cycle 225
# Total biomass:
# Model iAF1260.cmd: 1.0879055689791322E-5
# Model iJN1463.cmd: 5.596063389375886E-5
# Cycle 226
# Total biomass:
# Model iAF1260.cmd: 1.0958074356213643E-5
# Model iJN1463.cmd: 5.6080876320176694E-5
# Cycle 227
# Total biomass:
# Model iAF1260.cmd: 1.1037319464548758E-5
# Model iJN1463.cmd: 5.620068731882231E-5
# Cycle 228
# Total biomass:
# Model iAF1260.cmd: 1.111683240462648E-5
# Model iJN1463.cmd: 5.6320072755944366E-5
# Cycle 229
# Total biomass:
# Model iAF1260.cmd: 1.1196825833463843E-5
# Model iJN1463.cmd: 5.643903909744673E-5
# Cycle 230
# Total biomass:
# Model iAF1260.cmd: 1.1276981291291214E-5
# Model iJN1463.cmd: 5.655753635861589E-5
# Cycle 231
# Total biomass:
# Model iAF1260.cmd: 1.1357407837969386E-5
# Model iJN1463.cmd: 5.6675572841684354E-5
# Cycle 232
# Total biomass:
# Model iAF1260.cmd: 1.1438115968848785E-5
# Model iJN1463.cmd: 5.6793161571140334E-5
# Cycle 233
# Total biomass:
# Model iAF1260.cmd: 1.1518896373311641E-5
# Model iJN1463.cmd: 5.6910325558872574E-5
# Cycle 234
# Total biomass:
# Model iAF1260.cmd: 1.1599922609321042E-5
# Model iJN1463.cmd: 5.702711197852914E-5
# Cycle 235
# Total biomass:
# Model iAF1260.cmd: 1.1681096264728602E-5
# Model iJN1463.cmd: 5.714346211559322E-5
# Cycle 236
# Total biomass:
# Model iAF1260.cmd: 1.176250876666221E-5
# Model iJN1463.cmd: 5.725941288102412E-5
# Cycle 237
# Total biomass:
# Model iAF1260.cmd: 1.184415678588776E-5
# Model iJN1463.cmd: 5.7374975319137115E-5
# Cycle 238
# Total biomass:
# Model iAF1260.cmd: 1.1925981782042632E-5
# Model iJN1463.cmd: 5.749010832699817E-5
# Cycle 239
# Total biomass:
# Model iAF1260.cmd: 1.2007919702642686E-5
# Model iJN1463.cmd: 5.760483291194646E-5
# Cycle 240
# Total biomass:
# Model iAF1260.cmd: 1.2090693251549405E-5
# Model iJN1463.cmd: 5.7718251102189326E-5
# Cycle 241
# Total biomass:
# Model iAF1260.cmd: 1.217399390907895E-5
# Model iJN1463.cmd: 5.7831148026992996E-5
# Cycle 242
# Total biomass:
# Model iAF1260.cmd: 1.2257624482075254E-5
# Model iJN1463.cmd: 5.7943561455897146E-5
# Cycle 243
# Total biomass:
# Model iAF1260.cmd: 1.2341341491269274E-5
# Model iJN1463.cmd: 5.805562846808922E-5
# Cycle 244
# Total biomass:
# Model iAF1260.cmd: 1.242490574933767E-5
# Model iJN1463.cmd: 5.816778927581048E-5
# Cycle 245
# Total biomass:
# Model iAF1260.cmd: 1.250821402997377E-5
# Model iJN1463.cmd: 5.8279799407456784E-5
# Cycle 246
# Total biomass:
# Model iAF1260.cmd: 1.2592074440847964E-5
# Model iJN1463.cmd: 5.839081979429312E-5
# Cycle 247
# Total biomass:
# Model iAF1260.cmd: 1.2676379809601889E-5
# Model iJN1463.cmd: 5.8501404439463515E-5
# Cycle 248
# Total biomass:
# Model iAF1260.cmd: 1.2760155805539631E-5
# Model iJN1463.cmd: 5.861235134652747E-5
# Cycle 249
# Total biomass:
# Model iAF1260.cmd: 1.2843615961129943E-5
# Model iJN1463.cmd: 5.8723043672132446E-5
# Cycle 250
# Total biomass:
# Model iAF1260.cmd: 1.2927219632864714E-5
# Model iJN1463.cmd: 5.883330635074801E-5
# Cycle 251
# Total biomass:
# Model iAF1260.cmd: 1.301103207777987E-5
# Model iJN1463.cmd: 5.894318252560046E-5
# Cycle 252
# Total biomass:
# Model iAF1260.cmd: 1.309505228510201E-5
# Model iJN1463.cmd: 5.905268769033973E-5
# Cycle 253
# Total biomass:
# Model iAF1260.cmd: 1.3179482452512167E-5
# Model iJN1463.cmd: 5.9161474213811595E-5
# Cycle 254
# Total biomass:
# Model iAF1260.cmd: 1.32641853760384E-5
# Model iJN1463.cmd: 5.926985991795803E-5
# Cycle 255
# Total biomass:
# Model iAF1260.cmd: 1.3348828790051494E-5
# Model iJN1463.cmd: 5.937808976674557E-5
# Cycle 256
# Total biomass:
# Model iAF1260.cmd: 1.3433559673430803E-5
# Model iJN1463.cmd: 5.948609547708686E-5
# Cycle 257
# Total biomass:
# Model iAF1260.cmd: 1.351875260490829E-5
# Model iJN1463.cmd: 5.959355477669813E-5
# Cycle 258
# Total biomass:
# Model iAF1260.cmd: 1.360410805295854E-5
# Model iJN1463.cmd: 5.970068820233459E-5
# Cycle 259
# Total biomass:
# Model iAF1260.cmd: 1.3689480993383134E-5
# Model iJN1463.cmd: 5.980752943778193E-5
# Cycle 260
# Total biomass:
# Model iAF1260.cmd: 1.3775047352360978E-5
# Model iJN1463.cmd: 5.991393544496898E-5
# Cycle 261
# Total biomass:
# Model iAF1260.cmd: 1.3860811376352703E-5
# Model iJN1463.cmd: 6.0019944136399265E-5
# Cycle 262
# Total biomass:
# Model iAF1260.cmd: 1.3946859009355214E-5
# Model iJN1463.cmd: 6.0125548128049864E-5
# Cycle 263
# Total biomass:
# Model iAF1260.cmd: 1.4033114508659854E-5
# Model iJN1463.cmd: 6.0230729889729796E-5
# Cycle 264
# Total biomass:
# Model iAF1260.cmd: 1.4119594476576572E-5
# Model iJN1463.cmd: 6.033549818802522E-5
# Cycle 265
# Total biomass:
# Model iAF1260.cmd: 1.4206336086404642E-5
# Model iJN1463.cmd: 6.043985738265648E-5
# Cycle 266
# Total biomass:
# Model iAF1260.cmd: 1.42936122948364E-5
# Model iJN1463.cmd: 6.0543840761448715E-5
# Cycle 267
# Total biomass:
# Model iAF1260.cmd: 1.43842708528326E-5
# Model iJN1463.cmd: 6.064460774460069E-5
# Cycle 268
# Total biomass:
# Model iAF1260.cmd: 1.4476860431932175E-5
# Model iJN1463.cmd: 6.0743705673542656E-5
# Cycle 269
# Total biomass:
# Model iAF1260.cmd: 1.4578332894794028E-5
# Model iJN1463.cmd: 6.0833214707488684E-5
# Cycle 270
# Total biomass:
# Model iAF1260.cmd: 1.4683616791885419E-5
# Model iJN1463.cmd: 6.092023708746696E-5
# Cycle 271
# Total biomass:
# Model iAF1260.cmd: 1.477453627294729E-5
# Model iJN1463.cmd: 6.102129916162932E-5
# Cycle 272
# Total biomass:
# Model iAF1260.cmd: 1.4863412181917629E-5
# Model iJN1463.cmd: 6.112245839740382E-5
# Cycle 273
# Total biomass:
# Model iAF1260.cmd: 1.4952033888891929E-5
# Model iJN1463.cmd: 6.122344365270201E-5
# Cycle 274
# Total biomass:
# Model iAF1260.cmd: 1.5040597405594322E-5
# Model iJN1463.cmd: 6.132409731947066E-5
# Cycle 275
# Total biomass:
# Model iAF1260.cmd: 1.5129247402309397E-5
# Model iJN1463.cmd: 6.142437667285038E-5
# Cycle 276
# Total biomass:
# Model iAF1260.cmd: 1.5218030398513853E-5
# Model iJN1463.cmd: 6.152426261643144E-5
# Cycle 277
# Total biomass:
# Model iAF1260.cmd: 1.530707434727501E-5
# Model iJN1463.cmd: 6.162371700365604E-5
# Cycle 278
# Total biomass:
# Model iAF1260.cmd: 1.5396362475553766E-5
# Model iJN1463.cmd: 6.172276618913105E-5
# Cycle 279
# Total biomass:
# Model iAF1260.cmd: 1.5486014878264443E-5
# Model iJN1463.cmd: 6.18214425268579E-5
# Cycle 280
# Total biomass:
# Model iAF1260.cmd: 1.5577033086740125E-5
# Model iJN1463.cmd: 6.191908471156757E-5
# Cycle 281
# Total biomass:
# Model iAF1260.cmd: 1.5670218641818488E-5
# Model iJN1463.cmd: 6.20149999753658E-5
# Cycle 282
# Total biomass:
# Model iAF1260.cmd: 1.577050916103464E-5
# Model iJN1463.cmd: 6.210404523858812E-5
# Cycle 283
# Total biomass:
# Model iAF1260.cmd: 1.586137459375193E-5
# Model iJN1463.cmd: 6.220089112497811E-5
# Cycle 284
# Total biomass:
# Model iAF1260.cmd: 1.595143851029135E-5
# Model iJN1463.cmd: 6.229765939530056E-5
# Cycle 285
# Total biomass:
# Model iAF1260.cmd: 1.6041539744726057E-5
# Model iJN1463.cmd: 6.239413318232492E-5
# Cycle 286
# Total biomass:
# Model iAF1260.cmd: 1.6131718042466748E-5
# Model iJN1463.cmd: 6.249026921792965E-5
# Cycle 287
# Total biomass:
# Model iAF1260.cmd: 1.6222042071984776E-5
# Model iJN1463.cmd: 6.25860388696252E-5
# Cycle 288
# Total biomass:
# Model iAF1260.cmd: 1.631254286989192E-5
# Model iJN1463.cmd: 6.268143622643236E-5
# Cycle 289
# Total biomass:
# Model iAF1260.cmd: 1.6403216174896027E-5
# Model iJN1463.cmd: 6.277646391830341E-5
# Cycle 290
# Total biomass:
# Model iAF1260.cmd: 1.6493752812230074E-5
# Model iJN1463.cmd: 6.287109560029869E-5
# Cycle 291
# Total biomass:
# Model iAF1260.cmd: 1.6584857229399816E-5
# Model iJN1463.cmd: 6.29653732529722E-5
# Cycle 292
# Total biomass:
# Model iAF1260.cmd: 1.6678416223978208E-5
# Model iJN1463.cmd: 6.305754798360384E-5
# Cycle 293
# Total biomass:
# Model iAF1260.cmd: 1.677430424004369E-5
# Model iJN1463.cmd: 6.314759013771689E-5
# Cycle 294
# Total biomass:
# Model iAF1260.cmd: 1.687985559572619E-5
# Model iJN1463.cmd: 6.322887972815095E-5
# Cycle 295
# Total biomass:
# Model iAF1260.cmd: 1.698859152624048E-5
# Model iJN1463.cmd: 6.330736240206254E-5
# Cycle 296
# Total biomass:
# Model iAF1260.cmd: 1.70823908581976E-5
# Model iJN1463.cmd: 6.339766090629705E-5
# Cycle 297
# Total biomass:
# Model iAF1260.cmd: 1.7174293380619435E-5
# Model iJN1463.cmd: 6.348894371049602E-5
# Cycle 298
# Total biomass:
# Model iAF1260.cmd: 1.7265831072165613E-5
# Model iJN1463.cmd: 6.358024150786018E-5
# Cycle 299
# Total biomass:
# Model iAF1260.cmd: 1.735764385807969E-5
# Model iJN1463.cmd: 6.367111429942066E-5
# Cycle 300
# Total biomass:
# Model iAF1260.cmd: 1.7449398942153772E-5
# Model iJN1463.cmd: 6.376178402064803E-5
# Cycle 301
# Total biomass:
# Model iAF1260.cmd: 1.7541229303739354E-5
# Model iJN1463.cmd: 6.385214984145956E-5
# Cycle 302
# Total biomass:
# Model iAF1260.cmd: 1.7633179655638235E-5
# Model iJN1463.cmd: 6.394215624012772E-5
# Cycle 303
# Total biomass:
# Model iAF1260.cmd: 1.7725185248901428E-5
# Model iJN1463.cmd: 6.403177162183886E-5
# Cycle 304
# Total biomass:
# Model iAF1260.cmd: 1.7817518319985164E-5
# Model iJN1463.cmd: 6.412104334064835E-5
# Cycle 305
# Total biomass:
# Model iAF1260.cmd: 1.7910125086276955E-5
# Model iJN1463.cmd: 6.421004147567028E-5
# Cycle 306
# Total biomass:
# Model iAF1260.cmd: 1.8004764204423642E-5
# Model iJN1463.cmd: 6.429736777266673E-5
# Cycle 307
# Total biomass:
# Model iAF1260.cmd: 1.8101842866312774E-5
# Model iJN1463.cmd: 6.438249148400815E-5
# Cycle 308
# Total biomass:
# Model iAF1260.cmd: 1.819474838375255E-5
# Model iJN1463.cmd: 6.446994262749388E-5
# Cycle 309
# Total biomass:
# Model iAF1260.cmd: 1.8287515394895093E-5
# Model iJN1463.cmd: 6.455715104115991E-5
# Cycle 310
# Total biomass:
# Model iAF1260.cmd: 1.8380351000802063E-5
# Model iJN1463.cmd: 6.464401077005092E-5
# Cycle 311
# Total biomass:
# Model iAF1260.cmd: 1.8473305009408644E-5
# Model iJN1463.cmd: 6.473048815238761E-5
# Cycle 312
# Total biomass:
# Model iAF1260.cmd: 1.856669963649742E-5
# Model iJN1463.cmd: 6.48166423577221E-5
# Cycle 313
# Total biomass:
# Model iAF1260.cmd: 1.8660511669492136E-5
# Model iJN1463.cmd: 6.49024558610892E-5
# Cycle 314
# Total biomass:
# Model iAF1260.cmd: 1.8757990711913142E-5
# Model iJN1463.cmd: 6.498516453381782E-5
# Cycle 315
# Total biomass:
# Model iAF1260.cmd: 1.8861084371300935E-5
# Model iJN1463.cmd: 6.506307014452845E-5
# Cycle 316
# Total biomass:
# Model iAF1260.cmd: 1.8955574467648256E-5
# Model iJN1463.cmd: 6.514699366584423E-5
# Cycle 317
# Total biomass:
# Model iAF1260.cmd: 1.9049264934743584E-5
# Model iJN1463.cmd: 6.52309916476112E-5
# Cycle 318
# Total biomass:
# Model iAF1260.cmd: 1.914290300263508E-5
# Model iJN1463.cmd: 6.531475640823843E-5
# Cycle 319
# Total biomass:
# Model iAF1260.cmd: 1.9236594450444842E-5
# Model iJN1463.cmd: 6.539819985040287E-5
# Cycle 320
# Total biomass:
# Model iAF1260.cmd: 1.9330365309429824E-5
# Model iJN1463.cmd: 6.548129770534763E-5
# Cycle 321
# Total biomass:
# Model iAF1260.cmd: 1.942456076860693E-5
# Model iJN1463.cmd: 6.55640857316496E-5
# Cycle 322
# Total biomass:
# Model iAF1260.cmd: 1.9518983447904488E-5
# Model iJN1463.cmd: 6.564652789317202E-5
# Cycle 323
# Total biomass:
# Model iAF1260.cmd: 1.9616792061900954E-5
# Model iJN1463.cmd: 6.572626083520259E-5
# Cycle 324
# Total biomass:
# Model iAF1260.cmd: 1.9720023081228878E-5
# Model iJN1463.cmd: 6.580139637096268E-5
# Cycle 325
# Total biomass:
# Model iAF1260.cmd: 1.9815105920958388E-5
# Model iJN1463.cmd: 6.588186700602284E-5
# Cycle 326
# Total biomass:
# Model iAF1260.cmd: 1.990965154120928E-5
# Model iJN1463.cmd: 6.596240504051108E-5
# Cycle 327
# Total biomass:
# Model iAF1260.cmd: 2.000411165736191E-5
# Model iJN1463.cmd: 6.60427036741679E-5
# Cycle 328
# Total biomass:
# Model iAF1260.cmd: 2.0098623516969887E-5
# Model iJN1463.cmd: 6.612265720060809E-5
# Cycle 329
# Total biomass:
# Model iAF1260.cmd: 2.0193514688310653E-5
# Model iJN1463.cmd: 6.620238254408185E-5
# Cycle 330
# Total biomass:
# Model iAF1260.cmd: 2.0288656539394227E-5
# Model iJN1463.cmd: 6.628168641855988E-5
# Cycle 331
# Total biomass:
# Model iAF1260.cmd: 2.0383988893769946E-5
# Model iJN1463.cmd: 6.636065021758492E-5
# Cycle 332
# Total biomass:
# Model iAF1260.cmd: 2.0482504764780454E-5
# Model iJN1463.cmd: 6.643710270466187E-5
# Cycle 333
# Total biomass:
# Model iAF1260.cmd: 2.0586788213471837E-5
# Model iJN1463.cmd: 6.65088874799617E-5
# Cycle 334
# Total biomass:
# Model iAF1260.cmd: 2.0694531770113517E-5
# Model iJN1463.cmd: 6.657790218677813E-5
# Cycle 335
# Total biomass:
# Model iAF1260.cmd: 2.0804073926471447E-5
# Model iJN1463.cmd: 6.664537920971452E-5
# Cycle 336
# Total biomass:
# Model iAF1260.cmd: 2.0914012225648255E-5
# Model iJN1463.cmd: 6.671236032913795E-5
# Cycle 337
# Total biomass:
# Model iAF1260.cmd: 2.102385193799979E-5
# Model iJN1463.cmd: 6.677926096402888E-5
# Cycle 338
# Total biomass:
# Model iAF1260.cmd: 2.113182479108528E-5
# Model iJN1463.cmd: 6.68472437354569E-5
# Cycle 339
# Total biomass:
# Model iAF1260.cmd: 2.1238081258478484E-5
# Model iJN1463.cmd: 6.691572780518498E-5
# Cycle 340
# Total biomass:
# Model iAF1260.cmd: 2.134285121274801E-5
# Model iJN1463.cmd: 6.698506147317992E-5
# Cycle 341
# Total biomass:
# Model iAF1260.cmd: 2.1441969784845863E-5
# Model iJN1463.cmd: 6.70589810734651E-5
# Cycle 342
# Total biomass:
# Model iAF1260.cmd: 2.1538384737171693E-5
# Model iJN1463.cmd: 6.713500552523268E-5
# Cycle 343
# Total biomass:
# Model iAF1260.cmd: 2.1633926523425667E-5
# Model iJN1463.cmd: 6.721136452417307E-5
# Cycle 344
# Total biomass:
# Model iAF1260.cmd: 2.1729115804184975E-5
# Model iJN1463.cmd: 6.72876899092376E-5
# Cycle 345
# Total biomass:
# Model iAF1260.cmd: 2.1824098812634114E-5
# Model iJN1463.cmd: 6.736388838976945E-5
# Cycle 346
# Total biomass:
# Model iAF1260.cmd: 2.191891630313305E-5
# Model iJN1463.cmd: 6.743993346920099E-5
# Cycle 347
# Total biomass:
# Model iAF1260.cmd: 2.201357920053515E-5
# Model iJN1463.cmd: 6.751581667068127E-5
# Cycle 348
# Total biomass:
# Model iAF1260.cmd: 2.210808989221479E-5
# Model iJN1463.cmd: 6.759153491771022E-5
# Cycle 349
# Total biomass:
# Model iAF1260.cmd: 2.2202444457145223E-5
# Model iJN1463.cmd: 6.766707955057457E-5
# Cycle 350
# Total biomass:
# Model iAF1260.cmd: 2.2296628290111247E-5
# Model iJN1463.cmd: 6.77424525587692E-5
# Cycle 351
# Total biomass:
# Model iAF1260.cmd: 2.239065764077804E-5
# Model iJN1463.cmd: 6.781765503540186E-5
# Cycle 352
# Total biomass:
# Model iAF1260.cmd: 2.2484552259131238E-5
# Model iJN1463.cmd: 6.789266954952191E-5
# Cycle 353
# Total biomass:
# Model iAF1260.cmd: 2.2578370836180678E-5
# Model iJN1463.cmd: 6.796743735093273E-5
# Cycle 354
# Total biomass:
# Model iAF1260.cmd: 2.2672089179237988E-5
# Model iJN1463.cmd: 6.804197671111694E-5
# Cycle 355
# Total biomass:
# Model iAF1260.cmd: 2.2765697145497082E-5
# Model iJN1463.cmd: 6.811629593332859E-5
# Cycle 356
# Total biomass:
# Model iAF1260.cmd: 2.2859192170494747E-5
# Model iJN1463.cmd: 6.819039806336068E-5
# Cycle 357
# Total biomass:
# Model iAF1260.cmd: 2.2952568561841284E-5
# Model iJN1463.cmd: 6.826428494253065E-5
# Cycle 358
# Total biomass:
# Model iAF1260.cmd: 2.304586596259939E-5
# Model iJN1463.cmd: 6.833792706558968E-5
# Cycle 359
# Total biomass:
# Model iAF1260.cmd: 2.3139097521038977E-5
# Model iJN1463.cmd: 6.841131433394931E-5
# Cycle 360
# Total biomass:
# Model iAF1260.cmd: 2.323226345525618E-5
# Model iJN1463.cmd: 6.848444441569034E-5
# Cycle 361
# Total biomass:
# Model iAF1260.cmd: 2.3325362907755433E-5
# Model iJN1463.cmd: 6.855731615526356E-5
# Cycle 362
# Total biomass:
# Model iAF1260.cmd: 2.3418306805100085E-5
# Model iJN1463.cmd: 6.863000529601703E-5
# Cycle 363
# Total biomass:
# Model iAF1260.cmd: 2.351107328312618E-5
# Model iJN1463.cmd: 6.870253377590407E-5
# Cycle 364
# Total biomass:
# Model iAF1260.cmd: 2.3603649618643154E-5
# Model iJN1463.cmd: 6.877490991717004E-5
# Cycle 365
# Total biomass:
# Model iAF1260.cmd: 2.3696034291948748E-5
# Model iJN1463.cmd: 6.884712984917915E-5
# Cycle 366
# Total biomass:
# Model iAF1260.cmd: 2.3788216596841862E-5
# Model iJN1463.cmd: 6.891919560171838E-5
# Cycle 367
# Total biomass:
# Model iAF1260.cmd: 2.3880211207626192E-5
# Model iJN1463.cmd: 6.899110688394078E-5
# Cycle 368
# Total biomass:
# Model iAF1260.cmd: 2.3972005103733334E-5
# Model iJN1463.cmd: 6.906286727290623E-5
# Cycle 369
# Total biomass:
# Model iAF1260.cmd: 2.4063613283278263E-5
# Model iJN1463.cmd: 6.913448773650378E-5
# Cycle 370
# Total biomass:
# Model iAF1260.cmd: 2.41550456250881E-5
# Model iJN1463.cmd: 6.920596991219316E-5
# Cycle 371
# Total biomass:
# Model iAF1260.cmd: 2.4246301264000608E-5
# Model iJN1463.cmd: 6.927731620491613E-5
# Cycle 372
# Total biomass:
# Model iAF1260.cmd: 2.4337369465874416E-5
# Model iJN1463.cmd: 6.934852427796303E-5
# Cycle 373
# Total biomass:
# Model iAF1260.cmd: 2.442825865348578E-5
# Model iJN1463.cmd: 6.941959523148272E-5
# Cycle 374
# Total biomass:
# Model iAF1260.cmd: 2.4518984757405033E-5
# Model iJN1463.cmd: 6.949049831546962E-5
# Cycle 375
# Total biomass:
# Model iAF1260.cmd: 2.460960162880455E-5
# Model iJN1463.cmd: 6.956120041937358E-5
# Cycle 376
# Total biomass:
# Model iAF1260.cmd: 2.47001200789951E-5
# Model iJN1463.cmd: 6.963167310481156E-5
# Cycle 377
# Total biomass:
# Model iAF1260.cmd: 2.479056621053695E-5
# Model iJN1463.cmd: 6.970188557662637E-5
# Cycle 378
# Total biomass:
# Model iAF1260.cmd: 2.4880966152826697E-5
# Model iJN1463.cmd: 6.977183091279936E-5
# Cycle 379
# Total biomass:
# Model iAF1260.cmd: 2.4971293221679466E-5
# Model iJN1463.cmd: 6.984151529330184E-5
# Cycle 380
# Total biomass:
# Model iAF1260.cmd: 2.5061548316186213E-5
# Model iJN1463.cmd: 6.991095065817711E-5
# Cycle 381
# Total biomass:
# Model iAF1260.cmd: 2.5151637146839842E-5
# Model iJN1463.cmd: 6.998019081622165E-5
# Cycle 382
# Total biomass:
# Model iAF1260.cmd: 2.5241549359948023E-5
# Model iJN1463.cmd: 7.004923909543138E-5
# Cycle 383
# Total biomass:
# Model iAF1260.cmd: 2.5331300135514524E-5
# Model iJN1463.cmd: 7.011808115565471E-5
# Cycle 384
# Total biomass:
# Model iAF1260.cmd: 2.5420892923963953E-5
# Model iJN1463.cmd: 7.018671279864863E-5
# Cycle 385
# Total biomass:
# Model iAF1260.cmd: 2.551032956441571E-5
# Model iJN1463.cmd: 7.025513150222222E-5
# Cycle 386
# Total biomass:
# Model iAF1260.cmd: 2.5599608868202076E-5
# Model iJN1463.cmd: 7.032333660113829E-5
# Cycle 387
# Total biomass:
# Model iAF1260.cmd: 2.568872771237608E-5
# Model iJN1463.cmd: 7.039132821695215E-5
# Cycle 388
# Total biomass:
# Model iAF1260.cmd: 2.5777683197578654E-5
# Model iJN1463.cmd: 7.045910656184576E-5
# Cycle 389
# Total biomass:
# Model iAF1260.cmd: 2.586648088064768E-5
# Model iJN1463.cmd: 7.052667450771999E-5
# Cycle 390
# Total biomass:
# Model iAF1260.cmd: 2.595510587101135E-5
# Model iJN1463.cmd: 7.059402924747382E-5
# Cycle 391
# Total biomass:
# Model iAF1260.cmd: 2.6043569273089376E-5
# Model iJN1463.cmd: 7.066117337836808E-5
# Cycle 392
# Total biomass:
# Model iAF1260.cmd: 2.6131856704309745E-5
# Model iJN1463.cmd: 7.07281042044277E-5
# Cycle 393
# Total biomass:
# Model iAF1260.cmd: 2.6219980794372436E-5
# Model iJN1463.cmd: 7.079482394098922E-5
# Cycle 394
# Total biomass:
# Model iAF1260.cmd: 2.6307953117635378E-5
# ...
# Model iAF1260.cmd: 5.7983452817989644E-5
# Model iJN1463.cmd: 8.54984833016981E-5
# Cycle 850
# Total biomass:
# Model iAF1260.cmd: 5.803084468551807E-5
# Model iJN1463.cmd: 8.551019829624452E-5
# Cycle 851
# Total biomass:
# Model iAF1260.cmd: 5.807811667385318E-5
# Model iJN1463.cmd: 8.552184709496512E-5
# Cycle 852
# Total biomass:
# Model iAF1260.cmd: 5.8125523252250885E-5
# Model iJN1463.cmd: 8.55334886641118E-5
# Cycle 853
# Total biomass:
# Model iAF1260.cmd: 5.8172818109952184E-5
# Model iJN1463.cmd: 8.554508658201438E-5
# Cycle 854
# Total biomass:
# Model iAF1260.cmd: 5.82200154669475E-5
# Model iJN1463.cmd: 8.55566130804011E-5
# Cycle 855
# Total biomass:
# Model iAF1260.cmd: 5.8266969535990636E-5
# Model iJN1463.cmd: 8.556804058850629E-5
# Cycle 856
# Total biomass:
# Model iAF1260.cmd: 5.831375537371282E-5
# Model iJN1463.cmd: 8.557938380462206E-5
# Cycle 857
# Total biomass:
# Model iAF1260.cmd: 5.836042486663138E-5
# Model iJN1463.cmd: 8.559066702969607E-5
# Cycle 858
# Total biomass:
# Model iAF1260.cmd: 5.8407230367710325E-5
# Model iJN1463.cmd: 8.560193932019923E-5
# Cycle 859
# Total biomass:
# Model iAF1260.cmd: 5.845375290226148E-5
# Model iJN1463.cmd: 8.561312035856806E-5
# Cycle 860
# Total biomass:
# Model iAF1260.cmd: 5.8500368310641214E-5
# Model iJN1463.cmd: 8.562427372369375E-5
# Cycle 861
# Total biomass:
# Model iAF1260.cmd: 5.854669232365246E-5
# Model iJN1463.cmd: 8.563533333907272E-5
# Cycle 862
# Total biomass:
# Model iAF1260.cmd: 5.8592864175618805E-5
# Model iJN1463.cmd: 8.564630997372483E-5
# Cycle 863
# Total biomass:
# Model iAF1260.cmd: 5.863892575572163E-5
# Model iJN1463.cmd: 8.565722267286845E-5
# Cycle 864
# Total biomass:
# Model iAF1260.cmd: 5.868488337195881E-5
# Model iJN1463.cmd: 8.566807386686905E-5
# Cycle 865
# Total biomass:
# Model iAF1260.cmd: 5.873074039225784E-5
# Model iJN1463.cmd: 8.567886432993796E-5
# Cycle 866
# Total biomass:
# Model iAF1260.cmd: 5.877667703872287E-5
# Model iJN1463.cmd: 8.568964877271499E-5
# Cycle 867
# Total biomass:
# Model iAF1260.cmd: 5.882256407264792E-5
# Model iJN1463.cmd: 8.570038168505908E-5
# Cycle 868
# Total biomass:
# Model iAF1260.cmd: 5.886821175301144E-5
# Model iJN1463.cmd: 8.571101945061655E-5
# Cycle 869
# Total biomass:
# Model iAF1260.cmd: 5.8913871965045466E-5
# Model iJN1463.cmd: 8.572162667980625E-5
# Cycle 870
# Total biomass:
# Model iAF1260.cmd: 5.8959466803691576E-5
# Model iJN1463.cmd: 8.573218049120003E-5
# Cycle 871
# Total biomass:
# Model iAF1260.cmd: 5.900520037083566E-5
# Model iJN1463.cmd: 8.574271900865706E-5
# Cycle 872
# Total biomass:
# Model iAF1260.cmd: 5.905074202283645E-5
# Model iJN1463.cmd: 8.575318191757275E-5
# Cycle 873
# Total biomass:
# Model iAF1260.cmd: 5.909601601535071E-5
# Model iJN1463.cmd: 8.57635358422096E-5
# Cycle 874
# Total biomass:
# Model iAF1260.cmd: 5.914111918952116E-5
# Model iJN1463.cmd: 8.577380813263082E-5
# Cycle 875
# Total biomass:
# Model iAF1260.cmd: 5.9186110403003145E-5
# Model iJN1463.cmd: 8.578402010767019E-5
# Cycle 876
# Total biomass:
# Model iAF1260.cmd: 5.923125484477026E-5
# Model iJN1463.cmd: 8.579422895093875E-5
# Cycle 877
# Total biomass:
# Model iAF1260.cmd: 5.927612618772048E-5
# Model iJN1463.cmd: 8.58043592701224E-5
# Cycle 878
# Total biomass:
# Model iAF1260.cmd: 5.9321103506402746E-5
# Model iJN1463.cmd: 8.581446494396927E-5
# Cycle 879
# Total biomass:
# Model iAF1260.cmd: 5.9365796157270385E-5
# Model iJN1463.cmd: 8.582448823657871E-5
# Cycle 880
# Total biomass:
# Model iAF1260.cmd: 5.9410337469909495E-5
# Model iJN1463.cmd: 8.583443232855148E-5
# Cycle 881
# Total biomass:
# Model iAF1260.cmd: 5.94548504894146E-5
# Model iJN1463.cmd: 8.584431718235925E-5
# Cycle 882
# Total biomass:
# Model iAF1260.cmd: 5.9499524055046544E-5
# Model iJN1463.cmd: 8.585420214568815E-5
# Cycle 883
# Total biomass:
# Model iAF1260.cmd: 5.954392186292821E-5
# Model iJN1463.cmd: 8.586400994460334E-5
# Cycle 884
# Total biomass:
# Model iAF1260.cmd: 5.958817216535586E-5
# Model iJN1463.cmd: 8.587374189816558E-5
# Cycle 885
# Total biomass:
# Model iAF1260.cmd: 5.9632319868165315E-5
# Model iJN1463.cmd: 8.5883416586403E-5
# Cycle 886
# Total biomass:
# Model iAF1260.cmd: 5.9676373150568444E-5
# Model iJN1463.cmd: 8.589303684328617E-5
# Cycle 887
# Total biomass:
# Model iAF1260.cmd: 5.9720334511245734E-5
# Model iJN1463.cmd: 8.590260407327807E-5
# Cycle 888
# Total biomass:
# Model iAF1260.cmd: 5.976446309599123E-5
# Model iJN1463.cmd: 8.591217076830712E-5
# Cycle 889
# Total biomass:
# Model iAF1260.cmd: 5.980831468831761E-5
# Model iJN1463.cmd: 8.592166113751415E-5
# Cycle 890
# Total biomass:
# Model iAF1260.cmd: 5.985213412954708E-5
# Model iJN1463.cmd: 8.593107686974995E-5
# Cycle 891
# Total biomass:
# Model iAF1260.cmd: 5.9896111009488654E-5
# Model iJN1463.cmd: 8.594048831087295E-5
# Cycle 892
# Total biomass:
# Model iAF1260.cmd: 5.993980593693476E-5
# Model iJN1463.cmd: 8.594982226094211E-5
# Cycle 893
# Total biomass:
# Model iAF1260.cmd: 5.9983614127370856E-5
# Model iJN1463.cmd: 8.595913341633482E-5
# Cycle 894
# Total biomass:
# Model iAF1260.cmd: 6.0027125228732616E-5
# Model iJN1463.cmd: 8.596836194490883E-5
# Cycle 895
# Total biomass:
# Model iAF1260.cmd: 6.0070754473827434E-5
# Model iJN1463.cmd: 8.597756880382699E-5
# Cycle 896
# Total biomass:
# Model iAF1260.cmd: 6.0114085276263455E-5
# Model iJN1463.cmd: 8.598669331199886E-5
# Cycle 897
# Total biomass:
# Model iAF1260.cmd: 6.0157272133043225E-5
# Model iJN1463.cmd: 8.599574406196596E-5
# Cycle 898
# Total biomass:
# Model iAF1260.cmd: 6.020035701326374E-5
# Model iJN1463.cmd: 8.60047386807345E-5
# Cycle 899
# Total biomass:
# Model iAF1260.cmd: 6.0243611343371535E-5
# Model iJN1463.cmd: 8.60137325518862E-5
# Cycle 900
# Total biomass:
# Model iAF1260.cmd: 6.028681931282112E-5
# Model iJN1463.cmd: 8.602268837240492E-5
# Cycle 901
# Total biomass:
# Model iAF1260.cmd: 6.032970632930679E-5
# Model iJN1463.cmd: 8.60315557440977E-5
# Cycle 902
# Total biomass:
# Model iAF1260.cmd: 6.037244200127216E-5
# Model iJN1463.cmd: 8.60403470246361E-5
# Cycle 903
# Total biomass:
# Model iAF1260.cmd: 6.0415337621412676E-5
# Model iJN1463.cmd: 8.604913388876618E-5
# Cycle 904
# Total biomass:
# Model iAF1260.cmd: 6.045818930219523E-5
# Model iJN1463.cmd: 8.60578841003958E-5
# Cycle 905
# Total biomass:
# Model iAF1260.cmd: 6.0500718140094666E-5
# Model iJN1463.cmd: 8.606654614097398E-5
# Cycle 906
# Total biomass:
# Model iAF1260.cmd: 6.0543211732982194E-5
# Model iJN1463.cmd: 8.60751334809109E-5
# Cycle 907
# Total biomass:
# Model iAF1260.cmd: 6.058560166336582E-5
# Model iJN1463.cmd: 8.608366557665691E-5
# Cycle 908
# Total biomass:
# Model iAF1260.cmd: 6.0627898201810435E-5
# Model iJN1463.cmd: 8.609214588215368E-5
# Cycle 909
# Total biomass:
# Model iAF1260.cmd: 6.0670104527764706E-5
# Model iJN1463.cmd: 8.610057561849889E-5
# Cycle 910
# Total biomass:
# Model iAF1260.cmd: 6.071222137261267E-5
# Model iJN1463.cmd: 8.610895509902158E-5
# Cycle 911
# Total biomass:
# Model iAF1260.cmd: 6.0754249412902035E-5
# Model iJN1463.cmd: 8.611728468413923E-5
# Cycle 912
# Total biomass:
# Model iAF1260.cmd: 6.079618883645775E-5
# Model iJN1463.cmd: 8.612556433941036E-5
# Cycle 913
# Total biomass:
# Model iAF1260.cmd: 6.0838039597545365E-5
# Model iJN1463.cmd: 8.613379425679159E-5
# Cycle 914
# Total biomass:
# Model iAF1260.cmd: 6.087980195865767E-5
# Model iJN1463.cmd: 8.614197468415918E-5
# Cycle 915
# Total biomass:
# Model iAF1260.cmd: 6.092147633536372E-5
# Model iJN1463.cmd: 8.615010569317946E-5
# Cycle 916
# Total biomass:
# Model iAF1260.cmd: 6.0963062117177056E-5
# Model iJN1463.cmd: 8.615818772218086E-5
# Cycle 917
# Total biomass:
# Model iAF1260.cmd: 6.100456047062608E-5
# Model iJN1463.cmd: 8.616622139362332E-5
# Cycle 918
# Total biomass:
# Model iAF1260.cmd: 6.104597045905671E-5
# Model iJN1463.cmd: 8.61742066941649E-5
# Cycle 919
# Total biomass:
# Model iAF1260.cmd: 6.108729284507335E-5
# Model iJN1463.cmd: 8.618214353679274E-5
# Cycle 920
# Total biomass:
# Model iAF1260.cmd: 6.112852729717324E-5
# Model iJN1463.cmd: 8.619003193721172E-5
# Cycle 921
# Total biomass:
# Model iAF1260.cmd: 6.116967395287537E-5
# Model iJN1463.cmd: 8.619787193133428E-5
# Cycle 922
# Total biomass:
# Model iAF1260.cmd: 6.121073387441376E-5
# Model iJN1463.cmd: 8.620566376070492E-5
# Cycle 923
# Total biomass:
# Model iAF1260.cmd: 6.125170616886722E-5
# Model iJN1463.cmd: 8.621340746604544E-5
# Cycle 924
# Total biomass:
# Model iAF1260.cmd: 6.129259124283844E-5
# Model iJN1463.cmd: 8.622110350600127E-5
# Cycle 925
# Total biomass:
# Model iAF1260.cmd: 6.133338890346174E-5
# Model iJN1463.cmd: 8.622875216680595E-5
# Cycle 926
# Total biomass:
# Model iAF1260.cmd: 6.13740994516908E-5
# Model iJN1463.cmd: 8.6236353417988E-5
# Cycle 927
# Total biomass:
# Model iAF1260.cmd: 6.141472322155039E-5
# Model iJN1463.cmd: 8.624390740079199E-5
# Cycle 928
# Total biomass:
# Model iAF1260.cmd: 6.145526036708995E-5
# Model iJN1463.cmd: 8.625141455223478E-5
# Cycle 929
# Total biomass:
# Model iAF1260.cmd: 6.149571058095187E-5
# Model iJN1463.cmd: 8.625887469560384E-5
# Cycle 930
# Total biomass:
# Model iAF1260.cmd: 6.153607482150419E-5
# Model iJN1463.cmd: 8.62662877983847E-5
# Cycle 931
# Total biomass:
# Model iAF1260.cmd: 6.157635225203933E-5
# Model iJN1463.cmd: 8.627365386486211E-5
# Cycle 932
# Total biomass:
# Model iAF1260.cmd: 6.161654414537066E-5
# Model iJN1463.cmd: 8.62809730473258E-5
# Cycle 933
# Total biomass:
# Model iAF1260.cmd: 6.165685415774092E-5
# Model iJN1463.cmd: 8.628829831445918E-5
# Cycle 934
# Total biomass:
# Model iAF1260.cmd: 6.169695203084935E-5
# Model iJN1463.cmd: 8.629555434055287E-5
# Cycle 935
# Total biomass:
# Model iAF1260.cmd: 6.173690977786389E-5
# Model iJN1463.cmd: 8.630274352742542E-5
# Cycle 936
# Total biomass:
# Model iAF1260.cmd: 6.177676404331127E-5
# Model iJN1463.cmd: 8.6309880519709E-5
# Cycle 937
# Total biomass:
# Model iAF1260.cmd: 6.181652626941107E-5
# Model iJN1463.cmd: 8.631696970954934E-5
# Cycle 938
# Total biomass:
# Model iAF1260.cmd: 6.185620197491756E-5
# Model iJN1463.cmd: 8.632401337509818E-5
# Cycle 939
# Total biomass:
# Model iAF1260.cmd: 6.189579331428268E-5
# Model iJN1463.cmd: 8.633101192030983E-5
# Cycle 940
# Total biomass:
# Model iAF1260.cmd: 6.193530038363073E-5
# Model iJN1463.cmd: 8.633796532173209E-5
# Cycle 941
# Total biomass:
# Model iAF1260.cmd: 6.19748098620426E-5
# Model iJN1463.cmd: 8.634487369431095E-5
# Cycle 942
# Total biomass:
# Model iAF1260.cmd: 6.201423847526435E-5
# Model iJN1463.cmd: 8.63517391940707E-5
# Cycle 943
# Total biomass:
# Model iAF1260.cmd: 6.205358865235082E-5
# Model iJN1463.cmd: 8.635856207747437E-5
# Cycle 944
# Total biomass:
# Model iAF1260.cmd: 6.209286057286026E-5
# Model iJN1463.cmd: 8.636534246923921E-5
# Cycle 945
# Total biomass:
# Model iAF1260.cmd: 6.213213812092214E-5
# Model iJN1463.cmd: 8.637208101073713E-5
# Cycle 946
# Total biomass:
# Model iAF1260.cmd: 6.217133780726725E-5
# Model iJN1463.cmd: 8.637877886589877E-5
# Cycle 947
# Total biomass:
# Model iAF1260.cmd: 6.221045953323483E-5
# Model iJN1463.cmd: 8.638543539267191E-5
# Cycle 948
# Total biomass:
# Model iAF1260.cmd: 6.22495031531055E-5
# Model iJN1463.cmd: 8.639205079126756E-5
# Cycle 949
# Total biomass:
# Model iAF1260.cmd: 6.228846926307513E-5
# Model iJN1463.cmd: 8.63986257330528E-5
# Cycle 950
# Total biomass:
# Model iAF1260.cmd: 6.232735818598843E-5
# Model iJN1463.cmd: 8.640516063004358E-5
# Cycle 951
# Total biomass:
# Model iAF1260.cmd: 6.236616975030411E-5
# Model iJN1463.cmd: 8.641165532058664E-5
# Cycle 952
# Total biomass:
# Model iAF1260.cmd: 6.240490398139903E-5
# Model iJN1463.cmd: 8.641810983723495E-5
# Cycle 953
# Total biomass:
# Model iAF1260.cmd: 6.244356068753785E-5
# Model iJN1463.cmd: 8.642452423645917E-5
# Cycle 954
# Total biomass:
# Model iAF1260.cmd: 6.248214039298285E-5
# Model iJN1463.cmd: 8.643089861805654E-5
# Cycle 955
# Total biomass:
# Model iAF1260.cmd: 6.252064313242215E-5
# Model iJN1463.cmd: 8.643723326008312E-5
# Cycle 956
# Total biomass:
# Model iAF1260.cmd: 6.255906952136086E-5
# Model iJN1463.cmd: 8.644352816060976E-5
# Cycle 957
# Total biomass:
# Model iAF1260.cmd: 6.259741884359187E-5
# Model iJN1463.cmd: 8.64497833548107E-5
# Cycle 958
# Total biomass:
# Model iAF1260.cmd: 6.263569201625012E-5
# Model iJN1463.cmd: 8.645599892050358E-5
# Cycle 959
# Total biomass:
# Model iAF1260.cmd: 6.267388815991386E-5
# Model iJN1463.cmd: 8.646217555930562E-5
# Cycle 960
# Total biomass:
# Model iAF1260.cmd: 6.271200852912358E-5
# Model iJN1463.cmd: 8.646831334181953E-5
# Cycle 961
# Total biomass:
# Model iAF1260.cmd: 6.275032845413304E-5
# Model iJN1463.cmd: 8.647445817325063E-5
# Cycle 962
# Total biomass:
# Model iAF1260.cmd: 6.278837938438011E-5
# Model iJN1463.cmd: 8.64805472316112E-5
# Cycle 963
# Total biomass:
# Model iAF1260.cmd: 6.282629382711037E-5
# Model iJN1463.cmd: 8.648657587360992E-5
# Cycle 964
# Total biomass:
# Model iAF1260.cmd: 6.286411700536987E-5
# Model iJN1463.cmd: 8.64925605755311E-5
# Cycle 965
# Total biomass:
# Model iAF1260.cmd: 6.290185926861104E-5
# Model iJN1463.cmd: 8.649850509340322E-5
# Cycle 966
# Total biomass:
# Model iAF1260.cmd: 6.293952506642872E-5
# Model iJN1463.cmd: 8.650441063490225E-5
# Cycle 967
# Total biomass:
# Model iAF1260.cmd: 6.297711463522311E-5
# Model iJN1463.cmd: 8.651027777535412E-5
# Cycle 968
# Total biomass:
# Model iAF1260.cmd: 6.301462884061224E-5
# Model iJN1463.cmd: 8.651610653608393E-5
# Cycle 969
# Total biomass:
# Model iAF1260.cmd: 6.305206733666904E-5
# Model iJN1463.cmd: 8.652189753490404E-5
# Cycle 970
# Total biomass:
# Model iAF1260.cmd: 6.308943110629506E-5
# Model iJN1463.cmd: 8.652765072090395E-5
# Cycle 971
# Total biomass:
# Model iAF1260.cmd: 6.312672110566626E-5
# Model iJN1463.cmd: 8.653336632567103E-5
# Cycle 972
# Total biomass:
# Model iAF1260.cmd: 6.316393748167465E-5
# Model iJN1463.cmd: 8.653904464940683E-5
# Cycle 973
# Total biomass:
# Model iAF1260.cmd: 6.320108084438158E-5
# Model iJN1463.cmd: 8.654468598759541E-5
# Cycle 974
# Total biomass:
# Model iAF1260.cmd: 6.32381636304271E-5
# Model iJN1463.cmd: 8.655023121037779E-5
# Cycle 975
# Total biomass:
# Model iAF1260.cmd: 6.327077791164455E-5
# Model iJN1463.cmd: 8.655278051060875E-5
# Cycle 976
# Total biomass:
# Model iAF1260.cmd: 6.330138495158829E-5
# Model iJN1463.cmd: 8.655471870368787E-5
# Cycle 977
# Total biomass:
# Model iAF1260.cmd: 6.33319859388172E-5
# Model iJN1463.cmd: 8.65565095248156E-5
# Cycle 978
# Total biomass:
# Model iAF1260.cmd: 6.336237109863042E-5
# Model iJN1463.cmd: 8.655825232341239E-5
# Cycle 979
# Total biomass:
# Model iAF1260.cmd: 6.33925632274447E-5
# Model iJN1463.cmd: 8.655997116038468E-5
# Cycle 980
# Total biomass:
# Model iAF1260.cmd: 6.342236288946531E-5
# Model iJN1463.cmd: 8.656171042702568E-5
# Cycle 981
# Total biomass:
# Model iAF1260.cmd: 6.3457342790924E-5
# Model iJN1463.cmd: 8.656497222018924E-5
# Cycle 982
# Total biomass:
# Model iAF1260.cmd: 6.349376845900357E-5
# Model iJN1463.cmd: 8.656924943384542E-5
# Cycle 983
# Total biomass:
# Model iAF1260.cmd: 6.35292568659451E-5
# Model iJN1463.cmd: 8.657366706434495E-5
# Cycle 984
# Total biomass:
# Model iAF1260.cmd: 6.35652259769228E-5
# Model iJN1463.cmd: 8.657860955892811E-5
# Cycle 985
# Total biomass:
# Model iAF1260.cmd: 6.360135960597056E-5
# Model iJN1463.cmd: 8.6583730777181E-5
# Cycle 986
# Total biomass:
# Model iAF1260.cmd: 6.363752033644228E-5
# Model iJN1463.cmd: 8.658888586035312E-5
# Cycle 987
# Total biomass:
# Model iAF1260.cmd: 6.367364193314478E-5
# Model iJN1463.cmd: 8.659402752035659E-5
# Cycle 988
# Total biomass:
# Model iAF1260.cmd: 6.370970360073555E-5
# Model iJN1463.cmd: 8.659914126867925E-5
# Cycle 989
# Total biomass:
# Model iAF1260.cmd: 6.374569807414918E-5
# Model iJN1463.cmd: 8.660422294980333E-5
# Cycle 990
# Total biomass:
# Model iAF1260.cmd: 6.378170034903468E-5
# Model iJN1463.cmd: 8.660920106741526E-5
# Cycle 991
# Total biomass:
# Model iAF1260.cmd: 6.381350503771828E-5
# Model iJN1463.cmd: 8.661146955453328E-5
# Cycle 992
# Total biomass:
# Model iAF1260.cmd: 6.384335659162272E-5
# Model iJN1463.cmd: 8.661318381407139E-5
# Cycle 993
# Total biomass:
# Model iAF1260.cmd: 6.387297746167637E-5
# Model iJN1463.cmd: 8.661475961958812E-5
# Cycle 994
# Total biomass:
# Model iAF1260.cmd: 6.3902392623503E-5
# Model iJN1463.cmd: 8.661629084146572E-5
# Cycle 995
# Total biomass:
# Model iAF1260.cmd: 6.393171481401453E-5
# Model iJN1463.cmd: 8.661780947036482E-5
# Cycle 996
# Total biomass:
# Model iAF1260.cmd: 6.396019841588842E-5
# Model iJN1463.cmd: 8.661935239463605E-5
# Cycle 997
# Total biomass:
# Model iAF1260.cmd: 6.398924074360043E-5
# Model iJN1463.cmd: 8.662098825459256E-5
# Cycle 998
# Total biomass:
# Model iAF1260.cmd: 6.40170409280473E-5
# Model iJN1463.cmd: 8.662238499426361E-5
# Cycle 999
# Total biomass:
# Model iAF1260.cmd: 6.404446081650111E-5
# Model iJN1463.cmd: 8.662381983958131E-5
# Cycle 1000
# Total biomass:
# Model iAF1260.cmd: 6.407203625573473E-5
# Model iJN1463.cmd: 8.662532950619162E-5
# Cycle 1001
# End of simulation
# Total time = 9779.401s
#
# STDERR empty.

# %% [markdown]
# Para revisar la biomasa total

# %%
sim.total_biomass.plot(x = "cycle")
# Out:
# <AxesSubplot:xlabel='cycle'>

# %% [markdown]
# Graficamos los resultados de biomasa y demás metabolitos interesantes en el grid:

# %%
im = sim.get_biomass_image('iAF1260', params.all_params['maxCycles'])
im2 = sim.get_biomass_image('iJN1463',params.all_params['maxCycles'])

final = np.zeros((grid_size,grid_size,3))
final[:,:,0] = im / np.max(im)
final[:,:,1] = im2 / np.max(im2)
for rock in rock_locs:
    final[rock[0],rock[1],0:3] = 0.4 
from matplotlib import pyplot as plt
ﬁg, ax = plt.subplots(ﬁgsize = (3.1, 3.1))
ax.imshow(ﬁnal)
plt.imshow(final)

# %%
plt.imshow(sim.get_metabolite_image("succ_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("ac_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("nh4_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("o2_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("catechol_e",params.all_params['maxCycles']))
