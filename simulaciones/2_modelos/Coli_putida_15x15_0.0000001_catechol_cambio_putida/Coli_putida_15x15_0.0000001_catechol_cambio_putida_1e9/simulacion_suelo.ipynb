# %% [markdown]
# **Soil-air interface.**
#
# Using the functionality of COMETS, one can design simulations which go beyond in silico corollaries of lab experiments to make predictions for environments mimicking natural ecosystems, which is a necessary step for understanding natural ecology from first principles. In this example, we consider a simulation of a soil environment. We use source-and-sink functions to model how a root provides organic acids to the environment while removing ammonia (Huang et al 2014 Botany). While we restrict the root functionality to a source/sink, one could use functionality demonstrated above, for example extracellular enzymes, to generate feedback loops between microbe-produced metabolites and root exudation. We use fixed metabolite concentrations to mimic the largely unchanging air interface above a root, which generates an oxygen gradient. Additionally, since soil is characterized by strong spatial structure with many impenetrable barriers that localized interactions (Nunan 2017), we place “rock” barriers throughout the simulation area. A more complex simulation could use varying diffusion constants for metabolites, as described in a previous protocol (Virtual Petri Dish). Similarly, we use standard diffusion of biomass, but this could be changed to use pushing force or non-linear diffusion for a potentially increased realism.

# %%
import cobra 
import sys 
import copy 
import numpy as np 
from matplotlib import pyplot as plt 
import cometspy as c

# %% [markdown]
# Para nuestro proyecto, utilizaremos Escherichia coli (modelo iAF1260), Pseudomonas putida (modelo iJN1463) y Saccharomyces Cerevisiae (modelo iMM904), recuperados de la base de datos BIGG.
#
# Cambiamos los bounds de las funciones objetivo de los modelos:

# %%
model_dir = "./modelos" # model location
iAF = cobra.io.read_sbml_model(model_dir + '/iAF1260.xml')
iJN = cobra.io.read_sbml_model(model_dir + '/iJN1463.xml')

iAF.reactions.get_by_id('BIOMASS_Ec_iAF1260_core_59p81M').lower_bound = 0
iAF.reactions.get_by_id('BIOMASS_Ec_iAF1260_core_59p81M').upper_bound = 1000

iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').lower_bound = 0
iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').upper_bound = 1000

# %% [markdown]
# Luego se convierten estos modelos al formato de COMETS. Se utilizan funciones helper para dos cosas: a) Asegurar que el modelo en COMETS no confunda las reacciones de "sink" con las de exchange, ya que en COBRA están desbalanceadas y por tanto se parecen a las de exchange, y b) abrir todos los bounds de las reacciones de exchange, para que COMETS controle la composición del medio.

# %%
iAF_comets = c.model(iAF)
iAF_comets.ensure_sinks_are_not_exchanges()
iAF_comets.open_exchanges()

iJN_comets = c.model(iJN)
iJN_comets.ensure_sinks_are_not_exchanges()
iJN_comets.open_exchanges()

# %% [markdown]
# El mundo que se simulará tendrá dimensiones de 30x30. El eje de la izquierda (x = 0) corresponde a la raíz, y el eje superior (y = 0) corresponde al aire. La biomasa y las rocas se distribuyen en el resto del grid. Donde hayan rocas no puede haber ni biomasa ni metabolitos, así que seleccionamos esos lugares primero. Para esta simulación, se generarán 3 rocas con un un tamaño medio de 1 cuadraditos. Para generar las piedras se utiliza la función helper grow_rocks.

# %%
from cometspy.utils import grow_rocks, pick_random_locations

grid_size = 15 # 100
n_rocks = 27 # 70
rock_locs = grow_rocks(n = n_rocks, xrange = [1,grid_size-1],yrange = [1,grid_size-1],mean_size = 1)

# %% [markdown]
# Cada especie será plantada en 20 lugares sin sobreponerse. Para esto se utiliza la función helper pick_random_locations, la cual toma como argumento una tupla generada anteriormente que marca lugares "prohibidos", como los cuadrados donde se encuentran las rocas.
#
# Generamos una copia de rock_locs para no cambiarla accidentalmente, y la llamamos forbbiden_locs:

# %%
import copy
forbidden_locs = copy.deepcopy(rock_locs)

# %% [markdown]
# Ahora elegimos al azar los lugares para cada especie, y los vamos añadiendo a la lista forbidden locs para que no se sobrepongan:

# %%
founders_per_species = 15 # 60
iAF_locs = pick_random_locations(n = founders_per_species, 
                                   xrange = [1,grid_size], yrange = [1,grid_size], 
                                   forbidden_locs = forbidden_locs)
forbidden_locs.extend(iAF_locs)
iJN_locs = pick_random_locations(founders_per_species, [1,grid_size],[1,grid_size], forbidden_locs)

# %% [markdown]
# Para graficar los lugares utilizamos matplotlib:

# %%
from matplotlib import pyplot as plt
initial_image = np.zeros((grid_size,grid_size,3))
for rock in rock_locs:
    initial_image[rock[0],rock[1],0:3] = 0.5 
for loc in iAF_locs:
    initial_image[loc[0],loc[1],1] = 1
for loc in iJN_locs:
    initial_image[loc[0],loc[1],2] = 1
plt.imshow(initial_image)

# %% [markdown]
# Generamos el layout y agregamos las rocas:

# %%
# iAF
iAF_initial_pop = [] 
for loc in iJN_locs: 
    iAF_initial_pop.append([loc[0], loc[1], 1.e-8]) 
iAF_comets.initial_pop = iAF_initial_pop 
# iJN
iJN_initial_pop = [] 
for loc in iJN_locs: 
    iJN_initial_pop.append([loc[0], loc[1], 1.e-9]) 
iJN_comets.initial_pop = iJN_initial_pop

# %% [markdown]
# Setteamos las poblaciones iniciales para cada especie, con esto los modelos están listos y los añadimos al layout:

# %%
layout = c.layout([iAF_comets, iJN_comets])
layout.grid = [grid_size,grid_size]
layout.add_barriers(rock_locs)

# %% [markdown]
# Añadimos los metabolitos que estarán inicialmente disponibles en el ambiente. Usamos la función helper add_typical_trace_metabolites() para las trazas típicas. Bajamos el valor del oxígeno dado que la idea es que el que esté disponible difunda desde la atmósfera. Añadimos algunos metabolitos que no se añadieron con la función helper:

# %%
layout.add_typical_trace_metabolites()
layout.set_specific_metabolite('o2_e',0.000001)
layout.set_specific_metabolite('hco3_e',1000)
layout.set_specific_metabolite('co2_e',1000)
layout.set_specific_metabolite('h2_e',1000)
layout.set_specific_metabolite('so3_e',1000)
layout.set_specific_metabolite('nh4_e',0.0000001)

layout.set_specific_metabolite('glc__D_e',0.0000001)
layout.set_specific_metabolite('meoh_e',0.00000001)
layout.set_specific_metabolite('cys__L_e',0.0000001)
layout.set_specific_metabolite('catechol_e',0.0000001)

# %% [markdown]
# Para la capa de aire, dejamos el oxígeno en un valor constante. Al fondo también dejamos al oxígeno en un valor fijo e igual a 0, para simular el efecto de difusión. De manera similar, hacemos lo mismo con el amoniaco y la raíz en la parte izquierda:

# %%
# set static media of O2 and CO2 at the top and bottom-- the "air" and continuous loss of O2 downwards
for x in range(grid_size):
    layout.set_specific_static_at_location('o2_e', (x,0), .0001) # top
    layout.set_specific_static_at_location('o2_e', (x,grid_size-1), 0.) # bottom
    layout.set_specific_static_at_location('co2_e', (x,0), .0001)
    
for x in range(grid_size):
    layout.set_specific_static_at_location('nh4_e', (0,x), 0.0)

# %% [markdown]
# La raíz consume todo el amoniaco, pero es una fuente de acidos orgánicos y metanol para el ambiente. Asumiendo una tasa fija:

# %%
for x in range(grid_size):
    layout.set_specific_refresh_at_location('cit_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('meoh_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('succ_e', (0,x), .000001)

# %% [markdown]
# El layout y los modelos están listos, ahora setteamos los parámetros de la simulación:

# %%
params = c.params()
params.set_param('timeStep', 0.1)
params.set_param('maxCycles', 1000)
params.set_param('maxSpaceBiomass', 10)
params.set_param('deathRate', 0.0001) # die at rate of 1/10000 per hour
params.set_param('writeBiomassLog', True)
params.set_param('BiomassLogRate', 500)
params.set_param('writeMediaLog', True)
params.set_param('MediaLogRate', 500)
params.set_param("writeFluxLog", True)
params.set_param("FluxLogRate", 500)
params.set_param('numRunThreads', 3)
params.set_param('defaultKm', 0.000001)

# %% [markdown]
# Ahora creamos el objeto de la simulación y la corremos. Ojito que se demora y el pc empieza a despegar.

# %%
sim = c.comets(layout, params)
sim.run(False)
# Out:
# Running COMETS simulation ...
# C:\Users\pabli\AppData\Local\Temp/ipykernel_32896/1491467366.py:2: DtypeWarning: Columns (5,8,12,14,18,22,26,28,32,43,44,47,51,64,66,68,70,72,73,75,79,81,83,96,100,102,103,104,114,116,118,121,122,124,130,132,137,142,144,146,147,149,151,153,155,166,167,177,182,200,203,206,213,228,229,230,233,238,243,254,255,256,257,258,282,292,294,297,298,324,327,345,346,366,369,399,406,407,408,410,411,412,413,414,417,419,420,422,440,443,459,463,470,472,476,487,488,491,514,515,517,518,523,527,530,535,537,540,549,557,559,560,569,597,607,619,631,639,640,665,669,670,676,678,691,693,696,698,708,710,716,717,718,719,720,723,724,725,727,729,730,732,734,736,740,744,746,747,751,758,762,768,769,792,798,799,807,811,821,832,847,863,866,868,870,871,872,885,909,910,911,913,926,930,938,941,945,953,954,960,964,966,968,969,973,974,975,976,977,978,982,991,1021,1024,1025,1064,1065,1073,1084,1086,1088,1099,1113,1124,1125,1128,1134,1149,1151,1166,1180,1184,1185,1193,1197,1200,1203,1204,1216,1220,1221,1222,1225,1227,1232,1233,1243,1244,1246,1248,1255,1261,1262,1264,1266,1268,1269,1276,1279,1281,1282,1288,1297,1301,1302,1303,1307,1308,1310,1315,1316,1318,1320,1334,1336,1346,1363,1369,1371,1376,1377,1412,1418,1419,1421,1424,1426,1428,1439,1469,1474,1476,1478,1481,1499,1500,1501,1502,1503,1504,1505,1507,1508,1509,1510,1511,1515,1516,1517,1518,1519,1520,1521,1524,1526,1527,1528,1530,1534,1535,1542,1567,1601,1618,1620,1621,1622,1645,1660,1689,1692,1693,1726,1727,1734,1741,1746,1747,1755,1764,1766,1768,1770,1772,1774,1778,1790,1796,1799,1810,1811,1815,1816,1830,1831,1836,1855,1868,1878,1890,1891,1895,1902,1911,1915,1918,1919,1920,1921,1923,1924,1925,1927,1931,1932,1933,1934,1935,1936,1937,1938,1940,1941,1943,1944,1947,1949,1950,1958,1961,1963,1969,1970,1974,1975,1977,1978,1984,1985,1986,1987,1988,1989,1990,1991,1992,1994,1998,1999,2001,2002,2009,2055,2056,2060,2063,2072,2075,2079,2080,2085,2093,2094,2096,2098,2099,2103,2106,2107,2113,2121,2133,2134,2148,2150,2160,2167,2181,2219,2227,2231,2259,2262,2267,2268,2269,2274,2281,2282,2284,2285,2376,2382,2388,2391,2401,2402,2410,2431,2453,2474,2477,2480,2529,2533,2609,2639,2682,2694,2714,2719,2720,2769,2828,2833,2837,2840,2842,2852,2855,2857,2888,2900) have mixed types.Specify dtype option on import or set low_memory=False.
#   sim.run(False)
# Done!

# %%
print(sim.run_output)
print(sim.run_errors)
# Out:
# -script
# running script file: C:\Users\pabli\OneDrive\Escritorio\COMETS\ODRM\simulaciones\2_modelos\Coli_putida_15x15_0.0000001_catechol_cambio_putida\Coli_putida_15x15_0.0000001_catechol_cambio_putida_1e9/.current_script_0x2178ba5bca0
# Current Java version: 17.0.1
# Parameters file .current_global_0x2178ba5bca0 loaded.
# Parameters file .current_package_0x2178ba5bca0 loaded.
# Loading layout file '.current_layout_0x2178ba5bca0'...
# null\COMETS_manifest.txt (El sistema no puede encontrar la ruta especificada)
# Unable to initialize manifest file.
# Continuing without writing manifest file.
# Found 2 model files!
# Loading '.\iAF1260.cmd' ...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution = 395.73529219628256
# Loading '.\iJN1463.cmd' ...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution = 237.06607191111308
# Constructing world...
# Done!
# medialist	12dgr160_e	12dgr180_e	12ppd__R_e	12ppd__S_e	13dampp_e	14glucan_e	15dap_e	1ag160_e	1ag180_e	1ag181d9_e	1ag182d9d12_e	23camp_e	23ccmp_e	23cgmp_e	23cump_e	23dappa_e	25dkglcn_e	26dap__M_e	2ameph_e	2ddglcn_e	2dhglcn_e	2m35mdntha_e	34dhbz_e	34dhcinm_e	34dhpac_e	34dhphe_e	35dnta_e	3amp_e	3cmp_e	3gmp_e	3h4atb_e	3hcinnm_e	3hpppn_e	3mb_e	3oxoadp_e	3ump_e	4abut_e	4hbz_e	4hoxpacd_e	4hpro_DC_e	4hpro_LT_e	4hptn_e	4oxptn_e	5aptn_e	5dglcn_e	5g2oxpt_e	5mcsn_e	5oxpro_e	6atha_e	6hnac_e	LalaDgluMdapDala_e	LalaDgluMdap_e	LalaLglu_e	Ncbmpts_e	R3hdec4e_e	R_3h4atba_e	R_3h6atha_e	R_3hcmrs7e_e	R_3hdcaa_e	R_3hdd5ea_e	R_3hdd6e_e	R_3hdda_e	R_3hhdca_e	R_3hhpa_e	R_3hhxa_e	R_3hnonaa_e	R_3hocta_e	R_3hpba_e	R_3hpdeca_e	R_3hphpa_e	R_3hphxa_e	R_3hpnona_e	R_3hpocta_e	R_3hppta_e	R_3hpt_e	R_3htd58e_e	R_3htd5e_e	R_3httdca_e	T4hcinnm_e	ac_e	acac_e	acald_e	acgal1p_e	acgal_e	acgam1p_e	acgam_e	acmana_e	acmtsoxin_e	acmum_e	acnam_e	acolipa_e	acon_C_e	acpptrn_e	acser_e	actn__R_e	ade_e	adn_e	adocbl_e	ag_e	agm_e	akg_e	ala_B_e	ala__D_e	ala__L_e	alaala_e	alahis_e	alaleu_e	alathr_e	alatrp_e	algac_MG_14_e	algac_MG_23_e	algac_MG_32_e	algac_MG_41_e	algac__M_e	all__D_e	alltn_e	amp_e	anhgm_e	apc_e	arab__L_e	arbtn_e	arbtn_fe3_e	arg__D_e	arg__L_e	ascb__L_e	asn__D_e	asn__L_e	aso3_e	aso4_e	asp__L_e	balaala_e	balabala_e	balagly_e	balaleu_e	balamd_e	bhb_e	biliverd_e	btd_RR_e	btn_e	but_e	butso3_e	bz_e	ca2_e	carn_e	catechol_e	cbi_e	cbl1_e	cd2_e	cell4_e	cgly_e	chol_e	chols_e	chor_e	cinnm_e	cit_e	cl_e	cm_e	cmcbtt_e	cmp_e	co2_e	co_e	cobalt2_e	colipa_e	confrl_e	cpgn_e	cpgn_un_e	creat_e	crn_e	cro2_e	cro4_e	crtn_e	csn_e	cu2_e	cu_e	cyan_e	cynt_e	cys__D_e	cys__L_e	cytd_e	d2one_e	d3one_e	d4one_e	dad_2_e	dag181d9_e	dag182d9d12_e	damp_e	dca_e	dcmp_e	dcyt_e	ddca_e	dgmp_e	dgsn_e	dgudbutn_e	dha_e	dimp_e	din_e	dmanur_e	dmgly_e	dms_e	dmso2_e	dmso_e	dopa_e	dtmp_e	dump_e	duri_e	eca4colipa_e	ecto__L_e	enlipa_e	enter_e	etha_e	ethso3_e	etoh_e	f6p_e	fald_e	fcmcbtt_e	fe2_e	fe3_e	fe3dcit_e	fe3dhbzs_e	fe3hox_e	fe3hox_un_e	fe3mcbtt_e	fe3pyovd_e	fe3pyovd_kt_e	fecrm_e	fecrm_un_e	feenter_e	feoxam_e	feoxam_un_e	fer_e	for_e	fru_e	frulys_e	fruur_e	fuc__L_e	fum_e	g1p_e	g3pc_e	g3pe_e	g3pg_e	g3pi_e	g3ps_e	g6p_e	ga_e	gal1p_e	gal_bD_e	gal_e	galct__D_e	galctn__D_e	galctn__L_e	galt_e	galur_e	gam6p_e	gam_e	gbbtn_e	gdp_e	glc__D_e	glcn_e	glcr_e	glcur1p_e	glcur_e	gln__L_e	glu__L_e	glutar_e	gly_e	glyald_e	glyb_e	glyc2p_e	glyc3p_e	glyc__R_e	glyc_e	glyclt_e	glycol_e	glygln_e	glyglu_e	glygly_e	glymet_e	glyphe_e	glyser_e	gmp_e	gsn_e	gthox_e	gthrd_e	gtp_e	gua_e	gudac_e	gudptn_e	h2_e	h2o2_e	h2o_e	h2s_e	h_e	hacolipa_e	halipa_e	hco3_e	hcys__L_e	hdca_e	hdcea_e	hg2_e	hgentis_e	his__L_e	hisgly_e	hishis_e	hom__L_e	hpta_e	hxa_e	hxan_e	icit_e	idon__L_e	ile__L_e	imp_e	ind3ac_e	indole_e	inost_e	ins_e	isetac_e	k_e	kdo2lipid4_e	lac__D_e	lac__L_e	lcts_e	leu__D_e	leu__L_e	leuleu_e	lipa_cold_e	lipa_e	lnlc_e	lpspput_e	lys__D_e	lys__L_e	lyx__L_e	m_xyl_e	mal__D_e	mal__L_e	malt_e	malthx_e	maltpt_e	malttr_e	maltttr_e	man6p_e	man_e	manglyc_e	manur_e	mcbtt_e	melib_e	meoh_e	met__D_e	met__L_e	metsox_R__L_e	metsox_S__L_e	mg2_e	minohp_e	mmet_e	mn2_e	mnl_e	mobd_e	mso3_e	mtsoxin_e	n2o_e	n2one_e	na1_e	nac_e	nh4_e	ni2_e	nmn_e	no2_e	no3_e	no_e	nona_e	o16a4colipa_e	o2_e	o2s_e	o_xyl_e	oaa_e	ocdca_e	ocdcea_e	octa_e	orn__D_e	orn_e	orot_e	oxa_e	p_xyl_e	pac_e	pacald_e	pb2_e	pea_e	peamn_e	pentso3_e	phe__D_e	phe__L_e	phedca_e	phehpa_e	phehxa_e	pheme_e	phenona_e	pheocta_e	phept_e	phpyr_e	pi_e	pnto__R_e	ppa_e	ppal_e	ppi_e	pppn_e	ppt_e	pptrn_e	prealg_MG_14_e	prealg_MG_23_e	prealg_MG_32_e	prealg_MG_41_e	prealginate_G_e	pro__D_e	pro__L_e	progly_e	psclys_e	pser__L_e	pta_e	ptrc_e	ptsla_e	pydam_e	pyovd_e	pyovd_kt_e	pyr_e	quin_e	r5p_e	rib__D_e	rmn_e	sbo3_e	sbt__D_e	sel_e	ser__D_e	ser__L_e	sheme_e	skm_e	so2_e	so3_e	so4_e	spmd_e	succ_e	sucr_e	sulfac_e	tag160_e	tag180_e	tag181d9_e	tag182d9d12_e	tartr__L_e	taur_e	tcynt_e	thm_e	thr__L_e	thrp_e	thym_e	thymd_e	tma_e	tmanur_e	tmao_e	tnt_e	tol_e	tre_e	trp__L_e	tsul_e	ttdca_e	ttdcea_e	ttrcyc_e	tungs_e	tym_e	tyr__D_e	tyr__L_e	tyrp_e	uacg ...
# Cycle 1
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# FBARunThread-0 starting up.
# FBARunThread-1 starting up.
# FBARunThread-2 starting up.
# Total biomass:
# Model iAF1260.cmd: 1.5785755296924347E-7
# Model iJN1463.cmd: 1.552141073421856E-8
# Cycle 2
# Total biomass:
# Model iAF1260.cmd: 1.661739380757188E-7
# Model iJN1463.cmd: 1.6067055175776885E-8
# Cycle 3
# Total biomass:
# Model iAF1260.cmd: 1.762574920922405E-7
# Model iJN1463.cmd: 1.6715991041042564E-8
# Cycle 4
# Total biomass:
# Model iAF1260.cmd: 1.8748275851968402E-7
# Model iJN1463.cmd: 1.742282137640622E-8
# Cycle 5
# Total biomass:
# Model iAF1260.cmd: 1.9993916680507707E-7
# Model iJN1463.cmd: 1.8178688788179172E-8
# Cycle 6
# Total biomass:
# Model iAF1260.cmd: 2.1357208784308342E-7
# Model iJN1463.cmd: 1.8979223896376563E-8
# Cycle 7
# Total biomass:
# Model iAF1260.cmd: 2.284235280488192E-7
# Model iJN1463.cmd: 1.9825575027484213E-8
# Cycle 8
# Total biomass:
# Model iAF1260.cmd: 2.4450211637153697E-7
# Model iJN1463.cmd: 2.0718868984030987E-8
# Cycle 9
# Total biomass:
# Model iAF1260.cmd: 2.6189804181867177E-7
# Model iJN1463.cmd: 2.1661972012419717E-8
# Cycle 10
# Total biomass:
# Model iAF1260.cmd: 2.806452547939702E-7
# Model iJN1463.cmd: 2.2657641830955982E-8
# Cycle 11
# Total biomass:
# Model iAF1260.cmd: 3.007868736916104E-7
# Model iJN1463.cmd: 2.3707858685751264E-8
# Cycle 12
# Total biomass:
# Model iAF1260.cmd: 3.2242714261095223E-7
# Model iJN1463.cmd: 2.481554742072276E-8
# Cycle 13
# Total biomass:
# Model iAF1260.cmd: 3.4567853430092067E-7
# Model iJN1463.cmd: 2.5983803134509106E-8
# Cycle 14
# Total biomass:
# Model iAF1260.cmd: 3.7066256668577646E-7
# Model iJN1463.cmd: 2.721588826874758E-8
# Cycle 15
# Total biomass:
# Model iAF1260.cmd: 3.9750986699242E-7
# Model iJN1463.cmd: 2.8515241631458084E-8
# Cycle 16
# Total biomass:
# Model iAF1260.cmd: 4.2635968013862045E-7
# Model iJN1463.cmd: 2.988548792138571E-8
# Cycle 17
# Total biomass:
# Model iAF1260.cmd: 4.5735870324107677E-7
# Model iJN1463.cmd: 3.133044777537304E-8
# Cycle 18
# Total biomass:
# Model iAF1260.cmd: 4.906592530627674E-7
# Model iJN1463.cmd: 3.2854148364038606E-8
# Cycle 19
# Total biomass:
# Model iAF1260.cmd: 5.264276652131092E-7
# Model iJN1463.cmd: 3.446083456355225E-8
# Cycle 20
# Total biomass:
# Model iAF1260.cmd: 5.648509465810101E-7
# Model iJN1463.cmd: 3.615498073365528E-8
# Cycle 21
# Total biomass:
# Model iAF1260.cmd: 6.06129803394553E-7
# Model iJN1463.cmd: 3.7941303133337E-8
# Cycle 22
# Total biomass:
# Model iAF1260.cmd: 6.504797668543302E-7
# Model iJN1463.cmd: 3.9824773007923243E-8
# Cycle 23
# Total biomass:
# Model iAF1260.cmd: 6.98157750736493E-7
# Model iJN1463.cmd: 4.181063038185655E-8
# Cycle 24
# Total biomass:
# Model iAF1260.cmd: 7.493917228724468E-7
# Model iJN1463.cmd: 4.393046639161822E-8
# Cycle 25
# Total biomass:
# Model iAF1260.cmd: 8.041846773610835E-7
# Model iJN1463.cmd: 4.616514183782522E-8
# Cycle 26
# Total biomass:
# Model iAF1260.cmd: 8.617082418322568E-7
# Model iJN1463.cmd: 4.8516545864087295E-8
# Cycle 27
# Total biomass:
# Model iAF1260.cmd: 9.209109531912941E-7
# Model iJN1463.cmd: 5.0992336332027524E-8
# Cycle 28
# Total biomass:
# Model iAF1260.cmd: 9.818470728976895E-7
# Model iJN1463.cmd: 5.360172141922198E-8
# Cycle 29
# Total biomass:
# Model iAF1260.cmd: 1.044792616194893E-6
# Model iJN1463.cmd: 5.635146699087442E-8
# Cycle 30
# Total biomass:
# Model iAF1260.cmd: 1.1101601588378586E-6
# Model iJN1463.cmd: 5.9248567887605734E-8
# Cycle 31
# Total biomass:
# Model iAF1260.cmd: 1.177863106332657E-6
# Model iJN1463.cmd: 6.232586520176765E-8
# Cycle 32
# Total biomass:
# Model iAF1260.cmd: 1.247820413114712E-6
# Model iJN1463.cmd: 6.556788217783853E-8
# Cycle 33
# Total biomass:
# Model iAF1260.cmd: 1.3199021426018224E-6
# Model iJN1463.cmd: 6.900838969465146E-8
# Cycle 34
# Total biomass:
# Model iAF1260.cmd: 1.3939263333736561E-6
# Model iJN1463.cmd: 7.263159272103592E-8
# Cycle 35
# Total biomass:
# Model iAF1260.cmd: 1.469833275623217E-6
# Model iJN1463.cmd: 7.644513996962339E-8
# Cycle 36
# Total biomass:
# Model iAF1260.cmd: 1.5475690018220765E-6
# Model iJN1463.cmd: 8.045624472543116E-8
# Cycle 37
# Total biomass:
# Model iAF1260.cmd: 1.6276629313262822E-6
# Model iJN1463.cmd: 8.467157080636404E-8
# Cycle 38
# Total biomass:
# Model iAF1260.cmd: 1.709695343993185E-6
# Model iJN1463.cmd: 8.90962813555565E-8
# Cycle 39
# Total biomass:
# Model iAF1260.cmd: 1.7914640731604426E-6
# Model iJN1463.cmd: 9.371568206549595E-8
# Cycle 40
# Total biomass:
# Model iAF1260.cmd: 1.8735300224637435E-6
# Model iJN1463.cmd: 9.848224362715077E-8
# Cycle 41
# Total biomass:
# Model iAF1260.cmd: 1.9562932304884627E-6
# Model iJN1463.cmd: 1.0340455428546027E-7
# Cycle 42
# Total biomass:
# Model iAF1260.cmd: 2.0398419019655305E-6
# Model iJN1463.cmd: 1.0847722114761981E-7
# Cycle 43
# Total biomass:
# Model iAF1260.cmd: 2.124519261460656E-6
# Model iJN1463.cmd: 1.1381640522049038E-7
# Cycle 44
# Total biomass:
# Model iAF1260.cmd: 2.2107427718641897E-6
# Model iJN1463.cmd: 1.1926906240298235E-7
# Cycle 45
# Total biomass:
# Model iAF1260.cmd: 2.2985960544623654E-6
# Model iJN1463.cmd: 1.2515884249818817E-7
# Cycle 46
# Total biomass:
# Model iAF1260.cmd: 2.3881700614207628E-6
# Model iJN1463.cmd: 1.3122585127640898E-7
# Cycle 47
# Total biomass:
# Model iAF1260.cmd: 2.47962179300539E-6
# Model iJN1463.cmd: 1.377899979143362E-7
# Cycle 48
# Total biomass:
# Model iAF1260.cmd: 2.5730642019392177E-6
# Model iJN1463.cmd: 1.4474597841189268E-7
# Cycle 49
# Total biomass:
# Model iAF1260.cmd: 2.6687678176842754E-6
# Model iJN1463.cmd: 1.5202265525940413E-7
# Cycle 50
# Total biomass:
# Model iAF1260.cmd: 2.7666904668682563E-6
# Model iJN1463.cmd: 1.5963881840833316E-7
# Cycle 51
# Total biomass:
# Model iAF1260.cmd: 2.8669895206662845E-6
# Model iJN1463.cmd: 1.6761310624206856E-7
# Cycle 52
# Total biomass:
# Model iAF1260.cmd: 2.9698663184291333E-6
# Model iJN1463.cmd: 1.7596831686338123E-7
# Cycle 53
# Total biomass:
# Model iAF1260.cmd: 3.0753658664805276E-6
# Model iJN1463.cmd: 1.847171311693432E-7
# Cycle 54
# Total biomass:
# Model iAF1260.cmd: 3.1831861815271057E-6
# Model iJN1463.cmd: 1.9388197666717043E-7
# Cycle 55
# Total biomass:
# Model iAF1260.cmd: 3.2934115778150156E-6
# Model iJN1463.cmd: 2.0348399352884452E-7
# Cycle 56
# Total biomass:
# Model iAF1260.cmd: 3.4063486294557867E-6
# Model iJN1463.cmd: 2.1354210735891328E-7
# Cycle 57
# Total biomass:
# Model iAF1260.cmd: 3.5221608860822597E-6
# Model iJN1463.cmd: 2.240735659477922E-7
# Cycle 58
# Total biomass:
# Model iAF1260.cmd: 3.641047593641193E-6
# Model iJN1463.cmd: 2.350952989308738E-7
# Cycle 59
# Total biomass:
# Model iAF1260.cmd: 3.7632207539476643E-6
# Model iJN1463.cmd: 2.466269257687776E-7
# Cycle 60
# Total biomass:
# Model iAF1260.cmd: 3.888792242929291E-6
# Model iJN1463.cmd: 2.5868993060806685E-7
# Cycle 61
# Total biomass:
# Model iAF1260.cmd: 4.017703447157703E-6
# Model iJN1463.cmd: 2.713057313403024E-7
# Cycle 62
# Total biomass:
# Model iAF1260.cmd: 4.149473777580765E-6
# Model iJN1463.cmd: 2.846684737859469E-7
# Cycle 63
# Total biomass:
# Model iAF1260.cmd: 4.2841808314433235E-6
# Model iJN1463.cmd: 2.9872611671204276E-7
# Cycle 64
# Total biomass:
# Model iAF1260.cmd: 4.421686118933297E-6
# Model iJN1463.cmd: 3.1357066027993606E-7
# Cycle 65
# Total biomass:
# Model iAF1260.cmd: 4.562297820655362E-6
# Model iJN1463.cmd: 3.290903010149502E-7
# Cycle 66
# Total biomass:
# Model iAF1260.cmd: 4.706144252011477E-6
# Model iJN1463.cmd: 3.453257445601122E-7
# Cycle 67
# Total biomass:
# Model iAF1260.cmd: 4.853214139983136E-6
# Model iJN1463.cmd: 3.6230785049073304E-7
# Cycle 68
# Total biomass:
# Model iAF1260.cmd: 5.00372348787959E-6
# Model iJN1463.cmd: 3.800772796656935E-7
# Cycle 69
# Total biomass:
# Model iAF1260.cmd: 5.157523692999505E-6
# Model iJN1463.cmd: 3.9863519113137523E-7
# Cycle 70
# Total biomass:
# Model iAF1260.cmd: 5.314563381410902E-6
# Model iJN1463.cmd: 4.1801870091779935E-7
# Cycle 71
# Total biomass:
# Model iAF1260.cmd: 5.475057277012389E-6
# Model iJN1463.cmd: 4.3814494813305213E-7
# Cycle 72
# Total biomass:
# Model iAF1260.cmd: 5.639171370696959E-6
# Model iJN1463.cmd: 4.5918198867541166E-7
# Cycle 73
# Total biomass:
# Model iAF1260.cmd: 5.806218250543799E-6
# Model iJN1463.cmd: 4.811707035242157E-7
# Cycle 74
# Total biomass:
# Model iAF1260.cmd: 5.97624949599295E-6
# Model iJN1463.cmd: 5.041193526253045E-7
# Cycle 75
# Total biomass:
# Model iAF1260.cmd: 6.149691445774042E-6
# Model iJN1463.cmd: 5.280834672962501E-7
# Cycle 76
# Total biomass:
# Model iAF1260.cmd: 6.3266828723360405E-6
# Model iJN1463.cmd: 5.530756045313317E-7
# Cycle 77
# Total biomass:
# Model iAF1260.cmd: 6.506490008116639E-6
# Model iJN1463.cmd: 5.79282383962791E-7
# Cycle 78
# Total biomass:
# Model iAF1260.cmd: 6.689235380841114E-6
# Model iJN1463.cmd: 6.067398736653093E-7
# Cycle 79
# Total biomass:
# Model iAF1260.cmd: 6.874886090664147E-6
# Model iJN1463.cmd: 6.354144840178749E-7
# Cycle 80
# Total biomass:
# Model iAF1260.cmd: 7.065354709299966E-6
# Model iJN1463.cmd: 6.649924512098328E-7
# Cycle 81
# Total biomass:
# Model iAF1260.cmd: 7.25832121809532E-6
# Model iJN1463.cmd: 6.960131388896751E-7
# Cycle 82
# Total biomass:
# Model iAF1260.cmd: 7.45372094692094E-6
# Model iJN1463.cmd: 7.281196662261339E-7
# Cycle 83
# Total biomass:
# Model iAF1260.cmd: 7.651321776931348E-6
# Model iJN1463.cmd: 7.617386348194035E-7
# Cycle 84
# Total biomass:
# Model iAF1260.cmd: 7.851403764026048E-6
# Model iJN1463.cmd: 7.969422776343618E-7
# Cycle 85
# Total biomass:
# Model iAF1260.cmd: 8.054414956517992E-6
# Model iJN1463.cmd: 8.336114938665724E-7
# Cycle 86
# Total biomass:
# Model iAF1260.cmd: 8.26045436669788E-6
# Model iJN1463.cmd: 8.718995102960392E-7
# Cycle 87
# Total biomass:
# Model iAF1260.cmd: 8.469606687025141E-6
# Model iJN1463.cmd: 9.119331820372303E-7
# Cycle 88
# Total biomass:
# Model iAF1260.cmd: 8.681877054443518E-6
# Model iJN1463.cmd: 9.536911087404855E-7
# Cycle 89
# Total biomass:
# Model iAF1260.cmd: 8.897410306496722E-6
# Model iJN1463.cmd: 9.972458818881672E-7
# Cycle 90
# Total biomass:
# Model iAF1260.cmd: 9.116302708649107E-6
# Model iJN1463.cmd: 1.0426595530367705E-6
# Cycle 91
# Total biomass:
# Model iAF1260.cmd: 9.338706434358947E-6
# Model iJN1463.cmd: 1.0899918410328006E-6
# Cycle 92
# Total biomass:
# Model iAF1260.cmd: 9.564734363846152E-6
# Model iJN1463.cmd: 1.1393070411072442E-6
# Cycle 93
# Total biomass:
# Model iAF1260.cmd: 9.79451966488319E-6
# Model iJN1463.cmd: 1.1907198012278699E-6
# Cycle 94
# Total biomass:
# Model iAF1260.cmd: 1.002819180928075E-5
# Model iJN1463.cmd: 1.2443619875134845E-6
# Cycle 95
# Total biomass:
# Model iAF1260.cmd: 1.0267483726811936E-5
# Model iJN1463.cmd: 1.3003497368577442E-6
# Cycle 96
# Total biomass:
# Model iAF1260.cmd: 1.0511799052208552E-5
# Model iJN1463.cmd: 1.3587615472379766E-6
# Cycle 97
# Total biomass:
# Model iAF1260.cmd: 1.0761758675214534E-5
# Model iJN1463.cmd: 1.4194287143073388E-6
# Cycle 98
# Total biomass:
# Model iAF1260.cmd: 1.1015632967771105E-5
# Model iJN1463.cmd: 1.4826665246928729E-6
# Cycle 99
# Total biomass:
# Model iAF1260.cmd: 1.1273095347789004E-5
# Model iJN1463.cmd: 1.5485069987942493E-6
# Cycle 100
# Total biomass:
# Model iAF1260.cmd: 1.15345582908045E-5
# Model iJN1463.cmd: 1.6169106295668085E-6
# Cycle 101
# Total biomass:
# Model iAF1260.cmd: 1.1801053049778462E-5
# Model iJN1463.cmd: 1.6879205840018333E-6
# Cycle 102
# Total biomass:
# Model iAF1260.cmd: 1.2073112848575864E-5
# Model iJN1463.cmd: 1.7616587854918586E-6
# Cycle 103
# Total biomass:
# Model iAF1260.cmd: 1.2349709096812621E-5
# Model iJN1463.cmd: 1.83828728863323E-6
# Cycle 104
# Total biomass:
# Model iAF1260.cmd: 1.263012699125713E-5
# Model iJN1463.cmd: 1.9179904131445554E-6
# Cycle 105
# Total biomass:
# Model iAF1260.cmd: 1.2914178432967265E-5
# Model iJN1463.cmd: 2.001380080297491E-6
# Cycle 106
# Total biomass:
# Model iAF1260.cmd: 1.3203617268960257E-5
# Model iJN1463.cmd: 2.08820002294897E-6
# Cycle 107
# Total biomass:
# Model iAF1260.cmd: 1.3499354894282199E-5
# Model iJN1463.cmd: 2.178113290287423E-6
# Cycle 108
# Total biomass:
# Model iAF1260.cmd: 1.3799102140470411E-5
# Model iJN1463.cmd: 2.27194234527227E-6
# Cycle 109
# Total biomass:
# Model iAF1260.cmd: 1.410389402342966E-5
# Model iJN1463.cmd: 2.3694747949513656E-6
# Cycle 110
# Total biomass:
# Model iAF1260.cmd: 1.4415142221814632E-5
# Model iJN1463.cmd: 2.4706089926610975E-6
# Cycle 111
# Total biomass:
# Model iAF1260.cmd: 1.4732532260816053E-5
# Model iJN1463.cmd: 2.5757533947438797E-6
# Cycle 112
# Total biomass:
# Model iAF1260.cmd: 1.5055586293751004E-5
# Model iJN1463.cmd: 2.685131290094784E-6
# Cycle 113
# Total biomass:
# Model iAF1260.cmd: 1.5383309631226805E-5
# Model iJN1463.cmd: 2.7993353872477497E-6
# Cycle 114
# Total biomass:
# Model iAF1260.cmd: 1.5716377765073607E-5
# Model iJN1463.cmd: 2.9179646901389594E-6
# Cycle 115
# Total biomass:
# Model iAF1260.cmd: 1.605327909379021E-5
# Model iJN1463.cmd: 3.041440321682789E-6
# Cycle 116
# Total biomass:
# Model iAF1260.cmd: 1.639306980959996E-5
# Model iJN1463.cmd: 3.1697167291583743E-6
# Cycle 117
# Total biomass:
# Model iAF1260.cmd: 1.6733502565629578E-5
# Model iJN1463.cmd: 3.3029898908526652E-6
# Cycle 118
# Total biomass:
# Model iAF1260.cmd: 1.7070146850474107E-5
# Model iJN1463.cmd: 3.4414995857484405E-6
# Cycle 119
# Total biomass:
# Model iAF1260.cmd: 1.7396361088198253E-5
# Model iJN1463.cmd: 3.5851753482537956E-6
# Cycle 120
# Total biomass:
# Model iAF1260.cmd: 1.7710265235812404E-5
# Model iJN1463.cmd: 3.7345147630478576E-6
# Cycle 121
# Total biomass:
# Model iAF1260.cmd: 1.8008845978587185E-5
# Model iJN1463.cmd: 3.889392021936346E-6
# Cycle 122
# Total biomass:
# Model iAF1260.cmd: 1.8289267028623026E-5
# Model iJN1463.cmd: 4.0501367449157306E-6
# Cycle 123
# Total biomass:
# Model iAF1260.cmd: 1.8550213041928696E-5
# Model iJN1463.cmd: 4.2169617687556625E-6
# Cycle 124
# Total biomass:
# Model iAF1260.cmd: 1.8791332447202908E-5
# Model iJN1463.cmd: 4.389763676037489E-6
# Cycle 125
# Total biomass:
# Model iAF1260.cmd: 1.901445556001887E-5
# Model iJN1463.cmd: 4.5690291544904815E-6
# Cycle 126
# Total biomass:
# Model iAF1260.cmd: 1.9224814356207195E-5
# Model iJN1463.cmd: 4.75467488230737E-6
# Cycle 127
# Total biomass:
# Model iAF1260.cmd: 1.942293739275577E-5
# Model iJN1463.cmd: 4.946871605030695E-6
# Cycle 128
# Total biomass:
# Model iAF1260.cmd: 1.9610275873254135E-5
# Model iJN1463.cmd: 5.1463334744277206E-6
# Cycle 129
# Total biomass:
# Model iAF1260.cmd: 1.978835484932757E-5
# Model iJN1463.cmd: 5.352876849496902E-6
# Cycle 130
# Total biomass:
# Model iAF1260.cmd: 1.99588958705443E-5
# Model iJN1463.cmd: 5.566755477878913E-6
# Cycle 131
# Total biomass:
# Model iAF1260.cmd: 2.0123825206640366E-5
# Model iJN1463.cmd: 5.787819988138782E-6
# Cycle 132
# Total biomass:
# Model iAF1260.cmd: 2.0285737257484608E-5
# Model iJN1463.cmd: 6.0163946658213E-6
# Cycle 133
# Total biomass:
# Model iAF1260.cmd: 2.0444666942351636E-5
# Model iJN1463.cmd: 6.252517479556715E-6
# Cycle 134
# Total biomass:
# Model iAF1260.cmd: 2.0601506743677993E-5
# Model iJN1463.cmd: 6.495619789978529E-6
# Cycle 135
# Total biomass:
# Model iAF1260.cmd: 2.075650578660244E-5
# Model iJN1463.cmd: 6.744946071911301E-6
# Cycle 136
# Total biomass:
# Model iAF1260.cmd: 2.0910631532811162E-5
# Model iJN1463.cmd: 6.998826512608784E-6
# Cycle 137
# Total biomass:
# Model iAF1260.cmd: 2.1063687719557017E-5
# Model iJN1463.cmd: 7.256521570089226E-6
# Cycle 138
# Total biomass:
# Model iAF1260.cmd: 2.1214756420155503E-5
# Model iJN1463.cmd: 7.5168239388402575E-6
# Cycle 139
# Total biomass:
# Model iAF1260.cmd: 2.1366144629446062E-5
# Model iJN1463.cmd: 7.776140764920353E-6
# Cycle 140
# Total biomass:
# Model iAF1260.cmd: 2.1515542112528804E-5
# Model iJN1463.cmd: 8.032765412529289E-6
# Cycle 141
# Total biomass:
# Model iAF1260.cmd: 2.1665035816644088E-5
# Model iJN1463.cmd: 8.284747348288876E-6
# Cycle 142
# Total biomass:
# Model iAF1260.cmd: 2.181445671683294E-5
# Model iJN1463.cmd: 8.532235114998494E-6
# Cycle 143
# Total biomass:
# Model iAF1260.cmd: 2.19644336507319E-5
# Model iJN1463.cmd: 8.772303000769832E-6
# Cycle 144
# Total biomass:
# Model iAF1260.cmd: 2.211292781921984E-5
# Model iJN1463.cmd: 9.004599825151971E-6
# Cycle 145
# Total biomass:
# Model iAF1260.cmd: 2.2259829379045356E-5
# Model iJN1463.cmd: 9.229405842760871E-6
# Cycle 146
# Total biomass:
# Model iAF1260.cmd: 2.2406841580688315E-5
# Model iJN1463.cmd: 9.442141837185203E-6
# Cycle 147
# Total biomass:
# Model iAF1260.cmd: 2.2554924329462147E-5
# Model iJN1463.cmd: 9.635716581900895E-6
# Cycle 148
# Total biomass:
# Model iAF1260.cmd: 2.2703043745813347E-5
# Model iJN1463.cmd: 9.811845074329606E-6
# Cycle 149
# Total biomass:
# Model iAF1260.cmd: 2.2851275114399163E-5
# Model iJN1463.cmd: 9.971863552696344E-6
# Cycle 150
# Total biomass:
# Model iAF1260.cmd: 2.2998395516252815E-5
# Model iJN1463.cmd: 1.0118327320703077E-5
# Cycle 151
# Total biomass:
# Model iAF1260.cmd: 2.3144663674620144E-5
# Model iJN1463.cmd: 1.0253803096113472E-5
# Cycle 152
# Total biomass:
# Model iAF1260.cmd: 2.3290885883932708E-5
# Model iJN1463.cmd: 1.0379091713699264E-5
# Cycle 153
# Total biomass:
# Model iAF1260.cmd: 2.3436369188858555E-5
# Model iJN1463.cmd: 1.04959202248521E-5
# Cycle 154
# Total biomass:
# Model iAF1260.cmd: 2.358155870807036E-5
# Model iJN1463.cmd: 1.0606094321597331E-5
# Cycle 155
# Total biomass:
# Model iAF1260.cmd: 2.3726110222682502E-5
# Model iJN1463.cmd: 1.071203670568712E-5
# Cycle 156
# Total biomass:
# Model iAF1260.cmd: 2.386976272344845E-5
# Model iJN1463.cmd: 1.0815110795773878E-5
# Cycle 157
# Total biomass:
# Model iAF1260.cmd: 2.4013132316080454E-5
# Model iJN1463.cmd: 1.0916124885369084E-5
# Cycle 158
# Total biomass:
# Model iAF1260.cmd: 2.41558245549341E-5
# Model iJN1463.cmd: 1.1016259080923847E-5
# Cycle 159
# Total biomass:
# Model iAF1260.cmd: 2.429819448584226E-5
# Model iJN1463.cmd: 1.1116047222469907E-5
# Cycle 160
# Total biomass:
# Model iAF1260.cmd: 2.4440087528150014E-5
# Model iJN1463.cmd: 1.1214947476169431E-5
# Cycle 161
# Total biomass:
# Model iAF1260.cmd: 2.4581050267064868E-5
# Model iJN1463.cmd: 1.1312786416862946E-5
# Cycle 162
# Total biomass:
# Model iAF1260.cmd: 2.4720630219604442E-5
# Model iJN1463.cmd: 1.1411190413161165E-5
# Cycle 163
# Total biomass:
# Model iAF1260.cmd: 2.4859163036061126E-5
# Model iJN1463.cmd: 1.1509757324322285E-5
# Cycle 164
# Total biomass:
# Model iAF1260.cmd: 2.499793122782329E-5
# Model iJN1463.cmd: 1.1608409466513035E-5
# Cycle 165
# Total biomass:
# Model iAF1260.cmd: 2.513489186993532E-5
# Model iJN1463.cmd: 1.1706484512247518E-5
# Cycle 166
# Total biomass:
# Model iAF1260.cmd: 2.5270907617184575E-5
# Model iJN1463.cmd: 1.1805935245904038E-5
# Cycle 167
# Total biomass:
# Model iAF1260.cmd: 2.5406272826096683E-5
# Model iJN1463.cmd: 1.1906326573038545E-5
# Cycle 168
# Total biomass:
# Model iAF1260.cmd: 2.554095414432824E-5
# Model iJN1463.cmd: 1.2006922622153107E-5
# Cycle 169
# Total biomass:
# Model iAF1260.cmd: 2.5674965812531843E-5
# Model iJN1463.cmd: 1.2108076792948463E-5
# Cycle 170
# Total biomass:
# Model iAF1260.cmd: 2.5807852780465474E-5
# Model iJN1463.cmd: 1.2209466064856211E-5
# Cycle 171
# Total biomass:
# Model iAF1260.cmd: 2.5940022870455633E-5
# Model iJN1463.cmd: 1.2311562712248354E-5
# Cycle 172
# Total biomass:
# Model iAF1260.cmd: 2.6071648562564068E-5
# Model iJN1463.cmd: 1.241383452051474E-5
# Cycle 173
# Total biomass:
# Model iAF1260.cmd: 2.6203467924183907E-5
# Model iJN1463.cmd: 1.251619601077177E-5
# Cycle 174
# Total biomass:
# Model iAF1260.cmd: 2.6335162175723776E-5
# Model iJN1463.cmd: 1.2618190832003938E-5
# Cycle 175
# Total biomass:
# Model iAF1260.cmd: 2.646626060978652E-5
# Model iJN1463.cmd: 1.2721280500678637E-5
# Cycle 176
# Total biomass:
# Model iAF1260.cmd: 2.6598722737606818E-5
# Model iJN1463.cmd: 1.2822690753172667E-5
# Cycle 177
# Total biomass:
# Model iAF1260.cmd: 2.6732542992487868E-5
# Model iJN1463.cmd: 1.2923492376619648E-5
# Cycle 178
# Total biomass:
# Model iAF1260.cmd: 2.6865012468463336E-5
# Model iJN1463.cmd: 1.3025663624248529E-5
# Cycle 179
# Total biomass:
# Model iAF1260.cmd: 2.699648606364573E-5
# Model iJN1463.cmd: 1.3128648422562384E-5
# Cycle 180
# Total biomass:
# Model iAF1260.cmd: 2.7128929543016163E-5
# Model iJN1463.cmd: 1.3229692495659067E-5
# Cycle 181
# Total biomass:
# Model iAF1260.cmd: 2.7261098045999476E-5
# Model iJN1463.cmd: 1.3331042222126818E-5
# Cycle 182
# Total biomass:
# Model iAF1260.cmd: 2.7393094952168924E-5
# Model iJN1463.cmd: 1.343308857198705E-5
# Cycle 183
# Total biomass:
# Model iAF1260.cmd: 2.752495159596488E-5
# Model iJN1463.cmd: 1.3535560273061469E-5
# Cycle 184
# Total biomass:
# Model iAF1260.cmd: 2.765622843784038E-5
# Model iJN1463.cmd: 1.3638153526234488E-5
# Cycle 185
# Total biomass:
# Model iAF1260.cmd: 2.7787701870858023E-5
# Model iJN1463.cmd: 1.3740525928657496E-5
# Cycle 186
# Total biomass:
# Model iAF1260.cmd: 2.791930479281882E-5
# Model iJN1463.cmd: 1.3842623921728932E-5
# Cycle 187
# Total biomass:
# Model iAF1260.cmd: 2.805023402312918E-5
# Model iJN1463.cmd: 1.3945177724958175E-5
# Cycle 188
# Total biomass:
# Model iAF1260.cmd: 2.817980358251872E-5
# Model iJN1463.cmd: 1.4049004128397721E-5
# Cycle 189
# Total biomass:
# Model iAF1260.cmd: 2.8309160848420364E-5
# Model iJN1463.cmd: 1.4152857885882344E-5
# Cycle 190
# Total biomass:
# Model iAF1260.cmd: 2.8439619518299494E-5
# Model iJN1463.cmd: 1.4256004959609887E-5
# Cycle 191
# Total biomass:
# Model iAF1260.cmd: 2.8569980151176514E-5
# Model iJN1463.cmd: 1.4359055460243586E-5
# Cycle 192
# Total biomass:
# Model iAF1260.cmd: 2.8700108111730827E-5
# Model iJN1463.cmd: 1.4461694908817864E-5
# Cycle 193
# Total biomass:
# Model iAF1260.cmd: 2.882854129378959E-5
# Model iJN1463.cmd: 1.4564849656041777E-5
# Cycle 194
# Total biomass:
# Model iAF1260.cmd: 2.8958077109848688E-5
# Model iJN1463.cmd: 1.4669012790853759E-5
# Cycle 195
# Total biomass:
# Model iAF1260.cmd: 2.9086188934177245E-5
# Model iJN1463.cmd: 1.4773462262868015E-5
# Cycle 196
# Total biomass:
# Model iAF1260.cmd: 2.9213771578188985E-5
# Model iJN1463.cmd: 1.4878230643964917E-5
# Cycle 197
# Total biomass:
# Model iAF1260.cmd: 2.934189952539945E-5
# Model iJN1463.cmd: 1.4982550947149515E-5
# Cycle 198
# Total biomass:
# Model iAF1260.cmd: 2.947012151348924E-5
# Model iJN1463.cmd: 1.5086013019264426E-5
# Cycle 199
# Total biomass:
# Model iAF1260.cmd: 2.9598469014873963E-5
# Model iJN1463.cmd: 1.5189034726124833E-5
# Cycle 200
# Total biomass:
# Model iAF1260.cmd: 2.972698137319215E-5
# Model iJN1463.cmd: 1.5292036174917617E-5
# Cycle 201
# Total biomass:
# Model iAF1260.cmd: 2.9855323176737502E-5
# Model iJN1463.cmd: 1.539541871925067E-5
# Cycle 202
# Total biomass:
# Model iAF1260.cmd: 2.9983714977766798E-5
# Model iJN1463.cmd: 1.549895242782989E-5
# Cycle 203
# Total biomass:
# Model iAF1260.cmd: 3.0112161966403162E-5
# Model iJN1463.cmd: 1.5601902551688424E-5
# Cycle 204
# Total biomass:
# Model iAF1260.cmd: 3.0240518574807148E-5
# Model iJN1463.cmd: 1.570435262143593E-5
# Cycle 205
# Total biomass:
# Model iAF1260.cmd: 3.0368587793249984E-5
# Model iJN1463.cmd: 1.5806781364337013E-5
# Cycle 206
# Total biomass:
# Model iAF1260.cmd: 3.0496430438539928E-5
# Model iJN1463.cmd: 1.5909381527310826E-5
# Cycle 207
# Total biomass:
# Model iAF1260.cmd: 3.062403521716778E-5
# Model iJN1463.cmd: 1.601214440167563E-5
# Cycle 208
# Total biomass:
# Model iAF1260.cmd: 3.075133032546829E-5
# Model iJN1463.cmd: 1.6114294784181574E-5
# Cycle 209
# Total biomass:
# Model iAF1260.cmd: 3.0878361636289604E-5
# Model iJN1463.cmd: 1.621669384313888E-5
# Cycle 210
# Total biomass:
# Model iAF1260.cmd: 3.100517409799396E-5
# Model iJN1463.cmd: 1.6319237247163685E-5
# Cycle 211
# Total biomass:
# Model iAF1260.cmd: 3.1131687362908674E-5
# Model iJN1463.cmd: 1.6421454638546358E-5
# Cycle 212
# Total biomass:
# Model iAF1260.cmd: 3.125795586393689E-5
# Model iJN1463.cmd: 1.6523703023623207E-5
# Cycle 213
# Total biomass:
# Model iAF1260.cmd: 3.13818214622463E-5
# Model iJN1463.cmd: 1.6627558071657474E-5
# Cycle 214
# Total biomass:
# Model iAF1260.cmd: 3.150689769958031E-5
# Model iJN1463.cmd: 1.6730503165735664E-5
# Cycle 215
# Total biomass:
# Model iAF1260.cmd: 3.163213678269893E-5
# Model iJN1463.cmd: 1.6833257576107276E-5
# Cycle 216
# Total biomass:
# Model iAF1260.cmd: 3.1757413564516936E-5
# Model iJN1463.cmd: 1.6936246911823773E-5
# Cycle 217
# Total biomass:
# Model iAF1260.cmd: 3.18827272202424E-5
# Model iJN1463.cmd: 1.703918526394909E-5
# Cycle 218
# Total biomass:
# Model iAF1260.cmd: 3.200788979487783E-5
# Model iJN1463.cmd: 1.714202217602006E-5
# Cycle 219
# Total biomass:
# Model iAF1260.cmd: 3.2132944084504044E-5
# Model iJN1463.cmd: 1.724373966478225E-5
# Cycle 220
# Total biomass:
# Model iAF1260.cmd: 3.225785584095687E-5
# Model iJN1463.cmd: 1.734549846495815E-5
# Cycle 221
# Total biomass:
# Model iAF1260.cmd: 3.238266098804124E-5
# Model iJN1463.cmd: 1.7447259685260906E-5
# Cycle 222
# Total biomass:
# Model iAF1260.cmd: 3.250739074623883E-5
# Model iJN1463.cmd: 1.7549064483451328E-5
# Cycle 223
# Total biomass:
# Model iAF1260.cmd: 3.26320304300389E-5
# Model iJN1463.cmd: 1.76500169875208E-5
# Cycle 224
# Total biomass:
# Model iAF1260.cmd: 3.2756585797516577E-5
# Model iJN1463.cmd: 1.774987081840818E-5
# Cycle 225
# Total biomass:
# Model iAF1260.cmd: 3.287911784939525E-5
# Model iJN1463.cmd: 1.7851512586688792E-5
# Cycle 226
# Total biomass:
# Model iAF1260.cmd: 3.2999795649759016E-5
# Model iJN1463.cmd: 1.7954921226207918E-5
# Cycle 227
# Total biomass:
# Model iAF1260.cmd: 3.311963722293568E-5
# Model iJN1463.cmd: 1.805876439679063E-5
# Cycle 228
# Total biomass:
# Model iAF1260.cmd: 3.323876352495239E-5
# Model iJN1463.cmd: 1.816299207461522E-5
# Cycle 229
# Total biomass:
# Model iAF1260.cmd: 3.3357402989389105E-5
# Model iJN1463.cmd: 1.8267509008332235E-5
# Cycle 230
# Total biomass:
# Model iAF1260.cmd: 3.347613513685144E-5
# Model iJN1463.cmd: 1.8372143425874658E-5
# Cycle 231
# Total biomass:
# Model iAF1260.cmd: 3.359509261514356E-5
# Model iJN1463.cmd: 1.8476307468314363E-5
# Cycle 232
# Total biomass:
# Model iAF1260.cmd: 3.371429353777952E-5
# Model iJN1463.cmd: 1.8580703610033557E-5
# Cycle 233
# Total biomass:
# Model iAF1260.cmd: 3.383515303405215E-5
# Model iJN1463.cmd: 1.8682973409732083E-5
# Cycle 234
# Total biomass:
# Model iAF1260.cmd: 3.395449883679293E-5
# Model iJN1463.cmd: 1.878635390860185E-5
# Cycle 235
# Total biomass:
# Model iAF1260.cmd: 3.4072508598253846E-5
# Model iJN1463.cmd: 1.8889790396036878E-5
# Cycle 236
# Total biomass:
# Model iAF1260.cmd: 3.418868876426922E-5
# Model iJN1463.cmd: 1.899434892164073E-5
# Cycle 237
# Total biomass:
# Model iAF1260.cmd: 3.430447246487719E-5
# Model iJN1463.cmd: 1.909848142389346E-5
# Cycle 238
# Total biomass:
# Model iAF1260.cmd: 3.441968494245096E-5
# Model iJN1463.cmd: 1.9202756207685233E-5
# Cycle 239
# Total biomass:
# Model iAF1260.cmd: 3.4536146319119773E-5
# Model iJN1463.cmd: 1.9306123934276823E-5
# Cycle 240
# Total biomass:
# Model iAF1260.cmd: 3.465213780637563E-5
# Model iJN1463.cmd: 1.9409418838977E-5
# Cycle 241
# Total biomass:
# Model iAF1260.cmd: 3.4768408125359134E-5
# Model iJN1463.cmd: 1.9512509898786262E-5
# Cycle 242
# Total biomass:
# Model iAF1260.cmd: 3.4884127092423953E-5
# Model iJN1463.cmd: 1.9615455501989904E-5
# Cycle 243
# Total biomass:
# Model iAF1260.cmd: 3.499994576619459E-5
# Model iJN1463.cmd: 1.971818718431381E-5
# Cycle 244
# Total biomass:
# Model iAF1260.cmd: 3.511624370375235E-5
# Model iJN1463.cmd: 1.982068425654773E-5
# Cycle 245
# Total biomass:
# Model iAF1260.cmd: 3.5232490461424774E-5
# Model iJN1463.cmd: 1.99220433647415E-5
# Cycle 246
# Total biomass:
# Model iAF1260.cmd: 3.5348177979275185E-5
# Model iJN1463.cmd: 2.0023573872950348E-5
# Cycle 247
# Total biomass:
# Model iAF1260.cmd: 3.546359639315029E-5
# Model iJN1463.cmd: 2.0124970167124448E-5
# Cycle 248
# Total biomass:
# Model iAF1260.cmd: 3.557887537652893E-5
# Model iJN1463.cmd: 2.0226288136434077E-5
# Cycle 249
# Total biomass:
# Model iAF1260.cmd: 3.569824494941152E-5
# Model iJN1463.cmd: 2.0323434469420336E-5
# Cycle 250
# Total biomass:
# Model iAF1260.cmd: 3.581773626386703E-5
# Model iJN1463.cmd: 2.0420237576216398E-5
# Cycle 251
# Total biomass:
# Model iAF1260.cmd: 3.593840928179897E-5
# Model iJN1463.cmd: 2.051579708221582E-5
# Cycle 252
# Total biomass:
# Model iAF1260.cmd: 3.6059438227067815E-5
# Model iJN1463.cmd: 2.061088300096505E-5
# Cycle 253
# Total biomass:
# Model iAF1260.cmd: 3.6180569553322015E-5
# Model iJN1463.cmd: 2.0705689883938017E-5
# Cycle 254
# Total biomass:
# Model iAF1260.cmd: 3.630157505245285E-5
# Model iJN1463.cmd: 2.079995150427899E-5
# Cycle 255
# Total biomass:
# Model iAF1260.cmd: 3.64224164077083E-5
# Model iJN1463.cmd: 2.0893900006023617E-5
# Cycle 256
# Total biomass:
# Model iAF1260.cmd: 3.6543124294770364E-5
# Model iJN1463.cmd: 2.098762241319985E-5
# Cycle 257
# Total biomass:
# Model iAF1260.cmd: 3.666377582629176E-5
# Model iJN1463.cmd: 2.1081112708482508E-5
# Cycle 258
# Total biomass:
# Model iAF1260.cmd: 3.6784217339559726E-5
# Model iJN1463.cmd: 2.1174425175242945E-5
# Cycle 259
# Total biomass:
# Model iAF1260.cmd: 3.690462585764599E-5
# Model iJN1463.cmd: 2.1267485899233563E-5
# Cycle 260
# Total biomass:
# Model iAF1260.cmd: 3.702493737954195E-5
# Model iJN1463.cmd: 2.1360350802730864E-5
# Cycle 261
# Total biomass:
# Model iAF1260.cmd: 3.7145118198143836E-5
# Model iJN1463.cmd: 2.1453116193692583E-5
# Cycle 262
# Total biomass:
# Model iAF1260.cmd: 3.726510788811136E-5
# Model iJN1463.cmd: 2.1546106037927537E-5
# Cycle 263
# Total biomass:
# Model iAF1260.cmd: 3.7384657952989136E-5
# Model iJN1463.cmd: 2.16389032594988E-5
# Cycle 264
# Total biomass:
# Model iAF1260.cmd: 3.750423426201612E-5
# Model iJN1463.cmd: 2.1731334923754745E-5
# Cycle 265
# Total biomass:
# Model iAF1260.cmd: 3.7624005820901694E-5
# Model iJN1463.cmd: 2.1823951964602817E-5
# Cycle 266
# Total biomass:
# Model iAF1260.cmd: 3.7743800563392285E-5
# Model iJN1463.cmd: 2.1915525641476583E-5
# Cycle 267
# Total biomass:
# Model iAF1260.cmd: 3.7863560738325205E-5
# Model iJN1463.cmd: 2.2006869002730705E-5
# Cycle 268
# Total biomass:
# Model iAF1260.cmd: 3.798260924564112E-5
# Model iJN1463.cmd: 2.209950685765032E-5
# Cycle 269
# Total biomass:
# Model iAF1260.cmd: 3.810076312690951E-5
# Model iJN1463.cmd: 2.2192450679633648E-5
# Cycle 270
# Total biomass:
# Model iAF1260.cmd: 3.821952020366976E-5
# Model iJN1463.cmd: 2.228400694451059E-5
# Cycle 271
# Total biomass:
# Model iAF1260.cmd: 3.833845434412896E-5
# Model iJN1463.cmd: 2.237553543917714E-5
# Cycle 272
# Total biomass:
# Model iAF1260.cmd: 3.84573808770866E-5
# Model iJN1463.cmd: 2.2466675897977142E-5
# Cycle 273
# Total biomass:
# Model iAF1260.cmd: 3.857096061603244E-5
# Model iJN1463.cmd: 2.2561662762817276E-5
# Cycle 274
# Total biomass:
# Model iAF1260.cmd: 3.8682259697754234E-5
# Model iJN1463.cmd: 2.2658048608930014E-5
# Cycle 275
# Total biomass:
# Model iAF1260.cmd: 3.8798674779638236E-5
# Model iJN1463.cmd: 2.2750342624781998E-5
# Cycle 276
# Total biomass:
# Model iAF1260.cmd: 3.891179490458045E-5
# Model iJN1463.cmd: 2.2844919481252188E-5
# Cycle 277
# Total biomass:
# Model iAF1260.cmd: 3.902224470801202E-5
# Model iJN1463.cmd: 2.294124759930082E-5
# Cycle 278
# Total biomass:
# Model iAF1260.cmd: 3.9131859169783646E-5
# Model iJN1463.cmd: 2.303798588592257E-5
# Cycle 279
# Total biomass:
# Model iAF1260.cmd: 3.9240906912115566E-5
# Model iJN1463.cmd: 2.313492639566289E-5
# Cycle 280
# Total biomass:
# Model iAF1260.cmd: 3.934957985539328E-5
# Model iJN1463.cmd: 2.3232061192293376E-5
# Cycle 281
# Total biomass:
# Model iAF1260.cmd: 3.9463627195107114E-5
# Model iJN1463.cmd: 2.3325940948166722E-5
# Cycle 282
# Total biomass:
# Model iAF1260.cmd: 3.957911237487379E-5
# Model iJN1463.cmd: 2.341793944811854E-5
# Cycle 283
# Total biomass:
# Model iAF1260.cmd: 3.969504391597284E-5
# Model iJN1463.cmd: 2.3508462502228884E-5
# Cycle 284
# Total biomass:
# Model iAF1260.cmd: 3.981103424241078E-5
# Model iJN1463.cmd: 2.3598792274289292E-5
# Cycle 285
# Total biomass:
# Model iAF1260.cmd: 3.9926936553169764E-5
# Model iJN1463.cmd: 2.3688679677191113E-5
# Cycle 286
# Total biomass:
# Model iAF1260.cmd: 4.004204026617207E-5
# Model iJN1463.cmd: 2.378039199012571E-5
# Cycle 287
# Total biomass:
# Model iAF1260.cmd: 4.0156355655220647E-5
# Model iJN1463.cmd: 2.3871595079167175E-5
# Cycle 288
# Total biomass:
# Model iAF1260.cmd: 4.027041549408157E-5
# Model iJN1463.cmd: 2.3962280893975325E-5
# Cycle 289
# Total biomass:
# Model iAF1260.cmd: 4.0383296165486446E-5
# Model iJN1463.cmd: 2.4052992021249847E-5
# Cycle 290
# Total biomass:
# Model iAF1260.cmd: 4.049101411319144E-5
# Model iJN1463.cmd: 2.4147684337117E-5
# Cycle 291
# Total biomass:
# Model iAF1260.cmd: 4.05978364157185E-5
# Model iJN1463.cmd: 2.4242717920925724E-5
# Cycle 292
# Total biomass:
# Model iAF1260.cmd: 4.0704127209629415E-5
# Model iJN1463.cmd: 2.4337931126658362E-5
# Cycle 293
# Total biomass:
# Model iAF1260.cmd: 4.081285097696648E-5
# Model iJN1463.cmd: 2.443090376508617E-5
# Cycle 294
# Total biomass:
# Model iAF1260.cmd: 4.0919784365476154E-5
# Model iJN1463.cmd: 2.4526010287987847E-5
# Cycle 295
# Total biomass:
# Model iAF1260.cmd: 4.103050743348419E-5
# Model iJN1463.cmd: 2.461794011377652E-5
# Cycle 296
# Total biomass:
# Model iAF1260.cmd: 4.114061032988486E-5
# Model iJN1463.cmd: 2.4709486025283428E-5
# Cycle 297
# Total biomass:
# Model iAF1260.cmd: 4.12510054802173E-5
# Model iJN1463.cmd: 2.480134223538049E-5
# Cycle 298
# Total biomass:
# Model iAF1260.cmd: 4.1355610559606745E-5
# Model iJN1463.cmd: 2.489705402810104E-5
# Cycle 299
# Total biomass:
# Model iAF1260.cmd: 4.1463402524520334E-5
# Model iJN1463.cmd: 2.499083456456589E-5
# Cycle 300
# Total biomass:
# Model iAF1260.cmd: 4.15701504625628E-5
# Model iJN1463.cmd: 2.5085333552950588E-5
# Cycle 301
# Total biomass:
# Model iAF1260.cmd: 4.167944197221133E-5
# Model iJN1463.cmd: 2.5177856639197362E-5
# Cycle 302
# Total biomass:
# Model iAF1260.cmd: 4.178871051532155E-5
# Model iJN1463.cmd: 2.5270363926383173E-5
# Cycle 303
# Total biomass:
# Model iAF1260.cmd: 4.1897905355794805E-5
# Model iJN1463.cmd: 2.536272443618258E-5
# Cycle 304
# Total biomass:
# Model iAF1260.cmd: 4.200682150468365E-5
# Model iJN1463.cmd: 2.5454340355650612E-5
# Cycle 305
# Total biomass:
# Model iAF1260.cmd: 4.211597583219589E-5
# Model iJN1463.cmd: 2.5545449243948716E-5
# Cycle 306
# Total biomass:
# Model iAF1260.cmd: 4.221988629018566E-5
# Model iJN1463.cmd: 2.564020239339388E-5
# Cycle 307
# Total biomass:
# Model iAF1260.cmd: 4.2322731187456975E-5
# Model iJN1463.cmd: 2.5734381344228606E-5
# Cycle 308
# Total biomass:
# Model iAF1260.cmd: 4.242444913472869E-5
# Model iJN1463.cmd: 2.582897201782735E-5
# Cycle 309
# Total biomass:
# Model iAF1260.cmd: 4.252565602572665E-5
# Model iJN1463.cmd: 2.5923817354822407E-5
# Cycle 310
# Total biomass:
# Model iAF1260.cmd: 4.2626530029508606E-5
# Model iJN1463.cmd: 2.601874225404033E-5
# Cycle 311
# Total biomass:
# Model iAF1260.cmd: 4.2727110524134664E-5
# Model iJN1463.cmd: 2.611361910123106E-5
# Cycle 312
# Total biomass:
# Model iAF1260.cmd: 4.2830005582964946E-5
# Model iJN1463.cmd: 2.6205849915259083E-5
# Cycle 313
# Total biomass:
# Model iAF1260.cmd: 4.293116552890317E-5
# Model iJN1463.cmd: 2.6300037823755882E-5
# Cycle 314
# Total biomass:
# Model iAF1260.cmd: 4.303776562396267E-5
# Model iJN1463.cmd: 2.6389972204458517E-5
# Cycle 315
# Total biomass:
# Model iAF1260.cmd: 4.313949451607638E-5
# Model iJN1463.cmd: 2.648217819168456E-5
# Cycle 316
# Total biomass:
# Model iAF1260.cmd: 4.324079752400243E-5
# Model iJN1463.cmd: 2.6574403147832778E-5
# Cycle 317
# Total biomass:
# Model iAF1260.cmd: 4.3340602191786896E-5
# Model iJN1463.cmd: 2.666751721524562E-5
# Cycle 318
# Total biomass:
# Model iAF1260.cmd: 4.3447157820783E-5
# Model iJN1463.cmd: 2.6755708902718876E-5
# Cycle 319
# Total biomass:
# Model iAF1260.cmd: 4.355249349400832E-5
# Model iJN1463.cmd: 2.684436253314603E-5
# Cycle 320
# Total biomass:
# Model iAF1260.cmd: 4.3653917411965925E-5
# Model iJN1463.cmd: 2.6935609411886228E-5
# Cycle 321
# Total biomass:
# Model iAF1260.cmd: 4.375821063662513E-5
# Model iJN1463.cmd: 2.702472262312738E-5
# Cycle 322
# Total biomass:
# Model iAF1260.cmd: 4.386381745582579E-5
# Model iJN1463.cmd: 2.711218760261503E-5
# Cycle 323
# Total biomass:
# Model iAF1260.cmd: 4.396743323656826E-5
# Model iJN1463.cmd: 2.720033601715632E-5
# Cycle 324
# Total biomass:
# Model iAF1260.cmd: 4.406860862707751E-5
# Model iJN1463.cmd: 2.7290290433013235E-5
# Cycle 325
# Total biomass:
# Model iAF1260.cmd: 4.417343639965267E-5
# Model iJN1463.cmd: 2.7377139855558587E-5
# Cycle 326
# Total biomass:
# Model iAF1260.cmd: 4.427962050632112E-5
# Model iJN1463.cmd: 2.746256544863017E-5
# Cycle 327
# Total biomass:
# Model iAF1260.cmd: 4.438153686690845E-5
# Model iJN1463.cmd: 2.7550799595184327E-5
# Cycle 328
# Total biomass:
# Model iAF1260.cmd: 4.448043987595629E-5
# Model iJN1463.cmd: 2.7641121319165246E-5
# Cycle 329
# Total biomass:
# Model iAF1260.cmd: 4.4581513603174834E-5
# Model iJN1463.cmd: 2.7728940213547015E-5
# Cycle 330
# Total biomass:
# Model iAF1260.cmd: 4.468560206154467E-5
# Model iJN1463.cmd: 2.7815035977097038E-5
# Cycle 331
# Total biomass:
# Model iAF1260.cmd: 4.4791405794643824E-5
# Model iJN1463.cmd: 2.78996682961745E-5
# Cycle 332
# Total biomass:
# Model iAF1260.cmd: 4.489760611258522E-5
# Model iJN1463.cmd: 2.7983764111676543E-5
# Cycle 333
# Total biomass:
# Model iAF1260.cmd: 4.500385011137799E-5
# Model iJN1463.cmd: 2.806750878361965E-5
# Cycle 334
# Total biomass:
# Model iAF1260.cmd: 4.510518460862655E-5
# Model iJN1463.cmd: 2.8154577833456012E-5
# Cycle 335
# Total biomass:
# Model iAF1260.cmd: 4.520314150005335E-5
# Model iJN1463.cmd: 2.8244000020339866E-5
# Cycle 336
# Total biomass:
# Model iAF1260.cmd: 4.529924636045427E-5
# Model iJN1463.cmd: 2.8334569906161373E-5
# Cycle 337
# Total biomass:
# Model iAF1260.cmd: 4.5394610234173745E-5
# Model iJN1463.cmd: 2.842546135048754E-5
# Cycle 338
# Total biomass:
# Model iAF1260.cmd: 4.548946147479234E-5
# Model iJN1463.cmd: 2.851631518500505E-5
# Cycle 339
# Total biomass:
# Model iAF1260.cmd: 4.5584025836079664E-5
# Model iJN1463.cmd: 2.860715099486655E-5
# Cycle 340
# Total biomass:
# Model iAF1260.cmd: 4.56783586505745E-5
# Model iJN1463.cmd: 2.8697963761784774E-5
# Cycle 341
# Total biomass:
# Model iAF1260.cmd: 4.577246593644386E-5
# Model iJN1463.cmd: 2.8788756495722276E-5
# Cycle 342
# Total biomass:
# Model iAF1260.cmd: 4.5866327041610526E-5
# Model iJN1463.cmd: 2.8879534025108526E-5
# Cycle 343
# Total biomass:
# Model iAF1260.cmd: 4.595997679802646E-5
# Model iJN1463.cmd: 2.8970327528596525E-5
# Cycle 344
# Total biomass:
# Model iAF1260.cmd: 4.605339533706758E-5
# Model iJN1463.cmd: 2.9061075691435787E-5
# Cycle 345
# Total biomass:
# Model iAF1260.cmd: 4.614657152966356E-5
# Model iJN1463.cmd: 2.9151210026454984E-5
# Cycle 346
# Total biomass:
# Model iAF1260.cmd: 4.62394904853997E-5
# Model iJN1463.cmd: 2.9241219574119134E-5
# Cycle 347
# Total biomass:
# Model iAF1260.cmd: 4.6332203413245005E-5
# Model iJN1463.cmd: 2.9331160545614178E-5
# Cycle 348
# Total biomass:
# Model iAF1260.cmd: 4.6424694916470906E-5
# Model iJN1463.cmd: 2.9421031412554502E-5
# Cycle 349
# Total biomass:
# Model iAF1260.cmd: 4.651694860391918E-5
# Model iJN1463.cmd: 2.9510188098055852E-5
# Cycle 350
# Total biomass:
# Model iAF1260.cmd: 4.66090042346011E-5
# Model iJN1463.cmd: 2.9599244487843618E-5
# Cycle 351
# Total biomass:
# Model iAF1260.cmd: 4.6700820433377936E-5
# Model iJN1463.cmd: 2.9688185383663682E-5
# Cycle 352
# Total biomass:
# Model iAF1260.cmd: 4.6792396152245775E-5
# Model iJN1463.cmd: 2.9776983549081112E-5
# Cycle 353
# Total biomass:
# Model iAF1260.cmd: 4.688371039044687E-5
# Model iJN1463.cmd: 2.9865622431919367E-5
# Cycle 354
# Total biomass:
# Model iAF1260.cmd: 4.697478883612255E-5
# Model iJN1463.cmd: 2.9954105134395843E-5
# Cycle 355
# Total biomass:
# Model iAF1260.cmd: 4.7065647069491546E-5
# Model iJN1463.cmd: 3.00424443063899E-5
# Cycle 356
# Total biomass:
# Model iAF1260.cmd: 4.7156296508364886E-5
# Model iJN1463.cmd: 3.013063733226699E-5
# Cycle 357
# Total biomass:
# Model iAF1260.cmd: 4.724674109537018E-5
# Model iJN1463.cmd: 3.021868343673379E-5
# Cycle 358
# Total biomass:
# Model iAF1260.cmd: 4.733698438842405E-5
# Model iJN1463.cmd: 3.0306581167600024E-5
# Cycle 359
# Total biomass:
# Model iAF1260.cmd: 4.7427050491265586E-5
# Model iJN1463.cmd: 3.0394323123830204E-5
# Cycle 360
# Total biomass:
# Model iAF1260.cmd: 4.751695014358462E-5
# Model iJN1463.cmd: 3.04819100647846E-5
# Cycle 361
# Total biomass:
# Model iAF1260.cmd: 4.760667442879583E-5
# Model iJN1463.cmd: 3.056935573515018E-5
# Cycle 362
# Total biomass:
# Model iAF1260.cmd: 4.769623828424641E-5
# Model iJN1463.cmd: 3.065664938712742E-5
# Cycle 363
# Total biomass:
# Model iAF1260.cmd: 4.778566330854065E-5
# Model iJN1463.cmd: 3.0743774567300775E-5
# Cycle 364
# Total biomass:
# Model iAF1260.cmd: 4.787492765495643E-5
# Model iJN1463.cmd: 3.0830705008490024E-5
# Cycle 365
# Total biomass:
# Model iAF1260.cmd: 4.7963845044647946E-5
# Model iJN1463.cmd: 3.091730657822803E-5
# Cycle 366
# Total biomass:
# Model iAF1260.cmd: 4.805252797560111E-5
# Model iJN1463.cmd: 3.100373589202359E-5
# Cycle 367
# Total biomass:
# Model iAF1260.cmd: 4.8141074521109144E-5
# Model iJN1463.cmd: 3.109000378491005E-5
# Cycle 368
# Total biomass:
# Model iAF1260.cmd: 4.8229534314235E-5
# Model iJN1463.cmd: 3.117610116335722E-5
# Cycle 369
# Total biomass:
# Model iAF1260.cmd: 4.831787200211816E-5
# Model iJN1463.cmd: 3.1262053867562625E-5
# Cycle 370
# Total biomass:
# Model iAF1260.cmd: 4.840606798388249E-5
# Model iJN1463.cmd: 3.13479085074586E-5
# Cycle 371
# Total biomass:
# Model iAF1260.cmd: 4.8494108826666E-5
# Model iJN1463.cmd: 3.143364296762511E-5
# Cycle 372
# Total biomass:
# Model iAF1260.cmd: 4.8581981630129376E-5
# Model iJN1463.cmd: 3.151923358037049E-5
# Cycle 373
# Total biomass:
# Model iAF1260.cmd: 4.866976605731808E-5
# Model iJN1463.cmd: 3.160463092415109E-5
# Cycle 374
# Total biomass:
# Model iAF1260.cmd: 4.8757401735520014E-5
# Model iJN1463.cmd: 3.1689864307296355E-5
# Cycle 375
# Total biomass:
# Model iAF1260.cmd: 4.8844839287786386E-5
# Model iJN1463.cmd: 3.1774972538761666E-5
# Cycle 376
# Total biomass:
# Model iAF1260.cmd: 4.893211486086611E-5
# Model iJN1463.cmd: 3.1859357923320364E-5
# Cycle 377
# Total biomass:
# Model iAF1260.cmd: 4.901920701280715E-5
# Model iJN1463.cmd: 3.1943552125150764E-5
# Cycle 378
# Total biomass:
# Model iAF1260.cmd: 4.910615332460775E-5
# Model iJN1463.cmd: 3.202753104030363E-5
# Cycle 379
# Total biomass:
# Model iAF1260.cmd: 4.919294263799576E-5
# Model iJN1463.cmd: 3.211128562819559E-5
# Cycle 380
# Total biomass:
# Model iAF1260.cmd: 4.9279553887043605E-5
# Model iJN1463.cmd: 3.219479644415609E-5
# Cycle 381
# Total biomass:
# Model iAF1260.cmd: 4.936598582111371E-5
# Model iJN1463.cmd: 3.227808336358225E-5
# Cycle 382
# Total biomass:
# Model iAF1260.cmd: 4.945226479044566E-5
# Model iJN1463.cmd: 3.236116037963149E-5
# Cycle 383
# Total biomass:
# Model iAF1260.cmd: 4.953837776829698E-5
# Model iJN1463.cmd: 3.2444016852848527E-5
# Cycle 384
# Total biomass:
# Model iAF1260.cmd: 4.9624335973178746E-5
# Model iJN1463.cmd: 3.252665585216412E-5
# Cycle 385
# Total biomass:
# Model iAF1260.cmd: 4.971018067697177E-5
# Model iJN1463.cmd: 3.26090276944475E-5
# Cycle 386
# Total biomass:
# Model iAF1260.cmd: 4.979586635088846E-5
# Model iJN1463.cmd: 3.269117887411589E-5
# Cycle 387
# Total biomass:
# Model iAF1260.cmd: 4.9881397059468826E-5
# Model iJN1463.cmd: 3.277310158453737E-5
# Cycle 388
# Total biomass:
# Model iAF1260.cmd: 4.996677269862589E-5
# Model iJN1463.cmd: 3.285478545931572E-5
# Cycle 389
# Total biomass:
# Model iAF1260.cmd: 5.00520039096249E-5
# Model iJN1463.cmd: 3.2936221189423126E-5
# Cycle 390
# Total biomass:
# Model iAF1260.cmd: 5.013709854551194E-5
# Model iJN1463.cmd: 3.3017404825930827E-5
# Cycle 391
# Total biomass:
# Model iAF1260.cmd: 5.0222061763269075E-5
# Model iJN1463.cmd: 3.30983432221635E-5
# Cycle 392
# Total biomass:
# Model iAF1260.cmd: 5.03068807611602E-5
# Model iJN1463.cmd: 3.3179027264797884E-5
# Cycle 393
# Total biomass:
# Model iAF1260.cmd: 5.0391565670001304E-5
# Model iJN1463.cmd: 3.325946420910105E-5
# Cycle 394
# ...
# Model iJN1463.cmd: 5.132013315302808E-5
# Cycle 850
# Total biomass:
# Model iAF1260.cmd: 7.528641234149677E-5
# Model iJN1463.cmd: 5.133017639369225E-5
# Cycle 851
# Total biomass:
# Model iAF1260.cmd: 7.532050247810112E-5
# Model iJN1463.cmd: 5.134014426821124E-5
# Cycle 852
# Total biomass:
# Model iAF1260.cmd: 7.535369967422673E-5
# Model iJN1463.cmd: 5.135084242143067E-5
# Cycle 853
# Total biomass:
# Model iAF1260.cmd: 7.538756059695281E-5
# Model iJN1463.cmd: 5.1362655037269774E-5
# Cycle 854
# Total biomass:
# Model iAF1260.cmd: 7.542326698131046E-5
# Model iJN1463.cmd: 5.1374825455175445E-5
# Cycle 855
# Total biomass:
# Model iAF1260.cmd: 7.546230816532196E-5
# Model iJN1463.cmd: 5.13893558946389E-5
# Cycle 856
# Total biomass:
# Model iAF1260.cmd: 7.550365419283797E-5
# Model iJN1463.cmd: 5.140581748311801E-5
# Cycle 857
# Total biomass:
# Model iAF1260.cmd: 7.554535181701406E-5
# Model iJN1463.cmd: 5.142293278156738E-5
# Cycle 858
# Total biomass:
# Model iAF1260.cmd: 7.55872865182163E-5
# Model iJN1463.cmd: 5.1440328154059754E-5
# Cycle 859
# Total biomass:
# Model iAF1260.cmd: 7.562910611843055E-5
# Model iJN1463.cmd: 5.1457645953119273E-5
# Cycle 860
# Total biomass:
# Model iAF1260.cmd: 7.567101193369111E-5
# Model iJN1463.cmd: 5.147503101774474E-5
# Cycle 861
# Total biomass:
# Model iAF1260.cmd: 7.571274637978497E-5
# Model iJN1463.cmd: 5.149227189190025E-5
# Cycle 862
# Total biomass:
# Model iAF1260.cmd: 7.575451879212346E-5
# Model iJN1463.cmd: 5.150955781488458E-5
# Cycle 863
# Total biomass:
# Model iAF1260.cmd: 7.579611941564005E-5
# Model iJN1463.cmd: 5.152669545173424E-5
# Cycle 864
# Total biomass:
# Model iAF1260.cmd: 7.58376134589529E-5
# Model iJN1463.cmd: 5.154378088643779E-5
# Cycle 865
# Total biomass:
# Model iAF1260.cmd: 7.58789180260151E-5
# Model iJN1463.cmd: 5.156070110559225E-5
# Cycle 866
# Total biomass:
# Model iAF1260.cmd: 7.591958655503146E-5
# Model iJN1463.cmd: 5.1577108342905994E-5
# Cycle 867
# Total biomass:
# Model iAF1260.cmd: 7.596067698118916E-5
# Model iJN1463.cmd: 5.159378719221947E-5
# Cycle 868
# Total biomass:
# Model iAF1260.cmd: 7.600433723059895E-5
# Model iJN1463.cmd: 5.1612265831337255E-5
# Cycle 869
# Total biomass:
# Model iAF1260.cmd: 7.603990646116035E-5
# Model iJN1463.cmd: 5.162340116993515E-5
# Cycle 870
# Total biomass:
# Model iAF1260.cmd: 7.607377637564818E-5
# Model iJN1463.cmd: 5.163333082587311E-5
# Cycle 871
# Total biomass:
# Model iAF1260.cmd: 7.610709217220026E-5
# Model iJN1463.cmd: 5.164276313785346E-5
# Cycle 872
# Total biomass:
# Model iAF1260.cmd: 7.61395352214026E-5
# Model iJN1463.cmd: 5.165159924479464E-5
# Cycle 873
# Total biomass:
# Model iAF1260.cmd: 7.617174284175955E-5
# Model iJN1463.cmd: 5.166018571584311E-5
# Cycle 874
# Total biomass:
# Model iAF1260.cmd: 7.62038356767773E-5
# Model iJN1463.cmd: 5.166868977948485E-5
# Cycle 875
# Total biomass:
# Model iAF1260.cmd: 7.623583204914592E-5
# Model iJN1463.cmd: 5.167715982048554E-5
# Cycle 876
# Total biomass:
# Model iAF1260.cmd: 7.62688210810242E-5
# Model iJN1463.cmd: 5.168655789338143E-5
# Cycle 877
# Total biomass:
# Model iAF1260.cmd: 7.630280024417881E-5
# Model iJN1463.cmd: 5.169690111000565E-5
# Cycle 878
# Total biomass:
# Model iAF1260.cmd: 7.634050511898566E-5
# Model iJN1463.cmd: 5.1710134619484876E-5
# Cycle 879
# Total biomass:
# Model iAF1260.cmd: 7.637859157027582E-5
# Model iJN1463.cmd: 5.172387325801457E-5
# Cycle 880
# Total biomass:
# Model iAF1260.cmd: 7.64194081200035E-5
# Model iJN1463.cmd: 5.173989942331124E-5
# Cycle 881
# Total biomass:
# Model iAF1260.cmd: 7.645991017848588E-5
# Model iJN1463.cmd: 5.17559409061513E-5
# Cycle 882
# Total biomass:
# Model iAF1260.cmd: 7.650022308425565E-5
# Model iJN1463.cmd: 5.1771916315259587E-5
# Cycle 883
# Total biomass:
# Model iAF1260.cmd: 7.65404307358091E-5
# Model iJN1463.cmd: 5.17878993202542E-5
# Cycle 884
# Total biomass:
# Model iAF1260.cmd: 7.658051310606179E-5
# Model iJN1463.cmd: 5.180373381927736E-5
# Cycle 885
# Total biomass:
# Model iAF1260.cmd: 7.66205624266215E-5
# Model iJN1463.cmd: 5.181952567688672E-5
# Cycle 886
# Total biomass:
# Model iAF1260.cmd: 7.66605682378497E-5
# Model iJN1463.cmd: 5.183527673647109E-5
# Cycle 887
# Total biomass:
# Model iAF1260.cmd: 7.670054119227697E-5
# Model iJN1463.cmd: 5.1850983470758966E-5
# Cycle 888
# Total biomass:
# Model iAF1260.cmd: 7.674045759660545E-5
# Model iJN1463.cmd: 5.1866644326569476E-5
# Cycle 889
# Total biomass:
# Model iAF1260.cmd: 7.678031559820863E-5
# Model iJN1463.cmd: 5.188225791372677E-5
# Cycle 890
# Total biomass:
# Model iAF1260.cmd: 7.682011469743505E-5
# Model iJN1463.cmd: 5.18978238310663E-5
# Cycle 891
# Total biomass:
# Model iAF1260.cmd: 7.685990914880345E-5
# Model iJN1463.cmd: 5.191335142885001E-5
# Cycle 892
# Total biomass:
# Model iAF1260.cmd: 7.68995967669632E-5
# Model iJN1463.cmd: 5.192882272306711E-5
# Cycle 893
# Total biomass:
# Model iAF1260.cmd: 7.693922781010119E-5
# Model iJN1463.cmd: 5.1944252135793136E-5
# Cycle 894
# Total biomass:
# Model iAF1260.cmd: 7.697880292888647E-5
# Model iJN1463.cmd: 5.1959637515110806E-5
# Cycle 895
# Total biomass:
# Model iAF1260.cmd: 7.701832350849521E-5
# Model iJN1463.cmd: 5.1974979195903554E-5
# Cycle 896
# Total biomass:
# Model iAF1260.cmd: 7.705778952123417E-5
# Model iJN1463.cmd: 5.1990277000297E-5
# Cycle 897
# Total biomass:
# Model iAF1260.cmd: 7.709720086694273E-5
# Model iJN1463.cmd: 5.200553091533874E-5
# Cycle 898
# Total biomass:
# Model iAF1260.cmd: 7.713803039131547E-5
# Model iJN1463.cmd: 5.2021953785993655E-5
# Cycle 899
# Total biomass:
# Model iAF1260.cmd: 7.717751577038629E-5
# Model iJN1463.cmd: 5.2037310978164115E-5
# Cycle 900
# Total biomass:
# Model iAF1260.cmd: 7.722503929722499E-5
# Model iJN1463.cmd: 5.2058627961397436E-5
# Cycle 901
# Total biomass:
# Model iAF1260.cmd: 7.727549079846335E-5
# Model iJN1463.cmd: 5.2082196218423685E-5
# Cycle 902
# Total biomass:
# Model iAF1260.cmd: 7.732657647345408E-5
# Model iJN1463.cmd: 5.210638623734622E-5
# Cycle 903
# Total biomass:
# Model iAF1260.cmd: 7.737760080627837E-5
# Model iJN1463.cmd: 5.213052584489851E-5
# Cycle 904
# Total biomass:
# Model iAF1260.cmd: 7.742859991973107E-5
# Model iJN1463.cmd: 5.215465273988034E-5
# Cycle 905
# Total biomass:
# Model iAF1260.cmd: 7.747971857038623E-5
# Model iJN1463.cmd: 5.217887685110736E-5
# Cycle 906
# Total biomass:
# Model iAF1260.cmd: 7.75306107011773E-5
# Model iJN1463.cmd: 5.220288294135958E-5
# Cycle 907
# Total biomass:
# Model iAF1260.cmd: 7.758151208961781E-5
# Model iJN1463.cmd: 5.222697662667142E-5
# Cycle 908
# Total biomass:
# Model iAF1260.cmd: 7.763220256475024E-5
# Model iJN1463.cmd: 5.2250868623096414E-5
# Cycle 909
# Total biomass:
# Model iAF1260.cmd: 7.768301300338015E-5
# Model iJN1463.cmd: 5.227476111191431E-5
# Cycle 910
# Total biomass:
# Model iAF1260.cmd: 7.773376774620206E-5
# Model iJN1463.cmd: 5.229857873008439E-5
# Cycle 911
# Total biomass:
# Model iAF1260.cmd: 7.778451647017293E-5
# Model iJN1463.cmd: 5.2322475301228874E-5
# Cycle 912
# Total biomass:
# Model iAF1260.cmd: 7.783503909683516E-5
# Model iJN1463.cmd: 5.234616284293864E-5
# Cycle 913
# Total biomass:
# Model iAF1260.cmd: 7.788175901676011E-5
# Model iJN1463.cmd: 5.236690027437854E-5
# Cycle 914
# Total biomass:
# Model iAF1260.cmd: 7.792446687871444E-5
# Model iJN1463.cmd: 5.238450171638075E-5
# Cycle 915
# Total biomass:
# Model iAF1260.cmd: 7.796633090862921E-5
# Model iJN1463.cmd: 5.240159356869826E-5
# Cycle 916
# Total biomass:
# Model iAF1260.cmd: 7.800937007011346E-5
# Model iJN1463.cmd: 5.2419655246216587E-5
# Cycle 917
# Total biomass:
# Model iAF1260.cmd: 7.805696390034896E-5
# Model iJN1463.cmd: 5.2441037239567524E-5
# Cycle 918
# Total biomass:
# Model iAF1260.cmd: 7.810697694186268E-5
# Model iJN1463.cmd: 5.2464425551323195E-5
# Cycle 919
# Total biomass:
# Model iAF1260.cmd: 7.815693164391497E-5
# Model iJN1463.cmd: 5.2487652345257335E-5
# Cycle 920
# Total biomass:
# Model iAF1260.cmd: 7.82070231367437E-5
# Model iJN1463.cmd: 5.251085904336003E-5
# Cycle 921
# Total biomass:
# Model iAF1260.cmd: 7.825766520352435E-5
# Model iJN1463.cmd: 5.253459096776094E-5
# Cycle 922
# Total biomass:
# Model iAF1260.cmd: 7.830795031484538E-5
# Model iJN1463.cmd: 5.2557929901054127E-5
# Cycle 923
# Total biomass:
# Model iAF1260.cmd: 7.83584394377365E-5
# Model iJN1463.cmd: 5.2581604415070534E-5
# Cycle 924
# Total biomass:
# Model iAF1260.cmd: 7.840850431457762E-5
# Model iJN1463.cmd: 5.2605027966185196E-5
# Cycle 925
# Total biomass:
# Model iAF1260.cmd: 7.845847186391507E-5
# Model iJN1463.cmd: 5.262838392973666E-5
# Cycle 926
# Total biomass:
# Model iAF1260.cmd: 7.850839609723966E-5
# Model iJN1463.cmd: 5.2651651557613196E-5
# Cycle 927
# Total biomass:
# Model iAF1260.cmd: 7.855846599729659E-5
# Model iJN1463.cmd: 5.267505210521545E-5
# Cycle 928
# Total biomass:
# Model iAF1260.cmd: 7.860817931331512E-5
# Model iJN1463.cmd: 5.2698128429032474E-5
# Cycle 929
# Total biomass:
# Model iAF1260.cmd: 7.86580046944379E-5
# Model iJN1463.cmd: 5.2721391067255055E-5
# Cycle 930
# Total biomass:
# Model iAF1260.cmd: 7.870746809160172E-5
# Model iJN1463.cmd: 5.274426194147835E-5
# Cycle 931
# Total biomass:
# Model iAF1260.cmd: 7.875722752115844E-5
# Model iJN1463.cmd: 5.276747244710957E-5
# Cycle 932
# Total biomass:
# Model iAF1260.cmd: 7.880660778603694E-5
# Model iJN1463.cmd: 5.279033513765842E-5
# Cycle 933
# Total biomass:
# Model iAF1260.cmd: 7.885611090788192E-5
# Model iJN1463.cmd: 5.2813287095626925E-5
# Cycle 934
# Total biomass:
# Model iAF1260.cmd: 7.890549299687267E-5
# Model iJN1463.cmd: 5.2836101420899525E-5
# Cycle 935
# Total biomass:
# Model iAF1260.cmd: 7.895497351387501E-5
# Model iJN1463.cmd: 5.2859085691715114E-5
# Cycle 936
# Total biomass:
# Model iAF1260.cmd: 7.900413451247283E-5
# Model iJN1463.cmd: 5.288173392728503E-5
# Cycle 937
# Total biomass:
# Model iAF1260.cmd: 7.905347801284882E-5
# Model iJN1463.cmd: 5.290460756820641E-5
# Cycle 938
# Total biomass:
# Model iAF1260.cmd: 7.91026441558639E-5
# Model iJN1463.cmd: 5.2927020214046315E-5
# Cycle 939
# Total biomass:
# Model iAF1260.cmd: 7.915224516795085E-5
# Model iJN1463.cmd: 5.2949934488987213E-5
# Cycle 940
# Total biomass:
# Model iAF1260.cmd: 7.920188145653873E-5
# Model iJN1463.cmd: 5.297294603714299E-5
# Cycle 941
# Total biomass:
# Model iAF1260.cmd: 7.92513259701857E-5
# Model iJN1463.cmd: 5.299575624040396E-5
# Cycle 942
# Total biomass:
# Model iAF1260.cmd: 7.930083197522679E-5
# Model iJN1463.cmd: 5.301866695241239E-5
# Cycle 943
# Total biomass:
# Model iAF1260.cmd: 7.935001660664907E-5
# Model iJN1463.cmd: 5.304126915204891E-5
# Cycle 944
# Total biomass:
# Model iAF1260.cmd: 7.939941509732269E-5
# Model iJN1463.cmd: 5.306402378289202E-5
# Cycle 945
# Total biomass:
# Model iAF1260.cmd: 7.944864523545692E-5
# Model iJN1463.cmd: 5.3086707188063215E-5
# Cycle 946
# Total biomass:
# Model iAF1260.cmd: 7.949782434251149E-5
# Model iJN1463.cmd: 5.310922977298351E-5
# Cycle 947
# Total biomass:
# Model iAF1260.cmd: 7.954706852620979E-5
# Model iJN1463.cmd: 5.31317659574791E-5
# Cycle 948
# Total biomass:
# Model iAF1260.cmd: 7.959628118573336E-5
# Model iJN1463.cmd: 5.315439856502517E-5
# Cycle 949
# Total biomass:
# Model iAF1260.cmd: 7.964524367198775E-5
# Model iJN1463.cmd: 5.317687913161668E-5
# Cycle 950
# Total biomass:
# Model iAF1260.cmd: 7.969417226429799E-5
# Model iJN1463.cmd: 5.319920490210882E-5
# Cycle 951
# Total biomass:
# Model iAF1260.cmd: 7.97430998110292E-5
# Model iJN1463.cmd: 5.322142330742607E-5
# Cycle 952
# Total biomass:
# Model iAF1260.cmd: 7.979227066517218E-5
# Model iJN1463.cmd: 5.324406010192296E-5
# Cycle 953
# Total biomass:
# Model iAF1260.cmd: 7.98409115478483E-5
# Model iJN1463.cmd: 5.32662254200972E-5
# Cycle 954
# Total biomass:
# Model iAF1260.cmd: 7.988954638358591E-5
# Model iJN1463.cmd: 5.328837005833372E-5
# Cycle 955
# Total biomass:
# Model iAF1260.cmd: 7.993815003111787E-5
# Model iJN1463.cmd: 5.331048389572873E-5
# Cycle 956
# Total biomass:
# Model iAF1260.cmd: 7.998664571131728E-5
# Model iJN1463.cmd: 5.333244292237897E-5
# Cycle 957
# Total biomass:
# Model iAF1260.cmd: 8.003524302704317E-5
# Model iJN1463.cmd: 5.335452723338049E-5
# Cycle 958
# Total biomass:
# Model iAF1260.cmd: 8.008373081128462E-5
# Model iJN1463.cmd: 5.337653706996389E-5
# Cycle 959
# Total biomass:
# Model iAF1260.cmd: 8.013208037045145E-5
# Model iJN1463.cmd: 5.339837398438564E-5
# Cycle 960
# Total biomass:
# Model iAF1260.cmd: 8.018052145743066E-5
# Model iJN1463.cmd: 5.3420329734189104E-5
# Cycle 961
# Total biomass:
# Model iAF1260.cmd: 8.022884917313607E-5
# Model iJN1463.cmd: 5.34422089188783E-5
# Cycle 962
# Total biomass:
# Model iAF1260.cmd: 8.027709970047054E-5
# Model iJN1463.cmd: 5.3464030050954416E-5
# Cycle 963
# Total biomass:
# Model iAF1260.cmd: 8.03252264915001E-5
# Model iJN1463.cmd: 5.348568664397924E-5
# Cycle 964
# Total biomass:
# Model iAF1260.cmd: 8.037336626588425E-5
# Model iJN1463.cmd: 5.350733577945371E-5
# Cycle 965
# Total biomass:
# Model iAF1260.cmd: 8.042148003631584E-5
# Model iJN1463.cmd: 5.35289577321524E-5
# Cycle 966
# Total biomass:
# Model iAF1260.cmd: 8.046955089348982E-5
# Model iJN1463.cmd: 5.355054208007266E-5
# Cycle 967
# Total biomass:
# Model iAF1260.cmd: 8.051757160373912E-5
# Model iJN1463.cmd: 5.357208492074189E-5
# Cycle 968
# Total biomass:
# Model iAF1260.cmd: 8.056554002012093E-5
# Model iJN1463.cmd: 5.3593584866455424E-5
# Cycle 969
# Total biomass:
# Model iAF1260.cmd: 8.061345557050712E-5
# Model iJN1463.cmd: 5.361504150810821E-5
# Cycle 970
# Total biomass:
# Model iAF1260.cmd: 8.066131681111823E-5
# Model iJN1463.cmd: 5.3636454660001453E-5
# Cycle 971
# Total biomass:
# Model iAF1260.cmd: 8.070912506143663E-5
# Model iJN1463.cmd: 5.3657824357742047E-5
# Cycle 972
# Total biomass:
# Model iAF1260.cmd: 8.075687930188064E-5
# Model iJN1463.cmd: 5.3679150490851184E-5
# Cycle 973
# Total biomass:
# Model iAF1260.cmd: 8.080465588377422E-5
# Model iJN1463.cmd: 5.3700557447055846E-5
# Cycle 974
# Total biomass:
# Model iAF1260.cmd: 8.085223601323995E-5
# Model iJN1463.cmd: 5.3721760808777736E-5
# Cycle 975
# Total biomass:
# Model iAF1260.cmd: 8.089987677811639E-5
# Model iJN1463.cmd: 5.374306397248523E-5
# Cycle 976
# Total biomass:
# Model iAF1260.cmd: 8.094740863462262E-5
# Model iJN1463.cmd: 5.376429442383622E-5
# Cycle 977
# Total biomass:
# Model iAF1260.cmd: 8.099486945597293E-5
# Model iJN1463.cmd: 5.378547140156256E-5
# Cycle 978
# Total biomass:
# Model iAF1260.cmd: 8.104234844050411E-5
# Model iJN1463.cmd: 5.380671246558102E-5
# Cycle 979
# Total biomass:
# Model iAF1260.cmd: 8.108965475543236E-5
# Model iJN1463.cmd: 5.382784046534605E-5
# Cycle 980
# Total biomass:
# Model iAF1260.cmd: 8.113686444054972E-5
# Model iJN1463.cmd: 5.384889858847652E-5
# Cycle 981
# Total biomass:
# Model iAF1260.cmd: 8.118400551522967E-5
# Model iJN1463.cmd: 5.386990423126225E-5
# Cycle 982
# Total biomass:
# Model iAF1260.cmd: 8.123108818826687E-5
# Model iJN1463.cmd: 5.389086344450541E-5
# Cycle 983
# Total biomass:
# Model iAF1260.cmd: 8.127809278722929E-5
# Model iJN1463.cmd: 5.391167083518166E-5
# Cycle 984
# Total biomass:
# Model iAF1260.cmd: 8.132517485842212E-5
# Model iJN1463.cmd: 5.39326048739435E-5
# Cycle 985
# Total biomass:
# Model iAF1260.cmd: 8.137216225309375E-5
# Model iJN1463.cmd: 5.395345792750056E-5
# Cycle 986
# Total biomass:
# Model iAF1260.cmd: 8.14190703007659E-5
# Model iJN1463.cmd: 5.397425236286457E-5
# Cycle 987
# Total biomass:
# Model iAF1260.cmd: 8.14658839093228E-5
# Model iJN1463.cmd: 5.39949030726695E-5
# Cycle 988
# Total biomass:
# Model iAF1260.cmd: 8.151286621483703E-5
# Model iJN1463.cmd: 5.401559597894122E-5
# Cycle 989
# Total biomass:
# Model iAF1260.cmd: 8.155985911177027E-5
# Model iJN1463.cmd: 5.4036397956569955E-5
# Cycle 990
# Total biomass:
# Model iAF1260.cmd: 8.160664532991532E-5
# Model iJN1463.cmd: 5.405707466609668E-5
# Cycle 991
# Total biomass:
# Model iAF1260.cmd: 8.16533116089431E-5
# Model iJN1463.cmd: 5.407767043643999E-5
# Cycle 992
# Total biomass:
# Model iAF1260.cmd: 8.169989911712151E-5
# Model iJN1463.cmd: 5.4098208692787704E-5
# Cycle 993
# Total biomass:
# Model iAF1260.cmd: 8.174639273321002E-5
# Model iJN1463.cmd: 5.4118591447958655E-5
# Cycle 994
# Total biomass:
# Model iAF1260.cmd: 8.179296981029851E-5
# Model iJN1463.cmd: 5.4139098881877246E-5
# Cycle 995
# Total biomass:
# Model iAF1260.cmd: 8.183944206449498E-5
# Model iJN1463.cmd: 5.4159525525560136E-5
# Cycle 996
# Total biomass:
# Model iAF1260.cmd: 8.188583453280513E-5
# Model iJN1463.cmd: 5.4179894141947675E-5
# Cycle 997
# Total biomass:
# Model iAF1260.cmd: 8.193216480253542E-5
# Model iJN1463.cmd: 5.420021464967223E-5
# Cycle 998
# Total biomass:
# Model iAF1260.cmd: 8.197843785851181E-5
# Model iJN1463.cmd: 5.422049073299577E-5
# Cycle 999
# Total biomass:
# Model iAF1260.cmd: 8.202465709717066E-5
# Model iJN1463.cmd: 5.424072392745832E-5
# Cycle 1000
# Total biomass:
# Model iAF1260.cmd: 8.207082284479872E-5
# Model iJN1463.cmd: 5.426091451636806E-5
# Cycle 1001
# End of simulation
# Total time = 9703.697s
#
# STDERR empty.

# %% [markdown]
# Para revisar la biomasa total

# %%
sim.total_biomass.plot(x = "cycle")
# Out:
# <AxesSubplot:xlabel='cycle'>

# %% [markdown]
# Graficamos los resultados de biomasa y demás metabolitos interesantes en el grid:

# %%
im = sim.get_biomass_image('iAF1260', params.all_params['maxCycles'])
im2 = sim.get_biomass_image('iJN1463',params.all_params['maxCycles'])

final = np.zeros((grid_size,grid_size,3))
final[:,:,0] = im / np.max(im)
final[:,:,1] = im2 / np.max(im2)
for rock in rock_locs:
    final[rock[0],rock[1],0:3] = 0.4 
from matplotlib import pyplot as plt
ﬁg, ax = plt.subplots(ﬁgsize = (3.1, 3.1))
ax.imshow(ﬁnal)
plt.imshow(final)

# %%
plt.imshow(sim.get_metabolite_image("succ_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("ac_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("nh4_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("o2_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("catechol_e",params.all_params['maxCycles']))
