# %% [markdown]
# **Soil-air interface.**
#
# Using the functionality of COMETS, one can design simulations which go beyond in silico corollaries of lab experiments to make predictions for environments mimicking natural ecosystems, which is a necessary step for understanding natural ecology from first principles. In this example, we consider a simulation of a soil environment. We use source-and-sink functions to model how a root provides organic acids to the environment while removing ammonia (Huang et al 2014 Botany). While we restrict the root functionality to a source/sink, one could use functionality demonstrated above, for example extracellular enzymes, to generate feedback loops between microbe-produced metabolites and root exudation. We use fixed metabolite concentrations to mimic the largely unchanging air interface above a root, which generates an oxygen gradient. Additionally, since soil is characterized by strong spatial structure with many impenetrable barriers that localized interactions (Nunan 2017), we place “rock” barriers throughout the simulation area. A more complex simulation could use varying diffusion constants for metabolites, as described in a previous protocol (Virtual Petri Dish). Similarly, we use standard diffusion of biomass, but this could be changed to use pushing force or non-linear diffusion for a potentially increased realism.

# %%
import cobra 
import sys 
import copy 
import numpy as np 
from matplotlib import pyplot as plt 
import cometspy as c

# %% [markdown]
# Para nuestro proyecto, utilizaremos Escherichia coli (modelo iAF1260), Pseudomonas putida (modelo iJN1463) y Saccharomyces Cerevisiae (modelo iMM904), recuperados de la base de datos BIGG.
#
# Cambiamos los bounds de las funciones objetivo de los modelos:

# %%
model_dir = "./modelos" # model location
iMM = cobra.io.read_sbml_model(model_dir + '/iMM904.xml')
iJN = cobra.io.read_sbml_model(model_dir + '/iJN1463.xml')

iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').lower_bound = 0
iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').upper_bound = 1000

iMM.reactions.get_by_id('BIOMASS_SC5_notrace').lower_bound = 0
iMM.reactions.get_by_id('BIOMASS_SC5_notrace').upper_bound = 1000

# %% [markdown]
# Luego se convierten estos modelos al formato de COMETS. Se utilizan funciones helper para dos cosas: a) Asegurar que el modelo en COMETS no confunda las reacciones de "sink" con las de exchange, ya que en COBRA están desbalanceadas y por tanto se parecen a las de exchange, y b) abrir todos los bounds de las reacciones de exchange, para que COMETS controle la composición del medio.

# %%
iMM_comets = c.model(iMM)
iMM_comets.ensure_sinks_are_not_exchanges()
iMM_comets.open_exchanges()

iJN_comets = c.model(iJN)
iJN_comets.ensure_sinks_are_not_exchanges()
iJN_comets.open_exchanges()

# %% [markdown]
# El mundo que se simulará tendrá dimensiones de 30x30. El eje de la izquierda (x = 0) corresponde a la raíz, y el eje superior (y = 0) corresponde al aire. La biomasa y las rocas se distribuyen en el resto del grid. Donde hayan rocas no puede haber ni biomasa ni metabolitos, así que seleccionamos esos lugares primero. Para esta simulación, se generarán 3 rocas con un un tamaño medio de 1 cuadraditos. Para generar las piedras se utiliza la función helper grow_rocks.

# %%
from cometspy.utils import grow_rocks, pick_random_locations

grid_size = 15 # 100
n_rocks = 27 # 70
rock_locs = grow_rocks(n = n_rocks, xrange = [1,grid_size-1],yrange = [1,grid_size-1],mean_size = 1)

# %% [markdown]
# Cada especie será plantada en 20 lugares sin sobreponerse. Para esto se utiliza la función helper pick_random_locations, la cual toma como argumento una tupla generada anteriormente que marca lugares "prohibidos", como los cuadrados donde se encuentran las rocas.
#
# Generamos una copia de rock_locs para no cambiarla accidentalmente, y la llamamos forbbiden_locs:

# %%
import copy
forbidden_locs = copy.deepcopy(rock_locs)

# %% [markdown]
# Ahora elegimos al azar los lugares para cada especie, y los vamos añadiendo a la lista forbidden locs para que no se sobrepongan:

# %%
founders_per_species = 15 # 60
iMM_locs = pick_random_locations(n = founders_per_species, 
                                   xrange = [1,grid_size], yrange = [1,grid_size], 
                                   forbidden_locs = forbidden_locs)
forbidden_locs.extend(iMM_locs)
iJN_locs = pick_random_locations(founders_per_species, [1,grid_size],[1,grid_size], forbidden_locs)

# %% [markdown]
# Para graficar los lugares utilizamos matplotlib:

# %%
from matplotlib import pyplot as plt
initial_image = np.zeros((grid_size,grid_size,3))
for rock in rock_locs:
    initial_image[rock[0],rock[1],0:3] = 0.5 
for loc in iMM_locs:
    initial_image[loc[0],loc[1],1] = 1
for loc in iJN_locs:
    initial_image[loc[0],loc[1],2] = 1
plt.imshow(initial_image)

# %% [markdown]
# Generamos el layout y agregamos las rocas:

# %%
# iAF
iMM_initial_pop = [] 
for loc in iJN_locs: 
    iMM_initial_pop.append([loc[0], loc[1], 1.e-8]) 
iMM_comets.initial_pop = iMM_initial_pop 
# iJN
iJN_initial_pop = [] 
for loc in iJN_locs: 
    iJN_initial_pop.append([loc[0], loc[1], 1.e-9]) 
iJN_comets.initial_pop = iJN_initial_pop

# %% [markdown]
# Setteamos las poblaciones iniciales para cada especie, con esto los modelos están listos y los añadimos al layout:

# %%
layout = c.layout([iMM_comets, iJN_comets])
layout.grid = [grid_size,grid_size]
layout.add_barriers(rock_locs)

# %% [markdown]
# Añadimos los metabolitos que estarán inicialmente disponibles en el ambiente. Usamos la función helper add_typical_trace_metabolites() para las trazas típicas. Bajamos el valor del oxígeno dado que la idea es que el que esté disponible difunda desde la atmósfera. Añadimos algunos metabolitos que no se añadieron con la función helper:

# %%
layout.add_typical_trace_metabolites()
layout.set_specific_metabolite('o2_e',0.00001)
layout.set_specific_metabolite('hco3_e',1000)
layout.set_specific_metabolite('co2_e',1000)
#layout.set_specific_metabolite('h2_e',1000)
layout.set_specific_metabolite('so3_e',1000)
layout.set_specific_metabolite('nh4_e',0.000001)

layout.set_specific_metabolite('glc__D_e',0.0000001)
layout.set_specific_metabolite('meoh_e',0.00000001)
layout.set_specific_metabolite('cys__L_e',0.0000001)
layout.set_specific_metabolite('catechol_e',0.0000001)

# %% [markdown]
# Para la capa de aire, dejamos el oxígeno en un valor constante. Al fondo también dejamos al oxígeno en un valor fijo e igual a 0, para simular el efecto de difusión. De manera similar, hacemos lo mismo con el amoniaco y la raíz en la parte izquierda:

# %%
# set static media of O2 and CO2 at the top and bottom-- the "air" and continuous loss of O2 downwards
for x in range(grid_size):
    layout.set_specific_static_at_location('o2_e', (x,0), .0001) # top
    layout.set_specific_static_at_location('o2_e', (x,grid_size-1), 0.) # bottom
    layout.set_specific_static_at_location('co2_e', (x,0), .0001)
    
for x in range(grid_size):
    layout.set_specific_static_at_location('nh4_e', (0,x), 0.0)

# %% [markdown]
# La raíz consume todo el amoniaco, pero es una fuente de acidos orgánicos y metanol para el ambiente. Asumiendo una tasa fija:

# %%
for x in range(grid_size):
    layout.set_specific_refresh_at_location('cit_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('meoh_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('succ_e', (0,x), .000001)

# %% [markdown]
# El layout y los modelos están listos, ahora setteamos los parámetros de la simulación:

# %%
params = c.params()
params.set_param('timeStep', 0.1)
params.set_param('maxCycles', 1000)
params.set_param('maxSpaceBiomass', 10)
params.set_param('deathRate', 0.0001) # die at rate of 1/10000 per hour
params.set_param('writeBiomassLog', True)
params.set_param('BiomassLogRate', 500)
params.set_param('writeMediaLog', True)
params.set_param('MediaLogRate', 500)
params.set_param("writeFluxLog", True)
params.set_param("FluxLogRate", 500)
params.set_param('numRunThreads', 3)
params.set_param('defaultKm', 0.000001)

# %% [markdown]
# Ahora creamos el objeto de la simulación y la corremos. Ojito que se demora y el pc empieza a despegar.

# %%
sim = c.comets(layout, params)
sim.run(False)
# Out:
# Running COMETS simulation ...
# C:\Users\pabli\AppData\Local\Temp/ipykernel_4224/1491467366.py:2: DtypeWarning: Columns (10,13,14,15,16,17,18,22,23,24,25,26,27,29,30,31,33,35,42,48,51,61,62,68,69,82,83,92,93,95,96,101,102,103,104,105,115,118,123,124,135,140,142,147,153,158,162,163,169,171,177,187,188,193,194,195,214,223,232,234,245,255,256,257,258,264,265,295,296,301,306,312,315,324,325,328,331,334,335,338,339,343,344,348,350,351,365,369,374,375,388,400,402,406,415,418,419,420,423,424,425,426,436,437,440,444,449,465,467,469,470,482,491,501,507,511,512,513,515,516,520,522,525,527,533,538,541,546,554,557,559,560,563,565,571,576,581,584,590,591,600,601,614,619,633,634,641,648,649,664,665,667,668,674,675,676,677,678,679,684,687,688,689,690,692,693,695,698,701,708,709,711,712,713,716,718,719,720,721,722,727,728,732,738,740,742,744,746,752,753,765,766,773,794,799,806,810,823,829,847,849,850,851,866,869,870,874,878,879,882,897,913,923,929,930,932,934,940,941,953,960,978,979,999,1007,1009,1014,1016,1018,1021,1022,1024,1025,1036,1037,1040,1050,1051,1061,1063,1068,1071,1074,1080,1086,1087,1113,1115,1126,1141,1142,1150,1164,1165,1166,1176,1180,1181,1182,1183,1184,1188,1195,1197,1204,1206,1211,1213,1214,1216,1217,1218,1219,1227,1228,1229,1233,1237,1261,1262,1263,1264,1265,1269,1276,1277,1278,1279,1280,1282,1283,1284,1287,1288,1299,1301,1304,1312,1313,1334,1336,1346,1347,1351,1354,1355,1365,1369,1370,1375,1376,1396,1412,1416,1424,1426,1428,1439,1442,1443,1447,1453,1464,1467,1470,1472,1481,1482,1484,1487,1488,1491,1506,1514,1515,1520,1526,1534,1535,1541,1558,1562,1565,1567,1568,1569,1571,1573,1578,1580,1585,1586,1599,1601,1629,1630,1631,1632,1643,1645,1655,1664,1666,1676,1680,1689,1690,1692,1697,1698,1700,1701,1702,1764,1765,1766,1767,1768,1769,1770,1771,1772,1773,1774,1775,1778,1779,1797,1809,1811,1856,1877,1878,1890,1891,1892,1895,1896,1900,1910,1911,1914,1915,1918,1919,1924,1925,1933,1934,1949,1950,1957,1958,1968,1984,1986,1987,1988,1989,1990,1991,1993,1994,1995,1996,2004,2037,2080,2086,2127,2133,2134,2161,2162,2167,2168,2200,2205,2206,2215,2219,2223,2224,2225,2227,2241,2249,2250,2251,2254,2257,2263,2269,2270,2273,2279,2322,2342,2362,2373,2374,2382,2388,2390,2391,2393,2394,2398,2399,2410,2420,2423,2426,2427,2428,2429,2431,2433,2440,2453,2472,2473,2474,2476,2477,2479,2480,2482,2486,2531,2533,2535,2575,2589,2590,2591,2595,2607,2608,2639,2670,2682,2693,2694,2714,2715,2719,2720,2723,2725,2727,2729,2731,2769,2790,2795,2816,2817,2820,2821,2826,2833,2837,2842,2852,2857,2862,2888,2900,2912,2913) have mixed types.Specify dtype option on import or set low_memory=False.
#   sim.run(False)
# Done!

# %%
print(sim.run_output)
print(sim.run_errors)
# Out:
# -script
# running script file: C:\Users\pabli\OneDrive\Escritorio\COMETS\ODRM\simulaciones\2_modelos\Saccharomyces_putida_15x15_0.0000001_catechol_cambio_saccharomyces\Saccharomyces_putida_15x15_0.0000001_catechol_cambio_putida_1e9/.current_script_0x209dbfcf040
# Current Java version: 17.0.1
# Parameters file .current_global_0x209dbfcf040 loaded.
# Parameters file .current_package_0x209dbfcf040 loaded.
# Loading layout file '.current_layout_0x209dbfcf040'...
# null\COMETS_manifest.txt (El sistema no puede encontrar la ruta especificada)
# Unable to initialize manifest file.
# Continuing without writing manifest file.
# Found 2 model files!
# Loading '.\iMM904.cmd' ...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution = 133.8587770175764
# Loading '.\iJN1463.cmd' ...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution = 237.06607191111308
# Constructing world...
# Done!
# medialist	12dgr160_e	12dgr180_e	13BDglcn_e	13dampp_e	15dap_e	1ag160_e	1ag180_e	1ag181d9_e	1ag182d9d12_e	25dkglcn_e	26dap__M_e	2ameph_e	2ddglcn_e	2dhglcn_e	2hb_e	2m35mdntha_e	2mbac_e	2mbald_e	2mbtoh_e	2mppal_e	2phetoh_e	34dhbz_e	34dhcinm_e	34dhphe_e	35dnta_e	3c3hmp_e	3h4atb_e	3mb_e	3mbald_e	3mop_e	3oxoadp_e	4abut_e	4abz_e	4hbz_e	4hpro_DC_e	4hpro_LT_e	4hptn_e	4oxptn_e	5aop_e	5aptn_e	5g2oxpt_e	5mcsn_e	5oxpro_e	6atha_e	6hnac_e	8aonn_e	LalaLglu_e	Nbfortyr_e	Ncbmpts_e	R3hdec4e_e	R_3h4atba_e	R_3h6atha_e	R_3hcmrs7e_e	R_3hdcaa_e	R_3hdd5ea_e	R_3hdd6e_e	R_3hdda_e	R_3hhdca_e	R_3hhpa_e	R_3hhxa_e	R_3hnonaa_e	R_3hocta_e	R_3hpba_e	R_3hpdeca_e	R_3hphpa_e	R_3hphxa_e	R_3hpnona_e	R_3hpocta_e	R_3hppta_e	R_3hpt_e	R_3htd58e_e	R_3htd5e_e	R_3httdca_e	T4hcinnm_e	abt_e	ac_e	acac_e	acald_e	aces_e	acmtsoxin_e	acon_C_e	acpptrn_e	acser_e	actn__R_e	ade_e	adn_e	adocbl_e	ag_e	agm_e	akg_e	ala_B_e	ala__D_e	ala__L_e	alaala_e	alahis_e	alaleu_e	alathr_e	alatrp_e	algac_MG_14_e	algac_MG_23_e	algac_MG_32_e	algac_MG_41_e	algac__M_e	alltn_e	alltt_e	amet_e	apc_e	arab__D_e	arab__L_e	arbtn_e	arbtn_fe3_e	arg__D_e	arg__L_e	asn__D_e	asn__L_e	aso3_e	aso4_e	asp__L_e	balaala_e	balabala_e	balagly_e	balaleu_e	balamd_e	bhb_e	biliverd_e	btd_RR_e	btn_e	butso3_e	bz_e	ca2_e	carn_e	catechol_e	cbi_e	cbl1_e	cd2_e	cell4_e	cgly_e	chol_e	chols_e	chor_e	cinnm_e	cit_e	cl_e	cm_e	cmcbtt_e	co2_e	co_e	cobalt2_e	confrl_e	creat_e	crn_e	cro2_e	cro4_e	crtn_e	csn_e	cu2_e	cu_e	cyan_e	cys__D_e	cys__L_e	cytd_e	d2one_e	d3one_e	d4one_e	dad_2_e	dag181d9_e	dag182d9d12_e	dann_e	dca_e	dcyt_e	ddca_e	dgsn_e	dgudbutn_e	din_e	dmanur_e	dmgly_e	dmso2_e	dopa_e	dttp_e	duri_e	ecto__L_e	enter_e	epist_e	epistest_SC_e	ergst_e	ergstest_SC_e	etha_e	ethso3_e	etoh_e	fald_e	fcmcbtt_e	fe2_e	fe3_e	fe3dcit_e	fe3mcbtt_e	fe3pyovd_e	fe3pyovd_kt_e	fecost_e	fecostest_SC_e	fecrm_e	fecrm_un_e	feenter_e	feoxam_e	feoxam_un_e	fer_e	fmn_e	for_e	fru_e	fum_e	g3pc_e	g3pi_e	ga_e	gal_e	galct__D_e	galur_e	gam6p_e	gcald_e	glc__D_e	glcn_e	glcr_e	glcur_e	gln__L_e	glu__L_e	glutar_e	glx_e	gly_e	glyald_e	glyb_e	glyc__R_e	glyc_e	glyclt_e	glycol_e	glygln_e	glyglu_e	glygly_e	glymet_e	glyphe_e	glyser_e	gsn_e	gthox_e	gthrd_e	gua_e	gudac_e	gudptn_e	h2o2_e	h2o_e	h2s_e	h_e	hco3_e	hcys__L_e	hdca_e	hdcea_e	hexc_e	hg2_e	hgentis_e	his__L_e	hisgly_e	hishis_e	hom__L_e	hpta_e	hxa_e	hxan_e	iamac_e	iamoh_e	ibutac_e	ibutoh_e	icit_e	id3acald_e	ile__L_e	ind3ac_e	ind3eth_e	indole_e	inost_e	ins_e	isetac_e	k_e	lac__D_e	lac__L_e	lanost_e	lanostest_SC_e	leu__D_e	leu__L_e	leuleu_e	lnlc_e	lpspput_e	lys__D_e	lys__L_e	m_xyl_e	mal__D_e	mal__L_e	malt_e	man_e	manur_e	mcbtt_e	melib_e	meoh_e	met__D_e	met__L_e	mg2_e	mmet_e	mn2_e	mobd_e	mso3_e	mtsoxin_e	n2one_e	na1_e	nac_e	nadp_e	nh4_e	ni2_e	nmn_e	no2_e	no3_e	no_e	nona_e	o2_e	o_xyl_e	oaa_e	ocdca_e	ocdcea_e	ocdcya_e	octa_e	orn__D_e	orn_e	orot_e	oxa_e	p_xyl_e	pac_e	pacald_e	pap_e	pb2_e	pc_SC_e	pea_e	peamn_e	pectin_e	pentso3_e	pepd_e	phe__D_e	phe__L_e	pheac_e	phedca_e	phehpa_e	phehxa_e	pheme_e	phenona_e	pheocta_e	phept_e	phpyr_e	pi_e	pnto__R_e	ppa_e	ppi_e	pptrn_e	prealg_MG_14_e	prealg_MG_23_e	prealg_MG_32_e	prealg_MG_41_e	prealginate_G_e	pro__D_e	pro__L_e	progly_e	pta_e	ptd1ino_SC_e	ptrc_e	ptsla_e	pydam_e	pyovd_e	pyovd_kt_e	pyr_e	quin_e	rib__D_e	ribflv_e	sbo3_e	sbt__D_e	sbt__L_e	sel_e	ser__D_e	ser__L_e	sheme_e	skm_e	so2_e	so3_e	so4_e	spmd_e	sprm_e	srb__L_e	succ_e	sucr_e	sulfac_e	tag160_e	tag180_e	tag181d9_e	tag182d9d12_e	taur_e	tcynt_e	thm_e	thmmp_e	thmpp_e	thr__L_e	thym_e	thymd_e	tmanur_e	tnt_e	tol_e	tre_e	trp__L_e	tsul_e	ttdca_e	ttdcea_e	ttrcyc_e	tungs_e	tyr__D_e	tyr__L_e	und2one_e	ura_e	urea_e	uri_e	vacc_e	val__D_e	val__L_e	vanln_e	vanlt_e	xan_e	xtsn_e	xyl__D_e	xylt_e	zn2_e	zymst_e	zymstest_SC_e
# Cycle 1
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# FBARunThread-0 starting up.
# FBARunThread-1 starting up.
# FBARunThread-2 starting up.
# Total biomass:
# Model iMM904.cmd: 1.5698875152129714E-7
# Model iJN1463.cmd: 1.5566666345767603E-8
# Cycle 2
# Total biomass:
# Model iMM904.cmd: 1.6435126972053145E-7
# Model iJN1463.cmd: 1.615949482451094E-8
# Cycle 3
# Total biomass:
# Model iMM904.cmd: 1.729454239507506E-7
# Model iJN1463.cmd: 1.6868464753409732E-8
# Cycle 4
# Total biomass:
# Model iMM904.cmd: 1.8228743027995648E-7
# Model iJN1463.cmd: 1.7641387721918074E-8
# Cycle 5
# Total biomass:
# Model iMM904.cmd: 1.923743580767001E-7
# Model iJN1463.cmd: 1.8463468628217726E-8
# Cycle 6
# Total biomass:
# Model iMM904.cmd: 2.0325848175602418E-7
# Model iJN1463.cmd: 1.9332661412999163E-8
# Cycle 7
# Total biomass:
# Model iMM904.cmd: 2.14970318484893E-7
# Model iJN1463.cmd: 2.0250559405181313E-8
# Cycle 8
# Total biomass:
# Model iMM904.cmd: 2.2753514406055685E-7
# Model iJN1463.cmd: 2.1220181985679326E-8
# Cycle 9
# Total biomass:
# Model iMM904.cmd: 2.409369454878996E-7
# Model iJN1463.cmd: 2.2243369388706015E-8
# Cycle 10
# Total biomass:
# Model iMM904.cmd: 2.55199118464368E-7
# Model iJN1463.cmd: 2.3322243885031345E-8
# Cycle 11
# Total biomass:
# Model iMM904.cmd: 2.703711606790589E-7
# Model iJN1463.cmd: 2.4459662228552386E-8
# Cycle 12
# Total biomass:
# Model iMM904.cmd: 2.865112094058102E-7
# Model iJN1463.cmd: 2.565878824221394E-8
# Cycle 13
# Total biomass:
# Model iMM904.cmd: 3.03680771581648E-7
# Model iJN1463.cmd: 2.6922950672061616E-8
# Cycle 14
# Total biomass:
# Model iMM904.cmd: 3.21945279249272E-7
# Model iJN1463.cmd: 2.8255655432885076E-8
# Cycle 15
# Total biomass:
# Model iMM904.cmd: 3.4137745166119743E-7
# Model iJN1463.cmd: 2.9660585518257456E-8
# Cycle 16
# Total biomass:
# Model iMM904.cmd: 3.620510239005504E-7
# Model iJN1463.cmd: 3.1141625586741514E-8
# Cycle 17
# Total biomass:
# Model iMM904.cmd: 3.8404417051147013E-7
# Model iJN1463.cmd: 3.270286683334294E-8
# Cycle 18
# Total biomass:
# Model iMM904.cmd: 4.074399921463654E-7
# Model iJN1463.cmd: 3.4348618601740963E-8
# Cycle 19
# Total biomass:
# Model iMM904.cmd: 4.3232685395498886E-7
# Model iJN1463.cmd: 3.608342067640707E-8
# Cycle 20
# Total biomass:
# Model iMM904.cmd: 4.587987056172982E-7
# Model iJN1463.cmd: 3.791205608971047E-8
# Cycle 21
# Total biomass:
# Model iMM904.cmd: 4.869554263202356E-7
# Model iJN1463.cmd: 3.9839564499355395E-8
# Cycle 22
# Total biomass:
# Model iMM904.cmd: 5.169031941616649E-7
# Model iJN1463.cmd: 4.187125620468277E-8
# Cycle 23
# Total biomass:
# Model iMM904.cmd: 5.487548715753675E-7
# Model iJN1463.cmd: 4.401272686023581E-8
# Cycle 24
# Total biomass:
# Model iMM904.cmd: 5.826526745443554E-7
# Model iJN1463.cmd: 4.6269872898248353E-8
# Cycle 25
# Total biomass:
# Model iMM904.cmd: 6.18701636272705E-7
# Model iJN1463.cmd: 4.864890789833223E-8
# Cycle 26
# Total biomass:
# Model iMM904.cmd: 6.570894860693495E-7
# Model iJN1463.cmd: 5.1156379611238546E-8
# Cycle 27
# Total biomass:
# Model iMM904.cmd: 6.979183375839856E-7
# Model iJN1463.cmd: 5.3799188051332286E-8
# Cycle 28
# Total biomass:
# Model iMM904.cmd: 7.412716192037747E-7
# Model iJN1463.cmd: 5.658363335719537E-8
# Cycle 29
# Total biomass:
# Model iMM904.cmd: 7.864976543245078E-7
# Model iJN1463.cmd: 5.950992232474831E-8
# Cycle 30
# Total biomass:
# Model iMM904.cmd: 8.326212585379593E-7
# Model iJN1463.cmd: 6.25831267692209E-8
# Cycle 31
# Total biomass:
# Model iMM904.cmd: 8.79664623084665E-7
# Model iJN1463.cmd: 6.58948437890262E-8
# Cycle 32
# Total biomass:
# Model iMM904.cmd: 9.277245530027031E-7
# Model iJN1463.cmd: 6.938485885911869E-8
# Cycle 33
# Total biomass:
# Model iMM904.cmd: 9.769852609761083E-7
# Model iJN1463.cmd: 7.306205762570017E-8
# Cycle 34
# Total biomass:
# Model iMM904.cmd: 1.0279156026531037E-6
# Model iJN1463.cmd: 7.693556932608202E-8
# Cycle 35
# Total biomass:
# Model iMM904.cmd: 1.080355369817209E-6
# Model iJN1463.cmd: 8.101472910357407E-8
# Cycle 36
# Total biomass:
# Model iMM904.cmd: 1.1343809297860693E-6
# Model iJN1463.cmd: 8.530899686346578E-8
# Cycle 37
# Total biomass:
# Model iMM904.cmd: 1.1901153252137547E-6
# Model iJN1463.cmd: 8.982783683155093E-8
# Cycle 38
# Total biomass:
# Model iMM904.cmd: 1.2476133336411905E-6
# Model iJN1463.cmd: 9.458053145868242E-8
# Cycle 39
# Total biomass:
# Model iMM904.cmd: 1.306806854839062E-6
# Model iJN1463.cmd: 9.957585422747901E-8
# Cycle 40
# Total biomass:
# Model iMM904.cmd: 1.3672926850948243E-6
# Model iJN1463.cmd: 1.0482651425188924E-7
# Cycle 41
# Total biomass:
# Model iMM904.cmd: 1.4289745306203046E-6
# Model iJN1463.cmd: 1.1036670487859821E-7
# Cycle 42
# Total biomass:
# Model iMM904.cmd: 1.4910725649841305E-6
# Model iJN1463.cmd: 1.1619833786609076E-7
# Cycle 43
# Total biomass:
# Model iMM904.cmd: 1.5531396244745101E-6
# Model iJN1463.cmd: 1.223545006373949E-7
# Cycle 44
# Total biomass:
# Model iMM904.cmd: 1.6155803814222403E-6
# Model iJN1463.cmd: 1.2903184236956063E-7
# Cycle 45
# Total biomass:
# Model iMM904.cmd: 1.6787825232658611E-6
# Model iJN1463.cmd: 1.3608164712841398E-7
# Cycle 46
# Total biomass:
# Model iMM904.cmd: 1.7429259441799466E-6
# Model iJN1463.cmd: 1.4345739490183782E-7
# Cycle 47
# Total biomass:
# Model iMM904.cmd: 1.8080292313818024E-6
# Model iJN1463.cmd: 1.5168047019486912E-7
# Cycle 48
# Total biomass:
# Model iMM904.cmd: 1.8741326719157839E-6
# Model iJN1463.cmd: 1.6029962722838517E-7
# Cycle 49
# Total biomass:
# Model iMM904.cmd: 1.9414380914975543E-6
# Model iJN1463.cmd: 1.693141002601379E-7
# Cycle 50
# Total biomass:
# Model iMM904.cmd: 2.01028877636494E-6
# Model iJN1463.cmd: 1.7877258833743373E-7
# Cycle 51
# Total biomass:
# Model iMM904.cmd: 2.0809693146159547E-6
# Model iJN1463.cmd: 1.887119906303215E-7
# Cycle 52
# Total biomass:
# Model iMM904.cmd: 2.1538199694781547E-6
# Model iJN1463.cmd: 1.991694742586932E-7
# Cycle 53
# Total biomass:
# Model iMM904.cmd: 2.229047381793507E-6
# Model iJN1463.cmd: 2.101843965540768E-7
# Cycle 54
# Total biomass:
# Model iMM904.cmd: 2.3067971273961945E-6
# Model iJN1463.cmd: 2.2178859390414124E-7
# Cycle 55
# Total biomass:
# Model iMM904.cmd: 2.3872194288349445E-6
# Model iJN1463.cmd: 2.340184882617138E-7
# Cycle 56
# Total biomass:
# Model iMM904.cmd: 2.4703218697207915E-6
# Model iJN1463.cmd: 2.469171955505322E-7
# Cycle 57
# Total biomass:
# Model iMM904.cmd: 2.556185387744515E-6
# Model iJN1463.cmd: 2.6052357115609604E-7
# Cycle 58
# Total biomass:
# Model iMM904.cmd: 2.644805323998875E-6
# Model iJN1463.cmd: 2.748606166615069E-7
# Cycle 59
# Total biomass:
# Model iMM904.cmd: 2.7361669346341662E-6
# Model iJN1463.cmd: 2.8996963553181884E-7
# Cycle 60
# Total biomass:
# Model iMM904.cmd: 2.830287278710168E-6
# Model iJN1463.cmd: 3.05910074961457E-7
# Cycle 61
# Total biomass:
# Model iMM904.cmd: 2.927089504680747E-6
# Model iJN1463.cmd: 3.226912350691194E-7
# Cycle 62
# Total biomass:
# Model iMM904.cmd: 3.0265854963466858E-6
# Model iJN1463.cmd: 3.403653336357316E-7
# Cycle 63
# Total biomass:
# Model iMM904.cmd: 3.1289171581224153E-6
# Model iJN1463.cmd: 3.589738578844453E-7
# Cycle 64
# Total biomass:
# Model iMM904.cmd: 3.2343503603458845E-6
# Model iJN1463.cmd: 3.785809084943851E-7
# Cycle 65
# Total biomass:
# Model iMM904.cmd: 3.342823793545272E-6
# Model iJN1463.cmd: 3.992141251736279E-7
# Cycle 66
# Total biomass:
# Model iMM904.cmd: 3.4543075772023028E-6
# Model iJN1463.cmd: 4.2092247146744435E-7
# Cycle 67
# Total biomass:
# Model iMM904.cmd: 3.568717420114698E-6
# Model iJN1463.cmd: 4.437400585680027E-7
# Cycle 68
# Total biomass:
# Model iMM904.cmd: 3.6857811602852356E-6
# Model iJN1463.cmd: 4.6769546918988145E-7
# Cycle 69
# Total biomass:
# Model iMM904.cmd: 3.8052276003041303E-6
# Model iJN1463.cmd: 4.928594688692772E-7
# Cycle 70
# Total biomass:
# Model iMM904.cmd: 3.927560366598549E-6
# Model iJN1463.cmd: 5.192873797689679E-7
# Cycle 71
# Total biomass:
# Model iMM904.cmd: 4.052908245019182E-6
# Model iJN1463.cmd: 5.470408990651274E-7
# Cycle 72
# Total biomass:
# Model iMM904.cmd: 4.180853271861898E-6
# Model iJN1463.cmd: 5.762392429581642E-7
# Cycle 73
# Total biomass:
# Model iMM904.cmd: 4.311994158205855E-6
# Model iJN1463.cmd: 6.069288104205768E-7
# Cycle 74
# Total biomass:
# Model iMM904.cmd: 4.446547646101624E-6
# Model iJN1463.cmd: 6.391917829645474E-7
# Cycle 75
# Total biomass:
# Model iMM904.cmd: 4.5848250880478075E-6
# Model iJN1463.cmd: 6.73150392949085E-7
# Cycle 76
# Total biomass:
# Model iMM904.cmd: 4.727075713515211E-6
# Model iJN1463.cmd: 7.089096569619651E-7
# Cycle 77
# Total biomass:
# Model iMM904.cmd: 4.873469645219458E-6
# Model iJN1463.cmd: 7.465473348996313E-7
# Cycle 78
# Total biomass:
# Model iMM904.cmd: 5.024093381691941E-6
# Model iJN1463.cmd: 7.861916771430816E-7
# Cycle 79
# Total biomass:
# Model iMM904.cmd: 5.179048508196448E-6
# Model iJN1463.cmd: 8.27925756471052E-7
# Cycle 80
# Total biomass:
# Model iMM904.cmd: 5.338408192419637E-6
# Model iJN1463.cmd: 8.719113998188767E-7
# Cycle 81
# Total biomass:
# Model iMM904.cmd: 5.502234013432931E-6
# Model iJN1463.cmd: 9.18275800602349E-7
# Cycle 82
# Total biomass:
# Model iMM904.cmd: 5.6706434109354065E-6
# Model iJN1463.cmd: 9.669986428143283E-7
# Cycle 83
# Total biomass:
# Model iMM904.cmd: 5.843721258628578E-6
# Model iJN1463.cmd: 1.0181740144187356E-6
# Cycle 84
# Total biomass:
# Model iMM904.cmd: 6.021645292048296E-6
# Model iJN1463.cmd: 1.0720323593171167E-6
# Cycle 85
# Total biomass:
# Model iMM904.cmd: 6.204600470416248E-6
# Model iJN1463.cmd: 1.1284654092507673E-6
# Cycle 86
# Total biomass:
# Model iMM904.cmd: 6.392830201123772E-6
# Model iJN1463.cmd: 1.1876022003079183E-6
# Cycle 87
# Total biomass:
# Model iMM904.cmd: 6.586467479836555E-6
# Model iJN1463.cmd: 1.2495546639659037E-6
# Cycle 88
# Total biomass:
# Model iMM904.cmd: 6.78566986575642E-6
# Model iJN1463.cmd: 1.314355470305619E-6
# Cycle 89
# Total biomass:
# Model iMM904.cmd: 6.990529556864189E-6
# Model iJN1463.cmd: 1.3822576830933255E-6
# Cycle 90
# Total biomass:
# Model iMM904.cmd: 7.201187889188273E-6
# Model iJN1463.cmd: 1.4535150976821325E-6
# Cycle 91
# Total biomass:
# Model iMM904.cmd: 7.417795785827664E-6
# Model iJN1463.cmd: 1.5282354278809491E-6
# Cycle 92
# Total biomass:
# Model iMM904.cmd: 7.640501379230959E-6
# Model iJN1463.cmd: 1.6064759038585703E-6
# Cycle 93
# Total biomass:
# Model iMM904.cmd: 7.86944911105317E-6
# Model iJN1463.cmd: 1.6883205039780403E-6
# Cycle 94
# Total biomass:
# Model iMM904.cmd: 8.104820238449609E-6
# Model iJN1463.cmd: 1.7740075806272053E-6
# Cycle 95
# Total biomass:
# Model iMM904.cmd: 8.346647524714642E-6
# Model iJN1463.cmd: 1.863861342167496E-6
# Cycle 96
# Total biomass:
# Model iMM904.cmd: 8.594645228266716E-6
# Model iJN1463.cmd: 1.958073961264028E-6
# Cycle 97
# Total biomass:
# Model iMM904.cmd: 8.849486710709045E-6
# Model iJN1463.cmd: 2.056800113687491E-6
# Cycle 98
# Total biomass:
# Model iMM904.cmd: 9.111944727732965E-6
# Model iJN1463.cmd: 2.1603917371926344E-6
# Cycle 99
# Total biomass:
# Model iMM904.cmd: 9.381809151312524E-6
# Model iJN1463.cmd: 2.269081420477428E-6
# Cycle 100
# Total biomass:
# Model iMM904.cmd: 9.659300181838256E-6
# Model iJN1463.cmd: 2.383154093476408E-6
# Cycle 101
# Total biomass:
# Model iMM904.cmd: 9.94489146833495E-6
# Model iJN1463.cmd: 2.502885984637036E-6
# Cycle 102
# Total biomass:
# Model iMM904.cmd: 1.0238588994830308E-5
# Model iJN1463.cmd: 2.6285550126572954E-6
# Cycle 103
# Total biomass:
# Model iMM904.cmd: 1.054062336770807E-5
# Model iJN1463.cmd: 2.760424883321197E-6
# Cycle 104
# Total biomass:
# Model iMM904.cmd: 1.0851256313246432E-5
# Model iJN1463.cmd: 2.8989304694547044E-6
# Cycle 105
# Total biomass:
# Model iMM904.cmd: 1.1170269817774307E-5
# Model iJN1463.cmd: 3.0442071880723195E-6
# Cycle 106
# Total biomass:
# Model iMM904.cmd: 1.1498151606189051E-5
# Model iJN1463.cmd: 3.1952156534938078E-6
# Cycle 107
# Total biomass:
# Model iMM904.cmd: 1.1836073668225201E-5
# Model iJN1463.cmd: 3.3539696392311854E-6
# Cycle 108
# Total biomass:
# Model iMM904.cmd: 1.2183759060216973E-5
# Model iJN1463.cmd: 3.5205648823430916E-6
# Cycle 109
# Total biomass:
# Model iMM904.cmd: 1.2540918628310119E-5
# Model iJN1463.cmd: 3.6950471386296965E-6
# Cycle 110
# Total biomass:
# Model iMM904.cmd: 1.2907905364167053E-5
# Model iJN1463.cmd: 3.877809596978573E-6
# Cycle 111
# Total biomass:
# Model iMM904.cmd: 1.328416625590101E-5
# Model iJN1463.cmd: 4.069368420036811E-6
# Cycle 112
# Total biomass:
# Model iMM904.cmd: 1.3668070458315711E-5
# Model iJN1463.cmd: 4.269979219746615E-6
# Cycle 113
# Total biomass:
# Model iMM904.cmd: 1.4058737115461656E-5
# Model iJN1463.cmd: 4.4805135539338725E-6
# Cycle 114
# Total biomass:
# Model iMM904.cmd: 1.4456326962732085E-5
# Model iJN1463.cmd: 4.701743253654346E-6
# Cycle 115
# Total biomass:
# Model iMM904.cmd: 1.485820624795806E-5
# Model iJN1463.cmd: 4.933634859115885E-6
# Cycle 116
# Total biomass:
# Model iMM904.cmd: 1.5262284795009523E-5
# Model iJN1463.cmd: 5.176634170423021E-6
# Cycle 117
# Total biomass:
# Model iMM904.cmd: 1.5661091826023003E-5
# Model iJN1463.cmd: 5.430250242172142E-6
# Cycle 118
# Total biomass:
# Model iMM904.cmd: 1.604908363202206E-5
# Model iJN1463.cmd: 5.693607743890481E-6
# Cycle 119
# Total biomass:
# Model iMM904.cmd: 1.64228807540287E-5
# Model iJN1463.cmd: 5.967687631948039E-6
# Cycle 120
# Total biomass:
# Model iMM904.cmd: 1.6781531270582097E-5
# Model iJN1463.cmd: 6.253553921260493E-6
# Cycle 121
# Total biomass:
# Model iMM904.cmd: 1.7122433358326366E-5
# Model iJN1463.cmd: 6.550711722470009E-6
# Cycle 122
# Total biomass:
# Model iMM904.cmd: 1.7443687795278013E-5
# Model iJN1463.cmd: 6.8583859837893025E-6
# Cycle 123
# Total biomass:
# Model iMM904.cmd: 1.774242096210022E-5
# Model iJN1463.cmd: 7.176747580107304E-6
# Cycle 124
# Total biomass:
# Model iMM904.cmd: 1.8013312101007068E-5
# Model iJN1463.cmd: 7.505866256891129E-6
# Cycle 125
# Total biomass:
# Model iMM904.cmd: 1.8257390824409516E-5
# Model iJN1463.cmd: 7.845998422213978E-6
# Cycle 126
# Total biomass:
# Model iMM904.cmd: 1.8475309597735773E-5
# Model iJN1463.cmd: 8.195704388562967E-6
# Cycle 127
# Total biomass:
# Model iMM904.cmd: 1.8671109158067674E-5
# Model iJN1463.cmd: 8.554053391849386E-6
# Cycle 128
# Total biomass:
# Model iMM904.cmd: 1.884733861752845E-5
# Model iJN1463.cmd: 8.920642357959355E-6
# Cycle 129
# Total biomass:
# Model iMM904.cmd: 1.9005644657362697E-5
# Model iJN1463.cmd: 9.29551437515907E-6
# Cycle 130
# Total biomass:
# Model iMM904.cmd: 1.9149899876544014E-5
# Model iJN1463.cmd: 9.676780836848152E-6
# Cycle 131
# Total biomass:
# Model iMM904.cmd: 1.9283935010130618E-5
# Model iJN1463.cmd: 1.0063421640999234E-5
# Cycle 132
# Total biomass:
# Model iMM904.cmd: 1.941011669413035E-5
# Model iJN1463.cmd: 1.0450148056925472E-5
# Cycle 133
# Total biomass:
# Model iMM904.cmd: 1.953010043903906E-5
# Model iJN1463.cmd: 1.0832800733214876E-5
# Cycle 134
# Total biomass:
# Model iMM904.cmd: 1.9645294667807437E-5
# Model iJN1463.cmd: 1.1207942072025849E-5
# Cycle 135
# Total biomass:
# Model iMM904.cmd: 1.9756401805604466E-5
# Model iJN1463.cmd: 1.1574563487793674E-5
# Cycle 136
# Total biomass:
# Model iMM904.cmd: 1.9865392562912814E-5
# Model iJN1463.cmd: 1.1929886542328995E-5
# Cycle 137
# Total biomass:
# Model iMM904.cmd: 1.9972308317571267E-5
# Model iJN1463.cmd: 1.2271618146974327E-5
# Cycle 138
# Total biomass:
# Model iMM904.cmd: 2.007713369502756E-5
# Model iJN1463.cmd: 1.2599672836242651E-5
# Cycle 139
# Total biomass:
# Model iMM904.cmd: 2.018098399965138E-5
# Model iJN1463.cmd: 1.2912020910952016E-5
# Cycle 140
# Total biomass:
# Model iMM904.cmd: 2.0283675248639348E-5
# Model iJN1463.cmd: 1.3204226875986604E-5
# Cycle 141
# Total biomass:
# Model iMM904.cmd: 2.0385401594291715E-5
# Model iJN1463.cmd: 1.3466003259907284E-5
# Cycle 142
# Total biomass:
# Model iMM904.cmd: 2.0486969878611278E-5
# Model iJN1463.cmd: 1.3698291025789754E-5
# Cycle 143
# Total biomass:
# Model iMM904.cmd: 2.058817053319042E-5
# Model iJN1463.cmd: 1.390496303040617E-5
# Cycle 144
# Total biomass:
# Model iMM904.cmd: 2.068913014877478E-5
# Model iJN1463.cmd: 1.408853232997885E-5
# Cycle 145
# Total biomass:
# Model iMM904.cmd: 2.078940822843187E-5
# Model iJN1463.cmd: 1.4253439308691715E-5
# Cycle 146
# Total biomass:
# Model iMM904.cmd: 2.0889036559736666E-5
# Model iJN1463.cmd: 1.440320171974024E-5
# Cycle 147
# Total biomass:
# Model iMM904.cmd: 2.098835299301891E-5
# Model iJN1463.cmd: 1.454097053432767E-5
# Cycle 148
# Total biomass:
# Model iMM904.cmd: 2.1087006794522125E-5
# Model iJN1463.cmd: 1.466944117656248E-5
# Cycle 149
# Total biomass:
# Model iMM904.cmd: 2.118509094547617E-5
# Model iJN1463.cmd: 1.4791982310899546E-5
# Cycle 150
# Total biomass:
# Model iMM904.cmd: 2.1283245929319616E-5
# Model iJN1463.cmd: 1.4910231436142362E-5
# Cycle 151
# Total biomass:
# Model iMM904.cmd: 2.1381110721564317E-5
# Model iJN1463.cmd: 1.5026057389447556E-5
# Cycle 152
# Total biomass:
# Model iMM904.cmd: 2.1478630704138716E-5
# Model iJN1463.cmd: 1.5140408170904432E-5
# Cycle 153
# Total biomass:
# Model iMM904.cmd: 2.1574503235487743E-5
# Model iJN1463.cmd: 1.5254121022134852E-5
# Cycle 154
# Total biomass:
# Model iMM904.cmd: 2.1669954522935348E-5
# Model iJN1463.cmd: 1.536643990270976E-5
# Cycle 155
# Total biomass:
# Model iMM904.cmd: 2.1764419833816966E-5
# Model iJN1463.cmd: 1.547913832058424E-5
# Cycle 156
# Total biomass:
# Model iMM904.cmd: 2.185742600407714E-5
# Model iJN1463.cmd: 1.559247354894912E-5
# Cycle 157
# Total biomass:
# Model iMM904.cmd: 2.1950425756310617E-5
# Model iJN1463.cmd: 1.5704761221535E-5
# Cycle 158
# Total biomass:
# Model iMM904.cmd: 2.2042495291267252E-5
# Model iJN1463.cmd: 1.5816571495233236E-5
# Cycle 159
# Total biomass:
# Model iMM904.cmd: 2.213449560952668E-5
# Model iJN1463.cmd: 1.5928679153348666E-5
# Cycle 160
# Total biomass:
# Model iMM904.cmd: 2.222522239946182E-5
# Model iJN1463.cmd: 1.604181957062182E-5
# Cycle 161
# Total biomass:
# Model iMM904.cmd: 2.2315518980219106E-5
# Model iJN1463.cmd: 1.6154724966151565E-5
# Cycle 162
# Total biomass:
# Model iMM904.cmd: 2.2404475375402533E-5
# Model iJN1463.cmd: 1.6268764681759076E-5
# Cycle 163
# Total biomass:
# Model iMM904.cmd: 2.2492612322292135E-5
# Model iJN1463.cmd: 1.638263559336207E-5
# Cycle 164
# Total biomass:
# Model iMM904.cmd: 2.257935678581609E-5
# Model iJN1463.cmd: 1.649762202727501E-5
# Cycle 165
# Total biomass:
# Model iMM904.cmd: 2.2665454736371755E-5
# Model iJN1463.cmd: 1.6613544058842837E-5
# Cycle 166
# Total biomass:
# Model iMM904.cmd: 2.2750830836959755E-5
# Model iJN1463.cmd: 1.672974669901946E-5
# Cycle 167
# Total biomass:
# Model iMM904.cmd: 2.283673021416637E-5
# Model iJN1463.cmd: 1.6845870897073487E-5
# Cycle 168
# Total biomass:
# Model iMM904.cmd: 2.2921991821898194E-5
# Model iJN1463.cmd: 1.696245037331131E-5
# Cycle 169
# Total biomass:
# Model iMM904.cmd: 2.3007984766604337E-5
# Model iJN1463.cmd: 1.707841786026251E-5
# Cycle 170
# Total biomass:
# Model iMM904.cmd: 2.309328263866421E-5
# Model iJN1463.cmd: 1.719520882580011E-5
# Cycle 171
# Total biomass:
# Model iMM904.cmd: 2.3178171420268345E-5
# Model iJN1463.cmd: 1.731213248855569E-5
# Cycle 172
# Total biomass:
# Model iMM904.cmd: 2.3263007453384942E-5
# Model iJN1463.cmd: 1.7428759699699246E-5
# Cycle 173
# Total biomass:
# Model iMM904.cmd: 2.3347222416659016E-5
# Model iJN1463.cmd: 1.7546359432215878E-5
# Cycle 174
# Total biomass:
# Model iMM904.cmd: 2.34312259328479E-5
# Model iJN1463.cmd: 1.7664263804974765E-5
# Cycle 175
# Total biomass:
# Model iMM904.cmd: 2.351486168105987E-5
# Model iJN1463.cmd: 1.778264565626295E-5
# Cycle 176
# Total biomass:
# Model iMM904.cmd: 2.359822503516532E-5
# Model iJN1463.cmd: 1.790018526889577E-5
# Cycle 177
# Total biomass:
# Model iMM904.cmd: 2.368192466934174E-5
# Model iJN1463.cmd: 1.8018155014999995E-5
# Cycle 178
# Total biomass:
# Model iMM904.cmd: 2.3763595678318804E-5
# Model iJN1463.cmd: 1.8137741195685783E-5
# Cycle 179
# Total biomass:
# Model iMM904.cmd: 2.3846883798651842E-5
# Model iJN1463.cmd: 1.8255830843410632E-5
# Cycle 180
# Total biomass:
# Model iMM904.cmd: 2.3930420390726322E-5
# Model iJN1463.cmd: 1.8372976379747807E-5
# Cycle 181
# Total biomass:
# Model iMM904.cmd: 2.4014251229010757E-5
# Model iJN1463.cmd: 1.8489994786820727E-5
# Cycle 182
# Total biomass:
# Model iMM904.cmd: 2.4097619418271703E-5
# Model iJN1463.cmd: 1.860749850430198E-5
# Cycle 183
# Total biomass:
# Model iMM904.cmd: 2.4181334639493237E-5
# Model iJN1463.cmd: 1.8723428577996182E-5
# Cycle 184
# Total biomass:
# Model iMM904.cmd: 2.4263674583963377E-5
# Model iJN1463.cmd: 1.8840099737361734E-5
# Cycle 185
# Total biomass:
# Model iMM904.cmd: 2.434586885940975E-5
# Model iJN1463.cmd: 1.8956463874568477E-5
# Cycle 186
# Total biomass:
# Model iMM904.cmd: 2.44276250126064E-5
# Model iJN1463.cmd: 1.9072804867623856E-5
# Cycle 187
# Total biomass:
# Model iMM904.cmd: 2.4508450069413568E-5
# Model iJN1463.cmd: 1.91897383896698E-5
# Cycle 188
# Total biomass:
# Model iMM904.cmd: 2.4587977016257194E-5
# Model iJN1463.cmd: 1.9307777107667583E-5
# Cycle 189
# Total biomass:
# Model iMM904.cmd: 2.4666110462295283E-5
# Model iJN1463.cmd: 1.9426967168170025E-5
# Cycle 190
# Total biomass:
# Model iMM904.cmd: 2.474518242425976E-5
# Model iJN1463.cmd: 1.954487484986229E-5
# Cycle 191
# Total biomass:
# Model iMM904.cmd: 2.4824382118861013E-5
# Model iJN1463.cmd: 1.96631054854032E-5
# Cycle 192
# Total biomass:
# Model iMM904.cmd: 2.4905000417922942E-5
# Model iJN1463.cmd: 1.9780156407527457E-5
# Cycle 193
# Total biomass:
# Model iMM904.cmd: 2.498439104264768E-5
# Model iJN1463.cmd: 1.989755348529896E-5
# Cycle 194
# Total biomass:
# Model iMM904.cmd: 2.506369290932476E-5
# Model iJN1463.cmd: 2.0016138729938E-5
# Cycle 195
# Total biomass:
# Model iMM904.cmd: 2.5142551374878295E-5
# Model iJN1463.cmd: 2.0134593214380542E-5
# Cycle 196
# Total biomass:
# Model iMM904.cmd: 2.5219401336514064E-5
# Model iJN1463.cmd: 2.0255131955794543E-5
# Cycle 197
# Total biomass:
# Model iMM904.cmd: 2.529552063210946E-5
# Model iJN1463.cmd: 2.0375401003524464E-5
# Cycle 198
# Total biomass:
# Model iMM904.cmd: 2.537190106678235E-5
# Model iJN1463.cmd: 2.0494968998294765E-5
# Cycle 199
# Total biomass:
# Model iMM904.cmd: 2.5447587457516486E-5
# Model iJN1463.cmd: 2.0614787220398412E-5
# Cycle 200
# Total biomass:
# Model iMM904.cmd: 2.5524207242973682E-5
# Model iJN1463.cmd: 2.0733040208533243E-5
# Cycle 201
# Total biomass:
# Model iMM904.cmd: 2.5599228488003295E-5
# Model iJN1463.cmd: 2.084946782861766E-5
# Cycle 202
# Total biomass:
# Model iMM904.cmd: 2.5673408161996145E-5
# Model iJN1463.cmd: 2.0967602273796415E-5
# Cycle 203
# Total biomass:
# Model iMM904.cmd: 2.5747620428848246E-5
# Model iJN1463.cmd: 2.1087072665667706E-5
# Cycle 204
# Total biomass:
# Model iMM904.cmd: 2.5822657440031097E-5
# Model iJN1463.cmd: 2.1205447939351262E-5
# Cycle 205
# Total biomass:
# Model iMM904.cmd: 2.5895799061213717E-5
# Model iJN1463.cmd: 2.132542033451767E-5
# Cycle 206
# Total biomass:
# Model iMM904.cmd: 2.5970987071967518E-5
# Model iJN1463.cmd: 2.1443947112864692E-5
# Cycle 207
# Total biomass:
# Model iMM904.cmd: 2.604263856786878E-5
# Model iJN1463.cmd: 2.156612809543151E-5
# Cycle 208
# Total biomass:
# Model iMM904.cmd: 2.611655232335609E-5
# Model iJN1463.cmd: 2.168511929586861E-5
# Cycle 209
# Total biomass:
# Model iMM904.cmd: 2.6187788943925325E-5
# Model iJN1463.cmd: 2.1806011332975493E-5
# Cycle 210
# Total biomass:
# Model iMM904.cmd: 2.6260153616709518E-5
# Model iJN1463.cmd: 2.1926129939099943E-5
# Cycle 211
# Total biomass:
# Model iMM904.cmd: 2.6331839682840856E-5
# Model iJN1463.cmd: 2.2042565348020416E-5
# Cycle 212
# Total biomass:
# Model iMM904.cmd: 2.640346324520915E-5
# Model iJN1463.cmd: 2.2162453246909025E-5
# Cycle 213
# Total biomass:
# Model iMM904.cmd: 2.647456937929016E-5
# Model iJN1463.cmd: 2.228341833286961E-5
# Cycle 214
# Total biomass:
# Model iMM904.cmd: 2.654721298420788E-5
# Model iJN1463.cmd: 2.2403517726504238E-5
# Cycle 215
# Total biomass:
# Model iMM904.cmd: 2.6618799711908845E-5
# Model iJN1463.cmd: 2.2524952804523566E-5
# Cycle 216
# Total biomass:
# Model iMM904.cmd: 2.6690299229925025E-5
# Model iJN1463.cmd: 2.2646272582404276E-5
# Cycle 217
# Total biomass:
# Model iMM904.cmd: 2.67641772518531E-5
# Model iJN1463.cmd: 2.2765193379238966E-5
# Cycle 218
# Total biomass:
# Model iMM904.cmd: 2.683646300956852E-5
# Model iJN1463.cmd: 2.2884440780649596E-5
# Cycle 219
# Total biomass:
# Model iMM904.cmd: 2.6906479414389778E-5
# Model iJN1463.cmd: 2.3004918549667415E-5
# Cycle 220
# Total biomass:
# Model iMM904.cmd: 2.6979908351035194E-5
# Model iJN1463.cmd: 2.3123670401518935E-5
# Cycle 221
# Total biomass:
# Model iMM904.cmd: 2.7052738508908325E-5
# Model iJN1463.cmd: 2.324635475424728E-5
# Cycle 222
# Total biomass:
# Model iMM904.cmd: 2.712367975317465E-5
# Model iJN1463.cmd: 2.3366593170436197E-5
# Cycle 223
# Total biomass:
# Model iMM904.cmd: 2.7196250724399536E-5
# Model iJN1463.cmd: 2.3484032884048523E-5
# Cycle 224
# Total biomass:
# Model iMM904.cmd: 2.726718397503244E-5
# Model iJN1463.cmd: 2.360276464357913E-5
# Cycle 225
# Total biomass:
# Model iMM904.cmd: 2.7337431761777426E-5
# Model iJN1463.cmd: 2.372287999039562E-5
# Cycle 226
# Total biomass:
# Model iMM904.cmd: 2.7409895183350954E-5
# Model iJN1463.cmd: 2.3840185410837337E-5
# Cycle 227
# Total biomass:
# Model iMM904.cmd: 2.748103624194862E-5
# Model iJN1463.cmd: 2.395722744939658E-5
# Cycle 228
# Total biomass:
# Model iMM904.cmd: 2.7551550461861644E-5
# Model iJN1463.cmd: 2.4074223052239016E-5
# Cycle 229
# Total biomass:
# Model iMM904.cmd: 2.7622343243224392E-5
# Model iJN1463.cmd: 2.4190594412502486E-5
# Cycle 230
# Total biomass:
# Model iMM904.cmd: 2.7692307263389E-5
# Model iJN1463.cmd: 2.4307729068772804E-5
# Cycle 231
# Total biomass:
# Model iMM904.cmd: 2.7758977389211904E-5
# Model iJN1463.cmd: 2.442856390570985E-5
# Cycle 232
# Total biomass:
# Model iMM904.cmd: 2.782819357881686E-5
# Model iJN1463.cmd: 2.4548331781150333E-5
# Cycle 233
# Total biomass:
# Model iMM904.cmd: 2.7895063856811047E-5
# Model iJN1463.cmd: 2.4669347009312022E-5
# Cycle 234
# Total biomass:
# Model iMM904.cmd: 2.796130831710178E-5
# Model iJN1463.cmd: 2.4790955927145565E-5
# Cycle 235
# Total biomass:
# Model iMM904.cmd: 2.8028261797479393E-5
# Model iJN1463.cmd: 2.4911963224929223E-5
# Cycle 236
# Total biomass:
# Model iMM904.cmd: 2.8096475541665687E-5
# Model iJN1463.cmd: 2.5032072310730137E-5
# Cycle 237
# Total biomass:
# Model iMM904.cmd: 2.8165529974280043E-5
# Model iJN1463.cmd: 2.5151159513970318E-5
# Cycle 238
# Total biomass:
# Model iMM904.cmd: 2.823495353868002E-5
# Model iJN1463.cmd: 2.5267282324945263E-5
# Cycle 239
# Total biomass:
# Model iMM904.cmd: 2.8306062533078064E-5
# Model iJN1463.cmd: 2.5382066325453595E-5
# Cycle 240
# Total biomass:
# Model iMM904.cmd: 2.8374937325220163E-5
# Model iJN1463.cmd: 2.549858779143496E-5
# Cycle 241
# Total biomass:
# Model iMM904.cmd: 2.8447695569570915E-5
# Model iJN1463.cmd: 2.5613648678342768E-5
# Cycle 242
# Total biomass:
# Model iMM904.cmd: 2.85120787149535E-5
# Model iJN1463.cmd: 2.573248441437289E-5
# Cycle 243
# Total biomass:
# Model iMM904.cmd: 2.8575705730132875E-5
# Model iJN1463.cmd: 2.5851749392558967E-5
# Cycle 244
# Total biomass:
# Model iMM904.cmd: 2.8644728359730048E-5
# Model iJN1463.cmd: 2.5969315650731246E-5
# Cycle 245
# Total biomass:
# Model iMM904.cmd: 2.8712348148726494E-5
# Model iJN1463.cmd: 2.6089878783182444E-5
# Cycle 246
# Total biomass:
# Model iMM904.cmd: 2.877927808922884E-5
# Model iJN1463.cmd: 2.6209018018761717E-5
# Cycle 247
# Total biomass:
# Model iMM904.cmd: 2.884700206906489E-5
# Model iJN1463.cmd: 2.6326287636463162E-5
# Cycle 248
# Total biomass:
# Model iMM904.cmd: 2.8914602107632397E-5
# Model iJN1463.cmd: 2.6442039666592678E-5
# Cycle 249
# Total biomass:
# Model iMM904.cmd: 2.8979937205784135E-5
# Model iJN1463.cmd: 2.656183660428736E-5
# Cycle 250
# Total biomass:
# Model iMM904.cmd: 2.9045313718414484E-5
# Model iJN1463.cmd: 2.6683278977903396E-5
# Cycle 251
# Total biomass:
# Model iMM904.cmd: 2.911409980234215E-5
# Model iJN1463.cmd: 2.6798808389995623E-5
# Cycle 252
# Total biomass:
# Model iMM904.cmd: 2.9184449602353422E-5
# Model iJN1463.cmd: 2.6913145900226614E-5
# Cycle 253
# Total biomass:
# Model iMM904.cmd: 2.92547835415745E-5
# Model iJN1463.cmd: 2.7026678133187657E-5
# Cycle 254
# Total biomass:
# Model iMM904.cmd: 2.932351209089667E-5
# Model iJN1463.cmd: 2.7140861412763404E-5
# Cycle 255
# Total biomass:
# Model iMM904.cmd: 2.9391662544521484E-5
# Model iJN1463.cmd: 2.7255264562380107E-5
# Cycle 256
# Total biomass:
# Model iMM904.cmd: 2.9458645814725382E-5
# Model iJN1463.cmd: 2.7370630571883084E-5
# Cycle 257
# Total biomass:
# Model iMM904.cmd: 2.9525600039257498E-5
# Model iJN1463.cmd: 2.748602797986458E-5
# Cycle 258
# Total biomass:
# Model iMM904.cmd: 2.9590389428306062E-5
# Model iJN1463.cmd: 2.760158991375574E-5
# Cycle 259
# Total biomass:
# Model iMM904.cmd: 2.9659564384248478E-5
# Model iJN1463.cmd: 2.7716016783773373E-5
# Cycle 260
# Total biomass:
# Model iMM904.cmd: 2.9727598124259883E-5
# Model iJN1463.cmd: 2.7828910036531136E-5
# Cycle 261
# Total biomass:
# Model iMM904.cmd: 2.9795604810235936E-5
# Model iJN1463.cmd: 2.794163565965379E-5
# Cycle 262
# Total biomass:
# Model iMM904.cmd: 2.9861927271439236E-5
# Model iJN1463.cmd: 2.8056325911219064E-5
# Cycle 263
# Total biomass:
# Model iMM904.cmd: 2.992783658377379E-5
# Model iJN1463.cmd: 2.817232119723999E-5
# Cycle 264
# Total biomass:
# Model iMM904.cmd: 2.9992917845106647E-5
# Model iJN1463.cmd: 2.8289031042655096E-5
# Cycle 265
# Total biomass:
# Model iMM904.cmd: 3.006030870867049E-5
# Model iJN1463.cmd: 2.8403643599178328E-5
# Cycle 266
# Total biomass:
# Model iMM904.cmd: 3.0125253540964455E-5
# Model iJN1463.cmd: 2.8520968311693575E-5
# Cycle 267
# Total biomass:
# Model iMM904.cmd: 3.019357684655553E-5
# Model iJN1463.cmd: 2.8634942835009356E-5
# Cycle 268
# Total biomass:
# Model iMM904.cmd: 3.0262282636970386E-5
# Model iJN1463.cmd: 2.874792021863484E-5
# Cycle 269
# Total biomass:
# Model iMM904.cmd: 3.033123221640371E-5
# Model iJN1463.cmd: 2.8859264438235167E-5
# Cycle 270
# Total biomass:
# Model iMM904.cmd: 3.039886719444463E-5
# Model iJN1463.cmd: 2.8972256498173643E-5
# Cycle 271
# Total biomass:
# Model iMM904.cmd: 3.046582664871102E-5
# Model iJN1463.cmd: 2.9085064890103677E-5
# Cycle 272
# Total biomass:
# Model iMM904.cmd: 3.0531206607388834E-5
# Model iJN1463.cmd: 2.9197984949601048E-5
# Cycle 273
# Total biomass:
# Model iMM904.cmd: 3.0597884234903056E-5
# Model iJN1463.cmd: 2.9312163381197375E-5
# Cycle 274
# Total biomass:
# Model iMM904.cmd: 3.066414112295685E-5
# Model iJN1463.cmd: 2.942359046498137E-5
# Cycle 275
# Total biomass:
# Model iMM904.cmd: 3.072988237952916E-5
# Model iJN1463.cmd: 2.9534746085832325E-5
# Cycle 276
# Total biomass:
# Model iMM904.cmd: 3.07945287702111E-5
# Model iJN1463.cmd: 2.964658742399017E-5
# Cycle 277
# Total biomass:
# Model iMM904.cmd: 3.0859600640828026E-5
# Model iJN1463.cmd: 2.9758820913855466E-5
# Cycle 278
# Total biomass:
# Model iMM904.cmd: 3.0923580225778694E-5
# Model iJN1463.cmd: 2.9872750735243866E-5
# Cycle 279
# Total biomass:
# Model iMM904.cmd: 3.099072422711518E-5
# Model iJN1463.cmd: 2.998413474234498E-5
# Cycle 280
# Total biomass:
# Model iMM904.cmd: 3.105441353931896E-5
# Model iJN1463.cmd: 3.0100579291366913E-5
# Cycle 281
# Total biomass:
# Model iMM904.cmd: 3.111922880222696E-5
# Model iJN1463.cmd: 3.021363242401766E-5
# Cycle 282
# Total biomass:
# Model iMM904.cmd: 3.11861918449202E-5
# Model iJN1463.cmd: 3.032262947764259E-5
# Cycle 283
# Total biomass:
# Model iMM904.cmd: 3.1248234523073795E-5
# Model iJN1463.cmd: 3.043669111219179E-5
# Cycle 284
# Total biomass:
# Model iMM904.cmd: 3.131776780649411E-5
# Model iJN1463.cmd: 3.054433796403727E-5
# Cycle 285
# Total biomass:
# Model iMM904.cmd: 3.13846393495185E-5
# Model iJN1463.cmd: 3.065514390679201E-5
# Cycle 286
# Total biomass:
# Model iMM904.cmd: 3.1446144446925934E-5
# Model iJN1463.cmd: 3.076924382764517E-5
# Cycle 287
# Total biomass:
# Model iMM904.cmd: 3.150688233640968E-5
# Model iJN1463.cmd: 3.0883827387027566E-5
# Cycle 288
# Total biomass:
# Model iMM904.cmd: 3.156828230010039E-5
# Model iJN1463.cmd: 3.0997964085489306E-5
# Cycle 289
# Total biomass:
# Model iMM904.cmd: 3.16305384472774E-5
# Model iJN1463.cmd: 3.1111700745870314E-5
# Cycle 290
# Total biomass:
# Model iMM904.cmd: 3.1686342047547195E-5
# Model iJN1463.cmd: 3.1231775381373454E-5
# Cycle 291
# Total biomass:
# Model iMM904.cmd: 3.1746125360343156E-5
# Model iJN1463.cmd: 3.134766064213221E-5
# Cycle 292
# Total biomass:
# Model iMM904.cmd: 3.180801623885449E-5
# Model iJN1463.cmd: 3.146080200039802E-5
# Cycle 293
# Total biomass:
# Model iMM904.cmd: 3.1870844370465764E-5
# Model iJN1463.cmd: 3.1571286119723705E-5
# Cycle 294
# Total biomass:
# Model iMM904.cmd: 3.193593259440083E-5
# Model iJN1463.cmd: 3.168000348861298E-5
# Cycle 295
# Total biomass:
# Model iMM904.cmd: 3.2003677219149884E-5
# Model iJN1463.cmd: 3.178707433111621E-5
# Cycle 296
# Total biomass:
# Model iMM904.cmd: 3.206858089597579E-5
# Model iJN1463.cmd: 3.189457492896251E-5
# Cycle 297
# Total biomass:
# Model iMM904.cmd: 3.213194594106899E-5
# Model iJN1463.cmd: 3.200920137422711E-5
# Cycle 298
# Total biomass:
# Model iMM904.cmd: 3.2194774127054916E-5
# Model iJN1463.cmd: 3.212057058816726E-5
# Cycle 299
# Total biomass:
# Model iMM904.cmd: 3.2260893721256546E-5
# Model iJN1463.cmd: 3.222918365264788E-5
# Cycle 300
# Total biomass:
# Model iMM904.cmd: 3.232663956068822E-5
# Model iJN1463.cmd: 3.2339629263774913E-5
# Cycle 301
# Total biomass:
# Model iMM904.cmd: 3.238975405148675E-5
# Model iJN1463.cmd: 3.24504686882516E-5
# Cycle 302
# Total biomass:
# Model iMM904.cmd: 3.2454691396846986E-5
# Model iJN1463.cmd: 3.255669520470252E-5
# Cycle 303
# Total biomass:
# Model iMM904.cmd: 3.251825172601745E-5
# Model iJN1463.cmd: 3.266457350362839E-5
# Cycle 304
# Total biomass:
# Model iMM904.cmd: 3.258094171388597E-5
# Model iJN1463.cmd: 3.277329342362379E-5
# Cycle 305
# Total biomass:
# Model iMM904.cmd: 3.264553784345374E-5
# Model iJN1463.cmd: 3.28806429569145E-5
# Cycle 306
# Total biomass:
# Model iMM904.cmd: 3.270839798046609E-5
# Model iJN1463.cmd: 3.299003481013123E-5
# Cycle 307
# Total biomass:
# Model iMM904.cmd: 3.2767123721819756E-5
# Model iJN1463.cmd: 3.3102299033614645E-5
# Cycle 308
# Total biomass:
# Model iMM904.cmd: 3.282856053505493E-5
# Model iJN1463.cmd: 3.321254556029588E-5
# Cycle 309
# Total biomass:
# Model iMM904.cmd: 3.289180020196494E-5
# Model iJN1463.cmd: 3.331861005082929E-5
# Cycle 310
# Total biomass:
# Model iMM904.cmd: 3.2956333141052946E-5
# Model iJN1463.cmd: 3.342658930445598E-5
# Cycle 311
# Total biomass:
# Model iMM904.cmd: 3.3018898076491525E-5
# Model iJN1463.cmd: 3.353410676254117E-5
# Cycle 312
# Total biomass:
# Model iMM904.cmd: 3.3075582286151524E-5
# Model iJN1463.cmd: 3.364101310036451E-5
# Cycle 313
# Total biomass:
# Model iMM904.cmd: 3.31368974708418E-5
# Model iJN1463.cmd: 3.374713602046699E-5
# Cycle 314
# Total biomass:
# Model iMM904.cmd: 3.3196634871968824E-5
# Model iJN1463.cmd: 3.385369067965524E-5
# Cycle 315
# Total biomass:
# Model iMM904.cmd: 3.32556789795307E-5
# Model iJN1463.cmd: 3.395991884941911E-5
# Cycle 316
# Total biomass:
# Model iMM904.cmd: 3.3316687316938855E-5
# Model iJN1463.cmd: 3.40686496562153E-5
# Cycle 317
# Total biomass:
# Model iMM904.cmd: 3.337747624425945E-5
# Model iJN1463.cmd: 3.418021199002285E-5
# Cycle 318
# Total biomass:
# Model iMM904.cmd: 3.343921260317053E-5
# Model iJN1463.cmd: 3.428982015018267E-5
# Cycle 319
# Total biomass:
# Model iMM904.cmd: 3.3500914708394445E-5
# Model iJN1463.cmd: 3.4398655301444244E-5
# Cycle 320
# Total biomass:
# Model iMM904.cmd: 3.356227784816888E-5
# Model iJN1463.cmd: 3.450139495154157E-5
# Cycle 321
# Total biomass:
# Model iMM904.cmd: 3.362736282379939E-5
# Model iJN1463.cmd: 3.460194409300598E-5
# Cycle 322
# Total biomass:
# Model iMM904.cmd: 3.368901330891331E-5
# Model iJN1463.cmd: 3.470724236009663E-5
# Cycle 323
# Total biomass:
# Model iMM904.cmd: 3.374918731201278E-5
# Model iJN1463.cmd: 3.481087575769149E-5
# Cycle 324
# Total biomass:
# Model iMM904.cmd: 3.380743975094327E-5
# Model iJN1463.cmd: 3.491554978322882E-5
# Cycle 325
# Total biomass:
# Model iMM904.cmd: 3.3868753175808866E-5
# Model iJN1463.cmd: 3.5021132742791066E-5
# Cycle 326
# Total biomass:
# Model iMM904.cmd: 3.392897854676784E-5
# Model iJN1463.cmd: 3.51297667741057E-5
# Cycle 327
# Total biomass:
# Model iMM904.cmd: 3.399196637230641E-5
# Model iJN1463.cmd: 3.523555455814287E-5
# Cycle 328
# Total biomass:
# Model iMM904.cmd: 3.4054293048127854E-5
# Model iJN1463.cmd: 3.5339875942775983E-5
# Cycle 329
# Total biomass:
# Model iMM904.cmd: 3.411667904919938E-5
# Model iJN1463.cmd: 3.544244411924703E-5
# Cycle 330
# Total biomass:
# Model iMM904.cmd: 3.41777279890332E-5
# Model iJN1463.cmd: 3.55490492624915E-5
# Cycle 331
# Total biomass:
# Model iMM904.cmd: 3.423988549607219E-5
# Model iJN1463.cmd: 3.565353925057835E-5
# Cycle 332
# Total biomass:
# Model iMM904.cmd: 3.430419098361611E-5
# Model iJN1463.cmd: 3.5755828567806975E-5
# Cycle 333
# Total biomass:
# Model iMM904.cmd: 3.436861204893838E-5
# Model iJN1463.cmd: 3.585780441175017E-5
# Cycle 334
# Total biomass:
# Model iMM904.cmd: 3.44304131279046E-5
# Model iJN1463.cmd: 3.596165060698453E-5
# Cycle 335
# Total biomass:
# Model iMM904.cmd: 3.449533245049873E-5
# Model iJN1463.cmd: 3.6063325264584774E-5
# Cycle 336
# Total biomass:
# Model iMM904.cmd: 3.455049017041421E-5
# Model iJN1463.cmd: 3.6173986841094065E-5
# Cycle 337
# Total biomass:
# Model iMM904.cmd: 3.460723409947621E-5
# Model iJN1463.cmd: 3.628341735021624E-5
# Cycle 338
# Total biomass:
# Model iMM904.cmd: 3.46642494853989E-5
# Model iJN1463.cmd: 3.6390819275880775E-5
# Cycle 339
# Total biomass:
# Model iMM904.cmd: 3.472328771647699E-5
# Model iJN1463.cmd: 3.649431757110145E-5
# Cycle 340
# Total biomass:
# Model iMM904.cmd: 3.478082295533997E-5
# Model iJN1463.cmd: 3.660208083838459E-5
# Cycle 341
# Total biomass:
# Model iMM904.cmd: 3.4835582471217385E-5
# Model iJN1463.cmd: 3.671219927786139E-5
# Cycle 342
# Total biomass:
# Model iMM904.cmd: 3.489467949000642E-5
# Model iJN1463.cmd: 3.681621590192426E-5
# Cycle 343
# Total biomass:
# Model iMM904.cmd: 3.4950642011460686E-5
# Model iJN1463.cmd: 3.692367875535293E-5
# Cycle 344
# Total biomass:
# Model iMM904.cmd: 3.50088716036995E-5
# Model iJN1463.cmd: 3.7027471454606376E-5
# Cycle 345
# Total biomass:
# Model iMM904.cmd: 3.506760250990723E-5
# Model iJN1463.cmd: 3.713176707250634E-5
# Cycle 346
# Total biomass:
# Model iMM904.cmd: 3.5121754412672264E-5
# Model iJN1463.cmd: 3.724144915799878E-5
# Cycle 347
# Total biomass:
# Model iMM904.cmd: 3.517851959302366E-5
# Model iJN1463.cmd: 3.7347523796848424E-5
# Cycle 348
# Total biomass:
# Model iMM904.cmd: 3.523943699216023E-5
# Model iJN1463.cmd: 3.745339503385621E-5
# Cycle 349
# Total biomass:
# Model iMM904.cmd: 3.5297146697333816E-5
# Model iJN1463.cmd: 3.755770268236373E-5
# Cycle 350
# Total biomass:
# Model iMM904.cmd: 3.53605847908862E-5
# Model iJN1463.cmd: 3.7657059023913526E-5
# Cycle 351
# Total biomass:
# Model iMM904.cmd: 3.5420007676295976E-5
# Model iJN1463.cmd: 3.776126376063662E-5
# Cycle 352
# Total biomass:
# Model iMM904.cmd: 3.548057427048424E-5
# Model iJN1463.cmd: 3.7862207184286184E-5
# Cycle 353
# Total biomass:
# Model iMM904.cmd: 3.5539283937916175E-5
# Model iJN1463.cmd: 3.796388352308796E-5
# Cycle 354
# Total biomass:
# Model iMM904.cmd: 3.559764192600028E-5
# Model iJN1463.cmd: 3.806562028333149E-5
# Cycle 355
# Total biomass:
# Model iMM904.cmd: 3.5657252888937765E-5
# Model iJN1463.cmd: 3.816603703425891E-5
# Cycle 356
# Total biomass:
# Model iMM904.cmd: 3.571852128348985E-5
# Model iJN1463.cmd: 3.82651714158217E-5
# Cycle 357
# Total biomass:
# Model iMM904.cmd: 3.5778281303184165E-5
# Model iJN1463.cmd: 3.836587739815491E-5
# Cycle 358
# Total biomass:
# Model iMM904.cmd: 3.582962573771983E-5
# Model iJN1463.cmd: 3.847682212931335E-5
# Cycle 359
# Total biomass:
# Model iMM904.cmd: 3.588809758499534E-5
# Model iJN1463.cmd: 3.857835271248995E-5
# Cycle 360
# Total biomass:
# Model iMM904.cmd: 3.594827119009866E-5
# Model iJN1463.cmd: 3.8679700200187735E-5
# Cycle 361
# Total biomass:
# Model iMM904.cmd: 3.6005521840925233E-5
# Model iJN1463.cmd: 3.878203649737221E-5
# Cycle 362
# Total biomass:
# Model iMM904.cmd: 3.606268367244052E-5
# Model iJN1463.cmd: 3.888418058851471E-5
# Cycle 363
# Total biomass:
# Model iMM904.cmd: 3.612178495469492E-5
# Model iJN1463.cmd: 3.898386276657978E-5
# Cycle 364
# Total biomass:
# Model iMM904.cmd: 3.61795155680079E-5
# Model iJN1463.cmd: 3.908638881837067E-5
# Cycle 365
# Total biomass:
# Model iMM904.cmd: 3.62384203787183E-5
# Model iJN1463.cmd: 3.9185790065418895E-5
# Cycle 366
# Total biomass:
# Model iMM904.cmd: 3.6297993208129586E-5
# Model iJN1463.cmd: 3.9284144363923836E-5
# Cycle 367
# Total biomass:
# Model iMM904.cmd: 3.635627083271628E-5
# Model iJN1463.cmd: 3.938499836252251E-5
# Cycle 368
# Total biomass:
# Model iMM904.cmd: 3.6415068948423844E-5
# Model iJN1463.cmd: 3.948487411694429E-5
# Cycle 369
# Total biomass:
# Model iMM904.cmd: 3.647480489218513E-5
# Model iJN1463.cmd: 3.9582191188262055E-5
# Cycle 370
# Total biomass:
# Model iMM904.cmd: 3.653527033550224E-5
# Model iJN1463.cmd: 3.967917805923487E-5
# Cycle 371
# Total biomass:
# Model iMM904.cmd: 3.6594036980491486E-5
# Model iJN1463.cmd: 3.97779167851233E-5
# Cycle 372
# Total biomass:
# Model iMM904.cmd: 3.665401076034994E-5
# Model iJN1463.cmd: 3.987552947450366E-5
# Cycle 373
# Total biomass:
# Model iMM904.cmd: 3.6714641633916044E-5
# Model iJN1463.cmd: 3.997079569932066E-5
# Cycle 374
# Total biomass:
# Model iMM904.cmd: 3.677450271732888E-5
# Model iJN1463.cmd: 4.006725879808975E-5
# Cycle 375
# Total biomass:
# Model iMM904.cmd: 3.683357017773715E-5
# Model iJN1463.cmd: 4.016402575063299E-5
# Cycle 376
# Total biomass:
# Model iMM904.cmd: 3.689311885399304E-5
# Model iJN1463.cmd: 4.026118959822839E-5
# Cycle 377
# Total biomass:
# Model iMM904.cmd: 3.69516073911145E-5
# Model iJN1463.cmd: 4.035828377173717E-5
# Cycle 378
# Total biomass:
# Model iMM904.cmd: 3.7011348053859587E-5
# Model iJN1463.cmd: 4.0454116633081356E-5
# Cycle 379
# Total biomass:
# Model iMM904.cmd: 3.7069625024443165E-5
# Model iJN1463.cmd: 4.055122634781361E-5
# Cycle 380
# Total biomass:
# Model iMM904.cmd: 3.712731103684751E-5
# Model iJN1463.cmd: 4.064873519114631E-5
# Cycle 381
# Total biomass:
# Model iMM904.cmd: 3.718569652127137E-5
# Model iJN1463.cmd: 4.074469921629109E-5
# Cycle 382
# Total biomass:
# Model iMM904.cmd: 3.724568276187525E-5
# Model iJN1463.cmd: 4.084022014048202E-5
# Cycle 383
# Total biomass:
# Model iMM904.cmd: 3.730350604707211E-5
# Model iJN1463.cmd: 4.093777827737385E-5
# Cycle 384
# Total biomass:
# Model iMM904.cmd: 3.736180421930511E-5
# Model iJN1463.cmd: 4.1033124077730964E-5
# Cycle 385
# Total biomass:
# Model iMM904.cmd: 3.74215172659429E-5
# Model iJN1463.cmd: 4.112623602244088E-5
# Cycle 386
# Total biomass:
# Model iMM904.cmd: 3.747997844014292E-5
# Model iJN1463.cmd: 4.1220571743388936E-5
# Cycle 387
# Total biomass:
# Model iMM904.cmd: 3.7538419325206453E-5
# Model iJN1463.cmd: 4.13148306386544E-5
# Cycle 388
# Total biomass:
# Model iMM904.cmd: 3.7595788221218975E-5
# Model iJN1463.cmd: 4.141066185798168E-5
# Cycle 389
# Total biomass:
# Model iMM904.cmd: 3.765375244615291E-5
# Model iJN1463.cmd: 4.1505422800656346E-5
# Cycle 390
# Total biomass:
# Model iMM904.cmd: 3.7710604871682814E-5
# Model iJN1463.cmd: 4.160075021728107E-5
# Cycle 391
# Total biomass:
# Model iMM904.cmd: 3.7768628519351346E-5
# Model iJN1463.cmd: 4.169436171950159E-5
# Cycle 392
# Total biomass:
# Model iMM904.cmd: 3.7825619615495025E-5
# Model iJN1463.cmd: 4.178919058052892E-5
# Cycle 393
# Total biomass:
# Model iMM904.cmd: 3.788077660191329E-5
# Model iJN1463.cmd: 4.188589555176997E-5
# Cycle 394
# Total biomass:
# Model iMM904.cmd: 3.793754323443661E-5
# Model iJN1463.cmd: 4.198081420445724E-5
# Cycle 395
# Total biomass:
# Model iMM904.cmd: 3.799499824203742E-5
# Model iJN1463.cmd: 4.207500158821052E-5
# Cycle 396
# Total biomass:
# Model iMM904.cmd: 3.8051502793712256E-5
# Model iJN1463.cmd: 4.217150777026971E-5
# Cycle 397
# Total biomass:
# Model iMM904.cmd: 3.810831950067634E-5
# Model iJN1463.cmd: 4.226594076719873E-5
# Cycle 398
# Total biomass:
# Model iMM904.cmd: 3.816555157025373E-5
# Model iJN1463.cmd: 4.2358980767520234E-5
# Cycle 399
# Total biomass:
# Model iMM904.cmd: 3.8222805627417195E-5
# Model iJN1463.cmd: 4.245164302322013E-5
# Cycle 400
# Total biomass:
# Model iMM904.cmd: 3.827993805099401E-5
# Model iJN1463.cmd: 4.254445640284081E-5
# Cycle 401
# Total biomass:
# ...
# Cycle 848
# Total biomass:
# Model iMM904.cmd: 5.608392497055873E-5
# Model iJN1463.cmd: 7.222290680481616E-5
# Cycle 849
# Total biomass:
# Model iMM904.cmd: 5.610977784013648E-5
# Model iJN1463.cmd: 7.226396323594266E-5
# Cycle 850
# Total biomass:
# Model iMM904.cmd: 5.6137085349432404E-5
# Model iJN1463.cmd: 7.230157498366109E-5
# Cycle 851
# Total biomass:
# Model iMM904.cmd: 5.6162837326394936E-5
# Model iJN1463.cmd: 7.234054599685716E-5
# Cycle 852
# Total biomass:
# Model iMM904.cmd: 5.6188874538163476E-5
# Model iJN1463.cmd: 7.237924609642745E-5
# Cycle 853
# Total biomass:
# Model iMM904.cmd: 5.621522279762028E-5
# Model iJN1463.cmd: 7.241841063130637E-5
# Cycle 854
# Total biomass:
# Model iMM904.cmd: 5.623853927239997E-5
# Model iJN1463.cmd: 7.246115563905993E-5
# Cycle 855
# Total biomass:
# Model iMM904.cmd: 5.6265421571465634E-5
# Model iJN1463.cmd: 7.249885345686115E-5
# Cycle 856
# Total biomass:
# Model iMM904.cmd: 5.6292855530653044E-5
# Model iJN1463.cmd: 7.253758765017517E-5
# Cycle 857
# Total biomass:
# Model iMM904.cmd: 5.6317524265450954E-5
# Model iJN1463.cmd: 7.257775102597922E-5
# Cycle 858
# Total biomass:
# Model iMM904.cmd: 5.6343891466010954E-5
# Model iJN1463.cmd: 7.26177527967012E-5
# Cycle 859
# Total biomass:
# Model iMM904.cmd: 5.636651180633703E-5
# Model iJN1463.cmd: 7.266046714255006E-5
# Cycle 860
# Total biomass:
# Model iMM904.cmd: 5.639495683738698E-5
# Model iJN1463.cmd: 7.269848230797738E-5
# Cycle 861
# Total biomass:
# Model iMM904.cmd: 5.642016384317803E-5
# Model iJN1463.cmd: 7.273775595541647E-5
# Cycle 862
# Total biomass:
# Model iMM904.cmd: 5.644329931293977E-5
# Model iJN1463.cmd: 7.277998798228052E-5
# Cycle 863
# Total biomass:
# Model iMM904.cmd: 5.646761705607862E-5
# Model iJN1463.cmd: 7.282001582651524E-5
# Cycle 864
# Total biomass:
# Model iMM904.cmd: 5.649087111682749E-5
# Model iJN1463.cmd: 7.286203952772126E-5
# Cycle 865
# Total biomass:
# Model iMM904.cmd: 5.6517625717619436E-5
# Model iJN1463.cmd: 7.290006117284877E-5
# Cycle 866
# Total biomass:
# Model iMM904.cmd: 5.654230843327823E-5
# Model iJN1463.cmd: 7.293866409632472E-5
# Cycle 867
# Total biomass:
# Model iMM904.cmd: 5.656789315284038E-5
# Model iJN1463.cmd: 7.297792621885003E-5
# Cycle 868
# Total biomass:
# Model iMM904.cmd: 5.659430186062893E-5
# Model iJN1463.cmd: 7.301490017764572E-5
# Cycle 869
# Total biomass:
# Model iMM904.cmd: 5.66212004995408E-5
# Model iJN1463.cmd: 7.30539654326245E-5
# Cycle 870
# Total biomass:
# Model iMM904.cmd: 5.664854966972076E-5
# Model iJN1463.cmd: 7.309034075670259E-5
# Cycle 871
# Total biomass:
# Model iMM904.cmd: 5.667111306996009E-5
# Model iJN1463.cmd: 7.313100095002205E-5
# Cycle 872
# Total biomass:
# Model iMM904.cmd: 5.669375933078581E-5
# Model iJN1463.cmd: 7.3172699345808E-5
# Cycle 873
# Total biomass:
# Model iMM904.cmd: 5.6719311640901924E-5
# Model iJN1463.cmd: 7.321078244654111E-5
# Cycle 874
# Total biomass:
# Model iMM904.cmd: 5.6746144854692553E-5
# Model iJN1463.cmd: 7.324669209117267E-5
# Cycle 875
# Total biomass:
# Model iMM904.cmd: 5.677110996149511E-5
# Model iJN1463.cmd: 7.32851120436207E-5
# Cycle 876
# Total biomass:
# Model iMM904.cmd: 5.6796425036439316E-5
# Model iJN1463.cmd: 7.332257078983189E-5
# Cycle 877
# Total biomass:
# Model iMM904.cmd: 5.681731861813275E-5
# Model iJN1463.cmd: 7.336564587208293E-5
# Cycle 878
# Total biomass:
# Model iMM904.cmd: 5.6838061528712606E-5
# Model iJN1463.cmd: 7.340810519132624E-5
# Cycle 879
# Total biomass:
# Model iMM904.cmd: 5.686218316454381E-5
# Model iJN1463.cmd: 7.344536581961512E-5
# Cycle 880
# Total biomass:
# Model iMM904.cmd: 5.688483532191497E-5
# Model iJN1463.cmd: 7.348523440711247E-5
# Cycle 881
# Total biomass:
# Model iMM904.cmd: 5.6909997587212334E-5
# Model iJN1463.cmd: 7.352149842377543E-5
# Cycle 882
# Total biomass:
# Model iMM904.cmd: 5.693324399312541E-5
# Model iJN1463.cmd: 7.355880660672877E-5
# Cycle 883
# Total biomass:
# Model iMM904.cmd: 5.6955739710700935E-5
# Model iJN1463.cmd: 7.359713828397582E-5
# Cycle 884
# Total biomass:
# Model iMM904.cmd: 5.697839978411151E-5
# Model iJN1463.cmd: 7.36375300587322E-5
# Cycle 885
# Total biomass:
# Model iMM904.cmd: 5.699917987630936E-5
# Model iJN1463.cmd: 7.367849297238612E-5
# Cycle 886
# Total biomass:
# Model iMM904.cmd: 5.7024064516312616E-5
# Model iJN1463.cmd: 7.37149517364046E-5
# Cycle 887
# Total biomass:
# Model iMM904.cmd: 5.7050451100409255E-5
# Model iJN1463.cmd: 7.375069531976352E-5
# Cycle 888
# Total biomass:
# Model iMM904.cmd: 5.707363772596257E-5
# Model iJN1463.cmd: 7.378953750033605E-5
# Cycle 889
# Total biomass:
# Model iMM904.cmd: 5.7097815668487376E-5
# Model iJN1463.cmd: 7.382938377481866E-5
# Cycle 890
# Total biomass:
# Model iMM904.cmd: 5.7115958337728785E-5
# Model iJN1463.cmd: 7.387493320387674E-5
# Cycle 891
# Total biomass:
# Model iMM904.cmd: 5.7133272477682395E-5
# Model iJN1463.cmd: 7.392007979801784E-5
# Cycle 892
# Total biomass:
# Model iMM904.cmd: 5.7156876726634616E-5
# Model iJN1463.cmd: 7.395633248356712E-5
# Cycle 893
# Total biomass:
# Model iMM904.cmd: 5.7182131857517434E-5
# Model iJN1463.cmd: 7.399079310268875E-5
# Cycle 894
# Total biomass:
# Model iMM904.cmd: 5.7204040475427565E-5
# Model iJN1463.cmd: 7.402892915479336E-5
# Cycle 895
# Total biomass:
# Model iMM904.cmd: 5.722650652508748E-5
# Model iJN1463.cmd: 7.40662274017119E-5
# Cycle 896
# Total biomass:
# Model iMM904.cmd: 5.724764393393833E-5
# Model iJN1463.cmd: 7.410459792183784E-5
# Cycle 897
# Total biomass:
# Model iMM904.cmd: 5.726881701181877E-5
# Model iJN1463.cmd: 7.414439789916704E-5
# Cycle 898
# Total biomass:
# Model iMM904.cmd: 5.7287114847596394E-5
# Model iJN1463.cmd: 7.418743375728448E-5
# Cycle 899
# Total biomass:
# Model iMM904.cmd: 5.73099939514309E-5
# Model iJN1463.cmd: 7.422387556092282E-5
# Cycle 900
# Total biomass:
# Model iMM904.cmd: 5.733114791937194E-5
# Model iJN1463.cmd: 7.426155402906067E-5
# Cycle 901
# Total biomass:
# Model iMM904.cmd: 5.735696262671508E-5
# Model iJN1463.cmd: 7.429499386675265E-5
# Cycle 902
# Total biomass:
# Model iMM904.cmd: 5.738157202153287E-5
# Model iJN1463.cmd: 7.432931653564816E-5
# Cycle 903
# Total biomass:
# Model iMM904.cmd: 5.73989441550674E-5
# Model iJN1463.cmd: 7.437053616567624E-5
# Cycle 904
# Total biomass:
# Model iMM904.cmd: 5.741907935238927E-5
# Model iJN1463.cmd: 7.441006478487E-5
# Cycle 905
# Total biomass:
# Model iMM904.cmd: 5.744409360085233E-5
# Model iJN1463.cmd: 7.44423918038345E-5
# Cycle 906
# Total biomass:
# Model iMM904.cmd: 5.747017913413881E-5
# Model iJN1463.cmd: 7.447489120329147E-5
# Cycle 907
# Total biomass:
# Model iMM904.cmd: 5.7491050088677627E-5
# Model iJN1463.cmd: 7.451364852983846E-5
# Cycle 908
# Total biomass:
# Model iMM904.cmd: 5.751453008446955E-5
# Model iJN1463.cmd: 7.454753755007813E-5
# Cycle 909
# Total biomass:
# Model iMM904.cmd: 5.753805232508318E-5
# Model iJN1463.cmd: 7.458057481982716E-5
# Cycle 910
# Total biomass:
# Model iMM904.cmd: 5.756159064474264E-5
# Model iJN1463.cmd: 7.461597220660335E-5
# Cycle 911
# Total biomass:
# Model iMM904.cmd: 5.7582458134304444E-5
# Model iJN1463.cmd: 7.465282860779101E-5
# Cycle 912
# Total biomass:
# Model iMM904.cmd: 5.7601252964815334E-5
# Model iJN1463.cmd: 7.469311320560399E-5
# Cycle 913
# Total biomass:
# Model iMM904.cmd: 5.762440528493321E-5
# Model iJN1463.cmd: 7.472812027232412E-5
# Cycle 914
# Total biomass:
# Model iMM904.cmd: 5.764325337555006E-5
# Model iJN1463.cmd: 7.476791817876407E-5
# Cycle 915
# Total biomass:
# Model iMM904.cmd: 5.7658715098092634E-5
# Model iJN1463.cmd: 7.48105781619629E-5
# Cycle 916
# Total biomass:
# Model iMM904.cmd: 5.768066606657197E-5
# Model iJN1463.cmd: 7.4844727062553E-5
# Cycle 917
# Total biomass:
# Model iMM904.cmd: 5.77037894644753E-5
# Model iJN1463.cmd: 7.4877209872094E-5
# Cycle 918
# Total biomass:
# Model iMM904.cmd: 5.772489852157815E-5
# Model iJN1463.cmd: 7.491335441967314E-5
# Cycle 919
# Total biomass:
# Model iMM904.cmd: 5.7744313867026046E-5
# Model iJN1463.cmd: 7.495138516117914E-5
# Cycle 920
# Total biomass:
# Model iMM904.cmd: 5.776146677148698E-5
# Model iJN1463.cmd: 7.49919541117314E-5
# Cycle 921
# Total biomass:
# Model iMM904.cmd: 5.778013109106725E-5
# Model iJN1463.cmd: 7.502756218707628E-5
# Cycle 922
# Total biomass:
# Model iMM904.cmd: 5.780209476867705E-5
# Model iJN1463.cmd: 7.506022191715626E-5
# Cycle 923
# Total biomass:
# Model iMM904.cmd: 5.782507147975148E-5
# Model iJN1463.cmd: 7.509374724797245E-5
# Cycle 924
# Total biomass:
# Model iMM904.cmd: 5.784690287868536E-5
# Model iJN1463.cmd: 7.512757204233441E-5
# Cycle 925
# Total biomass:
# Model iMM904.cmd: 5.786883312057429E-5
# Model iJN1463.cmd: 7.516048165280983E-5
# Cycle 926
# Total biomass:
# Model iMM904.cmd: 5.7892308491371575E-5
# Model iJN1463.cmd: 7.519300817425749E-5
# Cycle 927
# Total biomass:
# Model iMM904.cmd: 5.790771608409531E-5
# Model iJN1463.cmd: 7.523448520476782E-5
# Cycle 928
# Total biomass:
# Model iMM904.cmd: 5.793005465232285E-5
# Model iJN1463.cmd: 7.526833627657149E-5
# Cycle 929
# Total biomass:
# Model iMM904.cmd: 5.7952843503517126E-5
# Model iJN1463.cmd: 7.530004178387867E-5
# Cycle 930
# Total biomass:
# Model iMM904.cmd: 5.797544249042716E-5
# Model iJN1463.cmd: 7.533305136234762E-5
# Cycle 931
# Total biomass:
# Model iMM904.cmd: 5.799815257209637E-5
# Model iJN1463.cmd: 7.536698173004579E-5
# Cycle 932
# Total biomass:
# Model iMM904.cmd: 5.802045826362453E-5
# Model iJN1463.cmd: 7.53999455778782E-5
# Cycle 933
# Total biomass:
# Model iMM904.cmd: 5.804088256475926E-5
# Model iJN1463.cmd: 7.543354869378674E-5
# Cycle 934
# Total biomass:
# Model iMM904.cmd: 5.8057044118544826E-5
# Model iJN1463.cmd: 7.547301819053362E-5
# Cycle 935
# Total biomass:
# Model iMM904.cmd: 5.807204665609442E-5
# Model iJN1463.cmd: 7.55141330294653E-5
# Cycle 936
# Total biomass:
# Model iMM904.cmd: 5.809339795792676E-5
# Model iJN1463.cmd: 7.554634075563585E-5
# Cycle 937
# Total biomass:
# Model iMM904.cmd: 5.811501315558695E-5
# Model iJN1463.cmd: 7.5577794187129E-5
# Cycle 938
# Total biomass:
# Model iMM904.cmd: 5.8130836984066826E-5
# Model iJN1463.cmd: 7.561613145473047E-5
# Cycle 939
# Total biomass:
# Model iMM904.cmd: 5.815207457306696E-5
# Model iJN1463.cmd: 7.564782571828364E-5
# Cycle 940
# Total biomass:
# Model iMM904.cmd: 5.817338290324406E-5
# Model iJN1463.cmd: 7.567893244300316E-5
# Cycle 941
# Total biomass:
# Model iMM904.cmd: 5.81904269506816E-5
# Model iJN1463.cmd: 7.57144040664994E-5
# Cycle 942
# Total biomass:
# Model iMM904.cmd: 5.8211241318703487E-5
# Model iJN1463.cmd: 7.574484360166869E-5
# Cycle 943
# Total biomass:
# Model iMM904.cmd: 5.822932490191172E-5
# Model iJN1463.cmd: 7.57779448988295E-5
# Cycle 944
# Total biomass:
# Model iMM904.cmd: 5.824288658391549E-5
# Model iJN1463.cmd: 7.581656525195323E-5
# Cycle 945
# Total biomass:
# Model iMM904.cmd: 5.825760005755977E-5
# Model iJN1463.cmd: 7.58556678006654E-5
# Cycle 946
# Total biomass:
# Model iMM904.cmd: 5.827446319975676E-5
# Model iJN1463.cmd: 7.589169540802595E-5
# Cycle 947
# Total biomass:
# Model iMM904.cmd: 5.829127150921751E-5
# Model iJN1463.cmd: 7.592756065366798E-5
# Cycle 948
# Total biomass:
# Model iMM904.cmd: 5.8308047374246193E-5
# Model iJN1463.cmd: 7.596334728512253E-5
# Cycle 949
# Total biomass:
# Model iMM904.cmd: 5.8325066679753944E-5
# Model iJN1463.cmd: 7.599879646833951E-5
# Cycle 950
# Total biomass:
# Model iMM904.cmd: 5.8341974091091895E-5
# Model iJN1463.cmd: 7.603439848430386E-5
# Cycle 951
# Total biomass:
# Model iMM904.cmd: 5.8358170933857285E-5
# Model iJN1463.cmd: 7.606948985112275E-5
# Cycle 952
# Total biomass:
# Model iMM904.cmd: 5.838039335445951E-5
# Model iJN1463.cmd: 7.609920023071477E-5
# Cycle 953
# Total biomass:
# Model iMM904.cmd: 5.8400034265542826E-5
# Model iJN1463.cmd: 7.613078693638329E-5
# Cycle 954
# Total biomass:
# Model iMM904.cmd: 5.8422086509380365E-5
# Model iJN1463.cmd: 7.615993525701764E-5
# Cycle 955
# Total biomass:
# Model iMM904.cmd: 5.843927328393778E-5
# Model iJN1463.cmd: 7.619583893120976E-5
# Cycle 956
# Total biomass:
# Model iMM904.cmd: 5.845387721345249E-5
# Model iJN1463.cmd: 7.623334183015525E-5
# Cycle 957
# Total biomass:
# Model iMM904.cmd: 5.846996360317813E-5
# Model iJN1463.cmd: 7.626874556103184E-5
# Cycle 958
# Total biomass:
# Model iMM904.cmd: 5.848610277026439E-5
# Model iJN1463.cmd: 7.630390160001171E-5
# Cycle 959
# Total biomass:
# Model iMM904.cmd: 5.8502224428533E-5
# Model iJN1463.cmd: 7.633900240207686E-5
# Cycle 960
# Total biomass:
# Model iMM904.cmd: 5.851734742799244E-5
# Model iJN1463.cmd: 7.637445989538245E-5
# Cycle 961
# Total biomass:
# Model iMM904.cmd: 5.853355338524407E-5
# Model iJN1463.cmd: 7.640860696737521E-5
# Cycle 962
# Total biomass:
# Model iMM904.cmd: 5.855019815111664E-5
# Model iJN1463.cmd: 7.644164928804317E-5
# Cycle 963
# Total biomass:
# Model iMM904.cmd: 5.8569332503509136E-5
# Model iJN1463.cmd: 7.64711357296092E-5
# Cycle 964
# Total biomass:
# Model iMM904.cmd: 5.8588031918276306E-5
# Model iJN1463.cmd: 7.650138427810713E-5
# Cycle 965
# Total biomass:
# Model iMM904.cmd: 5.860856027667116E-5
# Model iJN1463.cmd: 7.652976369187298E-5
# Cycle 966
# Total biomass:
# Model iMM904.cmd: 5.862211724067058E-5
# Model iJN1463.cmd: 7.656661811602859E-5
# Cycle 967
# Total biomass:
# Model iMM904.cmd: 5.863998761472855E-5
# Model iJN1463.cmd: 7.659949433769337E-5
# Cycle 968
# Total biomass:
# Model iMM904.cmd: 5.8660370554544654E-5
# Model iJN1463.cmd: 7.662860204096082E-5
# Cycle 969
# Total biomass:
# Model iMM904.cmd: 5.8676464161139014E-5
# Model iJN1463.cmd: 7.666198172982481E-5
# Cycle 970
# Total biomass:
# Model iMM904.cmd: 5.8692773274486496E-5
# Model iJN1463.cmd: 7.669207218073633E-5
# Cycle 971
# Total biomass:
# Model iMM904.cmd: 5.870964468709363E-5
# Model iJN1463.cmd: 7.672519980975855E-5
# Cycle 972
# Total biomass:
# Model iMM904.cmd: 5.873097069976286E-5
# Model iJN1463.cmd: 7.675316801597991E-5
# Cycle 973
# Total biomass:
# Model iMM904.cmd: 5.875221563838066E-5
# Model iJN1463.cmd: 7.678239948980654E-5
# Cycle 974
# Total biomass:
# Model iMM904.cmd: 5.877283704653558E-5
# Model iJN1463.cmd: 7.681103811116853E-5
# Cycle 975
# Total biomass:
# Model iMM904.cmd: 5.879360663468099E-5
# Model iJN1463.cmd: 7.683855483833111E-5
# Cycle 976
# Total biomass:
# Model iMM904.cmd: 5.881556181509387E-5
# Model iJN1463.cmd: 7.686574975570571E-5
# Cycle 977
# Total biomass:
# Model iMM904.cmd: 5.883488697732498E-5
# Model iJN1463.cmd: 7.689585959119919E-5
# Cycle 978
# Total biomass:
# Model iMM904.cmd: 5.885106383459497E-5
# Model iJN1463.cmd: 7.692996052550429E-5
# Cycle 979
# Total biomass:
# Model iMM904.cmd: 5.887052281479216E-5
# Model iJN1463.cmd: 7.695897395486982E-5
# Cycle 980
# Total biomass:
# Model iMM904.cmd: 5.8890193865793746E-5
# Model iJN1463.cmd: 7.698720743567476E-5
# Cycle 981
# Total biomass:
# Model iMM904.cmd: 5.8908373071958206E-5
# Model iJN1463.cmd: 7.701929853642433E-5
# Cycle 982
# Total biomass:
# Model iMM904.cmd: 5.8928036364962476E-5
# Model iJN1463.cmd: 7.704841794740463E-5
# Cycle 983
# Total biomass:
# Model iMM904.cmd: 5.8942323075118334E-5
# Model iJN1463.cmd: 7.7084163419944E-5
# Cycle 984
# Total biomass:
# Model iMM904.cmd: 5.895349149435094E-5
# Model iJN1463.cmd: 7.712387076160213E-5
# Cycle 985
# Total biomass:
# Model iMM904.cmd: 5.89671031848763E-5
# Model iJN1463.cmd: 7.716015950101782E-5
# Cycle 986
# Total biomass:
# Model iMM904.cmd: 5.89855066206042E-5
# Model iJN1463.cmd: 7.7189110076352E-5
# Cycle 987
# Total biomass:
# Model iMM904.cmd: 5.9006292587814203E-5
# Model iJN1463.cmd: 7.72192153112385E-5
# Cycle 988
# Total biomass:
# Model iMM904.cmd: 5.9023272054500375E-5
# Model iJN1463.cmd: 7.724998202879742E-5
# Cycle 989
# Total biomass:
# Model iMM904.cmd: 5.903792032510786E-5
# Model iJN1463.cmd: 7.728321212473741E-5
# Cycle 990
# Total biomass:
# Model iMM904.cmd: 5.905524496884136E-5
# Model iJN1463.cmd: 7.731222255931696E-5
# Cycle 991
# Total biomass:
# Model iMM904.cmd: 5.907375347215871E-5
# Model iJN1463.cmd: 7.734104703672532E-5
# Cycle 992
# Total biomass:
# Model iMM904.cmd: 5.908767707315898E-5
# Model iJN1463.cmd: 7.737711669210051E-5
# Cycle 993
# Total biomass:
# Model iMM904.cmd: 5.910170505255394E-5
# Model iJN1463.cmd: 7.741215753926428E-5
# Cycle 994
# Total biomass:
# Model iMM904.cmd: 5.912150985463487E-5
# Model iJN1463.cmd: 7.743991947795841E-5
# Cycle 995
# Total biomass:
# Model iMM904.cmd: 5.914131554510879E-5
# Model iJN1463.cmd: 7.746681907034397E-5
# Cycle 996
# Total biomass:
# Model iMM904.cmd: 5.916081455930998E-5
# Model iJN1463.cmd: 7.749354036794165E-5
# Cycle 997
# Total biomass:
# Model iMM904.cmd: 5.9179261684870154E-5
# Model iJN1463.cmd: 7.752101875440475E-5
# Cycle 998
# Total biomass:
# Model iMM904.cmd: 5.9196331931943954E-5
# Model iJN1463.cmd: 7.754980364268603E-5
# Cycle 999
# Total biomass:
# Model iMM904.cmd: 5.92135397560729E-5
# Model iJN1463.cmd: 7.757910098695371E-5
# Cycle 1000
# Total biomass:
# Model iMM904.cmd: 5.922870088700917E-5
# Model iJN1463.cmd: 7.761003494753126E-5
# Cycle 1001
# End of simulation
# Total time = 7605.115s
#
# STDERR empty.

# %% [markdown]
# Para revisar la biomasa total

# %%
sim.total_biomass.plot(x = "cycle")
# Out:
# <AxesSubplot:xlabel='cycle'>

# %% [markdown]
# Graficamos los resultados de biomasa y demás metabolitos interesantes en el grid:

# %%
im = sim.get_biomass_image('iMM904', params.all_params['maxCycles'])
im2 = sim.get_biomass_image('iJN1463',params.all_params['maxCycles'])

final = np.zeros((grid_size,grid_size,3))
final[:,:,0] = im / np.max(im)
final[:,:,1] = im2 / np.max(im2)
for rock in rock_locs:
    final[rock[0],rock[1],0:3] = 0.4 
from matplotlib import pyplot as plt
ﬁg, ax = plt.subplots(ﬁgsize = (3.1, 3.1))
ax.imshow(ﬁnal)
plt.imshow(final)

# %%
plt.imshow(sim.get_metabolite_image("succ_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("ac_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("nh4_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("o2_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("catechol_e",params.all_params['maxCycles']))
