# %% [markdown]
# **Soil-air interface.**
#
# Using the functionality of COMETS, one can design simulations which go beyond in silico corollaries of lab experiments to make predictions for environments mimicking natural ecosystems, which is a necessary step for understanding natural ecology from first principles. In this example, we consider a simulation of a soil environment. We use source-and-sink functions to model how a root provides organic acids to the environment while removing ammonia (Huang et al 2014 Botany). While we restrict the root functionality to a source/sink, one could use functionality demonstrated above, for example extracellular enzymes, to generate feedback loops between microbe-produced metabolites and root exudation. We use fixed metabolite concentrations to mimic the largely unchanging air interface above a root, which generates an oxygen gradient. Additionally, since soil is characterized by strong spatial structure with many impenetrable barriers that localized interactions (Nunan 2017), we place “rock” barriers throughout the simulation area. A more complex simulation could use varying diffusion constants for metabolites, as described in a previous protocol (Virtual Petri Dish). Similarly, we use standard diffusion of biomass, but this could be changed to use pushing force or non-linear diffusion for a potentially increased realism.

# %%
import cobra 
import sys 
import copy 
import numpy as np 
from matplotlib import pyplot as plt 
import cometspy as c

# %% [markdown]
# Para nuestro proyecto, utilizaremos Escherichia coli (modelo iAF1260), Pseudomonas putida (modelo iJN1463) y Saccharomyces Cerevisiae (modelo iMM904), recuperados de la base de datos BIGG.
#
# Cambiamos los bounds de las funciones objetivo de los modelos:

# %%
model_dir = "./modelos" # model location
iMM = cobra.io.read_sbml_model(model_dir + '/iMM904.xml')
iJN = cobra.io.read_sbml_model(model_dir + '/iJN1463.xml')

iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').lower_bound = 0
iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').upper_bound = 1000

iMM.reactions.get_by_id('BIOMASS_SC5_notrace').lower_bound = 0
iMM.reactions.get_by_id('BIOMASS_SC5_notrace').upper_bound = 1000

# %% [markdown]
# Luego se convierten estos modelos al formato de COMETS. Se utilizan funciones helper para dos cosas: a) Asegurar que el modelo en COMETS no confunda las reacciones de "sink" con las de exchange, ya que en COBRA están desbalanceadas y por tanto se parecen a las de exchange, y b) abrir todos los bounds de las reacciones de exchange, para que COMETS controle la composición del medio.

# %%
iMM_comets = c.model(iMM)
iMM_comets.ensure_sinks_are_not_exchanges()
iMM_comets.open_exchanges()

iJN_comets = c.model(iJN)
iJN_comets.ensure_sinks_are_not_exchanges()
iJN_comets.open_exchanges()

# %% [markdown]
# El mundo que se simulará tendrá dimensiones de 30x30. El eje de la izquierda (x = 0) corresponde a la raíz, y el eje superior (y = 0) corresponde al aire. La biomasa y las rocas se distribuyen en el resto del grid. Donde hayan rocas no puede haber ni biomasa ni metabolitos, así que seleccionamos esos lugares primero. Para esta simulación, se generarán 3 rocas con un un tamaño medio de 1 cuadraditos. Para generar las piedras se utiliza la función helper grow_rocks.

# %%
from cometspy.utils import grow_rocks, pick_random_locations

grid_size = 15 # 100
n_rocks = 27 # 70
rock_locs = grow_rocks(n = n_rocks, xrange = [1,grid_size-1],yrange = [1,grid_size-1],mean_size = 1)

# %% [markdown]
# Cada especie será plantada en 20 lugares sin sobreponerse. Para esto se utiliza la función helper pick_random_locations, la cual toma como argumento una tupla generada anteriormente que marca lugares "prohibidos", como los cuadrados donde se encuentran las rocas.
#
# Generamos una copia de rock_locs para no cambiarla accidentalmente, y la llamamos forbbiden_locs:

# %%
import copy
forbidden_locs = copy.deepcopy(rock_locs)

# %% [markdown]
# Ahora elegimos al azar los lugares para cada especie, y los vamos añadiendo a la lista forbidden locs para que no se sobrepongan:

# %%
founders_per_species = 15 # 60
iMM_locs = pick_random_locations(n = founders_per_species, 
                                   xrange = [1,grid_size], yrange = [1,grid_size], 
                                   forbidden_locs = forbidden_locs)
forbidden_locs.extend(iMM_locs)
iJN_locs = pick_random_locations(founders_per_species, [1,grid_size],[1,grid_size], forbidden_locs)

# %% [markdown]
# Para graficar los lugares utilizamos matplotlib:

# %%
from matplotlib import pyplot as plt
initial_image = np.zeros((grid_size,grid_size,3))
for rock in rock_locs:
    initial_image[rock[0],rock[1],0:3] = 0.5 
for loc in iMM_locs:
    initial_image[loc[0],loc[1],1] = 1
for loc in iJN_locs:
    initial_image[loc[0],loc[1],2] = 1
plt.imshow(initial_image)

# %% [markdown]
# Generamos el layout y agregamos las rocas:

# %%
# iAF
iMM_initial_pop = [] 
for loc in iJN_locs: 
    iMM_initial_pop.append([loc[0], loc[1], 1.e-8]) 
iMM_comets.initial_pop = iMM_initial_pop 
# iJN
iJN_initial_pop = [] 
for loc in iJN_locs: 
    iJN_initial_pop.append([loc[0], loc[1], 1.e-7]) 
iJN_comets.initial_pop = iJN_initial_pop

# %% [markdown]
# Setteamos las poblaciones iniciales para cada especie, con esto los modelos están listos y los añadimos al layout:

# %%
layout = c.layout([iMM_comets, iJN_comets])
layout.grid = [grid_size,grid_size]
layout.add_barriers(rock_locs)

# %% [markdown]
# Añadimos los metabolitos que estarán inicialmente disponibles en el ambiente. Usamos la función helper add_typical_trace_metabolites() para las trazas típicas. Bajamos el valor del oxígeno dado que la idea es que el que esté disponible difunda desde la atmósfera. Añadimos algunos metabolitos que no se añadieron con la función helper:

# %%
layout.add_typical_trace_metabolites()
layout.set_specific_metabolite('o2_e',0.00001)
layout.set_specific_metabolite('hco3_e',1000)
layout.set_specific_metabolite('co2_e',1000)
#layout.set_specific_metabolite('h2_e',1000)
layout.set_specific_metabolite('so3_e',1000)
layout.set_specific_metabolite('nh4_e',0.000001)

layout.set_specific_metabolite('glc__D_e',0.0000001)
layout.set_specific_metabolite('meoh_e',0.00000001)
layout.set_specific_metabolite('cys__L_e',0.0000001)
layout.set_specific_metabolite('catechol_e',0.0000001)

# %% [markdown]
# Para la capa de aire, dejamos el oxígeno en un valor constante. Al fondo también dejamos al oxígeno en un valor fijo e igual a 0, para simular el efecto de difusión. De manera similar, hacemos lo mismo con el amoniaco y la raíz en la parte izquierda:

# %%
# set static media of O2 and CO2 at the top and bottom-- the "air" and continuous loss of O2 downwards
for x in range(grid_size):
    layout.set_specific_static_at_location('o2_e', (x,0), .0001) # top
    layout.set_specific_static_at_location('o2_e', (x,grid_size-1), 0.) # bottom
    layout.set_specific_static_at_location('co2_e', (x,0), .0001)
    
for x in range(grid_size):
    layout.set_specific_static_at_location('nh4_e', (0,x), 0.0)

# %% [markdown]
# La raíz consume todo el amoniaco, pero es una fuente de acidos orgánicos y metanol para el ambiente. Asumiendo una tasa fija:

# %%
for x in range(grid_size):
    layout.set_specific_refresh_at_location('cit_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('meoh_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('succ_e', (0,x), .000001)

# %% [markdown]
# El layout y los modelos están listos, ahora setteamos los parámetros de la simulación:

# %%
params = c.params()
params.set_param('timeStep', 0.1)
params.set_param('maxCycles', 1000)
params.set_param('maxSpaceBiomass', 10)
params.set_param('deathRate', 0.0001) # die at rate of 1/10000 per hour
params.set_param('writeBiomassLog', True)
params.set_param('BiomassLogRate', 500)
params.set_param('writeMediaLog', True)
params.set_param('MediaLogRate', 500)
params.set_param("writeFluxLog", True)
params.set_param("FluxLogRate", 500)
params.set_param('numRunThreads', 3)
params.set_param('defaultKm', 0.000001)

# %% [markdown]
# Ahora creamos el objeto de la simulación y la corremos. Ojito que se demora y el pc empieza a despegar.

# %%
sim = c.comets(layout, params)
sim.run(False)
# Out:
# Running COMETS simulation ...
# C:\Users\pabli\AppData\Local\Temp/ipykernel_7976/1491467366.py:2: DtypeWarning: Columns (13,14,15,16,17,18,23,24,25,27,28,29,31,33,35,46,51,62,67,68,69,70,82,84,92,102,104,122,123,124,130,135,142,162,163,169,171,189,193,195,198,223,232,248,249,255,256,257,258,287,292,295,296,297,298,301,312,315,324,325,328,333,339,344,348,375,381,415,419,421,423,424,425,426,436,437,438,440,444,445,454,455,463,469,481,511,513,519,520,533,538,541,548,554,556,560,562,563,564,576,585,590,614,619,633,646,648,650,651,653,657,658,664,674,680,691,692,693,695,719,720,722,723,724,726,728,732,739,740,744,751,753,756,763,765,766,774,775,778,782,803,804,806,810,863,864,869,870,872,881,883,897,923,929,930,932,934,936,940,941,942,943,979,984,1014,1036,1040,1062,1063,1064,1068,1071,1080,1084,1086,1087,1097,1098,1113,1126,1130,1132,1134,1141,1142,1164,1165,1176,1180,1183,1184,1188,1195,1208,1209,1210,1214,1215,1216,1217,1218,1219,1233,1237,1263,1265,1266,1269,1277,1280,1281,1282,1283,1284,1288,1299,1301,1304,1308,1313,1332,1334,1336,1346,1354,1355,1369,1370,1372,1402,1405,1406,1410,1411,1416,1426,1429,1442,1447,1453,1481,1487,1503,1515,1525,1526,1530,1535,1549,1565,1567,1569,1572,1573,1578,1580,1585,1586,1587,1599,1617,1629,1630,1645,1664,1676,1689,1697,1699,1700,1747,1764,1765,1767,1771,1773,1775,1776,1777,1779,1809,1811,1815,1877,1878,1879,1880,1890,1891,1892,1911,1914,1915,1919,1920,1921,1926,1968,1984,1986,1987,1989,1990,1991,1993,1995,2037,2043,2080,2124,2133,2134,2160,2167,2168,2169,2170,2205,2227,2257,2263,2269,2270,2279,2371,2374,2382,2390,2398,2399,2401,2402,2420,2424,2426,2427,2428,2429,2431,2472,2474,2476,2477,2480,2533,2534,2535,2575,2639,2680,2694,2713,2716,2723,2764,2765,2769,2790,2833,2841,2857,2862,2879,2880,2883,2884,2888,2908,2912,2913,2916,2930) have mixed types.Specify dtype option on import or set low_memory=False.
#   sim.run(False)
# Done!

# %%
print(sim.run_output)
print(sim.run_errors)
# Out:
# -script
# running script file: C:\Users\pabli\OneDrive\Escritorio\COMETS\ODRM\simulaciones\2_modelos\Saccharomyces_putida_15x15_0.0000001_catechol_cambio_saccharomyces\Saccharomyces_putida_15x15_0.0000001_catechol_cambio_putida_1e7/.current_script_0x1faf771fa90
# Current Java version: 17.0.1
# Parameters file .current_global_0x1faf771fa90 loaded.
# Parameters file .current_package_0x1faf771fa90 loaded.
# Loading layout file '.current_layout_0x1faf771fa90'...
# null\COMETS_manifest.txt (El sistema no puede encontrar la ruta especificada)
# Unable to initialize manifest file.
# Continuing without writing manifest file.
# Found 2 model files!
# Loading '.\iMM904.cmd' ...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution = 133.8587770175764
# Loading '.\iJN1463.cmd' ...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution = 237.06607191111308
# Constructing world...
# Done!
# medialist	12dgr160_e	12dgr180_e	13BDglcn_e	13dampp_e	15dap_e	1ag160_e	1ag180_e	1ag181d9_e	1ag182d9d12_e	25dkglcn_e	26dap__M_e	2ameph_e	2ddglcn_e	2dhglcn_e	2hb_e	2m35mdntha_e	2mbac_e	2mbald_e	2mbtoh_e	2mppal_e	2phetoh_e	34dhbz_e	34dhcinm_e	34dhphe_e	35dnta_e	3c3hmp_e	3h4atb_e	3mb_e	3mbald_e	3mop_e	3oxoadp_e	4abut_e	4abz_e	4hbz_e	4hpro_DC_e	4hpro_LT_e	4hptn_e	4oxptn_e	5aop_e	5aptn_e	5g2oxpt_e	5mcsn_e	5oxpro_e	6atha_e	6hnac_e	8aonn_e	LalaLglu_e	Nbfortyr_e	Ncbmpts_e	R3hdec4e_e	R_3h4atba_e	R_3h6atha_e	R_3hcmrs7e_e	R_3hdcaa_e	R_3hdd5ea_e	R_3hdd6e_e	R_3hdda_e	R_3hhdca_e	R_3hhpa_e	R_3hhxa_e	R_3hnonaa_e	R_3hocta_e	R_3hpba_e	R_3hpdeca_e	R_3hphpa_e	R_3hphxa_e	R_3hpnona_e	R_3hpocta_e	R_3hppta_e	R_3hpt_e	R_3htd58e_e	R_3htd5e_e	R_3httdca_e	T4hcinnm_e	abt_e	ac_e	acac_e	acald_e	aces_e	acmtsoxin_e	acon_C_e	acpptrn_e	acser_e	actn__R_e	ade_e	adn_e	adocbl_e	ag_e	agm_e	akg_e	ala_B_e	ala__D_e	ala__L_e	alaala_e	alahis_e	alaleu_e	alathr_e	alatrp_e	algac_MG_14_e	algac_MG_23_e	algac_MG_32_e	algac_MG_41_e	algac__M_e	alltn_e	alltt_e	amet_e	apc_e	arab__D_e	arab__L_e	arbtn_e	arbtn_fe3_e	arg__D_e	arg__L_e	asn__D_e	asn__L_e	aso3_e	aso4_e	asp__L_e	balaala_e	balabala_e	balagly_e	balaleu_e	balamd_e	bhb_e	biliverd_e	btd_RR_e	btn_e	butso3_e	bz_e	ca2_e	carn_e	catechol_e	cbi_e	cbl1_e	cd2_e	cell4_e	cgly_e	chol_e	chols_e	chor_e	cinnm_e	cit_e	cl_e	cm_e	cmcbtt_e	co2_e	co_e	cobalt2_e	confrl_e	creat_e	crn_e	cro2_e	cro4_e	crtn_e	csn_e	cu2_e	cu_e	cyan_e	cys__D_e	cys__L_e	cytd_e	d2one_e	d3one_e	d4one_e	dad_2_e	dag181d9_e	dag182d9d12_e	dann_e	dca_e	dcyt_e	ddca_e	dgsn_e	dgudbutn_e	din_e	dmanur_e	dmgly_e	dmso2_e	dopa_e	dttp_e	duri_e	ecto__L_e	enter_e	epist_e	epistest_SC_e	ergst_e	ergstest_SC_e	etha_e	ethso3_e	etoh_e	fald_e	fcmcbtt_e	fe2_e	fe3_e	fe3dcit_e	fe3mcbtt_e	fe3pyovd_e	fe3pyovd_kt_e	fecost_e	fecostest_SC_e	fecrm_e	fecrm_un_e	feenter_e	feoxam_e	feoxam_un_e	fer_e	fmn_e	for_e	fru_e	fum_e	g3pc_e	g3pi_e	ga_e	gal_e	galct__D_e	galur_e	gam6p_e	gcald_e	glc__D_e	glcn_e	glcr_e	glcur_e	gln__L_e	glu__L_e	glutar_e	glx_e	gly_e	glyald_e	glyb_e	glyc__R_e	glyc_e	glyclt_e	glycol_e	glygln_e	glyglu_e	glygly_e	glymet_e	glyphe_e	glyser_e	gsn_e	gthox_e	gthrd_e	gua_e	gudac_e	gudptn_e	h2o2_e	h2o_e	h2s_e	h_e	hco3_e	hcys__L_e	hdca_e	hdcea_e	hexc_e	hg2_e	hgentis_e	his__L_e	hisgly_e	hishis_e	hom__L_e	hpta_e	hxa_e	hxan_e	iamac_e	iamoh_e	ibutac_e	ibutoh_e	icit_e	id3acald_e	ile__L_e	ind3ac_e	ind3eth_e	indole_e	inost_e	ins_e	isetac_e	k_e	lac__D_e	lac__L_e	lanost_e	lanostest_SC_e	leu__D_e	leu__L_e	leuleu_e	lnlc_e	lpspput_e	lys__D_e	lys__L_e	m_xyl_e	mal__D_e	mal__L_e	malt_e	man_e	manur_e	mcbtt_e	melib_e	meoh_e	met__D_e	met__L_e	mg2_e	mmet_e	mn2_e	mobd_e	mso3_e	mtsoxin_e	n2one_e	na1_e	nac_e	nadp_e	nh4_e	ni2_e	nmn_e	no2_e	no3_e	no_e	nona_e	o2_e	o_xyl_e	oaa_e	ocdca_e	ocdcea_e	ocdcya_e	octa_e	orn__D_e	orn_e	orot_e	oxa_e	p_xyl_e	pac_e	pacald_e	pap_e	pb2_e	pc_SC_e	pea_e	peamn_e	pectin_e	pentso3_e	pepd_e	phe__D_e	phe__L_e	pheac_e	phedca_e	phehpa_e	phehxa_e	pheme_e	phenona_e	pheocta_e	phept_e	phpyr_e	pi_e	pnto__R_e	ppa_e	ppi_e	pptrn_e	prealg_MG_14_e	prealg_MG_23_e	prealg_MG_32_e	prealg_MG_41_e	prealginate_G_e	pro__D_e	pro__L_e	progly_e	pta_e	ptd1ino_SC_e	ptrc_e	ptsla_e	pydam_e	pyovd_e	pyovd_kt_e	pyr_e	quin_e	rib__D_e	ribflv_e	sbo3_e	sbt__D_e	sbt__L_e	sel_e	ser__D_e	ser__L_e	sheme_e	skm_e	so2_e	so3_e	so4_e	spmd_e	sprm_e	srb__L_e	succ_e	sucr_e	sulfac_e	tag160_e	tag180_e	tag181d9_e	tag182d9d12_e	taur_e	tcynt_e	thm_e	thmmp_e	thmpp_e	thr__L_e	thym_e	thymd_e	tmanur_e	tnt_e	tol_e	tre_e	trp__L_e	tsul_e	ttdca_e	ttdcea_e	ttrcyc_e	tungs_e	tyr__D_e	tyr__L_e	und2one_e	ura_e	urea_e	uri_e	vacc_e	val__D_e	val__L_e	vanln_e	vanlt_e	xan_e	xtsn_e	xyl__D_e	xylt_e	zn2_e	zymst_e	zymstest_SC_e
# Cycle 1
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# FBARunThread-0 starting up.
# FBARunThread-1 starting up.
# FBARunThread-2 starting up.
# Total biomass:
# Model iMM904.cmd: 1.5670861305911944E-7
# Model iJN1463.cmd: 1.5688372946182276E-6
# Cycle 2
# Total biomass:
# Model iMM904.cmd: 1.6372486751642573E-7
# Model iJN1463.cmd: 1.6406513143989593E-6
# Cycle 3
# Total biomass:
# Model iMM904.cmd: 1.716490360320812E-7
# Model iJN1463.cmd: 1.7170930155536457E-6
# Cycle 4
# Total biomass:
# Model iMM904.cmd: 1.8020762068600022E-7
# Model iJN1463.cmd: 1.7984418075841397E-6
# Cycle 5
# Total biomass:
# Model iMM904.cmd: 1.8933976318932482E-7
# Model iJN1463.cmd: 1.884720666128516E-6
# Cycle 6
# Total biomass:
# Model iMM904.cmd: 1.9903129192512107E-7
# Model iJN1463.cmd: 1.9759690521431145E-6
# Cycle 7
# Total biomass:
# Model iMM904.cmd: 2.0929779096217972E-7
# Model iJN1463.cmd: 2.0723870395305356E-6
# Cycle 8
# Total biomass:
# Model iMM904.cmd: 2.2012603357604658E-7
# Model iJN1463.cmd: 2.174020384811542E-6
# Cycle 9
# Total biomass:
# Model iMM904.cmd: 2.315272827782466E-7
# Model iJN1463.cmd: 2.280913968695624E-6
# Cycle 10
# Total biomass:
# Model iMM904.cmd: 2.4350172589569053E-7
# Model iJN1463.cmd: 2.393119863495523E-6
# Cycle 11
# Total biomass:
# Model iMM904.cmd: 2.5605023587770393E-7
# Model iJN1463.cmd: 2.5109341773459284E-6
# Cycle 12
# Total biomass:
# Model iMM904.cmd: 2.6917669375246913E-7
# Model iJN1463.cmd: 2.634837171393781E-6
# Cycle 13
# Total biomass:
# Model iMM904.cmd: 2.8288210044746844E-7
# Model iJN1463.cmd: 2.764618824778363E-6
# Cycle 14
# Total biomass:
# Model iMM904.cmd: 2.9716338635146584E-7
# Model iJN1463.cmd: 2.900504781672651E-6
# Cycle 15
# Total biomass:
# Model iMM904.cmd: 3.1201246519707216E-7
# Model iJN1463.cmd: 3.0426033425769276E-6
# Cycle 16
# Total biomass:
# Model iMM904.cmd: 3.2741448904970275E-7
# Model iJN1463.cmd: 3.1911410104338318E-6
# Cycle 17
# Total biomass:
# Model iMM904.cmd: 3.4333473654878155E-7
# Model iJN1463.cmd: 3.346514644096112E-6
# Cycle 18
# Total biomass:
# Model iMM904.cmd: 3.5961773719978176E-7
# Model iJN1463.cmd: 3.509284703191307E-6
# Cycle 19
# Total biomass:
# Model iMM904.cmd: 3.7613988615480394E-7
# Model iJN1463.cmd: 3.679347127996577E-6
# Cycle 20
# Total biomass:
# Model iMM904.cmd: 3.927812345427381E-7
# Model iJN1463.cmd: 3.856818706578575E-6
# Cycle 21
# Total biomass:
# Model iMM904.cmd: 4.095367118073387E-7
# Model iJN1463.cmd: 4.041744804990529E-6
# Cycle 22
# Total biomass:
# Model iMM904.cmd: 4.2646630608673827E-7
# Model iJN1463.cmd: 4.2342957199414565E-6
# Cycle 23
# Total biomass:
# Model iMM904.cmd: 4.435946580792549E-7
# Model iJN1463.cmd: 4.434657238025943E-6
# Cycle 24
# Total biomass:
# Model iMM904.cmd: 4.609669122383284E-7
# Model iJN1463.cmd: 4.643130318960563E-6
# Cycle 25
# Total biomass:
# Model iMM904.cmd: 4.78601919407309E-7
# Model iJN1463.cmd: 4.8600649023195044E-6
# Cycle 26
# Total biomass:
# Model iMM904.cmd: 4.965663788475674E-7
# Model iJN1463.cmd: 5.085944676181753E-6
# Cycle 27
# Total biomass:
# Model iMM904.cmd: 5.14844814956285E-7
# Model iJN1463.cmd: 5.320875676528514E-6
# Cycle 28
# Total biomass:
# Model iMM904.cmd: 5.333419939797639E-7
# Model iJN1463.cmd: 5.5654464566905555E-6
# Cycle 29
# Total biomass:
# Model iMM904.cmd: 5.519903338627585E-7
# Model iJN1463.cmd: 5.820298267767244E-6
# Cycle 30
# Total biomass:
# Model iMM904.cmd: 5.706051691164594E-7
# Model iJN1463.cmd: 6.086038429314433E-6
# Cycle 31
# Total biomass:
# Model iMM904.cmd: 5.893720644186644E-7
# Model iJN1463.cmd: 6.362493769510003E-6
# Cycle 32
# Total biomass:
# Model iMM904.cmd: 6.083356925765112E-7
# Model iJN1463.cmd: 6.649428768550005E-6
# Cycle 33
# Total biomass:
# Model iMM904.cmd: 6.275341582686669E-7
# Model iJN1463.cmd: 6.947187810730516E-6
# Cycle 34
# Total biomass:
# Model iMM904.cmd: 6.47007057280177E-7
# Model iJN1463.cmd: 7.255916030557692E-6
# Cycle 35
# Total biomass:
# Model iMM904.cmd: 6.668361780253512E-7
# Model iJN1463.cmd: 7.575765665824117E-6
# Cycle 36
# Total biomass:
# Model iMM904.cmd: 6.871134181739006E-7
# Model iJN1463.cmd: 7.906381989250442E-6
# Cycle 37
# Total biomass:
# Model iMM904.cmd: 7.079230282960009E-7
# Model iJN1463.cmd: 8.247613175294984E-6
# Cycle 38
# Total biomass:
# Model iMM904.cmd: 7.293899077159797E-7
# Model iJN1463.cmd: 8.599589752414835E-6
# Cycle 39
# Total biomass:
# Model iMM904.cmd: 7.515347469357629E-7
# Model iJN1463.cmd: 8.96256103861205E-6
# Cycle 40
# Total biomass:
# Model iMM904.cmd: 7.743443435974563E-7
# Model iJN1463.cmd: 9.334631212311134E-6
# Cycle 41
# Total biomass:
# Model iMM904.cmd: 7.977877566985842E-7
# Model iJN1463.cmd: 9.712016085083831E-6
# Cycle 42
# Total biomass:
# Model iMM904.cmd: 8.218824619785888E-7
# Model iJN1463.cmd: 1.0092004334888687E-5
# Cycle 43
# Total biomass:
# Model iMM904.cmd: 8.466812075369007E-7
# Model iJN1463.cmd: 1.047175065587664E-5
# Cycle 44
# Total biomass:
# Model iMM904.cmd: 8.72125144166117E-7
# Model iJN1463.cmd: 1.0849765467436325E-5
# Cycle 45
# Total biomass:
# Model iMM904.cmd: 8.982633298219601E-7
# Model iJN1463.cmd: 1.1224116058556186E-5
# Cycle 46
# Total biomass:
# Model iMM904.cmd: 9.251609289063983E-7
# Model iJN1463.cmd: 1.159533279543252E-5
# Cycle 47
# Total biomass:
# Model iMM904.cmd: 9.528110367464399E-7
# Model iJN1463.cmd: 1.1964147071233843E-5
# Cycle 48
# Total biomass:
# Model iMM904.cmd: 9.812362543312545E-7
# Model iJN1463.cmd: 1.2331151564015644E-5
# Cycle 49
# Total biomass:
# Model iMM904.cmd: 1.0104712230273846E-6
# Model iJN1463.cmd: 1.269671339183616E-5
# Cycle 50
# Total biomass:
# Model iMM904.cmd: 1.040516834245266E-6
# Model iJN1463.cmd: 1.3060973161303386E-5
# Cycle 51
# Total biomass:
# Model iMM904.cmd: 1.0714576576865787E-6
# Model iJN1463.cmd: 1.3424197917141716E-5
# Cycle 52
# Total biomass:
# Model iMM904.cmd: 1.103311672424827E-6
# Model iJN1463.cmd: 1.378632260936373E-5
# Cycle 53
# Total biomass:
# Model iMM904.cmd: 1.1360727981750184E-6
# Model iJN1463.cmd: 1.4146906505746058E-5
# Cycle 54
# Total biomass:
# Model iMM904.cmd: 1.169780476458344E-6
# Model iJN1463.cmd: 1.4506090318958565E-5
# Cycle 55
# Total biomass:
# Model iMM904.cmd: 1.2043044945607064E-6
# Model iJN1463.cmd: 1.4863648866344102E-5
# Cycle 56
# Total biomass:
# Model iMM904.cmd: 1.2393079025103835E-6
# Model iJN1463.cmd: 1.5218389885555028E-5
# Cycle 57
# Total biomass:
# Model iMM904.cmd: 1.2746737748573585E-6
# Model iJN1463.cmd: 1.556449014005954E-5
# Cycle 58
# Total biomass:
# Model iMM904.cmd: 1.3104427709945517E-6
# Model iJN1463.cmd: 1.589909600227606E-5
# Cycle 59
# Total biomass:
# Model iMM904.cmd: 1.346807043964104E-6
# Model iJN1463.cmd: 1.6221405208305812E-5
# Cycle 60
# Total biomass:
# Model iMM904.cmd: 1.3829580912125335E-6
# Model iJN1463.cmd: 1.6531453339088614E-5
# Cycle 61
# Total biomass:
# Model iMM904.cmd: 1.4197124574052012E-6
# Model iJN1463.cmd: 1.6824017392672087E-5
# Cycle 62
# Total biomass:
# Model iMM904.cmd: 1.4568467547859559E-6
# Model iJN1463.cmd: 1.7108838570625167E-5
# Cycle 63
# Total biomass:
# Model iMM904.cmd: 1.4941732042643994E-6
# Model iJN1463.cmd: 1.738105579677073E-5
# Cycle 64
# Total biomass:
# Model iMM904.cmd: 1.5317653916872489E-6
# Model iJN1463.cmd: 1.7641604821145233E-5
# Cycle 65
# Total biomass:
# Model iMM904.cmd: 1.5697846818098107E-6
# Model iJN1463.cmd: 1.7891203721249992E-5
# Cycle 66
# Total biomass:
# Model iMM904.cmd: 1.6082191476402786E-6
# Model iJN1463.cmd: 1.8133271258471943E-5
# Cycle 67
# Total biomass:
# Model iMM904.cmd: 1.647049291328079E-6
# Model iJN1463.cmd: 1.836788728591308E-5
# Cycle 68
# Total biomass:
# Model iMM904.cmd: 1.686188962847243E-6
# Model iJN1463.cmd: 1.8595700118326127E-5
# Cycle 69
# Total biomass:
# Model iMM904.cmd: 1.7255318237159427E-6
# Model iJN1463.cmd: 1.8817664352950717E-5
# Cycle 70
# Total biomass:
# Model iMM904.cmd: 1.7649805638690062E-6
# Model iJN1463.cmd: 1.9035465867083378E-5
# Cycle 71
# Total biomass:
# Model iMM904.cmd: 1.8049696089708477E-6
# Model iJN1463.cmd: 1.9248148957500725E-5
# Cycle 72
# Total biomass:
# Model iMM904.cmd: 1.8454511213331321E-6
# Model iJN1463.cmd: 1.945611385281341E-5
# Cycle 73
# Total biomass:
# Model iMM904.cmd: 1.8860850829051181E-6
# Model iJN1463.cmd: 1.9662609069452082E-5
# Cycle 74
# Total biomass:
# Model iMM904.cmd: 1.9270824164521334E-6
# Model iJN1463.cmd: 1.9863726795050432E-5
# Cycle 75
# Total biomass:
# Model iMM904.cmd: 1.968078391116332E-6
# Model iJN1463.cmd: 2.0064148901762698E-5
# Cycle 76
# Total biomass:
# Model iMM904.cmd: 2.0093762180729436E-6
# Model iJN1463.cmd: 2.0262486293360594E-5
# Cycle 77
# Total biomass:
# Model iMM904.cmd: 2.0504812740628284E-6
# Model iJN1463.cmd: 2.045876407780078E-5
# Cycle 78
# Total biomass:
# Model iMM904.cmd: 2.091920967222277E-6
# Model iJN1463.cmd: 2.0652932412451355E-5
# Cycle 79
# Total biomass:
# Model iMM904.cmd: 2.1334080173409904E-6
# Model iJN1463.cmd: 2.0844140254336325E-5
# Cycle 80
# Total biomass:
# Model iMM904.cmd: 2.1751161806809315E-6
# Model iJN1463.cmd: 2.103438319957677E-5
# Cycle 81
# Total biomass:
# Model iMM904.cmd: 2.2170231686359387E-6
# Model iJN1463.cmd: 2.1223250141883003E-5
# Cycle 82
# Total biomass:
# Model iMM904.cmd: 2.25949224030239E-6
# Model iJN1463.cmd: 2.141004122464482E-5
# Cycle 83
# Total biomass:
# Model iMM904.cmd: 2.302367618512147E-6
# Model iJN1463.cmd: 2.1595924679587202E-5
# Cycle 84
# Total biomass:
# Model iMM904.cmd: 2.3456314495743486E-6
# Model iJN1463.cmd: 2.1780763881227917E-5
# Cycle 85
# Total biomass:
# Model iMM904.cmd: 2.3887941417977027E-6
# Model iJN1463.cmd: 2.1965102775417626E-5
# Cycle 86
# Total biomass:
# Model iMM904.cmd: 2.431715720588804E-6
# Model iJN1463.cmd: 2.2151007051903676E-5
# Cycle 87
# Total biomass:
# Model iMM904.cmd: 2.4739980291867783E-6
# Model iJN1463.cmd: 2.2341661980437353E-5
# Cycle 88
# Total biomass:
# Model iMM904.cmd: 2.5160794862711944E-6
# Model iJN1463.cmd: 2.2529825392156187E-5
# Cycle 89
# Total biomass:
# Model iMM904.cmd: 2.5581500613925984E-6
# Model iJN1463.cmd: 2.2715762018826886E-5
# Cycle 90
# Total biomass:
# Model iMM904.cmd: 2.6004981500702705E-6
# Model iJN1463.cmd: 2.290003147399462E-5
# Cycle 91
# Total biomass:
# Model iMM904.cmd: 2.6429979974689435E-6
# Model iJN1463.cmd: 2.308357375290448E-5
# Cycle 92
# Total biomass:
# Model iMM904.cmd: 2.6858615911080027E-6
# Model iJN1463.cmd: 2.326439907101522E-5
# Cycle 93
# Total biomass:
# Model iMM904.cmd: 2.73015018979617E-6
# Model iJN1463.cmd: 2.3439323818027826E-5
# Cycle 94
# Total biomass:
# Model iMM904.cmd: 2.7752304789338457E-6
# Model iJN1463.cmd: 2.3615824451521484E-5
# Cycle 95
# Total biomass:
# Model iMM904.cmd: 2.8205587433742387E-6
# Model iJN1463.cmd: 2.3793028997611076E-5
# Cycle 96
# Total biomass:
# Model iMM904.cmd: 2.8662184367684784E-6
# Model iJN1463.cmd: 2.3970113726578833E-5
# Cycle 97
# Total biomass:
# Model iMM904.cmd: 2.912196144457263E-6
# Model iJN1463.cmd: 2.4147125985640537E-5
# Cycle 98
# Total biomass:
# Model iMM904.cmd: 2.9585290150551232E-6
# Model iJN1463.cmd: 2.4323518065622625E-5
# Cycle 99
# Total biomass:
# Model iMM904.cmd: 3.0050102926053474E-6
# Model iJN1463.cmd: 2.449892998071704E-5
# Cycle 100
# Total biomass:
# Model iMM904.cmd: 3.0517610202216632E-6
# Model iJN1463.cmd: 2.4673349943883027E-5
# Cycle 101
# Total biomass:
# Model iMM904.cmd: 3.0987760041724933E-6
# Model iJN1463.cmd: 2.484657911082513E-5
# Cycle 102
# Total biomass:
# Model iMM904.cmd: 3.1461650574968427E-6
# Model iJN1463.cmd: 2.5019409328414593E-5
# Cycle 103
# Total biomass:
# Model iMM904.cmd: 3.1936779735295464E-6
# Model iJN1463.cmd: 2.519190274985649E-5
# Cycle 104
# Total biomass:
# Model iMM904.cmd: 3.2408855436108136E-6
# Model iJN1463.cmd: 2.53678087052734E-5
# Cycle 105
# Total biomass:
# Model iMM904.cmd: 3.288990686115753E-6
# Model iJN1463.cmd: 2.5537994651417334E-5
# Cycle 106
# Total biomass:
# Model iMM904.cmd: 3.3374884168744837E-6
# Model iJN1463.cmd: 2.570572753298827E-5
# Cycle 107
# Total biomass:
# Model iMM904.cmd: 3.3865049342786836E-6
# Model iJN1463.cmd: 2.5872841381014464E-5
# Cycle 108
# Total biomass:
# Model iMM904.cmd: 3.435904669692025E-6
# Model iJN1463.cmd: 2.604016248764989E-5
# Cycle 109
# Total biomass:
# Model iMM904.cmd: 3.4857518927987314E-6
# Model iJN1463.cmd: 2.6207016359031475E-5
# Cycle 110
# Total biomass:
# Model iMM904.cmd: 3.535870135729798E-6
# Model iJN1463.cmd: 2.6373407216172505E-5
# Cycle 111
# Total biomass:
# Model iMM904.cmd: 3.5862399298848165E-6
# Model iJN1463.cmd: 2.654004310062036E-5
# Cycle 112
# Total biomass:
# Model iMM904.cmd: 3.6357817025699014E-6
# Model iJN1463.cmd: 2.6709424914972485E-5
# Cycle 113
# Total biomass:
# Model iMM904.cmd: 3.6854682115752846E-6
# Model iJN1463.cmd: 2.6875814902147327E-5
# Cycle 114
# Total biomass:
# Model iMM904.cmd: 3.735209580982698E-6
# Model iJN1463.cmd: 2.7042565055359507E-5
# Cycle 115
# Total biomass:
# Model iMM904.cmd: 3.7849830296997737E-6
# Model iJN1463.cmd: 2.7207553558437745E-5
# Cycle 116
# Total biomass:
# Model iMM904.cmd: 3.834950111523485E-6
# Model iJN1463.cmd: 2.7373148367777506E-5
# Cycle 117
# Total biomass:
# Model iMM904.cmd: 3.88500735589656E-6
# Model iJN1463.cmd: 2.75388522643392E-5
# Cycle 118
# Total biomass:
# Model iMM904.cmd: 3.935012944401691E-6
# Model iJN1463.cmd: 2.7703919069796988E-5
# Cycle 119
# Total biomass:
# Model iMM904.cmd: 3.985260397673761E-6
# Model iJN1463.cmd: 2.7868491019754988E-5
# Cycle 120
# Total biomass:
# Model iMM904.cmd: 4.035934279718061E-6
# Model iJN1463.cmd: 2.803273158457306E-5
# Cycle 121
# Total biomass:
# Model iMM904.cmd: 4.086591019503612E-6
# Model iJN1463.cmd: 2.819680444781649E-5
# Cycle 122
# Total biomass:
# Model iMM904.cmd: 4.136795269740943E-6
# Model iJN1463.cmd: 2.836365850618298E-5
# Cycle 123
# Total biomass:
# Model iMM904.cmd: 4.186274266707191E-6
# Model iJN1463.cmd: 2.8530311205042306E-5
# Cycle 124
# Total biomass:
# Model iMM904.cmd: 4.2361104323974835E-6
# Model iJN1463.cmd: 2.8694936206790037E-5
# Cycle 125
# Total biomass:
# Model iMM904.cmd: 4.28619472790665E-6
# Model iJN1463.cmd: 2.885515122615122E-5
# Cycle 126
# Total biomass:
# Model iMM904.cmd: 4.336632969930151E-6
# Model iJN1463.cmd: 2.9015891245405414E-5
# Cycle 127
# Total biomass:
# Model iMM904.cmd: 4.38725457397123E-6
# Model iJN1463.cmd: 2.9177347149229554E-5
# Cycle 128
# Total biomass:
# Model iMM904.cmd: 4.438214353524795E-6
# Model iJN1463.cmd: 2.933835764007746E-5
# Cycle 129
# Total biomass:
# Model iMM904.cmd: 4.489049714678733E-6
# Model iJN1463.cmd: 2.94997358593815E-5
# Cycle 130
# Total biomass:
# Model iMM904.cmd: 4.540253198617021E-6
# Model iJN1463.cmd: 2.9660756539147135E-5
# Cycle 131
# Total biomass:
# Model iMM904.cmd: 4.5914405160548545E-6
# Model iJN1463.cmd: 2.982177307163176E-5
# Cycle 132
# Total biomass:
# Model iMM904.cmd: 4.642710460258898E-6
# Model iJN1463.cmd: 2.9982390408245546E-5
# Cycle 133
# Total biomass:
# Model iMM904.cmd: 4.694066494037059E-6
# Model iJN1463.cmd: 3.014264121581536E-5
# Cycle 134
# Total biomass:
# Model iMM904.cmd: 4.74541746918817E-6
# Model iJN1463.cmd: 3.0302721872300036E-5
# Cycle 135
# Total biomass:
# Model iMM904.cmd: 4.7965107759605315E-6
# Model iJN1463.cmd: 3.0462292648404835E-5
# Cycle 136
# Total biomass:
# Model iMM904.cmd: 4.847921086543068E-6
# Model iJN1463.cmd: 3.0619837084623696E-5
# Cycle 137
# Total biomass:
# Model iMM904.cmd: 4.899840101016692E-6
# Model iJN1463.cmd: 3.077729962397283E-5
# Cycle 138
# Total biomass:
# Model iMM904.cmd: 4.95186699524784E-6
# Model iJN1463.cmd: 3.093519947058504E-5
# Cycle 139
# Total biomass:
# Model iMM904.cmd: 5.004081981539833E-6
# Model iJN1463.cmd: 3.109335539770076E-5
# Cycle 140
# Total biomass:
# Model iMM904.cmd: 5.0561561052761966E-6
# Model iJN1463.cmd: 3.125075241989057E-5
# Cycle 141
# Total biomass:
# Model iMM904.cmd: 5.108421766196438E-6
# Model iJN1463.cmd: 3.140791169834337E-5
# Cycle 142
# Total biomass:
# Model iMM904.cmd: 5.160286682066912E-6
# Model iJN1463.cmd: 3.1565486020158134E-5
# Cycle 143
# Total biomass:
# Model iMM904.cmd: 5.212465584207512E-6
# Model iJN1463.cmd: 3.172188208733745E-5
# Cycle 144
# Total biomass:
# Model iMM904.cmd: 5.264746455416393E-6
# Model iJN1463.cmd: 3.1877808694915266E-5
# Cycle 145
# Total biomass:
# Model iMM904.cmd: 5.317634218668647E-6
# Model iJN1463.cmd: 3.2033049052667794E-5
# Cycle 146
# Total biomass:
# Model iMM904.cmd: 5.370924745200687E-6
# Model iJN1463.cmd: 3.218819289108458E-5
# Cycle 147
# Total biomass:
# Model iMM904.cmd: 5.423991423517199E-6
# Model iJN1463.cmd: 3.234339752199699E-5
# Cycle 148
# Total biomass:
# Model iMM904.cmd: 5.477460954475941E-6
# Model iJN1463.cmd: 3.2497135059642104E-5
# Cycle 149
# Total biomass:
# Model iMM904.cmd: 5.5310576022368884E-6
# Model iJN1463.cmd: 3.2649855230592046E-5
# Cycle 150
# Total biomass:
# Model iMM904.cmd: 5.585199152558116E-6
# Model iJN1463.cmd: 3.280206081552542E-5
# Cycle 151
# Total biomass:
# Model iMM904.cmd: 5.64020360353326E-6
# Model iJN1463.cmd: 3.29539441000944E-5
# Cycle 152
# Total biomass:
# Model iMM904.cmd: 5.6955403359418306E-6
# Model iJN1463.cmd: 3.3105319553618635E-5
# Cycle 153
# Total biomass:
# Model iMM904.cmd: 5.751147860426434E-6
# Model iJN1463.cmd: 3.3256106588418425E-5
# Cycle 154
# Total biomass:
# Model iMM904.cmd: 5.806369670347798E-6
# Model iJN1463.cmd: 3.340665034471784E-5
# Cycle 155
# Total biomass:
# Model iMM904.cmd: 5.861503317657137E-6
# Model iJN1463.cmd: 3.3557685298499965E-5
# Cycle 156
# Total biomass:
# Model iMM904.cmd: 5.916369375374172E-6
# Model iJN1463.cmd: 3.3708534350073334E-5
# Cycle 157
# Total biomass:
# Model iMM904.cmd: 5.971382438520596E-6
# Model iJN1463.cmd: 3.385917255199055E-5
# Cycle 158
# Total biomass:
# Model iMM904.cmd: 6.026323411163566E-6
# Model iJN1463.cmd: 3.40093608372169E-5
# Cycle 159
# Total biomass:
# Model iMM904.cmd: 6.081197912200644E-6
# Model iJN1463.cmd: 3.415932882330251E-5
# Cycle 160
# Total biomass:
# Model iMM904.cmd: 6.136140136777732E-6
# Model iJN1463.cmd: 3.4308865731377073E-5
# Cycle 161
# Total biomass:
# Model iMM904.cmd: 6.191252279408979E-6
# Model iJN1463.cmd: 3.445823851231597E-5
# Cycle 162
# Total biomass:
# Model iMM904.cmd: 6.246489383918708E-6
# Model iJN1463.cmd: 3.4606982363511494E-5
# Cycle 163
# Total biomass:
# Model iMM904.cmd: 6.302020692124237E-6
# Model iJN1463.cmd: 3.475582403795351E-5
# Cycle 164
# Total biomass:
# Model iMM904.cmd: 6.359306487345342E-6
# Model iJN1463.cmd: 3.490182986749194E-5
# Cycle 165
# Total biomass:
# Model iMM904.cmd: 6.417183631530551E-6
# Model iJN1463.cmd: 3.5047026895293133E-5
# Cycle 166
# Total biomass:
# Model iMM904.cmd: 6.475201288309743E-6
# Model iJN1463.cmd: 3.519313205119855E-5
# Cycle 167
# Total biomass:
# Model iMM904.cmd: 6.532566949449191E-6
# Model iJN1463.cmd: 3.533791728435886E-5
# Cycle 168
# Total biomass:
# Model iMM904.cmd: 6.589665181339366E-6
# Model iJN1463.cmd: 3.5483948304178366E-5
# Cycle 169
# Total biomass:
# Model iMM904.cmd: 6.646898739001345E-6
# Model iJN1463.cmd: 3.5630107425808106E-5
# Cycle 170
# Total biomass:
# Model iMM904.cmd: 6.703937444314451E-6
# Model iJN1463.cmd: 3.5776479329536435E-5
# Cycle 171
# Total biomass:
# Model iMM904.cmd: 6.76082158093376E-6
# Model iJN1463.cmd: 3.592215072432993E-5
# Cycle 172
# Total biomass:
# Model iMM904.cmd: 6.817291542913946E-6
# Model iJN1463.cmd: 3.607023093580705E-5
# Cycle 173
# Total biomass:
# Model iMM904.cmd: 6.87332891577356E-6
# Model iJN1463.cmd: 3.621661470226117E-5
# Cycle 174
# Total biomass:
# Model iMM904.cmd: 6.9290684831469615E-6
# Model iJN1463.cmd: 3.636251329109572E-5
# Cycle 175
# Total biomass:
# Model iMM904.cmd: 6.985225493046516E-6
# Model iJN1463.cmd: 3.6506023456065844E-5
# Cycle 176
# Total biomass:
# Model iMM904.cmd: 7.044506452391776E-6
# Model iJN1463.cmd: 3.664592214050901E-5
# Cycle 177
# Total biomass:
# Model iMM904.cmd: 7.105269323030074E-6
# Model iJN1463.cmd: 3.678533630738087E-5
# Cycle 178
# Total biomass:
# Model iMM904.cmd: 7.1661302462958946E-6
# Model iJN1463.cmd: 3.692403191406373E-5
# Cycle 179
# Total biomass:
# Model iMM904.cmd: 7.227113622459091E-6
# Model iJN1463.cmd: 3.706284301623498E-5
# Cycle 180
# Total biomass:
# Model iMM904.cmd: 7.287646879168332E-6
# Model iJN1463.cmd: 3.7202631548943025E-5
# Cycle 181
# Total biomass:
# Model iMM904.cmd: 7.3494214499630575E-6
# Model iJN1463.cmd: 3.734091378367968E-5
# Cycle 182
# Total biomass:
# Model iMM904.cmd: 7.411814831651907E-6
# Model iJN1463.cmd: 3.747843793003521E-5
# Cycle 183
# Total biomass:
# Model iMM904.cmd: 7.473038555674429E-6
# Model iJN1463.cmd: 3.761623125358046E-5
# Cycle 184
# Total biomass:
# Model iMM904.cmd: 7.532056201340954E-6
# Model iJN1463.cmd: 3.775678369647379E-5
# Cycle 185
# Total biomass:
# Model iMM904.cmd: 7.5893991200344665E-6
# Model iJN1463.cmd: 3.789768862832533E-5
# Cycle 186
# Total biomass:
# Model iMM904.cmd: 7.650725085368957E-6
# Model iJN1463.cmd: 3.803283722208673E-5
# Cycle 187
# Total biomass:
# Model iMM904.cmd: 7.712910867670898E-6
# Model iJN1463.cmd: 3.816735874457201E-5
# Cycle 188
# Total biomass:
# Model iMM904.cmd: 7.775104780968005E-6
# Model iJN1463.cmd: 3.830231957554649E-5
# Cycle 189
# Total biomass:
# Model iMM904.cmd: 7.836911266948394E-6
# Model iJN1463.cmd: 3.843687126049274E-5
# Cycle 190
# Total biomass:
# Model iMM904.cmd: 7.897848617453998E-6
# Model iJN1463.cmd: 3.8572026665185335E-5
# Cycle 191
# Total biomass:
# Model iMM904.cmd: 7.956416433973286E-6
# Model iJN1463.cmd: 3.871332222030372E-5
# Cycle 192
# Total biomass:
# Model iMM904.cmd: 8.014157915142309E-6
# Model iJN1463.cmd: 3.885006220430738E-5
# Cycle 193
# Total biomass:
# Model iMM904.cmd: 8.073632806926848E-6
# Model iJN1463.cmd: 3.898615359378112E-5
# Cycle 194
# Total biomass:
# Model iMM904.cmd: 8.134938722010938E-6
# Model iJN1463.cmd: 3.912120148751237E-5
# Cycle 195
# Total biomass:
# Model iMM904.cmd: 8.192813846700739E-6
# Model iJN1463.cmd: 3.9258659620201934E-5
# Cycle 196
# Total biomass:
# Model iMM904.cmd: 8.254674661182E-6
# Model iJN1463.cmd: 3.938981809530879E-5
# Cycle 197
# Total biomass:
# Model iMM904.cmd: 8.317454472657399E-6
# Model iJN1463.cmd: 3.9519703617974004E-5
# Cycle 198
# Total biomass:
# Model iMM904.cmd: 8.381273896647968E-6
# Model iJN1463.cmd: 3.964811558028039E-5
# Cycle 199
# Total biomass:
# Model iMM904.cmd: 8.441596006304007E-6
# Model iJN1463.cmd: 3.978389894776092E-5
# Cycle 200
# Total biomass:
# Model iMM904.cmd: 8.504234659430735E-6
# Model iJN1463.cmd: 3.991568088565681E-5
# Cycle 201
# Total biomass:
# Model iMM904.cmd: 8.56780736275603E-6
# Model iJN1463.cmd: 4.004448408015354E-5
# Cycle 202
# Total biomass:
# Model iMM904.cmd: 8.628684529973318E-6
# Model iJN1463.cmd: 4.017799777590706E-5
# Cycle 203
# Total biomass:
# Model iMM904.cmd: 8.690406179043595E-6
# Model iJN1463.cmd: 4.030954026202289E-5
# Cycle 204
# Total biomass:
# Model iMM904.cmd: 8.754252409680496E-6
# Model iJN1463.cmd: 4.043892938426429E-5
# Cycle 205
# Total biomass:
# Model iMM904.cmd: 8.814993720054425E-6
# Model iJN1463.cmd: 4.057089031564684E-5
# Cycle 206
# Total biomass:
# Model iMM904.cmd: 8.8747099013856E-6
# Model iJN1463.cmd: 4.0703259852395426E-5
# Cycle 207
# Total biomass:
# Model iMM904.cmd: 8.937290354025297E-6
# Model iJN1463.cmd: 4.083294984324205E-5
# Cycle 208
# Total biomass:
# Model iMM904.cmd: 8.999506596758502E-6
# Model iJN1463.cmd: 4.0962368530963984E-5
# Cycle 209
# Total biomass:
# Model iMM904.cmd: 9.06452824516024E-6
# Model iJN1463.cmd: 4.1088179545161694E-5
# Cycle 210
# Total biomass:
# Model iMM904.cmd: 9.12722928195771E-6
# Model iJN1463.cmd: 4.1216987912178725E-5
# Cycle 211
# Total biomass:
# Model iMM904.cmd: 9.19067916522341E-6
# Model iJN1463.cmd: 4.134419663278735E-5
# Cycle 212
# Total biomass:
# Model iMM904.cmd: 9.250254936725904E-6
# Model iJN1463.cmd: 4.147617746568842E-5
# Cycle 213
# Total biomass:
# Model iMM904.cmd: 9.306408683950544E-6
# Model iJN1463.cmd: 4.161112347376805E-5
# Cycle 214
# Total biomass:
# Model iMM904.cmd: 9.362670657987727E-6
# Model iJN1463.cmd: 4.1745499755950945E-5
# Cycle 215
# Total biomass:
# Model iMM904.cmd: 9.422614460636351E-6
# Model iJN1463.cmd: 4.187472993802262E-5
# Cycle 216
# Total biomass:
# Model iMM904.cmd: 9.486132574966632E-6
# Model iJN1463.cmd: 4.200129079995667E-5
# Cycle 217
# Total biomass:
# Model iMM904.cmd: 9.550259388706801E-6
# Model iJN1463.cmd: 4.212775466558203E-5
# Cycle 218
# Total biomass:
# Model iMM904.cmd: 9.614993991760848E-6
# Model iJN1463.cmd: 4.224953950080922E-5
# Cycle 219
# Total biomass:
# Model iMM904.cmd: 9.680381015890483E-6
# Model iJN1463.cmd: 4.237137629398709E-5
# Cycle 220
# Total biomass:
# Model iMM904.cmd: 9.736230286742867E-6
# Model iJN1463.cmd: 4.250563167834528E-5
# Cycle 221
# Total biomass:
# Model iMM904.cmd: 9.801771095248056E-6
# Model iJN1463.cmd: 4.262587341794398E-5
# Cycle 222
# Total biomass:
# Model iMM904.cmd: 9.86269973799521E-6
# Model iJN1463.cmd: 4.275250067062433E-5
# Cycle 223
# Total biomass:
# Model iMM904.cmd: 9.924790572166995E-6
# Model iJN1463.cmd: 4.287810388898786E-5
# Cycle 224
# Total biomass:
# Model iMM904.cmd: 9.990471332033958E-6
# Model iJN1463.cmd: 4.299815481657843E-5
# Cycle 225
# Total biomass:
# Model iMM904.cmd: 1.0053662212763796E-5
# Model iJN1463.cmd: 4.312156333959189E-5
# Cycle 226
# Total biomass:
# Model iMM904.cmd: 1.0122208453383738E-5
# Model iJN1463.cmd: 4.323755826000114E-5
# Cycle 227
# Total biomass:
# Model iMM904.cmd: 1.018974556594316E-5
# Model iJN1463.cmd: 4.335580773251397E-5
# Cycle 228
# Total biomass:
# Model iMM904.cmd: 1.0256738089325332E-5
# Model iJN1463.cmd: 4.347379113263513E-5
# Cycle 229
# Total biomass:
# Model iMM904.cmd: 1.0324841468748191E-5
# Model iJN1463.cmd: 4.3592408836246973E-5
# Cycle 230
# Total biomass:
# Model iMM904.cmd: 1.0389813827942592E-5
# Model iJN1463.cmd: 4.371406444774702E-5
# Cycle 231
# Total biomass:
# Model iMM904.cmd: 1.0457585604263835E-5
# Model iJN1463.cmd: 4.383223372208532E-5
# Cycle 232
# Total biomass:
# Model iMM904.cmd: 1.0515788761478214E-5
# Model iJN1463.cmd: 4.395848847677875E-5
# Cycle 233
# Total biomass:
# Model iMM904.cmd: 1.0575689862260896E-5
# Model iJN1463.cmd: 4.408258522877547E-5
# Cycle 234
# Total biomass:
# Model iMM904.cmd: 1.0637089989087967E-5
# Model iJN1463.cmd: 4.420579917395274E-5
# Cycle 235
# Total biomass:
# Model iMM904.cmd: 1.0698691738663949E-5
# Model iJN1463.cmd: 4.432772490750806E-5
# Cycle 236
# Total biomass:
# Model iMM904.cmd: 1.0762496601605054E-5
# Model iJN1463.cmd: 4.4447553457857794E-5
# Cycle 237
# Total biomass:
# Model iMM904.cmd: 1.0829959798875412E-5
# Model iJN1463.cmd: 4.456188875563035E-5
# Cycle 238
# Total biomass:
# Model iMM904.cmd: 1.0897986920008786E-5
# Model iJN1463.cmd: 4.467566920039846E-5
# Cycle 239
# Total biomass:
# Model iMM904.cmd: 1.0965108597727928E-5
# Model iJN1463.cmd: 4.479084989233524E-5
# Cycle 240
# Total biomass:
# Model iMM904.cmd: 1.1028052327627654E-5
# Model iJN1463.cmd: 4.491059057050606E-5
# Cycle 241
# Total biomass:
# Model iMM904.cmd: 1.109301228592514E-5
# Model iJN1463.cmd: 4.502684315296757E-5
# Cycle 242
# Total biomass:
# Model iMM904.cmd: 1.1157811391527993E-5
# Model iJN1463.cmd: 4.51442308703695E-5
# Cycle 243
# Total biomass:
# Model iMM904.cmd: 1.1227773306145335E-5
# Model iJN1463.cmd: 4.525535340246644E-5
# Cycle 244
# Total biomass:
# Model iMM904.cmd: 1.1287955094071428E-5
# Model iJN1463.cmd: 4.5376164738682386E-5
# Cycle 245
# Total biomass:
# Model iMM904.cmd: 1.1348811763350352E-5
# Model iJN1463.cmd: 4.549471444786093E-5
# Cycle 246
# Total biomass:
# Model iMM904.cmd: 1.141071175733795E-5
# Model iJN1463.cmd: 4.5611875961228385E-5
# Cycle 247
# Total biomass:
# Model iMM904.cmd: 1.1472536244458197E-5
# Model iJN1463.cmd: 4.5728981743032714E-5
# Cycle 248
# Total biomass:
# Model iMM904.cmd: 1.1533012532273838E-5
# Model iJN1463.cmd: 4.584984539316792E-5
# Cycle 249
# Total biomass:
# Model iMM904.cmd: 1.1591965914031518E-5
# Model iJN1463.cmd: 4.597269213383316E-5
# Cycle 250
# Total biomass:
# Model iMM904.cmd: 1.1647646005747057E-5
# Model iJN1463.cmd: 4.609888199066046E-5
# Cycle 251
# Total biomass:
# Model iMM904.cmd: 1.1704953649621994E-5
# Model iJN1463.cmd: 4.6220375706382456E-5
# Cycle 252
# Total biomass:
# Model iMM904.cmd: 1.176220300008876E-5
# Model iJN1463.cmd: 4.6340364415582495E-5
# Cycle 253
# Total biomass:
# Model iMM904.cmd: 1.1826776625181679E-5
# Model iJN1463.cmd: 4.645095013186164E-5
# Cycle 254
# Total biomass:
# Model iMM904.cmd: 1.1891767026252929E-5
# Model iJN1463.cmd: 4.6561119616013644E-5
# Cycle 255
# Total biomass:
# Model iMM904.cmd: 1.1950523554371414E-5
# Model iJN1463.cmd: 4.6678853990549415E-5
# Cycle 256
# Total biomass:
# Model iMM904.cmd: 1.2008739505047285E-5
# Model iJN1463.cmd: 4.679812271450715E-5
# Cycle 257
# Total biomass:
# Model iMM904.cmd: 1.2073723417527385E-5
# Model iJN1463.cmd: 4.6908643556473315E-5
# Cycle 258
# Total biomass:
# Model iMM904.cmd: 1.2141235308072104E-5
# Model iJN1463.cmd: 4.7016009172455186E-5
# Cycle 259
# Total biomass:
# Model iMM904.cmd: 1.2206769610383717E-5
# Model iJN1463.cmd: 4.71268092610178E-5
# Cycle 260
# Total biomass:
# Model iMM904.cmd: 1.2271876410712328E-5
# Model iJN1463.cmd: 4.723505115261699E-5
# Cycle 261
# Total biomass:
# Model iMM904.cmd: 1.2328388865408723E-5
# Model iJN1463.cmd: 4.735197906005884E-5
# Cycle 262
# Total biomass:
# Model iMM904.cmd: 1.2382571160840187E-5
# Model iJN1463.cmd: 4.7470312258036415E-5
# Cycle 263
# Total biomass:
# Model iMM904.cmd: 1.2440240850126528E-5
# Model iJN1463.cmd: 4.758476382780292E-5
# Cycle 264
# Total biomass:
# Model iMM904.cmd: 1.2504932246111093E-5
# Model iJN1463.cmd: 4.769201252486897E-5
# Cycle 265
# Total biomass:
# Model iMM904.cmd: 1.2567527573636826E-5
# Model iJN1463.cmd: 4.7802434405006135E-5
# Cycle 266
# Total biomass:
# Model iMM904.cmd: 1.2628308085984667E-5
# Model iJN1463.cmd: 4.791525614195498E-5
# Cycle 267
# Total biomass:
# Model iMM904.cmd: 1.2694691669457065E-5
# Model iJN1463.cmd: 4.802053446005415E-5
# Cycle 268
# Total biomass:
# Model iMM904.cmd: 1.2752467756338566E-5
# Model iJN1463.cmd: 4.81348978496573E-5
# Cycle 269
# Total biomass:
# Model iMM904.cmd: 1.2807444023180875E-5
# Model iJN1463.cmd: 4.825457934079465E-5
# Cycle 270
# Total biomass:
# Model iMM904.cmd: 1.2870421934729923E-5
# Model iJN1463.cmd: 4.836661471175754E-5
# Cycle 271
# Total biomass:
# Model iMM904.cmd: 1.2936750679496938E-5
# Model iJN1463.cmd: 4.8470462487780645E-5
# Cycle 272
# Total biomass:
# Model iMM904.cmd: 1.3000466428775643E-5
# Model iJN1463.cmd: 4.857986382844786E-5
# Cycle 273
# Total biomass:
# Model iMM904.cmd: 1.3065425853074153E-5
# Model iJN1463.cmd: 4.8684915131905296E-5
# Cycle 274
# Total biomass:
# Model iMM904.cmd: 1.3129479745058367E-5
# Model iJN1463.cmd: 4.8789335907938085E-5
# Cycle 275
# Total biomass:
# Model iMM904.cmd: 1.319377482741283E-5
# Model iJN1463.cmd: 4.88936858557871E-5
# Cycle 276
# Total biomass:
# Model iMM904.cmd: 1.3260501812736335E-5
# Model iJN1463.cmd: 4.899653772956802E-5
# Cycle 277
# Total biomass:
# Model iMM904.cmd: 1.3325933007729553E-5
# Model iJN1463.cmd: 4.909948045676173E-5
# Cycle 278
# Total biomass:
# Model iMM904.cmd: 1.3387248630800045E-5
# Model iJN1463.cmd: 4.920615183402314E-5
# Cycle 279
# Total biomass:
# Model iMM904.cmd: 1.3443940183227585E-5
# Model iJN1463.cmd: 4.931507278271714E-5
# Cycle 280
# Total biomass:
# Model iMM904.cmd: 1.3506460155138053E-5
# Model iJN1463.cmd: 4.941826802251511E-5
# Cycle 281
# Total biomass:
# Model iMM904.cmd: 1.3573051530966294E-5
# Model iJN1463.cmd: 4.95167613840722E-5
# Cycle 282
# Total biomass:
# Model iMM904.cmd: 1.3633237851431516E-5
# Model iJN1463.cmd: 4.962252359180594E-5
# Cycle 283
# Total biomass:
# Model iMM904.cmd: 1.3700956768219546E-5
# Model iJN1463.cmd: 4.9724336588906744E-5
# Cycle 284
# Total biomass:
# Model iMM904.cmd: 1.3761831474415343E-5
# Model iJN1463.cmd: 4.983065496654099E-5
# Cycle 285
# Total biomass:
# Model iMM904.cmd: 1.381991679336227E-5
# Model iJN1463.cmd: 4.99426871180617E-5
# Cycle 286
# Total biomass:
# Model iMM904.cmd: 1.3881968397389137E-5
# Model iJN1463.cmd: 5.0044887657829E-5
# Cycle 287
# Total biomass:
# Model iMM904.cmd: 1.3940637899934149E-5
# Model iJN1463.cmd: 5.015077438750774E-5
# Cycle 288
# Total biomass:
# Model iMM904.cmd: 1.3999953611864574E-5
# Model iJN1463.cmd: 5.025658396414479E-5
# Cycle 289
# Total biomass:
# Model iMM904.cmd: 1.4055282440324916E-5
# Model iJN1463.cmd: 5.036467490279328E-5
# Cycle 290
# Total biomass:
# Model iMM904.cmd: 1.4113764896873272E-5
# Model iJN1463.cmd: 5.0469927840482655E-5
# Cycle 291
# Total biomass:
# Model iMM904.cmd: 1.417694834337688E-5
# Model iJN1463.cmd: 5.05700934515153E-5
# Cycle 292
# Total biomass:
# Model iMM904.cmd: 1.4242168325000111E-5
# Model iJN1463.cmd: 5.06666254855503E-5
# Cycle 293
# Total biomass:
# Model iMM904.cmd: 1.4306898944895737E-5
# Model iJN1463.cmd: 5.076287891096765E-5
# Cycle 294
# Total biomass:
# Model iMM904.cmd: 1.4365933207330912E-5
# Model iJN1463.cmd: 5.086625745424611E-5
# Cycle 295
# Total biomass:
# Model iMM904.cmd: 1.442823588553216E-5
# Model iJN1463.cmd: 5.096651631180194E-5
# Cycle 296
# Total biomass:
# Model iMM904.cmd: 1.449153570375996E-5
# Model iJN1463.cmd: 5.106414868809324E-5
# Cycle 297
# Total biomass:
# Model iMM904.cmd: 1.455379129144639E-5
# Model iJN1463.cmd: 5.116312321087932E-5
# Cycle 298
# Total biomass:
# Model iMM904.cmd: 1.4614387054515303E-5
# Model iJN1463.cmd: 5.1263148729136415E-5
# Cycle 299
# Total biomass:
# Model iMM904.cmd: 1.4676708561652316E-5
# Model iJN1463.cmd: 5.1361416317804366E-5
# Cycle 300
# Total biomass:
# Model iMM904.cmd: 1.4741033399863558E-5
# Model iJN1463.cmd: 5.145783972784473E-5
# Cycle 301
# Total biomass:
# Model iMM904.cmd: 1.480425934927009E-5
# Model iJN1463.cmd: 5.155528326658051E-5
# Cycle 302
# Total biomass:
# Model iMM904.cmd: 1.4867835931445138E-5
# Model iJN1463.cmd: 5.16511647544245E-5
# Cycle 303
# Total biomass:
# Model iMM904.cmd: 1.4929555801529699E-5
# Model iJN1463.cmd: 5.1746648705799854E-5
# Cycle 304
# Total biomass:
# Model iMM904.cmd: 1.4992691654032895E-5
# Model iJN1463.cmd: 5.1842204983727145E-5
# Cycle 305
# Total biomass:
# Model iMM904.cmd: 1.5054995671122953E-5
# Model iJN1463.cmd: 5.1939229240630193E-5
# Cycle 306
# Total biomass:
# Model iMM904.cmd: 1.5113780551009573E-5
# Model iJN1463.cmd: 5.203808867546768E-5
# Cycle 307
# Total biomass:
# Model iMM904.cmd: 1.5173914630897775E-5
# Model iJN1463.cmd: 5.213492180268872E-5
# Cycle 308
# Total biomass:
# Model iMM904.cmd: 1.5235165686096229E-5
# Model iJN1463.cmd: 5.223240086508993E-5
# Cycle 309
# Total biomass:
# Model iMM904.cmd: 1.52984377218274E-5
# Model iJN1463.cmd: 5.2325880682582766E-5
# Cycle 310
# Total biomass:
# Model iMM904.cmd: 1.536056386359657E-5
# Model iJN1463.cmd: 5.241916434437154E-5
# Cycle 311
# Total biomass:
# Model iMM904.cmd: 1.5420413080375564E-5
# Model iJN1463.cmd: 5.2515603662027884E-5
# Cycle 312
# Total biomass:
# Model iMM904.cmd: 1.5480754454986594E-5
# Model iJN1463.cmd: 5.261119958015613E-5
# Cycle 313
# Total biomass:
# Model iMM904.cmd: 1.5541891119020455E-5
# Model iJN1463.cmd: 5.270593982390078E-5
# Cycle 314
# Total biomass:
# Model iMM904.cmd: 1.5603775972918702E-5
# Model iJN1463.cmd: 5.2798724083624567E-5
# Cycle 315
# Total biomass:
# Model iMM904.cmd: 1.5667858746955037E-5
# Model iJN1463.cmd: 5.289274287169637E-5
# Cycle 316
# Total biomass:
# Model iMM904.cmd: 1.572765707769916E-5
# Model iJN1463.cmd: 5.298854997448032E-5
# Cycle 317
# Total biomass:
# Model iMM904.cmd: 1.5784696677373234E-5
# Model iJN1463.cmd: 5.308612272690058E-5
# Cycle 318
# Total biomass:
# Model iMM904.cmd: 1.584511102045152E-5
# Model iJN1463.cmd: 5.3180418106015564E-5
# Cycle 319
# Total biomass:
# Model iMM904.cmd: 1.5903464099684864E-5
# Model iJN1463.cmd: 5.327740310974791E-5
# Cycle 320
# Total biomass:
# Model iMM904.cmd: 1.5960063214329045E-5
# Model iJN1463.cmd: 5.337438839226031E-5
# Cycle 321
# Total biomass:
# Model iMM904.cmd: 1.602369010197685E-5
# Model iJN1463.cmd: 5.346273633161777E-5
# Cycle 322
# Total biomass:
# Model iMM904.cmd: 1.608682126478882E-5
# Model iJN1463.cmd: 5.355124831927625E-5
# Cycle 323
# Total biomass:
# Model iMM904.cmd: 1.6146932210272924E-5
# Model iJN1463.cmd: 5.364253788048037E-5
# Cycle 324
# Total biomass:
# Model iMM904.cmd: 1.6203243180687576E-5
# Model iJN1463.cmd: 5.3736225204623526E-5
# Cycle 325
# Total biomass:
# Model iMM904.cmd: 1.625942506893908E-5
# Model iJN1463.cmd: 5.3830028595503526E-5
# Cycle 326
# Total biomass:
# Model iMM904.cmd: 1.6315208237809404E-5
# Model iJN1463.cmd: 5.392407591403281E-5
# Cycle 327
# Total biomass:
# Model iMM904.cmd: 1.6370669288023285E-5
# Model iJN1463.cmd: 5.4017992784243216E-5
# Cycle 328
# Total biomass:
# Model iMM904.cmd: 1.6431128809575208E-5
# Model iJN1463.cmd: 5.410735328854335E-5
# Cycle 329
# Total biomass:
# Model iMM904.cmd: 1.6489809671808E-5
# Model iJN1463.cmd: 5.4198353771680914E-5
# Cycle 330
# Total biomass:
# Model iMM904.cmd: 1.6549037243316518E-5
# Model iJN1463.cmd: 5.428767565626671E-5
# Cycle 331
# Total biomass:
# Model iMM904.cmd: 1.661086831369206E-5
# Model iJN1463.cmd: 5.4373726746930494E-5
# Cycle 332
# Total biomass:
# Model iMM904.cmd: 1.6671935863402074E-5
# Model iJN1463.cmd: 5.44598990605083E-5
# Cycle 333
# Total biomass:
# Model iMM904.cmd: 1.6732497273078128E-5
# Model iJN1463.cmd: 5.454669009984605E-5
# Cycle 334
# Total biomass:
# Model iMM904.cmd: 1.679443817560992E-5
# Model iJN1463.cmd: 5.4632487969677525E-5
# Cycle 335
# Total biomass:
# Model iMM904.cmd: 1.6850383413720864E-5
# Model iJN1463.cmd: 5.4724172524375686E-5
# Cycle 336
# Total biomass:
# Model iMM904.cmd: 1.6907783494019133E-5
# Model iJN1463.cmd: 5.481430249672999E-5
# Cycle 337
# Total biomass:
# Model iMM904.cmd: 1.6968430764418955E-5
# Model iJN1463.cmd: 5.490144392854335E-5
# Cycle 338
# Total biomass:
# Model iMM904.cmd: 1.7029360808979115E-5
# Model iJN1463.cmd: 5.498695716695384E-5
# Cycle 339
# Total biomass:
# Model iMM904.cmd: 1.7088527036461747E-5
# Model iJN1463.cmd: 5.5072732316268916E-5
# Cycle 340
# Total biomass:
# Model iMM904.cmd: 1.714778320267154E-5
# Model iJN1463.cmd: 5.515857327990183E-5
# Cycle 341
# Total biomass:
# Model iMM904.cmd: 1.720864197247107E-5
# Model iJN1463.cmd: 5.5243039408360336E-5
# Cycle 342
# Total biomass:
# Model iMM904.cmd: 1.7268992912173682E-5
# Model iJN1463.cmd: 5.53276418994456E-5
# Cycle 343
# Total biomass:
# Model iMM904.cmd: 1.732961371026587E-5
# Model iJN1463.cmd: 5.5411473506693655E-5
# Cycle 344
# Total biomass:
# Model iMM904.cmd: 1.7388795034958725E-5
# Model iJN1463.cmd: 5.549723393251367E-5
# Cycle 345
# Total biomass:
# Model iMM904.cmd: 1.7444855759129037E-5
# Model iJN1463.cmd: 5.55860799216811E-5
# Cycle 346
# Total biomass:
# Model iMM904.cmd: 1.750034484827157E-5
# Model iJN1463.cmd: 5.56752662778185E-5
# Cycle 347
# Total biomass:
# Model iMM904.cmd: 1.7554887575724664E-5
# Model iJN1463.cmd: 5.576474618522658E-5
# Cycle 348
# Total biomass:
# Model iMM904.cmd: 1.760904473235842E-5
# Model iJN1463.cmd: 5.585437483932375E-5
# Cycle 349
# Total biomass:
# Model iMM904.cmd: 1.766505580224167E-5
# Model iJN1463.cmd: 5.594205080787911E-5
# Cycle 350
# Total biomass:
# Model iMM904.cmd: 1.772001322600118E-5
# Model iJN1463.cmd: 5.6030876301725476E-5
# Cycle 351
# Total biomass:
# Model iMM904.cmd: 1.7774546177689708E-5
# Model iJN1463.cmd: 5.611944362651361E-5
# Cycle 352
# Total biomass:
# Model iMM904.cmd: 1.782920981414407E-5
# Model iJN1463.cmd: 5.6207550080043364E-5
# Cycle 353
# Total biomass:
# Model iMM904.cmd: 1.7885601153451148E-5
# Model iJN1463.cmd: 5.629324262097499E-5
# Cycle 354
# Total biomass:
# Model iMM904.cmd: 1.7942968886400972E-5
# Model iJN1463.cmd: 5.63779755382808E-5
# Cycle 355
# Total biomass:
# Model iMM904.cmd: 1.799906840101549E-5
# Model iJN1463.cmd: 5.6462912399453844E-5
# Cycle 356
# Total biomass:
# Model iMM904.cmd: 1.8055312114858483E-5
# Model iJN1463.cmd: 5.654723855963571E-5
# Cycle 357
# Total biomass:
# Model iMM904.cmd: 1.811254749299958E-5
# Model iJN1463.cmd: 5.662972321225593E-5
# Cycle 358
# Total biomass:
# Model iMM904.cmd: 1.8168657367242125E-5
# Model iJN1463.cmd: 5.671262201076092E-5
# Cycle 359
# Total biomass:
# Model iMM904.cmd: 1.822353949195246E-5
# Model iJN1463.cmd: 5.679736477667757E-5
# Cycle 360
# Total biomass:
# Model iMM904.cmd: 1.828154236316452E-5
# Model iJN1463.cmd: 5.687930742647344E-5
# Cycle 361
# Total biomass:
# Model iMM904.cmd: 1.833553651979658E-5
# Model iJN1463.cmd: 5.696436177094806E-5
# Cycle 362
# Total biomass:
# Model iMM904.cmd: 1.8389417640341946E-5
# Model iJN1463.cmd: 5.70491609366839E-5
# Cycle 363
# Total biomass:
# Model iMM904.cmd: 1.844311370142841E-5
# Model iJN1463.cmd: 5.713401791385405E-5
# Cycle 364
# Total biomass:
# Model iMM904.cmd: 1.8497558233101423E-5
# Model iJN1463.cmd: 5.7217439974808076E-5
# Cycle 365
# Total biomass:
# Model iMM904.cmd: 1.8552330862047637E-5
# Model iJN1463.cmd: 5.730004877084636E-5
# Cycle 366
# Total biomass:
# Model iMM904.cmd: 1.8608200072783575E-5
# Model iJN1463.cmd: 5.738067724917178E-5
# Cycle 367
# Total biomass:
# Model iMM904.cmd: 1.866447308524816E-5
# Model iJN1463.cmd: 5.746043607990884E-5
# Cycle 368
# Total biomass:
# Model iMM904.cmd: 1.8724122731775957E-5
# Model iJN1463.cmd: 5.753798695237202E-5
# Cycle 369
# Total biomass:
# Model iMM904.cmd: 1.8784097446233647E-5
# Model iJN1463.cmd: 5.7615542909781655E-5
# Cycle 370
# Total biomass:
# Model iMM904.cmd: 1.8842178533687647E-5
# Model iJN1463.cmd: 5.769385251589285E-5
# Cycle 371
# Total biomass:
# Model iMM904.cmd: 1.8899671317532867E-5
# Model iJN1463.cmd: 5.77719011877942E-5
# Cycle 372
# Total biomass:
# Model iMM904.cmd: 1.8952726672908215E-5
# Model iJN1463.cmd: 5.7854548460096145E-5
# Cycle 373
# Total biomass:
# Model iMM904.cmd: 1.9004549440444835E-5
# Model iJN1463.cmd: 5.793826977706264E-5
# Cycle 374
# Total biomass:
# Model iMM904.cmd: 1.905591300395006E-5
# Model iJN1463.cmd: 5.802221599450039E-5
# Cycle 375
# Total biomass:
# Model iMM904.cmd: 1.9108470133106664E-5
# Model iJN1463.cmd: 5.810455547369097E-5
# Cycle 376
# Total biomass:
# Model iMM904.cmd: 1.916140958397243E-5
# Model iJN1463.cmd: 5.818620143359522E-5
# Cycle 377
# Total biomass:
# Model iMM904.cmd: 1.9214662980137202E-5
# Model iJN1463.cmd: 5.826718773940531E-5
# Cycle 378
# Total biomass:
# Model iMM904.cmd: 1.926915244941839E-5
# Model iJN1463.cmd: 5.834651568902474E-5
# Cycle 379
# Total biomass:
# Model iMM904.cmd: 1.932384795163778E-5
# Model iJN1463.cmd: 5.842510538824906E-5
# Cycle 380
# Total biomass:
# Model iMM904.cmd: 1.9378507958110303E-5
# Model iJN1463.cmd: 5.8503372428784175E-5
# Cycle 381
# Total biomass:
# Model iMM904.cmd: 1.9433021468209604E-5
# Model iJN1463.cmd: 5.8581503387994395E-5
# Cycle 382
# Total biomass:
# Model iMM904.cmd: 1.9487496564761456E-5
# Model iJN1463.cmd: 5.865960855669185E-5
# Cycle 383
# Total biomass:
# Model iMM904.cmd: 1.954250628408131E-5
# Model iJN1463.cmd: 5.873672096351219E-5
# Cycle 384
# Total biomass:
# Model iMM904.cmd: 1.9596703940346772E-5
# Model iJN1463.cmd: 5.881434906528314E-5
# Cycle 385
# Total biomass:
# Model iMM904.cmd: 1.965075848878858E-5
# Model iJN1463.cmd: 5.889181916112765E-5
# Cycle 386
# Total biomass:
# Model iMM904.cmd: 1.9704782746916098E-5
# Model iJN1463.cmd: 5.8969258285689776E-5
# Cycle 387
# Total biomass:
# Model iMM904.cmd: 1.9758645471434724E-5
# Model iJN1463.cmd: 5.9046555920699804E-5
# Cycle 388
# Total biomass:
# Model iMM904.cmd: 1.98120386824959E-5
# Model iJN1463.cmd: 5.9124619810298075E-5
# Cycle 389
# Total biomass:
# Model iMM904.cmd: 1.986559794079981E-5
# Model iJN1463.cmd: 5.920162740267226E-5
# Cycle 390
# Total biomass:
# Model iMM904.cmd: 1.9919068510836483E-5
# Model iJN1463.cmd: 5.9278319064026566E-5
# Cycle 391
# Total biomass:
# Model iMM904.cmd: 1.9972142407612176E-5
# Model iJN1463.cmd: 5.93553432858103E-5
# Cycle 392
# Total biomass:
# Model iMM904.cmd: 2.0025309359907295E-5
# Model iJN1463.cmd: 5.943171882606079E-5
# Cycle 393
# Total biomass:
# Model iMM904.cmd: 2.0078780355131357E-5
# Model iJN1463.cmd: 5.950813814817334E-5
# Cycle 394
# Total biomass:
# Model iMM904.cmd: 2.0131882926713266E-5
# Model iJN1463.cmd: 5.958438811356045E-5
# Cycle 395
# Total biomass:
# Model iMM904.cmd: 2.0184528799097753E-5
# Model iJN1463.cmd: 5.966156740201076E-5
# Cycle 396
# Total biomass:
# Model iMM904.cmd: 2.0237290720817475E-5
# Model iJN1463.cmd: 5.973750166043443E-5
# Cycle 397
# Total biomass:
# Model iMM904.cmd: 2.0290010130106325E-5
# Model iJN1463.cmd: 5.981291371777211E-5
# Cycle 398
# Total biomass:
# Model iMM904.cmd: 2.034204206010951E-5
# Model iJN1463.cmd: 5.988934226201946E-5
# Cycle 399
# Total biomass:
# Model iMM904.cmd: 2.0394554511987697E-5
# Model iJN1463.cmd: 5.9964509825338336E-5
# Cycle 400
# Total biomass:
# Model iMM904.cmd: 2.0446999204801403E-5
# Model iJN1463.cmd: 6.004031186710727E-5
# Cycle 401
# Total biomass:
# ...
# Cycle 848
# Total biomass:
# Model iMM904.cmd: 3.3814469492748605E-5
# Model iJN1463.cmd: 7.97167820125266E-5
# Cycle 849
# Total biomass:
# Model iMM904.cmd: 3.382436668762556E-5
# Model iJN1463.cmd: 7.973786273592742E-5
# Cycle 850
# Total biomass:
# Model iMM904.cmd: 3.383402252743827E-5
# Model iJN1463.cmd: 7.975810379779701E-5
# Cycle 851
# Total biomass:
# Model iMM904.cmd: 3.385085024143376E-5
# Model iJN1463.cmd: 7.977152429920937E-5
# Cycle 852
# Total biomass:
# Model iMM904.cmd: 3.38658506937364E-5
# Model iJN1463.cmd: 7.978677322425846E-5
# Cycle 853
# Total biomass:
# Model iMM904.cmd: 3.388168787353534E-5
# Model iJN1463.cmd: 7.980103043539259E-5
# Cycle 854
# Total biomass:
# Model iMM904.cmd: 3.3896110698484134E-5
# Model iJN1463.cmd: 7.981638734695404E-5
# Cycle 855
# Total biomass:
# Model iMM904.cmd: 3.391054694341358E-5
# Model iJN1463.cmd: 7.983202854043532E-5
# Cycle 856
# Total biomass:
# Model iMM904.cmd: 3.3922093580208705E-5
# Model iJN1463.cmd: 7.985098144389751E-5
# Cycle 857
# Total biomass:
# Model iMM904.cmd: 3.393899445841404E-5
# Model iJN1463.cmd: 7.986404792480625E-5
# Cycle 858
# Total biomass:
# Model iMM904.cmd: 3.3956155266512034E-5
# Model iJN1463.cmd: 7.987826078521242E-5
# Cycle 859
# Total biomass:
# Model iMM904.cmd: 3.397234411491171E-5
# Model iJN1463.cmd: 7.98924372384061E-5
# Cycle 860
# Total biomass:
# Model iMM904.cmd: 3.398799825891379E-5
# Model iJN1463.cmd: 7.990673749518645E-5
# Cycle 861
# Total biomass:
# Model iMM904.cmd: 3.4004489750551015E-5
# Model iJN1463.cmd: 7.991963278777379E-5
# Cycle 862
# Total biomass:
# Model iMM904.cmd: 3.402095062572619E-5
# Model iJN1463.cmd: 7.993251846258263E-5
# Cycle 863
# Total biomass:
# Model iMM904.cmd: 3.4036911357840374E-5
# Model iJN1463.cmd: 7.994579410340353E-5
# Cycle 864
# Total biomass:
# Model iMM904.cmd: 3.405268567708993E-5
# Model iJN1463.cmd: 7.995911233355169E-5
# Cycle 865
# Total biomass:
# Model iMM904.cmd: 3.406846573221473E-5
# Model iJN1463.cmd: 7.997247718316002E-5
# Cycle 866
# Total biomass:
# Model iMM904.cmd: 3.408450222976806E-5
# Model iJN1463.cmd: 7.998542465400624E-5
# Cycle 867
# Total biomass:
# Model iMM904.cmd: 3.4100378693655226E-5
# Model iJN1463.cmd: 7.999829066389325E-5
# Cycle 868
# Total biomass:
# Model iMM904.cmd: 3.411676623703533E-5
# Model iJN1463.cmd: 8.00107910139811E-5
# Cycle 869
# Total biomass:
# Model iMM904.cmd: 3.413342996927785E-5
# Model iJN1463.cmd: 8.002267635515076E-5
# Cycle 870
# Total biomass:
# Model iMM904.cmd: 3.4150165435233394E-5
# Model iJN1463.cmd: 8.003441305629461E-5
# Cycle 871
# Total biomass:
# Model iMM904.cmd: 3.416680471211732E-5
# Model iJN1463.cmd: 8.004603880864746E-5
# Cycle 872
# Total biomass:
# Model iMM904.cmd: 3.418354470946064E-5
# Model iJN1463.cmd: 8.005771264266758E-5
# Cycle 873
# Total biomass:
# Model iMM904.cmd: 3.4191709953873324E-5
# Model iJN1463.cmd: 8.007769256830719E-5
# Cycle 874
# Total biomass:
# Model iMM904.cmd: 3.420758849583775E-5
# Model iJN1463.cmd: 8.008974170704593E-5
# Cycle 875
# Total biomass:
# Model iMM904.cmd: 3.421669625184047E-5
# Model iJN1463.cmd: 8.010715873422562E-5
# Cycle 876
# Total biomass:
# Model iMM904.cmd: 3.423195049414866E-5
# Model iJN1463.cmd: 8.012054694884903E-5
# Cycle 877
# Total biomass:
# Model iMM904.cmd: 3.424115353141938E-5
# Model iJN1463.cmd: 8.013767021254278E-5
# Cycle 878
# Total biomass:
# Model iMM904.cmd: 3.4251258452706754E-5
# Model iJN1463.cmd: 8.015550649944786E-5
# Cycle 879
# Total biomass:
# Model iMM904.cmd: 3.426631830301274E-5
# Model iJN1463.cmd: 8.016739531881161E-5
# Cycle 880
# Total biomass:
# Model iMM904.cmd: 3.4277061647236995E-5
# Model iJN1463.cmd: 8.018225118495536E-5
# Cycle 881
# Total biomass:
# Model iMM904.cmd: 3.428622741693703E-5
# Model iJN1463.cmd: 8.019918094995948E-5
# Cycle 882
# Total biomass:
# Model iMM904.cmd: 3.429402178933598E-5
# Model iJN1463.cmd: 8.021710980724099E-5
# Cycle 883
# Total biomass:
# Model iMM904.cmd: 3.4302757396184776E-5
# Model iJN1463.cmd: 8.023370909682008E-5
# Cycle 884
# Total biomass:
# Model iMM904.cmd: 3.4310401030384046E-5
# Model iJN1463.cmd: 8.025109458895624E-5
# Cycle 885
# Total biomass:
# Model iMM904.cmd: 3.432135392238211E-5
# Model iJN1463.cmd: 8.027177765466822E-5
# Cycle 886
# Total biomass:
# Model iMM904.cmd: 3.4333974798429766E-5
# Model iJN1463.cmd: 8.029609295886819E-5
# Cycle 887
# Total biomass:
# Model iMM904.cmd: 3.434798374968349E-5
# Model iJN1463.cmd: 8.031010419366823E-5
# Cycle 888
# Total biomass:
# Model iMM904.cmd: 3.4361624558308864E-5
# Model iJN1463.cmd: 8.032292636092542E-5
# Cycle 889
# Total biomass:
# Model iMM904.cmd: 3.437388291129746E-5
# Model iJN1463.cmd: 8.033591013052114E-5
# Cycle 890
# Total biomass:
# Model iMM904.cmd: 3.4386597940161454E-5
# Model iJN1463.cmd: 8.03483743896633E-5
# Cycle 891
# Total biomass:
# Model iMM904.cmd: 3.439567120732341E-5
# Model iJN1463.cmd: 8.03642143014375E-5
# Cycle 892
# Total biomass:
# Model iMM904.cmd: 3.440629898721762E-5
# Model iJN1463.cmd: 8.037791630075055E-5
# Cycle 893
# Total biomass:
# Model iMM904.cmd: 3.441557221578161E-5
# Model iJN1463.cmd: 8.039302479643386E-5
# Cycle 894
# Total biomass:
# Model iMM904.cmd: 3.4425163792663104E-5
# Model iJN1463.cmd: 8.040793016389075E-5
# Cycle 895
# Total biomass:
# Model iMM904.cmd: 3.4439055515683745E-5
# Model iJN1463.cmd: 8.041878314533878E-5
# Cycle 896
# Total biomass:
# Model iMM904.cmd: 3.44526319570556E-5
# Model iJN1463.cmd: 8.043080737300112E-5
# Cycle 897
# Total biomass:
# Model iMM904.cmd: 3.4465968385792165E-5
# Model iJN1463.cmd: 8.044301743424838E-5
# Cycle 898
# Total biomass:
# Model iMM904.cmd: 3.447676300891472E-5
# Model iJN1463.cmd: 8.045602038274629E-5
# Cycle 899
# Total biomass:
# Model iMM904.cmd: 3.4485688721967294E-5
# Model iJN1463.cmd: 8.047114677894506E-5
# Cycle 900
# Total biomass:
# Model iMM904.cmd: 3.4493173433952424E-5
# Model iJN1463.cmd: 8.048751844592861E-5
# Cycle 901
# Total biomass:
# Model iMM904.cmd: 3.45011840431507E-5
# Model iJN1463.cmd: 8.050316011650791E-5
# Cycle 902
# Total biomass:
# Model iMM904.cmd: 3.451054966473496E-5
# Model iJN1463.cmd: 8.051952658072734E-5
# Cycle 903
# Total biomass:
# Model iMM904.cmd: 3.451870936910137E-5
# Model iJN1463.cmd: 8.053581948506287E-5
# Cycle 904
# Total biomass:
# Model iMM904.cmd: 3.4531697621230605E-5
# Model iJN1463.cmd: 8.054625433776368E-5
# Cycle 905
# Total biomass:
# Model iMM904.cmd: 3.454127656164574E-5
# Model iJN1463.cmd: 8.055963390178679E-5
# Cycle 906
# Total biomass:
# Model iMM904.cmd: 3.45534616744283E-5
# Model iJN1463.cmd: 8.057144830314821E-5
# Cycle 907
# Total biomass:
# Model iMM904.cmd: 3.456404002794228E-5
# Model iJN1463.cmd: 8.058389163225808E-5
# Cycle 908
# Total biomass:
# Model iMM904.cmd: 3.457889833473267E-5
# Model iJN1463.cmd: 8.059426606785497E-5
# Cycle 909
# Total biomass:
# Model iMM904.cmd: 3.458771746472099E-5
# Model iJN1463.cmd: 8.060840236269228E-5
# Cycle 910
# Total biomass:
# Model iMM904.cmd: 3.4600889360391376E-5
# Model iJN1463.cmd: 8.06184317090862E-5
# Cycle 911
# Total biomass:
# Model iMM904.cmd: 3.4614755858938154E-5
# Model iJN1463.cmd: 8.062793214629135E-5
# Cycle 912
# Total biomass:
# Model iMM904.cmd: 3.462487462853626E-5
# Model iJN1463.cmd: 8.064083709512283E-5
# Cycle 913
# Total biomass:
# Model iMM904.cmd: 3.4636801818761186E-5
# Model iJN1463.cmd: 8.065144697169189E-5
# Cycle 914
# Total biomass:
# Model iMM904.cmd: 3.464640406167009E-5
# Model iJN1463.cmd: 8.066529816883995E-5
# Cycle 915
# Total biomass:
# Model iMM904.cmd: 3.465972059938984E-5
# Model iJN1463.cmd: 8.067575391195962E-5
# Cycle 916
# Total biomass:
# Model iMM904.cmd: 3.467083041238472E-5
# Model iJN1463.cmd: 8.068779665078028E-5
# Cycle 917
# Total biomass:
# Model iMM904.cmd: 3.4678653720086034E-5
# Model iJN1463.cmd: 8.07029508734595E-5
# Cycle 918
# Total biomass:
# Model iMM904.cmd: 3.4685487840003166E-5
# Model iJN1463.cmd: 8.071876024542596E-5
# Cycle 919
# Total biomass:
# Model iMM904.cmd: 3.469202997999824E-5
# Model iJN1463.cmd: 8.073416816487756E-5
# Cycle 920
# Total biomass:
# Model iMM904.cmd: 3.469962167145375E-5
# Model iJN1463.cmd: 8.07494813256036E-5
# Cycle 921
# Total biomass:
# Model iMM904.cmd: 3.471185881872738E-5
# Model iJN1463.cmd: 8.075927433607593E-5
# Cycle 922
# Total biomass:
# Model iMM904.cmd: 3.47244000035331E-5
# Model iJN1463.cmd: 8.076992684070485E-5
# Cycle 923
# Total biomass:
# Model iMM904.cmd: 3.473472916505394E-5
# Model iJN1463.cmd: 8.078127612598392E-5
# Cycle 924
# Total biomass:
# Model iMM904.cmd: 3.4743945924480017E-5
# Model iJN1463.cmd: 8.079378929540465E-5
# Cycle 925
# Total biomass:
# Model iMM904.cmd: 3.4752981121703746E-5
# Model iJN1463.cmd: 8.080727574811838E-5
# Cycle 926
# Total biomass:
# Model iMM904.cmd: 3.476083499888153E-5
# Model iJN1463.cmd: 8.08220885485271E-5
# Cycle 927
# Total biomass:
# Model iMM904.cmd: 3.47693033284001E-5
# Model iJN1463.cmd: 8.08360587642091E-5
# Cycle 928
# Total biomass:
# Model iMM904.cmd: 3.477833586599653E-5
# Model iJN1463.cmd: 8.084881537585117E-5
# Cycle 929
# Total biomass:
# Model iMM904.cmd: 3.4785139332943546E-5
# Model iJN1463.cmd: 8.086292857965724E-5
# Cycle 930
# Total biomass:
# Model iMM904.cmd: 3.4792061898969554E-5
# Model iJN1463.cmd: 8.087768693343374E-5
# Cycle 931
# Total biomass:
# Model iMM904.cmd: 3.479908554719494E-5
# Model iJN1463.cmd: 8.089310769071533E-5
# Cycle 932
# Total biomass:
# Model iMM904.cmd: 3.480607044750386E-5
# Model iJN1463.cmd: 8.090844686728502E-5
# Cycle 933
# Total biomass:
# Model iMM904.cmd: 3.481304376587834E-5
# Model iJN1463.cmd: 8.092347886415606E-5
# Cycle 934
# Total biomass:
# Model iMM904.cmd: 3.482027911737353E-5
# Model iJN1463.cmd: 8.09381369587837E-5
# Cycle 935
# Total biomass:
# Model iMM904.cmd: 3.483070996510334E-5
# Model iJN1463.cmd: 8.094951499850975E-5
# Cycle 936
# Total biomass:
# Model iMM904.cmd: 3.483806139195756E-5
# Model iJN1463.cmd: 8.096312687160508E-5
# Cycle 937
# Total biomass:
# Model iMM904.cmd: 3.4844666073521656E-5
# Model iJN1463.cmd: 8.097687944680877E-5
# Cycle 938
# Total biomass:
# Model iMM904.cmd: 3.485152150134818E-5
# Model iJN1463.cmd: 8.099128105378472E-5
# Cycle 939
# Total biomass:
# Model iMM904.cmd: 3.485850933770005E-5
# Model iJN1463.cmd: 8.100613542495961E-5
# Cycle 940
# Total biomass:
# Model iMM904.cmd: 3.486538244151899E-5
# Model iJN1463.cmd: 8.102060966723839E-5
# Cycle 941
# Total biomass:
# Model iMM904.cmd: 3.487506513958569E-5
# Model iJN1463.cmd: 8.103181460887424E-5
# Cycle 942
# Total biomass:
# Model iMM904.cmd: 3.4887221898744E-5
# Model iJN1463.cmd: 8.104030113128124E-5
# Cycle 943
# Total biomass:
# Model iMM904.cmd: 3.4896364590975573E-5
# Model iJN1463.cmd: 8.105081502693104E-5
# Cycle 944
# Total biomass:
# Model iMM904.cmd: 3.49052041485982E-5
# Model iJN1463.cmd: 8.10617010286969E-5
# Cycle 945
# Total biomass:
# Model iMM904.cmd: 3.4911643558421606E-5
# Model iJN1463.cmd: 8.107507143868615E-5
# Cycle 946
# Total biomass:
# Model iMM904.cmd: 3.492379618851004E-5
# Model iJN1463.cmd: 8.108474909988129E-5
# Cycle 947
# Total biomass:
# Model iMM904.cmd: 3.493436115186357E-5
# Model iJN1463.cmd: 8.1094675009082E-5
# Cycle 948
# Total biomass:
# Model iMM904.cmd: 3.494582639296506E-5
# Model iJN1463.cmd: 8.110325409930125E-5
# Cycle 949
# Total biomass:
# Model iMM904.cmd: 3.495740692498399E-5
# Model iJN1463.cmd: 8.111158310242437E-5
# Cycle 950
# Total biomass:
# Model iMM904.cmd: 3.496900928405268E-5
# Model iJN1463.cmd: 8.111983220576416E-5
# Cycle 951
# Total biomass:
# Model iMM904.cmd: 3.4977849803061376E-5
# Model iJN1463.cmd: 8.113038373486191E-5
# Cycle 952
# Total biomass:
# Model iMM904.cmd: 3.49867893885296E-5
# Model iJN1463.cmd: 8.114084829788471E-5
# Cycle 953
# Total biomass:
# Model iMM904.cmd: 3.499439466892524E-5
# Model iJN1463.cmd: 8.115225443667777E-5
# Cycle 954
# Total biomass:
# Model iMM904.cmd: 3.5001644818137754E-5
# Model iJN1463.cmd: 8.116396551651313E-5
# Cycle 955
# Total biomass:
# Model iMM904.cmd: 3.50101109830246E-5
# Model iJN1463.cmd: 8.117486097695864E-5
# Cycle 956
# Total biomass:
# Model iMM904.cmd: 3.5019139874603455E-5
# Model iJN1463.cmd: 8.118506731018401E-5
# Cycle 957
# Total biomass:
# Model iMM904.cmd: 3.502706947686812E-5
# Model iJN1463.cmd: 8.119595701331286E-5
# Cycle 958
# Total biomass:
# Model iMM904.cmd: 3.5038271273334375E-5
# Model iJN1463.cmd: 8.120398308520389E-5
# Cycle 959
# Total biomass:
# Model iMM904.cmd: 3.5047291280730837E-5
# Model iJN1463.cmd: 8.121362593078112E-5
# Cycle 960
# Total biomass:
# Model iMM904.cmd: 3.5054680590938946E-5
# Model iJN1463.cmd: 8.122454371566588E-5
# Cycle 961
# Total biomass:
# Model iMM904.cmd: 3.506184022387484E-5
# Model iJN1463.cmd: 8.12358069106601E-5
# Cycle 962
# Total biomass:
# Model iMM904.cmd: 3.5070673301974214E-5
# Model iJN1463.cmd: 8.124641581773857E-5
# Cycle 963
# Total biomass:
# Model iMM904.cmd: 3.5077703803816506E-5
# Model iJN1463.cmd: 8.12579990410855E-5
# Cycle 964
# Total biomass:
# Model iMM904.cmd: 3.508456268190632E-5
# Model iJN1463.cmd: 8.126962963910654E-5
# Cycle 965
# Total biomass:
# Model iMM904.cmd: 3.5091377268677155E-5
# Model iJN1463.cmd: 8.12811877161416E-5
# Cycle 966
# Total biomass:
# Model iMM904.cmd: 3.50980791755905E-5
# Model iJN1463.cmd: 8.12925879881886E-5
# Cycle 967
# Total biomass:
# Model iMM904.cmd: 3.510772377852286E-5
# Model iJN1463.cmd: 8.130671001012564E-5
# Cycle 968
# Total biomass:
# Model iMM904.cmd: 3.511680323757221E-5
# Model iJN1463.cmd: 8.132294180881086E-5
# Cycle 969
# Total biomass:
# Model iMM904.cmd: 3.512298360327613E-5
# Model iJN1463.cmd: 8.133676980989383E-5
# Cycle 970
# Total biomass:
# Model iMM904.cmd: 3.5132753617404465E-5
# Model iJN1463.cmd: 8.134829129740598E-5
# Cycle 971
# Total biomass:
# Model iMM904.cmd: 3.51442663584718E-5
# Model iJN1463.cmd: 8.135937239915613E-5
# Cycle 972
# Total biomass:
# Model iMM904.cmd: 3.515531041516274E-5
# Model iJN1463.cmd: 8.136856485573786E-5
# Cycle 973
# Total biomass:
# Model iMM904.cmd: 3.5162653638169564E-5
# Model iJN1463.cmd: 8.13796162641897E-5
# Cycle 974
# Total biomass:
# Model iMM904.cmd: 3.516882723737097E-5
# Model iJN1463.cmd: 8.139143736579516E-5
# Cycle 975
# Total biomass:
# Model iMM904.cmd: 3.517481712561779E-5
# Model iJN1463.cmd: 8.140300164515673E-5
# Cycle 976
# Total biomass:
# Model iMM904.cmd: 3.51807655390834E-5
# Model iJN1463.cmd: 8.141441115863774E-5
# Cycle 977
# Total biomass:
# Model iMM904.cmd: 3.5186500572437564E-5
# Model iJN1463.cmd: 8.142557905486181E-5
# Cycle 978
# Total biomass:
# Model iMM904.cmd: 3.5194225177922175E-5
# Model iJN1463.cmd: 8.143959929756247E-5
# Cycle 979
# Total biomass:
# Model iMM904.cmd: 3.520077244504866E-5
# Model iJN1463.cmd: 8.14512914501116E-5
# Cycle 980
# Total biomass:
# Model iMM904.cmd: 3.521045891948466E-5
# Model iJN1463.cmd: 8.147011873630844E-5
# Cycle 981
# Total biomass:
# Model iMM904.cmd: 3.521948093995945E-5
# Model iJN1463.cmd: 8.14864676534213E-5
# Cycle 982
# Total biomass:
# Model iMM904.cmd: 3.522540260511632E-5
# Model iJN1463.cmd: 8.150010194224003E-5
# Cycle 983
# Total biomass:
# Model iMM904.cmd: 3.523069962183072E-5
# Model iJN1463.cmd: 8.151238062392356E-5
# Cycle 984
# Total biomass:
# Model iMM904.cmd: 3.523642521143235E-5
# Model iJN1463.cmd: 8.152432444363724E-5
# Cycle 985
# Total biomass:
# Model iMM904.cmd: 3.524207254071131E-5
# Model iJN1463.cmd: 8.15357146875018E-5
# Cycle 986
# Total biomass:
# Model iMM904.cmd: 3.5248154057141723E-5
# Model iJN1463.cmd: 8.154710920713907E-5
# Cycle 987
# Total biomass:
# Model iMM904.cmd: 3.525391690020589E-5
# Model iJN1463.cmd: 8.155848775303129E-5
# Cycle 988
# Total biomass:
# Model iMM904.cmd: 3.525975199556774E-5
# Model iJN1463.cmd: 8.15696333771467E-5
# Cycle 989
# Total biomass:
# Model iMM904.cmd: 3.526580315138295E-5
# Model iJN1463.cmd: 8.158103076029378E-5
# Cycle 990
# Total biomass:
# Model iMM904.cmd: 3.527154005846621E-5
# Model iJN1463.cmd: 8.15923944447748E-5
# Cycle 991
# Total biomass:
# Model iMM904.cmd: 3.527917279242741E-5
# Model iJN1463.cmd: 8.160104020520582E-5
# Cycle 992
# Total biomass:
# Model iMM904.cmd: 3.5285400534802474E-5
# Model iJN1463.cmd: 8.161189474868659E-5
# Cycle 993
# Total biomass:
# Model iMM904.cmd: 3.529133762309486E-5
# Model iJN1463.cmd: 8.1623227068438E-5
# Cycle 994
# Total biomass:
# Model iMM904.cmd: 3.529751788688889E-5
# Model iJN1463.cmd: 8.163380795170665E-5
# Cycle 995
# Total biomass:
# Model iMM904.cmd: 3.530399453108081E-5
# Model iJN1463.cmd: 8.164454306870682E-5
# Cycle 996
# Total biomass:
# Model iMM904.cmd: 3.531054605497887E-5
# Model iJN1463.cmd: 8.1655512678348E-5
# Cycle 997
# Total biomass:
# Model iMM904.cmd: 3.531937788155226E-5
# Model iJN1463.cmd: 8.166405152831202E-5
# Cycle 998
# Total biomass:
# Model iMM904.cmd: 3.532924774721152E-5
# Model iJN1463.cmd: 8.1671336388525E-5
# Cycle 999
# Total biomass:
# Model iMM904.cmd: 3.5337202604985656E-5
# Model iJN1463.cmd: 8.167969817844971E-5
# Cycle 1000
# Total biomass:
# Model iMM904.cmd: 3.534434873298907E-5
# Model iJN1463.cmd: 8.168964736531256E-5
# Cycle 1001
# End of simulation
# Total time = 7419.878s
#
# STDERR empty.

# %% [markdown]
# Para revisar la biomasa total

# %%
sim.total_biomass.plot(x = "cycle")
# Out:
# <AxesSubplot:xlabel='cycle'>

# %% [markdown]
# Graficamos los resultados de biomasa y demás metabolitos interesantes en el grid:

# %%
im = sim.get_biomass_image('iMM904', params.all_params['maxCycles'])
im2 = sim.get_biomass_image('iJN1463',params.all_params['maxCycles'])

final = np.zeros((grid_size,grid_size,3))
final[:,:,0] = im / np.max(im)
final[:,:,1] = im2 / np.max(im2)
for rock in rock_locs:
    final[rock[0],rock[1],0:3] = 0.4 
from matplotlib import pyplot as plt
ﬁg, ax = plt.subplots(ﬁgsize = (3.1, 3.1))
ax.imshow(ﬁnal)
plt.imshow(final)

# %%
plt.imshow(sim.get_metabolite_image("succ_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("ac_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("nh4_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("o2_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("catechol_e",params.all_params['maxCycles']))
