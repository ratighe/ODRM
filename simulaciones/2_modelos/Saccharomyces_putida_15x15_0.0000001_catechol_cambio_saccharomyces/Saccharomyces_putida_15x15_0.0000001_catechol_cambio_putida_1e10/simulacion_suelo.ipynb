# %% [markdown]
# **Soil-air interface.**
#
# Using the functionality of COMETS, one can design simulations which go beyond in silico corollaries of lab experiments to make predictions for environments mimicking natural ecosystems, which is a necessary step for understanding natural ecology from first principles. In this example, we consider a simulation of a soil environment. We use source-and-sink functions to model how a root provides organic acids to the environment while removing ammonia (Huang et al 2014 Botany). While we restrict the root functionality to a source/sink, one could use functionality demonstrated above, for example extracellular enzymes, to generate feedback loops between microbe-produced metabolites and root exudation. We use fixed metabolite concentrations to mimic the largely unchanging air interface above a root, which generates an oxygen gradient. Additionally, since soil is characterized by strong spatial structure with many impenetrable barriers that localized interactions (Nunan 2017), we place “rock” barriers throughout the simulation area. A more complex simulation could use varying diffusion constants for metabolites, as described in a previous protocol (Virtual Petri Dish). Similarly, we use standard diffusion of biomass, but this could be changed to use pushing force or non-linear diffusion for a potentially increased realism.

# %%
import cobra 
import sys 
import copy 
import numpy as np 
from matplotlib import pyplot as plt 
import cometspy as c

# %% [markdown]
# Para nuestro proyecto, utilizaremos Escherichia coli (modelo iAF1260), Pseudomonas putida (modelo iJN1463) y Saccharomyces Cerevisiae (modelo iMM904), recuperados de la base de datos BIGG.
#
# Cambiamos los bounds de las funciones objetivo de los modelos:

# %%
model_dir = "./modelos" # model location
iMM = cobra.io.read_sbml_model(model_dir + '/iMM904.xml')
iJN = cobra.io.read_sbml_model(model_dir + '/iJN1463.xml')

iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').lower_bound = 0
iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').upper_bound = 1000

iMM.reactions.get_by_id('BIOMASS_SC5_notrace').lower_bound = 0
iMM.reactions.get_by_id('BIOMASS_SC5_notrace').upper_bound = 1000

# %% [markdown]
# Luego se convierten estos modelos al formato de COMETS. Se utilizan funciones helper para dos cosas: a) Asegurar que el modelo en COMETS no confunda las reacciones de "sink" con las de exchange, ya que en COBRA están desbalanceadas y por tanto se parecen a las de exchange, y b) abrir todos los bounds de las reacciones de exchange, para que COMETS controle la composición del medio.

# %%
iMM_comets = c.model(iMM)
iMM_comets.ensure_sinks_are_not_exchanges()
iMM_comets.open_exchanges()

iJN_comets = c.model(iJN)
iJN_comets.ensure_sinks_are_not_exchanges()
iJN_comets.open_exchanges()

# %% [markdown]
# El mundo que se simulará tendrá dimensiones de 30x30. El eje de la izquierda (x = 0) corresponde a la raíz, y el eje superior (y = 0) corresponde al aire. La biomasa y las rocas se distribuyen en el resto del grid. Donde hayan rocas no puede haber ni biomasa ni metabolitos, así que seleccionamos esos lugares primero. Para esta simulación, se generarán 3 rocas con un un tamaño medio de 1 cuadraditos. Para generar las piedras se utiliza la función helper grow_rocks.

# %%
from cometspy.utils import grow_rocks, pick_random_locations

grid_size = 15 # 100
n_rocks = 27 # 70
rock_locs = grow_rocks(n = n_rocks, xrange = [1,grid_size-1],yrange = [1,grid_size-1],mean_size = 1)

# %% [markdown]
# Cada especie será plantada en 20 lugares sin sobreponerse. Para esto se utiliza la función helper pick_random_locations, la cual toma como argumento una tupla generada anteriormente que marca lugares "prohibidos", como los cuadrados donde se encuentran las rocas.
#
# Generamos una copia de rock_locs para no cambiarla accidentalmente, y la llamamos forbbiden_locs:

# %%
import copy
forbidden_locs = copy.deepcopy(rock_locs)

# %% [markdown]
# Ahora elegimos al azar los lugares para cada especie, y los vamos añadiendo a la lista forbidden locs para que no se sobrepongan:

# %%
founders_per_species = 15 # 60
iMM_locs = pick_random_locations(n = founders_per_species, 
                                   xrange = [1,grid_size], yrange = [1,grid_size], 
                                   forbidden_locs = forbidden_locs)
forbidden_locs.extend(iMM_locs)
iJN_locs = pick_random_locations(founders_per_species, [1,grid_size],[1,grid_size], forbidden_locs)

# %% [markdown]
# Para graficar los lugares utilizamos matplotlib:

# %%
from matplotlib import pyplot as plt
initial_image = np.zeros((grid_size,grid_size,3))
for rock in rock_locs:
    initial_image[rock[0],rock[1],0:3] = 0.5 
for loc in iMM_locs:
    initial_image[loc[0],loc[1],1] = 1
for loc in iJN_locs:
    initial_image[loc[0],loc[1],2] = 1
plt.imshow(initial_image)

# %% [markdown]
# Generamos el layout y agregamos las rocas:

# %%
# iAF
iMM_initial_pop = [] 
for loc in iJN_locs: 
    iMM_initial_pop.append([loc[0], loc[1], 1.e-8]) 
iMM_comets.initial_pop = iMM_initial_pop 
# iJN
iJN_initial_pop = [] 
for loc in iJN_locs: 
    iJN_initial_pop.append([loc[0], loc[1], 1.e-10]) 
iJN_comets.initial_pop = iJN_initial_pop

# %% [markdown]
# Setteamos las poblaciones iniciales para cada especie, con esto los modelos están listos y los añadimos al layout:

# %%
layout = c.layout([iMM_comets, iJN_comets])
layout.grid = [grid_size,grid_size]
layout.add_barriers(rock_locs)

# %% [markdown]
# Añadimos los metabolitos que estarán inicialmente disponibles en el ambiente. Usamos la función helper add_typical_trace_metabolites() para las trazas típicas. Bajamos el valor del oxígeno dado que la idea es que el que esté disponible difunda desde la atmósfera. Añadimos algunos metabolitos que no se añadieron con la función helper:

# %%
layout.add_typical_trace_metabolites()
layout.set_specific_metabolite('o2_e',0.00001)
layout.set_specific_metabolite('hco3_e',1000)
layout.set_specific_metabolite('co2_e',1000)
#layout.set_specific_metabolite('h2_e',1000)
layout.set_specific_metabolite('so3_e',1000)
layout.set_specific_metabolite('nh4_e',0.000001)

layout.set_specific_metabolite('glc__D_e',0.0000001)
layout.set_specific_metabolite('meoh_e',0.00000001)
layout.set_specific_metabolite('cys__L_e',0.0000001)
layout.set_specific_metabolite('catechol_e',0.0000001)

# %% [markdown]
# Para la capa de aire, dejamos el oxígeno en un valor constante. Al fondo también dejamos al oxígeno en un valor fijo e igual a 0, para simular el efecto de difusión. De manera similar, hacemos lo mismo con el amoniaco y la raíz en la parte izquierda:

# %%
# set static media of O2 and CO2 at the top and bottom-- the "air" and continuous loss of O2 downwards
for x in range(grid_size):
    layout.set_specific_static_at_location('o2_e', (x,0), .0001) # top
    layout.set_specific_static_at_location('o2_e', (x,grid_size-1), 0.) # bottom
    layout.set_specific_static_at_location('co2_e', (x,0), .0001)
    
for x in range(grid_size):
    layout.set_specific_static_at_location('nh4_e', (0,x), 0.0)

# %% [markdown]
# La raíz consume todo el amoniaco, pero es una fuente de acidos orgánicos y metanol para el ambiente. Asumiendo una tasa fija:

# %%
for x in range(grid_size):
    layout.set_specific_refresh_at_location('cit_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('meoh_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('succ_e', (0,x), .000001)

# %% [markdown]
# El layout y los modelos están listos, ahora setteamos los parámetros de la simulación:

# %%
params = c.params()
params.set_param('timeStep', 0.1)
params.set_param('maxCycles', 1000)
params.set_param('maxSpaceBiomass', 10)
params.set_param('deathRate', 0.0001) # die at rate of 1/10000 per hour
params.set_param('writeBiomassLog', True)
params.set_param('BiomassLogRate', 500)
params.set_param('writeMediaLog', True)
params.set_param('MediaLogRate', 500)
params.set_param("writeFluxLog", True)
params.set_param("FluxLogRate", 500)
params.set_param('numRunThreads', 3)
params.set_param('defaultKm', 0.000001)

# %% [markdown]
# Ahora creamos el objeto de la simulación y la corremos. Ojito que se demora y el pc empieza a despegar.

# %%
sim = c.comets(layout, params)
sim.run(False)
# Out:
# Running COMETS simulation ...
# C:\Users\pabli\AppData\Local\Temp/ipykernel_36392/1491467366.py:2: DtypeWarning: Columns (13,14,15,16,17,18,22,23,24,26,28,30,31,35,45,48,51,59,60,61,68,69,93,95,96,100,102,103,104,105,115,118,123,124,130,138,140,147,153,156,158,162,163,169,171,174,177,187,193,195,196,198,199,214,230,232,234,236,245,248,249,256,258,265,275,276,287,295,306,312,315,324,325,326,327,328,331,333,334,335,338,344,346,348,351,374,375,376,378,380,393,394,400,402,406,409,414,415,418,419,420,423,424,425,430,431,434,435,436,437,440,441,444,453,463,469,501,512,533,541,546,551,563,564,567,577,594,639,648,652,660,666,674,676,680,691,692,695,701,702,713,716,719,720,722,723,726,727,728,730,732,734,735,736,740,744,763,764,765,766,771,774,775,778,782,793,797,799,804,806,810,816,818,819,820,821,822,823,847,848,849,868,869,870,874,878,879,882,886,892,897,911,912,913,914,915,916,919,920,923,924,925,929,930,932,933,934,936,940,941,943,953,960,961,966,978,979,982,984,986,999,1005,1006,1007,1009,1014,1015,1016,1018,1022,1024,1025,1036,1039,1040,1041,1043,1050,1053,1056,1061,1068,1071,1072,1074,1078,1079,1080,1081,1086,1087,1089,1090,1095,1113,1115,1116,1126,1130,1132,1141,1152,1166,1176,1179,1181,1182,1183,1184,1185,1188,1197,1201,1204,1205,1206,1211,1213,1216,1217,1219,1221,1222,1227,1228,1229,1233,1237,1261,1262,1265,1266,1269,1278,1279,1280,1281,1283,1284,1288,1299,1304,1307,1308,1310,1311,1312,1314,1329,1332,1334,1336,1346,1347,1365,1369,1370,1375,1396,1403,1405,1406,1412,1414,1415,1416,1424,1426,1432,1433,1439,1442,1443,1447,1451,1453,1455,1462,1464,1467,1470,1472,1481,1484,1487,1491,1505,1507,1515,1516,1520,1521,1528,1534,1549,1558,1562,1565,1567,1568,1569,1570,1571,1572,1573,1578,1580,1587,1588,1589,1590,1599,1601,1617,1629,1630,1632,1645,1655,1663,1664,1665,1666,1674,1676,1678,1680,1688,1690,1692,1693,1697,1698,1702,1721,1726,1728,1740,1741,1747,1764,1766,1767,1768,1769,1770,1771,1772,1775,1776,1779,1797,1811,1815,1854,1855,1871,1877,1878,1890,1891,1892,1895,1896,1902,1905,1910,1911,1914,1915,1916,1917,1918,1923,1924,1925,1926,1931,1932,1937,1938,1945,1946,1949,1950,1951,1952,1953,1954,1959,1967,1968,1984,1985,1986,1988,1989,1990,1991,1992,1993,1994,1996,1998,2002,2004,2037,2038,2043,2055,2067,2071,2072,2080,2086,2100,2108,2109,2127,2133,2134,2161,2162,2167,2168,2169,2200,2202,2204,2206,2219,2223,2224,2225,2227,2231,2241,2249,2253,2254,2256,2257,2263,2265,2269,2270,2279,2281,2283,2304,2322,2352,2354,2371,2373,2374,2382,2387,2388,2389,2391,2392,2393,2394,2398,2399,2410,2420,2423,2426,2427,2428,2429,2431,2432,2433,2440,2453,2471,2472,2473,2474,2475,2476,2477,2478,2479,2480,2482,2486,2532,2533,2534,2553,2554,2555,2575,2578,2580,2581,2589,2590,2591,2609,2632,2634,2635,2636,2637,2638,2639,2659,2660,2683,2684,2714,2715,2719,2720,2727,2729,2731,2769,2783,2786,2869,2884,2888,2900,2908,2916,2918,2919,2930) have mixed types.Specify dtype option on import or set low_memory=False.
#   sim.run(False)
# Done!

# %%
print(sim.run_output)
print(sim.run_errors)
# Out:
# -script
# running script file: C:\Users\pabli\OneDrive\Escritorio\COMETS\ODRM\simulaciones\2_modelos\Saccharomyces_putida_15x15_0.0000001_catechol_cambio_saccharomyces\Saccharomyces_putida_15x15_0.0000001_catechol_cambio_putida_1e10/.current_script_0x24243a7b970
# Current Java version: 17.0.1
# Parameters file .current_global_0x24243a7b970 loaded.
# Parameters file .current_package_0x24243a7b970 loaded.
# Loading layout file '.current_layout_0x24243a7b970'...
# null\COMETS_manifest.txt (El sistema no puede encontrar la ruta especificada)
# Unable to initialize manifest file.
# Continuing without writing manifest file.
# Found 2 model files!
# Loading '.\iMM904.cmd' ...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution = 133.8587770175764
# Loading '.\iJN1463.cmd' ...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution = 237.06607191111308
# Constructing world...
# Done!
# medialist	12dgr160_e	12dgr180_e	13BDglcn_e	13dampp_e	15dap_e	1ag160_e	1ag180_e	1ag181d9_e	1ag182d9d12_e	25dkglcn_e	26dap__M_e	2ameph_e	2ddglcn_e	2dhglcn_e	2hb_e	2m35mdntha_e	2mbac_e	2mbald_e	2mbtoh_e	2mppal_e	2phetoh_e	34dhbz_e	34dhcinm_e	34dhphe_e	35dnta_e	3c3hmp_e	3h4atb_e	3mb_e	3mbald_e	3mop_e	3oxoadp_e	4abut_e	4abz_e	4hbz_e	4hpro_DC_e	4hpro_LT_e	4hptn_e	4oxptn_e	5aop_e	5aptn_e	5g2oxpt_e	5mcsn_e	5oxpro_e	6atha_e	6hnac_e	8aonn_e	LalaLglu_e	Nbfortyr_e	Ncbmpts_e	R3hdec4e_e	R_3h4atba_e	R_3h6atha_e	R_3hcmrs7e_e	R_3hdcaa_e	R_3hdd5ea_e	R_3hdd6e_e	R_3hdda_e	R_3hhdca_e	R_3hhpa_e	R_3hhxa_e	R_3hnonaa_e	R_3hocta_e	R_3hpba_e	R_3hpdeca_e	R_3hphpa_e	R_3hphxa_e	R_3hpnona_e	R_3hpocta_e	R_3hppta_e	R_3hpt_e	R_3htd58e_e	R_3htd5e_e	R_3httdca_e	T4hcinnm_e	abt_e	ac_e	acac_e	acald_e	aces_e	acmtsoxin_e	acon_C_e	acpptrn_e	acser_e	actn__R_e	ade_e	adn_e	adocbl_e	ag_e	agm_e	akg_e	ala_B_e	ala__D_e	ala__L_e	alaala_e	alahis_e	alaleu_e	alathr_e	alatrp_e	algac_MG_14_e	algac_MG_23_e	algac_MG_32_e	algac_MG_41_e	algac__M_e	alltn_e	alltt_e	amet_e	apc_e	arab__D_e	arab__L_e	arbtn_e	arbtn_fe3_e	arg__D_e	arg__L_e	asn__D_e	asn__L_e	aso3_e	aso4_e	asp__L_e	balaala_e	balabala_e	balagly_e	balaleu_e	balamd_e	bhb_e	biliverd_e	btd_RR_e	btn_e	butso3_e	bz_e	ca2_e	carn_e	catechol_e	cbi_e	cbl1_e	cd2_e	cell4_e	cgly_e	chol_e	chols_e	chor_e	cinnm_e	cit_e	cl_e	cm_e	cmcbtt_e	co2_e	co_e	cobalt2_e	confrl_e	creat_e	crn_e	cro2_e	cro4_e	crtn_e	csn_e	cu2_e	cu_e	cyan_e	cys__D_e	cys__L_e	cytd_e	d2one_e	d3one_e	d4one_e	dad_2_e	dag181d9_e	dag182d9d12_e	dann_e	dca_e	dcyt_e	ddca_e	dgsn_e	dgudbutn_e	din_e	dmanur_e	dmgly_e	dmso2_e	dopa_e	dttp_e	duri_e	ecto__L_e	enter_e	epist_e	epistest_SC_e	ergst_e	ergstest_SC_e	etha_e	ethso3_e	etoh_e	fald_e	fcmcbtt_e	fe2_e	fe3_e	fe3dcit_e	fe3mcbtt_e	fe3pyovd_e	fe3pyovd_kt_e	fecost_e	fecostest_SC_e	fecrm_e	fecrm_un_e	feenter_e	feoxam_e	feoxam_un_e	fer_e	fmn_e	for_e	fru_e	fum_e	g3pc_e	g3pi_e	ga_e	gal_e	galct__D_e	galur_e	gam6p_e	gcald_e	glc__D_e	glcn_e	glcr_e	glcur_e	gln__L_e	glu__L_e	glutar_e	glx_e	gly_e	glyald_e	glyb_e	glyc__R_e	glyc_e	glyclt_e	glycol_e	glygln_e	glyglu_e	glygly_e	glymet_e	glyphe_e	glyser_e	gsn_e	gthox_e	gthrd_e	gua_e	gudac_e	gudptn_e	h2o2_e	h2o_e	h2s_e	h_e	hco3_e	hcys__L_e	hdca_e	hdcea_e	hexc_e	hg2_e	hgentis_e	his__L_e	hisgly_e	hishis_e	hom__L_e	hpta_e	hxa_e	hxan_e	iamac_e	iamoh_e	ibutac_e	ibutoh_e	icit_e	id3acald_e	ile__L_e	ind3ac_e	ind3eth_e	indole_e	inost_e	ins_e	isetac_e	k_e	lac__D_e	lac__L_e	lanost_e	lanostest_SC_e	leu__D_e	leu__L_e	leuleu_e	lnlc_e	lpspput_e	lys__D_e	lys__L_e	m_xyl_e	mal__D_e	mal__L_e	malt_e	man_e	manur_e	mcbtt_e	melib_e	meoh_e	met__D_e	met__L_e	mg2_e	mmet_e	mn2_e	mobd_e	mso3_e	mtsoxin_e	n2one_e	na1_e	nac_e	nadp_e	nh4_e	ni2_e	nmn_e	no2_e	no3_e	no_e	nona_e	o2_e	o_xyl_e	oaa_e	ocdca_e	ocdcea_e	ocdcya_e	octa_e	orn__D_e	orn_e	orot_e	oxa_e	p_xyl_e	pac_e	pacald_e	pap_e	pb2_e	pc_SC_e	pea_e	peamn_e	pectin_e	pentso3_e	pepd_e	phe__D_e	phe__L_e	pheac_e	phedca_e	phehpa_e	phehxa_e	pheme_e	phenona_e	pheocta_e	phept_e	phpyr_e	pi_e	pnto__R_e	ppa_e	ppi_e	pptrn_e	prealg_MG_14_e	prealg_MG_23_e	prealg_MG_32_e	prealg_MG_41_e	prealginate_G_e	pro__D_e	pro__L_e	progly_e	pta_e	ptd1ino_SC_e	ptrc_e	ptsla_e	pydam_e	pyovd_e	pyovd_kt_e	pyr_e	quin_e	rib__D_e	ribflv_e	sbo3_e	sbt__D_e	sbt__L_e	sel_e	ser__D_e	ser__L_e	sheme_e	skm_e	so2_e	so3_e	so4_e	spmd_e	sprm_e	srb__L_e	succ_e	sucr_e	sulfac_e	tag160_e	tag180_e	tag181d9_e	tag182d9d12_e	taur_e	tcynt_e	thm_e	thmmp_e	thmpp_e	thr__L_e	thym_e	thymd_e	tmanur_e	tnt_e	tol_e	tre_e	trp__L_e	tsul_e	ttdca_e	ttdcea_e	ttrcyc_e	tungs_e	tyr__D_e	tyr__L_e	und2one_e	ura_e	urea_e	uri_e	vacc_e	val__D_e	val__L_e	vanln_e	vanlt_e	xan_e	xtsn_e	xyl__D_e	xylt_e	zn2_e	zymst_e	zymstest_SC_e
# Cycle 1
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-20
# FBARunThread-0 starting up.
# FBARunThread-1 starting up.
# FBARunThread-2 starting up.
# Total biomass:
# Model iMM904.cmd: 1.580652147903404E-7
# Model iJN1463.cmd: 1.56759394539921E-9
# Cycle 2
# Total biomass:
# Model iMM904.cmd: 1.6655534355962021E-7
# Model iJN1463.cmd: 1.638238807924468E-9
# Cycle 3
# Total biomass:
# Model iMM904.cmd: 1.7599269941558809E-7
# Model iJN1463.cmd: 1.7234899701537622E-9
# Cycle 4
# Total biomass:
# Model iMM904.cmd: 1.863490832386974E-7
# Model iJN1463.cmd: 1.8160751891131893E-9
# Cycle 5
# Total biomass:
# Model iMM904.cmd: 1.9767954669276353E-7
# Model iJN1463.cmd: 1.913966943423256E-9
# Cycle 6
# Total biomass:
# Model iMM904.cmd: 2.0996216471996215E-7
# Model iJN1463.cmd: 2.0172514572361118E-9
# Cycle 7
# Total biomass:
# Model iMM904.cmd: 2.2318633084619261E-7
# Model iJN1463.cmd: 2.1261529246635E-9
# Cycle 8
# Total biomass:
# Model iMM904.cmd: 2.3740821783148992E-7
# Model iJN1463.cmd: 2.240970207654294E-9
# Cycle 9
# Total biomass:
# Model iMM904.cmd: 2.526230076437217E-7
# Model iJN1463.cmd: 2.362015934500288E-9
# Cycle 10
# Total biomass:
# Model iMM904.cmd: 2.6885598567227166E-7
# Model iJN1463.cmd: 2.4896191903604343E-9
# Cycle 11
# Total biomass:
# Model iMM904.cmd: 2.86134680924497E-7
# Model iJN1463.cmd: 2.6241396109521694E-9
# Cycle 12
# Total biomass:
# Model iMM904.cmd: 3.0451245040588984E-7
# Model iJN1463.cmd: 2.7659395897162904E-9
# Cycle 13
# Total biomass:
# Model iMM904.cmd: 3.240588507990374E-7
# Model iJN1463.cmd: 2.91541345606369E-9
# Cycle 14
# Total biomass:
# Model iMM904.cmd: 3.4484782556179796E-7
# Model iJN1463.cmd: 3.07297693505785E-9
# Cycle 15
# Total biomass:
# Model iMM904.cmd: 3.669579797478255E-7
# Model iJN1463.cmd: 3.239068305958922E-9
# Cycle 16
# Total biomass:
# Model iMM904.cmd: 3.9047287216994733E-7
# Model iJN1463.cmd: 3.4141496242988533E-9
# Cycle 17
# Total biomass:
# Model iMM904.cmd: 4.154813260035779E-7
# Model iJN1463.cmd: 3.598708011116719E-9
# Cycle 18
# Total biomass:
# Model iMM904.cmd: 4.4207775892249307E-7
# Model iJN1463.cmd: 3.793257012877669E-9
# Cycle 19
# Total biomass:
# Model iMM904.cmd: 4.70362533925899E-7
# Model iJN1463.cmd: 3.998338035551962E-9
# Cycle 20
# Total biomass:
# Model iMM904.cmd: 5.004423320894413E-7
# Model iJN1463.cmd: 4.214521856821396E-9
# Cycle 21
# Total biomass:
# Model iMM904.cmd: 5.324305485441212E-7
# Model iJN1463.cmd: 4.442410220481695E-9
# Cycle 22
# Total biomass:
# Model iMM904.cmd: 5.664477130479286E-7
# Model iJN1463.cmd: 4.682637517396942E-9
# Cycle 23
# Total biomass:
# Model iMM904.cmd: 6.026219365624733E-7
# Model iJN1463.cmd: 4.935872557487514E-9
# Cycle 24
# Total biomass:
# Model iMM904.cmd: 6.410893852603258E-7
# Model iJN1463.cmd: 5.202820437561163E-9
# Cycle 25
# Total biomass:
# Model iMM904.cmd: 6.819947833420968E-7
# Model iJN1463.cmd: 5.484224509765304E-9
# Cycle 26
# Total biomass:
# Model iMM904.cmd: 7.255697008373811E-7
# Model iJN1463.cmd: 5.780868455451582E-9
# Cycle 27
# Total biomass:
# Model iMM904.cmd: 7.716685513680267E-7
# Model iJN1463.cmd: 6.093520295360311E-9
# Cycle 28
# Total biomass:
# Model iMM904.cmd: 8.200301047831523E-7
# Model iJN1463.cmd: 6.423090949124759E-9
# Cycle 29
# Total biomass:
# Model iMM904.cmd: 8.703140002024292E-7
# Model iJN1463.cmd: 6.7703968563805755E-9
# Cycle 30
# Total biomass:
# Model iMM904.cmd: 9.219207289013297E-7
# Model iJN1463.cmd: 7.136407720814347E-9
# Cycle 31
# Total biomass:
# Model iMM904.cmd: 9.745641854854316E-7
# Model iJN1463.cmd: 7.52215814780279E-9
# Cycle 32
# Total biomass:
# Model iMM904.cmd: 1.028380840351396E-6
# Model iJN1463.cmd: 7.92871526042136E-9
# Cycle 33
# Total biomass:
# Model iMM904.cmd: 1.0837167021881471E-6
# Model iJN1463.cmd: 8.357183880493606E-9
# Cycle 34
# Total biomass:
# Model iMM904.cmd: 1.1408162804236064E-6
# Model iJN1463.cmd: 8.808719872390067E-9
# Cycle 35
# Total biomass:
# Model iMM904.cmd: 1.1995598266770668E-6
# Model iJN1463.cmd: 9.284520316313976E-9
# Cycle 36
# Total biomass:
# Model iMM904.cmd: 1.2600425293239787E-6
# Model iJN1463.cmd: 9.785823310281371E-9
# Cycle 37
# Total biomass:
# Model iMM904.cmd: 1.3222440136093802E-6
# Model iJN1463.cmd: 1.0313916996181475E-8
# Cycle 38
# Total biomass:
# Model iMM904.cmd: 1.3861501198247917E-6
# Model iJN1463.cmd: 1.0873241529581006E-8
# Cycle 39
# Total biomass:
# Model iMM904.cmd: 1.451629961808396E-6
# Model iJN1463.cmd: 1.1465242310197979E-8
# Cycle 40
# Total biomass:
# Model iMM904.cmd: 1.5185684230862712E-6
# Model iJN1463.cmd: 1.2090479596295047E-8
# Cycle 41
# Total biomass:
# Model iMM904.cmd: 1.586541791976561E-6
# Model iJN1463.cmd: 1.2751552052934327E-8
# Cycle 42
# Total biomass:
# Model iMM904.cmd: 1.654991832298889E-6
# Model iJN1463.cmd: 1.3449246317878077E-8
# Cycle 43
# Total biomass:
# Model iMM904.cmd: 1.7234810450375632E-6
# Model iJN1463.cmd: 1.4184758033296782E-8
# Cycle 44
# Total biomass:
# Model iMM904.cmd: 1.7925245058490208E-6
# Model iJN1463.cmd: 1.4957062351285408E-8
# Cycle 45
# Total biomass:
# Model iMM904.cmd: 1.8625174680179266E-6
# Model iJN1463.cmd: 1.57664142850685E-8
# Cycle 46
# Total biomass:
# Model iMM904.cmd: 1.9337803877541686E-6
# Model iJN1463.cmd: 1.6613504057803176E-8
# Cycle 47
# Total biomass:
# Model iMM904.cmd: 2.0065153754342875E-6
# Model iJN1463.cmd: 1.7498810912260135E-8
# Cycle 48
# Total biomass:
# Model iMM904.cmd: 2.0808122585769025E-6
# Model iJN1463.cmd: 1.8421666938262522E-8
# Cycle 49
# Total biomass:
# Model iMM904.cmd: 2.1567384287302784E-6
# Model iJN1463.cmd: 1.9382042668714897E-8
# Cycle 50
# Total biomass:
# Model iMM904.cmd: 2.2345133425335633E-6
# Model iJN1463.cmd: 2.0378707261892607E-8
# Cycle 51
# Total biomass:
# Model iMM904.cmd: 2.314357233847856E-6
# Model iJN1463.cmd: 2.141280656425067E-8
# Cycle 52
# Total biomass:
# Model iMM904.cmd: 2.396468852459686E-6
# Model iJN1463.cmd: 2.248711876991427E-8
# Cycle 53
# Total biomass:
# Model iMM904.cmd: 2.4809833270942195E-6
# Model iJN1463.cmd: 2.3604326749391352E-8
# Cycle 54
# Total biomass:
# Model iMM904.cmd: 2.5679782552698573E-6
# Model iJN1463.cmd: 2.4767664124630733E-8
# Cycle 55
# Total biomass:
# Model iMM904.cmd: 2.657558324384863E-6
# Model iJN1463.cmd: 2.5980869584582277E-8
# Cycle 56
# Total biomass:
# Model iMM904.cmd: 2.7498445274222935E-6
# Model iJN1463.cmd: 2.724693952063955E-8
# Cycle 57
# Total biomass:
# Model iMM904.cmd: 2.844917698726984E-6
# Model iJN1463.cmd: 2.8568014831832497E-8
# Cycle 58
# Total biomass:
# Model iMM904.cmd: 2.9428613679306126E-6
# Model iJN1463.cmd: 2.9948231106354074E-8
# Cycle 59
# Total biomass:
# Model iMM904.cmd: 3.0437662099406247E-6
# Model iJN1463.cmd: 3.139132061556564E-8
# Cycle 60
# Total biomass:
# Model iMM904.cmd: 3.1476749897991287E-6
# Model iJN1463.cmd: 3.2901226074657104E-8
# Cycle 61
# Total biomass:
# Model iMM904.cmd: 3.2546683531472383E-6
# Model iJN1463.cmd: 3.448142088450774E-8
# Cycle 62
# Total biomass:
# Model iMM904.cmd: 3.3647527662297254E-6
# Model iJN1463.cmd: 3.6135531031912164E-8
# Cycle 63
# Total biomass:
# Model iMM904.cmd: 3.4779593921642304E-6
# Model iJN1463.cmd: 3.7867513287657E-8
# Cycle 64
# Total biomass:
# Model iMM904.cmd: 3.594353159402341E-6
# Model iJN1463.cmd: 3.968124636053185E-8
# Cycle 65
# Total biomass:
# Model iMM904.cmd: 3.7139512888210276E-6
# Model iJN1463.cmd: 4.158431828454158E-8
# Cycle 66
# Total biomass:
# Model iMM904.cmd: 3.8368914086207996E-6
# Model iJN1463.cmd: 4.3578066789082853E-8
# Cycle 67
# Total biomass:
# Model iMM904.cmd: 3.963271025900454E-6
# Model iJN1463.cmd: 4.566679926259702E-8
# Cycle 68
# Total biomass:
# Model iMM904.cmd: 4.093166028246124E-6
# Model iJN1463.cmd: 4.7854587597225155E-8
# Cycle 69
# Total biomass:
# Model iMM904.cmd: 4.226610751180992E-6
# Model iJN1463.cmd: 5.0143822473008905E-8
# Cycle 70
# Total biomass:
# Model iMM904.cmd: 4.363062517865996E-6
# Model iJN1463.cmd: 5.253508721965241E-8
# Cycle 71
# Total biomass:
# Model iMM904.cmd: 4.502347399446555E-6
# Model iJN1463.cmd: 5.5051630596309637E-8
# Cycle 72
# Total biomass:
# Model iMM904.cmd: 4.644839280980868E-6
# Model iJN1463.cmd: 5.766709882222543E-8
# Cycle 73
# Total biomass:
# Model iMM904.cmd: 4.791048589934169E-6
# Model iJN1463.cmd: 6.038752008005558E-8
# Cycle 74
# Total biomass:
# Model iMM904.cmd: 4.941057740749862E-6
# Model iJN1463.cmd: 6.322300379718743E-8
# Cycle 75
# Total biomass:
# Model iMM904.cmd: 5.095117273044955E-6
# Model iJN1463.cmd: 6.617973180434047E-8
# Cycle 76
# Total biomass:
# Model iMM904.cmd: 5.2535665624763955E-6
# Model iJN1463.cmd: 6.928799252030116E-8
# Cycle 77
# Total biomass:
# Model iMM904.cmd: 5.416420637748708E-6
# Model iJN1463.cmd: 7.253154505947678E-8
# Cycle 78
# Total biomass:
# Model iMM904.cmd: 5.583838025242292E-6
# Model iJN1463.cmd: 7.594366363507514E-8
# Cycle 79
# Total biomass:
# Model iMM904.cmd: 5.755982134604951E-6
# Model iJN1463.cmd: 7.950955294900296E-8
# Cycle 80
# Total biomass:
# Model iMM904.cmd: 5.933051695255514E-6
# Model iJN1463.cmd: 8.323699751839626E-8
# Cycle 81
# Total biomass:
# Model iMM904.cmd: 6.115149058942909E-6
# Model iJN1463.cmd: 8.713270930051491E-8
# Cycle 82
# Total biomass:
# Model iMM904.cmd: 6.302400401205527E-6
# Model iJN1463.cmd: 9.120046951111877E-8
# Cycle 83
# Total biomass:
# Model iMM904.cmd: 6.49494634887092E-6
# Model iJN1463.cmd: 9.544207519808803E-8
# Cycle 84
# Total biomass:
# Model iMM904.cmd: 6.692947250372969E-6
# Model iJN1463.cmd: 9.985440604779899E-8
# Cycle 85
# Total biomass:
# Model iMM904.cmd: 6.896619372547695E-6
# Model iJN1463.cmd: 1.0444291843183873E-7
# Cycle 86
# Total biomass:
# Model iMM904.cmd: 7.106136686431857E-6
# Model iJN1463.cmd: 1.0921155287221926E-7
# Cycle 87
# Total biomass:
# Model iMM904.cmd: 7.3216724776542505E-6
# Model iJN1463.cmd: 1.141773182722695E-7
# Cycle 88
# Total biomass:
# Model iMM904.cmd: 7.543399182145985E-6
# Model iJN1463.cmd: 1.194555931077328E-7
# Cycle 89
# Total biomass:
# Model iMM904.cmd: 7.77150278397393E-6
# Model iJN1463.cmd: 1.249906756703175E-7
# Cycle 90
# Total biomass:
# Model iMM904.cmd: 8.006174263071742E-6
# Model iJN1463.cmd: 1.307776335985369E-7
# Cycle 91
# Total biomass:
# Model iMM904.cmd: 8.247576078675595E-6
# Model iJN1463.cmd: 1.368179343395089E-7
# Cycle 92
# Total biomass:
# Model iMM904.cmd: 8.495843845286796E-6
# Model iJN1463.cmd: 1.4313093711978755E-7
# Cycle 93
# Total biomass:
# Model iMM904.cmd: 8.751118599543412E-6
# Model iJN1463.cmd: 1.5004004143669467E-7
# Cycle 94
# Total biomass:
# Model iMM904.cmd: 9.013635485783634E-6
# Model iJN1463.cmd: 1.575069928873517E-7
# Cycle 95
# Total biomass:
# Model iMM904.cmd: 9.283598307904936E-6
# Model iJN1463.cmd: 1.6533448640553408E-7
# Cycle 96
# Total biomass:
# Model iMM904.cmd: 9.561247078408298E-6
# Model iJN1463.cmd: 1.7353477691787135E-7
# Cycle 97
# Total biomass:
# Model iMM904.cmd: 9.846710242480199E-6
# Model iJN1463.cmd: 1.8214826041480203E-7
# Cycle 98
# Total biomass:
# Model iMM904.cmd: 1.0140198304526736E-5
# Model iJN1463.cmd: 1.9127086218291673E-7
# Cycle 99
# Total biomass:
# Model iMM904.cmd: 1.0442017371220831E-5
# Model iJN1463.cmd: 2.0111161232117086E-7
# Cycle 100
# Total biomass:
# Model iMM904.cmd: 1.075237875564471E-5
# Model iJN1463.cmd: 2.1142670747332545E-7
# Cycle 101
# Total biomass:
# Model iMM904.cmd: 1.1071529782660542E-5
# Model iJN1463.cmd: 2.22244662901944E-7
# Cycle 102
# Total biomass:
# Model iMM904.cmd: 1.1399746305086483E-5
# Model iJN1463.cmd: 2.3359587780720435E-7
# Cycle 103
# Total biomass:
# Model iMM904.cmd: 1.1737279622377563E-5
# Model iJN1463.cmd: 2.4550416223788156E-7
# Cycle 104
# Total biomass:
# Model iMM904.cmd: 1.2084449323699624E-5
# Model iJN1463.cmd: 2.579942275019847E-7
# Cycle 105
# Total biomass:
# Model iMM904.cmd: 1.2441456304089037E-5
# Model iJN1463.cmd: 2.710975936378481E-7
# Cycle 106
# Total biomass:
# Model iMM904.cmd: 1.2808368658436615E-5
# Model iJN1463.cmd: 2.848377760877015E-7
# Cycle 107
# Total biomass:
# Model iMM904.cmd: 1.318508799057325E-5
# Model iJN1463.cmd: 2.992437534610323E-7
# Cycle 108
# Total biomass:
# Model iMM904.cmd: 1.3571537997371153E-5
# Model iJN1463.cmd: 3.143445079246582E-7
# Cycle 109
# Total biomass:
# Model iMM904.cmd: 1.3967384522825678E-5
# Model iJN1463.cmd: 3.3017267690226253E-7
# Cycle 110
# Total biomass:
# Model iMM904.cmd: 1.4372517476882106E-5
# Model iJN1463.cmd: 3.467603503413167E-7
# Cycle 111
# Total biomass:
# Model iMM904.cmd: 1.478621883475247E-5
# Model iJN1463.cmd: 3.6414323094358443E-7
# Cycle 112
# Total biomass:
# Model iMM904.cmd: 1.5207914226189565E-5
# Model iJN1463.cmd: 3.8236787290692825E-7
# Cycle 113
# Total biomass:
# Model iMM904.cmd: 1.5637240347964807E-5
# Model iJN1463.cmd: 4.0146773195957407E-7
# Cycle 114
# Total biomass:
# Model iMM904.cmd: 1.6073438673022386E-5
# Model iJN1463.cmd: 4.2148180601869595E-7
# Cycle 115
# Total biomass:
# Model iMM904.cmd: 1.651564795217677E-5
# Model iJN1463.cmd: 4.424615385796432E-7
# Cycle 116
# Total biomass:
# Model iMM904.cmd: 1.6961911682600062E-5
# Model iJN1463.cmd: 4.644256165409706E-7
# Cycle 117
# Total biomass:
# Model iMM904.cmd: 1.7410598045951117E-5
# Model iJN1463.cmd: 4.874159342585005E-7
# Cycle 118
# Total biomass:
# Model iMM904.cmd: 1.7859043065924212E-5
# Model iJN1463.cmd: 5.115360781128022E-7
# Cycle 119
# Total biomass:
# Model iMM904.cmd: 1.8304826288795855E-5
# Model iJN1463.cmd: 5.36803532201325E-7
# Cycle 120
# Total biomass:
# Model iMM904.cmd: 1.874624012679802E-5
# Model iJN1463.cmd: 5.633071660066595E-7
# Cycle 121
# Total biomass:
# Model iMM904.cmd: 1.9179347202264034E-5
# Model iJN1463.cmd: 5.910572088286824E-7
# Cycle 122
# Total biomass:
# Model iMM904.cmd: 1.9601363275939276E-5
# Model iJN1463.cmd: 6.201293161125754E-7
# Cycle 123
# Total biomass:
# Model iMM904.cmd: 2.0010246255432038E-5
# Model iJN1463.cmd: 6.50515855556268E-7
# Cycle 124
# Total biomass:
# Model iMM904.cmd: 2.0404678404562903E-5
# Model iJN1463.cmd: 6.823031014827946E-7
# Cycle 125
# Total biomass:
# Model iMM904.cmd: 2.078248189711611E-5
# Model iJN1463.cmd: 7.155793099332298E-7
# Cycle 126
# Total biomass:
# Model iMM904.cmd: 2.1141677717695114E-5
# Model iJN1463.cmd: 7.50703561187178E-7
# Cycle 127
# Total biomass:
# Model iMM904.cmd: 2.1480473272009156E-5
# Model iJN1463.cmd: 7.875298837782402E-7
# Cycle 128
# Total biomass:
# Model iMM904.cmd: 2.179707796387326E-5
# Model iJN1463.cmd: 8.260857111433783E-7
# Cycle 129
# Total biomass:
# Model iMM904.cmd: 2.2093128629995486E-5
# Model iJN1463.cmd: 8.663750313152365E-7
# Cycle 130
# Total biomass:
# Model iMM904.cmd: 2.2369352930990723E-5
# Model iJN1463.cmd: 9.084247178308794E-7
# Cycle 131
# Total biomass:
# Model iMM904.cmd: 2.2625999987268407E-5
# Model iJN1463.cmd: 9.524363318675582E-7
# Cycle 132
# Total biomass:
# Model iMM904.cmd: 2.2863422565034397E-5
# Model iJN1463.cmd: 9.983743815958796E-7
# Cycle 133
# Total biomass:
# Model iMM904.cmd: 2.3084847957352248E-5
# Model iJN1463.cmd: 1.0462977505555595E-6
# Cycle 134
# Total biomass:
# Model iMM904.cmd: 2.3292650648854087E-5
# Model iJN1463.cmd: 1.096305447900812E-6
# Cycle 135
# Total biomass:
# Model iMM904.cmd: 2.348819148327335E-5
# Model iJN1463.cmd: 1.148497431572147E-6
# Cycle 136
# Total biomass:
# Model iMM904.cmd: 2.3674013372859143E-5
# Model iJN1463.cmd: 1.2030904433024563E-6
# Cycle 137
# Total biomass:
# Model iMM904.cmd: 2.3852523812808824E-5
# Model iJN1463.cmd: 1.2600089386849776E-6
# Cycle 138
# Total biomass:
# Model iMM904.cmd: 2.402513234225876E-5
# Model iJN1463.cmd: 1.3195700523910885E-6
# Cycle 139
# Total biomass:
# Model iMM904.cmd: 2.419469419593354E-5
# Model iJN1463.cmd: 1.3817503185359853E-6
# Cycle 140
# Total biomass:
# Model iMM904.cmd: 2.4360288404026013E-5
# Model iJN1463.cmd: 1.446587152436436E-6
# Cycle 141
# Total biomass:
# Model iMM904.cmd: 2.4523556064422625E-5
# Model iJN1463.cmd: 1.514328717509488E-6
# Cycle 142
# Total biomass:
# Model iMM904.cmd: 2.468689710662332E-5
# Model iJN1463.cmd: 1.584991057366291E-6
# Cycle 143
# Total biomass:
# Model iMM904.cmd: 2.4848046957624045E-5
# Model iJN1463.cmd: 1.6586325135256322E-6
# Cycle 144
# Total biomass:
# Model iMM904.cmd: 2.5008065551038727E-5
# Model iJN1463.cmd: 1.7353499834860365E-6
# Cycle 145
# Total biomass:
# Model iMM904.cmd: 2.5166510625060223E-5
# Model iJN1463.cmd: 1.8152213117318078E-6
# Cycle 146
# Total biomass:
# Model iMM904.cmd: 2.532358937953946E-5
# Model iJN1463.cmd: 1.8983791940137588E-6
# Cycle 147
# Total biomass:
# Model iMM904.cmd: 2.5478851992725975E-5
# Model iJN1463.cmd: 1.9849761873529245E-6
# Cycle 148
# Total biomass:
# Model iMM904.cmd: 2.5628398203549103E-5
# Model iJN1463.cmd: 2.07522869534877E-6
# Cycle 149
# Total biomass:
# Model iMM904.cmd: 2.577641749497029E-5
# Model iJN1463.cmd: 2.169357199725964E-6
# Cycle 150
# Total biomass:
# Model iMM904.cmd: 2.5927915821493722E-5
# Model iJN1463.cmd: 2.267328801157176E-6
# Cycle 151
# Total biomass:
# Model iMM904.cmd: 2.6078162290277337E-5
# Model iJN1463.cmd: 2.3693085065254747E-6
# Cycle 152
# Total biomass:
# Model iMM904.cmd: 2.6227342558341168E-5
# Model iJN1463.cmd: 2.4754746437178785E-6
# Cycle 153
# Total biomass:
# Model iMM904.cmd: 2.6375574532549124E-5
# Model iJN1463.cmd: 2.585862551432345E-6
# Cycle 154
# Total biomass:
# Model iMM904.cmd: 2.652252365995955E-5
# Model iJN1463.cmd: 2.700667373077523E-6
# Cycle 155
# Total biomass:
# Model iMM904.cmd: 2.66668168524575E-5
# Model iJN1463.cmd: 2.8199940196697063E-6
# Cycle 156
# Total biomass:
# Model iMM904.cmd: 2.6809783490213124E-5
# Model iJN1463.cmd: 2.943948260461099E-6
# Cycle 157
# Total biomass:
# Model iMM904.cmd: 2.695175695861054E-5
# Model iJN1463.cmd: 3.0725630607013076E-6
# Cycle 158
# Total biomass:
# Model iMM904.cmd: 2.709203624114822E-5
# Model iJN1463.cmd: 3.206123184170255E-6
# Cycle 159
# Total biomass:
# Model iMM904.cmd: 2.7231206448841398E-5
# Model iJN1463.cmd: 3.3448299245158285E-6
# Cycle 160
# Total biomass:
# Model iMM904.cmd: 2.736892888332292E-5
# Model iJN1463.cmd: 3.488821827431072E-6
# Cycle 161
# Total biomass:
# Model iMM904.cmd: 2.750522254073895E-5
# Model iJN1463.cmd: 3.638272476551065E-6
# Cycle 162
# Total biomass:
# Model iMM904.cmd: 2.7640334177035693E-5
# Model iJN1463.cmd: 3.793360291091943E-6
# Cycle 163
# Total biomass:
# Model iMM904.cmd: 2.777452833821717E-5
# Model iJN1463.cmd: 3.954380417117227E-6
# Cycle 164
# Total biomass:
# Model iMM904.cmd: 2.7907689063377672E-5
# Model iJN1463.cmd: 4.121613557080816E-6
# Cycle 165
# Total biomass:
# Model iMM904.cmd: 2.804085484432404E-5
# Model iJN1463.cmd: 4.295162057252283E-6
# Cycle 166
# Total biomass:
# Model iMM904.cmd: 2.817709833561217E-5
# Model iJN1463.cmd: 4.474761859053768E-6
# Cycle 167
# Total biomass:
# Model iMM904.cmd: 2.8312165278556208E-5
# Model iJN1463.cmd: 4.660664273977488E-6
# Cycle 168
# Total biomass:
# Model iMM904.cmd: 2.8444019521222276E-5
# Model iJN1463.cmd: 4.853521814745932E-6
# Cycle 169
# Total biomass:
# Model iMM904.cmd: 2.8576309023791913E-5
# Model iJN1463.cmd: 5.053416683938861E-6
# Cycle 170
# Total biomass:
# Model iMM904.cmd: 2.8707853210079687E-5
# Model iJN1463.cmd: 5.260411444127431E-6
# Cycle 171
# Total biomass:
# Model iMM904.cmd: 2.8838973869094157E-5
# Model iJN1463.cmd: 5.474799650682949E-6
# Cycle 172
# Total biomass:
# Model iMM904.cmd: 2.8969202510156857E-5
# Model iJN1463.cmd: 5.697238704518204E-6
# Cycle 173
# Total biomass:
# Model iMM904.cmd: 2.909844609746617E-5
# Model iJN1463.cmd: 5.928055620664483E-6
# Cycle 174
# Total biomass:
# Model iMM904.cmd: 2.9226951079999747E-5
# Model iJN1463.cmd: 6.167208466426111E-6
# Cycle 175
# Total biomass:
# Model iMM904.cmd: 2.9354495515932936E-5
# Model iJN1463.cmd: 6.414967675009065E-6
# Cycle 176
# Total biomass:
# Model iMM904.cmd: 2.9481489691828656E-5
# Model iJN1463.cmd: 6.67121846516128E-6
# Cycle 177
# Total biomass:
# Model iMM904.cmd: 2.9607601334769783E-5
# Model iJN1463.cmd: 6.9367660437306514E-6
# Cycle 178
# Total biomass:
# Model iMM904.cmd: 2.973261161786241E-5
# Model iJN1463.cmd: 7.2118144118280586E-6
# Cycle 179
# Total biomass:
# Model iMM904.cmd: 2.98560454833002E-5
# Model iJN1463.cmd: 7.4958204480633775E-6
# Cycle 180
# Total biomass:
# Model iMM904.cmd: 2.9978393652832817E-5
# Model iJN1463.cmd: 7.788473105932916E-6
# Cycle 181
# Total biomass:
# Model iMM904.cmd: 3.0101504531828763E-5
# Model iJN1463.cmd: 8.088153264167975E-6
# Cycle 182
# Total biomass:
# Model iMM904.cmd: 3.0223487937001135E-5
# Model iJN1463.cmd: 8.391894718774753E-6
# Cycle 183
# Total biomass:
# Model iMM904.cmd: 3.0344205512450735E-5
# Model iJN1463.cmd: 8.69829669050365E-6
# Cycle 184
# Total biomass:
# Model iMM904.cmd: 3.0462577230017207E-5
# Model iJN1463.cmd: 9.005728801633085E-6
# Cycle 185
# Total biomass:
# Model iMM904.cmd: 3.0579720768895767E-5
# Model iJN1463.cmd: 9.311203034679412E-6
# Cycle 186
# Total biomass:
# Model iMM904.cmd: 3.069635071917955E-5
# Model iJN1463.cmd: 9.61384739745084E-6
# Cycle 187
# Total biomass:
# Model iMM904.cmd: 3.0812877354541213E-5
# Model iJN1463.cmd: 9.91115190838708E-6
# Cycle 188
# Total biomass:
# Model iMM904.cmd: 3.092953396896713E-5
# Model iJN1463.cmd: 1.0200748308551836E-5
# Cycle 189
# Total biomass:
# Model iMM904.cmd: 3.104609033517034E-5
# Model iJN1463.cmd: 1.048008221397412E-5
# Cycle 190
# Total biomass:
# Model iMM904.cmd: 3.116070164585874E-5
# Model iJN1463.cmd: 1.0748692106341223E-5
# Cycle 191
# Total biomass:
# Model iMM904.cmd: 3.127385781790231E-5
# Model iJN1463.cmd: 1.1001041576142148E-5
# Cycle 192
# Total biomass:
# Model iMM904.cmd: 3.1388774904645935E-5
# Model iJN1463.cmd: 1.1236033907341482E-5
# Cycle 193
# Total biomass:
# Model iMM904.cmd: 3.1503593832873696E-5
# Model iJN1463.cmd: 1.1453505085756313E-5
# Cycle 194
# Total biomass:
# Model iMM904.cmd: 3.1617593747798E-5
# Model iJN1463.cmd: 1.1654225276325845E-5
# Cycle 195
# Total biomass:
# Model iMM904.cmd: 3.173129111261603E-5
# Model iJN1463.cmd: 1.1835377086114612E-5
# Cycle 196
# Total biomass:
# Model iMM904.cmd: 3.1844705865159104E-5
# Model iJN1463.cmd: 1.1998720038206536E-5
# Cycle 197
# Total biomass:
# Model iMM904.cmd: 3.195795720173115E-5
# Model iJN1463.cmd: 1.2147040482469045E-5
# Cycle 198
# Total biomass:
# Model iMM904.cmd: 3.207056283129809E-5
# Model iJN1463.cmd: 1.2282766748189531E-5
# Cycle 199
# Total biomass:
# Model iMM904.cmd: 3.218224321114041E-5
# Model iJN1463.cmd: 1.240938647458936E-5
# Cycle 200
# Total biomass:
# Model iMM904.cmd: 3.22934698199195E-5
# Model iJN1463.cmd: 1.2529922971109791E-5
# Cycle 201
# Total biomass:
# Model iMM904.cmd: 3.240304153558075E-5
# Model iJN1463.cmd: 1.2645652090169878E-5
# Cycle 202
# Total biomass:
# Model iMM904.cmd: 3.251301688662765E-5
# Model iJN1463.cmd: 1.2757330778677877E-5
# Cycle 203
# Total biomass:
# Model iMM904.cmd: 3.2622787445665796E-5
# Model iJN1463.cmd: 1.2864679138595273E-5
# Cycle 204
# Total biomass:
# Model iMM904.cmd: 3.2733552983917154E-5
# Model iJN1463.cmd: 1.2968361054209756E-5
# Cycle 205
# Total biomass:
# Model iMM904.cmd: 3.284384158957949E-5
# Model iJN1463.cmd: 1.3069688287673328E-5
# Cycle 206
# Total biomass:
# Model iMM904.cmd: 3.295308431293837E-5
# Model iJN1463.cmd: 1.3169529135972936E-5
# Cycle 207
# Total biomass:
# Model iMM904.cmd: 3.306268724435776E-5
# Model iJN1463.cmd: 1.3268562978131487E-5
# Cycle 208
# Total biomass:
# Model iMM904.cmd: 3.317196351248913E-5
# Model iJN1463.cmd: 1.3366711059604084E-5
# Cycle 209
# Total biomass:
# Model iMM904.cmd: 3.3280899203819464E-5
# Model iJN1463.cmd: 1.3464430933195163E-5
# Cycle 210
# Total biomass:
# Model iMM904.cmd: 3.3389491552237846E-5
# Model iJN1463.cmd: 1.3561381961209107E-5
# Cycle 211
# Total biomass:
# Model iMM904.cmd: 3.349769805279738E-5
# Model iJN1463.cmd: 1.3657748360453908E-5
# Cycle 212
# Total biomass:
# Model iMM904.cmd: 3.360558324595297E-5
# Model iJN1463.cmd: 1.3754057136165974E-5
# Cycle 213
# Total biomass:
# Model iMM904.cmd: 3.371318884907553E-5
# Model iJN1463.cmd: 1.3850388883779504E-5
# Cycle 214
# Total biomass:
# Model iMM904.cmd: 3.3820398516555664E-5
# Model iJN1463.cmd: 1.3946395537958999E-5
# Cycle 215
# Total biomass:
# Model iMM904.cmd: 3.392746688213985E-5
# Model iJN1463.cmd: 1.4042476263534805E-5
# Cycle 216
# Total biomass:
# Model iMM904.cmd: 3.403419479274786E-5
# Model iJN1463.cmd: 1.4138810879542724E-5
# Cycle 217
# Total biomass:
# Model iMM904.cmd: 3.414058320927333E-5
# Model iJN1463.cmd: 1.4235475086640489E-5
# Cycle 218
# Total biomass:
# Model iMM904.cmd: 3.424655020312478E-5
# Model iJN1463.cmd: 1.4332691674591775E-5
# Cycle 219
# Total biomass:
# Model iMM904.cmd: 3.435219916911814E-5
# Model iJN1463.cmd: 1.4429558404429113E-5
# Cycle 220
# Total biomass:
# Model iMM904.cmd: 3.445742333188063E-5
# Model iJN1463.cmd: 1.4526784891041429E-5
# Cycle 221
# Total biomass:
# Model iMM904.cmd: 3.4562312394984154E-5
# Model iJN1463.cmd: 1.4624191204985956E-5
# Cycle 222
# Total biomass:
# Model iMM904.cmd: 3.4666824122210155E-5
# Model iJN1463.cmd: 1.4721226180771678E-5
# Cycle 223
# Total biomass:
# Model iMM904.cmd: 3.477051353828765E-5
# Model iJN1463.cmd: 1.481829219149318E-5
# Cycle 224
# Total biomass:
# Model iMM904.cmd: 3.487315103262081E-5
# Model iJN1463.cmd: 1.491532675227455E-5
# Cycle 225
# Total biomass:
# Model iMM904.cmd: 3.49754093588571E-5
# Model iJN1463.cmd: 1.5012700540486488E-5
# Cycle 226
# Total biomass:
# Model iMM904.cmd: 3.507678175611455E-5
# Model iJN1463.cmd: 1.511023941923644E-5
# Cycle 227
# Total biomass:
# Model iMM904.cmd: 3.517736873429828E-5
# Model iJN1463.cmd: 1.5208320205034267E-5
# Cycle 228
# Total biomass:
# Model iMM904.cmd: 3.527751338281353E-5
# Model iJN1463.cmd: 1.5307151418026556E-5
# Cycle 229
# Total biomass:
# Model iMM904.cmd: 3.5377411963742745E-5
# Model iJN1463.cmd: 1.540645222330778E-5
# Cycle 230
# Total biomass:
# Model iMM904.cmd: 3.5477111558284934E-5
# Model iJN1463.cmd: 1.5506257924510614E-5
# Cycle 231
# Total biomass:
# Model iMM904.cmd: 3.5576011568383966E-5
# Model iJN1463.cmd: 1.5606667606535462E-5
# Cycle 232
# Total biomass:
# Model iMM904.cmd: 3.567472705021064E-5
# Model iJN1463.cmd: 1.570745573852871E-5
# Cycle 233
# Total biomass:
# Model iMM904.cmd: 3.577569025430632E-5
# Model iJN1463.cmd: 1.5808528232004665E-5
# Cycle 234
# Total biomass:
# Model iMM904.cmd: 3.587647038669697E-5
# Model iJN1463.cmd: 1.5909090599893235E-5
# Cycle 235
# Total biomass:
# Model iMM904.cmd: 3.597662340256369E-5
# Model iJN1463.cmd: 1.6009135826880283E-5
# Cycle 236
# Total biomass:
# Model iMM904.cmd: 3.607659109899626E-5
# Model iJN1463.cmd: 1.6109263732971013E-5
# Cycle 237
# Total biomass:
# Model iMM904.cmd: 3.617628804246655E-5
# Model iJN1463.cmd: 1.6209090957097577E-5
# Cycle 238
# Total biomass:
# Model iMM904.cmd: 3.627558891429349E-5
# Model iJN1463.cmd: 1.6309290563203258E-5
# Cycle 239
# Total biomass:
# Model iMM904.cmd: 3.6373493404538566E-5
# Model iJN1463.cmd: 1.6409606352922182E-5
# Cycle 240
# Total biomass:
# Model iMM904.cmd: 3.6472090624112583E-5
# Model iJN1463.cmd: 1.6510758483828018E-5
# Cycle 241
# Total biomass:
# Model iMM904.cmd: 3.657116771979854E-5
# Model iJN1463.cmd: 1.6612216757122823E-5
# Cycle 242
# Total biomass:
# Model iMM904.cmd: 3.667048691072414E-5
# Model iJN1463.cmd: 1.671351467082136E-5
# Cycle 243
# Total biomass:
# Model iMM904.cmd: 3.6768770734204395E-5
# Model iJN1463.cmd: 1.6815237869276685E-5
# Cycle 244
# Total biomass:
# Model iMM904.cmd: 3.686622974060185E-5
# Model iJN1463.cmd: 1.69176919783518E-5
# Cycle 245
# Total biomass:
# Model iMM904.cmd: 3.6963644854605225E-5
# Model iJN1463.cmd: 1.7019701194614875E-5
# Cycle 246
# Total biomass:
# Model iMM904.cmd: 3.706028985897801E-5
# Model iJN1463.cmd: 1.7122132838460236E-5
# Cycle 247
# Total biomass:
# Model iMM904.cmd: 3.71568417101555E-5
# Model iJN1463.cmd: 1.722529408942371E-5
# Cycle 248
# Total biomass:
# Model iMM904.cmd: 3.725283671676005E-5
# Model iJN1463.cmd: 1.7328942430702377E-5
# Cycle 249
# Total biomass:
# Model iMM904.cmd: 3.734869653089072E-5
# Model iJN1463.cmd: 1.743150141211322E-5
# Cycle 250
# Total biomass:
# Model iMM904.cmd: 3.7444333393862284E-5
# Model iJN1463.cmd: 1.7534464474255466E-5
# Cycle 251
# Total biomass:
# Model iMM904.cmd: 3.7540879819753005E-5
# Model iJN1463.cmd: 1.7637420953357517E-5
# Cycle 252
# Total biomass:
# Model iMM904.cmd: 3.763739206562994E-5
# Model iJN1463.cmd: 1.7740293011600534E-5
# Cycle 253
# Total biomass:
# Model iMM904.cmd: 3.7733581090976416E-5
# Model iJN1463.cmd: 1.78433575474501E-5
# Cycle 254
# Total biomass:
# Model iMM904.cmd: 3.7829643282984396E-5
# Model iJN1463.cmd: 1.7946946469801815E-5
# Cycle 255
# Total biomass:
# Model iMM904.cmd: 3.792519228179249E-5
# Model iJN1463.cmd: 1.8051057870604874E-5
# Cycle 256
# Total biomass:
# Model iMM904.cmd: 3.802031858005248E-5
# Model iJN1463.cmd: 1.815469348277571E-5
# Cycle 257
# Total biomass:
# Model iMM904.cmd: 3.811528631306524E-5
# Model iJN1463.cmd: 1.8257716484067295E-5
# Cycle 258
# Total biomass:
# Model iMM904.cmd: 3.820975004223947E-5
# Model iJN1463.cmd: 1.8360871864614945E-5
# Cycle 259
# Total biomass:
# Model iMM904.cmd: 3.830426131526058E-5
# Model iJN1463.cmd: 1.846438158707786E-5
# Cycle 260
# Total biomass:
# Model iMM904.cmd: 3.8398447102122903E-5
# Model iJN1463.cmd: 1.856845673298548E-5
# Cycle 261
# Total biomass:
# Model iMM904.cmd: 3.849205004788431E-5
# Model iJN1463.cmd: 1.8672845916435427E-5
# Cycle 262
# Total biomass:
# Model iMM904.cmd: 3.858552181636349E-5
# Model iJN1463.cmd: 1.877759701592507E-5
# Cycle 263
# Total biomass:
# Model iMM904.cmd: 3.8678591189127564E-5
# Model iJN1463.cmd: 1.888218902489346E-5
# Cycle 264
# Total biomass:
# Model iMM904.cmd: 3.877120279364234E-5
# Model iJN1463.cmd: 1.8986969640661794E-5
# Cycle 265
# Total biomass:
# Model iMM904.cmd: 3.886305073945422E-5
# Model iJN1463.cmd: 1.909127658007624E-5
# Cycle 266
# Total biomass:
# Model iMM904.cmd: 3.89543033290556E-5
# Model iJN1463.cmd: 1.9195557219971497E-5
# Cycle 267
# Total biomass:
# Model iMM904.cmd: 3.904502648036875E-5
# Model iJN1463.cmd: 1.9299978744716945E-5
# Cycle 268
# Total biomass:
# Model iMM904.cmd: 3.9135411756070514E-5
# Model iJN1463.cmd: 1.9404883904315496E-5
# Cycle 269
# Total biomass:
# Model iMM904.cmd: 3.922571613341697E-5
# Model iJN1463.cmd: 1.951006343909735E-5
# Cycle 270
# Total biomass:
# Model iMM904.cmd: 3.931599516614664E-5
# Model iJN1463.cmd: 1.961571212928348E-5
# Cycle 271
# Total biomass:
# Model iMM904.cmd: 3.940610365607678E-5
# Model iJN1463.cmd: 1.9721871904683933E-5
# Cycle 272
# Total biomass:
# Model iMM904.cmd: 3.9496671165532564E-5
# Model iJN1463.cmd: 1.9828111097196564E-5
# Cycle 273
# Total biomass:
# Model iMM904.cmd: 3.9586963512100715E-5
# Model iJN1463.cmd: 1.9934346907146197E-5
# Cycle 274
# Total biomass:
# Model iMM904.cmd: 3.967770022428087E-5
# Model iJN1463.cmd: 2.0040711572609115E-5
# Cycle 275
# Total biomass:
# Model iMM904.cmd: 3.976637818063705E-5
# Model iJN1463.cmd: 2.014675598742334E-5
# Cycle 276
# Total biomass:
# Model iMM904.cmd: 3.985459246268392E-5
# Model iJN1463.cmd: 2.0253389695141642E-5
# Cycle 277
# Total biomass:
# Model iMM904.cmd: 3.9942654398517876E-5
# Model iJN1463.cmd: 2.036049726251734E-5
# Cycle 278
# Total biomass:
# Model iMM904.cmd: 4.0030569068057747E-5
# Model iJN1463.cmd: 2.0468105799302524E-5
# Cycle 279
# Total biomass:
# Model iMM904.cmd: 4.011798546886296E-5
# Model iJN1463.cmd: 2.0576443830464274E-5
# Cycle 280
# Total biomass:
# Model iMM904.cmd: 4.020502743237373E-5
# Model iJN1463.cmd: 2.068537281585652E-5
# Cycle 281
# Total biomass:
# Model iMM904.cmd: 4.0293493097293976E-5
# Model iJN1463.cmd: 2.079332912862199E-5
# Cycle 282
# Total biomass:
# Model iMM904.cmd: 4.038151502589136E-5
# Model iJN1463.cmd: 2.090078704955254E-5
# Cycle 283
# Total biomass:
# Model iMM904.cmd: 4.046896584689865E-5
# Model iJN1463.cmd: 2.1008193395045678E-5
# Cycle 284
# Total biomass:
# Model iMM904.cmd: 4.055638313971618E-5
# Model iJN1463.cmd: 2.1116395930617674E-5
# Cycle 285
# Total biomass:
# Model iMM904.cmd: 4.064345728194224E-5
# Model iJN1463.cmd: 2.1224102127949532E-5
# Cycle 286
# Total biomass:
# Model iMM904.cmd: 4.073019373876935E-5
# Model iJN1463.cmd: 2.1331883325882633E-5
# Cycle 287
# Total biomass:
# Model iMM904.cmd: 4.081698533091871E-5
# Model iJN1463.cmd: 2.143956066124878E-5
# Cycle 288
# Total biomass:
# Model iMM904.cmd: 4.090330552493431E-5
# Model iJN1463.cmd: 2.1547488476455647E-5
# Cycle 289
# Total biomass:
# Model iMM904.cmd: 4.098864582551044E-5
# Model iJN1463.cmd: 2.1655335452942508E-5
# Cycle 290
# Total biomass:
# Model iMM904.cmd: 4.107347259754043E-5
# Model iJN1463.cmd: 2.176330951990781E-5
# Cycle 291
# Total biomass:
# Model iMM904.cmd: 4.115801612217591E-5
# Model iJN1463.cmd: 2.1871024964490664E-5
# Cycle 292
# Total biomass:
# Model iMM904.cmd: 4.124258214509945E-5
# Model iJN1463.cmd: 2.1979135325049127E-5
# Cycle 293
# Total biomass:
# Model iMM904.cmd: 4.132696223669899E-5
# Model iJN1463.cmd: 2.2087553061712086E-5
# Cycle 294
# Total biomass:
# Model iMM904.cmd: 4.1411774466275453E-5
# Model iJN1463.cmd: 2.2195531614429263E-5
# Cycle 295
# Total biomass:
# Model iMM904.cmd: 4.149770552108795E-5
# Model iJN1463.cmd: 2.2303167688362805E-5
# Cycle 296
# Total biomass:
# Model iMM904.cmd: 4.1582632986296885E-5
# Model iJN1463.cmd: 2.2411274918172472E-5
# Cycle 297
# Total biomass:
# Model iMM904.cmd: 4.166786666124997E-5
# Model iJN1463.cmd: 2.2519755943206072E-5
# Cycle 298
# Total biomass:
# Model iMM904.cmd: 4.175300730046462E-5
# Model iJN1463.cmd: 2.2628327982119834E-5
# Cycle 299
# Total biomass:
# Model iMM904.cmd: 4.183766066225942E-5
# Model iJN1463.cmd: 2.2737567732194298E-5
# Cycle 300
# Total biomass:
# Model iMM904.cmd: 4.192264925305141E-5
# Model iJN1463.cmd: 2.2846487182727253E-5
# Cycle 301
# Total biomass:
# Model iMM904.cmd: 4.2006566591720966E-5
# Model iJN1463.cmd: 2.295571474994605E-5
# Cycle 302
# Total biomass:
# Model iMM904.cmd: 4.2089731866294743E-5
# Model iJN1463.cmd: 2.3066368175689147E-5
# Cycle 303
# Total biomass:
# Model iMM904.cmd: 4.2172050923662485E-5
# Model iJN1463.cmd: 2.317741398664183E-5
# Cycle 304
# Total biomass:
# Model iMM904.cmd: 4.2255226682731384E-5
# Model iJN1463.cmd: 2.3287581193350986E-5
# Cycle 305
# Total biomass:
# Model iMM904.cmd: 4.2338619411986255E-5
# Model iJN1463.cmd: 2.3397453858806904E-5
# Cycle 306
# Total biomass:
# Model iMM904.cmd: 4.242158281553975E-5
# Model iJN1463.cmd: 2.3507313546897905E-5
# Cycle 307
# Total biomass:
# Model iMM904.cmd: 4.2503428394146514E-5
# Model iJN1463.cmd: 2.3616871437966098E-5
# Cycle 308
# Total biomass:
# Model iMM904.cmd: 4.2585313250095317E-5
# Model iJN1463.cmd: 2.3726406429789678E-5
# Cycle 309
# Total biomass:
# Model iMM904.cmd: 4.266714618498941E-5
# Model iJN1463.cmd: 2.3835928670783907E-5
# Cycle 310
# Total biomass:
# Model iMM904.cmd: 4.2748615864998496E-5
# Model iJN1463.cmd: 2.3945565400145138E-5
# Cycle 311
# Total biomass:
# Model iMM904.cmd: 4.2830024325438E-5
# Model iJN1463.cmd: 2.405535988366018E-5
# Cycle 312
# Total biomass:
# Model iMM904.cmd: 4.291126977609524E-5
# Model iJN1463.cmd: 2.4165419049430975E-5
# Cycle 313
# Total biomass:
# Model iMM904.cmd: 4.299250066235129E-5
# Model iJN1463.cmd: 2.4276132433341135E-5
# Cycle 314
# Total biomass:
# Model iMM904.cmd: 4.3073366996743324E-5
# Model iJN1463.cmd: 2.4386855314698512E-5
# Cycle 315
# Total biomass:
# Model iMM904.cmd: 4.315391919925683E-5
# Model iJN1463.cmd: 2.4498112526017223E-5
# Cycle 316
# Total biomass:
# Model iMM904.cmd: 4.32346037967922E-5
# Model iJN1463.cmd: 2.4608599453938554E-5
# Cycle 317
# Total biomass:
# Model iMM904.cmd: 4.331436895885638E-5
# Model iJN1463.cmd: 2.4718944781495296E-5
# Cycle 318
# Total biomass:
# Model iMM904.cmd: 4.339432668209572E-5
# Model iJN1463.cmd: 2.4829041835113226E-5
# Cycle 319
# Total biomass:
# Model iMM904.cmd: 4.34747406034407E-5
# Model iJN1463.cmd: 2.4938611421179983E-5
# Cycle 320
# Total biomass:
# Model iMM904.cmd: 4.3554385253673496E-5
# Model iJN1463.cmd: 2.5048310008627684E-5
# Cycle 321
# Total biomass:
# Model iMM904.cmd: 4.363394955216031E-5
# Model iJN1463.cmd: 2.5158393188635773E-5
# Cycle 322
# Total biomass:
# Model iMM904.cmd: 4.3714355837994706E-5
# Model iJN1463.cmd: 2.526844595632376E-5
# Cycle 323
# Total biomass:
# Model iMM904.cmd: 4.3794481416803816E-5
# Model iJN1463.cmd: 2.5378877356746387E-5
# Cycle 324
# Total biomass:
# Model iMM904.cmd: 4.387503259245968E-5
# Model iJN1463.cmd: 2.549036995481956E-5
# Cycle 325
# Total biomass:
# Model iMM904.cmd: 4.395537471250774E-5
# Model iJN1463.cmd: 2.5601251637497248E-5
# Cycle 326
# Total biomass:
# Model iMM904.cmd: 4.403495546155186E-5
# Model iJN1463.cmd: 2.571271858353707E-5
# Cycle 327
# Total biomass:
# Model iMM904.cmd: 4.4114343218015516E-5
# Model iJN1463.cmd: 2.5824233118472265E-5
# Cycle 328
# Total biomass:
# Model iMM904.cmd: 4.4193926155706084E-5
# Model iJN1463.cmd: 2.5935971510172766E-5
# Cycle 329
# Total biomass:
# Model iMM904.cmd: 4.4272562624856805E-5
# Model iJN1463.cmd: 2.6048320779990734E-5
# Cycle 330
# Total biomass:
# Model iMM904.cmd: 4.4350747545685625E-5
# Model iJN1463.cmd: 2.616094232272614E-5
# Cycle 331
# Total biomass:
# Model iMM904.cmd: 4.442868338323801E-5
# Model iJN1463.cmd: 2.6272234360974592E-5
# Cycle 332
# Total biomass:
# Model iMM904.cmd: 4.450629305195599E-5
# Model iJN1463.cmd: 2.6382632546888996E-5
# Cycle 333
# Total biomass:
# Model iMM904.cmd: 4.458368032352064E-5
# Model iJN1463.cmd: 2.6493289308503015E-5
# Cycle 334
# Total biomass:
# Model iMM904.cmd: 4.4660222028808766E-5
# Model iJN1463.cmd: 2.660625706835585E-5
# Cycle 335
# Total biomass:
# Model iMM904.cmd: 4.4738175278251803E-5
# Model iJN1463.cmd: 2.6716574872294207E-5
# Cycle 336
# Total biomass:
# Model iMM904.cmd: 4.481566470622568E-5
# Model iJN1463.cmd: 2.682631986714321E-5
# Cycle 337
# Total biomass:
# Model iMM904.cmd: 4.489300075825017E-5
# Model iJN1463.cmd: 2.6936732546855374E-5
# Cycle 338
# Total biomass:
# Model iMM904.cmd: 4.4969170785247106E-5
# Model iJN1463.cmd: 2.704810031868769E-5
# Cycle 339
# Total biomass:
# Model iMM904.cmd: 4.504555862960012E-5
# Model iJN1463.cmd: 2.715893869313251E-5
# Cycle 340
# Total biomass:
# Model iMM904.cmd: 4.5121570586448685E-5
# Model iJN1463.cmd: 2.72704496676615E-5
# Cycle 341
# Total biomass:
# Model iMM904.cmd: 4.5197581924092986E-5
# Model iJN1463.cmd: 2.7381749667898794E-5
# Cycle 342
# Total biomass:
# Model iMM904.cmd: 4.527274661059824E-5
# Model iJN1463.cmd: 2.7493367474135582E-5
# Cycle 343
# Total biomass:
# Model iMM904.cmd: 4.534781012119285E-5
# Model iJN1463.cmd: 2.7605666245299524E-5
# Cycle 344
# Total biomass:
# Model iMM904.cmd: 4.542360220411672E-5
# Model iJN1463.cmd: 2.7717443956634722E-5
# Cycle 345
# Total biomass:
# Model iMM904.cmd: 4.5499095877225714E-5
# Model iJN1463.cmd: 2.782901074360922E-5
# Cycle 346
# Total biomass:
# Model iMM904.cmd: 4.557568491119222E-5
# Model iJN1463.cmd: 2.7941229768218634E-5
# Cycle 347
# Total biomass:
# Model iMM904.cmd: 4.56517542679493E-5
# Model iJN1463.cmd: 2.8054099642339755E-5
# Cycle 348
# Total biomass:
# Model iMM904.cmd: 4.57277184512341E-5
# Model iJN1463.cmd: 2.81671428830201E-5
# Cycle 349
# Total biomass:
# Model iMM904.cmd: 4.5803615862086936E-5
# Model iJN1463.cmd: 2.828032430197294E-5
# Cycle 350
# Total biomass:
# Model iMM904.cmd: 4.587879725253455E-5
# Model iJN1463.cmd: 2.839393649880366E-5
# Cycle 351
# Total biomass:
# Model iMM904.cmd: 4.595372960578588E-5
# Model iJN1463.cmd: 2.850776040722389E-5
# Cycle 352
# Total biomass:
# Model iMM904.cmd: 4.60281192558906E-5
# Model iJN1463.cmd: 2.8620560039063742E-5
# Cycle 353
# Total biomass:
# Model iMM904.cmd: 4.610203975835519E-5
# Model iJN1463.cmd: 2.8733336850493433E-5
# Cycle 354
# Total biomass:
# Model iMM904.cmd: 4.617624228516082E-5
# Model iJN1463.cmd: 2.8845400182595313E-5
# Cycle 355
# Total biomass:
# Model iMM904.cmd: 4.6249508317489274E-5
# Model iJN1463.cmd: 2.8958134074006657E-5
# Cycle 356
# Total biomass:
# Model iMM904.cmd: 4.632232499192418E-5
# Model iJN1463.cmd: 2.907098121682297E-5
# Cycle 357
# Total biomass:
# Model iMM904.cmd: 4.639572955526705E-5
# Model iJN1463.cmd: 2.9182615974806605E-5
# Cycle 358
# Total biomass:
# Model iMM904.cmd: 4.646903175875682E-5
# Model iJN1463.cmd: 2.929414663119131E-5
# Cycle 359
# Total biomass:
# Model iMM904.cmd: 4.654108017176502E-5
# Model iJN1463.cmd: 2.9406537178559148E-5
# Cycle 360
# Total biomass:
# Model iMM904.cmd: 4.661199120018018E-5
# Model iJN1463.cmd: 2.9517950250597883E-5
# Cycle 361
# Total biomass:
# Model iMM904.cmd: 4.668362795729281E-5
# Model iJN1463.cmd: 2.9630921394296424E-5
# Cycle 362
# Total biomass:
# Model iMM904.cmd: 4.675453824569515E-5
# Model iJN1463.cmd: 2.9745556595132042E-5
# Cycle 363
# Total biomass:
# Model iMM904.cmd: 4.6825848768509916E-5
# Model iJN1463.cmd: 2.9859814831951973E-5
# Cycle 364
# Total biomass:
# Model iMM904.cmd: 4.689661166958754E-5
# Model iJN1463.cmd: 2.9973459572461662E-5
# Cycle 365
# Total biomass:
# Model iMM904.cmd: 4.696834633609798E-5
# Model iJN1463.cmd: 3.008665113735554E-5
# Cycle 366
# Total biomass:
# Model iMM904.cmd: 4.703996277542942E-5
# Model iJN1463.cmd: 3.0200131206012586E-5
# Cycle 367
# Total biomass:
# Model iMM904.cmd: 4.710946035370938E-5
# Model iJN1463.cmd: 3.0318271681356577E-5
# Cycle 368
# Total biomass:
# Model iMM904.cmd: 4.7179398949165E-5
# Model iJN1463.cmd: 3.0435083339078456E-5
# Cycle 369
# Total biomass:
# Model iMM904.cmd: 4.724764544848004E-5
# Model iJN1463.cmd: 3.055422683577231E-5
# Cycle 370
# Total biomass:
# Model iMM904.cmd: 4.731577349303833E-5
# Model iJN1463.cmd: 3.067181728045486E-5
# Cycle 371
# Total biomass:
# Model iMM904.cmd: 4.738470248752731E-5
# Model iJN1463.cmd: 3.078762242017176E-5
# Cycle 372
# Total biomass:
# Model iMM904.cmd: 4.7453749978995005E-5
# Model iJN1463.cmd: 3.090321621881001E-5
# Cycle 373
# Total biomass:
# Model iMM904.cmd: 4.752353435310571E-5
# Model iJN1463.cmd: 3.101777403532122E-5
# Cycle 374
# Total biomass:
# Model iMM904.cmd: 4.759240937081948E-5
# Model iJN1463.cmd: 3.113311665030919E-5
# Cycle 375
# Total biomass:
# Model iMM904.cmd: 4.766114819146986E-5
# Model iJN1463.cmd: 3.1248379704109676E-5
# Cycle 376
# Total biomass:
# Model iMM904.cmd: 4.773175735502734E-5
# Model iJN1463.cmd: 3.13624092381721E-5
# Cycle 377
# Total biomass:
# Model iMM904.cmd: 4.7802331537772144E-5
# Model iJN1463.cmd: 3.147618275697049E-5
# Cycle 378
# Total biomass:
# Model iMM904.cmd: 4.787375978641149E-5
# Model iJN1463.cmd: 3.158820990588335E-5
# Cycle 379
# Total biomass:
# Model iMM904.cmd: 4.794184813469628E-5
# Model iJN1463.cmd: 3.170292159990494E-5
# Cycle 380
# Total biomass:
# Model iMM904.cmd: 4.800908691222565E-5
# Model iJN1463.cmd: 3.181857361421835E-5
# Cycle 381
# Total biomass:
# Model iMM904.cmd: 4.8077529380751455E-5
# Model iJN1463.cmd: 3.193285704034268E-5
# Cycle 382
# Total biomass:
# Model iMM904.cmd: 4.814531127104595E-5
# Model iJN1463.cmd: 3.20476687191281E-5
# Cycle 383
# Total biomass:
# Model iMM904.cmd: 4.8213897374296705E-5
# Model iJN1463.cmd: 3.2161568243753165E-5
# Cycle 384
# Total biomass:
# Model iMM904.cmd: 4.8283170618911155E-5
# Model iJN1463.cmd: 3.2276290705263695E-5
# Cycle 385
# Total biomass:
# Model iMM904.cmd: 4.8351466326694075E-5
# Model iJN1463.cmd: 3.2391903249200304E-5
# Cycle 386
# Total biomass:
# Model iMM904.cmd: 4.8419363204139384E-5
# Model iJN1463.cmd: 3.250810688607709E-5
# Cycle 387
# Total biomass:
# Model iMM904.cmd: 4.8488917532611684E-5
# Model iJN1463.cmd: 3.262187787467302E-5
# Cycle 388
# Total biomass:
# Model iMM904.cmd: 4.85584842116155E-5
# Model iJN1463.cmd: 3.2736244711310765E-5
# Cycle 389
# Total biomass:
# Model iMM904.cmd: 4.862728857655622E-5
# Model iJN1463.cmd: 3.284953160254393E-5
# Cycle 390
# Total biomass:
# Model iMM904.cmd: 4.869349446037114E-5
# Model iJN1463.cmd: 3.2961118420143366E-5
# Cycle 391
# Total biomass:
# Model iMM904.cmd: 4.875675191267583E-5
# Model iJN1463.cmd: 3.3072429387109864E-5
# Cycle 392
# Total biomass:
# Model iMM904.cmd: 4.8819464705869205E-5
# Model iJN1463.cmd: 3.318333905503073E-5
# Cycle 393
# Total biomass:
# Model iMM904.cmd: 4.888548924107005E-5
# Model iJN1463.cmd: 3.329599497686027E-5
# Cycle 394
# Total biomass:
# Model iMM904.cmd: 4.895146816608009E-5
# Model iJN1463.cmd: 3.340996481793222E-5
# Cycle 395
# Total biomass:
# Model iMM904.cmd: 4.90173659060391E-5
# Model iJN1463.cmd: 3.352442063977342E-5
# Cycle 396
# Total biomass:
# Model iMM904.cmd: 4.90869397807742E-5
# Model iJN1463.cmd: 3.364026222996882E-5
# Cycle 397
# Total biomass:
# Model iMM904.cmd: 4.9155963770258335E-5
# Model iJN1463.cmd: 3.3752856125597544E-5
# Cycle 398
# Total biomass:
# Model iMM904.cmd: 4.92215974592851E-5
# Model iJN1463.cmd: 3.3868677922414096E-5
# Cycle 399
# Total biomass:
# Model iMM904.cmd: 4.9288415891223905E-5
# Model iJN1463.cmd: 3.398185930783222E-5
# Cycle 400
# Total biomass:
# Model iMM904.cmd: 4.9354296305523366E-5
# Model iJN1463.cmd: 3.409549465304211E-5
# Cycle 401
# Total biomass:
# ...
# Model iJN1463.cmd: 7.337603081593761E-5
# Cycle 848
# Total biomass:
# Model iMM904.cmd: 7.049845546380308E-5
# Model iJN1463.cmd: 7.343656572087677E-5
# Cycle 849
# Total biomass:
# Model iMM904.cmd: 7.052901861094649E-5
# Model iJN1463.cmd: 7.349404774425676E-5
# Cycle 850
# Total biomass:
# Model iMM904.cmd: 7.055717506349148E-5
# Model iJN1463.cmd: 7.355402293719562E-5
# Cycle 851
# Total biomass:
# Model iMM904.cmd: 7.058788783360663E-5
# Model iJN1463.cmd: 7.361038928320846E-5
# Cycle 852
# Total biomass:
# Model iMM904.cmd: 7.061693071030268E-5
# Model iJN1463.cmd: 7.366841813629959E-5
# Cycle 853
# Total biomass:
# Model iMM904.cmd: 7.064462929684664E-5
# Model iJN1463.cmd: 7.372844878152283E-5
# Cycle 854
# Total biomass:
# Model iMM904.cmd: 7.067434124940819E-5
# Model iJN1463.cmd: 7.378546268145806E-5
# Cycle 855
# Total biomass:
# Model iMM904.cmd: 7.070604747527848E-5
# Model iJN1463.cmd: 7.38395791416688E-5
# Cycle 856
# Total biomass:
# Model iMM904.cmd: 7.073445848135704E-5
# Model iJN1463.cmd: 7.389866753265635E-5
# Cycle 857
# Total biomass:
# Model iMM904.cmd: 7.076414328309368E-5
# Model iJN1463.cmd: 7.395519788860216E-5
# Cycle 858
# Total biomass:
# Model iMM904.cmd: 7.079478436356958E-5
# Model iJN1463.cmd: 7.401006243303887E-5
# Cycle 859
# Total biomass:
# Model iMM904.cmd: 7.082875372369455E-5
# Model iJN1463.cmd: 7.406071954254772E-5
# Cycle 860
# Total biomass:
# Model iMM904.cmd: 7.085759284079588E-5
# Model iJN1463.cmd: 7.411859389727156E-5
# Cycle 861
# Total biomass:
# Model iMM904.cmd: 7.088709638201187E-5
# Model iJN1463.cmd: 7.41744392791899E-5
# Cycle 862
# Total biomass:
# Model iMM904.cmd: 7.091692962881636E-5
# Model iJN1463.cmd: 7.422959874592797E-5
# Cycle 863
# Total biomass:
# Model iMM904.cmd: 7.095045565568701E-5
# Model iJN1463.cmd: 7.427953420919996E-5
# Cycle 864
# Total biomass:
# Model iMM904.cmd: 7.097897800253884E-5
# Model iJN1463.cmd: 7.433692720894064E-5
# Cycle 865
# Total biomass:
# Model iMM904.cmd: 7.100660569012246E-5
# Model iJN1463.cmd: 7.439487898108755E-5
# Cycle 866
# Total biomass:
# Model iMM904.cmd: 7.103411685910814E-5
# Model iJN1463.cmd: 7.445487560656389E-5
# Cycle 867
# Total biomass:
# Model iMM904.cmd: 7.106389577644143E-5
# Model iJN1463.cmd: 7.451140255492527E-5
# Cycle 868
# Total biomass:
# Model iMM904.cmd: 7.109218518721448E-5
# Model iJN1463.cmd: 7.456893965409182E-5
# Cycle 869
# Total biomass:
# Model iMM904.cmd: 7.112150070716414E-5
# Model iJN1463.cmd: 7.462470150994697E-5
# Cycle 870
# Total biomass:
# Model iMM904.cmd: 7.114782518375527E-5
# Model iJN1463.cmd: 7.468256096576257E-5
# Cycle 871
# Total biomass:
# Model iMM904.cmd: 7.117686864177977E-5
# Model iJN1463.cmd: 7.473816979230377E-5
# Cycle 872
# Total biomass:
# Model iMM904.cmd: 7.120610328172612E-5
# Model iJN1463.cmd: 7.4791901044827E-5
# Cycle 873
# Total biomass:
# Model iMM904.cmd: 7.123740652299987E-5
# Model iJN1463.cmd: 7.484555531036789E-5
# Cycle 874
# Total biomass:
# Model iMM904.cmd: 7.12659489227616E-5
# Model iJN1463.cmd: 7.490025898070139E-5
# Cycle 875
# Total biomass:
# Model iMM904.cmd: 7.129488205177328E-5
# Model iJN1463.cmd: 7.495393843196274E-5
# Cycle 876
# Total biomass:
# Model iMM904.cmd: 7.132729803892635E-5
# Model iJN1463.cmd: 7.500325876743596E-5
# Cycle 877
# Total biomass:
# Model iMM904.cmd: 7.135479047111601E-5
# Model iJN1463.cmd: 7.505974099114117E-5
# Cycle 878
# Total biomass:
# Model iMM904.cmd: 7.138098711972748E-5
# Model iJN1463.cmd: 7.511629141914744E-5
# Cycle 879
# Total biomass:
# Model iMM904.cmd: 7.140940741558328E-5
# Model iJN1463.cmd: 7.516977206876437E-5
# Cycle 880
# Total biomass:
# Model iMM904.cmd: 7.143558669424634E-5
# Model iJN1463.cmd: 7.522694179930963E-5
# Cycle 881
# Total biomass:
# Model iMM904.cmd: 7.146315419969121E-5
# Model iJN1463.cmd: 7.528103719141297E-5
# Cycle 882
# Total biomass:
# Model iMM904.cmd: 7.149200757837377E-5
# Model iJN1463.cmd: 7.533273584669104E-5
# Cycle 883
# Total biomass:
# Model iMM904.cmd: 7.15180543961963E-5
# Model iJN1463.cmd: 7.538910351123961E-5
# Cycle 884
# Total biomass:
# Model iMM904.cmd: 7.154531524628778E-5
# Model iJN1463.cmd: 7.544274076177629E-5
# Cycle 885
# Total biomass:
# Model iMM904.cmd: 7.157452243786794E-5
# Model iJN1463.cmd: 7.549396681171169E-5
# Cycle 886
# Total biomass:
# Model iMM904.cmd: 7.160091271006377E-5
# Model iJN1463.cmd: 7.554894298808543E-5
# Cycle 887
# Total biomass:
# Model iMM904.cmd: 7.162993716786022E-5
# Model iJN1463.cmd: 7.559982725317989E-5
# Cycle 888
# Total biomass:
# Model iMM904.cmd: 7.165878866212848E-5
# Model iJN1463.cmd: 7.565285478318587E-5
# Cycle 889
# Total biomass:
# Model iMM904.cmd: 7.168415496447315E-5
# Model iJN1463.cmd: 7.570852431595609E-5
# Cycle 890
# Total biomass:
# Model iMM904.cmd: 7.171476601858816E-5
# Model iJN1463.cmd: 7.575885590345598E-5
# Cycle 891
# Total biomass:
# Model iMM904.cmd: 7.174206758119574E-5
# Model iJN1463.cmd: 7.581233714880238E-5
# Cycle 892
# Total biomass:
# Model iMM904.cmd: 7.177189719308346E-5
# Model iJN1463.cmd: 7.586229399368604E-5
# Cycle 893
# Total biomass:
# Model iMM904.cmd: 7.17972575449076E-5
# Model iJN1463.cmd: 7.59169607624133E-5
# Cycle 894
# Total biomass:
# Model iMM904.cmd: 7.182533925403296E-5
# Model iJN1463.cmd: 7.59685320634885E-5
# Cycle 895
# Total biomass:
# Model iMM904.cmd: 7.18517127268004E-5
# Model iJN1463.cmd: 7.602141863029777E-5
# Cycle 896
# Total biomass:
# Model iMM904.cmd: 7.188284371354766E-5
# Model iJN1463.cmd: 7.606775402348056E-5
# Cycle 897
# Total biomass:
# Model iMM904.cmd: 7.19087849579028E-5
# Model iJN1463.cmd: 7.612183489632716E-5
# Cycle 898
# Total biomass:
# Model iMM904.cmd: 7.193738003075097E-5
# Model iJN1463.cmd: 7.617204030324406E-5
# Cycle 899
# Total biomass:
# Model iMM904.cmd: 7.196586489545169E-5
# Model iJN1463.cmd: 7.622132465059975E-5
# Cycle 900
# Total biomass:
# Model iMM904.cmd: 7.199686223083689E-5
# Model iJN1463.cmd: 7.626740259940677E-5
# Cycle 901
# Total biomass:
# Model iMM904.cmd: 7.202245484350177E-5
# Model iJN1463.cmd: 7.632100762728856E-5
# Cycle 902
# Total biomass:
# Model iMM904.cmd: 7.204860017021748E-5
# Model iJN1463.cmd: 7.637267057227958E-5
# Cycle 903
# Total biomass:
# Model iMM904.cmd: 7.207562430958668E-5
# Model iJN1463.cmd: 7.642283629107424E-5
# Cycle 904
# Total biomass:
# Model iMM904.cmd: 7.210610847511984E-5
# Model iJN1463.cmd: 7.646852190120372E-5
# Cycle 905
# Total biomass:
# Model iMM904.cmd: 7.213133252561268E-5
# Model iJN1463.cmd: 7.652159755462807E-5
# Cycle 906
# Total biomass:
# Model iMM904.cmd: 7.21571542500339E-5
# Model iJN1463.cmd: 7.65729789302637E-5
# Cycle 907
# Total biomass:
# Model iMM904.cmd: 7.218388250576581E-5
# Model iJN1463.cmd: 7.662279822109526E-5
# Cycle 908
# Total biomass:
# Model iMM904.cmd: 7.22132088766994E-5
# Model iJN1463.cmd: 7.666962365608192E-5
# Cycle 909
# Total biomass:
# Model iMM904.cmd: 7.223770623710389E-5
# Model iJN1463.cmd: 7.672247768296691E-5
# Cycle 910
# Total biomass:
# Model iMM904.cmd: 7.226135295800231E-5
# Model iJN1463.cmd: 7.677607757802416E-5
# Cycle 911
# Total biomass:
# Model iMM904.cmd: 7.228420543208717E-5
# Model iJN1463.cmd: 7.682992304344569E-5
# Cycle 912
# Total biomass:
# Model iMM904.cmd: 7.231069697571123E-5
# Model iJN1463.cmd: 7.688112444954363E-5
# Cycle 913
# Total biomass:
# Model iMM904.cmd: 7.233784277119678E-5
# Model iJN1463.cmd: 7.69296921178061E-5
# Cycle 914
# Total biomass:
# Model iMM904.cmd: 7.236153152410654E-5
# Model iJN1463.cmd: 7.698285386705604E-5
# Cycle 915
# Total biomass:
# Model iMM904.cmd: 7.238704115373253E-5
# Model iJN1463.cmd: 7.703289223033255E-5
# Cycle 916
# Total biomass:
# Model iMM904.cmd: 7.241659456418159E-5
# Model iJN1463.cmd: 7.707748188000543E-5
# Cycle 917
# Total biomass:
# Model iMM904.cmd: 7.244089282306113E-5
# Model iJN1463.cmd: 7.712947728692645E-5
# Cycle 918
# Total biomass:
# Model iMM904.cmd: 7.246573736094485E-5
# Model iJN1463.cmd: 7.717966405658178E-5
# Cycle 919
# Total biomass:
# Model iMM904.cmd: 7.249185520193518E-5
# Model iJN1463.cmd: 7.722807268252269E-5
# Cycle 920
# Total biomass:
# Model iMM904.cmd: 7.251706249928427E-5
# Model iJN1463.cmd: 7.727820580081168E-5
# Cycle 921
# Total biomass:
# Model iMM904.cmd: 7.253848847127743E-5
# Model iJN1463.cmd: 7.73320694633276E-5
# Cycle 922
# Total biomass:
# Model iMM904.cmd: 7.256149290855575E-5
# Model iJN1463.cmd: 7.738451542028188E-5
# Cycle 923
# Total biomass:
# Model iMM904.cmd: 7.258461878225483E-5
# Model iJN1463.cmd: 7.743581428283787E-5
# Cycle 924
# Total biomass:
# Model iMM904.cmd: 7.26074357154758E-5
# Model iJN1463.cmd: 7.748837119753502E-5
# Cycle 925
# Total biomass:
# Model iMM904.cmd: 7.262971917515556E-5
# Model iJN1463.cmd: 7.754026081446819E-5
# Cycle 926
# Total biomass:
# Model iMM904.cmd: 7.265129439266588E-5
# Model iJN1463.cmd: 7.759298856838764E-5
# Cycle 927
# Total biomass:
# Model iMM904.cmd: 7.267505704961749E-5
# Model iJN1463.cmd: 7.764277960971304E-5
# Cycle 928
# Total biomass:
# Model iMM904.cmd: 7.270371620071185E-5
# Model iJN1463.cmd: 7.76863793604686E-5
# Cycle 929
# Total biomass:
# Model iMM904.cmd: 7.272692404112943E-5
# Model iJN1463.cmd: 7.773689503935204E-5
# Cycle 930
# Total biomass:
# Model iMM904.cmd: 7.274839585767694E-5
# Model iJN1463.cmd: 7.77887130362664E-5
# Cycle 931
# Total biomass:
# Model iMM904.cmd: 7.276931667009856E-5
# Model iJN1463.cmd: 7.784093539414539E-5
# Cycle 932
# Total biomass:
# Model iMM904.cmd: 7.279002338484706E-5
# Model iJN1463.cmd: 7.789317089362532E-5
# Cycle 933
# Total biomass:
# Model iMM904.cmd: 7.281418589180328E-5
# Model iJN1463.cmd: 7.794161268655801E-5
# Cycle 934
# Total biomass:
# Model iMM904.cmd: 7.283939528091729E-5
# Model iJN1463.cmd: 7.798870151219715E-5
# Cycle 935
# Total biomass:
# Model iMM904.cmd: 7.286520601677877E-5
# Model iJN1463.cmd: 7.80358430457854E-5
# Cycle 936
# Total biomass:
# Model iMM904.cmd: 7.289199886644205E-5
# Model iJN1463.cmd: 7.808202493251039E-5
# Cycle 937
# Total biomass:
# Model iMM904.cmd: 7.29155989992332E-5
# Model iJN1463.cmd: 7.813051537563633E-5
# Cycle 938
# Total biomass:
# Model iMM904.cmd: 7.293668696032721E-5
# Model iJN1463.cmd: 7.818141129958925E-5
# Cycle 939
# Total biomass:
# Model iMM904.cmd: 7.295909764737721E-5
# Model iJN1463.cmd: 7.823104514128159E-5
# Cycle 940
# Total biomass:
# Model iMM904.cmd: 7.297977951663003E-5
# Model iJN1463.cmd: 7.828235278880618E-5
# Cycle 941
# Total biomass:
# Model iMM904.cmd: 7.299997867850178E-5
# Model iJN1463.cmd: 7.833383828576643E-5
# Cycle 942
# Total biomass:
# Model iMM904.cmd: 7.302001713377452E-5
# Model iJN1463.cmd: 7.838545423235711E-5
# Cycle 943
# Total biomass:
# Model iMM904.cmd: 7.303991133881862E-5
# Model iJN1463.cmd: 7.843684639974922E-5
# Cycle 944
# Total biomass:
# Model iMM904.cmd: 7.305967967316864E-5
# Model iJN1463.cmd: 7.848801043869617E-5
# Cycle 945
# Total biomass:
# Model iMM904.cmd: 7.307933593683707E-5
# Model iJN1463.cmd: 7.853899515487967E-5
# Cycle 946
# Total biomass:
# Model iMM904.cmd: 7.309889177493631E-5
# Model iJN1463.cmd: 7.858984470226278E-5
# Cycle 947
# Total biomass:
# Model iMM904.cmd: 7.311836609925651E-5
# Model iJN1463.cmd: 7.86405830727627E-5
# Cycle 948
# Total biomass:
# Model iMM904.cmd: 7.314009751123206E-5
# Model iJN1463.cmd: 7.86885088967749E-5
# Cycle 949
# Total biomass:
# Model iMM904.cmd: 7.316340102356431E-5
# Model iJN1463.cmd: 7.873485050457651E-5
# Cycle 950
# Total biomass:
# Model iMM904.cmd: 7.318578446731737E-5
# Model iJN1463.cmd: 7.878087570638904E-5
# Cycle 951
# Total biomass:
# Model iMM904.cmd: 7.32091489907717E-5
# Model iJN1463.cmd: 7.882705200604614E-5
# Cycle 952
# Total biomass:
# Model iMM904.cmd: 7.32313944760969E-5
# Model iJN1463.cmd: 7.887547501686423E-5
# Cycle 953
# Total biomass:
# Model iMM904.cmd: 7.325226418519515E-5
# Model iJN1463.cmd: 7.892573971897876E-5
# Cycle 954
# Total biomass:
# Model iMM904.cmd: 7.327270908310205E-5
# Model iJN1463.cmd: 7.897652641241157E-5
# Cycle 955
# Total biomass:
# Model iMM904.cmd: 7.329510840247903E-5
# Model iJN1463.cmd: 7.902381002672363E-5
# Cycle 956
# Total biomass:
# Model iMM904.cmd: 7.331509619145694E-5
# Model iJN1463.cmd: 7.907352814594871E-5
# Cycle 957
# Total biomass:
# Model iMM904.cmd: 7.333418382107758E-5
# Model iJN1463.cmd: 7.912352701725657E-5
# Cycle 958
# Total biomass:
# Model iMM904.cmd: 7.335406741968326E-5
# Model iJN1463.cmd: 7.917410181872805E-5
# Cycle 959
# Total biomass:
# Model iMM904.cmd: 7.337606846407867E-5
# Model iJN1463.cmd: 7.922077874843763E-5
# Cycle 960
# Total biomass:
# Model iMM904.cmd: 7.339782529943004E-5
# Model iJN1463.cmd: 7.926796698466001E-5
# Cycle 961
# Total biomass:
# Model iMM904.cmd: 7.342072979088887E-5
# Model iJN1463.cmd: 7.931432587278493E-5
# Cycle 962
# Total biomass:
# Model iMM904.cmd: 7.34414961402586E-5
# Model iJN1463.cmd: 7.936321340088302E-5
# Cycle 963
# Total biomass:
# Model iMM904.cmd: 7.34615496293833E-5
# Model iJN1463.cmd: 7.941296357358317E-5
# Cycle 964
# Total biomass:
# Model iMM904.cmd: 7.348260471527045E-5
# Model iJN1463.cmd: 7.946104280209396E-5
# Cycle 965
# Total biomass:
# Model iMM904.cmd: 7.350496111721494E-5
# Model iJN1463.cmd: 7.950741847312776E-5
# Cycle 966
# Total biomass:
# Model iMM904.cmd: 7.35276742845377E-5
# Model iJN1463.cmd: 7.955262140553605E-5
# Cycle 967
# Total biomass:
# Model iMM904.cmd: 7.355380302638214E-5
# Model iJN1463.cmd: 7.959330531534825E-5
# Cycle 968
# Total biomass:
# Model iMM904.cmd: 7.358069879065828E-5
# Model iJN1463.cmd: 7.9632285382696E-5
# Cycle 969
# Total biomass:
# Model iMM904.cmd: 7.360084609046646E-5
# Model iJN1463.cmd: 7.96786036679885E-5
# Cycle 970
# Total biomass:
# Model iMM904.cmd: 7.362756945759232E-5
# Model iJN1463.cmd: 7.971790653072842E-5
# Cycle 971
# Total biomass:
# Model iMM904.cmd: 7.365319846301598E-5
# Model iJN1463.cmd: 7.97583920191209E-5
# Cycle 972
# Total biomass:
# Model iMM904.cmd: 7.36789473780485E-5
# Model iJN1463.cmd: 7.979770457407983E-5
# Cycle 973
# Total biomass:
# Model iMM904.cmd: 7.370468968356472E-5
# Model iJN1463.cmd: 7.983678697078751E-5
# Cycle 974
# Total biomass:
# Model iMM904.cmd: 7.372978268325931E-5
# Model iJN1463.cmd: 7.987637812038234E-5
# Cycle 975
# Total biomass:
# Model iMM904.cmd: 7.375470834941641E-5
# Model iJN1463.cmd: 7.991595266871087E-5
# Cycle 976
# Total biomass:
# Model iMM904.cmd: 7.378005139782125E-5
# Model iJN1463.cmd: 7.995474490262903E-5
# Cycle 977
# Total biomass:
# Model iMM904.cmd: 7.380444677355584E-5
# Model iJN1463.cmd: 7.999431859290918E-5
# Cycle 978
# Total biomass:
# Model iMM904.cmd: 7.38270438092831E-5
# Model iJN1463.cmd: 8.003599073722761E-5
# Cycle 979
# Total biomass:
# Model iMM904.cmd: 7.385268044169759E-5
# Model iJN1463.cmd: 8.007489486866534E-5
# Cycle 980
# Total biomass:
# Model iMM904.cmd: 7.387752589086152E-5
# Model iJN1463.cmd: 8.01137385977254E-5
# Cycle 981
# Total biomass:
# Model iMM904.cmd: 7.390212046018386E-5
# Model iJN1463.cmd: 8.015265050290236E-5
# Cycle 982
# Total biomass:
# Model iMM904.cmd: 7.392657688524295E-5
# Model iJN1463.cmd: 8.019154084440961E-5
# Cycle 983
# Total biomass:
# Model iMM904.cmd: 7.39515670747127E-5
# Model iJN1463.cmd: 8.023070392442725E-5
# Cycle 984
# Total biomass:
# Model iMM904.cmd: 7.397575198094719E-5
# Model iJN1463.cmd: 8.026948003342023E-5
# Cycle 985
# Total biomass:
# Model iMM904.cmd: 7.400062864817288E-5
# Model iJN1463.cmd: 8.030871885733237E-5
# Cycle 986
# Total biomass:
# Model iMM904.cmd: 7.402418054220072E-5
# Model iJN1463.cmd: 8.03479404520737E-5
# Cycle 987
# Total biomass:
# Model iMM904.cmd: 7.404813401919744E-5
# Model iJN1463.cmd: 8.038758019489789E-5
# Cycle 988
# Total biomass:
# Model iMM904.cmd: 7.40710945273904E-5
# Model iJN1463.cmd: 8.042732490975652E-5
# Cycle 989
# Total biomass:
# Model iMM904.cmd: 7.409341844618563E-5
# Model iJN1463.cmd: 8.046750099054702E-5
# Cycle 990
# Total biomass:
# Model iMM904.cmd: 7.411575608150031E-5
# Model iJN1463.cmd: 8.050704263500267E-5
# Cycle 991
# Total biomass:
# Model iMM904.cmd: 7.413801258157107E-5
# Model iJN1463.cmd: 8.054657357204072E-5
# Cycle 992
# Total biomass:
# Model iMM904.cmd: 7.4160181913251E-5
# Model iJN1463.cmd: 8.058603796171129E-5
# Cycle 993
# Total biomass:
# Model iMM904.cmd: 7.418294571036942E-5
# Model iJN1463.cmd: 8.062355826163331E-5
# Cycle 994
# Total biomass:
# Model iMM904.cmd: 7.420664704831184E-5
# Model iJN1463.cmd: 8.065907867836587E-5
# Cycle 995
# Total biomass:
# Model iMM904.cmd: 7.42295436744027E-5
# Model iJN1463.cmd: 8.069525685472816E-5
# Cycle 996
# Total biomass:
# Model iMM904.cmd: 7.42526415674196E-5
# Model iJN1463.cmd: 8.073179365177108E-5
# Cycle 997
# Total biomass:
# Model iMM904.cmd: 7.427529223968166E-5
# Model iJN1463.cmd: 8.076871421762198E-5
# Cycle 998
# Total biomass:
# Model iMM904.cmd: 7.429775455534357E-5
# Model iJN1463.cmd: 8.080564230820061E-5
# Cycle 999
# Total biomass:
# Model iMM904.cmd: 7.431811131369226E-5
# Model iJN1463.cmd: 8.084522817748616E-5
# Cycle 1000
# Total biomass:
# Model iMM904.cmd: 7.434170664256632E-5
# Model iJN1463.cmd: 8.08825176524204E-5
# Cycle 1001
# End of simulation
# Total time = 7621.761s
#
# STDERR empty.

# %% [markdown]
# Para revisar la biomasa total

# %%
sim.total_biomass.plot(x = "cycle")
# Out:
# <AxesSubplot:xlabel='cycle'>

# %% [markdown]
# Graficamos los resultados de biomasa y demás metabolitos interesantes en el grid:

# %%
im = sim.get_biomass_image('iMM904', params.all_params['maxCycles'])
im2 = sim.get_biomass_image('iJN1463',params.all_params['maxCycles'])

final = np.zeros((grid_size,grid_size,3))
final[:,:,0] = im / np.max(im)
final[:,:,1] = im2 / np.max(im2)
for rock in rock_locs:
    final[rock[0],rock[1],0:3] = 0.4 
from matplotlib import pyplot as plt
ﬁg, ax = plt.subplots(ﬁgsize = (3.1, 3.1))
ax.imshow(ﬁnal)
plt.imshow(final)

# %%
plt.imshow(sim.get_metabolite_image("succ_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("ac_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("nh4_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("o2_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("catechol_e",params.all_params['maxCycles']))
