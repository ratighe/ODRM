# %% [markdown]
# **Soil-air interface.**
#
# Using the functionality of COMETS, one can design simulations which go beyond in silico corollaries of lab experiments to make predictions for environments mimicking natural ecosystems, which is a necessary step for understanding natural ecology from first principles. In this example, we consider a simulation of a soil environment. We use source-and-sink functions to model how a root provides organic acids to the environment while removing ammonia (Huang et al 2014 Botany). While we restrict the root functionality to a source/sink, one could use functionality demonstrated above, for example extracellular enzymes, to generate feedback loops between microbe-produced metabolites and root exudation. We use fixed metabolite concentrations to mimic the largely unchanging air interface above a root, which generates an oxygen gradient. Additionally, since soil is characterized by strong spatial structure with many impenetrable barriers that localized interactions (Nunan 2017), we place “rock” barriers throughout the simulation area. A more complex simulation could use varying diffusion constants for metabolites, as described in a previous protocol (Virtual Petri Dish). Similarly, we use standard diffusion of biomass, but this could be changed to use pushing force or non-linear diffusion for a potentially increased realism.

# %%
import cobra 
import sys 
import copy 
import numpy as np 
from matplotlib import pyplot as plt 
import cometspy as c

# %% [markdown]
# Para nuestro proyecto, utilizaremos Escherichia coli (modelo iAF1260), Pseudomonas putida (modelo iJN1463) y Saccharomyces Cerevisiae (modelo iMM904), recuperados de la base de datos BIGG.
#
# Cambiamos los bounds de las funciones objetivo de los modelos:

# %%
model_dir = "./modelos" # model location
iAF = cobra.io.read_sbml_model(model_dir + '/iAF1260.xml')
iJN = cobra.io.read_sbml_model(model_dir + '/iJN1463.xml')

iAF.reactions.get_by_id('BIOMASS_Ec_iAF1260_core_59p81M').lower_bound = 0
iAF.reactions.get_by_id('BIOMASS_Ec_iAF1260_core_59p81M').upper_bound = 1000

iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').lower_bound = 0
iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').upper_bound = 1000

# %% [markdown]
# Luego se convierten estos modelos al formato de COMETS. Se utilizan funciones helper para dos cosas: a) Asegurar que el modelo en COMETS no confunda las reacciones de "sink" con las de exchange, ya que en COBRA están desbalanceadas y por tanto se parecen a las de exchange, y b) abrir todos los bounds de las reacciones de exchange, para que COMETS controle la composición del medio.

# %%
iAF_comets = c.model(iAF)
iAF_comets.ensure_sinks_are_not_exchanges()
iAF_comets.open_exchanges()

iJN_comets = c.model(iJN)
iJN_comets.ensure_sinks_are_not_exchanges()
iJN_comets.open_exchanges()

# %% [markdown]
# El mundo que se simulará tendrá dimensiones de 30x30. El eje de la izquierda (x = 0) corresponde a la raíz, y el eje superior (y = 0) corresponde al aire. La biomasa y las rocas se distribuyen en el resto del grid. Donde hayan rocas no puede haber ni biomasa ni metabolitos, así que seleccionamos esos lugares primero. Para esta simulación, se generarán 3 rocas con un un tamaño medio de 1 cuadraditos. Para generar las piedras se utiliza la función helper grow_rocks.

# %%
from cometspy.utils import grow_rocks, pick_random_locations

grid_size = 20 # 100
n_rocks = 40 # 70
rock_locs = grow_rocks(n = n_rocks, xrange = [1,grid_size-1],yrange = [1,grid_size-1],mean_size = 1)

# %% [markdown]
# Cada especie será plantada en 20 lugares sin sobreponerse. Para esto se utiliza la función helper pick_random_locations, la cual toma como argumento una tupla generada anteriormente que marca lugares "prohibidos", como los cuadrados donde se encuentran las rocas.
#
# Generamos una copia de rock_locs para no cambiarla accidentalmente, y la llamamos forbbiden_locs:

# %%
import copy
forbidden_locs = copy.deepcopy(rock_locs)

# %% [markdown]
# Ahora elegimos al azar los lugares para cada especie, y los vamos añadiendo a la lista forbidden locs para que no se sobrepongan:

# %%
founders_per_species = 20 # 60
iAF_locs = pick_random_locations(n = founders_per_species, 
                                   xrange = [1,grid_size], yrange = [1,grid_size], 
                                   forbidden_locs = forbidden_locs)
forbidden_locs.extend(iAF_locs)
iJN_locs = pick_random_locations(founders_per_species, [1,grid_size],[1,grid_size], forbidden_locs)

# %% [markdown]
# Para graficar los lugares utilizamos matplotlib:

# %%
from matplotlib import pyplot as plt
initial_image = np.zeros((grid_size,grid_size,3))
for rock in rock_locs:
    initial_image[rock[0],rock[1],0:3] = 0.5 
for loc in iAF_locs:
    initial_image[loc[0],loc[1],1] = 1
for loc in iJN_locs:
    initial_image[loc[0],loc[1],2] = 1
plt.imshow(initial_image)

# %% [markdown]
# Generamos el layout y agregamos las rocas:

# %%
# iAF
iAF_initial_pop = [] 
for loc in iJN_locs: 
    iAF_initial_pop.append([loc[0], loc[1], 1.e-8]) 
iAF_comets.initial_pop = iAF_initial_pop 
# iJN
iJN_initial_pop = [] 
for loc in iJN_locs: 
    iJN_initial_pop.append([loc[0], loc[1], 1.e-8]) 
iJN_comets.initial_pop = iJN_initial_pop

# %% [markdown]
# Setteamos las poblaciones iniciales para cada especie, con esto los modelos están listos y los añadimos al layout:

# %%
layout = c.layout([iAF_comets, iJN_comets])
layout.grid = [grid_size,grid_size]
layout.add_barriers(rock_locs)

# %% [markdown]
# Añadimos los metabolitos que estarán inicialmente disponibles en el ambiente. Usamos la función helper add_typical_trace_metabolites() para las trazas típicas. Bajamos el valor del oxígeno dado que la idea es que el que esté disponible difunda desde la atmósfera. Añadimos algunos metabolitos que no se añadieron con la función helper:

# %%
layout.add_typical_trace_metabolites()
layout.set_specific_metabolite('o2_e',0.00001)
layout.set_specific_metabolite('hco3_e',1000)
layout.set_specific_metabolite('co2_e',1000)
layout.set_specific_metabolite('h2_e',1000)
layout.set_specific_metabolite('so3_e',1000)
layout.set_specific_metabolite('nh4_e',0.000001)

layout.set_specific_metabolite('glc__D_e',0.0000001)
layout.set_specific_metabolite('meoh_e',0.00000001)
layout.set_specific_metabolite('cys__L_e',0.0000001)
layout.set_specific_metabolite('nac_e',0.00000001)

# %% [markdown]
# Para la capa de aire, dejamos el oxígeno en un valor constante. Al fondo también dejamos al oxígeno en un valor fijo e igual a 0, para simular el efecto de difusión. De manera similar, hacemos lo mismo con el amoniaco y la raíz en la parte izquierda:

# %%
# set static media of O2 and CO2 at the top and bottom-- the "air" and continuous loss of O2 downwards
for x in range(grid_size):
    layout.set_specific_static_at_location('o2_e', (x,0), .0001) # top
    layout.set_specific_static_at_location('o2_e', (x,grid_size-1), 0.) # bottom
    layout.set_specific_static_at_location('co2_e', (x,0), .0001)
    
for x in range(grid_size):
    layout.set_specific_static_at_location('nh4_e', (0,x), 0.0)

# %% [markdown]
# La raíz consume todo el amoniaco, pero es una fuente de acidos orgánicos y metanol para el ambiente. Asumiendo una tasa fija:

# %%
for x in range(grid_size):
    layout.set_specific_refresh_at_location('cit_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('meoh_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('succ_e', (0,x), .000001)

# %% [markdown]
# El layout y los modelos están listos, ahora setteamos los parámetros de la simulación:

# %%
params = c.params()
params.set_param('timeStep', 0.1)
params.set_param('maxCycles', 1000)
params.set_param('maxSpaceBiomass', 10)
params.set_param('deathRate', 0.0001) # die at rate of 1/10000 per hour
params.set_param('writeBiomassLog', True)
params.set_param('BiomassLogRate', 500)
params.set_param('writeMediaLog', True)
params.set_param('MediaLogRate', 500)
params.set_param("writeFluxLog", True)
params.set_param("FluxLogRate", 500)
params.set_param('numRunThreads', 3)
params.set_param('defaultKm', 0.000001)

# %% [markdown]
# Ahora creamos el objeto de la simulación y la corremos. Ojito que se demora y el pc empieza a despegar.

# %%
sim = c.comets(layout, params)
sim.run()
# Out:
# Running COMETS simulation ...
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3357: DtypeWarning: Columns (5,7,8,9,12,14,18,22,23,25,26,28,31,32,35,41,43,44,47,62,63,64,66,70,75,81,83,100,104,114,116,118,121,122,124,131,134,136,137,142,144,146,147,148,149,151,153,155,163,166,167,176,177,181,189,190,193,200,213,214,222,228,230,238,243,246,248,249,252,254,255,256,277,299,300,301,303,304,324,327,331,346,361,366,369,374,402,406,407,408,411,412,413,417,419,420,421,429,430,432,435,444,445,453,459,481,491,506,507,515,517,523,530,535,537,539,544,547,548,549,550,559,569,590,605,607,614,631,640,656,657,670,677,678,691,692,696,698,701,703,714,716,719,720,721,723,726,727,728,729,732,744,746,748,749,751,753,755,756,758,766,769,775,783,792,798,807,843,850,863,864,868,871,872,873,878,879,881,882,883,884,885,892,909,910,911,920,924,925,926,927,928,930,939,942,944,953,954,964,966,968,969,971,974,975,976,977,978,980,981,983,991,992,1016,1017,1018,1021,1035,1037,1038,1039,1050,1053,1054,1055,1056,1059,1061,1062,1063,1070,1080,1081,1098,1107,1108,1113,1124,1126,1131,1132,1134,1138,1141,1149,1164,1165,1179,1180,1185,1197,1200,1201,1203,1213,1214,1220,1221,1224,1225,1227,1228,1229,1230,1232,1233,1242,1243,1244,1246,1261,1262,1264,1266,1269,1276,1279,1284,1285,1288,1298,1303,1310,1316,1317,1318,1320,1333,1336,1338,1346,1347,1349,1354,1355,1358,1359,1360,1363,1364,1365,1369,1370,1371,1376,1397,1404,1414,1415,1422,1424,1439,1459,1461,1467,1470,1481,1491,1499,1500,1501,1503,1505,1506,1507,1508,1509,1510,1511,1516,1517,1519,1520,1524,1526,1527,1528,1530,1534,1542,1549,1558,1567,1572,1573,1588,1600,1601,1604,1605,1610,1618,1621,1622,1626,1627,1629,1634,1645,1646,1665,1678,1690,1697,1698,1700,1702,1715,1721,1725,1731,1734,1736,1764,1765,1766,1767,1768,1769,1770,1771,1772,1774,1775,1788,1789,1790,1799,1810,1811,1816,1824,1830,1831,1836,1854,1855,1858,1862,1863,1864,1884,1886,1887,1891,1895,1896,1900,1901,1902,1905,1906,1908,1910,1915,1917,1919,1920,1921,1924,1925,1927,1928,1930,1931,1932,1933,1935,1936,1937,1938,1940,1941,1942,1943,1944,1946,1947,1948,1950,1951,1961,1963,1964,1967,1968,1969,1973,1974,1975,1977,1984,1986,1988,1989,1990,1991,1992,1994,1998,1999,2001,2002,2004,2008,2009,2049,2055,2056,2062,2063,2071,2072,2080,2084,2086,2093,2094,2096,2100,2101,2107,2113,2120,2121,2124,2133,2134,2148,2150,2160,2167,2173,2182,2200,2205,2207,2210,2219,2225,2227,2249,2267,2268,2274,2285,2331,2376,2377,2390,2391,2398,2399,2401,2402,2420,2423,2457,2473,2474,2478,2479,2480,2529,2532,2533,2534,2535,2575,2639,2682,2694,2698,2714,2715,2719,2723,2727,2731,2764,2765,2769,2790,2833,2835,2837,2838,2840,2842,2852,2884) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Done!

# %%
print(sim.run_output)
print(sim.run_errors)
# Out:
# -script
# running script file: C:\Users\ronal\Desktop\Proyecto ODRM\ODRM\simulaciones\2_modelos\Coli_putida_20x20/.current_script_0x2219d2f0c10
# Current Java version: 17.0.1
# Parameters file .current_global_0x2219d2f0c10 loaded.
# Parameters file .current_package_0x2219d2f0c10 loaded.
# Loading layout file '.current_layout_0x2219d2f0c10'...
# null\COMETS_manifest.txt (El sistema no puede encontrar la ruta especificada)
# Unable to initialize manifest file.
# Continuing without writing manifest file.
# Found 2 model files!
# Loading '.\iAF1260.cmd' ...
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-12-02
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-12-02
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution = 395.7352921962825
# Loading '.\iJN1463.cmd' ...
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-12-02
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-12-02
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution = 237.06607191111198
# Constructing world...
# Done!
# medialist	12dgr160_e	12dgr180_e	12ppd__R_e	12ppd__S_e	13dampp_e	14glucan_e	15dap_e	1ag160_e	1ag180_e	1ag181d9_e	1ag182d9d12_e	23camp_e	23ccmp_e	23cgmp_e	23cump_e	23dappa_e	25dkglcn_e	26dap__M_e	2ameph_e	2ddglcn_e	2dhglcn_e	2m35mdntha_e	34dhbz_e	34dhcinm_e	34dhpac_e	34dhphe_e	35dnta_e	3amp_e	3cmp_e	3gmp_e	3h4atb_e	3hcinnm_e	3hpppn_e	3mb_e	3oxoadp_e	3ump_e	4abut_e	4hbz_e	4hoxpacd_e	4hpro_DC_e	4hpro_LT_e	4hptn_e	4oxptn_e	5aptn_e	5dglcn_e	5g2oxpt_e	5mcsn_e	5oxpro_e	6atha_e	6hnac_e	LalaDgluMdapDala_e	LalaDgluMdap_e	LalaLglu_e	Ncbmpts_e	R3hdec4e_e	R_3h4atba_e	R_3h6atha_e	R_3hcmrs7e_e	R_3hdcaa_e	R_3hdd5ea_e	R_3hdd6e_e	R_3hdda_e	R_3hhdca_e	R_3hhpa_e	R_3hhxa_e	R_3hnonaa_e	R_3hocta_e	R_3hpba_e	R_3hpdeca_e	R_3hphpa_e	R_3hphxa_e	R_3hpnona_e	R_3hpocta_e	R_3hppta_e	R_3hpt_e	R_3htd58e_e	R_3htd5e_e	R_3httdca_e	T4hcinnm_e	ac_e	acac_e	acald_e	acgal1p_e	acgal_e	acgam1p_e	acgam_e	acmana_e	acmtsoxin_e	acmum_e	acnam_e	acolipa_e	acon_C_e	acpptrn_e	acser_e	actn__R_e	ade_e	adn_e	adocbl_e	ag_e	agm_e	akg_e	ala_B_e	ala__D_e	ala__L_e	alaala_e	alahis_e	alaleu_e	alathr_e	alatrp_e	algac_MG_14_e	algac_MG_23_e	algac_MG_32_e	algac_MG_41_e	algac__M_e	all__D_e	alltn_e	amp_e	anhgm_e	apc_e	arab__L_e	arbtn_e	arbtn_fe3_e	arg__D_e	arg__L_e	ascb__L_e	asn__D_e	asn__L_e	aso3_e	aso4_e	asp__L_e	balaala_e	balabala_e	balagly_e	balaleu_e	balamd_e	bhb_e	biliverd_e	btd_RR_e	btn_e	but_e	butso3_e	bz_e	ca2_e	carn_e	catechol_e	cbi_e	cbl1_e	cd2_e	cell4_e	cgly_e	chol_e	chols_e	chor_e	cinnm_e	cit_e	cl_e	cm_e	cmcbtt_e	cmp_e	co2_e	co_e	cobalt2_e	colipa_e	confrl_e	cpgn_e	cpgn_un_e	creat_e	crn_e	cro2_e	cro4_e	crtn_e	csn_e	cu2_e	cu_e	cyan_e	cynt_e	cys__D_e	cys__L_e	cytd_e	d2one_e	d3one_e	d4one_e	dad_2_e	dag181d9_e	dag182d9d12_e	damp_e	dca_e	dcmp_e	dcyt_e	ddca_e	dgmp_e	dgsn_e	dgudbutn_e	dha_e	dimp_e	din_e	dmanur_e	dmgly_e	dms_e	dmso2_e	dmso_e	dopa_e	dtmp_e	dump_e	duri_e	eca4colipa_e	ecto__L_e	enlipa_e	enter_e	etha_e	ethso3_e	etoh_e	f6p_e	fald_e	fcmcbtt_e	fe2_e	fe3_e	fe3dcit_e	fe3dhbzs_e	fe3hox_e	fe3hox_un_e	fe3mcbtt_e	fe3pyovd_e	fe3pyovd_kt_e	fecrm_e	fecrm_un_e	feenter_e	feoxam_e	feoxam_un_e	fer_e	for_e	fru_e	frulys_e	fruur_e	fuc__L_e	fum_e	g1p_e	g3pc_e	g3pe_e	g3pg_e	g3pi_e	g3ps_e	g6p_e	ga_e	gal1p_e	gal_bD_e	gal_e	galct__D_e	galctn__D_e	galctn__L_e	galt_e	galur_e	gam6p_e	gam_e	gbbtn_e	gdp_e	glc__D_e	glcn_e	glcr_e	glcur1p_e	glcur_e	gln__L_e	glu__L_e	glutar_e	gly_e	glyald_e	glyb_e	glyc2p_e	glyc3p_e	glyc__R_e	glyc_e	glyclt_e	glycol_e	glygln_e	glyglu_e	glygly_e	glymet_e	glyphe_e	glyser_e	gmp_e	gsn_e	gthox_e	gthrd_e	gtp_e	gua_e	gudac_e	gudptn_e	h2_e	h2o2_e	h2o_e	h2s_e	h_e	hacolipa_e	halipa_e	hco3_e	hcys__L_e	hdca_e	hdcea_e	hg2_e	hgentis_e	his__L_e	hisgly_e	hishis_e	hom__L_e	hpta_e	hxa_e	hxan_e	icit_e	idon__L_e	ile__L_e	imp_e	ind3ac_e	indole_e	inost_e	ins_e	isetac_e	k_e	kdo2lipid4_e	lac__D_e	lac__L_e	lcts_e	leu__D_e	leu__L_e	leuleu_e	lipa_cold_e	lipa_e	lnlc_e	lpspput_e	lys__D_e	lys__L_e	lyx__L_e	m_xyl_e	mal__D_e	mal__L_e	malt_e	malthx_e	maltpt_e	malttr_e	maltttr_e	man6p_e	man_e	manglyc_e	manur_e	mcbtt_e	melib_e	meoh_e	met__D_e	met__L_e	metsox_R__L_e	metsox_S__L_e	mg2_e	minohp_e	mmet_e	mn2_e	mnl_e	mobd_e	mso3_e	mtsoxin_e	n2o_e	n2one_e	na1_e	nac_e	nh4_e	ni2_e	nmn_e	no2_e	no3_e	no_e	nona_e	o16a4colipa_e	o2_e	o2s_e	o_xyl_e	oaa_e	ocdca_e	ocdcea_e	octa_e	orn__D_e	orn_e	orot_e	oxa_e	p_xyl_e	pac_e	pacald_e	pb2_e	pea_e	peamn_e	pentso3_e	phe__D_e	phe__L_e	phedca_e	phehpa_e	phehxa_e	pheme_e	phenona_e	pheocta_e	phept_e	phpyr_e	pi_e	pnto__R_e	ppa_e	ppal_e	ppi_e	pppn_e	ppt_e	pptrn_e	prealg_MG_14_e	prealg_MG_23_e	prealg_MG_32_e	prealg_MG_41_e	prealginate_G_e	pro__D_e	pro__L_e	progly_e	psclys_e	pser__L_e	pta_e	ptrc_e	ptsla_e	pydam_e	pyovd_e	pyovd_kt_e	pyr_e	quin_e	r5p_e	rib__D_e	rmn_e	sbo3_e	sbt__D_e	sel_e	ser__D_e	ser__L_e	sheme_e	skm_e	so2_e	so3_e	so4_e	spmd_e	succ_e	sucr_e	sulfac_e	tag160_e	tag180_e	tag181d9_e	tag182d9d12_e	tartr__L_e	taur_e	tcynt_e	thm_e	thr__L_e	thrp_e	thym_e	thymd_e	tma_e	tmanur_e	tmao_e	tnt_e	tol_e	tre_e	trp__L_e	tsul_e	ttdca_e	ttdcea_e	ttrcyc_e	tungs_e	tym_e	tyr__D_e	tyr__L_e	tyrp_e	uacg ...
# Cycle 1
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-12-02
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-12-02
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-12-02
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-12-02
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-12-02
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-12-02
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-12-02
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-12-02
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-12-02
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-12-02
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-12-02
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-12-02
# FBARunThread-0 starting up.
# FBARunThread-2 starting up.
# FBARunThread-1 starting up.
# Total biomass:
# Model iAF1260.cmd: 2.113098034436399E-7
# Model iJN1463.cmd: 2.0958868346807303E-7
# Cycle 2
# Total biomass:
# Model iAF1260.cmd: 2.2334103645449073E-7
# Model iJN1463.cmd: 2.196754296075175E-7
# Cycle 3
# Total biomass:
# Model iAF1260.cmd: 2.372670125868788E-7
# Model iJN1463.cmd: 2.3088905134889604E-7
# Cycle 4
# Total biomass:
# Model iAF1260.cmd: 2.526936447847859E-7
# Model iJN1463.cmd: 2.429513264785393E-7
# Cycle 5
# Total biomass:
# Model iAF1260.cmd: 2.69586135621246E-7
# Model iJN1463.cmd: 2.5586717325368413E-7
# Cycle 6
# Total biomass:
# Model iAF1260.cmd: 2.879669611446008E-7
# Model iJN1463.cmd: 2.696497161731668E-7
# Cycle 7
# Total biomass:
# Model iAF1260.cmd: 3.079489866517589E-7
# Model iJN1463.cmd: 2.843615327495417E-7
# Cycle 8
# Total biomass:
# Model iAF1260.cmd: 3.296176163797236E-7
# Model iJN1463.cmd: 3.0004961579774E-7
# Cycle 9
# Total biomass:
# Model iAF1260.cmd: 3.5311512371736826E-7
# Model iJN1463.cmd: 3.1675646847137795E-7
# Cycle 10
# Total biomass:
# Model iAF1260.cmd: 3.785950521577584E-7
# Model iJN1463.cmd: 3.3453174237401824E-7
# Cycle 11
# Total biomass:
# Model iAF1260.cmd: 4.0620671672321434E-7
# Model iJN1463.cmd: 3.53439436603772E-7
# Cycle 12
# Total biomass:
# Model iAF1260.cmd: 4.3608853239219325E-7
# Model iJN1463.cmd: 3.7354002572651327E-7
# Cycle 13
# Total biomass:
# Model iAF1260.cmd: 4.684015238757716E-7
# Model iJN1463.cmd: 3.9489805047139066E-7
# Cycle 14
# Total biomass:
# Model iAF1260.cmd: 5.03327691505581E-7
# Model iJN1463.cmd: 4.1758303858678734E-7
# Cycle 15
# Total biomass:
# Model iAF1260.cmd: 5.410548111960774E-7
# Model iJN1463.cmd: 4.4167051210601625E-7
# Cycle 16
# Total biomass:
# Model iAF1260.cmd: 5.81799103586237E-7
# Model iJN1463.cmd: 4.672293698527178E-7
# Cycle 17
# Total biomass:
# Model iAF1260.cmd: 6.257782435008992E-7
# Model iJN1463.cmd: 4.943405635474543E-7
# Cycle 18
# Total biomass:
# Model iAF1260.cmd: 6.732159059454848E-7
# Model iJN1463.cmd: 5.230948036423723E-7
# Cycle 19
# Total biomass:
# Model iAF1260.cmd: 7.241724503257774E-7
# Model iJN1463.cmd: 5.535682528263226E-7
# Cycle 20
# Total biomass:
# Model iAF1260.cmd: 7.784536959619512E-7
# Model iJN1463.cmd: 5.85817502809146E-7
# Cycle 21
# Total biomass:
# Model iAF1260.cmd: 8.360132158487741E-7
# Model iJN1463.cmd: 6.199194043028586E-7
# Cycle 22
# Total biomass:
# Model iAF1260.cmd: 8.961344256148733E-7
# Model iJN1463.cmd: 6.558922457317235E-7
# Cycle 23
# Total biomass:
# Model iAF1260.cmd: 9.584715144802793E-7
# Model iJN1463.cmd: 6.938038561928908E-7
# Cycle 24
# Total biomass:
# Model iAF1260.cmd: 1.0229996644178981E-6
# Model iJN1463.cmd: 7.337796316412911E-7
# Cycle 25
# Total biomass:
# Model iAF1260.cmd: 1.0898231254949155E-6
# Model iJN1463.cmd: 7.759289478385791E-7
# Cycle 26
# Total biomass:
# Model iAF1260.cmd: 1.1590483486564468E-6
# Model iJN1463.cmd: 8.203510866233427E-7
# Cycle 27
# Total biomass:
# Model iAF1260.cmd: 1.2305760382772214E-6
# Model iJN1463.cmd: 8.672104023887022E-7
# Cycle 28
# Total biomass:
# Model iAF1260.cmd: 1.3046466070850728E-6
# Model iJN1463.cmd: 9.165918749213232E-7
# Cycle 29
# Total biomass:
# Model iAF1260.cmd: 1.3818657951290312E-6
# Model iJN1463.cmd: 9.685795222099208E-7
# Cycle 30
# Total biomass:
# Model iAF1260.cmd: 1.4627908069975205E-6
# Model iJN1463.cmd: 1.0233432805884572E-6
# Cycle 31
# Total biomass:
# Model iAF1260.cmd: 1.5474998963597659E-6
# Model iJN1463.cmd: 1.0809591448411138E-6
# Cycle 32
# Total biomass:
# Model iAF1260.cmd: 1.6357551496602413E-6
# Model iJN1463.cmd: 1.1415368787665747E-6
# Cycle 33
# Total biomass:
# Model iAF1260.cmd: 1.7274615900333595E-6
# Model iJN1463.cmd: 1.2051371254511624E-6
# Cycle 34
# Total biomass:
# Model iAF1260.cmd: 1.8227061495186125E-6
# Model iJN1463.cmd: 1.2718754736868469E-6
# Cycle 35
# Total biomass:
# Model iAF1260.cmd: 1.921179108076735E-6
# Model iJN1463.cmd: 1.3422619587013766E-6
# Cycle 36
# Total biomass:
# Model iAF1260.cmd: 2.0230356075114737E-6
# Model iJN1463.cmd: 1.4163560938564363E-6
# Cycle 37
# Total biomass:
# Model iAF1260.cmd: 2.1262927093631353E-6
# Model iJN1463.cmd: 1.493712810336179E-6
# Cycle 38
# Total biomass:
# Model iAF1260.cmd: 2.230312066220906E-6
# Model iJN1463.cmd: 1.5731359694650606E-6
# Cycle 39
# Total biomass:
# Model iAF1260.cmd: 2.3348204522129375E-6
# Model iJN1463.cmd: 1.6560615017043754E-6
# Cycle 40
# Total biomass:
# Model iAF1260.cmd: 2.440721589026518E-6
# Model iJN1463.cmd: 1.7422834802380857E-6
# Cycle 41
# Total biomass:
# Model iAF1260.cmd: 2.5483407036646737E-6
# Model iJN1463.cmd: 1.8316296516959645E-6
# Cycle 42
# Total biomass:
# Model iAF1260.cmd: 2.657980326407705E-6
# Model iJN1463.cmd: 1.9243504699629256E-6
# Cycle 43
# Total biomass:
# Model iAF1260.cmd: 2.769461808847998E-6
# Model iJN1463.cmd: 2.020930801782973E-6
# Cycle 44
# Total biomass:
# Model iAF1260.cmd: 2.8825331597852356E-6
# Model iJN1463.cmd: 2.1217157839938345E-6
# Cycle 45
# Total biomass:
# Model iAF1260.cmd: 2.9966694971897665E-6
# Model iJN1463.cmd: 2.226944285328402E-6
# Cycle 46
# Total biomass:
# Model iAF1260.cmd: 3.1117123712013316E-6
# Model iJN1463.cmd: 2.336617733356181E-6
# Cycle 47
# Total biomass:
# Model iAF1260.cmd: 3.2281136897323198E-6
# Model iJN1463.cmd: 2.4508724132497878E-6
# Cycle 48
# Total biomass:
# Model iAF1260.cmd: 3.3461739494234856E-6
# Model iJN1463.cmd: 2.5699151055286818E-6
# Cycle 49
# Total biomass:
# Model iAF1260.cmd: 3.4662919065056827E-6
# Model iJN1463.cmd: 2.6940285362613416E-6
# Cycle 50
# Total biomass:
# Model iAF1260.cmd: 3.588600194674429E-6
# Model iJN1463.cmd: 2.8234843676199408E-6
# Cycle 51
# Total biomass:
# Model iAF1260.cmd: 3.7131152009656906E-6
# Model iJN1463.cmd: 2.9585911923516565E-6
# Cycle 52
# Total biomass:
# Model iAF1260.cmd: 3.839628015536757E-6
# Model iJN1463.cmd: 3.0996441908329103E-6
# Cycle 53
# Total biomass:
# Model iAF1260.cmd: 3.9681940828111025E-6
# Model iJN1463.cmd: 3.2469157142958866E-6
# Cycle 54
# Total biomass:
# Model iAF1260.cmd: 4.099195921558519E-6
# Model iJN1463.cmd: 3.40071028853904E-6
# Cycle 55
# Total biomass:
# Model iAF1260.cmd: 4.232814281358148E-6
# Model iJN1463.cmd: 3.561331277335766E-6
# Cycle 56
# Total biomass:
# Model iAF1260.cmd: 4.369378184852641E-6
# Model iJN1463.cmd: 3.7290762660320417E-6
# Cycle 57
# Total biomass:
# Model iAF1260.cmd: 4.508850984833486E-6
# Model iJN1463.cmd: 3.9044201737294974E-6
# Cycle 58
# Total biomass:
# Model iAF1260.cmd: 4.651577085243031E-6
# Model iJN1463.cmd: 4.087220447680091E-6
# Cycle 59
# Total biomass:
# Model iAF1260.cmd: 4.7976793429004965E-6
# Model iJN1463.cmd: 4.277648156064567E-6
# Cycle 60
# Total biomass:
# Model iAF1260.cmd: 4.94707882393682E-6
# Model iJN1463.cmd: 4.476003482591946E-6
# Cycle 61
# Total biomass:
# Model iAF1260.cmd: 5.09983014252555E-6
# Model iJN1463.cmd: 4.682551256145293E-6
# Cycle 62
# Total biomass:
# Model iAF1260.cmd: 5.2560657212760176E-6
# Model iJN1463.cmd: 4.89758818198294E-6
# Cycle 63
# Total biomass:
# Model iAF1260.cmd: 5.415948797037156E-6
# Model iJN1463.cmd: 5.121428869224089E-6
# Cycle 64
# Total biomass:
# Model iAF1260.cmd: 5.579625949023983E-6
# Model iJN1463.cmd: 5.35439974096111E-6
# Cycle 65
# Total biomass:
# Model iAF1260.cmd: 5.747088527526353E-6
# Model iJN1463.cmd: 5.5967510753698705E-6
# Cycle 66
# Total biomass:
# Model iAF1260.cmd: 5.918286462864712E-6
# Model iJN1463.cmd: 5.848867667295919E-6
# Cycle 67
# Total biomass:
# Model iAF1260.cmd: 6.093361804065036E-6
# Model iJN1463.cmd: 6.1110764374477135E-6
# Cycle 68
# Total biomass:
# Model iAF1260.cmd: 6.272420251784468E-6
# Model iJN1463.cmd: 6.383795409746253E-6
# Cycle 69
# Total biomass:
# Model iAF1260.cmd: 6.455480962047273E-6
# Model iJN1463.cmd: 6.667408871040333E-6
# Cycle 70
# Total biomass:
# Model iAF1260.cmd: 6.6424628480105E-6
# Model iJN1463.cmd: 6.962322721511834E-6
# Cycle 71
# Total biomass:
# Model iAF1260.cmd: 6.8332482884522545E-6
# Model iJN1463.cmd: 7.269092876047014E-6
# Cycle 72
# Total biomass:
# Model iAF1260.cmd: 7.027555490191859E-6
# Model iJN1463.cmd: 7.588413858614153E-6
# Cycle 73
# Total biomass:
# Model iAF1260.cmd: 7.225527693031004E-6
# Model iJN1463.cmd: 7.92036725665824E-6
# Cycle 74
# Total biomass:
# Model iAF1260.cmd: 7.427425124126069E-6
# Model iJN1463.cmd: 8.265061715676799E-6
# Cycle 75
# Total biomass:
# Model iAF1260.cmd: 7.633432241269977E-6
# Model iJN1463.cmd: 8.622219464293148E-6
# Cycle 76
# Total biomass:
# Model iAF1260.cmd: 7.843501890687582E-6
# Model iJN1463.cmd: 8.991383070916306E-6
# Cycle 77
# Total biomass:
# Model iAF1260.cmd: 8.058252115749135E-6
# Model iJN1463.cmd: 9.372106233381E-6
# Cycle 78
# Total biomass:
# Model iAF1260.cmd: 8.276306619735305E-6
# Model iJN1463.cmd: 9.764533140598199E-6
# Cycle 79
# Total biomass:
# Model iAF1260.cmd: 8.496996687337739E-6
# Model iJN1463.cmd: 1.0168913002535902E-5
# Cycle 80
# Total biomass:
# Model iAF1260.cmd: 8.720710620541816E-6
# Model iJN1463.cmd: 1.0584895561035256E-5
# Cycle 81
# Total biomass:
# Model iAF1260.cmd: 8.947375687750284E-6
# Model iJN1463.cmd: 1.1012961824795227E-5
# Cycle 82
# Total biomass:
# Model iAF1260.cmd: 9.176653476465346E-6
# Model iJN1463.cmd: 1.1453388677711866E-5
# Cycle 83
# Total biomass:
# Model iAF1260.cmd: 9.408642993653378E-6
# Model iJN1463.cmd: 1.1905593517946025E-5
# Cycle 84
# Total biomass:
# Model iAF1260.cmd: 9.64334585648597E-6
# Model iJN1463.cmd: 1.2365352640039771E-5
# Cycle 85
# Total biomass:
# Model iAF1260.cmd: 9.880594525841833E-6
# Model iJN1463.cmd: 1.2830634143741793E-5
# Cycle 86
# Total biomass:
# Model iAF1260.cmd: 1.0118866719537044E-5
# Model iJN1463.cmd: 1.3296025394842785E-5
# Cycle 87
# Total biomass:
# Model iAF1260.cmd: 1.035871460965268E-5
# Model iJN1463.cmd: 1.3760585991219104E-5
# Cycle 88
# Total biomass:
# Model iAF1260.cmd: 1.0598668701519309E-5
# Model iJN1463.cmd: 1.4211358863625348E-5
# Cycle 89
# Total biomass:
# Model iAF1260.cmd: 1.0838895530343688E-5
# Model iJN1463.cmd: 1.465351421962581E-5
# Cycle 90
# Total biomass:
# Model iAF1260.cmd: 1.1077760081954261E-5
# Model iJN1463.cmd: 1.5084815427723032E-5
# Cycle 91
# Total biomass:
# Model iAF1260.cmd: 1.1315348821898676E-5
# Model iJN1463.cmd: 1.5507273599363914E-5
# Cycle 92
# Total biomass:
# Model iAF1260.cmd: 1.1551227328012307E-5
# Model iJN1463.cmd: 1.5917973651026618E-5
# Cycle 93
# Total biomass:
# Model iAF1260.cmd: 1.178380676681348E-5
# Model iJN1463.cmd: 1.631516999826542E-5
# Cycle 94
# Total biomass:
# Model iAF1260.cmd: 1.2011428504031019E-5
# Model iJN1463.cmd: 1.6691445151749385E-5
# Cycle 95
# Total biomass:
# Model iAF1260.cmd: 1.2232662381188045E-5
# Model iJN1463.cmd: 1.703995787183201E-5
# Cycle 96
# Total biomass:
# Model iAF1260.cmd: 1.2446296553377792E-5
# Model iJN1463.cmd: 1.736514607527347E-5
# Cycle 97
# Total biomass:
# Model iAF1260.cmd: 1.265267992640023E-5
# Model iJN1463.cmd: 1.767070766579194E-5
# Cycle 98
# Total biomass:
# Model iAF1260.cmd: 1.2849710190660263E-5
# Model iJN1463.cmd: 1.7958535907398736E-5
# Cycle 99
# Total biomass:
# Model iAF1260.cmd: 1.3037964923989056E-5
# Model iJN1463.cmd: 1.8227125786399776E-5
# Cycle 100
# Total biomass:
# Model iAF1260.cmd: 1.3217005253681602E-5
# Model iJN1463.cmd: 1.8475663506484356E-5
# Cycle 101
# Total biomass:
# Model iAF1260.cmd: 1.338675165377503E-5
# Model iJN1463.cmd: 1.8708382891459998E-5
# Cycle 102
# Total biomass:
# Model iAF1260.cmd: 1.3550976977921678E-5
# Model iJN1463.cmd: 1.8928506918329933E-5
# Cycle 103
# Total biomass:
# Model iAF1260.cmd: 1.3710439663034335E-5
# Model iJN1463.cmd: 1.9138480494664678E-5
# Cycle 104
# Total biomass:
# Model iAF1260.cmd: 1.386526524597044E-5
# Model iJN1463.cmd: 1.934121654678521E-5
# Cycle 105
# Total biomass:
# Model iAF1260.cmd: 1.401606055908856E-5
# Model iJN1463.cmd: 1.9539120571717114E-5
# Cycle 106
# Total biomass:
# Model iAF1260.cmd: 1.4164263665660201E-5
# Model iJN1463.cmd: 1.9733480531315476E-5
# Cycle 107
# Total biomass:
# Model iAF1260.cmd: 1.4311323066282037E-5
# Model iJN1463.cmd: 1.99232342633359E-5
# Cycle 108
# Total biomass:
# Model iAF1260.cmd: 1.4457620533748267E-5
# Model iJN1463.cmd: 2.0109193831640693E-5
# Cycle 109
# Total biomass:
# Model iAF1260.cmd: 1.4601813741624532E-5
# Model iJN1463.cmd: 2.029247652271323E-5
# Cycle 110
# Total biomass:
# Model iAF1260.cmd: 1.4744633372352598E-5
# Model iJN1463.cmd: 2.0474409879840962E-5
# Cycle 111
# Total biomass:
# Model iAF1260.cmd: 1.488614101319644E-5
# Model iJN1463.cmd: 2.065488841420718E-5
# Cycle 112
# Total biomass:
# Model iAF1260.cmd: 1.5027580326031137E-5
# Model iJN1463.cmd: 2.0834956769166475E-5
# Cycle 113
# Total biomass:
# Model iAF1260.cmd: 1.5169878400410782E-5
# Model iJN1463.cmd: 2.1012707825159228E-5
# Cycle 114
# Total biomass:
# Model iAF1260.cmd: 1.5311944344032015E-5
# Model iJN1463.cmd: 2.1189898825854487E-5
# Cycle 115
# Total biomass:
# Model iAF1260.cmd: 1.5452743175059036E-5
# Model iJN1463.cmd: 2.1369295323935284E-5
# Cycle 116
# Total biomass:
# Model iAF1260.cmd: 1.5594537011934676E-5
# Model iJN1463.cmd: 2.1548443757444434E-5
# Cycle 117
# Total biomass:
# Model iAF1260.cmd: 1.5736343443995008E-5
# Model iJN1463.cmd: 2.1726386803044545E-5
# Cycle 118
# Total biomass:
# Model iAF1260.cmd: 1.587806409164282E-5
# Model iJN1463.cmd: 2.190341014963844E-5
# Cycle 119
# Total biomass:
# Model iAF1260.cmd: 1.6019125360216613E-5
# Model iJN1463.cmd: 2.2081129177330698E-5
# Cycle 120
# Total biomass:
# Model iAF1260.cmd: 1.6160306625055907E-5
# Model iJN1463.cmd: 2.225853434186487E-5
# Cycle 121
# Total biomass:
# Model iAF1260.cmd: 1.630190556925837E-5
# Model iJN1463.cmd: 2.2434609151867473E-5
# Cycle 122
# Total biomass:
# Model iAF1260.cmd: 1.6444054133213676E-5
# Model iJN1463.cmd: 2.2611617136011098E-5
# Cycle 123
# Total biomass:
# Model iAF1260.cmd: 1.6587017730567803E-5
# Model iJN1463.cmd: 2.2787006943805662E-5
# Cycle 124
# Total biomass:
# Model iAF1260.cmd: 1.6728311827723693E-5
# Model iJN1463.cmd: 2.296536582806339E-5
# Cycle 125
# Total biomass:
# Model iAF1260.cmd: 1.686973401290989E-5
# Model iJN1463.cmd: 2.3144957799213043E-5
# Cycle 126
# Total biomass:
# Model iAF1260.cmd: 1.701378166526837E-5
# Model iJN1463.cmd: 2.331690200624941E-5
# Cycle 127
# Total biomass:
# Model iAF1260.cmd: 1.715596030263369E-5
# Model iJN1463.cmd: 2.3488474869621184E-5
# Cycle 128
# Total biomass:
# Model iAF1260.cmd: 1.7297504284464336E-5
# Model iJN1463.cmd: 2.366048471047983E-5
# Cycle 129
# Total biomass:
# Model iAF1260.cmd: 1.7437790930366817E-5
# Model iJN1463.cmd: 2.3833446397701986E-5
# Cycle 130
# Total biomass:
# Model iAF1260.cmd: 1.7577686373697456E-5
# Model iJN1463.cmd: 2.4008665823026347E-5
# Cycle 131
# Total biomass:
# Model iAF1260.cmd: 1.77194112579874E-5
# Model iJN1463.cmd: 2.4180900115334745E-5
# Cycle 132
# Total biomass:
# Model iAF1260.cmd: 1.7860896659494692E-5
# Model iJN1463.cmd: 2.4352437137297477E-5
# Cycle 133
# Total biomass:
# Model iAF1260.cmd: 1.8001721755643654E-5
# Model iJN1463.cmd: 2.452396913240053E-5
# Cycle 134
# Total biomass:
# Model iAF1260.cmd: 1.8142661959400485E-5
# Model iJN1463.cmd: 2.469692628917362E-5
# Cycle 135
# Total biomass:
# Model iAF1260.cmd: 1.8284690246988486E-5
# Model iJN1463.cmd: 2.4868290921698888E-5
# Cycle 136
# Total biomass:
# Model iAF1260.cmd: 1.842651114317595E-5
# Model iJN1463.cmd: 2.504216583335136E-5
# Cycle 137
# Total biomass:
# Model iAF1260.cmd: 1.8569278672413797E-5
# Model iJN1463.cmd: 2.5215455421650466E-5
# Cycle 138
# Total biomass:
# Model iAF1260.cmd: 1.8712109133403205E-5
# Model iJN1463.cmd: 2.53895340500522E-5
# Cycle 139
# Total biomass:
# Model iAF1260.cmd: 1.885638195986078E-5
# Model iJN1463.cmd: 2.5561368432162527E-5
# Cycle 140
# Total biomass:
# Model iAF1260.cmd: 1.9000240992707467E-5
# Model iJN1463.cmd: 2.5733063407056934E-5
# Cycle 141
# Total biomass:
# Model iAF1260.cmd: 1.9143788921067793E-5
# Model iJN1463.cmd: 2.59045028572797E-5
# Cycle 142
# Total biomass:
# Model iAF1260.cmd: 1.9286579103047716E-5
# Model iJN1463.cmd: 2.6078873324436724E-5
# Cycle 143
# Total biomass:
# Model iAF1260.cmd: 1.943039063974888E-5
# Model iJN1463.cmd: 2.625317863079142E-5
# Cycle 144
# Total biomass:
# Model iAF1260.cmd: 1.9573596546128265E-5
# Model iJN1463.cmd: 2.6427716046875062E-5
# Cycle 145
# Total biomass:
# Model iAF1260.cmd: 1.97161149556784E-5
# Model iJN1463.cmd: 2.6603191371975188E-5
# Cycle 146
# Total biomass:
# Model iAF1260.cmd: 1.985712279727819E-5
# Model iJN1463.cmd: 2.6780911002350486E-5
# Cycle 147
# Total biomass:
# Model iAF1260.cmd: 1.9998212067519887E-5
# Model iJN1463.cmd: 2.6956378110665852E-5
# Cycle 148
# Total biomass:
# Model iAF1260.cmd: 2.0139591056586966E-5
# Model iJN1463.cmd: 2.7129832794131118E-5
# Cycle 149
# Total biomass:
# Model iAF1260.cmd: 2.0282485985515092E-5
# Model iJN1463.cmd: 2.7302105269748573E-5
# Cycle 150
# Total biomass:
# Model iAF1260.cmd: 2.0426211260971144E-5
# Model iJN1463.cmd: 2.7473524416625254E-5
# Cycle 151
# Total biomass:
# Model iAF1260.cmd: 2.0570349034973607E-5
# Model iJN1463.cmd: 2.764360861729086E-5
# Cycle 152
# Total biomass:
# Model iAF1260.cmd: 2.0714996973562698E-5
# Model iJN1463.cmd: 2.7812730290633407E-5
# Cycle 153
# Total biomass:
# Model iAF1260.cmd: 2.0858662183779553E-5
# Model iJN1463.cmd: 2.7981798741194125E-5
# Cycle 154
# Total biomass:
# Model iAF1260.cmd: 2.1001892137167897E-5
# Model iJN1463.cmd: 2.8151121100701114E-5
# Cycle 155
# Total biomass:
# Model iAF1260.cmd: 2.114627697114175E-5
# Model iJN1463.cmd: 2.8319057977232964E-5
# Cycle 156
# Total biomass:
# Model iAF1260.cmd: 2.129067017946484E-5
# Model iJN1463.cmd: 2.8485809694363694E-5
# Cycle 157
# Total biomass:
# Model iAF1260.cmd: 2.1434549779401046E-5
# Model iJN1463.cmd: 2.8654418218863763E-5
# Cycle 158
# Total biomass:
# Model iAF1260.cmd: 2.1576980956005524E-5
# Model iJN1463.cmd: 2.8824909070011353E-5
# Cycle 159
# Total biomass:
# Model iAF1260.cmd: 2.1720050914954106E-5
# Model iJN1463.cmd: 2.8995046333216133E-5
# Cycle 160
# Total biomass:
# Model iAF1260.cmd: 2.1864717975441086E-5
# Model iJN1463.cmd: 2.9163439197733383E-5
# Cycle 161
# Total biomass:
# Model iAF1260.cmd: 2.2010365258382304E-5
# Model iJN1463.cmd: 2.93306778548885E-5
# Cycle 162
# Total biomass:
# Model iAF1260.cmd: 2.2156314795669257E-5
# Model iJN1463.cmd: 2.949711250850329E-5
# Cycle 163
# Total biomass:
# Model iAF1260.cmd: 2.2301982814803976E-5
# Model iJN1463.cmd: 2.966330368169696E-5
# Cycle 164
# Total biomass:
# Model iAF1260.cmd: 2.2446881177905933E-5
# Model iJN1463.cmd: 2.9830081587424307E-5
# Cycle 165
# Total biomass:
# Model iAF1260.cmd: 2.2590926336028973E-5
# Model iJN1463.cmd: 2.9997225152319726E-5
# Cycle 166
# Total biomass:
# Model iAF1260.cmd: 2.2736275454198226E-5
# Model iJN1463.cmd: 3.0163091424424094E-5
# Cycle 167
# Total biomass:
# Model iAF1260.cmd: 2.288199850815298E-5
# Model iJN1463.cmd: 3.0328743383550733E-5
# Cycle 168
# Total biomass:
# Model iAF1260.cmd: 2.3027839930641062E-5
# Model iJN1463.cmd: 3.049457555684739E-5
# Cycle 169
# Total biomass:
# Model iAF1260.cmd: 2.317281426791877E-5
# Model iJN1463.cmd: 3.06616549601221E-5
# Cycle 170
# Total biomass:
# Model iAF1260.cmd: 2.3317747843708293E-5
# Model iJN1463.cmd: 3.0829179918075697E-5
# Cycle 171
# Total biomass:
# Model iAF1260.cmd: 2.346278261735664E-5
# Model iJN1463.cmd: 3.0996845704418956E-5
# Cycle 172
# Total biomass:
# Model iAF1260.cmd: 2.3608473069249814E-5
# Model iJN1463.cmd: 3.116320623038171E-5
# Cycle 173
# Total biomass:
# Model iAF1260.cmd: 2.3754497186717913E-5
# Model iJN1463.cmd: 3.132935545286118E-5
# Cycle 174
# Total biomass:
# Model iAF1260.cmd: 2.3901231629850358E-5
# Model iJN1463.cmd: 3.14929255347806E-5
# Cycle 175
# Total biomass:
# Model iAF1260.cmd: 2.4047323767605928E-5
# Model iJN1463.cmd: 3.16568316343854E-5
# Cycle 176
# Total biomass:
# Model iAF1260.cmd: 2.419358587782453E-5
# Model iJN1463.cmd: 3.182006415424559E-5
# Cycle 177
# Total biomass:
# Model iAF1260.cmd: 2.4336135487218296E-5
# Model iJN1463.cmd: 3.1988346349279144E-5
# Cycle 178
# Total biomass:
# Model iAF1260.cmd: 2.448037626138605E-5
# Model iJN1463.cmd: 3.2155744673306146E-5
# Cycle 179
# Total biomass:
# Model iAF1260.cmd: 2.4624875118840403E-5
# Model iJN1463.cmd: 3.232199920863047E-5
# Cycle 180
# Total biomass:
# Model iAF1260.cmd: 2.4769837265616402E-5
# Model iJN1463.cmd: 3.2487383958663294E-5
# Cycle 181
# Total biomass:
# Model iAF1260.cmd: 2.491483401613951E-5
# Model iJN1463.cmd: 3.2652557248400166E-5
# Cycle 182
# Total biomass:
# Model iAF1260.cmd: 2.5059113699641355E-5
# Model iJN1463.cmd: 3.28184186190406E-5
# Cycle 183
# Total biomass:
# Model iAF1260.cmd: 2.520182750634087E-5
# Model iJN1463.cmd: 3.298592528304402E-5
# Cycle 184
# Total biomass:
# Model iAF1260.cmd: 2.5345228134879367E-5
# Model iJN1463.cmd: 3.315164186878865E-5
# Cycle 185
# Total biomass:
# Model iAF1260.cmd: 2.5485402494549362E-5
# Model iJN1463.cmd: 3.332086074964962E-5
# Cycle 186
# Total biomass:
# Model iAF1260.cmd: 2.5628494475650766E-5
# Model iJN1463.cmd: 3.348717221230606E-5
# Cycle 187
# Total biomass:
# Model iAF1260.cmd: 2.5772878413320977E-5
# Model iJN1463.cmd: 3.365174063554871E-5
# Cycle 188
# Total biomass:
# Model iAF1260.cmd: 2.5918522562030456E-5
# Model iJN1463.cmd: 3.3815226851048736E-5
# Cycle 189
# Total biomass:
# Model iAF1260.cmd: 2.6064136296672346E-5
# Model iJN1463.cmd: 3.397893346368541E-5
# Cycle 190
# Total biomass:
# Model iAF1260.cmd: 2.621073169417626E-5
# Model iJN1463.cmd: 3.4139729691504756E-5
# Cycle 191
# Total biomass:
# Model iAF1260.cmd: 2.6358405761033613E-5
# Model iJN1463.cmd: 3.430266361548679E-5
# Cycle 192
# Total biomass:
# Model iAF1260.cmd: 2.6505605616294748E-5
# Model iJN1463.cmd: 3.446489940805134E-5
# Cycle 193
# Total biomass:
# Model iAF1260.cmd: 2.6652811219760777E-5
# Model iJN1463.cmd: 3.4624320773181806E-5
# Cycle 194
# Total biomass:
# Model iAF1260.cmd: 2.6797872440977305E-5
# Model iJN1463.cmd: 3.478885945365681E-5
# Cycle 195
# Total biomass:
# Model iAF1260.cmd: 2.6944711187270938E-5
# Model iJN1463.cmd: 3.495073952011352E-5
# Cycle 196
# Total biomass:
# Model iAF1260.cmd: 2.7091507562722238E-5
# Model iJN1463.cmd: 3.511206234316219E-5
# Cycle 197
# Total biomass:
# Model iAF1260.cmd: 2.7235460842779525E-5
# Model iJN1463.cmd: 3.527658874475862E-5
# Cycle 198
# Total biomass:
# Model iAF1260.cmd: 2.738221030935223E-5
# Model iJN1463.cmd: 3.5438349058163486E-5
# Cycle 199
# Total biomass:
# Model iAF1260.cmd: 2.7529562798522555E-5
# Model iJN1463.cmd: 3.559943929089255E-5
# Cycle 200
# Total biomass:
# Model iAF1260.cmd: 2.7677107417274836E-5
# Model iJN1463.cmd: 3.576029539886947E-5
# Cycle 201
# Total biomass:
# Model iAF1260.cmd: 2.782464179582043E-5
# Model iJN1463.cmd: 3.592082009924342E-5
# Cycle 202
# Total biomass:
# Model iAF1260.cmd: 2.797204518177752E-5
# Model iJN1463.cmd: 3.608102579405047E-5
# Cycle 203
# Total biomass:
# Model iAF1260.cmd: 2.811704069626614E-5
# Model iJN1463.cmd: 3.624361111223483E-5
# Cycle 204
# Total biomass:
# Model iAF1260.cmd: 2.82641472875065E-5
# Model iJN1463.cmd: 3.64042725224877E-5
# Cycle 205
# Total biomass:
# Model iAF1260.cmd: 2.8410253508071357E-5
# Model iJN1463.cmd: 3.656509830534139E-5
# Cycle 206
# Total biomass:
# Model iAF1260.cmd: 2.8557000925662695E-5
# Model iJN1463.cmd: 3.6725231021636085E-5
# Cycle 207
# Total biomass:
# Model iAF1260.cmd: 2.870284747759498E-5
# Model iJN1463.cmd: 3.688476866450916E-5
# Cycle 208
# Total biomass:
# Model iAF1260.cmd: 2.884573362213982E-5
# Model iJN1463.cmd: 3.7048435218860207E-5
# Cycle 209
# Total biomass:
# Model iAF1260.cmd: 2.8991360848372542E-5
# Model iJN1463.cmd: 3.7209370320021924E-5
# Cycle 210
# Total biomass:
# Model iAF1260.cmd: 2.9138006639752182E-5
# Model iJN1463.cmd: 3.736956351369958E-5
# Cycle 211
# Total biomass:
# Model iAF1260.cmd: 2.9284700653212633E-5
# Model iJN1463.cmd: 3.7529374440063536E-5
# Cycle 212
# Total biomass:
# Model iAF1260.cmd: 2.9431344635327885E-5
# Model iJN1463.cmd: 3.768900898515713E-5
# Cycle 213
# Total biomass:
# Model iAF1260.cmd: 2.9577688761704627E-5
# Model iJN1463.cmd: 3.7848518768387217E-5
# Cycle 214
# Total biomass:
# Model iAF1260.cmd: 2.9722493947006494E-5
# Model iJN1463.cmd: 3.800933698244743E-5
# Cycle 215
# Total biomass:
# Model iAF1260.cmd: 2.9867713681366497E-5
# Model iJN1463.cmd: 3.816891812631872E-5
# Cycle 216
# Total biomass:
# Model iAF1260.cmd: 3.0013498840017896E-5
# Model iJN1463.cmd: 3.832789285051249E-5
# Cycle 217
# Total biomass:
# Model iAF1260.cmd: 3.0160015397903146E-5
# Model iJN1463.cmd: 3.848558765129552E-5
# Cycle 218
# Total biomass:
# Model iAF1260.cmd: 3.0300446006777745E-5
# Model iJN1463.cmd: 3.864691435219854E-5
# Cycle 219
# Total biomass:
# Model iAF1260.cmd: 3.0444041726269963E-5
# Model iJN1463.cmd: 3.880651147515536E-5
# Cycle 220
# Total biomass:
# Model iAF1260.cmd: 3.058461467971752E-5
# Model iJN1463.cmd: 3.896910344136944E-5
# Cycle 221
# Total biomass:
# Model iAF1260.cmd: 3.072935843288994E-5
# Model iJN1463.cmd: 3.912730594878067E-5
# Cycle 222
# Total biomass:
# Model iAF1260.cmd: 3.0873585117104623E-5
# Model iJN1463.cmd: 3.928575599171688E-5
# Cycle 223
# Total biomass:
# Model iAF1260.cmd: 3.1019179835990604E-5
# Model iJN1463.cmd: 3.944348727105634E-5
# Cycle 224
# Total biomass:
# Model iAF1260.cmd: 3.1165266742876435E-5
# Model iJN1463.cmd: 3.960073776101503E-5
# Cycle 225
# Total biomass:
# Model iAF1260.cmd: 3.131137782797848E-5
# Model iJN1463.cmd: 3.975771771802338E-5
# Cycle 226
# Total biomass:
# Model iAF1260.cmd: 3.1457569213040886E-5
# Model iJN1463.cmd: 3.991455246975681E-5
# Cycle 227
# Total biomass:
# Model iAF1260.cmd: 3.160374927558251E-5
# Model iJN1463.cmd: 4.0070815431470896E-5
# Cycle 228
# Total biomass:
# Model iAF1260.cmd: 3.174998217247762E-5
# Model iJN1463.cmd: 4.022685065304085E-5
# Cycle 229
# Total biomass:
# Model iAF1260.cmd: 3.189627119670697E-5
# Model iJN1463.cmd: 4.038271420146066E-5
# Cycle 230
# Total biomass:
# Model iAF1260.cmd: 3.2042283722076583E-5
# Model iJN1463.cmd: 4.0538508954250676E-5
# Cycle 231
# Total biomass:
# Model iAF1260.cmd: 3.21885602017282E-5
# Model iJN1463.cmd: 4.069408551226685E-5
# Cycle 232
# Total biomass:
# Model iAF1260.cmd: 3.2331523472139414E-5
# Model iJN1463.cmd: 4.085218807295105E-5
# Cycle 233
# Total biomass:
# Model iAF1260.cmd: 3.24745317218215E-5
# Model iJN1463.cmd: 4.100982705172525E-5
# Cycle 234
# Total biomass:
# Model iAF1260.cmd: 3.2617739781123204E-5
# Model iJN1463.cmd: 4.116452006840601E-5
# Cycle 235
# Total biomass:
# Model iAF1260.cmd: 3.2760852756250675E-5
# Model iJN1463.cmd: 4.132220618658081E-5
# Cycle 236
# Total biomass:
# Model iAF1260.cmd: 3.290643799413023E-5
# Model iJN1463.cmd: 4.147723534179647E-5
# Cycle 237
# Total biomass:
# Model iAF1260.cmd: 3.3052689281833326E-5
# Model iJN1463.cmd: 4.1631383454340486E-5
# Cycle 238
# Total biomass:
# Model iAF1260.cmd: 3.319773483106943E-5
# Model iJN1463.cmd: 4.1786373665568156E-5
# Cycle 239
# Total biomass:
# Model iAF1260.cmd: 3.3341906044779674E-5
# Model iJN1463.cmd: 4.1942256104261346E-5
# Cycle 240
# Total biomass:
# Model iAF1260.cmd: 3.348751033841853E-5
# Model iJN1463.cmd: 4.2092953364299516E-5
# Cycle 241
# Total biomass:
# Model iAF1260.cmd: 3.363524636007956E-5
# Model iJN1463.cmd: 4.2247329151810995E-5
# Cycle 242
# Total biomass:
# Model iAF1260.cmd: 3.378265345715472E-5
# Model iJN1463.cmd: 4.239702227231294E-5
# Cycle 243
# Total biomass:
# Model iAF1260.cmd: 3.392110023426511E-5
# Model iJN1463.cmd: 4.255476966453478E-5
# Cycle 244
# Total biomass:
# Model iAF1260.cmd: 3.406168657407121E-5
# Model iJN1463.cmd: 4.271079766799128E-5
# Cycle 245
# Total biomass:
# Model iAF1260.cmd: 3.420204972776235E-5
# Model iJN1463.cmd: 4.28672323667176E-5
# Cycle 246
# Total biomass:
# Model iAF1260.cmd: 3.434466903695502E-5
# Model iJN1463.cmd: 4.3020876658562215E-5
# Cycle 247
# Total biomass:
# Model iAF1260.cmd: 3.448942782451001E-5
# Model iJN1463.cmd: 4.317265434854965E-5
# Cycle 248
# Total biomass:
# Model iAF1260.cmd: 3.4635347600673434E-5
# Model iJN1463.cmd: 4.3324354388084166E-5
# Cycle 249
# Total biomass:
# Model iAF1260.cmd: 3.478177122669287E-5
# Model iJN1463.cmd: 4.3475881112351334E-5
# Cycle 250
# Total biomass:
# Model iAF1260.cmd: 3.4928816081953115E-5
# Model iJN1463.cmd: 4.362405102734534E-5
# Cycle 251
# Total biomass:
# Model iAF1260.cmd: 3.507534756622988E-5
# Model iJN1463.cmd: 4.3773270801579216E-5
# Cycle 252
# Total biomass:
# Model iAF1260.cmd: 3.522106011071796E-5
# Model iJN1463.cmd: 4.3924196728388085E-5
# Cycle 253
# Total biomass:
# Model iAF1260.cmd: 3.5361313099896456E-5
# Model iJN1463.cmd: 4.407915099296227E-5
# Cycle 254
# Total biomass:
# Model iAF1260.cmd: 3.549580448636407E-5
# Model iJN1463.cmd: 4.42367143480746E-5
# Cycle 255
# Total biomass:
# Model iAF1260.cmd: 3.5632664123189724E-5
# Model iJN1463.cmd: 4.439061295800882E-5
# Cycle 256
# Total biomass:
# Model iAF1260.cmd: 3.5776356869741045E-5
# Model iJN1463.cmd: 4.4543518241908436E-5
# Cycle 257
# Total biomass:
# Model iAF1260.cmd: 3.5921751628690234E-5
# Model iJN1463.cmd: 4.46949510586379E-5
# Cycle 258
# Total biomass:
# Model iAF1260.cmd: 3.6066828074785936E-5
# Model iJN1463.cmd: 4.484517441210166E-5
# Cycle 259
# Total biomass:
# Model iAF1260.cmd: 3.620730003570123E-5
# Model iJN1463.cmd: 4.499841017419966E-5
# Cycle 260
# Total biomass:
# Model iAF1260.cmd: 3.634827029197461E-5
# Model iJN1463.cmd: 4.515144970323948E-5
# Cycle 261
# Total biomass:
# Model iAF1260.cmd: 3.649434609537264E-5
# Model iJN1463.cmd: 4.5303838261317974E-5
# Cycle 262
# Total biomass:
# Model iAF1260.cmd: 3.6641371036256024E-5
# Model iJN1463.cmd: 4.5451070840957634E-5
# Cycle 263
# Total biomass:
# Model iAF1260.cmd: 3.6782460835835917E-5
# Model iJN1463.cmd: 4.5604450988712005E-5
# Cycle 264
# Total biomass:
# Model iAF1260.cmd: 3.692771152498827E-5
# Model iJN1463.cmd: 4.575269595356212E-5
# Cycle 265
# Total biomass:
# Model iAF1260.cmd: 3.706797342694579E-5
# Model iJN1463.cmd: 4.590461632228052E-5
# Cycle 266
# Total biomass:
# Model iAF1260.cmd: 3.720822170237681E-5
# Model iJN1463.cmd: 4.6058623897526414E-5
# Cycle 267
# Total biomass:
# Model iAF1260.cmd: 3.7351193853339124E-5
# Model iJN1463.cmd: 4.621017105191248E-5
# Cycle 268
# Total biomass:
# Model iAF1260.cmd: 3.7495118774348395E-5
# Model iJN1463.cmd: 4.635946808992986E-5
# Cycle 269
# Total biomass:
# Model iAF1260.cmd: 3.764108804684365E-5
# Model iJN1463.cmd: 4.6505686848686355E-5
# Cycle 270
# Total biomass:
# Model iAF1260.cmd: 3.778834591413386E-5
# Model iJN1463.cmd: 4.665055355324492E-5
# Cycle 271
# Total biomass:
# Model iAF1260.cmd: 3.79333654141788E-5
# Model iJN1463.cmd: 4.679564653408502E-5
# Cycle 272
# Total biomass:
# Model iAF1260.cmd: 3.807869747473708E-5
# Model iJN1463.cmd: 4.694100525680391E-5
# Cycle 273
# Total biomass:
# Model iAF1260.cmd: 3.822530426794035E-5
# Model iJN1463.cmd: 4.708544989557374E-5
# Cycle 274
# Total biomass:
# Model iAF1260.cmd: 3.8373489951827516E-5
# Model iJN1463.cmd: 4.723008750378968E-5
# Cycle 275
# Total biomass:
# Model iAF1260.cmd: 3.852009883446273E-5
# Model iJN1463.cmd: 4.737554875796892E-5
# Cycle 276
# Total biomass:
# Model iAF1260.cmd: 3.866709929050058E-5
# Model iJN1463.cmd: 4.752066510759752E-5
# Cycle 277
# Total biomass:
# Model iAF1260.cmd: 3.881531145630739E-5
# Model iJN1463.cmd: 4.766405980436087E-5
# Cycle 278
# Total biomass:
# Model iAF1260.cmd: 3.8963739141397264E-5
# Model iJN1463.cmd: 4.7807140846439734E-5
# Cycle 279
# Total biomass:
# Model iAF1260.cmd: 3.91102951681781E-5
# Model iJN1463.cmd: 4.794913383684922E-5
# Cycle 280
# Total biomass:
# Model iAF1260.cmd: 3.92578397172121E-5
# Model iJN1463.cmd: 4.809286338154568E-5
# Cycle 281
# Total biomass:
# Model iAF1260.cmd: 3.940623111746351E-5
# Model iJN1463.cmd: 4.8232704408656914E-5
# Cycle 282
# Total biomass:
# Model iAF1260.cmd: 3.9553683604380844E-5
# Model iJN1463.cmd: 4.8373592924722645E-5
# Cycle 283
# Total biomass:
# Model iAF1260.cmd: 3.969384376802237E-5
# Model iJN1463.cmd: 4.8524249291749236E-5
# Cycle 284
# Total biomass:
# Model iAF1260.cmd: 3.983155607256574E-5
# Model iJN1463.cmd: 4.86758492621461E-5
# Cycle 285
# Total biomass:
# Model iAF1260.cmd: 3.9967187889123685E-5
# Model iJN1463.cmd: 4.8828651246012434E-5
# Cycle 286
# Total biomass:
# Model iAF1260.cmd: 4.0102347167559366E-5
# Model iJN1463.cmd: 4.898107116454776E-5
# Cycle 287
# Total biomass:
# Model iAF1260.cmd: 4.024632916736709E-5
# Model iJN1463.cmd: 4.912543325021258E-5
# Cycle 288
# Total biomass:
# Model iAF1260.cmd: 4.038426688668452E-5
# Model iJN1463.cmd: 4.9274684834789446E-5
# Cycle 289
# Total biomass:
# Model iAF1260.cmd: 4.052029841743768E-5
# Model iJN1463.cmd: 4.9425318406209475E-5
# Cycle 290
# Total biomass:
# Model iAF1260.cmd: 4.066222748271144E-5
# Model iJN1463.cmd: 4.9571889048771604E-5
# Cycle 291
# Total biomass:
# Model iAF1260.cmd: 4.0802000476635834E-5
# Model iJN1463.cmd: 4.9720068990646636E-5
# Cycle 292
# Total biomass:
# Model iAF1260.cmd: 4.094531432818344E-5
# Model iJN1463.cmd: 4.986562721446651E-5
# Cycle 293
# Total biomass:
# Model iAF1260.cmd: 4.10923559871099E-5
# Model iJN1463.cmd: 5.0005854631269765E-5
# Cycle 294
# Total biomass:
# Model iAF1260.cmd: 4.124179132093455E-5
# Model iJN1463.cmd: 5.0145053842686455E-5
# Cycle 295
# Total biomass:
# Model iAF1260.cmd: 4.1392244613629455E-5
# Model iJN1463.cmd: 5.0282359737854526E-5
# Cycle 296
# Total biomass:
# Model iAF1260.cmd: 4.154156561383595E-5
# Model iJN1463.cmd: 5.0420171470604434E-5
# Cycle 297
# Total biomass:
# Model iAF1260.cmd: 4.169146771543441E-5
# Model iJN1463.cmd: 5.0556774654640546E-5
# Cycle 298
# Total biomass:
# Model iAF1260.cmd: 4.184214993279654E-5
# Model iJN1463.cmd: 5.06923624221932E-5
# Cycle 299
# Total biomass:
# Model iAF1260.cmd: 4.199197310876075E-5
# Model iJN1463.cmd: 5.082831084768588E-5
# Cycle 300
# Total biomass:
# Model iAF1260.cmd: 4.214256074032111E-5
# Model iJN1463.cmd: 5.096344005062392E-5
# Cycle 301
# Total biomass:
# Model iAF1260.cmd: 4.22935932017269E-5
# Model iJN1463.cmd: 5.109798541846353E-5
# Cycle 302
# Total biomass:
# Model iAF1260.cmd: 4.2444800035726695E-5
# Model iJN1463.cmd: 5.123209175042906E-5
# Cycle 303
# Total biomass:
# Model iAF1260.cmd: 4.259614792177645E-5
# Model iJN1463.cmd: 5.136584638056273E-5
# Cycle 304
# Total biomass:
# Model iAF1260.cmd: 4.274219781293279E-5
# Model iJN1463.cmd: 5.150412328368555E-5
# Cycle 305
# Total biomass:
# Model iAF1260.cmd: 4.289307653892505E-5
# Model iJN1463.cmd: 5.163794094049262E-5
# Cycle 306
# Total biomass:
# Model iAF1260.cmd: 4.304617357598952E-5
# Model iJN1463.cmd: 5.177190092162818E-5
# Cycle 307
# Total biomass:
# Model iAF1260.cmd: 4.319699848524883E-5
# Model iJN1463.cmd: 5.190335825855935E-5
# Cycle 308
# Total biomass:
# Model iAF1260.cmd: 4.333503382374448E-5
# Model iJN1463.cmd: 5.204329613302612E-5
# Cycle 309
# Total biomass:
# Model iAF1260.cmd: 4.3473026011304197E-5
# Model iJN1463.cmd: 5.218559725352784E-5
# Cycle 310
# Total biomass:
# Model iAF1260.cmd: 4.362222050802112E-5
# Model iJN1463.cmd: 5.231766021090672E-5
# Cycle 311
# Total biomass:
# Model iAF1260.cmd: 4.377303349511305E-5
# Model iJN1463.cmd: 5.244911690353479E-5
# Cycle 312
# Total biomass:
# Model iAF1260.cmd: 4.392451722836625E-5
# Model iJN1463.cmd: 5.258225846581167E-5
# Cycle 313
# Total biomass:
# Model iAF1260.cmd: 4.40765385737154E-5
# Model iJN1463.cmd: 5.2713732938469596E-5
# Cycle 314
# Total biomass:
# Model iAF1260.cmd: 4.422224000350708E-5
# Model iJN1463.cmd: 5.285071805837667E-5
# Cycle 315
# Total biomass:
# Model iAF1260.cmd: 4.4374245861762494E-5
# Model iJN1463.cmd: 5.298170239227992E-5
# Cycle 316
# Total biomass:
# Model iAF1260.cmd: 4.4521144710694514E-5
# Model iJN1463.cmd: 5.3118538043153205E-5
# Cycle 317
# Total biomass:
# Model iAF1260.cmd: 4.467281316432858E-5
# Model iJN1463.cmd: 5.3248911163001504E-5
# Cycle 318
# Total biomass:
# Model iAF1260.cmd: 4.482598433761016E-5
# Model iJN1463.cmd: 5.3378954633870986E-5
# Cycle 319
# Total biomass:
# Model iAF1260.cmd: 4.497970148257004E-5
# Model iJN1463.cmd: 5.3508818210116986E-5
# Cycle 320
# Total biomass:
# Model iAF1260.cmd: 4.513369255752194E-5
# Model iJN1463.cmd: 5.363841768578386E-5
# Cycle 321
# Total biomass:
# Model iAF1260.cmd: 4.528785795364821E-5
# Model iJN1463.cmd: 5.376769793574795E-5
# Cycle 322
# Total biomass:
# Model iAF1260.cmd: 4.544215089761601E-5
# Model iJN1463.cmd: 5.389662946271817E-5
# Cycle 323
# Total biomass:
# Model iAF1260.cmd: 4.559655585645613E-5
# Model iJN1463.cmd: 5.4025229174617914E-5
# Cycle 324
# Total biomass:
# Model iAF1260.cmd: 4.5751059747629115E-5
# Model iJN1463.cmd: 5.4153493248089564E-5
# Cycle 325
# Total biomass:
# Model iAF1260.cmd: 4.590571204291742E-5
# Model iJN1463.cmd: 5.4281423534057934E-5
# Cycle 326
# Total biomass:
# Model iAF1260.cmd: 4.606047964411066E-5
# Model iJN1463.cmd: 5.440903107466843E-5
# Cycle 327
# Total biomass:
# Model iAF1260.cmd: 4.621536499686909E-5
# Model iJN1463.cmd: 5.4536350900272036E-5
# Cycle 328
# Total biomass:
# Model iAF1260.cmd: 4.63702826582647E-5
# Model iJN1463.cmd: 5.4663343241337854E-5
# Cycle 329
# Total biomass:
# Model iAF1260.cmd: 4.6525122244850946E-5
# Model iJN1463.cmd: 5.4789927463756565E-5
# Cycle 330
# Total biomass:
# Model iAF1260.cmd: 4.66799708497314E-5
# Model iJN1463.cmd: 5.491614870553641E-5
# Cycle 331
# Total biomass:
# Model iAF1260.cmd: 4.6834894700933504E-5
# Model iJN1463.cmd: 5.504201589043999E-5
# Cycle 332
# Total biomass:
# Model iAF1260.cmd: 4.698991576647947E-5
# Model iJN1463.cmd: 5.516755427213616E-5
# Cycle 333
# Total biomass:
# Model iAF1260.cmd: 4.714503400018954E-5
# Model iJN1463.cmd: 5.5292756914044664E-5
# Cycle 334
# Total biomass:
# Model iAF1260.cmd: 4.730027210736034E-5
# Model iJN1463.cmd: 5.541762998564794E-5
# Cycle 335
# Total biomass:
# Model iAF1260.cmd: 4.745561848952934E-5
# Model iJN1463.cmd: 5.554219540327411E-5
# Cycle 336
# Total biomass:
# Model iAF1260.cmd: 4.761101755700532E-5
# Model iJN1463.cmd: 5.5666486667117594E-5
# Cycle 337
# Total biomass:
# Model iAF1260.cmd: 4.776651111935232E-5
# Model iJN1463.cmd: 5.5790523402410185E-5
# Cycle 338
# Total biomass:
# Model iAF1260.cmd: 4.7922036126783436E-5
# Model iJN1463.cmd: 5.5914295380047014E-5
# Cycle 339
# Total biomass:
# Model iAF1260.cmd: 4.8077748774589255E-5
# Model iJN1463.cmd: 5.603788159996822E-5
# Cycle 340
# Total biomass:
# Model iAF1260.cmd: 4.823357642714344E-5
# Model iJN1463.cmd: 5.616127452634373E-5
# Cycle 341
# Total biomass:
# Model iAF1260.cmd: 4.838947136094439E-5
# Model iJN1463.cmd: 5.628444903160772E-5
# Cycle 342
# Total biomass:
# Model iAF1260.cmd: 4.854540940682314E-5
# Model iJN1463.cmd: 5.6407402132507676E-5
# Cycle 343
# Total biomass:
# Model iAF1260.cmd: 4.870144505566898E-5
# Model iJN1463.cmd: 5.6530137226283656E-5
# Cycle 344
# Total biomass:
# Model iAF1260.cmd: 4.8857350095798594E-5
# Model iJN1463.cmd: 5.665247323872394E-5
# Cycle 345
# Total biomass:
# Model iAF1260.cmd: 4.901324741284669E-5
# Model iJN1463.cmd: 5.6774484648043366E-5
# Cycle 346
# Total biomass:
# Model iAF1260.cmd: 4.9169031929716835E-5
# Model iJN1463.cmd: 5.6896157562433246E-5
# Cycle 347
# Total biomass:
# Model iAF1260.cmd: 4.932482920752215E-5
# Model iJN1463.cmd: 5.701738929458152E-5
# Cycle 348
# Total biomass:
# Model iAF1260.cmd: 4.948074637702107E-5
# Model iJN1463.cmd: 5.713828769883449E-5
# Cycle 349
# Total biomass:
# Model iAF1260.cmd: 4.9636734567056755E-5
# Model iJN1463.cmd: 5.725884348720863E-5
# Cycle 350
# Total biomass:
# Model iAF1260.cmd: 4.979254288442642E-5
# Model iJN1463.cmd: 5.737900870322737E-5
# Cycle 351
# Total biomass:
# Model iAF1260.cmd: 4.994816879310325E-5
# Model iJN1463.cmd: 5.749860340805051E-5
# Cycle 352
# Total biomass:
# Model iAF1260.cmd: 5.010380347314509E-5
# Model iJN1463.cmd: 5.761775836208494E-5
# Cycle 353
# Total biomass:
# Model iAF1260.cmd: 5.025946953270601E-5
# Model iJN1463.cmd: 5.77365142433736E-5
# Cycle 354
# Total biomass:
# Model iAF1260.cmd: 5.041360489054377E-5
# Model iJN1463.cmd: 5.7854482159134123E-5
# Cycle 355
# Total biomass:
# Model iAF1260.cmd: 5.056353677216763E-5
# Model iJN1463.cmd: 5.796919689535492E-5
# Cycle 356
# Total biomass:
# Model iAF1260.cmd: 5.071358066234456E-5
# Model iJN1463.cmd: 5.8082869581606806E-5
# Cycle 357
# Total biomass:
# Model iAF1260.cmd: 5.0863657807596965E-5
# Model iJN1463.cmd: 5.8195928055465336E-5
# Cycle 358
# Total biomass:
# Model iAF1260.cmd: 5.101377465968535E-5
# Model iJN1463.cmd: 5.830854120221433E-5
# Cycle 359
# Total biomass:
# Model iAF1260.cmd: 5.1163912166595923E-5
# Model iJN1463.cmd: 5.8420755193659736E-5
# Cycle 360
# Total biomass:
# Model iAF1260.cmd: 5.131407251648587E-5
# Model iJN1463.cmd: 5.853258476348252E-5
# Cycle 361
# Total biomass:
# Model iAF1260.cmd: 5.145412370424916E-5
# Model iJN1463.cmd: 5.865255325743828E-5
# Cycle 362
# Total biomass:
# Model iAF1260.cmd: 5.160373242497379E-5
# Model iJN1463.cmd: 5.8764190273110956E-5
# Cycle 363
# Total biomass:
# Model iAF1260.cmd: 5.1753737440439094E-5
# Model iJN1463.cmd: 5.8875010062257784E-5
# Cycle 364
# Total biomass:
# Model iAF1260.cmd: 5.190381495326159E-5
# Model iJN1463.cmd: 5.898531957365746E-5
# Cycle 365
# Total biomass:
# Model iAF1260.cmd: 5.2053865970118555E-5
# Model iJN1463.cmd: 5.9095222603916876E-5
# Cycle 366
# Total biomass:
# Model iAF1260.cmd: 5.2203883197384315E-5
# Model iJN1463.cmd: 5.920473984048136E-5
# Cycle 367
# Total biomass:
# Model iAF1260.cmd: 5.235385208580087E-5
# Model iJN1463.cmd: 5.931389906609167E-5
# Cycle 368
# Total biomass:
# Model iAF1260.cmd: 5.250379272918974E-5
# Model iJN1463.cmd: 5.942268235534029E-5
# Cycle 369
# Total biomass:
# Model iAF1260.cmd: 5.265365089254534E-5
# Model iJN1463.cmd: 5.953111999186544E-5
# Cycle 370
# Total biomass:
# Model iAF1260.cmd: 5.280342956586409E-5
# Model iJN1463.cmd: 5.963922028987388E-5
# Cycle 371
# Total biomass:
# Model iAF1260.cmd: 5.2953120025695606E-5
# Model iJN1463.cmd: 5.974698581847769E-5
# Cycle 372
# Total biomass:
# Model iAF1260.cmd: 5.3102711627596085E-5
# Model iJN1463.cmd: 5.985441835644363E-5
# Cycle 373
# Total biomass:
# Model iAF1260.cmd: 5.325220382557949E-5
# Model iJN1463.cmd: 5.996152229792072E-5
# Cycle 374
# Total biomass:
# Model iAF1260.cmd: 5.340159014254146E-5
# Model iJN1463.cmd: 6.0068304794452015E-5
# Cycle 375
# Total biomass:
# Model iAF1260.cmd: 5.355086594685304E-5
# Model iJN1463.cmd: 6.017476634273843E-5
# Cycle 376
# Total biomass:
# Model iAF1260.cmd: 5.370002855359924E-5
# Model iJN1463.cmd: 6.028090517992386E-5
# Cycle 377
# Total biomass:
# Model iAF1260.cmd: 5.384907612053003E-5
# Model iJN1463.cmd: 6.0386720531054235E-5
# Cycle 378
# ...
# Model iAF1260.cmd: 9.928671514895371E-5
# Model iJN1463.cmd: 8.481436572268193E-5
# Cycle 851
# Total biomass:
# Model iAF1260.cmd: 9.933593998396578E-5
# Model iJN1463.cmd: 8.482653085918962E-5
# Cycle 852
# Total biomass:
# Model iAF1260.cmd: 9.938503610462376E-5
# Model iJN1463.cmd: 8.483859173597226E-5
# Cycle 853
# Total biomass:
# Model iAF1260.cmd: 9.943400679690485E-5
# Model iJN1463.cmd: 8.485057284606097E-5
# Cycle 854
# Total biomass:
# Model iAF1260.cmd: 9.948295965979925E-5
# Model iJN1463.cmd: 8.486239927773318E-5
# Cycle 855
# Total biomass:
# Model iAF1260.cmd: 9.953171891583491E-5
# Model iJN1463.cmd: 8.48740458992275E-5
# Cycle 856
# Total biomass:
# Model iAF1260.cmd: 9.957536541404036E-5
# Model iJN1463.cmd: 8.488253408065496E-5
# Cycle 857
# Total biomass:
# Model iAF1260.cmd: 9.963588619109866E-5
# Model iJN1463.cmd: 8.489990161728235E-5
# Cycle 858
# Total biomass:
# Model iAF1260.cmd: 9.970188987762757E-5
# Model iJN1463.cmd: 8.492008462728473E-5
# Cycle 859
# Total biomass:
# Model iAF1260.cmd: 9.976122576195703E-5
# Model iJN1463.cmd: 8.493606462482946E-5
# Cycle 860
# Total biomass:
# Model iAF1260.cmd: 9.980751671578592E-5
# Model iJN1463.cmd: 8.494449329627418E-5
# Cycle 861
# Total biomass:
# Model iAF1260.cmd: 9.984754830466974E-5
# Model iJN1463.cmd: 8.495081324982403E-5
# Cycle 862
# Total biomass:
# Model iAF1260.cmd: 9.988899212368056E-5
# Model iJN1463.cmd: 8.49660652870508E-5
# Cycle 863
# Total biomass:
# Model iAF1260.cmd: 9.993619205024265E-5
# Model iJN1463.cmd: 8.497740225482169E-5
# Cycle 864
# Total biomass:
# Model iAF1260.cmd: 9.998383405563996E-5
# Model iJN1463.cmd: 8.498870048627004E-5
# Cycle 865
# Total biomass:
# Model iAF1260.cmd: 1.000313751836521E-4
# Model iJN1463.cmd: 8.499988088726664E-5
# Cycle 866
# Total biomass:
# Model iAF1260.cmd: 1.0007884895683829E-4
# Model iJN1463.cmd: 8.501099978520711E-5
# Cycle 867
# Total biomass:
# Model iAF1260.cmd: 1.0012631707799507E-4
# Model iJN1463.cmd: 8.502197077662433E-5
# Cycle 868
# Total biomass:
# Model iAF1260.cmd: 1.0017370223293733E-4
# Model iJN1463.cmd: 8.503266874724127E-5
# Cycle 869
# Total biomass:
# Model iAF1260.cmd: 1.0021965406036442E-4
# Model iJN1463.cmd: 8.504205121820523E-5
# Cycle 870
# Total biomass:
# Model iAF1260.cmd: 1.002616407737059E-4
# Model iJN1463.cmd: 8.50496351009192E-5
# Cycle 871
# Total biomass:
# Model iAF1260.cmd: 1.0029651012441937E-4
# Model iJN1463.cmd: 8.50621450000168E-5
# Cycle 872
# Total biomass:
# Model iAF1260.cmd: 1.0032887112671732E-4
# Model iJN1463.cmd: 8.508878517332005E-5
# Cycle 873
# Total biomass:
# Model iAF1260.cmd: 1.0037525987921172E-4
# Model iJN1463.cmd: 8.509982048618185E-5
# Cycle 874
# Total biomass:
# Model iAF1260.cmd: 1.0042096324186716E-4
# Model iJN1463.cmd: 8.510995844396887E-5
# Cycle 875
# Total biomass:
# Model iAF1260.cmd: 1.004664346802813E-4
# Model iJN1463.cmd: 8.511985334926042E-5
# Cycle 876
# Total biomass:
# Model iAF1260.cmd: 1.0051179072967739E-4
# Model iJN1463.cmd: 8.512964750331941E-5
# Cycle 877
# Total biomass:
# Model iAF1260.cmd: 1.0055667702060294E-4
# Model iJN1463.cmd: 8.513892565727412E-5
# Cycle 878
# Total biomass:
# Model iAF1260.cmd: 1.006023918005074E-4
# Model iJN1463.cmd: 8.5148375064942E-5
# Cycle 879
# Total biomass:
# Model iAF1260.cmd: 1.0063993847133433E-4
# Model iJN1463.cmd: 8.516243477694922E-5
# Cycle 880
# Total biomass:
# Model iAF1260.cmd: 1.0067262601350744E-4
# Model iJN1463.cmd: 8.518723965759073E-5
# Cycle 881
# Total biomass:
# Model iAF1260.cmd: 1.0071639673827953E-4
# Model iJN1463.cmd: 8.519570396381118E-5
# Cycle 882
# Total biomass:
# Model iAF1260.cmd: 1.0075295530431124E-4
# Model iJN1463.cmd: 8.520650540720583E-5
# Cycle 883
# Total biomass:
# Model iAF1260.cmd: 1.007915557399224E-4
# Model iJN1463.cmd: 8.521524241131096E-5
# Cycle 884
# Total biomass:
# Model iAF1260.cmd: 1.0083393916547398E-4
# Model iJN1463.cmd: 8.522318667588534E-5
# Cycle 885
# Total biomass:
# Model iAF1260.cmd: 1.0087999830266992E-4
# Model iJN1463.cmd: 8.523168358272437E-5
# Cycle 886
# Total biomass:
# Model iAF1260.cmd: 1.0092840793477192E-4
# Model iJN1463.cmd: 8.524121520074783E-5
# Cycle 887
# Total biomass:
# Model iAF1260.cmd: 1.0098950689512085E-4
# Model iJN1463.cmd: 8.525826439294233E-5
# Cycle 888
# Total biomass:
# Model iAF1260.cmd: 1.010549574564619E-4
# Model iJN1463.cmd: 8.527808548069643E-5
# Cycle 889
# Total biomass:
# Model iAF1260.cmd: 1.01121897479598E-4
# Model iJN1463.cmd: 8.529882466202348E-5
# Cycle 890
# Total biomass:
# Model iAF1260.cmd: 1.0118931478939706E-4
# Model iJN1463.cmd: 8.531984885209541E-5
# Cycle 891
# Total biomass:
# Model iAF1260.cmd: 1.0125686683470283E-4
# Model iJN1463.cmd: 8.534094455306557E-5
# Cycle 892
# Total biomass:
# Model iAF1260.cmd: 1.0132443265739415E-4
# Model iJN1463.cmd: 8.536204099114054E-5
# Cycle 893
# Total biomass:
# Model iAF1260.cmd: 1.0139197178578358E-4
# Model iJN1463.cmd: 8.5383115025274E-5
# Cycle 894
# Total biomass:
# Model iAF1260.cmd: 1.0145946985467961E-4
# Model iJN1463.cmd: 8.540415850480173E-5
# Cycle 895
# Total biomass:
# Model iAF1260.cmd: 1.0152692062749023E-4
# Model iJN1463.cmd: 8.542516839371092E-5
# Cycle 896
# Total biomass:
# Model iAF1260.cmd: 1.0159432886292232E-4
# Model iJN1463.cmd: 8.54461432592063E-5
# Cycle 897
# Total biomass:
# Model iAF1260.cmd: 1.0166168684184744E-4
# Model iJN1463.cmd: 8.54670830582132E-5
# Cycle 898
# Total biomass:
# Model iAF1260.cmd: 1.0172899449173156E-4
# Model iJN1463.cmd: 8.548798767309445E-5
# Cycle 899
# Total biomass:
# Model iAF1260.cmd: 1.0179625181053034E-4
# Model iJN1463.cmd: 8.550885710431716E-5
# Cycle 900
# Total biomass:
# Model iAF1260.cmd: 1.0186346102977163E-4
# Model iJN1463.cmd: 8.552969137786747E-5
# Cycle 901
# Total biomass:
# Model iAF1260.cmd: 1.0193061976679542E-4
# Model iJN1463.cmd: 8.55504907550489E-5
# Cycle 902
# Total biomass:
# Model iAF1260.cmd: 1.0199772837427002E-4
# Model iJN1463.cmd: 8.557125519020962E-5
# Cycle 903
# Total biomass:
# Model iAF1260.cmd: 1.0206478667525126E-4
# Model iJN1463.cmd: 8.559198473654029E-5
# Cycle 904
# Total biomass:
# Model iAF1260.cmd: 1.0213179470096076E-4
# Model iJN1463.cmd: 8.56126795122036E-5
# Cycle 905
# Total biomass:
# Model iAF1260.cmd: 1.0219875261248424E-4
# Model iJN1463.cmd: 8.563333955777191E-5
# Cycle 906
# Total biomass:
# Model iAF1260.cmd: 1.0226566015419635E-4
# Model iJN1463.cmd: 8.565396490323155E-5
# Cycle 907
# Total biomass:
# Model iAF1260.cmd: 1.023325175080923E-4
# Model iJN1463.cmd: 8.567455553367003E-5
# Cycle 908
# Total biomass:
# Model iAF1260.cmd: 1.0239932460973362E-4
# Model iJN1463.cmd: 8.569511153576157E-5
# Cycle 909
# Total biomass:
# Model iAF1260.cmd: 1.0246608165821436E-4
# Model iJN1463.cmd: 8.571563296839837E-5
# Cycle 910
# Total biomass:
# Model iAF1260.cmd: 1.02532789034162E-4
# Model iJN1463.cmd: 8.573611979097104E-5
# Cycle 911
# Total biomass:
# Model iAF1260.cmd: 1.0259944579864035E-4
# Model iJN1463.cmd: 8.575657214802513E-5
# Cycle 912
# Total biomass:
# Model iAF1260.cmd: 1.0266605287048789E-4
# Model iJN1463.cmd: 8.577698997775414E-5
# Cycle 913
# Total biomass:
# Model iAF1260.cmd: 1.0273260966327195E-4
# Model iJN1463.cmd: 8.579737331132515E-5
# Cycle 914
# Total biomass:
# Model iAF1260.cmd: 1.0279911640510164E-4
# Model iJN1463.cmd: 8.581772230299844E-5
# Cycle 915
# Total biomass:
# Model iAF1260.cmd: 1.0286557297286554E-4
# Model iJN1463.cmd: 8.583803685817728E-5
# Cycle 916
# Total biomass:
# Model iAF1260.cmd: 1.0293197949954768E-4
# Model iJN1463.cmd: 8.585831703664228E-5
# Cycle 917
# Total biomass:
# Model iAF1260.cmd: 1.0299833607076446E-4
# Model iJN1463.cmd: 8.58785628393618E-5
# Cycle 918
# Total biomass:
# Model iAF1260.cmd: 1.0306464230950455E-4
# Model iJN1463.cmd: 8.589877430336617E-5
# Cycle 919
# Total biomass:
# Model iAF1260.cmd: 1.0313089903022823E-4
# Model iJN1463.cmd: 8.59189514094662E-5
# Cycle 920
# Total biomass:
# Model iAF1260.cmd: 1.0319710537124367E-4
# Model iJN1463.cmd: 8.593909427284417E-5
# Cycle 921
# Total biomass:
# Model iAF1260.cmd: 1.0326331730428863E-4
# Model iJN1463.cmd: 8.595920323321851E-5
# Cycle 922
# Total biomass:
# Model iAF1260.cmd: 1.0332947926863594E-4
# Model iJN1463.cmd: 8.597927796891714E-5
# Cycle 923
# Total biomass:
# Model iAF1260.cmd: 1.0339559106512231E-4
# Model iJN1463.cmd: 8.599931863621004E-5
# Cycle 924
# Total biomass:
# Model iAF1260.cmd: 1.0346165322671503E-4
# Model iJN1463.cmd: 8.601932512234044E-5
# Cycle 925
# Total biomass:
# Model iAF1260.cmd: 1.0352766767293353E-4
# Model iJN1463.cmd: 8.603929747223202E-5
# Cycle 926
# Total biomass:
# Model iAF1260.cmd: 1.0359368429449838E-4
# Model iJN1463.cmd: 8.605923567871203E-5
# Cycle 927
# Total biomass:
# Model iAF1260.cmd: 1.0365965103215887E-4
# Model iJN1463.cmd: 8.607913981870787E-5
# Cycle 928
# Total biomass:
# Model iAF1260.cmd: 1.0372557002431535E-4
# Model iJN1463.cmd: 8.609900993340741E-5
# Cycle 929
# Total biomass:
# Model iAF1260.cmd: 1.037914366921544E-4
# Model iJN1463.cmd: 8.611884612349388E-5
# Cycle 930
# Total biomass:
# Model iAF1260.cmd: 1.0385725590864412E-4
# Model iJN1463.cmd: 8.613864833399883E-5
# Cycle 931
# Total biomass:
# Model iAF1260.cmd: 1.0392302270824068E-4
# Model iJN1463.cmd: 8.615841666950415E-5
# Cycle 932
# Total biomass:
# Model iAF1260.cmd: 1.039887418187837E-4
# Model iJN1463.cmd: 8.617815109564878E-5
# Cycle 933
# Total biomass:
# Model iAF1260.cmd: 1.0405441096051264E-4
# Model iJN1463.cmd: 8.619785166522864E-5
# Cycle 934
# Total biomass:
# Model iAF1260.cmd: 1.0412002788063512E-4
# Model iJN1463.cmd: 8.621751840095314E-5
# Cycle 935
# Total biomass:
# Model iAF1260.cmd: 1.0418559713472585E-4
# Model iJN1463.cmd: 8.623715129117187E-5
# Cycle 936
# Total biomass:
# Model iAF1260.cmd: 1.0425111663800857E-4
# Model iJN1463.cmd: 8.625675034332335E-5
# Cycle 937
# Total biomass:
# Model iAF1260.cmd: 1.0431658605444467E-4
# Model iJN1463.cmd: 8.627631566125705E-5
# Cycle 938
# Total biomass:
# Model iAF1260.cmd: 1.0438201474961039E-4
# Model iJN1463.cmd: 8.629584723257373E-5
# Cycle 939
# Total biomass:
# Model iAF1260.cmd: 1.0444738444620867E-4
# Model iJN1463.cmd: 8.631534563051878E-5
# Cycle 940
# Total biomass:
# Model iAF1260.cmd: 1.0451271306887342E-4
# Model iJN1463.cmd: 8.633481014388426E-5
# Cycle 941
# Total biomass:
# Model iAF1260.cmd: 1.0457799175569836E-4
# Model iJN1463.cmd: 8.635424121415304E-5
# Cycle 942
# Total biomass:
# Model iAF1260.cmd: 1.0464322072308894E-4
# Model iJN1463.cmd: 8.637363869551688E-5
# Cycle 943
# Total biomass:
# Model iAF1260.cmd: 1.0470839952355031E-4
# Model iJN1463.cmd: 8.639300292122789E-5
# Cycle 944
# Total biomass:
# Model iAF1260.cmd: 1.0477352830249455E-4
# Model iJN1463.cmd: 8.641233388862761E-5
# Cycle 945
# Total biomass:
# Model iAF1260.cmd: 1.0483860720509634E-4
# Model iJN1463.cmd: 8.643163165195858E-5
# Cycle 946
# Total biomass:
# Model iAF1260.cmd: 1.0490363601862044E-4
# Model iJN1463.cmd: 8.64508961163393E-5
# Cycle 947
# Total biomass:
# Model iAF1260.cmd: 1.0496861487687411E-4
# Model iJN1463.cmd: 8.647012728219455E-5
# Cycle 948
# Total biomass:
# Model iAF1260.cmd: 1.0503354397153983E-4
# Model iJN1463.cmd: 8.648932519458216E-5
# Cycle 949
# Total biomass:
# Model iAF1260.cmd: 1.0509847587102942E-4
# Model iJN1463.cmd: 8.650848987585713E-5
# Cycle 950
# Total biomass:
# Model iAF1260.cmd: 1.0516335790671437E-4
# Model iJN1463.cmd: 8.652762134494554E-5
# Cycle 951
# Total biomass:
# Model iAF1260.cmd: 1.0522819036602137E-4
# Model iJN1463.cmd: 8.654671960138516E-5
# Cycle 952
# Total biomass:
# Model iAF1260.cmd: 1.0529297262419716E-4
# Model iJN1463.cmd: 8.656578469135235E-5
# Cycle 953
# Total biomass:
# Model iAF1260.cmd: 1.0535770523533831E-4
# Model iJN1463.cmd: 8.658481661357098E-5
# Cycle 954
# Total biomass:
# Model iAF1260.cmd: 1.0542238809515152E-4
# Model iJN1463.cmd: 8.660381542906146E-5
# Cycle 955
# Total biomass:
# Model iAF1260.cmd: 1.0548702088163254E-4
# Model iJN1463.cmd: 8.662278115668809E-5
# Cycle 956
# Total biomass:
# Model iAF1260.cmd: 1.0555160388887034E-4
# Model iJN1463.cmd: 8.664171378591641E-5
# Cycle 957
# Total biomass:
# Model iAF1260.cmd: 1.0561613725043946E-4
# Model iJN1463.cmd: 8.666061334123582E-5
# Cycle 958
# Total biomass:
# Model iAF1260.cmd: 1.0568062085743247E-4
# Model iJN1463.cmd: 8.667947985534497E-5
# Cycle 959
# Total biomass:
# Model iAF1260.cmd: 1.0574505495003927E-4
# Model iJN1463.cmd: 8.669831334977907E-5
# Cycle 960
# Total biomass:
# Model iAF1260.cmd: 1.0580943929619575E-4
# Model iJN1463.cmd: 8.671711384544187E-5
# Cycle 961
# Total biomass:
# Model iAF1260.cmd: 1.0587377387346208E-4
# Model iJN1463.cmd: 8.673588156544337E-5
# Cycle 962
# Total biomass:
# Model iAF1260.cmd: 1.0593805885689476E-4
# Model iJN1463.cmd: 8.675461641884311E-5
# Cycle 963
# Total biomass:
# Model iAF1260.cmd: 1.0600229427260903E-4
# Model iJN1463.cmd: 8.677331842892664E-5
# Cycle 964
# Total biomass:
# Model iAF1260.cmd: 1.060664800131898E-4
# Model iJN1463.cmd: 8.679198755419843E-5
# Cycle 965
# Total biomass:
# Model iAF1260.cmd: 1.0613061610878087E-4
# Model iJN1463.cmd: 8.681062388018398E-5
# Cycle 966
# Total biomass:
# Model iAF1260.cmd: 1.0619470253453808E-4
# Model iJN1463.cmd: 8.682922746964808E-5
# Cycle 967
# Total biomass:
# Model iAF1260.cmd: 1.0625874078274238E-4
# Model iJN1463.cmd: 8.684779926518976E-5
# Cycle 968
# Total biomass:
# Model iAF1260.cmd: 1.0632273216149243E-4
# Model iJN1463.cmd: 8.68663400343546E-5
# Cycle 969
# Total biomass:
# Model iAF1260.cmd: 1.0638667605467781E-4
# Model iJN1463.cmd: 8.688484926134428E-5
# Cycle 970
# Total biomass:
# Model iAF1260.cmd: 1.0645057192267803E-4
# Model iJN1463.cmd: 8.690332674330345E-5
# Cycle 971
# Total biomass:
# Model iAF1260.cmd: 1.0651442013605366E-4
# Model iJN1463.cmd: 8.692177258757905E-5
# Cycle 972
# Total biomass:
# Model iAF1260.cmd: 1.0657822020460663E-4
# Model iJN1463.cmd: 8.694018677371934E-5
# Cycle 973
# Total biomass:
# Model iAF1260.cmd: 1.0664197233124304E-4
# Model iJN1463.cmd: 8.695856932356991E-5
# Cycle 974
# Total biomass:
# Model iAF1260.cmd: 1.0670567644963738E-4
# Model iJN1463.cmd: 8.69769200752583E-5
# Cycle 975
# Total biomass:
# Model iAF1260.cmd: 1.067693326961421E-4
# Model iJN1463.cmd: 8.699523903506961E-5
# Cycle 976
# Total biomass:
# Model iAF1260.cmd: 1.0683294065619941E-4
# Model iJN1463.cmd: 8.70135262695246E-5
# Cycle 977
# Total biomass:
# Model iAF1260.cmd: 1.0689650070835198E-4
# Model iJN1463.cmd: 8.7031781897238E-5
# Cycle 978
# Total biomass:
# Model iAF1260.cmd: 1.0696003884804934E-4
# Model iJN1463.cmd: 8.705000589347053E-5
# Cycle 979
# Total biomass:
# Model iAF1260.cmd: 1.0702352907887256E-4
# Model iJN1463.cmd: 8.706819855319137E-5
# Cycle 980
# Total biomass:
# Model iAF1260.cmd: 1.070869888126256E-4
# Model iJN1463.cmd: 8.708635966769373E-5
# Cycle 981
# Total biomass:
# Model iAF1260.cmd: 1.0715040102045292E-4
# Model iJN1463.cmd: 8.71044893332762E-5
# Cycle 982
# Total biomass:
# Model iAF1260.cmd: 1.0721376593397106E-4
# Model iJN1463.cmd: 8.712258756794983E-5
# Cycle 983
# Total biomass:
# Model iAF1260.cmd: 1.0727708419594084E-4
# Model iJN1463.cmd: 8.714065476501445E-5
# Cycle 984
# Total biomass:
# Model iAF1260.cmd: 1.0734035735669908E-4
# Model iJN1463.cmd: 8.715869187470229E-5
# Cycle 985
# Total biomass:
# Model iAF1260.cmd: 1.0740358776892324E-4
# Model iJN1463.cmd: 8.717670032613189E-5
# Cycle 986
# Total biomass:
# Model iAF1260.cmd: 1.0746677564999107E-4
# Model iJN1463.cmd: 8.719468034932024E-5
# Cycle 987
# Total biomass:
# Model iAF1260.cmd: 1.0752992106213649E-4
# Model iJN1463.cmd: 8.721263184413141E-5
# Cycle 988
# Total biomass:
# Model iAF1260.cmd: 1.0759302413354336E-4
# Model iJN1463.cmd: 8.723055492038631E-5
# Cycle 989
# Total biomass:
# Model iAF1260.cmd: 1.0765608473940481E-4
# Model iJN1463.cmd: 8.724844956634056E-5
# Cycle 990
# Total biomass:
# Model iAF1260.cmd: 1.0771910259948043E-4
# Model iJN1463.cmd: 8.726631574472076E-5
# Cycle 991
# Total biomass:
# Model iAF1260.cmd: 1.0778207806852951E-4
# Model iJN1463.cmd: 8.728415359443834E-5
# Cycle 992
# Total biomass:
# Model iAF1260.cmd: 1.0784501096395148E-4
# Model iJN1463.cmd: 8.73019631342547E-5
# Cycle 993
# Total biomass:
# Model iAF1260.cmd: 1.0790790140355393E-4
# Model iJN1463.cmd: 8.73197443347129E-5
# Cycle 994
# Total biomass:
# Model iAF1260.cmd: 1.0797079945426295E-4
# Model iJN1463.cmd: 8.733749721602731E-5
# Cycle 995
# Total biomass:
# Model iAF1260.cmd: 1.080336551213205E-4
# Model iJN1463.cmd: 8.735522180997816E-5
# Cycle 996
# Total biomass:
# Model iAF1260.cmd: 1.0809646807054446E-4
# Model iJN1463.cmd: 8.737291814028466E-5
# Cycle 997
# Total biomass:
# Model iAF1260.cmd: 1.0815926348039042E-4
# Model iJN1463.cmd: 8.739058635563617E-5
# Cycle 998
# Total biomass:
# Model iAF1260.cmd: 1.0822201647828031E-4
# Model iJN1463.cmd: 8.740822645920958E-5
# Cycle 999
# Total biomass:
# Model iAF1260.cmd: 1.0828472698658316E-4
# Model iJN1463.cmd: 8.742583837735735E-5
# Cycle 1000
# Total biomass:
# Model iAF1260.cmd: 1.0834739518500837E-4
# Model iJN1463.cmd: 8.744342235473179E-5
# Cycle 1001
# End of simulation
# Total time = 14969.244s
#
# STDERR empty.

# %% [markdown]
# Para revisar la biomasa total

# %%
sim.total_biomass.plot(x = "cycle")
# Out:
# <AxesSubplot:xlabel='cycle'>

# %% [markdown]
# Graficamos los resultados de biomasa y demás metabolitos interesantes en el grid:

# %%
im = sim.get_biomass_image('iAF1260', params.all_params['maxCycles'])
im2 = sim.get_biomass_image('iJN1463',params.all_params['maxCycles'])

final = np.zeros((grid_size,grid_size,3))
final[:,:,0] = im / np.max(im)
final[:,:,1] = im2 / np.max(im2)
for rock in rock_locs:
    final[rock[0],rock[1],0:3] = 0.4 
from matplotlib import pyplot as plt
ﬁg, ax = plt.subplots(ﬁgsize = (3.1, 3.1))
ax.imshow(ﬁnal)
plt.imshow(final)

# %%
plt.imshow(sim.get_metabolite_image("succ_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("ac_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("nh4_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("o2_e",params.all_params['maxCycles']))
