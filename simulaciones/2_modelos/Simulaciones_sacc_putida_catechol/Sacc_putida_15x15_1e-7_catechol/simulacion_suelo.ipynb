# %% [markdown]
# **Soil-air interface.**
#
# Using the functionality of COMETS, one can design simulations which go beyond in silico corollaries of lab experiments to make predictions for environments mimicking natural ecosystems, which is a necessary step for understanding natural ecology from first principles. In this example, we consider a simulation of a soil environment. We use source-and-sink functions to model how a root provides organic acids to the environment while removing ammonia (Huang et al 2014 Botany). While we restrict the root functionality to a source/sink, one could use functionality demonstrated above, for example extracellular enzymes, to generate feedback loops between microbe-produced metabolites and root exudation. We use fixed metabolite concentrations to mimic the largely unchanging air interface above a root, which generates an oxygen gradient. Additionally, since soil is characterized by strong spatial structure with many impenetrable barriers that localized interactions (Nunan 2017), we place “rock” barriers throughout the simulation area. A more complex simulation could use varying diffusion constants for metabolites, as described in a previous protocol (Virtual Petri Dish). Similarly, we use standard diffusion of biomass, but this could be changed to use pushing force or non-linear diffusion for a potentially increased realism.

# %%
import cobra 
import sys 
import copy 
import numpy as np 
from matplotlib import pyplot as plt 
import cometspy as c

# %% [markdown]
# Para nuestro proyecto, utilizaremos Escherichia coli (modelo iAF1260), Pseudomonas putida (modelo iJN1463) y Saccharomyces Cerevisiae (modelo iMM904), recuperados de la base de datos BIGG.
#
# Cambiamos los bounds de las funciones objetivo de los modelos:

# %%
model_dir = "./modelos" # model location
iMM = cobra.io.read_sbml_model(model_dir + '/iMM904.xml')
iJN = cobra.io.read_sbml_model(model_dir + '/iJN1463.xml')

iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').lower_bound = 0
iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').upper_bound = 1000

iMM.reactions.get_by_id('BIOMASS_SC5_notrace').lower_bound = 0
iMM.reactions.get_by_id('BIOMASS_SC5_notrace').upper_bound = 1000

# %% [markdown]
# Luego se convierten estos modelos al formato de COMETS. Se utilizan funciones helper para dos cosas: a) Asegurar que el modelo en COMETS no confunda las reacciones de "sink" con las de exchange, ya que en COBRA están desbalanceadas y por tanto se parecen a las de exchange, y b) abrir todos los bounds de las reacciones de exchange, para que COMETS controle la composición del medio.

# %%
iMM_comets = c.model(iMM)
iMM_comets.ensure_sinks_are_not_exchanges()
iMM_comets.open_exchanges()

iJN_comets = c.model(iJN)
iJN_comets.ensure_sinks_are_not_exchanges()
iJN_comets.open_exchanges()

# %% [markdown]
# El mundo que se simulará tendrá dimensiones de 30x30. El eje de la izquierda (x = 0) corresponde a la raíz, y el eje superior (y = 0) corresponde al aire. La biomasa y las rocas se distribuyen en el resto del grid. Donde hayan rocas no puede haber ni biomasa ni metabolitos, así que seleccionamos esos lugares primero. Para esta simulación, se generarán 3 rocas con un un tamaño medio de 1 cuadraditos. Para generar las piedras se utiliza la función helper grow_rocks.

# %%
from cometspy.utils import grow_rocks, pick_random_locations

grid_size = 15 # 100
n_rocks = 27 # 70
rock_locs = grow_rocks(n = n_rocks, xrange = [1,grid_size-1],yrange = [1,grid_size-1],mean_size = 1)

# %% [markdown]
# Cada especie será plantada en 20 lugares sin sobreponerse. Para esto se utiliza la función helper pick_random_locations, la cual toma como argumento una tupla generada anteriormente que marca lugares "prohibidos", como los cuadrados donde se encuentran las rocas.
#
# Generamos una copia de rock_locs para no cambiarla accidentalmente, y la llamamos forbbiden_locs:

# %%
import copy
forbidden_locs = copy.deepcopy(rock_locs)

# %% [markdown]
# Ahora elegimos al azar los lugares para cada especie, y los vamos añadiendo a la lista forbidden locs para que no se sobrepongan:

# %%
founders_per_species = 15 # 60
iMM_locs = pick_random_locations(n = founders_per_species, 
                                   xrange = [1,grid_size], yrange = [1,grid_size], 
                                   forbidden_locs = forbidden_locs)
forbidden_locs.extend(iMM_locs)
iJN_locs = pick_random_locations(founders_per_species, [1,grid_size],[1,grid_size], forbidden_locs)

# %% [markdown]
# Para graficar los lugares utilizamos matplotlib:

# %%
from matplotlib import pyplot as plt
initial_image = np.zeros((grid_size,grid_size,3))
for rock in rock_locs:
    initial_image[rock[0],rock[1],0:3] = 0.5 
for loc in iMM_locs:
    initial_image[loc[0],loc[1],1] = 1
for loc in iJN_locs:
    initial_image[loc[0],loc[1],2] = 1
plt.imshow(initial_image)

# %% [markdown]
# Generamos el layout y agregamos las rocas:

# %%
# iMM
iMM_initial_pop = [] 
for loc in iJN_locs: 
    iMM_initial_pop.append([loc[0], loc[1], 1.e-8]) 
iMM_comets.initial_pop = iMM_initial_pop 
# iJN
iJN_initial_pop = [] 
for loc in iJN_locs: 
    iJN_initial_pop.append([loc[0], loc[1], 1.e-8]) 
iJN_comets.initial_pop = iJN_initial_pop

# %% [markdown]
# Setteamos las poblaciones iniciales para cada especie, con esto los modelos están listos y los añadimos al layout:

# %%
layout = c.layout([iMM_comets, iJN_comets])
layout.grid = [grid_size,grid_size]
layout.add_barriers(rock_locs)

# %% [markdown]
# Añadimos los metabolitos que estarán inicialmente disponibles en el ambiente. Usamos la función helper add_typical_trace_metabolites() para las trazas típicas. Bajamos el valor del oxígeno dado que la idea es que el que esté disponible difunda desde la atmósfera. Añadimos algunos metabolitos que no se añadieron con la función helper:

# %%
layout.add_typical_trace_metabolites()
layout.set_specific_metabolite('o2_e',0.000001)
layout.set_specific_metabolite('hco3_e',1000)
layout.set_specific_metabolite('co2_e',1000)
#layout.set_specific_metabolite('h2_e',1000)
layout.set_specific_metabolite('so3_e',1000)
layout.set_specific_metabolite('nh4_e',0.0000001)

layout.set_specific_metabolite('glc__D_e',0.0000001)
layout.set_specific_metabolite('meoh_e',0.00000001)
layout.set_specific_metabolite('cys__L_e',0.0000001)
layout.set_specific_metabolite('catechol_e',0.0000001)

# %% [markdown]
# Para la capa de aire, dejamos el oxígeno en un valor constante. Al fondo también dejamos al oxígeno en un valor fijo e igual a 0, para simular el efecto de difusión. De manera similar, hacemos lo mismo con el amoniaco y la raíz en la parte izquierda:

# %%
# set static media of O2 and CO2 at the top and bottom-- the "air" and continuous loss of O2 downwards
for x in range(grid_size):
    layout.set_specific_static_at_location('o2_e', (x,0), .0001) # top
    layout.set_specific_static_at_location('o2_e', (x,grid_size-1), 0.) # bottom
    layout.set_specific_static_at_location('co2_e', (x,0), .0001)
    
for x in range(grid_size):
    layout.set_specific_static_at_location('nh4_e', (0,x), 0.0)

# %% [markdown]
# La raíz consume todo el amoniaco, pero es una fuente de acidos orgánicos y metanol para el ambiente. Asumiendo una tasa fija:

# %%
for x in range(grid_size):
    layout.set_specific_refresh_at_location('cit_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('meoh_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('succ_e', (0,x), .000001)

# %% [markdown]
# El layout y los modelos están listos, ahora setteamos los parámetros de la simulación:

# %%
params = c.params()
params.set_param('timeStep', 0.1)
params.set_param('maxCycles', 1000)
params.set_param('maxSpaceBiomass', 10)
params.set_param('deathRate', 0.0001) # die at rate of 1/10000 per hour
params.set_param('writeBiomassLog', True)
params.set_param('BiomassLogRate', 500)
params.set_param('writeMediaLog', True)
params.set_param('MediaLogRate', 500)
params.set_param("writeFluxLog", True)
params.set_param("FluxLogRate", 500)
params.set_param('numRunThreads', 3)
params.set_param('defaultKm', 0.000001)

# %% [markdown]
# Ahora creamos el objeto de la simulación y la corremos. Ojito que se demora y el pc empieza a despegar.

# %%
sim = c.comets(layout, params)
sim.run(False)
# Out:
# Running COMETS simulation ...
# C:\Users\mfran\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3357: DtypeWarning: Columns (13,15,16,17,18,24,59,60,61,86,95,96,98,104,108,110,116,124,139,140,142,147,153,162,163,171,177,187,196,198,199,214,228,232,234,236,245,248,249,256,257,295,306,311,312,315,324,325,326,327,328,334,344,346,348,351,376,378,402,406,408,409,414,422,430,431,434,435,441,442,444,449,454,455,469,470,478,511,512,525,533,541,546,551,563,571,651,652,660,662,665,676,692,693,702,716,718,719,722,726,727,735,736,738,763,765,771,793,794,804,806,847,866,897,913,930,936,940,943,953,961,962,966,979,982,986,1006,1016,1018,1022,1036,1040,1061,1065,1071,1072,1078,1080,1081,1089,1090,1093,1095,1111,1112,1126,1128,1130,1149,1164,1165,1166,1201,1205,1211,1216,1217,1221,1222,1227,1262,1278,1280,1299,1304,1307,1312,1332,1333,1334,1347,1354,1355,1359,1365,1370,1403,1405,1406,1422,1432,1439,1470,1472,1481,1484,1491,1506,1509,1514,1534,1539,1543,1549,1558,1570,1572,1588,1589,1590,1617,1629,1632,1645,1655,1666,1680,1692,1693,1697,1698,1700,1702,1704,1706,1734,1764,1765,1772,1797,1811,1856,1871,1890,1891,1892,1905,1907,1909,1910,1912,1914,1916,1917,1918,1933,1934,1939,1940,1947,1948,1953,1954,1955,1956,1957,1958,1968,1985,1987,1988,1991,1992,1997,1998,2000,2002,2004,2005,2006,2007,2008,2011,2012,2037,2043,2055,2086,2100,2108,2109,2133,2134,2200,2202,2206,2225,2227,2231,2249,2254,2256,2279,2283,2306,2310,2313,2315,2316,2322,2355,2362,2371,2373,2374,2398,2399,2401,2402,2414,2416,2418,2426,2432,2471,2473,2474,2476,2477,2478,2479,2480,2524,2525,2526,2527,2532,2534,2601,2609,2621,2639,2670,2680,2683,2684,2714,2715,2719,2720,2723,2727,2764,2765,2804,2817,2819,2821,2852,2857,2884,2909,2910,2916,2918,2919,2930) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Done!

# %%
print(sim.run_output)
print(sim.run_errors)
# Out:
# -script
# running script file: C:\Users\mfran\OneDrive\Escritorio\Proyecto opti simulaciones\ODRM\simulaciones\2_modelos\Coli_putida_15x15_1e-8_catechol - copia/.current_script_0x1d8ce989250
# Current Java version: 17.0.1
# Parameters file .current_global_0x1d8ce989250 loaded.
# Parameters file .current_package_0x1d8ce989250 loaded.
# Loading layout file '.current_layout_0x1d8ce989250'...
# null\COMETS_manifest.txt (El sistema no puede encontrar la ruta especificada)
# Unable to initialize manifest file.
# Continuing without writing manifest file.
# Found 2 model files!
# Loading '.\iMM904.cmd' ...
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution =
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# FBARunThread-0 starting up.
# FBARunThread-1 starting up.
# FBARunThread-2 starting up.
# Total biomass:
# Model iMM904.cmd: 1.5752702072302714E-7
# Model iJN1463.cmd: 1.574579687004808E-7
# Cycle 2
# Total biomass:
# Model iMM904.cmd: 1.6544812206054714E-7
# Model iJN1463.cmd: 1.6530633124038757E-7
# Cycle 3
# Total biomass:
# Model iMM904.cmd: 1.744315122455952E-7
# Model iJN1463.cmd: 1.7411855319443998E-7
# Cycle 4
# Total biomass:
# Model iMM904.cmd: 1.8418102403795775E-7
# Model iJN1463.cmd: 1.8363597377200338E-7
# Cycle 5
# Total biomass:
# Model iMM904.cmd: 1.9473507642207092E-7
# Model iJN1463.cmd: 1.93896960155828E-7
# Cycle 6
# Total biomass:
# Model iMM904.cmd: 2.0610137378307026E-7
# Model iJN1463.cmd: 2.0490125846371502E-7
# Cycle 7
# Total biomass:
# Model iMM904.cmd: 2.1828292065887937E-7
# Model iJN1463.cmd: 2.1665423865569196E-7
# Cycle 8
# Total biomass:
# Model iMM904.cmd: 2.3132149140157582E-7
# Model iJN1463.cmd: 2.2919783177520766E-7
# Cycle 9
# Total biomass:
# Model iMM904.cmd: 2.452601898948148E-7
# Model iJN1463.cmd: 2.425731909136009E-7
# Cycle 10
# Total biomass:
# Model iMM904.cmd: 2.601536420084259E-7
# Model iJN1463.cmd: 2.568166938395395E-7
# Cycle 11
# Total biomass:
# Model iMM904.cmd: 2.760587871849805E-7
# Model iJN1463.cmd: 2.7196773154524415E-7
# Cycle 12
# Total biomass:
# Model iMM904.cmd: 2.9302807131242055E-7
# Model iJN1463.cmd: 2.8806398698924756E-7
# Cycle 13
# Total biomass:
# Model iMM904.cmd: 3.1112245040340483E-7
# Model iJN1463.cmd: 3.051607801299743E-7
# Cycle 14
# Total biomass:
# Model iMM904.cmd: 3.304066298277655E-7
# Model iJN1463.cmd: 3.2331596805990397E-7
# Cycle 15
# Total biomass:
# Model iMM904.cmd: 3.509420768542761E-7
# Model iJN1463.cmd: 3.4258793254053377E-7
# Cycle 16
# Total biomass:
# Model iMM904.cmd: 3.7279265947141243E-7
# Model iJN1463.cmd: 3.630380392509195E-7
# Cycle 17
# Total biomass:
# Model iMM904.cmd: 3.9603930843082406E-7
# Model iJN1463.cmd: 3.847366603616934E-7
# Cycle 18
# Total biomass:
# Model iMM904.cmd: 4.2076850210282175E-7
# Model iJN1463.cmd: 4.07758499301719E-7
# Cycle 19
# Total biomass:
# Model iMM904.cmd: 4.470716737299043E-7
# Model iJN1463.cmd: 4.321825556356007E-7
# Cycle 20
# Total biomass:
# Model iMM904.cmd: 4.744238205547148E-7
# Model iJN1463.cmd: 4.580039804172929E-7
# Cycle 21
# Total biomass:
# Model iMM904.cmd: 5.023386432576916E-7
# Model iJN1463.cmd: 4.852289706579471E-7
# Cycle 22
# Total biomass:
# Model iMM904.cmd: 5.308007925285062E-7
# Model iJN1463.cmd: 5.13934434592157E-7
# Cycle 23
# Total biomass:
# Model iMM904.cmd: 5.598766520224354E-7
# Model iJN1463.cmd: 6.360184521969511E-6
# Cycle 71
# Total biomass:
# Model iMM904.cmd: 3.0332073673575667E-6
# Model iJN1463.cmd: 6.6681427899095015E-6
# Cycle 72
# Total biomass:
# Model iMM904.cmd: 3.1220630927950235E-6
# Model iJN1463.cmd: 6.9885808061941894E-6
# Cycle 73
# Total biomass:
# Model iMM904.cmd: 3.213213351180193E-6
# Model iJN1463.cmd: 7.323646781785407E-6
# Cycle 74
# Total biomass:
# Model iMM904.cmd: 3.306773336702312E-6
# Model iJN1463.cmd: 7.67247236738022E-6
# Cycle 75
# Total biomass:
# Model iMM904.cmd: 3.4026564061218894E-6
# Model iJN1463.cmd: 8.035756489601832E-6
# Cycle 76
# Total biomass:
# Model iMM904.cmd: 3.5012452698218276E-6
# Model iJN1463.cmd: 8.41614948775225E-6
# Cycle 77
# Total biomass:
# Model iMM904.cmd: 3.6024144700397565E-6
# Model iJN1463.cmd: 8.812720927543914E-6
# Cycle 78
# Total biomass:
# Model iMM904.cmd: 3.7066542846846523E-6
# Model iJN1463.cmd: 9.224899172231159E-6
# Cycle 79
# Total biomass:
# Model iMM904.cmd: 3.813838159836682E-6
# Model iJN1463.cmd: 9.654777712583221E-6
# Cycle 80
# Total biomass:
# Model iMM904.cmd: 3.923885542852293E-6
# Model iJN1463.cmd: 1.0099989294116592E-5
# Cycle 81
# Total biomass:
# Model iMM904.cmd: 4.037143760663068E-6
# Model iJN1463.cmd: 1.0565174968625744E-5
# Cycle 82
# Total biomass:
# Model iMM904.cmd: 4.153468542561813E-6
# Model iJN1463.cmd: 1.104948070350675E-5
# Cycle 83
# Total biomass:
# Model iMM904.cmd: 4.2728417660675645E-6
# Model iJN1463.cmd: 1.1548798049786287E-5
# Cycle 84
# Total biomass:
# Model iMM904.cmd: 4.3951869473886755E-6
# Model iJN1463.cmd: 1.2061972362567068E-5
# Cycle 85
# Total biomass:
# Model iMM904.cmd: 4.520043586727797E-6
# Model iJN1463.cmd: 1.257554348677257E-5
# Cycle 86
# Total biomass:
# Model iMM904.cmd: 4.646658870801066E-6
# Model iJN1463.cmd: 1.3087892961607298E-5
# Cycle 87
# Total biomass:
# Model iMM904.cmd: 4.774777242162138E-6
# Model iJN1463.cmd: 1.3594758268354213E-5
# Cycle 88
# Total biomass:
# Model iMM904.cmd: 4.904027837002644E-6
# Model iJN1463.cmd: 1.4095251606400378E-5
# Cycle 89
# Total biomass:
# Model iMM904.cmd: 5.031400415630941E-6
# Model iJN1463.cmd: 1.4582277135033021E-5
# Cycle 90
# Total biomass:
# Model iMM904.cmd: 5.157108419884833E-6
# Model iJN1463.cmd: 1.5053133457293278E-5
# Cycle 91
# Total biomass:
# Model iMM904.cmd: 5.281760152842499E-6
# Model iJN1463.cmd: 1.5505397477895986E-5
# Cycle 92
# Total biomass:
# Model iMM904.cmd: 5.404494886036337E-6
# Model iJN1463.cmd: 1.5926331274308342E-5
# Cycle 93
# Total biomass:
# Model iMM904.cmd: 5.5254471272508116E-6
# Model iJN1463.cmd: 1.6320464517089917E-5
# Cycle 94
# Model iJN1463.cmd: 2.102298225158919E-5
# Cycle 118
# Total biomass:
# Model iMM904.cmd: 7.436781644184254E-6
# Model iJN1463.cmd: 2.1166932702420486E-5
# Cycle 119
# Total biomass:
# Model iMM904.cmd: 7.4990399733578635E-6
# Model iJN1463.cmd: 2.1311852390231715E-5
# Cycle 120
# Total biomass:
# Model iMM904.cmd: 7.560777058522043E-6
# Model iJN1463.cmd: 2.1453821268560034E-5
# Cycle 121
# Total biomass:
# Model iMM904.cmd: 7.6215730837354904E-6
# Model iJN1463.cmd: 2.15977156896067E-5
# Cycle 122
# Total biomass:
# Model iMM904.cmd: 7.68144238688454E-6
# Model iJN1463.cmd: 2.174238650735262E-5
# Cycle 123
# Total biomass:
# Model iMM904.cmd: 7.741958636535839E-6
# Model iJN1463.cmd: 2.1884905814922743E-5
# Cycle 124
# Total biomass:
# Model iMM904.cmd: 7.80276085543813E-6
# Model iJN1463.cmd: 2.2025284890728646E-5
# Cycle 125
# Total biomass:
# Model iMM904.cmd: 7.862248372754735E-6
# Model iJN1463.cmd: 2.2167084389299303E-5
# Cycle 126
# Total biomass:
# Model iMM904.cmd: 7.920863182552344E-6
# Model iJN1463.cmd: 2.2310818238372923E-5
# Cycle 127
# Total biomass:
# Model iMM904.cmd: 7.978156194295808E-6
# Model iJN1463.cmd: 2.2453600870882676E-5
# Cycle 128
# Total biomass:
# Model iMM904.cmd: 8.035578385697943E-6
# Model iJN1463.cmd: 2.2596628828320248E-5
# Cycle 129
# Total biomass:
# Model iMM904.cmd: 8.092263059801042E-6
# Model iJN1463.cmd: 2.2740595632534884E-5
# Cycle 130
# Total biomass:
# Model iMM904.cmd: 8.148154203269139E-6
# Model iJN1463.cmd: 2.288358044425873E-5
# Cycle 131
# Total biomass:
# Model iMM904.cmd: 8.2027323895537E-6
# Model iJN1463.cmd: 2.3027375313921077E-5
# Cycle 132
# Total biomass:
# Model iMM904.cmd: 8.259745720345908E-6
# Model iJN1463.cmd: 2.3167889430748416E-5
# Cycle 133
# Total biomass:
# Model iMM904.cmd: 8.316738722181599E-6
# Model iJN1463.cmd: 2.3309404937660555E-5
# Cycle 134
# Total biomass:
# Model iMM904.cmd: 8.373757708761588E-6
# Model iJN1463.cmd: 2.3451373327847263E-5
# Cycle 135
# Total biomass:
# Model iMM904.cmd: 8.432299132204228E-6
# Model iJN1463.cmd: 2.3589170994122772E-5
# Cycle 136
# Total biomass:
# Model iMM904.cmd: 8.49292097060657E-6
# Model iJN1463.cmd: 2.3723887247428874E-5
# Cycle 137
# Total biomass:
# Model iMM904.cmd: 8.550642458708886E-6
# Model iJN1463.cmd: 2.3863244922595668E-5
# Cycle 138
# Total biomass:
# Model iMM904.cmd: 8.607866173282548E-6
# Model iJN1463.cmd: 2.4001633574634332E-5
# Cycle 139
# Total biomass:
# Model iMM904.cmd: 8.663460961394301E-6
# Model iJN1463.cmd: 2.41415518423948E-5
# Cycle 140
# Total biomass:
# Model iMM904.cmd: 8.71733506560849E-6
# Model iJN1463.cmd: 2.4283077434425623E-5
# Cycle 141
# Model iJN1463.cmd: 2.7458009584170257E-5
# Cycle 165
# Total biomass:
# Model iMM904.cmd: 1.0163338187356734E-5
# Model iJN1463.cmd: 2.758561699995615E-5
# Cycle 166
# Total biomass:
# Model iMM904.cmd: 1.0221229601310006E-5
# Model iJN1463.cmd: 2.7714734011420915E-5
# Cycle 167
# Total biomass:
# Model iMM904.cmd: 1.0279428387983106E-5
# Model iJN1463.cmd: 2.784286585506231E-5
# Cycle 168
# Total biomass:
# Model iMM904.cmd: 1.0338323503025808E-5
# Model iJN1463.cmd: 2.7970448625621127E-5
# Cycle 169
# Total biomass:
# Model iMM904.cmd: 1.0397935508527323E-5
# Model iJN1463.cmd: 2.8096758644198755E-5
# Cycle 170
# Total biomass:
# Model iMM904.cmd: 1.0456412673868127E-5
# Model iJN1463.cmd: 2.8224857391321883E-5
# Cycle 171
# Total biomass:
# Model iMM904.cmd: 1.051591503232174E-5
# Model iJN1463.cmd: 2.8351677144737245E-5
# Cycle 172
# Total biomass:
# Model iMM904.cmd: 1.0573403601404273E-5
# Model iJN1463.cmd: 2.847861224669368E-5
# Cycle 173
# Total biomass:
# Model iMM904.cmd: 1.062887300793684E-5
# Model iJN1463.cmd: 2.8603221660419952E-5
# Cycle 174
# Total biomass:
# Model iMM904.cmd: 1.0686247461470717E-5
# Model iJN1463.cmd: 2.8729931958900032E-5
# Cycle 175
# Total biomass:
# Model iMM904.cmd: 1.0744966291080662E-5
# Model iJN1463.cmd: 2.885617433369073E-5
# Cycle 176
# Total biomass:
# Model iMM904.cmd: 1.0805050855821493E-5
# Model iJN1463.cmd: 2.897856011984987E-5
# Cycle 177
# Total biomass:
# Model iMM904.cmd: 1.0864960753296914E-5
# Model iJN1463.cmd: 2.9100375789847586E-5
# Cycle 178
# Total biomass:
# Model iMM904.cmd: 1.0924375359953629E-5
# Model iJN1463.cmd: 2.9222494632940197E-5
# Cycle 179
# Total biomass:
# Model iMM904.cmd: 1.0983136725867756E-5
# Model iJN1463.cmd: 2.9348089482608722E-5
# Cycle 180
# Total biomass:
# Model iMM904.cmd: 1.1039093666100201E-5
# Model iJN1463.cmd: 2.9474982726838066E-5
# Cycle 181
# Total biomass:
# Model iMM904.cmd: 1.109524986363406E-5
# Model iJN1463.cmd: 2.959993677699865E-5
# Cycle 182
# Total biomass:
# Model iMM904.cmd: 1.1150535274986124E-5
# Model iJN1463.cmd: 2.9725241473289668E-5
# Cycle 183
# Total biomass:
# Model iMM904.cmd: 1.1209608305424257E-5
# Model iJN1463.cmd: 2.98478665536937E-5
# Cycle 184
# Total biomass:
# Model iMM904.cmd: 1.1266615547080103E-5
# Model iJN1463.cmd: 2.997299867874794E-5
# Cycle 185
# Total biomass:
# Model iMM904.cmd: 1.1326849525561691E-5
# Model iJN1463.cmd: 3.0096054832361184E-5
# Cycle 186
# Total biomass:
# Model iMM904.cmd: 1.1384216556056688E-5
# Model iJN1463.cmd: 3.021849031746878E-5
# Cycle 187
# Total biomass:
# Model iMM904.cmd: 1.1442089552838296E-5
# Model iJN1463.cmd: 3.0341590148814866E-5
# Cycle 188
# Total biomass:
# Model iMM904.cmd: 1.1501693112196628E-5
# Model iJN1463.cmd: 3.0461938886903775E-5
# Cycle 189
# Total biomass:
# Model iMM904.cmd: 1.156378703815824E-5
# Model iJN1463.cmd: 3.0583561623632774E-5
# Cycle 190
# Total biomass:
# Model iMM904.cmd: 1.1624032282080183E-5
# Model iJN1463.cmd: 3.0704934988163494E-5
# Cycle 191
# Total biomass:
# Model iMM904.cmd: 1.1685001737793502E-5
# Model iJN1463.cmd: 3.0824379913799206E-5
# Cycle 192
# Total biomass:
# Model iMM904.cmd: 1.1745593580746254E-5
# Model iJN1463.cmd: 3.095078043528367E-5
# Cycle 193
# Total biomass:
# Model iMM904.cmd: 1.1808473528615729E-5
# Model iJN1463.cmd: 3.106884271229565E-5
# Cycle 194
# Total biomass:
# Model iMM904.cmd: 1.1868300767666143E-5
# Model iJN1463.cmd: 3.118262705116683E-5
# Cycle 195
# Total biomass:
# Model iMM904.cmd: 1.1927221416403007E-5
# Model iJN1463.cmd: 3.1295360067171985E-5
# Cycle 196
# Total biomass:
# Model iMM904.cmd: 1.1985036191552953E-5
# Model iJN1463.cmd: 3.141424899263797E-5
# Cycle 197
# Total biomass:
# Model iMM904.cmd: 1.2043530554161205E-5
# Model iJN1463.cmd: 3.153298790276395E-5
# Cycle 198
# Total biomass:
# Model iMM904.cmd: 1.2105223922907352E-5
# Model iJN1463.cmd: 3.164781751870404E-5
# Cycle 199
# Total biomass:
# Model iMM904.cmd: 1.2165995082213024E-5
# Model iJN1463.cmd: 3.176402565943535E-5
# Cycle 200
# Total biomass:
# Model iMM904.cmd: 1.2228370455703052E-5
# Model iJN1463.cmd: 3.1880470204311115E-5
# Cycle 201
# Total biomass:
# Model iMM904.cmd: 1.2288271504814582E-5
# Model iJN1463.cmd: 3.1996060681562446E-5
# Cycle 202
# Total biomass:
# Model iMM904.cmd: 1.2348351868762306E-5
# Model iJN1463.cmd: 3.211170583909193E-5
# Cycle 203
# Total biomass:
# Model iMM904.cmd: 1.2407114754830258E-5
# Model iJN1463.cmd: 3.222676196516764E-5
# Cycle 204
# Total biomass:
# Model iMM904.cmd: 1.246556524808192E-5
# Model iJN1463.cmd: 3.234311575477016E-5
# Cycle 205
# Total biomass:
# Model iMM904.cmd: 1.2529747297147711E-5
# Model iJN1463.cmd: 3.246878625525773E-5
# Cycle 206
# Total biomass:
# Model iMM904.cmd: 1.2585017035087022E-5
# Model iJN1463.cmd: 3.259082076421802E-5
# Cycle 207
# Total biomass:
# Model iMM904.cmd: 1.2646611001454093E-5
# Model iJN1463.cmd: 3.270426257955019E-5
# Cycle 208
# Total biomass:
# Model iMM904.cmd: 1.2709545712541243E-5
# Model iJN1463.cmd: 3.2816076432913417E-5
# Cycle 209
# Total biomass:
# Model iMM904.cmd: 1.2769051962979239E-5
# Model iJN1463.cmd: 3.293088971054292E-5
# Cycle 210
# Total biomass:
# Model iMM904.cmd: 1.282759070466534E-5
# Model iJN1463.cmd: 3.304479066401395E-5
# Cycle 211
# Total biomass:
# Model iMM904.cmd: 1.2888454586102572E-5
# Model iJN1463.cmd: 3.315601904045804E-5
# Cycle 212
# Total biomass:
# Model iMM904.cmd: 1.2944833468302558E-5
# Model iJN1463.cmd: 3.327235719454723E-5
# Cycle 213
# Total biomass:
# Model iMM904.cmd: 1.3007448757979352E-5
# Model iJN1463.cmd: 3.338287846180255E-5
# Cycle 214
# Total biomass:
# Model iMM904.cmd: 1.3068026947733129E-5
# Model iJN1463.cmd: 3.349546669919978E-5
# Cycle 215
# Total biomass:
# Model iMM904.cmd: 1.3133763988500668E-5
# Model iJN1463.cmd: 3.3606913785573105E-5
# Cycle 216
# Total biomass:
# Model iMM904.cmd: 1.3196319082506245E-5
# Model iJN1463.cmd: 3.371805076750789E-5
# Cycle 217
# Total biomass:
# Model iMM904.cmd: 1.32576519618945E-5
# Model iJN1463.cmd: 3.382841728459718E-5
# Cycle 218
# Total biomass:
# Model iMM904.cmd: 1.331663488296543E-5
# Model iJN1463.cmd: 3.394142198739689E-5
# Cycle 219
# Total biomass:
# Model iMM904.cmd: 1.3373872873275635E-5
# Model iJN1463.cmd: 3.405615750719875E-5
# Cycle 220
# Total biomass:
# Model iMM904.cmd: 1.3429818851450401E-5
# Model iJN1463.cmd: 3.417058464734296E-5
# Cycle 221
# Total biomass:
# Model iMM904.cmd: 1.3488442024949136E-5
# Model iJN1463.cmd: 3.428194154994279E-5
# Cycle 222
# Total biomass:
# Model iMM904.cmd: 1.354749600960248E-5
# Model iJN1463.cmd: 3.4387872659429136E-5
# Cycle 223
# Total biomass:
# Model iMM904.cmd: 1.3607312347056164E-5
# Model iJN1463.cmd: 3.449546818082074E-5
# Cycle 224
# Total biomass:
# Model iMM904.cmd: 1.366646049316944E-5
# Model iJN1463.cmd: 3.460614029585746E-5
# Cycle 225
# Total biomass:
# Model iMM904.cmd: 1.3732472969497555E-5
# Model iJN1463.cmd: 3.4718685306910336E-5
# Cycle 226
# Total biomass:
# Model iMM904.cmd: 1.3796189800097662E-5
# Model iJN1463.cmd: 3.482652443108722E-5
# Cycle 227
# Total biomass:
# Model iMM904.cmd: 1.3858303421240934E-5
# Model iJN1463.cmd: 3.493173913086496E-5
# Cycle 228
# Total biomass:
# Model iMM904.cmd: 1.3918474169280266E-5
# Model iJN1463.cmd: 3.503823181949473E-5
# Cycle 229
# Total biomass:
# Model iMM904.cmd: 1.3978352458404895E-5
# Model iJN1463.cmd: 3.5145604015475585E-5
# Cycle 230
# Total biomass:
# Model iMM904.cmd: 1.4038889473574466E-5
# Model iJN1463.cmd: 3.5250907150058775E-5
# Cycle 231
# Total biomass:
# Model iMM904.cmd: 1.4097212380454346E-5
# Model iJN1463.cmd: 3.535752789437139E-5
# Cycle 232
# Total biomass:
# Model iMM904.cmd: 1.4156970875304105E-5
# Model iJN1463.cmd: 3.5463769760270345E-5
# Cycle 233
# Total biomass:
# Model iMM904.cmd: 1.4216447450396602E-5
# Model iJN1463.cmd: 3.557563554493704E-5
# Cycle 234
# Total biomass:
# Model iMM904.cmd: 1.4275362837658681E-5
# Model iJN1463.cmd: 3.568322397099116E-5
# Cycle 235
# Total biomass:
# Model iMM904.cmd: 1.4335907103426863E-5
# Model iJN1463.cmd: 3.578866157858168E-5
# Cycle 236
# Total biomass:
# Model iMM904.cmd: 1.4395031758397526E-5
# Model iJN1463.cmd: 3.5895155630374644E-5
# Cycle 237
# Total biomass:
# Model iMM904.cmd: 1.4454515158787327E-5
# Model iJN1463.cmd: 3.60026471832443E-5
# Cycle 238
# Total biomass:
# Model iMM904.cmd: 1.4515316511481503E-5
# Model iJN1463.cmd: 3.6105492222299934E-5
# Cycle 239
# Total biomass:
# Model iMM904.cmd: 1.4578124762117568E-5
# Model iJN1463.cmd: 3.620650071696109E-5
# Cycle 240
# Total biomass:
# Model iMM904.cmd: 1.4639260291714938E-5
# Model iJN1463.cmd: 3.6308697541369486E-5
# Cycle 241
# Total biomass:
# Model iMM904.cmd: 1.4699138814948203E-5
# Model iJN1463.cmd: 3.641249734631864E-5
# Cycle 242
# Total biomass:
# Model iMM904.cmd: 1.4762379136440657E-5
# Model iJN1463.cmd: 3.6513047480307034E-5
# Cycle 243
# Total biomass:
# Model iMM904.cmd: 1.4824481924206868E-5
# Model iJN1463.cmd: 3.661458160371969E-5
# Cycle 244
# Total biomass:
# Model iMM904.cmd: 1.488518074275951E-5
# Model iJN1463.cmd: 3.6721713468011304E-5
# Cycle 245
# Total biomass:
# Model iMM904.cmd: 1.494790423535349E-5
# Model iJN1463.cmd: 3.682462086612451E-5
# Cycle 246
# Total biomass:
# Model iMM904.cmd: 1.5010536227615764E-5
# Model iJN1463.cmd: 3.6927287214804736E-5
# Cycle 247
# Total biomass:
# Model iMM904.cmd: 1.5070916411349676E-5
# Model iJN1463.cmd: 3.702970896404097E-5
# Cycle 248
# Total biomass:
# Model iMM904.cmd: 1.5129972992002005E-5
# Model iJN1463.cmd: 3.713267569882053E-5
# Cycle 249
# Total biomass:
# Model iMM904.cmd: 1.5185493881784244E-5
# Model iJN1463.cmd: 3.723119555580077E-5
# Cycle 250
# Total biomass:
# Model iMM904.cmd: 1.5242197074044959E-5
# Model iJN1463.cmd: 3.7326168108861604E-5
# Cycle 251
# Total biomass:
# Model iMM904.cmd: 1.5302638902682374E-5
# Model iJN1463.cmd: 3.742372516430951E-5
# Cycle 252
# Total biomass:
# Model iMM904.cmd: 1.5362831545534537E-5
# Model iJN1463.cmd: 3.752332407137925E-5
# Cycle 253
# Total biomass:
# Model iMM904.cmd: 1.542239557180273E-5
# Model iJN1463.cmd: 3.7626603515710506E-5
# Cycle 254
# Total biomass:
# Model iMM904.cmd: 1.548565018562093E-5
# Model iJN1463.cmd: 3.772413473629551E-5
# Cycle 255
# Total biomass:
# Model iMM904.cmd: 1.554716043308067E-5
# Model iJN1463.cmd: 3.782074593536814E-5
# Cycle 256
# Total biomass:
# Model iMM904.cmd: 1.561050719654489E-5
# Model iJN1463.cmd: 3.7918489658935555E-5
# Cycle 257
# Total biomass:
# Model iMM904.cmd: 1.5669812735333127E-5
# Model iJN1463.cmd: 3.801400859390815E-5
# Cycle 258
# Total biomass:
# Model iMM904.cmd: 1.572729841677566E-5
# Model iJN1463.cmd: 3.810967467159438E-5
# Cycle 259
# Total biomass:
# Model iMM904.cmd: 1.5785697367533934E-5
# Model iJN1463.cmd: 3.8205139514256346E-5
# Cycle 260
# Total biomass:
# Model iMM904.cmd: 1.584094265287661E-5
# Model iJN1463.cmd: 3.8304313020027776E-5
# Cycle 261
# Total biomass:
# Model iMM904.cmd: 1.589706152236248E-5
# Model iJN1463.cmd: 3.840435910452239E-5
# Cycle 262
# Total biomass:
# Model iMM904.cmd: 1.5954067149631006E-5
# Model iJN1463.cmd: 3.8504762941341E-5
# Cycle 263
# Total biomass:
# Model iMM904.cmd: 1.6011967368903904E-5
# Model iJN1463.cmd: 3.860675857589515E-5
# Cycle 264
# Total biomass:
# Model iMM904.cmd: 1.6073497743505615E-5
# Model iJN1463.cmd: 3.870675493684271E-5
# Cycle 265
# Total biomass:
# Model iMM904.cmd: 1.613491108994845E-5
# Model iJN1463.cmd: 3.8803055386163843E-5
# Cycle 266
# Total biomass:
# Model iMM904.cmd: 1.6192192198920713E-5
# Model iJN1463.cmd: 3.89000430741867E-5
# Cycle 267
# Total biomass:
# Model iMM904.cmd: 1.6250095931048924E-5
# Model iJN1463.cmd: 3.899848947503304E-5
# Cycle 268
# Total biomass:
# Model iMM904.cmd: 1.6308066064375572E-5
# Model iJN1463.cmd: 3.909966358787998E-5
# Cycle 269
# Total biomass:
# Model iMM904.cmd: 1.636328932600625E-5
# Model iJN1463.cmd: 3.920030715376599E-5
# Cycle 270
# Total biomass:
# Model iMM904.cmd: 1.642305441745411E-5
# Model iJN1463.cmd: 3.9297824844766904E-5
# Cycle 271
# Total biomass:
# Model iMM904.cmd: 1.6484038186285612E-5
# Model iJN1463.cmd: 3.939613789782696E-5
# Cycle 272
# Total biomass:
# Model iMM904.cmd: 1.6543264214948735E-5
# Model iJN1463.cmd: 3.949415233739818E-5
# Cycle 273
# Total biomass:
# Model iMM904.cmd: 1.660527715200485E-5
# Model iJN1463.cmd: 3.958850362695081E-5
# Cycle 274
# Total biomass:
# Model iMM904.cmd: 1.6667362306200942E-5
# Model iJN1463.cmd: 3.968249375701874E-5
# Cycle 275
# Total biomass:
# Model iMM904.cmd: 1.6728700750068533E-5
# Model iJN1463.cmd: 3.9776331611127365E-5
# Cycle 276
# Total biomass:
# Model iMM904.cmd: 1.678966256169714E-5
# Model iJN1463.cmd: 3.987172565288149E-5
# Cycle 277
# Total biomass:
# Model iMM904.cmd: 1.6846298400902696E-5
# Model iJN1463.cmd: 3.9972787830395806E-5
# Cycle 278
# Total biomass:
# Model iMM904.cmd: 1.690268577692576E-5
# Model iJN1463.cmd: 4.007109325628094E-5
# Cycle 279
# Total biomass:
# Model iMM904.cmd: 1.695997201691645E-5
# Model iJN1463.cmd: 4.0166866701011796E-5
# Cycle 280
# Total biomass:
# Model iMM904.cmd: 1.7016037540916892E-5
# Model iJN1463.cmd: 4.026387915774389E-5
# Cycle 281
# Total biomass:
# Model iMM904.cmd: 1.707058642940528E-5
# Model iJN1463.cmd: 4.036019859290909E-5
# Cycle 282
# Total biomass:
# Model iMM904.cmd: 1.7121699818843446E-5
# Model iJN1463.cmd: 4.045556278126789E-5
# Cycle 283
# Total biomass:
# Model iMM904.cmd: 1.7171895681323877E-5
# Model iJN1463.cmd: 4.054895735571636E-5
# Cycle 284
# Total biomass:
# Model iMM904.cmd: 1.722521240252E-5
# Model iJN1463.cmd: 4.064362943061214E-5
# Cycle 285
# Total biomass:
# Model iMM904.cmd: 1.728244942995492E-5
# Model iJN1463.cmd: 4.073728246483621E-5
# Cycle 286
# Total biomass:
# Model iMM904.cmd: 1.734117384000611E-5
# Model iJN1463.cmd: 4.083081777372411E-5
# Cycle 287
# Total biomass:
# Model iMM904.cmd: 1.7396871578798365E-5
# Model iJN1463.cmd: 4.092721858458008E-5
# Cycle 288
# Total biomass:
# Model iMM904.cmd: 1.7455265378544635E-5
# Model iJN1463.cmd: 4.102182584936116E-5
# Cycle 289
# Total biomass:
# Model iMM904.cmd: 1.751149640293674E-5
# Model iJN1463.cmd: 4.111819921612587E-5
# Cycle 290
# Total biomass:
# Model iMM904.cmd: 1.756528258532655E-5
# Model iJN1463.cmd: 4.1215983027661155E-5
# Cycle 291
# Total biomass:
# Model iMM904.cmd: 1.7619278715562225E-5
# Model iJN1463.cmd: 4.13072256700626E-5
# Cycle 292
# Total biomass:
# Model iMM904.cmd: 1.7673413261006787E-5
# Model iJN1463.cmd: 4.140013058037216E-5
# Cycle 293
# Total biomass:
# Model iMM904.cmd: 1.772913733824289E-5
# Model iJN1463.cmd: 4.1496124540454925E-5
# Cycle 294
# Total biomass:
# Model iMM904.cmd: 1.778329227653075E-5
# Model iJN1463.cmd: 4.159138617802048E-5
# Cycle 295
# Total biomass:
# Model iMM904.cmd: 1.7837001771722975E-5
# Model iJN1463.cmd: 4.1684687455640024E-5
# Cycle 296
# Total biomass:
# Model iMM904.cmd: 1.7889501574843865E-5
# Model iJN1463.cmd: 4.177577555307162E-5
# Cycle 297
# Total biomass:
# Model iMM904.cmd: 1.794228217551337E-5
# Model iJN1463.cmd: 4.186798187521085E-5
# Cycle 298
# Total biomass:
# Model iMM904.cmd: 1.799203194034443E-5
# Model iJN1463.cmd: 4.196055018744491E-5
# Cycle 299
# Total biomass:
# Model iMM904.cmd: 1.8040895597791783E-5
# Model iJN1463.cmd: 4.205406606776784E-5
# Cycle 300
# Total biomass:
# Model iMM904.cmd: 1.8089307444077547E-5
# Model iJN1463.cmd: 4.214649218329736E-5
# Cycle 301
# Total biomass:
# Model iMM904.cmd: 1.814109030620705E-5
# Model iJN1463.cmd: 4.2240005091745136E-5
# Cycle 302
# Total biomass:
# Model iMM904.cmd: 1.8195087612562863E-5
# Model iJN1463.cmd: 4.233333134600171E-5
# Cycle 303
# Total biomass:
# Model iMM904.cmd: 1.8248707533242503E-5
# Model iJN1463.cmd: 4.242706699752746E-5
# Cycle 304
# Total biomass:
# Model iMM904.cmd: 1.8304292309878518E-5
# Model iJN1463.cmd: 4.2518842790781284E-5
# Cycle 305
# Total biomass:
# Cycle 329
# Total biomass:
# Model iMM904.cmd: 1.963361656042094E-5
# Model iJN1463.cmd: 4.4742176044725075E-5
# Cycle 330
# Total biomass:
# Model iMM904.cmd: 1.969070361064668E-5
# Model iJN1463.cmd: 4.482790319227434E-5
# Cycle 331
# Total biomass:
# Model iMM904.cmd: 1.974886310188437E-5
# Model iJN1463.cmd: 4.491102472836752E-5
# Cycle 332
# Total biomass:
# Model iMM904.cmd: 1.980696054219693E-5
# Model iJN1463.cmd: 4.4994536820310524E-5
# Cycle 333
# Total biomass:
# Model iMM904.cmd: 1.9863386365586E-5
# Model iJN1463.cmd: 4.5079232434734945E-5
# Cycle 334
# Total biomass:
# Model iMM904.cmd: 1.9918551442696568E-5
# Model iJN1463.cmd: 4.5168153924658994E-5
# Cycle 335
# Total biomass:
# Model iMM904.cmd: 1.9974167956736903E-5
# Model iJN1463.cmd: 4.525349913361749E-5
# Cycle 336
# Total biomass:
# Model iMM904.cmd: 2.0032979922140052E-5
# Model iJN1463.cmd: 4.533488735725358E-5
# Cycle 337
# Total biomass:
# Model iMM904.cmd: 2.0089880801066052E-5
# Model iJN1463.cmd: 4.541923407541183E-5
# Cycle 338
# Total biomass:
# Model iMM904.cmd: 2.01451773889603E-5
# Model iJN1463.cmd: 4.5503260787252925E-5
# Cycle 339
# Total biomass:
# Model iMM904.cmd: 2.0200097678846883E-5
# Model iJN1463.cmd: 4.558587194716983E-5
# Cycle 340
# Total biomass:
# Model iMM904.cmd: 2.024753554432496E-5
# Model iJN1463.cmd: 4.567501334171707E-5
# Cycle 341
# Total biomass:
# Model iMM904.cmd: 2.0301518053111606E-5
# Model iJN1463.cmd: 4.57611262758398E-5
# Cycle 342
# Total biomass:
# Model iMM904.cmd: 2.0356884916643976E-5
# Model iJN1463.cmd: 4.584590222757216E-5
# Cycle 343
# Total biomass:
# Model iMM904.cmd: 2.0414417409614717E-5
# Model iJN1463.cmd: 4.5928001662459746E-5
# Cycle 344
# Total biomass:
# Model iMM904.cmd: 2.0472055563642862E-5
# Model iJN1463.cmd: 4.600694821789457E-5
# Cycle 345
# Total biomass:
# Model iMM904.cmd: 2.0529208779296348E-5
# Model iJN1463.cmd: 4.60845277266624E-5
# Cycle 346
# Total biomass:
# Model iMM904.cmd: 2.0581403771916254E-5
# Model iJN1463.cmd: 4.616756079842904E-5
# Cycle 347
# Total biomass:
# Model iMM904.cmd: 2.0629760940529407E-5
# Model iJN1463.cmd: 4.624960480191076E-5
# Cycle 348
# Total biomass:
# Model iMM904.cmd: 2.0674638256209825E-5
# Model iJN1463.cmd: 4.633355580224819E-5
# Cycle 349
# Total biomass:
# Model iMM904.cmd: 2.071823038810668E-5
# Model iJN1463.cmd: 4.641788606797835E-5
# Cycle 350
# Total biomass:
# Model iMM904.cmd: 2.076970645717872E-5
# Model iJN1463.cmd: 4.650173993052406E-5
# Cycle 351
# Total biomass:
# Model iMM904.cmd: 2.0822554843490493E-5
# Model iJN1463.cmd: 4.658424977151019E-5
# Cycle 352
# Total biomass:
# Model iMM904.cmd: 2.087447504204638E-5
# Model iJN1463.cmd: 4.667022030004389E-5
# Cycle 353
# Total biomass:
# Model iMM904.cmd: 2.0924024231238037E-5
# Model iJN1463.cmd: 4.675748791226121E-5
# Cycle 354
# Total biomass:
# Model iMM904.cmd: 2.0971501674590856E-5
# Model iJN1463.cmd: 4.684090644229247E-5
# Cycle 355
# Total biomass:
# Model iMM904.cmd: 2.101861388235026E-5
# Model iJN1463.cmd: 4.692560346488846E-5
# Cycle 356
# Total biomass:
# Model iMM904.cmd: 2.1066403465615695E-5
# Model iJN1463.cmd: 4.7010668163755944E-5
# Cycle 357
# Total biomass:
# Model iMM904.cmd: 2.1117486934658893E-5
# Model iJN1463.cmd: 4.709423042920793E-5
# Cycle 358
# Total biomass:
# Model iMM904.cmd: 2.1169559643572742E-5
# Model iJN1463.cmd: 4.7174207727621446E-5
# Cycle 359
# Total biomass:
# Model iMM904.cmd: 2.121972259333199E-5
# Model iJN1463.cmd: 4.72538968694206E-5
# Cycle 360
# Total biomass:
# Model iMM904.cmd: 2.1269273732395304E-5
# Model iJN1463.cmd: 4.7332513502495706E-5
# Cycle 361
# Total biomass:
# Model iMM904.cmd: 2.131664902903032E-5
# Model iJN1463.cmd: 4.741361040409321E-5
# Cycle 362
# Total biomass:
# Model iMM904.cmd: 2.1364518652517273E-5
# Model iJN1463.cmd: 4.7497328024387644E-5
# Cycle 363
# Total biomass:
# Model iMM904.cmd: 2.141029796625082E-5
# Model iJN1463.cmd: 4.758229993735424E-5
# Cycle 364
# Total biomass:
# Model iMM904.cmd: 2.1459379547668375E-5
# Model iJN1463.cmd: 4.766534654300165E-5
# Cycle 365
# Total biomass:
# Model iMM904.cmd: 2.150145159226058E-5
# Model iJN1463.cmd: 4.77540573809595E-5
# Cycle 366
# Total biomass:
# Model iMM904.cmd: 2.1548938910051328E-5
# Model iJN1463.cmd: 4.785558988918732E-5
# Cycle 367
# Total biomass:
# Model iMM904.cmd: 2.1602638734925974E-5
# Model iJN1463.cmd: 4.79371254301304E-5
# Cycle 368
# Total biomass:
# Model iMM904.cmd: 2.1656843111029953E-5
# Model iJN1463.cmd: 4.8015128378332386E-5
# Cycle 369
# Total biomass:
# Model iMM904.cmd: 2.1708282575008666E-5
# Model iJN1463.cmd: 4.809658826557337E-5
# Cycle 370
# Total biomass:
# Model iMM904.cmd: 2.1759555071256217E-5
# Model iJN1463.cmd: 4.817885453135448E-5
# Cycle 371
# Total biomass:
# Model iMM904.cmd: 2.181322342512595E-5
# Model iJN1463.cmd: 4.8255324652256045E-5
# Cycle 372
# Total biomass:
# Model iMM904.cmd: 2.186573439889527E-5
# Model iJN1463.cmd: 4.8334017930684256E-5
# Cycle 373
# Total biomass:
# Model iMM904.cmd: 2.1913797501212683E-5
# Model iJN1463.cmd: 4.8416689546649555E-5
# Cycle 374
# Total biomass:
# Model iMM904.cmd: 2.1962916528752646E-5
# Model iJN1463.cmd: 4.8493219475567384E-5
# Cycle 375
# Total biomass:
# Model iMM904.cmd: 2.2013429260170945E-5
# Model iJN1463.cmd: 4.85683872742123E-5
# Cycle 376
# Total biomass:
# Model iMM904.cmd: 2.206434820177643E-5
# Model iJN1463.cmd: 4.864660869108527E-5
# Cycle 377
# Total biomass:
# Model iMM904.cmd: 2.2119056319633083E-5
# Model iJN1463.cmd: 4.872282200398952E-5
# Cycle 378
# Total biomass:
# Model iMM904.cmd: 2.2173693027830936E-5
# Model iJN1463.cmd: 4.8799428392963096E-5
# Cycle 379
# Total biomass:
# Model iMM904.cmd: 2.222813251991145E-5
# Model iJN1463.cmd: 4.887454460208606E-5
# Cycle 380
# Total biomass:
# Model iMM904.cmd: 2.2281487670104212E-5
# Model iJN1463.cmd: 4.895165537778584E-5
# Cycle 381
# Total biomass:
# Model iMM904.cmd: 2.2330576890362074E-5
# Model iJN1463.cmd: 4.902933759730181E-5
# Cycle 382
# Total biomass:
# Model iMM904.cmd: 2.237802407399844E-5
# Model iJN1463.cmd: 4.910686521063494E-5
# Cycle 383
# Total biomass:
# Model iMM904.cmd: 2.2426199130678125E-5
# Model iJN1463.cmd: 4.91845678029038E-5
# Cycle 384
# Total biomass:
# Model iMM904.cmd: 2.2474652705144038E-5
# Model iJN1463.cmd: 4.9264567373864384E-5
# Cycle 385
# Total biomass:
# Model iMM904.cmd: 2.2525255195253915E-5
# Model iJN1463.cmd: 4.934345778239617E-5
# Cycle 386
# Total biomass:
# Model iMM904.cmd: 2.2578166781832292E-5
# Model iJN1463.cmd: 4.941922506851916E-5
# Cycle 387
# Total biomass:
# Model iMM904.cmd: 2.2627967306066862E-5
# Model iJN1463.cmd: 4.949652047491111E-5
# Cycle 388
# Total biomass:
# Model iMM904.cmd: 2.2675377288238373E-5
# Model iJN1463.cmd: 4.95753509672832E-5
# Cycle 389
# Total biomass:
# Model iMM904.cmd: 2.2722350547624738E-5
# Model iJN1463.cmd: 4.9651622847528154E-5
# Cycle 390
# Total biomass:
# Model iMM904.cmd: 2.276777035564905E-5
# Model iJN1463.cmd: 4.9727529434421705E-5
# Cycle 391
# Total biomass:
# Model iMM904.cmd: 2.2820588654739226E-5
# Model iJN1463.cmd: 4.980441773135916E-5
# Cycle 392
# Total biomass:
# Model iMM904.cmd: 2.286914990499462E-5
# Model iJN1463.cmd: 4.988893440002188E-5
# Cycle 393
# Total biomass:
# Model iMM904.cmd: 2.291884956606357E-5
# Model iJN1463.cmd: 4.996704704770309E-5
# Cycle 394
# Total biomass:
# Model iMM904.cmd: 2.296793290762517E-5
# Model iJN1463.cmd: 5.004548092167418E-5
# Cycle 395
# Total biomass:
# Model iMM904.cmd: 2.3016397597965444E-5
# Model iJN1463.cmd: 5.012314836387526E-5
# Cycle 396
# Total biomass:
# Model iMM904.cmd: 2.306744304350624E-5
# Model iJN1463.cmd: 5.01957401016971E-5
# Cycle 397
# Total biomass:
# Model iMM904.cmd: 2.3115790988241033E-5
# Model iJN1463.cmd: 5.0269892478936006E-5
# Cycle 398
# Total biomass:
# Model iMM904.cmd: 2.315996096388672E-5
# Model iJN1463.cmd: 5.034606062118285E-5
# Cycle 399
# Total biomass:
# Model iMM904.cmd: 2.3204570428962732E-5
# Model iJN1463.cmd: 5.042522271408131E-5
# Cycle 400
# Total biomass:
# Model iMM904.cmd: 2.325495088530648E-5
# Model iJN1463.cmd: 5.050041442911349E-5
# Cycle 401
# Total biomass:
# Model iMM904.cmd: 2.3302109096333924E-5
# Model iJN1463.cmd: 5.057549776849906E-5
# Cycle 402
# Total biomass:
# Model iMM904.cmd: 2.3349846331298005E-5
# Model iJN1463.cmd: 5.06530541427999E-5
# Cycle 403
# Total biomass:
# Model iMM904.cmd: 2.3400260492881476E-5
# Model iJN1463.cmd: 5.072974517339482E-5
# Cycle 404
# Total biomass:
# Model iMM904.cmd: 2.3451274296896672E-5
# Model iJN1463.cmd: 5.080554345197604E-5
# Cycle 405
# Total biomass:
# ...
# Total biomass:
# Model iMM904.cmd: 3.895006614599562E-5
# Model iJN1463.cmd: 7.269745538078539E-5
# Cycle 849
# Total biomass:
# Model iMM904.cmd: 3.896773850058881E-5
# Model iJN1463.cmd: 7.272901104602728E-5
# Cycle 850
# Total biomass:
# Model iMM904.cmd: 3.8987116532804326E-5
# Model iJN1463.cmd: 7.276441911128357E-5
# Cycle 851
# Total biomass:
# Model iMM904.cmd: 3.900738055560281E-5
# Model iJN1463.cmd: 7.279949590488297E-5
# Cycle 852
# Total biomass:
# Model iMM904.cmd: 3.902872697671337E-5
# Model iJN1463.cmd: 7.283362724258673E-5
# Cycle 853
# Total biomass:
# Model iMM904.cmd: 3.905053458650202E-5
# Model iJN1463.cmd: 7.286573733945471E-5
# Cycle 854
# Total biomass:
# Model iMM904.cmd: 3.907078636752514E-5
# Model iJN1463.cmd: 7.28992783710754E-5
# Cycle 855
# Total biomass:
# Model iMM904.cmd: 3.908724091235552E-5
# Model iJN1463.cmd: 7.293261958792749E-5
# Cycle 856
# Total biomass:
# Model iMM904.cmd: 3.910339711410338E-5
# Model iJN1463.cmd: 7.296930048034644E-5
# Cycle 857
# Total biomass:
# Model iMM904.cmd: 3.9122106111250757E-5
# Model iJN1463.cmd: 7.300207905741002E-5
# Cycle 858
# Total biomass:
# Model iMM904.cmd: 3.913733102511296E-5
# Model iJN1463.cmd: 7.303384140590654E-5
# Cycle 859
# Total biomass:
# Model iMM904.cmd: 3.9158314158629544E-5
# Model iJN1463.cmd: 7.306362080214762E-5
# Cycle 860
# Total biomass:
# Model iMM904.cmd: 3.9176233003117626E-5
# Model iJN1463.cmd: 7.309413622861811E-5
# Cycle 861
# Total biomass:
# Model iMM904.cmd: 3.9197297733946924E-5
# Model iJN1463.cmd: 7.312087424725356E-5
# Cycle 862
# Total biomass:
# Model iMM904.cmd: 3.92148268953899E-5
# Model iJN1463.cmd: 7.315058347202902E-5
# Cycle 863
# Total biomass:
# Model iMM904.cmd: 3.923637728316491E-5
# Model iJN1463.cmd: 7.317922513726113E-5
# Cycle 864
# Total biomass:
# Model iMM904.cmd: 3.9257715044843886E-5
# Model iJN1463.cmd: 7.320841989320963E-5
# Cycle 865
# Total biomass:
# Model iMM904.cmd: 3.928031448295878E-5
# Model iJN1463.cmd: 7.323869259686646E-5
# Cycle 937
# Total biomass:
# Model iMM904.cmd: 4.065765489036053E-5
# Model iJN1463.cmd: 7.52547362235366E-5
# Cycle 938
# Total biomass:
# Model iMM904.cmd: 4.067283362334991E-5
# Model iJN1463.cmd: 7.528063635200229E-5
# Cycle 939
# Total biomass:
# Model iMM904.cmd: 4.069202066217476E-5
# Model iJN1463.cmd: 7.530241871918117E-5
# Cycle 940
# Total biomass:
# Model iMM904.cmd: 4.0706228296789316E-5
# Model iJN1463.cmd: 7.532947966929042E-5
# Cycle 941
# Total biomass:
# Model iMM904.cmd: 4.072205567013121E-5
# Model iJN1463.cmd: 7.535462944345464E-5
# Cycle 942
# Total biomass:
# Model iMM904.cmd: 4.073895966602591E-5
# Model iJN1463.cmd: 7.537869173014455E-5
# Cycle 943
# Total biomass:
# Model iMM904.cmd: 4.075595356646012E-5
# Model iJN1463.cmd: 7.540117838761728E-5
# Cycle 944
# Total biomass:
# Model iMM904.cmd: 4.0773488190251866E-5
# Model iJN1463.cmd: 7.542400123485726E-5
# Cycle 945
# Total biomass:
# Model iMM904.cmd: 4.079288896681742E-5
# Model iJN1463.cmd: 7.544444765139038E-5
# Cycle 946
# Total biomass:
# Model iMM904.cmd: 4.0808882008226166E-5
# Model iJN1463.cmd: 7.546869573524127E-5
# Cycle 947
# Total biomass:
# Model iMM904.cmd: 4.082542388890618E-5
# Model iJN1463.cmd: 7.549262416705032E-5
# Cycle 948
# Total biomass:
# Model iMM904.cmd: 4.0839914480313306E-5
# Model iJN1463.cmd: 7.551857949215556E-5
# Cycle 949
# Total biomass:
# Model iMM904.cmd: 4.085199567841025E-5
# Model iJN1463.cmd: 7.554712477757525E-5
# Cycle 950
# Total biomass:
# Model iMM904.cmd: 4.0865082456275934E-5
# Model iJN1463.cmd: 7.557497254133602E-5
# Cycle 951
# Total biomass:
# Model iMM904.cmd: 4.088134646614311E-5
# Model iJN1463.cmd: 7.559866955895451E-5
# Cycle 952
# Total biomass:
# Model iMM904.cmd: 4.0898311114025005E-5
# Model iJN1463.cmd: 7.562155661974041E-5
# Cycle 953
# Total biomass:
# Model iMM904.cmd: 4.091484812581142E-5
# Model iJN1463.cmd: 7.564527943624413E-5
# Cycle 954
# Total biomass:
# Model iMM904.cmd: 4.0931235223358917E-5
# Model iJN1463.cmd: 7.56687356717984E-5
# Cycle 955
# Total biomass:
# Model iMM904.cmd: 4.0947679055261944E-5
# Model iJN1463.cmd: 7.569142414225102E-5
# Cycle 956
# Total biomass:
# Model iMM904.cmd: 4.096370823633648E-5
# Model iJN1463.cmd: 7.571526872415801E-5
# Cycle 957
# Total biomass:
# Model iMM904.cmd: 4.097685154650957E-5
# Model iJN1463.cmd: 7.57417755741336E-5
# Cycle 958
# Total biomass:
# Model iMM904.cmd: 4.0995289982177596E-5
# Model iJN1463.cmd: 7.576259339359718E-5
# Cycle 959
# Total biomass:
# Model iMM904.cmd: 4.101137381717325E-5
# Model iJN1463.cmd: 7.578578108342936E-5
# Cycle 960
# Total biomass:
# Model iMM904.cmd: 4.1025381396795305E-5
# Model iJN1463.cmd: 7.581091388289537E-5
# Cycle 961
# Total biomass:
# Model iMM904.cmd: 4.103940189586198E-5
# Model iJN1463.cmd: 7.583515187397246E-5
# Cycle 962
# Total biomass:
# Model iMM904.cmd: 4.1058175215032904E-5
# Model iJN1463.cmd: 7.585538129407644E-5
# Cycle 963
# Total biomass:
# Model iMM904.cmd: 4.107895913229315E-5
# Model iJN1463.cmd: 7.587581515757526E-5
# Cycle 964
# Total biomass:
# Model iMM904.cmd: 4.109475397972462E-5
# Model iJN1463.cmd: 7.590013218336853E-5
# Cycle 965
# Total biomass:
# Model iMM904.cmd: 4.1111001153327196E-5
# Model iJN1463.cmd: 7.592270971133355E-5
# Cycle 966
# Total biomass:
# Model iMM904.cmd: 4.1126416109237384E-5
# Model iJN1463.cmd: 7.594559665327647E-5
# Cycle 967
# Total biomass:
# Model iMM904.cmd: 4.1141118411468495E-5
# Model iJN1463.cmd: 7.596933969821632E-5
# Cycle 968
# Total biomass:
# Model iMM904.cmd: 4.1157936912225854E-5
# Model iJN1463.cmd: 7.59910399731285E-5
# Cycle 969
# Total biomass:
# Model iMM904.cmd: 4.117729630136804E-5
# Model iJN1463.cmd: 7.601248404657702E-5
# Cycle 970
# Total biomass:
# Model iMM904.cmd: 4.1194224005257694E-5
# Model iJN1463.cmd: 7.603122294124385E-5
# Cycle 971
# Total biomass:
# Model iMM904.cmd: 4.121469591453777E-5
# Model iJN1463.cmd: 7.605596354605827E-5
# Cycle 972
# Total biomass:
# Model iMM904.cmd: 4.1229730620318336E-5
# Model iJN1463.cmd: 7.608199960345316E-5
# Cycle 973
# Total biomass:
# Model iMM904.cmd: 4.1250605419593805E-5
# Model iJN1463.cmd: 7.6107701732563E-5
# Cycle 974
# Total biomass:
# Model iMM904.cmd: 4.1267138373932467E-5
# Model iJN1463.cmd: 7.613247014924149E-5
# Cycle 975
# Total biomass:
# Model iMM904.cmd: 4.1282474218770184E-5
# Model iJN1463.cmd: 7.615684671898112E-5
# Cycle 976
# Total biomass:
# Model iMM904.cmd: 4.130069173289202E-5
# Model iJN1463.cmd: 7.61773189772725E-5
# Cycle 977
# Total biomass:
# Model iMM904.cmd: 4.13192594049928E-5
# Model iJN1463.cmd: 7.619671998489576E-5
# Cycle 978
# Total biomass:
# Model iMM904.cmd: 4.1338309660932465E-5
# Model iJN1463.cmd: 7.621681452350377E-5
# Cycle 979
# Total biomass:
# Model iMM904.cmd: 4.1356242032887013E-5
# Model iJN1463.cmd: 7.623696230331121E-5
# Cycle 980
# Total biomass:
# Model iMM904.cmd: 4.137711842718646E-5
# Model iJN1463.cmd: 7.626018685249328E-5
# Cycle 981
# Total biomass:
# Model iMM904.cmd: 4.139125235398298E-5
# Model iJN1463.cmd: 7.628622428303246E-5
# Cycle 982
# Total biomass:
# Model iMM904.cmd: 4.141595224649042E-5
# Model iJN1463.cmd: 7.631818911977268E-5
# Cycle 983
# Total biomass:
# Model iMM904.cmd: 4.142774353358331E-5
# Model iJN1463.cmd: 7.634349765934709E-5
# Cycle 984
# Total biomass:
# Model iMM904.cmd: 4.145446986890512E-5
# Model iJN1463.cmd: 7.637474615023398E-5
# Cycle 985
# Total biomass:
# Model iMM904.cmd: 4.148412025798116E-5
# Model iJN1463.cmd: 7.640583938293939E-5
# Cycle 986
# Total biomass:
# Model iMM904.cmd: 4.150410500583499E-5
# Model iJN1463.cmd: 7.64314304768446E-5
# Cycle 987
# Total biomass:
# Model iMM904.cmd: 4.152298478970754E-5
# Model iJN1463.cmd: 7.64548761623341E-5
# Cycle 988
# Total biomass:
# Model iMM904.cmd: 4.154379505071624E-5
# Model iJN1463.cmd: 7.647922346140568E-5
# Cycle 989
# Total biomass:
# Model iMM904.cmd: 4.15644646531807E-5
# Model iJN1463.cmd: 7.650518795854998E-5
# Cycle 990
# Total biomass:
# Model iMM904.cmd: 4.1585777478953175E-5
# Model iJN1463.cmd: 7.653922985038182E-5
# Cycle 991
# Total biomass:
# Model iMM904.cmd: 4.160371142039729E-5
# Model iJN1463.cmd: 7.656919675391785E-5
# Cycle 992
# Total biomass:
# Model iMM904.cmd: 4.162461686523808E-5
# Model iJN1463.cmd: 7.65958833206275E-5
# Cycle 993
# Total biomass:
# Model iMM904.cmd: 4.1641770124639485E-5
# Model iJN1463.cmd: 7.66203183070247E-5
# Cycle 994
# Total biomass:
# Model iMM904.cmd: 4.1659856080101036E-5
# Model iJN1463.cmd: 7.664872549631206E-5
# Cycle 995
# Total biomass:
# Model iMM904.cmd: 4.1674491171502106E-5
# Model iJN1463.cmd: 7.667147097444752E-5
# Cycle 996
# Total biomass:
# Model iMM904.cmd: 4.169762685029839E-5
# Model iJN1463.cmd: 7.669808056673861E-5
# Cycle 997
# Total biomass:
# Model iMM904.cmd: 4.1715235861961685E-5
# Model iJN1463.cmd: 7.672255739760526E-5
# Cycle 998
# Total biomass:
# Model iMM904.cmd: 4.173327251542787E-5
# Model iJN1463.cmd: 7.674900626664598E-5
# Cycle 999
# Total biomass:
# Model iMM904.cmd: 4.174710514724554E-5
# Model iJN1463.cmd: 7.676817871330146E-5
# Cycle 1000
# Total biomass:
# Model iMM904.cmd: 4.175413843454729E-5
# Model iJN1463.cmd: 7.678386219622823E-5
# Cycle 1001
# End of simulation
# Total time = 20491.312s
#
# STDERR empty.

# %% [markdown]
# Para revisar la biomasa total

# %%
sim.total_biomass.plot(x = "cycle")
# Out:
# <AxesSubplot:xlabel='cycle'>

# %% [markdown]
# Graficamos los resultados de biomasa y demás metabolitos interesantes en el grid:

# %%
im = sim.get_biomass_image('iMM904', params.all_params['maxCycles'])
im2 = sim.get_biomass_image('iJN1463',params.all_params['maxCycles'])

final = np.zeros((grid_size,grid_size,3))
final[:,:,0] = im / np.max(im)
final[:,:,1] = im2 / np.max(im2)
for rock in rock_locs:
    final[rock[0],rock[1],0:3] = 0.4 
from matplotlib import pyplot as plt
ﬁg, ax = plt.subplots(ﬁgsize = (3.1, 3.1))
ax.imshow(ﬁnal)
plt.imshow(final)

# %%
plt.imshow(sim.get_metabolite_image("succ_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("ac_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("nh4_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("o2_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("catechol_e",params.all_params['maxCycles']))
