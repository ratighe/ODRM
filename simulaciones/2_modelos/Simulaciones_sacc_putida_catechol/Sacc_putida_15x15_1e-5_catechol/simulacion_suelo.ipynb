# %% [markdown]
# **Soil-air interface.**
#
# Using the functionality of COMETS, one can design simulations which go beyond in silico corollaries of lab experiments to make predictions for environments mimicking natural ecosystems, which is a necessary step for understanding natural ecology from first principles. In this example, we consider a simulation of a soil environment. We use source-and-sink functions to model how a root provides organic acids to the environment while removing ammonia (Huang et al 2014 Botany). While we restrict the root functionality to a source/sink, one could use functionality demonstrated above, for example extracellular enzymes, to generate feedback loops between microbe-produced metabolites and root exudation. We use fixed metabolite concentrations to mimic the largely unchanging air interface above a root, which generates an oxygen gradient. Additionally, since soil is characterized by strong spatial structure with many impenetrable barriers that localized interactions (Nunan 2017), we place “rock” barriers throughout the simulation area. A more complex simulation could use varying diffusion constants for metabolites, as described in a previous protocol (Virtual Petri Dish). Similarly, we use standard diffusion of biomass, but this could be changed to use pushing force or non-linear diffusion for a potentially increased realism.

# %%
import cobra 
import sys 
import copy 
import numpy as np 
from matplotlib import pyplot as plt 
import cometspy as c

# %% [markdown]
# Para nuestro proyecto, utilizaremos Escherichia coli (modelo iAF1260), Pseudomonas putida (modelo iJN1463) y Saccharomyces Cerevisiae (modelo iMM904), recuperados de la base de datos BIGG.
#
# Cambiamos los bounds de las funciones objetivo de los modelos:

# %%
model_dir = "./modelos" # model location
iMM = cobra.io.read_sbml_model(model_dir + '/iMM904.xml')
iJN = cobra.io.read_sbml_model(model_dir + '/iJN1463.xml')

iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').lower_bound = 0
iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').upper_bound = 1000

iMM.reactions.get_by_id('BIOMASS_SC5_notrace').lower_bound = 0
iMM.reactions.get_by_id('BIOMASS_SC5_notrace').upper_bound = 1000

# %% [markdown]
# Luego se convierten estos modelos al formato de COMETS. Se utilizan funciones helper para dos cosas: a) Asegurar que el modelo en COMETS no confunda las reacciones de "sink" con las de exchange, ya que en COBRA están desbalanceadas y por tanto se parecen a las de exchange, y b) abrir todos los bounds de las reacciones de exchange, para que COMETS controle la composición del medio.

# %%
iMM_comets = c.model(iMM)
iMM_comets.ensure_sinks_are_not_exchanges()
iMM_comets.open_exchanges()

iJN_comets = c.model(iJN)
iJN_comets.ensure_sinks_are_not_exchanges()
iJN_comets.open_exchanges()

# %% [markdown]
# El mundo que se simulará tendrá dimensiones de 30x30. El eje de la izquierda (x = 0) corresponde a la raíz, y el eje superior (y = 0) corresponde al aire. La biomasa y las rocas se distribuyen en el resto del grid. Donde hayan rocas no puede haber ni biomasa ni metabolitos, así que seleccionamos esos lugares primero. Para esta simulación, se generarán 3 rocas con un un tamaño medio de 1 cuadraditos. Para generar las piedras se utiliza la función helper grow_rocks.

# %%
from cometspy.utils import grow_rocks, pick_random_locations

grid_size = 15 # 100
n_rocks = 27 # 70
rock_locs = grow_rocks(n = n_rocks, xrange = [1,grid_size-1],yrange = [1,grid_size-1],mean_size = 1)

# %% [markdown]
# Cada especie será plantada en 20 lugares sin sobreponerse. Para esto se utiliza la función helper pick_random_locations, la cual toma como argumento una tupla generada anteriormente que marca lugares "prohibidos", como los cuadrados donde se encuentran las rocas.
#
# Generamos una copia de rock_locs para no cambiarla accidentalmente, y la llamamos forbbiden_locs:

# %%
import copy
forbidden_locs = copy.deepcopy(rock_locs)

# %% [markdown]
# Ahora elegimos al azar los lugares para cada especie, y los vamos añadiendo a la lista forbidden locs para que no se sobrepongan:

# %%
founders_per_species = 15 # 60
iMM_locs = pick_random_locations(n = founders_per_species, 
                                   xrange = [1,grid_size], yrange = [1,grid_size], 
                                   forbidden_locs = forbidden_locs)
forbidden_locs.extend(iMM_locs)
iJN_locs = pick_random_locations(founders_per_species, [1,grid_size],[1,grid_size], forbidden_locs)

# %% [markdown]
# Para graficar los lugares utilizamos matplotlib:

# %%
from matplotlib import pyplot as plt
initial_image = np.zeros((grid_size,grid_size,3))
for rock in rock_locs:
    initial_image[rock[0],rock[1],0:3] = 0.5 
for loc in iMM_locs:
    initial_image[loc[0],loc[1],1] = 1
for loc in iJN_locs:
    initial_image[loc[0],loc[1],2] = 1
plt.imshow(initial_image)

# %% [markdown]
# Generamos el layout y agregamos las rocas:

# %%
# iMM
iMM_initial_pop = [] 
for loc in iJN_locs: 
    iMM_initial_pop.append([loc[0], loc[1], 1.e-8]) 
iMM_comets.initial_pop = iMM_initial_pop 
# iJN
iJN_initial_pop = [] 
for loc in iJN_locs: 
    iJN_initial_pop.append([loc[0], loc[1], 1.e-8]) 
iJN_comets.initial_pop = iJN_initial_pop

# %% [markdown]
# Setteamos las poblaciones iniciales para cada especie, con esto los modelos están listos y los añadimos al layout:

# %%
layout = c.layout([iMM_comets, iJN_comets])
layout.grid = [grid_size,grid_size]
layout.add_barriers(rock_locs)

# %% [markdown]
# Añadimos los metabolitos que estarán inicialmente disponibles en el ambiente. Usamos la función helper add_typical_trace_metabolites() para las trazas típicas. Bajamos el valor del oxígeno dado que la idea es que el que esté disponible difunda desde la atmósfera. Añadimos algunos metabolitos que no se añadieron con la función helper:

# %%
layout.add_typical_trace_metabolites()
layout.set_specific_metabolite('o2_e',0.000001)
layout.set_specific_metabolite('hco3_e',1000)
layout.set_specific_metabolite('co2_e',1000)
#layout.set_specific_metabolite('h2_e',1000)
layout.set_specific_metabolite('so3_e',1000)
layout.set_specific_metabolite('nh4_e',0.0000001)

layout.set_specific_metabolite('glc__D_e',0.0000001)
layout.set_specific_metabolite('meoh_e',0.00000001)
layout.set_specific_metabolite('cys__L_e',0.0000001)
layout.set_specific_metabolite('catechol_e',0.00001)

# %% [markdown]
# Para la capa de aire, dejamos el oxígeno en un valor constante. Al fondo también dejamos al oxígeno en un valor fijo e igual a 0, para simular el efecto de difusión. De manera similar, hacemos lo mismo con el amoniaco y la raíz en la parte izquierda:

# %%
# set static media of O2 and CO2 at the top and bottom-- the "air" and continuous loss of O2 downwards
for x in range(grid_size):
    layout.set_specific_static_at_location('o2_e', (x,0), .0001) # top
    layout.set_specific_static_at_location('o2_e', (x,grid_size-1), 0.) # bottom
    layout.set_specific_static_at_location('co2_e', (x,0), .0001)
    
for x in range(grid_size):
    layout.set_specific_static_at_location('nh4_e', (0,x), 0.0)

# %% [markdown]
# La raíz consume todo el amoniaco, pero es una fuente de acidos orgánicos y metanol para el ambiente. Asumiendo una tasa fija:

# %%
for x in range(grid_size):
    layout.set_specific_refresh_at_location('cit_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('meoh_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('succ_e', (0,x), .000001)

# %% [markdown]
# El layout y los modelos están listos, ahora setteamos los parámetros de la simulación:

# %%
params = c.params()
params.set_param('timeStep', 0.1)
params.set_param('maxCycles', 1000)
params.set_param('maxSpaceBiomass', 10)
params.set_param('deathRate', 0.0001) # die at rate of 1/10000 per hour
params.set_param('writeBiomassLog', True)
params.set_param('BiomassLogRate', 500)
params.set_param('writeMediaLog', True)
params.set_param('MediaLogRate', 500)
params.set_param("writeFluxLog", True)
params.set_param("FluxLogRate", 500)
params.set_param('numRunThreads', 3)
params.set_param('defaultKm', 0.000001)

# %% [markdown]
# Ahora creamos el objeto de la simulación y la corremos. Ojito que se demora y el pc empieza a despegar.

# %%
sim = c.comets(layout, params)
sim.run(False)
# Out:
# Running COMETS simulation ...
# C:\Users\mfran\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3357: DtypeWarning: Columns (10,11,13,14,15,16,17,18,23,24,26,27,28,29,30,31,32,35,39,48,51,61,62,68,69,93,95,97,101,102,103,104,105,118,122,135,142,150,152,153,162,169,174,175,177,187,193,195,214,223,225,232,234,236,245,248,249,255,256,257,258,265,274,295,296,301,303,306,315,321,322,324,325,327,331,334,338,339,344,346,348,351,374,375,380,391,392,406,414,415,419,420,423,424,425,426,434,436,437,444,445,449,450,452,453,454,482,507,539,541,546,562,564,594,624,648,653,661,674,676,691,692,695,701,716,719,720,722,726,732,735,736,738,740,744,753,755,760,771,773,782,789,804,806,810,814,822,842,847,849,850,851,869,870,878,879,882,897,925,930,932,934,939,941,942,943,953,961,962,979,982,1006,1014,1016,1018,1022,1026,1036,1040,1050,1053,1061,1063,1068,1071,1074,1078,1079,1082,1086,1087,1091,1093,1095,1113,1115,1116,1126,1128,1130,1132,1141,1142,1150,1159,1164,1165,1166,1176,1180,1182,1183,1184,1188,1194,1197,1204,1213,1214,1216,1217,1219,1227,1228,1229,1233,1237,1254,1261,1262,1265,1277,1278,1279,1280,1284,1286,1294,1304,1307,1308,1316,1317,1332,1333,1334,1336,1340,1344,1346,1347,1354,1355,1359,1361,1365,1369,1370,1372,1375,1396,1406,1414,1415,1416,1424,1426,1439,1443,1447,1453,1472,1481,1484,1487,1488,1491,1505,1514,1520,1526,1531,1533,1534,1535,1536,1539,1544,1546,1548,1549,1552,1553,1554,1555,1556,1557,1558,1562,1569,1571,1573,1577,1580,1585,1586,1587,1588,1589,1590,1601,1624,1625,1629,1631,1632,1641,1645,1655,1663,1665,1666,1674,1678,1680,1698,1739,1740,1741,1764,1765,1766,1767,1768,1769,1771,1772,1775,1784,1785,1787,1788,1797,1809,1811,1812,1813,1814,1873,1874,1875,1902,1910,1911,1914,1915,1918,1923,1924,1925,1926,1933,1934,1945,1946,1984,1985,1986,1987,1988,1990,1991,1993,1994,1996,2004,2085,2133,2134,2135,2140,2156,2162,2167,2168,2197,2200,2202,2210,2219,2225,2227,2241,2242,2244,2249,2250,2251,2252,2254,2256,2257,2263,2264,2269,2281,2288,2304,2322,2354,2371,2373,2389,2391,2392,2401,2402,2410,2420,2423,2426,2427,2428,2429,2431,2453,2474,2477,2479,2480,2532,2533,2534,2575,2594,2601,2602,2607,2608,2609,2639,2668,2673,2694,2712,2714,2715,2719,2720,2729,2731,2733,2762,2763,2766,2783,2817,2819,2888,2900,2911,2912,2913,2917,2918,2919,2930) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
182d9d12_e	taur_e	tcynt_e	thm_e	thmmp_e	thmpp_e	thr__L_e	thym_e	thymd_e	tmanur_e	tnt_e	tol_e	tre_e	trp__L_e	tsul_e	ttdca_e	ttdcea_e	ttrcyc_e	tungs_e	tyr__D_e	tyr__L_e	und2one_e	ura_e	urea_e	uri_e	vacc_e	val__D_e	val__L_e	vanln_e	vanlt_e	xan_e	xtsn_e	xyl__D_e	xylt_e	zn2_e	zymst_e	zymstest_SC_e
# Cycle 1
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# FBARunThread-0 starting up.
# FBARunThread-1 starting up.
# FBARunThread-2 starting up.
# Total biomass:
# Model iMM904.cmd: 1.5806496104830232E-7
# Model iJN1463.cmd: 1.5799097673843122E-7
# Cycle 2
# Total biomass:
# Model iMM904.cmd: 1.6655293323000064E-7
# Model iJN1463.cmd: 1.6639700860625656E-7
# Cycle 3
# Total biomass:
# Model iMM904.cmd: 1.758912499734008E-7
# Model iJN1463.cmd: 1.756179529540148E-7
# Cycle 4
# Total biomass:
# Model iMM904.cmd: 1.8608705145667635E-7
# Model iJN1463.cmd: 1.8561711886529635E-7
# Cycle 5
# Total biomass:
# Model iMM904.cmd: 1.9715269559227225E-7
# Model iJN1463.cmd: 1.9641431914239155E-7
# Cycle 6
# Total biomass:
# Model iMM904.cmd: 2.090679065480485E-7
# Model iJN1463.cmd: 2.0800925758607943E-7
# Cycle 7
# Total biomass:
# Model iMM904.cmd: 2.2186005921198392E-7
# Model iJN1463.cmd: 2.2040886209654127E-7
# Cycle 8
# Total biomass:
# Model iMM904.cmd: 2.3556131877495673E-7
# Model iJN1463.cmd: 2.3365652956620304E-7
# Cycle 9
# Total biomass:
# Model iMM904.cmd: 2.502185309154323E-7
# Model iJN1463.cmd: 2.477933961537974E-7
# Cycle 10
# Total biomass:
# Model iMM904.cmd: 2.6588656478811385E-7
# Model iJN1463.cmd: 2.6285723155658374E-7
# Cycle 11
# Total biomass:
# Model iMM904.cmd: 2.826268494078553E-7
# Model iJN1463.cmd: 2.788916192121139E-7
# Cycle 12
# Total biomass:
# Model iMM904.cmd: 3.0049959414236806E-7
# Model iJN1463.cmd: 2.9594131684807575E-7
# Cycle 13
# Total biomass:
# Model iMM904.cmd: 3.19561451736249E-7
# Model iJN1463.cmd: 3.140524909978791E-7
# Cycle 14
# Total biomass:
# Model iMM904.cmd: 3.398803468322551E-7
# Model iJN1463.cmd: 3.332836793870518E-7
# Cycle 15
# Total biomass:
# Model iMM904.cmd: 3.6151835198036903E-7
# Model iJN1463.cmd: 3.536951135890289E-7
# Cycle 16
# Total biomass:
# Model iMM904.cmd: 3.845508119492711E-7
# Model iJN1463.cmd: 3.7535492055678063E-7
# Cycle 17
# Total biomass:
# Model iMM904.cmd: 4.0905684793058214E-7
# Model iJN1463.cmd: 3.9833486965306725E-7
# Cycle 18
# Total biomass:
# Model iMM904.cmd: 4.351232071609207E-7
# Model iJN1463.cmd: 4.2271202897530386E-7
# Cycle 19
# Total biomass:
# Model iMM904.cmd: 4.627368772009738E-7
# Model iJN1463.cmd: 4.4855317643096905E-7
# Cycle 20
# Total biomass:
# Total biomass:
# Model iMM904.cmd: 1.3638736676688397E-6
# Model iJN1463.cmd: 1.7933550822047789E-6
# Cycle 45
# Total biomass:
# Model iMM904.cmd: 1.4090381072403043E-6
# Model iJN1463.cmd: 1.8898710310012985E-6
# Cycle 46
# Total biomass:
# Model iMM904.cmd: 1.4552665783849173E-6
# Model iJN1463.cmd: 1.991144458012399E-6
# Cycle 47
# Total biomass:
# Model iMM904.cmd: 1.5027110291528373E-6
# Model iJN1463.cmd: 2.0974800070611387E-6
# Cycle 48
# Total biomass:
# Model iMM904.cmd: 1.5513751664403172E-6
# Model iJN1463.cmd: 2.2091715092205363E-6
# Cycle 49
# Total biomass:
# Model iMM904.cmd: 1.6012395062376372E-6
# Model iJN1463.cmd: 2.326503437572037E-6
# Cycle 50
# Total biomass:
# Model iMM904.cmd: 1.652432889806647E-6
# Model iJN1463.cmd: 2.4498443878756093E-6
# Cycle 51
# Total biomass:
# Model iMM904.cmd: 1.7050407156752434E-6
# Model iJN1463.cmd: 2.579533100210401E-6
# Cycle 52
# Total biomass:
# Model iMM904.cmd: 1.7591349373831158E-6
# Model iJN1463.cmd: 2.7159000894094285E-6
# Cycle 53
# Total biomass:
# Model iMM904.cmd: 1.8147774367616974E-6
# Model iJN1463.cmd: 2.859287928875471E-6
# Cycle 54
# Total biomass:
# Model iMM904.cmd: 1.8719530623815979E-6
# Model iJN1463.cmd: 3.009916634920135E-6
# Cycle 55
# Total biomass:
# Model iMM904.cmd: 1.930736571400858E-6
# Model iJN1463.cmd: 3.168148823886861E-6
# Cycle 56
# Total biomass:
# Model iMM904.cmd: 1.9910528684103125E-6
# Model iJN1463.cmd: 3.3340548703708166E-6
# Cycle 57
# Total biomass:
# Model iMM904.cmd: 2.0527780994078954E-6
# Model iJN1463.cmd: 3.507748319474292E-6
# Cycle 58
# Total biomass:
# Model iMM904.cmd: 2.1162151285441886E-6
# Model iJN1463.cmd: 3.689220889591715E-6
# Cycle 59
# Total biomass:
# Model iMM904.cmd: 2.1814936357799785E-6
# Model iJN1463.cmd: 3.878712743281176E-6
# Cycle 60
# Total biomass:
# Model iMM904.cmd: 2.2486286648496606E-6
# Model iJN1463.cmd: 4.0768148263424705E-6
# Cycle 61
# Total biomass:
# Model iMM904.cmd: 2.3177273808924878E-6
# Model iJN1463.cmd: 4.283502175079007E-6
# Cycle 62
# Total biomass:
# Model iMM904.cmd: 2.3886927433674147E-6
# Model iJN1463.cmd: 4.499564739218792E-6
# Cycle 63
# Total biomass:
# Model iMM904.cmd: 2.4617208955577273E-6
# Model iJN1463.cmd: 4.7248962986352995E-6
# Cycle 64
# Total biomass:
# Model iMM904.cmd: 2.53665095672705E-6
# Model iJN1463.cmd: 4.960181018821461E-6
# Cycle 65
# Total biomass:
# Model iMM904.cmd: 2.613623874361141E-6
# Model iJN1463.cmd: 5.205329243057906E-6
# Cycle 66
# Total biomass:
# Model iMM904.cmd: 2.692660416184286E-6
# Model iJN1463.cmd: 5.4609066243984875E-6
# Cycle 67
# Total biomass:
# Model iMM904.cmd: 2.7738668756178932E-6
# Cycle 139
# Total biomass:
# Model iMM904.cmd: 9.013486317585999E-6
# Model iJN1463.cmd: 7.481035037841907E-5
# Cycle 140
# Total biomass:
# Model iMM904.cmd: 9.080329800598313E-6
# Model iJN1463.cmd: 7.708959331571324E-5
# Cycle 141
# Total biomass:
# Model iMM904.cmd: 9.1470303037885E-6
# Model iJN1463.cmd: 7.943656488393106E-5
# Cycle 142
# Total biomass:
# Model iMM904.cmd: 9.213713603427939E-6
# Model iJN1463.cmd: 8.185283700278898E-5
# Cycle 143
# Total biomass:
# Model iMM904.cmd: 9.280394324092607E-6
# Model iJN1463.cmd: 8.434080590148842E-5
# Cycle 144
# Total biomass:
# Model iMM904.cmd: 9.34787232532715E-6
# Model iJN1463.cmd: 8.690102638112221E-5
# Cycle 145
# Total biomass:
# Model iMM904.cmd: 9.415864341245477E-6
# Model iJN1463.cmd: 8.953724657427446E-5
# Cycle 146
# Total biomass:
# Model iMM904.cmd: 9.483792061840134E-6
# Model iJN1463.cmd: 9.225161935695078E-5
# Cycle 147
# Total biomass:
# Model iMM904.cmd: 9.5520239379245E-6
# Model iJN1463.cmd: 9.504629322916776E-5
# Cycle 148
# Total biomass:
# Model iMM904.cmd: 9.619824131234663E-6
# Model iJN1463.cmd: 9.79236884341204E-5
# Cycle 149
# Total biomass:
# Model iMM904.cmd: 9.687328433782357E-6
# Model iJN1463.cmd: 1.0088615265215335E-4
# Cycle 150
# Total biomass:
# Model iMM904.cmd: 9.754625131566597E-6
# Model iJN1463.cmd: 1.0393627600355328E-4
# Cycle 151
# Total biomass:
# Model iMM904.cmd: 9.82197465419446E-6
# Model iJN1463.cmd: 1.07076648969279E-4
# Cycle 152
# Total biomass:
# Model iMM904.cmd: 9.889444028712885E-6
# Model iJN1463.cmd: 1.1030986067279271E-4
# Cycle 153
# Total biomass:
# Model iMM904.cmd: 9.956711379632209E-6
# Model iJN1463.cmd: 1.1363888487409615E-4
# Cycle 154
# Total biomass:
# Model iMM904.cmd: 1.0023893954170313E-5
# Model iJN1463.cmd: 1.1706632276672056E-4
# Cycle 155
# Total biomass:
# Model iMM904.cmd: 1.0091333838867617E-5
# Model iJN1463.cmd: 1.2059494003122969E-4
# Cycle 156
# Total biomass:
# Model iMM904.cmd: 1.0158811903010909E-5
# Model iJN1463.cmd: 1.242280312567684E-4
# Cycle 157
# Total biomass:
# Model iMM904.cmd: 1.0226143078095416E-5
# Model iJN1463.cmd: 1.2796865425095783E-4
# Cycle 158
# Total biomass:
# Model iMM904.cmd: 1.029347249861252E-5
# Model iJN1463.cmd: 1.3181978410558562E-4
# Cycle 159
# Total biomass:
# Model iMM904.cmd: 1.0360676242176874E-5
# Model iJN1463.cmd: 1.357850114489339E-4
# Cycle 160
# Total biomass:
# Model iMM904.cmd: 1.042832785495016E-5
# Model iJN1463.cmd: 1.398676699460206E-4
# Cycle 161
# Total biomass:
# Model iMM904.cmd: 1.0496221817387975E-5
# Model iJN1463.cmd: 1.4407066014047792E-4
# Cycle 162
# Total biomass:
# Model iMM904.cmd: 1.0564240573701369E-5
# Model iJN1463.cmd: 1.4839826728525266E-4
# Cycle 163
# Total biomass:
# Model iMM904.cmd: 1.063155851982257E-5
# Model iJN1463.cmd: 1.528542581114419E-4
# Cycle 164
# Total biomass:
# Model iMM904.cmd: 1.0698825470703276E-5
# Model iJN1463.cmd: 1.5744208508201653E-4
# Cycle 165
# Total biomass:
# Model iMM904.cmd: 1.0766216459060098E-5
# Model iJN1463.cmd: 1.6216563193322166E-4
# Cycle 166
# Total biomass:
# Model iMM904.cmd: 1.0833674741461969E-5
# Model iJN1463.cmd: 1.6702898403103393E-4
# Cycle 167
# Total biomass:
# Model iMM904.cmd: 1.0901072048631875E-5
# Model iJN1463.cmd: 1.7202875172152966E-4
# Cycle 168
# Total biomass:
# Model iMM904.cmd: 1.0968318650486979E-5
# Model iJN1463.cmd: 1.7706769771321613E-4
# Cycle 169
# Total biomass:
# Model iMM904.cmd: 1.1036205766580308E-5
# Model iJN1463.cmd: 1.8199587658454395E-4
# Cycle 170
# Total biomass:
# Model iMM904.cmd: 1.1103727295114279E-5
# Model iJN1463.cmd: 1.8663453232894747E-4
# Cycle 171
# Total biomass:
# Model iMM904.cmd: 1.1171478086972253E-5
# Model iJN1463.cmd: 1.9076122868504067E-4
# Cycle 172
# Total biomass:
# Model iMM904.cmd: 1.1239992025891125E-5
# Model iJN1463.cmd: 1.9397528566746067E-4
# Cycle 173
# Total biomass:
# Model iMM904.cmd: 1.1307444258578012E-5
# Model iJN1463.cmd: 1.9628976655781743E-4
# Cycle 174
# Total biomass:
# Model iMM904.cmd: 1.137544674063655E-5
# Model iJN1463.cmd: 1.9779199033293947E-4
# Cycle 175
# Total biomass:
# Model iMM904.cmd: 1.1443623129019846E-5
# Model iJN1463.cmd: 1.987333707344472E-4
# Cycle 176
# Total biomass:
# Model iMM904.cmd: 1.1511846279100263E-5
# Model iJN1463.cmd: 1.9937604386585084E-4
# Cycle 177
# Total biomass:
# Model iMM904.cmd: 1.1579634263560622E-5
# Model iJN1463.cmd: 1.9985588684617693E-4
# Cycle 178
# Total biomass:
# Model iMM904.cmd: 1.1647757425353112E-5
# Model iJN1463.cmd: 2.0022814233084573E-4
# Cycle 179
# Total biomass:
# Model iMM904.cmd: 1.1715568306442848E-5
# Model iJN1463.cmd: 2.005246127248994E-4
# Cycle 180
# Total biomass:
# Model iMM904.cmd: 1.1783630747096953E-5
# Model iJN1463.cmd: 2.0077051183878622E-4
# Cycle 181
# Total biomass:
# Model iMM904.cmd: 1.1852252065560793E-5
# Model iJN1463.cmd: 2.0098107485579683E-4
# Cycle 182
# Total biomass:
# Model iMM904.cmd: 1.192226730028968E-5
# Model iJN1463.cmd: 2.0116447562620348E-4
# Cycle 183
# Total biomass:
# Model iMM904.cmd: 1.1992275832889376E-5
# Model iJN1463.cmd: 2.0132895920187816E-4
# Cycle 184
# Total biomass:
# Model iMM904.cmd: 1.2062800274548634E-5
# Model iJN1463.cmd: 2.0147897859857145E-4
# Cycle 185
# Total biomass:
# Model iMM904.cmd: 1.2132910499847172E-5
# Model iJN1463.cmd: 2.0161872479572865E-4
# Cycle 186
# Total biomass:
# Model iMM904.cmd: 1.2203685356086946E-5
# Model iJN1463.cmd: 2.0174878123269238E-4
# Cycle 187
# Total biomass:
# Model iMM904.cmd: 1.2274071489277903E-5
# Model iJN1463.cmd: 2.0187333721393634E-4
# Cycle 188
# Total biomass:
# Model iMM904.cmd: 1.2343207715168894E-5
# Model iJN1463.cmd: 2.0199459326376466E-4
# Cycle 189
# Total biomass:
# Model iMM904.cmd: 1.2412340604884362E-5
# Model iJN1463.cmd: 2.021125082419644E-4
# Cycle 190
# Total biomass:
# Model iMM904.cmd: 1.2482488587719643E-5
# Model iJN1463.cmd: 2.0222750463321204E-4
# Cycle 191
# Total biomass:
# Model iMM904.cmd: 1.2553180102063419E-5
# Model iJN1463.cmd: 2.023397149102413E-4
# Cycle 192
# Total biomass:
# Model iMM904.cmd: 1.2623876538844516E-5
# Model iJN1463.cmd: 2.024504754798929E-4
# Cycle 193
# Total biomass:
# Model iMM904.cmd: 1.2694070502015286E-5
# Model iJN1463.cmd: 2.0256061718542493E-4
# Cycle 194
# Total biomass:
# Model iMM904.cmd: 1.2764688220021137E-5
# Model iJN1463.cmd: 2.0266943884465676E-4
# Cycle 195
# Total biomass:
# Model iMM904.cmd: 1.283512166754524E-5
# Model iJN1463.cmd: 2.0277773555952682E-4
# Cycle 196
# Total biomass:
# Model iMM904.cmd: 1.2904423946041908E-5
# Model iJN1463.cmd: 2.0288701524078602E-4
# Cycle 197
# Total biomass:
# Model iMM904.cmd: 1.2973368407020664E-5
# Model iJN1463.cmd: 2.029961194760338E-4
# Cycle 198
# Total biomass:
# Model iMM904.cmd: 1.3043771155360895E-5
# Model iJN1463.cmd: 2.0310355438381544E-4
# Cycle 199
# Total biomass:
# Model iMM904.cmd: 1.3114619213613076E-5
# Model iJN1463.cmd: 2.0321094727208995E-4
# Cycle 200
# Total biomass:
# Model iMM904.cmd: 1.3185019249226609E-5
# Model iJN1463.cmd: 2.0331878798834948E-4
# Cycle 201
# Total biomass:
# Model iMM904.cmd: 1.3254187821865908E-5
# Model iJN1463.cmd: 2.0342681251875395E-4
# Cycle 202
# Total biomass:
# Model iMM904.cmd: 1.3321422055971418E-5
# Model iJN1463.cmd: 2.0353714070638448E-4
# Cycle 203
# Total biomass:
# Model iMM904.cmd: 1.3390561163250313E-5
# Model iJN1463.cmd: 2.0364570372178667E-4
# Cycle 204
# Total biomass:
# Model iMM904.cmd: 1.346033299726674E-5
# Model iJN1463.cmd: 2.037534090795224E-4
# Cycle 205
# Total biomass:
# Model iMM904.cmd: 1.3530188725854927E-5
# Model iJN1463.cmd: 2.038608165039012E-4
# Cycle 206
# Total biomass:
# Model iMM904.cmd: 1.3599784755880931E-5
# Model iJN1463.cmd: 2.0396786206623192E-4
# Cycle 207
# Total biomass:
# Model iMM904.cmd: 1.3668808162823247E-5
# Model iJN1463.cmd: 2.040754199124632E-4
# Cycle 208
# Total biomass:
# Model iMM904.cmd: 1.3738166328212045E-5
# Model iJN1463.cmd: 2.0418226245395862E-4
# Cycle 209
# Total biomass:
# Model iMM904.cmd: 1.3807484556749848E-5
# Model iJN1463.cmd: 2.0428989051039892E-4
# Cycle 210
# Total biomass:
# Model iMM904.cmd: 1.3876276659052274E-5
# Model iJN1463.cmd: 2.0439721451169957E-4
# Cycle 211
# Total biomass:
# Model iMM904.cmd: 1.3941560086984093E-5
# Model iJN1463.cmd: 2.0450773036809598E-4
# Cycle 212
# Total biomass:
# Model iMM904.cmd: 1.4005278223428905E-5
# Model iJN1463.cmd: 2.0461994671627662E-4
# Cycle 213
# Total biomass:
# Model iMM904.cmd: 1.4067510795939645E-5
# Model iJN1463.cmd: 2.0473345157663464E-4
# Cycle 214
# Total biomass:
# Model iMM904.cmd: 1.4133136023458232E-5
# Model iJN1463.cmd: 2.0484355722723635E-4
# Cycle 215
# Total biomass:
# Model iMM904.cmd: 1.4198030795600614E-5
# Model iJN1463.cmd: 2.0495417374873274E-4
# Cycle 216
# Total biomass:
# Model iMM904.cmd: 1.4264593235636444E-5
# Model iJN1463.cmd: 2.0506332487119265E-4
# Cycle 217
# Total biomass:
# Model iMM904.cmd: 1.433073103444047E-5
# Model iJN1463.cmd: 2.0517118046235755E-4
# Cycle 218
# Total biomass:
# Model iMM904.cmd: 1.4396750835595628E-5
# Model iJN1463.cmd: 2.0527859831833358E-4
# Cycle 219
# Total biomass:
# Model iMM904.cmd: 1.4463375821067028E-5
# Model iJN1463.cmd: 2.053855991448018E-4
# Cycle 220
# Total biomass:
# Model iMM904.cmd: 1.4527591457332895E-5
# Model iJN1463.cmd: 2.0549486377058232E-4
# Cycle 221
# Total biomass:
# Model iMM904.cmd: 1.4591130253233312E-5
# Model iJN1463.cmd: 2.0560431851827728E-4
# Cycle 222
# Total biomass:
# Model iMM904.cmd: 1.4653349025497057E-5
# Model iJN1463.cmd: 2.0571476917050622E-4
# Cycle 223
# Total biomass:
# Model iMM904.cmd: 1.4715156793888881E-5
# Model iJN1463.cmd: 2.05825403088866E-4
# Cycle 224
# Total biomass:
# Model iMM904.cmd: 1.4781317116013996E-5
# Model iJN1463.cmd: 2.059315985948413E-4
# Cycle 225
# Total biomass:
# Model iMM904.cmd: 1.484553783302904E-5
# Model iJN1463.cmd: 2.060405948675708E-4
# Cycle 226
# Total biomass:
# Model iMM904.cmd: 1.4912180077969577E-5
# Model iJN1463.cmd: 2.0614593774725813E-4
# Cycle 227
# Total biomass:
# Model iMM904.cmd: 1.4974872646038254E-5
# Model iJN1463.cmd: 2.0625497350062577E-4
# Cycle 228
# Total biomass:
# Model iMM904.cmd: 1.5039729537030266E-5
# Model iJN1463.cmd: 2.063616247061507E-4
# Cycle 229
# Total biomass:
# Model iMM904.cmd: 1.5101316531185304E-5
# Model iJN1463.cmd: 2.064709599175822E-4
# Cycle 230
# Total biomass:
# Model iMM904.cmd: 1.516511478133027E-5
# Model iJN1463.cmd: 2.0657824915070353E-4
# Cycle 231
# Total biomass:
# Model iMM904.cmd: 1.5231603050324863E-5
# Model iJN1463.cmd: 2.0668349442069247E-4
# Cycle 232
# Total biomass:
# Model iMM904.cmd: 1.5298517395611813E-5
# Model iJN1463.cmd: 2.067879654126808E-4
# Cycle 233
# Total biomass:
# Model iMM904.cmd: 1.536190678523704E-5
# Model iJN1463.cmd: 2.0689663665327047E-4
# Cycle 234
# Total biomass:
# Model iMM904.cmd: 1.542368256097543E-5
# Model iJN1463.cmd: 2.0700596426681254E-4
# Cycle 235
# Total biomass:
# Model iMM904.cmd: 1.5488255019380123E-5
# Model iJN1463.cmd: 2.071122208354276E-4
# Cycle 236
# Total biomass:
# Model iMM904.cmd: 1.5549141283238553E-5
# Model iJN1463.cmd: 2.072212887367572E-4
# Cycle 237
# Total biomass:
# Model iMM904.cmd: 1.560888268349353E-5
# Model iJN1463.cmd: 2.073339622686939E-4
# Cycle 238
# Total biomass:
# Model iMM904.cmd: 1.5669411749737914E-5
# Model iJN1463.cmd: 2.0744800834387504E-4
# Cycle 239
# Total biomass:
# Model iMM904.cmd: 1.5729026866750366E-5
# Model iJN1463.cmd: 2.0756246898497054E-4
# Cycle 240
# Total biomass:
# Model iMM904.cmd: 1.578655129264502E-5
# Model iJN1463.cmd: 2.0767613369656826E-4
# Cycle 241
# Total biomass:
# Model iMM904.cmd: 1.584784337107452E-5
# Model iJN1463.cmd: 2.077844979713187E-4
# Cycle 242
# Total biomass:
# Model iMM904.cmd: 1.5911236931974187E-5
# Model iJN1463.cmd: 2.078917213393281E-4
# Cycle 243
# Total biomass:
# Model iMM904.cmd: 1.597543567746165E-5
# Model iJN1463.cmd: 2.0799730279199655E-4
# Cycle 244
# Total biomass:
# Model iMM904.cmd: 1.6037059063924767E-5
# Model iJN1463.cmd: 2.081049088317359E-4
# Cycle 245
# Total biomass:
# Model iMM904.cmd: 1.6096686010516544E-5
# Model iJN1463.cmd: 2.0821371760525818E-4
# Cycle 246
# Total biomass:
# Model iMM904.cmd: 1.615556299333418E-5
# Model iJN1463.cmd: 2.0832303897307594E-4
# Cycle 247
# Total biomass:
# Model iMM904.cmd: 1.621457146106661E-5
# Model iJN1463.cmd: 2.0843211920924698E-4
# Cycle 248
# Total biomass:
# Model iMM904.cmd: 1.6280332127306827E-5
# Model iJN1463.cmd: 2.0853506888145537E-4
# Cycle 249
# Total biomass:
# Model iMM904.cmd: 1.6339194347276046E-5
# Model iJN1463.cmd: 2.0864420197993973E-4
# Cycle 250
# Total biomass:
# Model iMM904.cmd: 1.6396099411396216E-5
# Model iJN1463.cmd: 2.087550195544254E-4
# Cycle 251
# Total biomass:
# Model iMM904.cmd: 1.6454717193004385E-5
# Model iJN1463.cmd: 2.0886389178179424E-4
# Cycle 252
# Total biomass:
# Model iMM904.cmd: 1.651071799208539E-5
# Model iJN1463.cmd: 2.089744949034594E-4
# Cycle 253
# Total biomass:
# Model iMM904.cmd: 1.6566299504849223E-5
# Model iJN1463.cmd: 2.09086411030669E-4
# Cycle 254
# Total biomass:
# Model iMM904.cmd: 1.662724949030974E-5
# Model iJN1463.cmd: 2.0919292935710988E-4
# Cycle 255
# Total biomass:
# Model iMM904.cmd: 1.6689621544277247E-5
# Model iJN1463.cmd: 2.0929766584125778E-4
# Cycle 256
# Total biomass:
# Model iMM904.cmd: 1.6747981669335217E-5
# Model iJN1463.cmd: 2.094053745649409E-4
# Cycle 257
# Total biomass:
# Model iMM904.cmd: 1.6811541457233093E-5
# Model iJN1463.cmd: 2.0950863312596682E-4
# Cycle 258
# Total biomass:
# Model iMM904.cmd: 1.687377212655034E-5
# Model iJN1463.cmd: 2.0961252742993656E-4
# Cycle 259
# Total biomass:
# Model iMM904.cmd: 1.6933391811901864E-5
# Model iJN1463.cmd: 2.097222198753005E-4
# Cycle 260
# Total biomass:
# Model iMM904.cmd: 1.6991837862971556E-5
# Model iJN1463.cmd: 2.098279607788974E-4
# Cycle 261
# Total biomass:
# Model iMM904.cmd: 1.705145445516758E-5
# Model iJN1463.cmd: 2.0993429709036975E-4
# Cycle 262
# Total biomass:
# Model iMM904.cmd: 1.7114629378956147E-5
# Model iJN1463.cmd: 2.1003605269365535E-4
# Cycle 263
# Total biomass:
# Model iMM904.cmd: 1.717724579264413E-5
# Model iJN1463.cmd: 2.101405619353637E-4
# Cycle 264
# Total biomass:
# Model iMM904.cmd: 1.7237802765591876E-5
# Model iJN1463.cmd: 2.102451417120193E-4
# Cycle 265
# Total biomass:
# Model iMM904.cmd: 1.7295210366048165E-5
# Model iJN1463.cmd: 2.1035137168395052E-4
# Cycle 266
# Total biomass:
# Model iMM904.cmd: 1.7349007368518863E-5
# Model iJN1463.cmd: 2.1046223670016903E-4
# Cycle 267
# Total biomass:
# Model iMM904.cmd: 1.740864880705263E-5
# Model iJN1463.cmd: 2.105693195387342E-4
# Cycle 268
# Total biomass:
# Model iMM904.cmd: 1.74695110486721E-5
# Model iJN1463.cmd: 2.106754918497187E-4
# Cycle 269
# Total biomass:
# Model iMM904.cmd: 1.7528771503043355E-5
# Model iJN1463.cmd: 2.1078246352221932E-4
# Cycle 270
# Total biomass:
# Model iMM904.cmd: 1.7587630043045435E-5
# Model iJN1463.cmd: 2.1088799610923697E-4
# Cycle 271
# Total biomass:
# Model iMM904.cmd: 1.7648304056423605E-5
# Model iJN1463.cmd: 2.10990210682591E-4
# Cycle 272
# Total biomass:
# Model iMM904.cmd: 1.770526062378079E-5
# Model iJN1463.cmd: 2.1109637725769785E-4
# Cycle 273
# Total biomass:
# Model iMM904.cmd: 1.7761785804253717E-5
# Model iJN1463.cmd: 2.1120419799813104E-4
# Cycle 274
# Total biomass:
# Model iMM904.cmd: 1.7817115234287995E-5
# Model iJN1463.cmd: 2.1131178799249712E-4
# Cycle 275
# Total biomass:
# Model iMM904.cmd: 1.78746115836421E-5
# Model iJN1463.cmd: 2.1141561429373243E-4
# Cycle 276
# Total biomass:
# Model iMM904.cmd: 1.793257977537849E-5
# Model iJN1463.cmd: 2.1151706796592644E-4
# Cycle 277
# Total biomass:
# Model iMM904.cmd: 1.7993040829499072E-5
# Model iJN1463.cmd: 2.11621868232491E-4
# Cycle 278
# Total biomass:
# Model iMM904.cmd: 1.805302500948724E-5
# Model iJN1463.cmd: 2.117229968071117E-4
# Cycle 279
# Total biomass:
# Model iMM904.cmd: 1.8110898850486064E-5
# Model iJN1463.cmd: 2.1182582429217327E-4
# Cycle 280
# Total biomass:
# Model iMM904.cmd: 1.8168074660008074E-5
# Model iJN1463.cmd: 2.119288995254004E-4
# Cycle 281
# Total biomass:
# Model iMM904.cmd: 1.8224926581948996E-5
# Model iJN1463.cmd: 2.1203226932560483E-4
# Cycle 282
# Total biomass:
# Model iMM904.cmd: 1.828334722703153E-5
# Model iJN1463.cmd: 2.1213438029323156E-4
# Cycle 283
# Total biomass:
# Model iMM904.cmd: 1.8342220943766997E-5
# Model iJN1463.cmd: 2.122352683828869E-4
# Cycle 284
# Total biomass:
# Model iMM904.cmd: 1.840235964073053E-5
# Model iJN1463.cmd: 2.1233462827404317E-4
# Cycle 285
# Total biomass:
# Model iMM904.cmd: 1.846216252778568E-5
# Model iJN1463.cmd: 2.1243487668014092E-4
# Cycle 286
# Total biomass:
# Model iMM904.cmd: 1.851708443272599E-5
# Model iJN1463.cmd: 2.1253732439014571E-4
# Cycle 287
# Total biomass:
# Model iMM904.cmd: 1.8574182644702716E-5
# Model iJN1463.cmd: 2.1263793757853668E-4
# Cycle 288
# Total biomass:
# Model iMM904.cmd: 1.8631431987692093E-5
# Model iJN1463.cmd: 2.1273985017906065E-4
# Cycle 289
# Total biomass:
# Model iMM904.cmd: 1.868866078161367E-5
# Model iJN1463.cmd: 2.1283998835920715E-4
# Cycle 290
# Total biomass:
# Model iMM904.cmd: 1.8744249099156638E-5
# Model iJN1463.cmd: 2.1294056766494788E-4
# Cycle 291
# Total biomass:
# Model iMM904.cmd: 1.8803249670444173E-5
# Model iJN1463.cmd: 2.1303926725036834E-4
# Cycle 292
# Total biomass:
# Model iMM904.cmd: 1.8856174742841884E-5
# Model iJN1463.cmd: 2.131427461926628E-4
# Cycle 293
# Total biomass:
# Model iMM904.cmd: 1.8908457525399632E-5
# Model iJN1463.cmd: 2.132448639997269E-4
# Cycle 294
# Total biomass:
# Model iMM904.cmd: 1.8964231607347704E-5
# Model iJN1463.cmd: 2.1334580557037444E-4
# Cycle 295
# Total biomass:
# Model iMM904.cmd: 1.9020273988106262E-5
# Model iJN1463.cmd: 2.134459806976418E-4
# Cycle 296
# Total biomass:
# Model iMM904.cmd: 1.907636390562104E-5
# Model iJN1463.cmd: 2.1354849164938617E-4
# Cycle 297
# Total biomass:
# Model iMM904.cmd: 1.9127443974349125E-5
# Model iJN1463.cmd: 2.1365145697887366E-4
# Cycle 298
# Total biomass:
# Model iMM904.cmd: 1.9177878372925044E-5
# Model iJN1463.cmd: 2.1375369432679822E-4
# Cycle 299
# Total biomass:
# Model iMM904.cmd: 1.92305877910054E-5
# Model iJN1463.cmd: 2.1385334118979496E-4
# Cycle 300
# Total biomass:
# Model iMM904.cmd: 1.928660208928816E-5
# Model iJN1463.cmd: 2.1395167231761178E-4
# Cycle 301
# Total biomass:
# Model iMM904.cmd: 1.9344010854435E-5
# Model iJN1463.cmd: 2.1404896834464516E-4
# Cycle 302
# Total biomass:
# Model iMM904.cmd: 1.939732575843929E-5
# Model iJN1463.cmd: 2.14152236744514E-4
# Cycle 303
# Total biomass:
# Model iMM904.cmd: 1.9453857022937702E-5
# Model iJN1463.cmd: 2.1425079153598251E-4
# Cycle 304
# Total biomass:
# Model iMM904.cmd: 1.9512854896713183E-5
# Model iJN1463.cmd: 2.1434692262169345E-4
# Cycle 305
# Total biomass:
# Model iMM904.cmd: 1.956965656422571E-5
# Model iJN1463.cmd: 2.1444416191593186E-4
# Cycle 306
# Total biomass:
# Model iMM904.cmd: 1.9626130707878835E-5
# Model iJN1463.cmd: 2.145419408923431E-4
# Cycle 307
# Total biomass:
# Model iMM904.cmd: 1.9684482808772393E-5
# Model iJN1463.cmd: 2.1463856219296605E-4
# Cycle 308
# Total biomass:
# Model iMM904.cmd: 1.974082185440641E-5
# Model iJN1463.cmd: 2.1473461553093455E-4
# Cycle 309
# Total biomass:
# Model iMM904.cmd: 1.979757108173501E-5
# Model iJN1463.cmd: 2.14830852704264E-4
# Cycle 310
# Total biomass:
# Model iMM904.cmd: 1.9852823784042892E-5
# Model iJN1463.cmd: 2.149263047369737E-4
# Cycle 311
# Total biomass:
# Model iMM904.cmd: 1.9905886012431066E-5
# Model iJN1463.cmd: 2.1502430060742786E-4
# Cycle 312
# Total biomass:
# Model iMM904.cmd: 1.9961372564586553E-5
# Model iJN1463.cmd: 2.1511963171140988E-4
# Cycle 313
# Total biomass:
# Model iMM904.cmd: 2.001868170693556E-5
# Model iJN1463.cmd: 2.1521328394658764E-4
# Cycle 314
# Total biomass:
# Model iMM904.cmd: 2.0074257404145922E-5
# Model iJN1463.cmd: 2.153095268746151E-4
# Cycle 315
# Total biomass:
# Model iMM904.cmd: 2.013202371541644E-5
# Model iJN1463.cmd: 2.1540271930616754E-4
# Cycle 316
# Total biomass:
# Model iMM904.cmd: 2.0190398018712462E-5
# Model iJN1463.cmd: 2.1549593624084715E-4
# Cycle 317
# Total biomass:
# Model iMM904.cmd: 2.024535254797274E-5
# Model iJN1463.cmd: 2.1559033400698116E-4
# Cycle 318
# Total biomass:
# Model iMM904.cmd: 2.030226036598653E-5
# Model iJN1463.cmd: 2.1568067474581488E-4
# Cycle 319
# Total biomass:
# Model iMM904.cmd: 2.0358705454124483E-5
# Model iJN1463.cmd: 2.1577111768914504E-4
# Cycle 320
# Total biomass:
# Model iMM904.cmd: 2.0411035217357447E-5
# Model iJN1463.cmd: 2.1586473754818297E-4
# Cycle 321
# Total biomass:
# Model iMM904.cmd: 2.0464358095199404E-5
# Model iJN1463.cmd: 2.159580173029852E-4
# Cycle 322
# Total biomass:
# Model iMM904.cmd: 2.0517750049505588E-5
# Model iJN1463.cmd: 2.1605141349030876E-4
# Cycle 323
# Total biomass:
# Model iMM904.cmd: 2.0573593611802557E-5
# Model iJN1463.cmd: 2.161457419586858E-4
# Cycle 324
# Total biomass:
# Model iMM904.cmd: 2.0631686160157582E-5
# Model iJN1463.cmd: 2.162361354119273E-4
# Cycle 325
# Total biomass:
# Model iMM904.cmd: 2.0689352981285485E-5
# Model iJN1463.cmd: 2.163272559485733E-4
# Cycle 326
# Total biomass:
# Model iMM904.cmd: 2.0745151024531485E-5
# Model iJN1463.cmd: 2.1641630778505827E-4
# Cycle 327
# Total biomass:
# Model iMM904.cmd: 2.080240668877565E-5
# Model iJN1463.cmd: 2.165088779909485E-4
# Cycle 328
# Total biomass:
# Model iMM904.cmd: 2.086056720169912E-5
# Model iJN1463.cmd: 2.1659898709674256E-4
# Cycle 329
# Total biomass:
# Model iMM904.cmd: 2.0917269690172002E-5
# Model iJN1463.cmd: 2.1668633490712407E-4
# Cycle 330
# Total biomass:
# Model iMM904.cmd: 2.0974316357075186E-5
# Model iJN1463.cmd: 2.1677467596318466E-4
# Cycle 331
# Total biomass:
# Model iMM904.cmd: 2.103250574618943E-5
# Model iJN1463.cmd: 2.168628816503611E-4
# Cycle 332
# Total biomass:
# Model iMM904.cmd: 2.108694335702066E-5
# Model iJN1463.cmd: 2.1695433494285286E-4
# Cycle 333
# Total biomass:
# Model iMM904.cmd: 2.1145595025959638E-5
# Model iJN1463.cmd: 2.1704144326259293E-4
# Cycle 334
# Total biomass:
# Model iMM904.cmd: 2.1205294639097074E-5
# Model iJN1463.cmd: 2.1713017471386325E-4
# Cycle 335
# Total biomass:
# Model iMM904.cmd: 2.1263435903990834E-5
# Model iJN1463.cmd: 2.172162908555323E-4
# Cycle 336
# Total biomass:
# Model iMM904.cmd: 2.1318099440021472E-5
# Model iJN1463.cmd: 2.1730569745112734E-4
# Cycle 337
# Total biomass:
# Model iMM904.cmd: 2.1374789977085777E-5
# Model iJN1463.cmd: 2.1739045540876813E-4
# Cycle 338
# Total biomass:
# Model iMM904.cmd: 2.142345529740197E-5
# Model iJN1463.cmd: 2.1748856542539883E-4
# Cycle 339
# Total biomass:
# Model iMM904.cmd: 2.147548850006143E-5
# Model iJN1463.cmd: 2.1757807937432562E-4
# Cycle 340
# Total biomass:
# Model iMM904.cmd: 2.152875695156451E-5
# Model iJN1463.cmd: 2.1766375660523695E-4
# Cycle 341
# Total biomass:
# Model iMM904.cmd: 2.1585621066033404E-5
# Model iJN1463.cmd: 2.17752444704899E-4
# Cycle 342
# Total biomass:
# Model iMM904.cmd: 2.164165629563715E-5
# Model iJN1463.cmd: 2.178401284234324E-4
# Cycle 343
# Total biomass:
# Model iMM904.cmd: 2.1698279096199884E-5
# Model iJN1463.cmd: 2.1792659496384885E-4
# Cycle 344
# Total biomass:
# Model iMM904.cmd: 2.175600993517822E-5
# Model iJN1463.cmd: 2.1801138054720732E-4
# Cycle 345
# Total biomass:
# Model iMM904.cmd: 2.1812697370042925E-5
# Model iJN1463.cmd: 2.180960442994689E-4
# Cycle 346
# Total biomass:
# Model iMM904.cmd: 2.1869583611611264E-5
# Model iJN1463.cmd: 2.1817986547595104E-4
# Cycle 347
# Total biomass:
# Model iMM904.cmd: 2.192871058953191E-5
# Model iJN1463.cmd: 2.182638557988134E-4
# Cycle 348
# Total biomass:
# Model iMM904.cmd: 2.1981277255903293E-5
# Model iJN1463.cmd: 2.1835421126441577E-4
# Cycle 349
# Total biomass:
# Model iMM904.cmd: 2.2037054246216916E-5
# Model iJN1463.cmd: 2.184392023233856E-4
# Cycle 350
# Total biomass:
# Model iMM904.cmd: 2.209526251226265E-5
# Model iJN1463.cmd: 2.1852184813252006E-4
# Cycle 351
# Total biomass:
# Model iMM904.cmd: 2.2151765375854968E-5
# Model iJN1463.cmd: 2.1860486014949024E-4
# Cycle 352
# Total biomass:
# Model iMM904.cmd: 2.2208855834650325E-5
# Model iJN1463.cmd: 2.1868766732902222E-4
# Cycle 353
# Total biomass:
# Model iMM904.cmd: 2.2265800670190462E-5
# Model iJN1463.cmd: 2.187698186258992E-4
# Cycle 354
# Total biomass:
# Model iMM904.cmd: 2.231946662401924E-5
# Model iJN1463.cmd: 2.1885508349007955E-4
# Cycle 355
# Total biomass:
# Model iMM904.cmd: 2.2375280295430744E-5
# Model iJN1463.cmd: 2.189381110715968E-4
# Cycle 356
# Total biomass:
# Model iMM904.cmd: 2.2435195530344768E-5
# Model iJN1463.cmd: 2.1901582889476145E-4
# Cycle 357
# Total biomass:
# Model iMM904.cmd: 2.2492486949321578E-5
# Model iJN1463.cmd: 2.1909554181648042E-4
# Cycle 358
# Total biomass:
# Model iMM904.cmd: 2.254892031399708E-5
# Model iJN1463.cmd: 2.1917666573048158E-4
# Cycle 359
# Total biomass:
# Model iMM904.cmd: 2.2606919634461173E-5
# Model iJN1463.cmd: 2.1925799169099301E-4
# Cycle 360
# Total biomass:
# Model iMM904.cmd: 2.2666193605316264E-5
# Model iJN1463.cmd: 2.19333640860215E-4
# Cycle 361
# Total biomass:
# Model iMM904.cmd: 2.272331977715626E-5
# Model iJN1463.cmd: 2.1941302613994956E-4
# Cycle 362
# Total biomass:
# Model iMM904.cmd: 2.2782417109049587E-5
# Model iJN1463.cmd: 2.1948998766088432E-4
# Cycle 363
# Total biomass:
# Model iMM904.cmd: 2.284025686459591E-5
# Model iJN1463.cmd: 2.195662319105057E-4
# Cycle 364
# Total biomass:
# Model iMM904.cmd: 2.2899294423952692E-5
# Model iJN1463.cmd: 2.1964187034710354E-4
# Cycle 365
# Total biomass:
# Model iMM904.cmd: 2.2959404022741493E-5
# Model iJN1463.cmd: 2.1971817198620554E-4
# Cycle 366
# Total biomass:
# Model iMM904.cmd: 2.301547283812836E-5
# Model iJN1463.cmd: 2.1980319477095988E-4
# Cycle 367
# Total biomass:
# Model iMM904.cmd: 2.3073832559511042E-5
# Model iJN1463.cmd: 2.1988105228907764E-4
# Cycle 368
# Total biomass:
# Model iMM904.cmd: 2.3135695332332112E-5
# Model iJN1463.cmd: 2.199547966305139E-4
# Cycle 369
# Total biomass:
# Model iMM904.cmd: 2.3196008216533495E-5
# Model iJN1463.cmd: 2.2003250356195507E-4
# Cycle 370
# Total biomass:
# Model iMM904.cmd: 2.325441086832305E-5
# Model iJN1463.cmd: 2.2010953028633927E-4
# Cycle 371
# Total biomass:
# Model iMM904.cmd: 2.331592626596582E-5
# Model iJN1463.cmd: 2.2019561819207675E-4
# Cycle 372
# Total biomass:
# Model iMM904.cmd: 2.3380324245753148E-5
# Model iJN1463.cmd: 2.2027875751219844E-4
# Cycle 373
# Total biomass:
# Model iMM904.cmd: 2.3442750648199534E-5
# Model iJN1463.cmd: 2.2035443766901436E-4
# Cycle 374
# Total biomass:
# Model iMM904.cmd: 2.3502416004095927E-5
# Model iJN1463.cmd: 2.2042886077691136E-4
# Cycle 375
# Total biomass:
# Model iMM904.cmd: 2.3563541840391746E-5
# Model iJN1463.cmd: 2.2050037116350403E-4
# Cycle 376
# Total biomass:
# Model iMM904.cmd: 2.3625243992961243E-5
# Model iJN1463.cmd: 2.2056943226970633E-4
# Cycle 377
# Total biomass:
# Model iMM904.cmd: 2.3681756935884607E-5
# Model iJN1463.cmd: 2.2064631733341734E-4
# Cycle 378
# Total biomass:
# Model iMM904.cmd: 2.3743082562114856E-5
# Model iJN1463.cmd: 2.2071547399286535E-4
# Cycle 379
# Total biomass:
# Model iMM904.cmd: 2.3806193013066652E-5
# Model iJN1463.cmd: 2.2078693454972723E-4
# Cycle 380
# Total biomass:
# Model iMM904.cmd: 2.3867243123221296E-5
# Model iJN1463.cmd: 2.208582730267864E-4
# Cycle 381
# Total biomass:
# Model iMM904.cmd: 2.3924431849395355E-5
# Model iJN1463.cmd: 2.209323688775324E-4
# Cycle 382
# Total biomass:
# Model iMM904.cmd: 2.398560200868347E-5
# Model iJN1463.cmd: 2.2100160292360527E-4
# Cycle 383
# Total biomass:
# Model iMM904.cmd: 2.4043800098176172E-5
# Model iJN1463.cmd: 2.2107295136765707E-4
# Cycle 384
# Total biomass:
# Model iMM904.cmd: 2.409828099111562E-5
# Model iJN1463.cmd: 2.2114823881443568E-4
# Cycle 385
# Total biomass:
# Model iMM904.cmd: 2.4155602126307698E-5
# Model iJN1463.cmd: 2.21220030899291E-4
# Cycle 386
# Total biomass:
# Model iMM904.cmd: 2.4214218869519916E-5
# Model iJN1463.cmd: 2.2129061761149704E-4
# Cycle 387
# Total biomass:
# Model iMM904.cmd: 2.426811137423746E-5
# Model iJN1463.cmd: 2.213669602262202E-4
# Cycle 388
# Total biomass:
# Model iMM904.cmd: 2.4324194660862316E-5
# Model iJN1463.cmd: 2.214403911096487E-4
# Cycle 389
# Total biomass:
# Model iMM904.cmd: 2.438634769429528E-5
# Model iJN1463.cmd: 2.215054848872585E-4
# Cycle 390
# Total biomass:
# Model iMM904.cmd: 2.444869993827827E-5
# Model iJN1463.cmd: 2.2157013792878936E-4
# Cycle 391
# Total biomass:
# Model iMM904.cmd: 2.451062271312114E-5
# Model iJN1463.cmd: 2.2163491091662887E-4
# Cycle 392
# Total biomass:
# Model iMM904.cmd: 2.4570999188400974E-5
# Model iJN1463.cmd: 2.2170081107396737E-4
# Cycle 393
# Total biomass:
# Model iMM904.cmd: 2.462872960081208E-5
# Model iJN1463.cmd: 2.2176935127032774E-4
# Cycle 394
# Total biomass:
# Model iMM904.cmd: 2.4686081949879913E-5
# Model iJN1463.cmd: 2.218377669334225E-4
# Cycle 395
# Total biomass:
# Model iMM904.cmd: 2.4741893830160148E-5
# Model iJN1463.cmd: 2.219074331339246E-4
# Cycle 396
# Total biomass:
# Model iMM904.cmd: 2.4796345224447636E-5
# Model iJN1463.cmd: 2.2197822721688827E-4
# Cycle 397
# Total biomass:
# Model iMM904.cmd: 2.485815964113063E-5
# Model iJN1463.cmd: 2.220406208052351E-4
# Cycle 398
# Total biomass:
# Model iMM904.cmd: 2.4916420667379955E-5
# Model iJN1463.cmd: 2.221067783152463E-4
# Cycle 399
# Total biomass:
# Model iMM904.cmd: 2.4972987203321688E-5
# Model iJN1463.cmd: 2.2217494909020698E-4
# Cycle 400
# Total biomass:
# Model iMM904.cmd: 2.5029421531965912E-5
# Model iJN1463.cmd: 2.2224376503518018E-4
# Cycle 401
# Total biomass:
# Model iMM904.cmd: 2.5085658916177325E-5
# Model iJN1463.cmd: 2.2231138105317636E-4
# Cycle 402
# Total biomass:
# Model iMM904.cmd: 2.5140340270233688E-5
# Model iJN1463.cmd: 2.2237991066261862E-4
# Cycle 403
# Total biomass:
# Model iMM904.cmd: 2.5193082442710716E-5
# Model iJN1463.cmd: 2.2245008855008704E-4
# Cycle 404
# Total biomass:
# Model iMM904.cmd: 2.5244657888803257E-5
# ...
# Model iMM904.cmd: 4.1713927216830346E-5
# Model iJN1463.cmd: 2.353779170684376E-4
# Cycle 850
# Total biomass:
# Model iMM904.cmd: 4.17311399963836E-5
# Model iJN1463.cmd: 2.3539096683373325E-4
# Cycle 851
# Total biomass:
# Model iMM904.cmd: 4.174764491415759E-5
# Model iJN1463.cmd: 2.3540331350579473E-4
# Cycle 852
# Total biomass:
# Model iMM904.cmd: 4.177225205425689E-5
# Model iJN1463.cmd: 2.354133006505524E-4
# Cycle 853
# Total biomass:
# Model iMM904.cmd: 4.1796071209398E-5
# Model iJN1463.cmd: 2.3542283747919555E-4
# Cycle 854
# Total biomass:
# Model iMM904.cmd: 4.182021174884712E-5
# Model iJN1463.cmd: 2.3543243786607623E-4
# Cycle 855
# Total biomass:
# Model iMM904.cmd: 4.184444446159309E-5
# Model iJN1463.cmd: 2.3544242995006908E-4
# Cycle 856
# Total biomass:
# Model iMM904.cmd: 4.186644390493391E-5
# Model iJN1463.cmd: 2.354522839917063E-4
# Cycle 857
# Total biomass:
# Model iMM904.cmd: 4.1890430432578876E-5
# Model iJN1463.cmd: 2.3546224947873384E-4
# Cycle 858
# Total biomass:
# Model iMM904.cmd: 4.191388901153424E-5
# Model iJN1463.cmd: 2.3547181029883265E-4
# Cycle 859
# Total biomass:
# Model iMM904.cmd: 4.193520597404601E-5
# Model iJN1463.cmd: 2.3548115384779906E-4
# Cycle 860
# Total biomass:
# Model iMM904.cmd: 4.195551130636019E-5
# Model iJN1463.cmd: 2.354900613195339E-4
# Cycle 861
# Total biomass:
# Model iMM904.cmd: 4.1976769860406706E-5
# Model iJN1463.cmd: 2.354981001874651E-4
# Cycle 862
# Total biomass:
# Model iMM904.cmd: 4.199821156634166E-5
# Model iJN1463.cmd: 2.3550651702298258E-4
# Cycle 863
# Total biomass:
# Model iMM904.cmd: 4.202126601539938E-5
# Model iJN1463.cmd: 2.3551582993828414E-4
# Cycle 864
# Total biomass:
# Model iMM904.cmd: 4.203933188328558E-5
# Model iJN1463.cmd: 2.3552611718874258E-4
# Cycle 865
# Total biomass:
# Model iMM904.cmd: 4.206145707006664E-5
# Model iJN1463.cmd: 2.355347695921732E-4
# Cycle 866
# Total biomass:
# Model iMM904.cmd: 4.2083265087125994E-5
# Model iJN1463.cmd: 2.3554338161086628E-4
# Cycle 867
# Total biomass:
# Model iMM904.cmd: 4.2104708243322505E-5
# Model iJN1463.cmd: 2.355513702812641E-4
# Cycle 868
# Total biomass:
# Model iMM904.cmd: 4.2126094460292306E-5
# Model iJN1463.cmd: 2.3555955195229264E-4
# Cycle 869
# Total biomass:
# Model iMM904.cmd: 4.2148938267160015E-5
# Model iJN1463.cmd: 2.3556880674300272E-4
# Cycle 870
# Total biomass:
# Model iMM904.cmd: 4.217035508280846E-5
# Model iJN1463.cmd: 2.3557695447933168E-4
# Cycle 871
# Total biomass:
# Model iMM904.cmd: 4.2193233462380546E-5
# Model iJN1463.cmd: 2.3558555475095892E-4
# Cycle 872
# Total biomass:
# Model iMM904.cmd: 4.2215451823351656E-5
# Model iJN1463.cmd: 2.3559394979600175E-4
# Cycle 873
# Total biomass:
# Model iMM904.cmd: 4.2227149816299314E-5
# Model iJN1463.cmd: 2.3560055986522613E-4
# Cycle 874
# Total biomass:
# Model iMM904.cmd: 4.223402291132535E-5
# Model iJN1463.cmd: 2.3561026549024787E-4
# Cycle 875
# Total biomass:
# Model iMM904.cmd: 4.224613625305256E-5
# Model iJN1463.cmd: 2.3562627397801729E-4
# Cycle 876
# Total biomass:
# Model iMM904.cmd: 4.2255573443560636E-5
# Model iJN1463.cmd: 2.3564201628869968E-4
# Cycle 877
# Total biomass:
# Model iMM904.cmd: 4.22651908626097E-5
# Model iJN1463.cmd: 2.3565755872465921E-4
# Cycle 878
# Total biomass:
# Model iMM904.cmd: 4.227398625804757E-5
# Model iJN1463.cmd: 2.356729853855997E-4
# Cycle 879
# Total biomass:
# Model iMM904.cmd: 4.228345435403258E-5
# Model iJN1463.cmd: 2.3568853818626702E-4
# Cycle 880
# Total biomass:
# Model iMM904.cmd: 4.229203784487483E-5
# Model iJN1463.cmd: 2.3570402274006704E-4
# Cycle 881
# Total biomass:
# Model iMM904.cmd: 4.230120293775595E-5
# Model iJN1463.cmd: 2.3571962284199265E-4
# Cycle 882
# Total biomass:
# Model iMM904.cmd: 4.230974156183665E-5
# Model iJN1463.cmd: 2.35735087612779E-4
# Cycle 883
# Total biomass:
# Model iMM904.cmd: 4.232145419169504E-5
# Model iJN1463.cmd: 2.357497611382749E-4
# Cycle 884
# Total biomass:
# Model iMM904.cmd: 4.233143467179443E-5
# Model iJN1463.cmd: 2.357644704480018E-4
# Cycle 885
# Total biomass:
# Model iMM904.cmd: 4.2348078959472887E-5
# Model iJN1463.cmd: 2.3577588368406567E-4
# Cycle 886
# Total biomass:
# Model iMM904.cmd: 4.2361683981398487E-5
# Model iJN1463.cmd: 2.357878903660358E-4
# Cycle 887
# Total biomass:
# Model iMM904.cmd: 4.238141277747583E-5
# Model iJN1463.cmd: 2.3579894441209227E-4
# Cycle 888
# Total biomass:
# Model iMM904.cmd: 4.240247374826187E-5
# Model iJN1463.cmd: 2.3580726641058252E-4
# Cycle 889
# Total biomass:
# Model iMM904.cmd: 4.2424426037830034E-5
# Model iJN1463.cmd: 2.358156382179949E-4
# Cycle 890
# Total biomass:
# Model iMM904.cmd: 4.2445991709946325E-5
# Model iJN1463.cmd: 2.3582380055596136E-4
# Cycle 891
# Total biomass:
# Model iMM904.cmd: 4.246762642297192E-5
# Model iJN1463.cmd: 2.358319681626177E-4
# Cycle 892
# Total biomass:
# Model iMM904.cmd: 4.248827420133319E-5
# Model iJN1463.cmd: 2.3583985438742344E-4
# Cycle 893
# Total biomass:
# Model iMM904.cmd: 4.250975368872363E-5
# Model iJN1463.cmd: 2.3584783557518721E-4
# Cycle 894
# Total biomass:
# Model iMM904.cmd: 4.25307322542085E-5
# Model iJN1463.cmd: 2.3585550830769876E-4
# Cycle 895
# Total biomass:
# Model iMM904.cmd: 4.255058588719239E-5
# Model iJN1463.cmd: 2.3586283332615023E-4
# Cycle 896
# Total biomass:
# Model iMM904.cmd: 4.257087355820166E-5
# Model iJN1463.cmd: 2.3587264687458385E-4
# Cycle 897
# Total biomass:
# Model iMM904.cmd: 4.259125536763383E-5
# Model iJN1463.cmd: 2.3588338914928088E-4
# Cycle 898
# Total biomass:
# Model iMM904.cmd: 4.261139399956823E-5
# Model iJN1463.cmd: 2.3589421393853147E-4
# Cycle 899
# Total biomass:
# Model iMM904.cmd: 4.263213530818895E-5
# Model iJN1463.cmd: 2.3590340209336317E-4
# Cycle 900
# Total biomass:
# Model iMM904.cmd: 4.265338009916116E-5
# Model iJN1463.cmd: 2.3591119375598088E-4
# Cycle 901
# Total biomass:
# Model iMM904.cmd: 4.267313777166843E-5
# Model iJN1463.cmd: 2.359181069457483E-4
# Cycle 902
# Total biomass:
# Model iMM904.cmd: 4.269387634518196E-5
# Model iJN1463.cmd: 2.3592558808121754E-4
# Cycle 903
# Total biomass:
# Model iMM904.cmd: 4.2713959910738355E-5
# Model iJN1463.cmd: 2.3593248059346238E-4
# Cycle 904
# Total biomass:
# Model iMM904.cmd: 4.273471744374861E-5
# Model iJN1463.cmd: 2.3593981782369928E-4
# Cycle 905
# Total biomass:
# Model iMM904.cmd: 4.2755502077493804E-5
# Model iJN1463.cmd: 2.3594932141812505E-4
# Cycle 906
# Total biomass:
# Model iMM904.cmd: 4.277502743677364E-5
# Model iJN1463.cmd: 2.3595955797412458E-4
# Cycle 907
# Total biomass:
# Model iMM904.cmd: 4.2797436503431704E-5
# Model iJN1463.cmd: 2.3596973717675908E-4
# Cycle 908
# Total biomass:
# Model iMM904.cmd: 4.281730292545123E-5
# Model iJN1463.cmd: 2.359772546463584E-4
# Cycle 909
# Total biomass:
# Model iMM904.cmd: 4.283693257308134E-5
# Model iJN1463.cmd: 2.3598453720243202E-4
# Cycle 910
# Total biomass:
# Model iMM904.cmd: 4.285718417549626E-5
# Model iJN1463.cmd: 2.3599174567915963E-4
# Cycle 911
# Total biomass:
# Model iMM904.cmd: 4.2876323474848525E-5
# Model iJN1463.cmd: 2.3599926081369795E-4
# Cycle 912
# Total biomass:
# Model iMM904.cmd: 4.289437677484714E-5
# Model iJN1463.cmd: 2.360060040669521E-4
# Cycle 913
# Total biomass:
# Model iMM904.cmd: 4.291299057799261E-5
# Model iJN1463.cmd: 2.3601196655660794E-4
# Cycle 914
# Total biomass:
# Model iMM904.cmd: 4.293265772598998E-5
# Model iJN1463.cmd: 2.3601860515853312E-4
# Cycle 915
# Total biomass:
# Model iMM904.cmd: 4.295138680340498E-5
# Model iJN1463.cmd: 2.360246305299683E-4
# Cycle 916
# Total biomass:
# Model iMM904.cmd: 4.296940881723521E-5
# Model iJN1463.cmd: 2.3603111902104686E-4
# Cycle 917
# Total biomass:
# Model iMM904.cmd: 4.2987794756172305E-5
# Model iJN1463.cmd: 2.3603693868196304E-4
# Cycle 918
# Total biomass:
# Model iMM904.cmd: 4.3006167352489066E-5
# Model iJN1463.cmd: 2.3604289815109676E-4
# Cycle 919
# Total biomass:
# Model iMM904.cmd: 4.302487236548041E-5
# Model iJN1463.cmd: 2.3605096441467954E-4
# Cycle 920
# Total biomass:
# Model iMM904.cmd: 4.3042525917466524E-5
# Model iJN1463.cmd: 2.3605891657676981E-4
# Cycle 921
# Total biomass:
# Model iMM904.cmd: 4.3062848544642444E-5
# Model iJN1463.cmd: 2.360656567985058E-4
# Cycle 922
# Total biomass:
# Model iMM904.cmd: 4.3082895642816455E-5
# Model iJN1463.cmd: 2.3607235771662223E-4
# Cycle 923
# Total biomass:
# Model iMM904.cmd: 4.3102595109115295E-5
# Model iJN1463.cmd: 2.360790399928883E-4
# Cycle 924
# Total biomass:
# Model iMM904.cmd: 4.3122360906547674E-5
# Model iJN1463.cmd: 2.360855706913773E-4
# Cycle 925
# Total biomass:
# Model iMM904.cmd: 4.314097906655326E-5
# Model iJN1463.cmd: 2.3609341808033946E-4
# Cycle 926
# Total biomass:
# Model iMM904.cmd: 4.3157640181392645E-5
# Model iJN1463.cmd: 2.361029328376898E-4
# Cycle 927
# Total biomass:
# Model iMM904.cmd: 4.317362522452195E-5
# Model iJN1463.cmd: 2.3611237533499945E-4
# Cycle 928
# Total biomass:
# Model iMM904.cmd: 4.319077005650781E-5
# Model iJN1463.cmd: 2.36118655686806E-4
# Cycle 929
# Total biomass:
# Model iMM904.cmd: 4.3207003346770725E-5
# Model iJN1463.cmd: 2.3612672478323568E-4
# Cycle 930
# Total biomass:
# Model iMM904.cmd: 4.322328002198211E-5
# Model iJN1463.cmd: 2.3613315448001607E-4
# Cycle 931
# Total biomass:
# Model iMM904.cmd: 4.324109819209007E-5
# Model iJN1463.cmd: 2.3613880664126593E-4
# Cycle 932
# Total biomass:
# Model iMM904.cmd: 4.325839006305443E-5
# Model iJN1463.cmd: 2.3614421342673823E-4
# Cycle 933
# Total biomass:
# Model iMM904.cmd: 4.327670109961669E-5
# Model iJN1463.cmd: 2.3615074920082266E-4
# Cycle 934
# Total biomass:
# Model iMM904.cmd: 4.3294585436394684E-5
# Model iJN1463.cmd: 2.3615661578856403E-4
# Cycle 935
# Total biomass:
# Model iMM904.cmd: 4.3312031642341174E-5
# Model iJN1463.cmd: 2.3616193788254634E-4
# Cycle 936
# Total biomass:
# Model iMM904.cmd: 4.332852513800522E-5
# Model iJN1463.cmd: 2.361690896550006E-4
# Cycle 937
# Total biomass:
# Model iMM904.cmd: 4.334514714190149E-5
# Model iJN1463.cmd: 2.361756781545199E-4
# Cycle 938
# Total biomass:
# Model iMM904.cmd: 4.3361592063506044E-5
# Model iJN1463.cmd: 2.3618144667436367E-4
# Cycle 939
# Total biomass:
# Model iMM904.cmd: 4.3378781504840764E-5
# Model iJN1463.cmd: 2.3618817073054756E-4
# Cycle 940
# Total biomass:
# Model iMM904.cmd: 4.3395767473588235E-5
# Model iJN1463.cmd: 2.3619593932149805E-4
# Cycle 941
# Total biomass:
# Model iMM904.cmd: 4.341439649407133E-5
# Model iJN1463.cmd: 2.362025765948606E-4
# Cycle 942
# Total biomass:
# Model iMM904.cmd: 4.343377973929382E-5
# Model iJN1463.cmd: 2.36208662132665E-4
# Cycle 943
# Total biomass:
# Model iMM904.cmd: 4.345277661781811E-5
# Model iJN1463.cmd: 2.3621502891117886E-4
# Cycle 944
# Total biomass:
# Model iMM904.cmd: 4.347361690657942E-5
# Model iJN1463.cmd: 2.36223267780295E-4
# Cycle 945
# Total biomass:
# Model iMM904.cmd: 4.349264256326548E-5
# Model iJN1463.cmd: 2.3622948137759216E-4
# Cycle 946
# Total biomass:
# Model iMM904.cmd: 4.350873661772196E-5
# Model iJN1463.cmd: 2.3623680737625715E-4
# Cycle 947
# Total biomass:
# Model iMM904.cmd: 4.352603186322158E-5
# Model iJN1463.cmd: 2.362453966642812E-4
# Cycle 948
# Total biomass:
# Model iMM904.cmd: 4.354344469612023E-5
# Model iJN1463.cmd: 2.3625409192514412E-4
# Cycle 949
# Total biomass:
# Model iMM904.cmd: 4.355744073032427E-5
# Model iJN1463.cmd: 2.3625727107673923E-4
# Cycle 950
# Total biomass:
# Model iMM904.cmd: 4.357188746333487E-5
# Model iJN1463.cmd: 2.3626409748605308E-4
# Cycle 951
# Total biomass:
# Model iMM904.cmd: 4.35867436130744E-5
# Model iJN1463.cmd: 2.362716286708716E-4
# Cycle 952
# Total biomass:
# Model iMM904.cmd: 4.360302176638572E-5
# Model iJN1463.cmd: 2.3627814285700818E-4
# Cycle 953
# Total biomass:
# Model iMM904.cmd: 4.361990894980102E-5
# Model iJN1463.cmd: 2.3628333029983268E-4
# Cycle 954
# Total biomass:
# Model iMM904.cmd: 4.363630746591535E-5
# Model iJN1463.cmd: 2.3628817358094597E-4
# Cycle 955
# Total biomass:
# Model iMM904.cmd: 4.36512208827668E-5
# Model iJN1463.cmd: 2.3629421690990392E-4
# Cycle 956
# Total biomass:
# Model iMM904.cmd: 4.366710567286517E-5
# Model iJN1463.cmd: 2.3629929836471172E-4
# Cycle 957
# Total biomass:
# Model iMM904.cmd: 4.368140479318299E-5
# Model iJN1463.cmd: 2.363052940124246E-4
# Cycle 958
# Total biomass:
# Model iMM904.cmd: 4.3695590881848585E-5
# Model iJN1463.cmd: 2.3631322889764727E-4
# Cycle 959
# Total biomass:
# Model iMM904.cmd: 4.3709942751494707E-5
# Model iJN1463.cmd: 2.363218297686136E-4
# Cycle 960
# Total biomass:
# Model iMM904.cmd: 4.372380287521986E-5
# Model iJN1463.cmd: 2.3633070708908692E-4
# Cycle 961
# Total biomass:
# Model iMM904.cmd: 4.3739170292659195E-5
# Model iJN1463.cmd: 2.3633881786549462E-4
# Cycle 962
# Total biomass:
# Model iMM904.cmd: 4.3747894966565985E-5
# Model iJN1463.cmd: 2.363393821148598E-4
# Cycle 963
# Total biomass:
# Model iMM904.cmd: 4.3759746856699124E-5
# Model iJN1463.cmd: 2.3634404199143435E-4
# Cycle 964
# Total biomass:
# Model iMM904.cmd: 4.37730281783682E-5
# Model iJN1463.cmd: 2.3634970122423534E-4
# Cycle 965
# Total biomass:
# Model iMM904.cmd: 4.378933288772043E-5
# Model iJN1463.cmd: 2.3635521574362508E-4
# Cycle 966
# Total biomass:
# Model iMM904.cmd: 4.3805007821065835E-5
# Model iJN1463.cmd: 2.3635978409274272E-4
# Cycle 967
# Total biomass:
# Model iMM904.cmd: 4.3822503260584974E-5
# Model iJN1463.cmd: 2.3636508178137696E-4
# Cycle 968
# Total biomass:
# Model iMM904.cmd: 4.383676382517314E-5
# Model iJN1463.cmd: 2.3637038862466488E-4
# Cycle 969
# Total biomass:
# Model iMM904.cmd: 4.384559247218538E-5
# Model iJN1463.cmd: 2.3637402560864826E-4
# Cycle 970
# Total biomass:
# Model iMM904.cmd: 4.385003868134566E-5
# Model iJN1463.cmd: 2.3637852263799853E-4
# Cycle 971
# Total biomass:
# Model iMM904.cmd: 4.386237175971702E-5
# Model iJN1463.cmd: 2.36386909598191E-4
# Cycle 972
# Total biomass:
# Model iMM904.cmd: 4.387341983112495E-5
# Model iJN1463.cmd: 2.363959271335295E-4
# Cycle 973
# Total biomass:
# Model iMM904.cmd: 4.389042165264209E-5
# Model iJN1463.cmd: 2.3640091783996386E-4
# Cycle 974
# Total biomass:
# Model iMM904.cmd: 4.3907281243329886E-5
# Model iJN1463.cmd: 2.3640575538801155E-4
# Cycle 975
# Total biomass:
# Model iMM904.cmd: 4.392162559137055E-5
# Model iJN1463.cmd: 2.364120090184425E-4
# Cycle 976
# Total biomass:
# Model iMM904.cmd: 4.393618314449812E-5
# Model iJN1463.cmd: 2.3641651210920667E-4
# Cycle 977
# Total biomass:
# Model iMM904.cmd: 4.3949552390773106E-5
# Model iJN1463.cmd: 2.3642427048705905E-4
# Cycle 978
# Total biomass:
# Model iMM904.cmd: 4.396291082667145E-5
# Model iJN1463.cmd: 2.3643073825506302E-4
# Cycle 979
# Total biomass:
# Model iMM904.cmd: 4.3975509818468744E-5
# Model iJN1463.cmd: 2.3643677337995025E-4
# Cycle 980
# Total biomass:
# Model iMM904.cmd: 4.398742635867618E-5
# Model iJN1463.cmd: 2.3644450351409233E-4
# Cycle 981
# Total biomass:
# Model iMM904.cmd: 4.399962253177338E-5
# Model iJN1463.cmd: 2.3645245306616543E-4
# Cycle 982
# Total biomass:
# Model iMM904.cmd: 4.401615296817029E-5
# Model iJN1463.cmd: 2.3645736945091425E-4
# Cycle 983
# Total biomass:
# Model iMM904.cmd: 4.403288119268198E-5
# Model iJN1463.cmd: 2.3646206169757714E-4
# Cycle 984
# Total biomass:
# Model iMM904.cmd: 4.4044399764535034E-5
# Model iJN1463.cmd: 2.3646805090394345E-4
# Cycle 985
# Total biomass:
# Model iMM904.cmd: 4.405913399629256E-5
# Model iJN1463.cmd: 2.3647571765149028E-4
# Cycle 986
# Total biomass:
# Model iMM904.cmd: 4.4074424284860336E-5
# Model iJN1463.cmd: 2.3648185785629425E-4
# Cycle 987
# Total biomass:
# Model iMM904.cmd: 4.408727455013653E-5
# Model iJN1463.cmd: 2.3648974779864833E-4
# Cycle 988
# Total biomass:
# Model iMM904.cmd: 4.4099192386817807E-5
# Model iJN1463.cmd: 2.3649826789584645E-4
# Cycle 989
# Total biomass:
# Model iMM904.cmd: 4.4112767378386794E-5
# Model iJN1463.cmd: 2.3650534598553279E-4
# Cycle 990
# Total biomass:
# Model iMM904.cmd: 4.4126298978170025E-5
# Model iJN1463.cmd: 2.3651263182973E-4
# Cycle 991
# Total biomass:
# Model iMM904.cmd: 4.414432480501556E-5
# Model iJN1463.cmd: 2.3651944090135582E-4
# Cycle 992
# Total biomass:
# Model iMM904.cmd: 4.415826137913657E-5
# Model iJN1463.cmd: 2.3652468146248735E-4
# Cycle 993
# Total biomass:
# Model iMM904.cmd: 4.417322804202327E-5
# Model iJN1463.cmd: 2.3652999724510623E-4
# Cycle 994
# Total biomass:
# Model iMM904.cmd: 4.418523107418042E-5
# Model iJN1463.cmd: 2.3653542653356607E-4
# Cycle 995
# Total biomass:
# Model iMM904.cmd: 4.4198790926950554E-5
# Model iJN1463.cmd: 2.365410574171106E-4
# Cycle 996
# Total biomass:
# Model iMM904.cmd: 4.421050749411024E-5
# Model iJN1463.cmd: 2.365464538994889E-4
# Cycle 997
# Total biomass:
# Model iMM904.cmd: 4.422596819873553E-5
# Model iJN1463.cmd: 2.365522623060484E-4
# Cycle 998
# Total biomass:
# Model iMM904.cmd: 4.423370381764374E-5
# Model iJN1463.cmd: 2.365543038021242E-4
# Cycle 999
# Total biomass:
# Model iMM904.cmd: 4.424816889436433E-5
# Model iJN1463.cmd: 2.3655829600933414E-4
# Cycle 1000
# Total biomass:
# Model iMM904.cmd: 4.426169534537911E-5
# Model iJN1463.cmd: 2.3656181455905415E-4
# Cycle 1001
# End of simulation
# Total time = 18351.135s
#
# STDERR empty.

# %% [markdown]
# Para revisar la biomasa total

# %%
sim.total_biomass.plot(x = "cycle")
# Out:
# <AxesSubplot:xlabel='cycle'>

# %% [markdown]
# Graficamos los resultados de biomasa y demás metabolitos interesantes en el grid:

# %%
im = sim.get_biomass_image('iMM904', params.all_params['maxCycles'])
im2 = sim.get_biomass_image('iJN1463',params.all_params['maxCycles'])

final = np.zeros((grid_size,grid_size,3))
final[:,:,0] = im / np.max(im)
final[:,:,1] = im2 / np.max(im2)
for rock in rock_locs:
    final[rock[0],rock[1],0:3] = 0.4 
from matplotlib import pyplot as plt
ﬁg, ax = plt.subplots(ﬁgsize = (3.1, 3.1))
ax.imshow(ﬁnal)
plt.imshow(final)

# %%
plt.imshow(sim.get_metabolite_image("succ_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("ac_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("nh4_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("o2_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("catechol_e",params.all_params['maxCycles']))
