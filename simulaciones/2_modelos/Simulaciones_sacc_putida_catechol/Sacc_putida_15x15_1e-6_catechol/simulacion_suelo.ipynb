# %% [markdown]
# **Soil-air interface.**
#
# Using the functionality of COMETS, one can design simulations which go beyond in silico corollaries of lab experiments to make predictions for environments mimicking natural ecosystems, which is a necessary step for understanding natural ecology from first principles. In this example, we consider a simulation of a soil environment. We use source-and-sink functions to model how a root provides organic acids to the environment while removing ammonia (Huang et al 2014 Botany). While we restrict the root functionality to a source/sink, one could use functionality demonstrated above, for example extracellular enzymes, to generate feedback loops between microbe-produced metabolites and root exudation. We use fixed metabolite concentrations to mimic the largely unchanging air interface above a root, which generates an oxygen gradient. Additionally, since soil is characterized by strong spatial structure with many impenetrable barriers that localized interactions (Nunan 2017), we place “rock” barriers throughout the simulation area. A more complex simulation could use varying diffusion constants for metabolites, as described in a previous protocol (Virtual Petri Dish). Similarly, we use standard diffusion of biomass, but this could be changed to use pushing force or non-linear diffusion for a potentially increased realism.

# %%
import cobra 
import sys 
import copy 
import numpy as np 
from matplotlib import pyplot as plt 
import cometspy as c

# %% [markdown]
# Para nuestro proyecto, utilizaremos Escherichia coli (modelo iAF1260), Pseudomonas putida (modelo iJN1463) y Saccharomyces Cerevisiae (modelo iMM904), recuperados de la base de datos BIGG.
#
# Cambiamos los bounds de las funciones objetivo de los modelos:

# %%
model_dir = "./modelos" # model location
iMM = cobra.io.read_sbml_model(model_dir + '/iMM904.xml')
iJN = cobra.io.read_sbml_model(model_dir + '/iJN1463.xml')

iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').lower_bound = 0
iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').upper_bound = 1000

iMM.reactions.get_by_id('BIOMASS_SC5_notrace').lower_bound = 0
iMM.reactions.get_by_id('BIOMASS_SC5_notrace').upper_bound = 1000

# %% [markdown]
# Luego se convierten estos modelos al formato de COMETS. Se utilizan funciones helper para dos cosas: a) Asegurar que el modelo en COMETS no confunda las reacciones de "sink" con las de exchange, ya que en COBRA están desbalanceadas y por tanto se parecen a las de exchange, y b) abrir todos los bounds de las reacciones de exchange, para que COMETS controle la composición del medio.

# %%
iMM_comets = c.model(iMM)
iMM_comets.ensure_sinks_are_not_exchanges()
iMM_comets.open_exchanges()

iJN_comets = c.model(iJN)
iJN_comets.ensure_sinks_are_not_exchanges()
iJN_comets.open_exchanges()

# %% [markdown]
# El mundo que se simulará tendrá dimensiones de 30x30. El eje de la izquierda (x = 0) corresponde a la raíz, y el eje superior (y = 0) corresponde al aire. La biomasa y las rocas se distribuyen en el resto del grid. Donde hayan rocas no puede haber ni biomasa ni metabolitos, así que seleccionamos esos lugares primero. Para esta simulación, se generarán 3 rocas con un un tamaño medio de 1 cuadraditos. Para generar las piedras se utiliza la función helper grow_rocks.

# %%
from cometspy.utils import grow_rocks, pick_random_locations

grid_size = 15 # 100
n_rocks = 27 # 70
rock_locs = grow_rocks(n = n_rocks, xrange = [1,grid_size-1],yrange = [1,grid_size-1],mean_size = 1)

# %% [markdown]
# Cada especie será plantada en 20 lugares sin sobreponerse. Para esto se utiliza la función helper pick_random_locations, la cual toma como argumento una tupla generada anteriormente que marca lugares "prohibidos", como los cuadrados donde se encuentran las rocas.
#
# Generamos una copia de rock_locs para no cambiarla accidentalmente, y la llamamos forbbiden_locs:

# %%
import copy
forbidden_locs = copy.deepcopy(rock_locs)

# %% [markdown]
# Ahora elegimos al azar los lugares para cada especie, y los vamos añadiendo a la lista forbidden locs para que no se sobrepongan:

# %%
founders_per_species = 15 # 60
iMM_locs = pick_random_locations(n = founders_per_species, 
                                   xrange = [1,grid_size], yrange = [1,grid_size], 
                                   forbidden_locs = forbidden_locs)
forbidden_locs.extend(iMM_locs)
iJN_locs = pick_random_locations(founders_per_species, [1,grid_size],[1,grid_size], forbidden_locs)

# %% [markdown]
# Para graficar los lugares utilizamos matplotlib:

# %%
from matplotlib import pyplot as plt
initial_image = np.zeros((grid_size,grid_size,3))
for rock in rock_locs:
    initial_image[rock[0],rock[1],0:3] = 0.5 
for loc in iMM_locs:
    initial_image[loc[0],loc[1],1] = 1
for loc in iJN_locs:
    initial_image[loc[0],loc[1],2] = 1
plt.imshow(initial_image)

# %% [markdown]
# Generamos el layout y agregamos las rocas:

# %%
# iMM
iMM_initial_pop = [] 
for loc in iJN_locs: 
    iMM_initial_pop.append([loc[0], loc[1], 1.e-8]) 
iMM_comets.initial_pop = iMM_initial_pop 
# iJN
iJN_initial_pop = [] 
for loc in iJN_locs: 
    iJN_initial_pop.append([loc[0], loc[1], 1.e-8]) 
iJN_comets.initial_pop = iJN_initial_pop

# %% [markdown]
# Setteamos las poblaciones iniciales para cada especie, con esto los modelos están listos y los añadimos al layout:

# %%
layout = c.layout([iMM_comets, iJN_comets])
layout.grid = [grid_size,grid_size]
layout.add_barriers(rock_locs)

# %% [markdown]
# Añadimos los metabolitos que estarán inicialmente disponibles en el ambiente. Usamos la función helper add_typical_trace_metabolites() para las trazas típicas. Bajamos el valor del oxígeno dado que la idea es que el que esté disponible difunda desde la atmósfera. Añadimos algunos metabolitos que no se añadieron con la función helper:

# %%
layout.add_typical_trace_metabolites()
layout.set_specific_metabolite('o2_e',0.000001)
layout.set_specific_metabolite('hco3_e',1000)
layout.set_specific_metabolite('co2_e',1000)
#layout.set_specific_metabolite('h2_e',1000)
layout.set_specific_metabolite('so3_e',1000)
layout.set_specific_metabolite('nh4_e',0.0000001)

layout.set_specific_metabolite('glc__D_e',0.0000001)
layout.set_specific_metabolite('meoh_e',0.00000001)
layout.set_specific_metabolite('cys__L_e',0.0000001)
layout.set_specific_metabolite('catechol_e',0.000001)

# %% [markdown]
# Para la capa de aire, dejamos el oxígeno en un valor constante. Al fondo también dejamos al oxígeno en un valor fijo e igual a 0, para simular el efecto de difusión. De manera similar, hacemos lo mismo con el amoniaco y la raíz en la parte izquierda:

# %%
# set static media of O2 and CO2 at the top and bottom-- the "air" and continuous loss of O2 downwards
for x in range(grid_size):
    layout.set_specific_static_at_location('o2_e', (x,0), .0001) # top
    layout.set_specific_static_at_location('o2_e', (x,grid_size-1), 0.) # bottom
    layout.set_specific_static_at_location('co2_e', (x,0), .0001)
    
for x in range(grid_size):
    layout.set_specific_static_at_location('nh4_e', (0,x), 0.0)

# %% [markdown]
# La raíz consume todo el amoniaco, pero es una fuente de acidos orgánicos y metanol para el ambiente. Asumiendo una tasa fija:

# %%
for x in range(grid_size):
    layout.set_specific_refresh_at_location('cit_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('meoh_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('succ_e', (0,x), .000001)

# %% [markdown]
# El layout y los modelos están listos, ahora setteamos los parámetros de la simulación:

# %%
params = c.params()
params.set_param('timeStep', 0.1)
params.set_param('maxCycles', 1000)
params.set_param('maxSpaceBiomass', 10)
params.set_param('deathRate', 0.0001) # die at rate of 1/10000 per hour
params.set_param('writeBiomassLog', True)
params.set_param('BiomassLogRate', 500)
params.set_param('writeMediaLog', True)
params.set_param('MediaLogRate', 500)
params.set_param("writeFluxLog", True)
params.set_param("FluxLogRate", 500)
params.set_param('numRunThreads', 3)
params.set_param('defaultKm', 0.000001)

# %% [markdown]
# Ahora creamos el objeto de la simulación y la corremos. Ojito que se demora y el pc empieza a despegar.

# %%
sim = c.comets(layout, params)
sim.run(False)
# Out:
# Running COMETS simulation ...
# C:\Users\mfran\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3357: DtypeWarning: Columns (10,13,14,15,16,17,18,23,24,25,27,29,31,32,35,42,45,48,59,61,62,68,69,82,93,94,95,96,100,101,102,103,104,105,112,115,118,122,127,135,140,142,153,162,163,169,171,177,187,190,193,195,199,205,214,228,230,232,234,236,245,248,249,256,257,258,265,287,295,296,301,303,312,315,324,325,327,331,333,334,338,339,344,346,351,369,374,375,378,380,400,402,406,414,415,418,419,420,421,423,424,426,434,435,440,444,449,453,454,455,463,481,482,507,512,539,541,546,563,585,648,664,674,676,691,692,695,701,705,716,718,719,720,726,727,740,744,746,753,764,773,782,806,810,829,847,849,850,851,869,870,878,879,882,893,897,913,925,932,937,939,940,953,961,979,999,1001,1002,1004,1005,1009,1014,1016,1018,1039,1040,1041,1050,1061,1062,1063,1064,1068,1071,1074,1078,1079,1080,1082,1095,1113,1115,1126,1130,1132,1141,1152,1164,1165,1166,1176,1179,1180,1181,1182,1184,1188,1197,1201,1204,1205,1206,1211,1213,1214,1215,1216,1217,1218,1219,1227,1228,1229,1233,1245,1246,1261,1262,1263,1264,1265,1269,1276,1279,1280,1281,1284,1288,1299,1304,1308,1316,1317,1331,1332,1334,1336,1346,1347,1358,1361,1365,1369,1370,1372,1375,1376,1396,1401,1405,1406,1412,1416,1424,1426,1428,1442,1443,1447,1451,1453,1455,1470,1482,1484,1488,1491,1505,1509,1520,1526,1534,1535,1549,1558,1562,1565,1567,1569,1571,1572,1573,1578,1580,1585,1586,1587,1588,1599,1601,1617,1629,1630,1632,1643,1655,1665,1678,1690,1692,1693,1697,1699,1702,1740,1741,1747,1764,1765,1767,1768,1771,1772,1773,1774,1775,1778,1779,1797,1811,1856,1871,1877,1878,1890,1891,1892,1910,1911,1914,1915,1923,1924,1925,1926,1945,1946,1949,1950,1968,1984,1985,1987,1988,1989,1990,1991,1993,1994,2004,2037,2080,2085,2086,2133,2134,2156,2167,2200,2219,2225,2227,2241,2242,2249,2250,2251,2252,2253,2254,2257,2263,2281,2283,2304,2305,2322,2325,2352,2354,2371,2373,2382,2387,2388,2390,2391,2393,2394,2398,2399,2401,2402,2410,2420,2423,2424,2426,2427,2428,2429,2431,2440,2472,2474,2477,2479,2480,2482,2484,2486,2532,2533,2534,2535,2575,2595,2601,2602,2609,2639,2666,2682,2714,2715,2719,2720,2727,2729,2731,2758,2764,2765,2817,2819,2884,2888,2900,2908,2912,2913,2916,2930) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
_e	thmmp_e	thmpp_e	thr__L_e	thym_e	thymd_e	tmanur_e	tnt_e	tol_e	tre_e	trp__L_e	tsul_e	ttdca_e	ttdcea_e	ttrcyc_e	tungs_e	tyr__D_e	tyr__L_e	und2one_e	ura_e	urea_e	uri_e	vacc_e	val__D_e	val__L_e	vanln_e	vanlt_e	xan_e	xtsn_e	xyl__D_e	xylt_e	zn2_e	zymst_e	zymstest_SC_e
# Cycle 1
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# Academic license - for non-commercial use only - expires 2022-09-29
# FBARunThread-1 starting up.
# FBARunThread-0 starting up.
# FBARunThread-2 starting up.
# Total biomass:
# Model iMM904.cmd: 1.5752694769801396E-7
# Model iJN1463.cmd: 1.5745789567546766E-7
# Cycle 2
# Total biomass:
# Model iMM904.cmd: 1.6544993584170778E-7
# Model iJN1463.cmd: 1.6530699527993194E-7
# Cycle 3
# Total biomass:
# Model iMM904.cmd: 1.7445330753590505E-7
# Model iJN1463.cmd: 1.7415716959142211E-7
# Cycle 4
# Total biomass:
# Model iMM904.cmd: 1.8430970520951932E-7
# Model iJN1463.cmd: 1.8374734926850508E-7
# Cycle 5
# Total biomass:
# Model iMM904.cmd: 1.9492505194537486E-7
# Model iJN1463.cmd: 1.940586755365649E-7
# Cycle 6
# Total biomass:
# Model iMM904.cmd: 2.063253091979883E-7
# Model iJN1463.cmd: 2.051050792044097E-7
# Cycle 7
# Total biomass:
# Model iMM904.cmd: 2.185565264548116E-7
# Model iJN1463.cmd: 2.169205741159952E-7
# Cycle 8
# Total biomass:
# Model iMM904.cmd: 2.3166333023768497E-7
# Model iJN1463.cmd: 2.2953498643576764E-7
# Cycle 9
# Total biomass:
# Model iMM904.cmd: 2.4569297193685396E-7
# Model iJN1463.cmd: 2.4298489648096854E-7
# Cycle 10
# Total biomass:
# Model iMM904.cmd: 2.606864655326312E-7
# Model iJN1463.cmd: 2.573024730455196E-7
# Cycle 11
# Total biomass:
# Model iMM904.cmd: 2.76690187852681E-7
# Model iJN1463.cmd: 2.7252216706408813E-7
# Cycle 12
# Total biomass:
# Model iMM904.cmd: 2.937571857471334E-7
# Model iJN1463.cmd: 2.886894402190068E-7
# Cycle 13
# Total biomass:
# Model iMM904.cmd: 3.1194700603667396E-7
# Model iJN1463.cmd: 3.058589770915741E-7
# Cycle 14
# Total biomass:
# Model iMM904.cmd: 3.3132261158280173E-7
# Model iJN1463.cmd: 3.240884975572816E-7
# Cycle 15
# Total biomass:
# Model iMM904.cmd: 3.5195213883202215E-7
# Model iJN1463.cmd: 3.4343950534461775E-7
# Cycle 16
# Total biomass:
# Model iMM904.cmd: 3.739102347597041E-7
# Model iJN1463.cmd: 3.6397677414880755E-7
# Cycle 17
# Total biomass:
# Model iMM904.cmd: 3.9727886775189716E-7
# Model iJN1463.cmd: 3.8577086258374837E-7
# Cycle 18
# Total biomass:
# Model iMM904.cmd: 4.2214158840203327E-7
# Model iJN1463.cmd: 4.0889573316689603E-7
# Cycle 19
# Total biomass:
# Model iMM904.cmd: 4.4858085720215224E-7
# Model iJN1463.cmd: 4.3342998665811505E-7
# Cycle 20
# Total biomass:
# Model iMM904.cmd: 4.761609450512896E-7
# Model iJN1463.cmd: 4.593825362167889E-7
# Cycle 21
# Total biomass:
# Model iMM904.cmd: 5.0428171081948E-7
# Model iJN1463.cmd: 4.867441568641557E-7
# Cycle 22
# Total biomass:
# Model iMM904.cmd: 5.329671014752697E-7
# Model iJN1463.cmd: 5.155982111628686E-7
# Cycle 23
# Total biomass:
# Model iMM904.cmd: 5.62282547446087E-7
# Model iJN1463.cmd: 5.460370533292915E-7
# Cycle 24
# Total biomass:
# Model iMM904.cmd: 5.923069564735621E-7
# Model iJN1463.cmd: 5.781826353242572E-7
# Cycle 25
# Total biomass:
# Model iMM904.cmd: 6.230637149840197E-7
# Model iJN1463.cmd: 6.121157346120038E-7
# Cycle 26
# Total biomass:
# Model iMM904.cmd: 6.54699976401664E-7
# Model iJN1463.cmd: 6.479002948191948E-7
# Cycle 27
# Total biomass:
# Model iMM904.cmd: 6.872459629029848E-7
# Model iJN1463.cmd: 6.856194958588819E-7
# Cycle 28
# Total biomass:
# Model iMM904.cmd: 7.207601273418676E-7
# Model iJN1463.cmd: 7.253407801461517E-7
# Cycle 29
# Total biomass:
# Model iMM904.cmd: 7.553186105482511E-7
# Model iJN1463.cmd: 7.671818501781117E-7
# Cycle 30
# Total biomass:
# Model iMM904.cmd: 7.90983243451049E-7
# Model iJN1463.cmd: 8.113635423721721E-7
# Cycle 31
# Total biomass:
# Model iMM904.cmd: 8.27609206488343E-7
# Model iJN1463.cmd: 8.579505715383354E-7
# Cycle 32
# Total biomass:
# Model iMM904.cmd: 8.651061193587676E-7
# Model iJN1463.cmd: 9.070221540492646E-7
# Cycle 33
# Total biomass:
# Model iMM904.cmd: 9.032120677093101E-7
# Model iJN1463.cmd: 9.58688125105596E-7
# Cycle 34
# Total biomass:
# Model iMM904.cmd: 9.413743204257985E-7
# Model iJN1463.cmd: 1.0130632708050987E-6
# Cycle 35
# Total biomass:
# Model iMM904.cmd: 9.792772025469107E-7
# Model iJN1463.cmd: 1.0703840973854226E-6
# Cycle 36
# Total biomass:
# Model iMM904.cmd: 1.0171996743693748E-6
# Model iJN1463.cmd: 1.1304009077255062E-6
# Cycle 37
# Total biomass:
# Model iMM904.cmd: 1.0557074335451007E-6
# Model iJN1463.cmd: 1.1931589701710008E-6
# Cycle 38
# Total biomass:
# Model iMM904.cmd: 1.0946293938326665E-6
# Model iJN1463.cmd: 1.2589478954341778E-6
# Cycle 39
# Total biomass:
# Model iMM904.cmd: 1.1340702043159285E-6
# Model iJN1463.cmd: 1.3280017007853417E-6
# Cycle 40
# Total biomass:
# Model iMM904.cmd: 1.174094096549539E-6
# Model iJN1463.cmd: 1.4004271989416761E-6
# Cycle 41
# Total biomass:
# Model iMM904.cmd: 1.2147303206289534E-6
# Model iJN1463.cmd: 1.4763713408376103E-6
# Cycle 42
# Total biomass:
# Model iMM904.cmd: 1.2560846439040038E-6
# Model iJN1463.cmd: 1.5560425731050918E-6
# Cycle 43
# Total biomass:
# Model iMM904.cmd: 1.2984609055348722E-6
# Model iJN1463.cmd: 1.6399885013606447E-6
# Cycle 44
# Total biomass:
# Cycle 163
# Total biomass:
# Model iMM904.cmd: 1.0626661602840517E-5
# Model iJN1463.cmd: 4.421103133772679E-5
# Cycle 164
# Total biomass:
# Model iMM904.cmd: 1.069291465839857E-5
# Model iJN1463.cmd: 4.433234511654312E-5
# Cycle 165
# Total biomass:
# Model iMM904.cmd: 1.0755661779679651E-5
# Model iJN1463.cmd: 4.445690552443581E-5
# Cycle 166
# Total biomass:
# Model iMM904.cmd: 1.0820501106072354E-5
# Model iJN1463.cmd: 4.457903140283611E-5
# Cycle 167
# Total biomass:
# Model iMM904.cmd: 1.0886871125141113E-5
# Model iJN1463.cmd: 4.4699705764000844E-5
# Cycle 168
# Total biomass:
# Model iMM904.cmd: 1.0952863051403941E-5
# Model iJN1463.cmd: 4.481943725361256E-5
# Cycle 169
# Total biomass:
# Model iMM904.cmd: 1.1019539729551087E-5
# Model iJN1463.cmd: 4.493918670343936E-5
# Cycle 170
# Total biomass:
# Model iMM904.cmd: 1.108315112870978E-5
# Model iJN1463.cmd: 4.506151848808498E-5
# Cycle 171
# Total biomass:
# Model iMM904.cmd: 1.1148751039297321E-5
# Model iJN1463.cmd: 4.5181017934761654E-5
# Cycle 172
# Total biomass:
# Model iMM904.cmd: 1.121313727434689E-5
# Model iJN1463.cmd: 4.530205902907453E-5
# Cycle 173
# Total biomass:
# Model iMM904.cmd: 1.127946037093384E-5
# Model iJN1463.cmd: 4.542090984527594E-5
# Cycle 174
# Total biomass:
# Model iMM904.cmd: 1.1341266634350031E-5
# Model iJN1463.cmd: 4.554391591984024E-5
# Cycle 175
# Total biomass:
# Model iMM904.cmd: 1.1401956226966086E-5
# Model iJN1463.cmd: 4.566683095571866E-5
# Cycle 176
# Total biomass:
# Model iMM904.cmd: 1.1466848194795753E-5
# Model iJN1463.cmd: 4.579022159079802E-5
# Cycle 177
# Total biomass:
# Model iMM904.cmd: 1.1533497212398193E-5
# Model iJN1463.cmd: 4.590754022445421E-5
# Cycle 178
# Total biomass:
# Model iMM904.cmd: 1.1597667946208925E-5
# Model iJN1463.cmd: 4.602559871476525E-5
# Cycle 179
# Total biomass:
# Model iMM904.cmd: 1.1661606187608237E-5
# Model iJN1463.cmd: 4.614100196893905E-5
# Cycle 180
# Total biomass:
# Model iMM904.cmd: 1.1725041550483911E-5
# Model iJN1463.cmd: 4.6258611388704187E-5
# Cycle 181
# Total biomass:
# Model iMM904.cmd: 1.1788952580156681E-5
# Model iJN1463.cmd: 4.6377789884138755E-5
# Cycle 182
# Total biomass:
# Model iMM904.cmd: 1.1851908571593765E-5
# Model iJN1463.cmd: 4.65003346739521E-5
# Cycle 183
# Total biomass:
# Model iMM904.cmd: 1.1915478960138232E-5
# Model iJN1463.cmd: 4.661831980985794E-5
# Cycle 184
# Total biomass:
# Model iMM904.cmd: 1.197690696195646E-5
# Model iJN1463.cmd: 4.673812318463327E-5
# Cycle 185
# Total biomass:
# Model iMM904.cmd: 1.2041058233308679E-5
# Model iJN1463.cmd: 4.685911422431518E-5
# Cycle 186
# Total biomass:
# Model iMM904.cmd: 1.210199157454802E-5
# Model iJN1463.cmd: 4.698051699585987E-5
# Cycle 187
# Total biomass:
# Model iMM904.cmd: 1.2163769520643716E-5
# Model iJN1463.cmd: 4.709786253402184E-5
# Cycle 188
# Total biomass:
# Model iMM904.cmd: 1.2227409251630672E-5
# Model iJN1463.cmd: 4.72147140432515E-5
# Cycle 189
# Total biomass:
# Model iMM904.cmd: 1.2287842970921613E-5
# Model iJN1463.cmd: 4.733439902189479E-5
# Cycle 190
# Total biomass:
# Model iMM904.cmd: 1.2354229305254308E-5
# Model iJN1463.cmd: 4.744581775187305E-5
# Cycle 191
# Total biomass:
# Model iMM904.cmd: 1.241485012855763E-5
# Model iJN1463.cmd: 4.756209403637916E-5
# Cycle 192
# Total biomass:
# Model iMM904.cmd: 1.247724315569419E-5
# Model iJN1463.cmd: 4.767770568792337E-5
# Cycle 193
# Total biomass:
# Model iMM904.cmd: 1.2538270895035764E-5
# Model iJN1463.cmd: 4.7795519672733975E-5
# Cycle 194
# Total biomass:
# Model iMM904.cmd: 1.2597684475002786E-5
# Model iJN1463.cmd: 4.79132798001051E-5
# Cycle 195
# Total biomass:
# Model iMM904.cmd: 1.2657125270774632E-5
# Model iJN1463.cmd: 4.8031964620724634E-5
# Cycle 196
# Total biomass:
# Model iMM904.cmd: 1.2717736514839772E-5
# Model iJN1463.cmd: 4.814757086991476E-5
# Cycle 197
# Total biomass:
# Model iMM904.cmd: 1.2780432972421777E-5
# Model iJN1463.cmd: 4.826333173932475E-5
# Cycle 198
# Total biomass:
# Model iMM904.cmd: 1.284392915346918E-5
# Model iJN1463.cmd: 4.837741185308412E-5
# Cycle 199
# Total biomass:
# Model iMM904.cmd: 1.2909039295557786E-5
# Model iJN1463.cmd: 4.848993908463974E-5
# Cycle 200
# Total biomass:
# Model iMM904.cmd: 1.2972648828026847E-5
# Model iJN1463.cmd: 4.860305346203441E-5
# Cycle 201
# Total biomass:
# Model iMM904.cmd: 1.3034097804196127E-5
# Model iJN1463.cmd: 4.8718654536984525E-5
# Cycle 202
# Total biomass:
# Model iMM904.cmd: 1.309801292021163E-5
# Model iJN1463.cmd: 4.883100351869017E-5
# Cycle 203
# Total biomass:
# Model iMM904.cmd: 1.316179055287725E-5
# Model iJN1463.cmd: 4.89418354382047E-5
# Cycle 204
# Total biomass:
# Model iMM904.cmd: 1.3223300313365074E-5
# Model iJN1463.cmd: 4.905698127172704E-5
# Cycle 205
# Total biomass:
# Model iMM904.cmd: 1.3286648046562125E-5
# Model iJN1463.cmd: 4.9167519446510604E-5
# Cycle 206
# Total biomass:
# Model iMM904.cmd: 1.3347798299541845E-5
# Model iJN1463.cmd: 4.928274129924615E-5
# Cycle 207
# Total biomass:
# Model iMM904.cmd: 1.3406486176344253E-5
# Model iJN1463.cmd: 4.939908436959847E-5
# Cycle 208
# Total biomass:
# Model iMM904.cmd: 1.3466856340374487E-5
# Model iJN1463.cmd: 4.951326681808736E-5
# Cycle 209
# Total biomass:
# Model iMM904.cmd: 1.3527381830828008E-5
# Model iJN1463.cmd: 4.962536438302036E-5
# Cycle 210
# Total biomass:
# Model iMM904.cmd: 1.3591110162746734E-5
# Model iJN1463.cmd: 4.973560582832731E-5
# Cycle 211
# Total biomass:
# Model iMM904.cmd: 1.3653225637559204E-5
# Model iJN1463.cmd: 4.984623999164918E-5
# Cycle 212
# Total biomass:
# Model iMM904.cmd: 1.371399213818546E-5
# Model iJN1463.cmd: 4.996043495798289E-5
# Cycle 213
# Total biomass:
# Model iMM904.cmd: 1.3777505952786929E-5
# Model iJN1463.cmd: 5.007114790679533E-5
# Cycle 214
# Total biomass:
# Model iMM904.cmd: 1.3841323588284853E-5
# Model iJN1463.cmd: 5.018151423250459E-5
# Cycle 215
# Total biomass:
# Model iMM904.cmd: 1.3902256718593537E-5
# Model iJN1463.cmd: 5.029435648667426E-5
# Cycle 216
# Total biomass:
# Model iMM904.cmd: 1.3965045379473614E-5
# Model iJN1463.cmd: 5.0403909183043486E-5
# Cycle 217
# Total biomass:
# Model iMM904.cmd: 1.4024383810418604E-5
# Model iJN1463.cmd: 5.051600324366611E-5
# Cycle 218
# Total biomass:
# Model iMM904.cmd: 1.4086548096411588E-5
# Model iJN1463.cmd: 5.062505232107915E-5
# Cycle 219
# Total biomass:
# Model iMM904.cmd: 1.4148540195721761E-5
# Model iJN1463.cmd: 5.0733924854980316E-5
# Cycle 220
# Total biomass:
# Model iMM904.cmd: 1.4206395250176104E-5
# Model iJN1463.cmd: 5.084678992264064E-5
# Cycle 221
# Total biomass:
# Model iMM904.cmd: 1.4267942400507763E-5
# Model iJN1463.cmd: 5.0956513280998763E-5
# Cycle 222
# Total biomass:
# Model iMM904.cmd: 1.4329643900322506E-5
# Model iJN1463.cmd: 5.1066339521044365E-5
# Cycle 223
# Total biomass:
# Model iMM904.cmd: 1.4390517602525068E-5
# Model iJN1463.cmd: 5.117651076184276E-5
# Cycle 224
# Total biomass:
# Model iMM904.cmd: 1.444887931442203E-5
# Model iJN1463.cmd: 5.128756402898411E-5
# Cycle 225
# Total biomass:
# Model iMM904.cmd: 1.4510452518924437E-5
# Model iJN1463.cmd: 5.139632109177929E-5
# Cycle 226
# Total biomass:
# Model iMM904.cmd: 1.4568373251893318E-5
# Model iJN1463.cmd: 5.1508976925811645E-5
# Cycle 227
# Total biomass:
# Model iMM904.cmd: 1.4628174379524842E-5
# Model iJN1463.cmd: 5.1620160080565784E-5
# Cycle 228
# Total biomass:
# Model iMM904.cmd: 1.4689922642714485E-5
# Model iJN1463.cmd: 5.172702888296584E-5
# Cycle 229
# Total biomass:
# Model iMM904.cmd: 1.474902057752507E-5
# Model iJN1463.cmd: 5.183786857014564E-5
# Cycle 230
# Total biomass:
# Model iMM904.cmd: 1.4810274350705879E-5
# Model iJN1463.cmd: 5.194424478328761E-5
# Cycle 231
# Total biomass:
# Model iMM904.cmd: 1.4872040350255146E-5
# Model iJN1463.cmd: 5.205125440178835E-5
# Cycle 232
# Total biomass:
# Model iMM904.cmd: 1.4932024339553548E-5
# Model iJN1463.cmd: 5.21598590222886E-5
# Cycle 233
# Total biomass:
# Model iMM904.cmd: 1.4992374766528889E-5
# Model iJN1463.cmd: 5.226860493324357E-5
# Cycle 234
# Total biomass:
# Model iMM904.cmd: 1.5048663364646079E-5
# Model iJN1463.cmd: 5.237994789826957E-5
# Cycle 235
# Total biomass:
# Model iMM904.cmd: 1.5108427046465E-5
# Model iJN1463.cmd: 5.248889016569902E-5
# Cycle 236
# Total biomass:
# Model iMM904.cmd: 1.516957316310095E-5
# Model iJN1463.cmd: 5.2595598344489224E-5
# Cycle 237
# Total biomass:
# Model iMM904.cmd: 1.5227169440164841E-5
# Model iJN1463.cmd: 5.270725550863788E-5
# Cycle 238
# Total biomass:
# Model iMM904.cmd: 1.529035404453683E-5
# Model iJN1463.cmd: 5.28118428960611E-5
# Cycle 239
# Total biomass:
# Model iMM904.cmd: 1.5347359359175366E-5
# Model iJN1463.cmd: 5.292279207810714E-5
# Cycle 240
# Total biomass:
# Model iMM904.cmd: 1.5408057834297605E-5
# Model iJN1463.cmd: 5.3027249516114576E-5
# Cycle 241
# Total biomass:
# Model iMM904.cmd: 1.5470088181518185E-5
# Model iJN1463.cmd: 5.3131735464819624E-5
# Cycle 242
# Total biomass:
# Model iMM904.cmd: 1.552881322281489E-5
# Model iJN1463.cmd: 5.3239272030722895E-5
# Cycle 243
# Total biomass:
# Model iMM904.cmd: 1.558640005553468E-5
# Model iJN1463.cmd: 5.334475092649502E-5
# Cycle 244
# Total biomass:
# Model iMM904.cmd: 1.5643577340556777E-5
# Model iJN1463.cmd: 5.344686567080372E-5
# Cycle 245
# Total biomass:
# Model iMM904.cmd: 1.5693771827395514E-5
# Model iJN1463.cmd: 5.356316304638335E-5
# Cycle 246
# Total biomass:
# Model iMM904.cmd: 1.575644035084564E-5
# Model iJN1463.cmd: 5.366547139173831E-5
# Cycle 247
# Total biomass:
# Model iMM904.cmd: 1.5811719826038326E-5
# Model iJN1463.cmd: 5.377530905794569E-5
# Cycle 248
# Total biomass:
# Model iMM904.cmd: 1.5871951558511946E-5
# Model iJN1463.cmd: 5.387945989527211E-5
# Cycle 249
# Total biomass:
# Model iMM904.cmd: 1.5930357823341356E-5
# Model iJN1463.cmd: 5.3983169605267786E-5
# Cycle 250
# Total biomass:
# Model iMM904.cmd: 1.5987029076355328E-5
# Model iJN1463.cmd: 5.409142849355548E-5
# Cycle 251
# Total biomass:
# Model iMM904.cmd: 1.6049603015887256E-5
# Model iJN1463.cmd: 5.419264010513533E-5
# Cycle 252
# Total biomass:
# Model iMM904.cmd: 1.6110870209152167E-5
# Model iJN1463.cmd: 5.429433502019658E-5
# Cycle 253
# Total biomass:
# Model iMM904.cmd: 1.616759989810511E-5
# Model iJN1463.cmd: 5.4400629723928704E-5
# Cycle 254
# Total biomass:
# Model iMM904.cmd: 1.6226715077738904E-5
# Model iJN1463.cmd: 5.450318704988738E-5
# Cycle 255
# Total biomass:
# Model iMM904.cmd: 1.6283869699906147E-5
# Model iJN1463.cmd: 5.4608578357030314E-5
# Cycle 256
# Total biomass:
# Model iMM904.cmd: 1.6341668820711414E-5
# Model iJN1463.cmd: 5.471462586577785E-5
# Cycle 257
# Total biomass:
# Model iMM904.cmd: 1.6396788805622214E-5
# Model iJN1463.cmd: 5.482035662292145E-5
# Cycle 258
# Total biomass:
# Model iMM904.cmd: 1.64546324941342E-5
# Model iJN1463.cmd: 5.492222889369922E-5
# Cycle 259
# Total biomass:
# Model iMM904.cmd: 1.6517756328498895E-5
# Model iJN1463.cmd: 5.502082340050527E-5
# Cycle 260
# Total biomass:
# Model iMM904.cmd: 1.6580283212436813E-5
# Model iJN1463.cmd: 5.511898838230202E-5
# Cycle 261
# Total biomass:
# Model iMM904.cmd: 1.664326796954329E-5
# Model iJN1463.cmd: 5.522330328928567E-5
# Cycle 262
# Total biomass:
# Model iMM904.cmd: 1.6702289239231772E-5
# Model iJN1463.cmd: 5.533090115043099E-5
# Cycle 263
# Total biomass:
# Model iMM904.cmd: 1.6753682040168175E-5
# Model iJN1463.cmd: 5.544337913313367E-5
# Cycle 264
# Total biomass:
# Model iMM904.cmd: 1.6813510539557777E-5
# Model iJN1463.cmd: 5.554389023382695E-5
# Cycle 265
# Total biomass:
# Model iMM904.cmd: 1.6873612855573835E-5
# Model iJN1463.cmd: 5.564520616795006E-5
# Cycle 266
# Total biomass:
# Model iMM904.cmd: 1.69326212098687E-5
# Model iJN1463.cmd: 5.5745396484569937E-5
# Cycle 267
# Total biomass:
# Model iMM904.cmd: 1.6991137790113087E-5
# Model iJN1463.cmd: 5.584653808315597E-5
# Cycle 268
# Total biomass:
# Model iMM904.cmd: 1.705028419731311E-5
# Model iJN1463.cmd: 5.5946101199279055E-5
# Cycle 269
# Total biomass:
# Model iMM904.cmd: 1.7111113192088894E-5
# Model iJN1463.cmd: 5.604395450946453E-5
# Cycle 270
# Total biomass:
# Model iMM904.cmd: 1.7169191924397915E-5
# Model iJN1463.cmd: 5.6150467510608964E-5
# Cycle 271
# Total biomass:
# Model iMM904.cmd: 1.7226635816979257E-5
# Model iJN1463.cmd: 5.625740744951543E-5
# Cycle 272
# Total biomass:
# Model iMM904.cmd: 1.72847063098332E-5
# Model iJN1463.cmd: 5.635871096445841E-5
# Cycle 273
# Total biomass:
# Model iMM904.cmd: 1.734391208763653E-5
# Model iJN1463.cmd: 5.6455381909868504E-5
# Cycle 274
# Total biomass:
# Model iMM904.cmd: 1.7399602748571853E-5
# Model iJN1463.cmd: 5.655595680885617E-5
# Cycle 275
# Total biomass:
# Model iMM904.cmd: 1.7454418332224136E-5
# Model iJN1463.cmd: 5.665831762839331E-5
# Cycle 276
# Total biomass:
# Model iMM904.cmd: 1.7513989443369878E-5
# Model iJN1463.cmd: 5.675789165312318E-5
# Cycle 277
# Total biomass:
# Model iMM904.cmd: 1.7576620628228835E-5
# Model iJN1463.cmd: 5.685264097484474E-5
# Cycle 278
# Total biomass:
# Model iMM904.cmd: 1.7637417954888893E-5
# Model iJN1463.cmd: 5.69494009204182E-5
# Cycle 279
# Total biomass:
# Model iMM904.cmd: 1.76945093449712E-5
# Model iJN1463.cmd: 5.704873006725182E-5
# Cycle 280
# Total biomass:
# Model iMM904.cmd: 1.774997024370072E-5
# Model iJN1463.cmd: 5.714871937274362E-5
# Cycle 281
# Total biomass:
# Model iMM904.cmd: 1.781093478379724E-5
# Model iJN1463.cmd: 5.7245902224023314E-5
# Cycle 282
# Total biomass:
# Model iMM904.cmd: 1.787396154434681E-5
# Model iJN1463.cmd: 5.733969069454345E-5
# Cycle 283
# Total biomass:
# Model iMM904.cmd: 1.7928943689535487E-5
# Model iJN1463.cmd: 5.743985798619911E-5
# Cycle 284
# Total biomass:
# Model iMM904.cmd: 1.7984746518673886E-5
# Model iJN1463.cmd: 5.753932706274742E-5
# Cycle 285
# Total biomass:
# Model iMM904.cmd: 1.804256524974642E-5
# Model iJN1463.cmd: 5.763770106211852E-5
# Cycle 286
# Total biomass:
# Model iMM904.cmd: 1.8103113509522832E-5
# Model iJN1463.cmd: 5.773867652931951E-5
# Cycle 287
# Total biomass:
# Model iMM904.cmd: 1.816046720670534E-5
# Model iJN1463.cmd: 5.783692451389259E-5
# Cycle 288
# Total biomass:
# Model iMM904.cmd: 1.8215260143792854E-5
# Model iJN1463.cmd: 5.7934929390185327E-5
# Cycle 289
# Total biomass:
# Model iMM904.cmd: 1.8274765807138703E-5
# Model iJN1463.cmd: 5.802855770978208E-5
# Cycle 290
# Total biomass:
# Model iMM904.cmd: 1.8333352725990108E-5
# Model iJN1463.cmd: 5.812482528723844E-5
# Cycle 291
# Total biomass:
# Model iMM904.cmd: 1.8391353431926375E-5
# Model iJN1463.cmd: 5.8220222222251114E-5
# Cycle 292
# Total biomass:
# Model iMM904.cmd: 1.8448723635141074E-5
# Model iJN1463.cmd: 5.831403685899978E-5
# Cycle 293
# Total biomass:
# Model iMM904.cmd: 1.850395531507518E-5
# Model iJN1463.cmd: 5.841175855878803E-5
# Cycle 294
# Total biomass:
# Model iMM904.cmd: 1.856464522036822E-5
# Model iJN1463.cmd: 5.850355583854925E-5
# Cycle 295
# Total biomass:
# Model iMM904.cmd: 1.8623933656112924E-5
# Model iJN1463.cmd: 5.859542984313971E-5
# Cycle 296
# Total biomass:
# Model iMM904.cmd: 1.8685994984900262E-5
# Model iJN1463.cmd: 5.868809642906602E-5
# Cycle 297
# Total biomass:
# Model iMM904.cmd: 1.874912762649292E-5
# Model iJN1463.cmd: 5.87845169248111E-5
# Cycle 298
# Total biomass:
# Model iMM904.cmd: 1.880953188460499E-5
# Model iJN1463.cmd: 5.8878636738493563E-5
# Cycle 299
# Total biomass:
# Model iMM904.cmd: 1.887141585971917E-5
# Model iJN1463.cmd: 5.897302924598101E-5
# Cycle 300
# Total biomass:
# Model iMM904.cmd: 1.893210340479816E-5
# Model iJN1463.cmd: 5.906544571597548E-5
# Cycle 301
# Total biomass:
# Model iMM904.cmd: 1.8992099966905566E-5
# Model iJN1463.cmd: 5.915695585980005E-5
# Cycle 302
# Total biomass:
# Model iMM904.cmd: 1.9048845136790264E-5
# Model iJN1463.cmd: 5.925113022233778E-5
# Cycle 303
# Total biomass:
# Model iMM904.cmd: 1.9105589092439584E-5
# Model iJN1463.cmd: 5.9340824265416824E-5
# Cycle 304
# Total biomass:
# Model iMM904.cmd: 1.9165292250469512E-5
# Model iJN1463.cmd: 5.943166002552456E-5
# Cycle 305
# Total biomass:
# Model iMM904.cmd: 1.9227430622279328E-5
# Model iJN1463.cmd: 5.9519532940590216E-5
# Cycle 306
# Total biomass:
# Model iMM904.cmd: 1.9284389531208935E-5
# Model iJN1463.cmd: 5.961311460266078E-5
# Cycle 307
# Total biomass:
# Model iMM904.cmd: 1.9343976893423093E-5
# Model iJN1463.cmd: 5.97014828837044E-5
# Cycle 308
# Total biomass:
# Model iMM904.cmd: 1.9401941959962277E-5
# Model iJN1463.cmd: 5.979619858575552E-5
# Cycle 309
# Total biomass:
# Model iMM904.cmd: 1.9458108402751283E-5
# Model iJN1463.cmd: 5.988945004945173E-5
# Cycle 310
# Total biomass:
# Model iMM904.cmd: 1.9516236206115537E-5
# Model iJN1463.cmd: 5.9978813305658817E-5
# Cycle 311
# Total biomass:
# Model iMM904.cmd: 1.9573045086482013E-5
# Model iJN1463.cmd: 6.0070645801630596E-5
# Cycle 312
# Total biomass:
# Model iMM904.cmd: 1.9633237919819893E-5
# Model iJN1463.cmd: 6.015880220878991E-5
# Cycle 313
# Total biomass:
# Model iMM904.cmd: 1.9690765513815684E-5
# Model iJN1463.cmd: 6.0250908409072236E-5
# Cycle 314
# Total biomass:
# Model iMM904.cmd: 1.9746002143058938E-5
# Model iJN1463.cmd: 6.0344477557744404E-5
# Cycle 315
# Total biomass:
# Model iMM904.cmd: 1.980415260385762E-5
# Model iJN1463.cmd: 6.043443479549701E-5
# Cycle 316
# Total biomass:
# Model iMM904.cmd: 1.9860943967965626E-5
# Model iJN1463.cmd: 6.0524632951252756E-5
# Cycle 317
# Total biomass:
# Model iMM904.cmd: 1.9917239097782865E-5
# Model iJN1463.cmd: 6.0614205319808965E-5
# Cycle 318
# Total biomass:
# Model iMM904.cmd: 1.997306536883718E-5
# Model iJN1463.cmd: 6.070335380459581E-5
# Cycle 319
# Total biomass:
# Model iMM904.cmd: 2.0027378046922075E-5
# Model iJN1463.cmd: 6.079420823877186E-5
# Cycle 320
# Total biomass:
# Model iMM904.cmd: 2.008264414592574E-5
# Model iJN1463.cmd: 6.088351478326183E-5
# Cycle 321
# Total biomass:
# Model iMM904.cmd: 2.0140596760070813E-5
# Model iJN1463.cmd: 6.096787148146969E-5
# Cycle 322
# Total biomass:
# Model iMM904.cmd: 2.019767751329537E-5
# Model iJN1463.cmd: 6.105366779451412E-5
# Cycle 323
# Total biomass:
# Model iMM904.cmd: 2.0257184658073696E-5
# Model iJN1463.cmd: 6.114100304130057E-5
# Cycle 324
# Total biomass:
# Model iMM904.cmd: 2.0314312094279313E-5
# Model iJN1463.cmd: 6.122850298367903E-5
# Cycle 325
# Total biomass:
# Model iMM904.cmd: 2.0370968998316167E-5
# Model iJN1463.cmd: 6.13151814064548E-5
# Cycle 326
# Total biomass:
# Model iMM904.cmd: 2.042698395614964E-5
# Model iJN1463.cmd: 6.140356249813896E-5
# Cycle 327
# Total biomass:
# Model iMM904.cmd: 2.048185987099289E-5
# Model iJN1463.cmd: 6.149255624609545E-5
# Cycle 328
# Total biomass:
# Model iMM904.cmd: 2.0534008009726685E-5
# Model iJN1463.cmd: 6.158463744293535E-5
# Cycle 329
# Total biomass:
# Model iMM904.cmd: 2.058681424461094E-5
# Model iJN1463.cmd: 6.168023504812462E-5
# Cycle 330
# Total biomass:
# Model iMM904.cmd: 2.0642443714257404E-5
# Model iJN1463.cmd: 6.176923362692623E-5
# Cycle 331
# Total biomass:
# Model iMM904.cmd: 2.0702256790382303E-5
# Model iJN1463.cmd: 6.18502038912123E-5
# Cycle 332
# Total biomass:
# Model iMM904.cmd: 2.0760585251422626E-5
# Model iJN1463.cmd: 6.1936166336876E-5
# Cycle 333
# Total biomass:
# Model iMM904.cmd: 2.0818953111340075E-5
# Model iJN1463.cmd: 6.201885544705579E-5
# Cycle 334
# Total biomass:
# Model iMM904.cmd: 2.087271746644387E-5
# Model iJN1463.cmd: 6.210595413903456E-5
# Cycle 335
# Total biomass:
# Model iMM904.cmd: 2.0927315553403606E-5
# Model iJN1463.cmd: 6.219246451618928E-5
# Cycle 336
# Total biomass:
# Model iMM904.cmd: 2.0984823744996894E-5
# Model iJN1463.cmd: 6.227718737614657E-5
# Cycle 337
# Total biomass:
# Model iMM904.cmd: 2.1043877898744797E-5
# Model iJN1463.cmd: 6.236062614725346E-5
# Cycle 338
# Total biomass:
# Model iMM904.cmd: 2.1101962497279882E-5
# Model iJN1463.cmd: 6.244141248916116E-5
# Cycle 339
# Total biomass:
# Model iMM904.cmd: 2.115904706490632E-5
# Model iJN1463.cmd: 6.25246856183989E-5
# Cycle 340
# Total biomass:
# Model iMM904.cmd: 2.121565098863085E-5
# Model iJN1463.cmd: 6.260835015314718E-5
# Cycle 341
# Total biomass:
# Model iMM904.cmd: 2.12697526543045E-5
# Model iJN1463.cmd: 6.269477160855783E-5
# Cycle 342
# Total biomass:
# Model iMM904.cmd: 2.1326031636922366E-5
# Model iJN1463.cmd: 6.27788194814667E-5
# Cycle 343
# Total biomass:
# Model iMM904.cmd: 2.1376552921008695E-5
# Model iJN1463.cmd: 6.28682865547764E-5
# Cycle 344
# Total biomass:
# Model iMM904.cmd: 2.1431399433531066E-5
# Model iJN1463.cmd: 6.294922490909514E-5
# Cycle 345
# Total biomass:
# Model iMM904.cmd: 2.1485705062623792E-5
# Model iJN1463.cmd: 6.303125736223508E-5
# Cycle 346
# Total biomass:
# Model iMM904.cmd: 2.1541583128442603E-5
# Model iJN1463.cmd: 6.31136272927E-5
# Cycle 347
# Total biomass:
# Model iMM904.cmd: 2.1597110560211607E-5
# Model iJN1463.cmd: 6.319538925500599E-5
# Cycle 348
# Total biomass:
# Model iMM904.cmd: 2.1649574582794052E-5
# Model iJN1463.cmd: 6.32804117773215E-5
# Cycle 349
# Total biomass:
# Model iMM904.cmd: 2.1703107848366497E-5
# Model iJN1463.cmd: 6.336420917201249E-5
# Cycle 350
# Total biomass:
# Model iMM904.cmd: 2.175359026195944E-5
# Model iJN1463.cmd: 6.343851762476476E-5
# Cycle 351
# Total biomass:
# Model iMM904.cmd: 2.1808719322527665E-5
# Model iJN1463.cmd: 6.351717784704469E-5
# Cycle 352
# Total biomass:
# Model iMM904.cmd: 2.1864988101842087E-5
# Model iJN1463.cmd: 6.359794272149387E-5
# Cycle 353
# Total biomass:
# Model iMM904.cmd: 2.1921522286978622E-5
# Model iJN1463.cmd: 6.368040704855609E-5
# Cycle 354
# Total biomass:
# Model iMM904.cmd: 2.1981549996342935E-5
# Model iJN1463.cmd: 6.375680688873479E-5
# Cycle 355
# Total biomass:
# Model iMM904.cmd: 2.2038997276014768E-5
# Model iJN1463.cmd: 6.38370563158047E-5
# Cycle 356
# Total biomass:
# Model iMM904.cmd: 2.2096162152980127E-5
# Model iJN1463.cmd: 6.392586747842339E-5
# Cycle 357
# Total biomass:
# Model iMM904.cmd: 2.2153423267117847E-5
# Model iJN1463.cmd: 6.4005026647003E-5
# Cycle 358
# Total biomass:
# Model iMM904.cmd: 2.2214996727973284E-5
# Model iJN1463.cmd: 6.408084380786344E-5
# Cycle 359
# Total biomass:
# Model iMM904.cmd: 2.226979915101189E-5
# Model iJN1463.cmd: 6.41599982529418E-5
# Cycle 360
# Total biomass:
# Model iMM904.cmd: 2.2324425290850356E-5
# Model iJN1463.cmd: 6.423202253573913E-5
# Cycle 361
# Total biomass:
# Model iMM904.cmd: 2.23771175516629E-5
# Model iJN1463.cmd: 6.431273035936906E-5
# Cycle 362
# Total biomass:
# Model iMM904.cmd: 2.243432718356456E-5
# Model iJN1463.cmd: 6.438419031114386E-5
# Cycle 363
# Total biomass:
# Model iMM904.cmd: 2.2488240949535493E-5
# Model iJN1463.cmd: 6.44624435313861E-5
# Cycle 364
# Total biomass:
# Model iMM904.cmd: 2.25429289835488E-5
# Model iJN1463.cmd: 6.454021089351225E-5
# Cycle 365
# Total biomass:
# Model iMM904.cmd: 2.259736194688164E-5
# Model iJN1463.cmd: 6.461822724586062E-5
# Cycle 366
# Total biomass:
# Model iMM904.cmd: 2.2652084025885976E-5
# Model iJN1463.cmd: 6.469438882860275E-5
# Cycle 367
# Total biomass:
# Model iMM904.cmd: 2.270702038337812E-5
# Model iJN1463.cmd: 6.477266251321991E-5
# Cycle 368
# Total biomass:
# Model iMM904.cmd: 2.2758880089875622E-5
# Model iJN1463.cmd: 6.485538190057505E-5
# Cycle 369
# Total biomass:
# Model iMM904.cmd: 2.281524548230301E-5
# Model iJN1463.cmd: 6.493194203515625E-5
# Cycle 370
# Total biomass:
# Model iMM904.cmd: 2.2869154209454868E-5
# Model iJN1463.cmd: 6.501174549658549E-5
# Cycle 371
# Total biomass:
# Model iMM904.cmd: 2.292339508756283E-5
# Model iJN1463.cmd: 6.508634039170089E-5
# Cycle 372
# Total biomass:
# Model iMM904.cmd: 2.2975406743953053E-5
# Model iJN1463.cmd: 6.516744496732036E-5
# Cycle 373
# Total biomass:
# Model iMM904.cmd: 2.3028584739088825E-5
# Model iJN1463.cmd: 6.52450045262406E-5
# Cycle 374
# Total biomass:
# Model iMM904.cmd: 2.3082998953987588E-5
# Model iJN1463.cmd: 6.532355758150611E-5
# Cycle 375
# Total biomass:
# Model iMM904.cmd: 2.313511647561398E-5
# Model iJN1463.cmd: 6.540378307599253E-5
# Cycle 376
# Total biomass:
# Model iMM904.cmd: 2.318890820936449E-5
# Model iJN1463.cmd: 6.548263082901146E-5
# Cycle 377
# Total biomass:
# Model iMM904.cmd: 2.3242922019434426E-5
# Model iJN1463.cmd: 6.555955841819988E-5
# Cycle 378
# Total biomass:
# Model iMM904.cmd: 2.3294233145785485E-5
# Model iJN1463.cmd: 6.563820554321194E-5
# Cycle 379
# Total biomass:
# Model iMM904.cmd: 2.3344515957573597E-5
# Model iJN1463.cmd: 6.571839974169135E-5
# Cycle 380
# Total biomass:
# Model iMM904.cmd: 2.339993420563711E-5
# Model iJN1463.cmd: 6.579292675541718E-5
# Cycle 381
# Total biomass:
# Model iMM904.cmd: 2.3458645207733925E-5
# Model iJN1463.cmd: 6.586673514190815E-5
# Cycle 382
# Total biomass:
# Model iMM904.cmd: 2.3518512290226273E-5
# Model iJN1463.cmd: 6.59366607208352E-5
# Cycle 383
# Total biomass:
# Model iMM904.cmd: 2.3578077979064744E-5
# Model iJN1463.cmd: 6.600549119759557E-5
# Cycle 384
# Total biomass:
# Model iMM904.cmd: 2.363628477461547E-5
# Model iJN1463.cmd: 6.607646265842831E-5
# Cycle 385
# Total biomass:
# Model iMM904.cmd: 2.369314562173114E-5
# Model iJN1463.cmd: 6.614893150490907E-5
# Cycle 386
# Total biomass:
# Model iMM904.cmd: 2.3747374455317778E-5
# Model iJN1463.cmd: 6.621914211237792E-5
# Cycle 387
# Total biomass:
# Model iMM904.cmd: 2.3803457919807286E-5
# Model iJN1463.cmd: 6.629269085583429E-5
# Cycle 388
# Total biomass:
# Model iMM904.cmd: 2.3858067534944638E-5
# Model iJN1463.cmd: 6.636901388186132E-5
# Cycle 389
# Total biomass:
# Model iMM904.cmd: 2.3910958751941302E-5
# Model iJN1463.cmd: 6.644546114317048E-5
# Cycle 390
# Total biomass:
# Model iMM904.cmd: 2.3963661964371458E-5
# Model iJN1463.cmd: 6.65218855063586E-5
# Cycle 391
# Total biomass:
# Model iMM904.cmd: 2.4016988880561172E-5
# Model iJN1463.cmd: 6.659757009445679E-5
# Cycle 392
# Total biomass:
# Model iMM904.cmd: 2.4069878820293887E-5
# Model iJN1463.cmd: 6.667373999310888E-5
# Cycle 393
# Total biomass:
# Model iMM904.cmd: 2.4122307561235713E-5
# Model iJN1463.cmd: 6.674914682144081E-5
# Cycle 394
# Total biomass:
# Model iMM904.cmd: 2.4175858731621823E-5
# Model iJN1463.cmd: 6.682424706391308E-5
# Cycle 395
# Total biomass:
# Model iMM904.cmd: 2.4228211454461307E-5
# Model iJN1463.cmd: 6.69000992530996E-5
# Cycle 396
# Total biomass:
# Model iMM904.cmd: 2.4283270586040788E-5
# Model iJN1463.cmd: 6.697338908661952E-5
# Cycle 397
# Total biomass:
# Model iMM904.cmd: 2.433688658887706E-5
# Model iJN1463.cmd: 6.704538825134156E-5
# Cycle 398
# Total biomass:
# Model iMM904.cmd: 2.4390121828572907E-5
# Model iJN1463.cmd: 6.711755616875652E-5
# Cycle 399
# Total biomass:
# Model iMM904.cmd: 2.444368185630766E-5
# Model iJN1463.cmd: 6.718927092828984E-5
# Cycle 400
# Total biomass:
# Model iMM904.cmd: 2.44962913899404E-5
# Model iJN1463.cmd: 6.726364182977352E-5
# Cycle 401
# Total biomass:
# Model iMM904.cmd: 2.454849412507646E-5
# Model iJN1463.cmd: 6.733831113200453E-5
# Cycle 402
# Total biomass:
# Model iMM904.cmd: 2.4600453132925342E-5
# Model iJN1463.cmd: 6.74123620856049E-5
# Cycle 403
# Total biomass:
# Model iMM904.cmd: 2.4652307617172373E-5
# Model iJN1463.cmd: 6.748727806376102E-5
# Cycle 404
# Total biomass:
# Model iMM904.cmd: 2.4706867547675998E-5
# Model iJN1463.cmd: 6.755939676408809E-5
# Cycle 405
# Total biomass:
# Model iMM904.cmd: 2.4759374717511273E-5
# Model iJN1463.cmd: 6.763233553695486E-5
# Cycle 406
# ...
# Cycle 848
# Total biomass:
# Model iMM904.cmd: 4.15193711610299E-5
# Model iJN1463.cmd: 8.791861486031243E-5
# Cycle 849
# Total biomass:
# Model iMM904.cmd: 4.154355576667518E-5
# Model iJN1463.cmd: 8.794656124985432E-5
# Cycle 850
# Total biomass:
# Model iMM904.cmd: 4.156947378031939E-5
# Model iJN1463.cmd: 8.797371706410042E-5
# Cycle 851
# Total biomass:
# Model iMM904.cmd: 4.1595447820011987E-5
# Model iJN1463.cmd: 8.799939419330855E-5
# Cycle 852
# Total biomass:
# Model iMM904.cmd: 4.162239170528534E-5
# Model iJN1463.cmd: 8.802489932246197E-5
# Cycle 853
# Total biomass:
# Model iMM904.cmd: 4.164660606360215E-5
# Model iJN1463.cmd: 8.805195386385586E-5
# Cycle 854
# Total biomass:
# Model iMM904.cmd: 4.1671761122043E-5
# Model iJN1463.cmd: 8.8077815112429E-5
# Cycle 855
# Total biomass:
# Model iMM904.cmd: 4.169391213250632E-5
# Model iJN1463.cmd: 8.810478803830396E-5
# Cycle 856
# Total biomass:
# Model iMM904.cmd: 4.171936829655398E-5
# Model iJN1463.cmd: 8.812955181986419E-5
# Cycle 857
# Total biomass:
# Model iMM904.cmd: 4.1740078989694265E-5
# Model iJN1463.cmd: 8.815208176900456E-5
# Cycle 858
# Total biomass:
# Model iMM904.cmd: 4.176607700600145E-5
# Model iJN1463.cmd: 8.81771736029351E-5
# Cycle 859
# Total biomass:
# Model iMM904.cmd: 4.1783827574052286E-5
# Model iJN1463.cmd: 8.820290492548189E-5
# Cycle 860
# Total biomass:
# Model iMM904.cmd: 4.1805874187202116E-5
# Model iJN1463.cmd: 8.823097099464636E-5
# Cycle 861
# Total biomass:
# Model iMM904.cmd: 4.1822507357036355E-5
# Model iJN1463.cmd: 8.826233173692121E-5
# Cycle 862
# Total biomass:
# Model iMM904.cmd: 4.1845243690867E-5
# Model iJN1463.cmd: 8.828765584407113E-5
# Cycle 863
# Total biomass:
# Model iMM904.cmd: 4.1867646591259895E-5
# Model iJN1463.cmd: 8.830927638454074E-5
# Cycle 864
# Total biomass:
# Model iMM904.cmd: 4.189301655943606E-5
# Model iJN1463.cmd: 8.833295188373189E-5
# Cycle 865
# Total biomass:
# Model iMM904.cmd: 4.191885817001513E-5
# Model iJN1463.cmd: 8.835686578065789E-5
# Cycle 866
# Total biomass:
# Model iMM904.cmd: 4.194462040036988E-5
# Model iJN1463.cmd: 8.838061869961879E-5
# Cycle 867
# Total biomass:
# Model iMM904.cmd: 4.1970154942673004E-5
# Model iJN1463.cmd: 8.8404082890799E-5
# Cycle 868
# Total biomass:
# Model iMM904.cmd: 4.199530651526893E-5
# Model iJN1463.cmd: 8.842709272717144E-5
# Cycle 869
# Total biomass:
# Model iMM904.cmd: 4.202031908711755E-5
# Model iJN1463.cmd: 8.84499705632487E-5
# Cycle 870
# Total biomass:
# Model iMM904.cmd: 4.204523486188478E-5
# Model iJN1463.cmd: 8.847276841960331E-5
# Cycle 871
# Total biomass:
# Model iMM904.cmd: 4.207009127079123E-5
# Model iJN1463.cmd: 8.849550723927176E-5
# Cycle 872
# Total biomass:
# Model iMM904.cmd: 4.209457493979879E-5
# Model iJN1463.cmd: 8.851930273652176E-5
# Cycle 873
# Total biomass:
# Model iMM904.cmd: 4.210852763987853E-5
# Model iJN1463.cmd: 8.855600485897803E-5
# Cycle 874
# Total biomass:
# Model iMM904.cmd: 4.21337114998618E-5
# Model iJN1463.cmd: 8.858055768563307E-5
# Cycle 875
# Total biomass:
# Model iMM904.cmd: 4.2152483308710665E-5
# Model iJN1463.cmd: 8.861025098207729E-5
# Cycle 876
# Total biomass:
# Model iMM904.cmd: 4.217770769942232E-5
# Model iJN1463.cmd: 8.863426237386542E-5
# Cycle 877
# Total biomass:
# Model iMM904.cmd: 4.219649823349921E-5
# Model iJN1463.cmd: 8.866166635657334E-5
# Cycle 878
# Total biomass:
# Model iMM904.cmd: 4.221614812684515E-5
# Model iJN1463.cmd: 8.868746225636803E-5
# Cycle 879
# Total biomass:
# Model iMM904.cmd: 4.224075194116754E-5
# Model iJN1463.cmd: 8.871119809756584E-5
# Cycle 880
# Total biomass:
# Model iMM904.cmd: 4.225952126445584E-5
# Model iJN1463.cmd: 8.874017905447285E-5
# Cycle 881
# Total biomass:
# Model iMM904.cmd: 4.2278405000272865E-5
# Model iJN1463.cmd: 8.876787300071764E-5
# Cycle 882
# Total biomass:
# Model iMM904.cmd: 4.229713875337017E-5
# Model iJN1463.cmd: 8.879638336330597E-5
# Cycle 883
# Total biomass:
# Model iMM904.cmd: 4.2315810557844074E-5
# Model iJN1463.cmd: 8.882324991853227E-5
# Cycle 884
# Total biomass:
# Model iMM904.cmd: 4.233554762179837E-5
# Model iJN1463.cmd: 8.885136082467121E-5
# Cycle 885
# Total biomass:
# Model iMM904.cmd: 4.2354015171747506E-5
# Model iJN1463.cmd: 8.88784615221999E-5
# Cycle 886
# Total biomass:
# Model iMM904.cmd: 4.2376485432865036E-5
# Model iJN1463.cmd: 8.890414374299261E-5
# Cycle 887
# Total biomass:
# Model iMM904.cmd: 4.239605502807841E-5
# Model iJN1463.cmd: 8.893173181567989E-5
# Cycle 888
# Total biomass:
# Model iMM904.cmd: 4.2420176048113706E-5
# Model iJN1463.cmd: 8.895517979015682E-5
# Cycle 889
# Total biomass:
# Model iMM904.cmd: 4.24447663729365E-5
# Model iJN1463.cmd: 8.89781407355439E-5
# Cycle 890
# Total biomass:
# Model iMM904.cmd: 4.246918613067752E-5
# Model iJN1463.cmd: 8.900065544263292E-5
# Cycle 891
# Total biomass:
# Model iMM904.cmd: 4.249328879129783E-5
# Model iJN1463.cmd: 8.902274394984821E-5
# Cycle 892
# Total biomass:
# Model iMM904.cmd: 4.250783800972586E-5
# Model iJN1463.cmd: 8.904894464402391E-5
# Cycle 893
# Total biomass:
# Model iMM904.cmd: 4.253064108370304E-5
# Model iJN1463.cmd: 8.907322057263556E-5
# Cycle 894
# Total biomass:
# Model iMM904.cmd: 4.255412176117374E-5
# Model iJN1463.cmd: 8.909526064266109E-5
# Cycle 895
# Total biomass:
# Model iMM904.cmd: 4.257764127277835E-5
# Model iJN1463.cmd: 8.911683418088183E-5
# Cycle 896
# Total biomass:
# Model iMM904.cmd: 4.260110028328072E-5
# Model iJN1463.cmd: 8.91382474898177E-5
# Cycle 897
# Total biomass:
# Model iMM904.cmd: 4.262726284388475E-5
# Model iJN1463.cmd: 8.916302494273698E-5
# Cycle 898
# Total biomass:
# Model iMM904.cmd: 4.264406535805712E-5
# Model iJN1463.cmd: 8.918881048952264E-5
# Cycle 899
# Total biomass:
# Model iMM904.cmd: 4.266668550686014E-5
# Model iJN1463.cmd: 8.92106737123225E-5
# Cycle 900
# Total biomass:
# Model iMM904.cmd: 4.2684544551668806E-5
# Model iJN1463.cmd: 8.923133100534061E-5
# Cycle 901
# Total biomass:
# Model iMM904.cmd: 4.269928518962744E-5
# Model iJN1463.cmd: 8.925392834364598E-5
# Cycle 902
# Total biomass:
# Model iMM904.cmd: 4.271215001571223E-5
# Model iJN1463.cmd: 8.927953406401286E-5
# Cycle 903
# Total biomass:
# Model iMM904.cmd: 4.27317742673434E-5
# Model iJN1463.cmd: 8.930327330963927E-5
# Cycle 904
# Total biomass:
# Model iMM904.cmd: 4.274825731596948E-5
# Model iJN1463.cmd: 8.932754831861083E-5
# Cycle 905
# Total biomass:
# Model iMM904.cmd: 4.276131441445212E-5
# Model iJN1463.cmd: 8.935400557839958E-5
# Cycle 906
# Total biomass:
# Model iMM904.cmd: 4.2780997790072036E-5
# Model iJN1463.cmd: 8.937927942052129E-5
# Cycle 907
# Total biomass:
# Model iMM904.cmd: 4.280246947618877E-5
# Model iJN1463.cmd: 8.940277540547809E-5
# Cycle 908
# Total biomass:
# Model iMM904.cmd: 4.282401946817653E-5
# Model iJN1463.cmd: 8.942433332993711E-5
# Cycle 909
# Total biomass:
# Model iMM904.cmd: 4.284450735101252E-5
# Model iJN1463.cmd: 8.944582465561748E-5
# Cycle 910
# Total biomass:
# Model iMM904.cmd: 4.2862708635585376E-5
# Model iJN1463.cmd: 8.946875350017829E-5
# Cycle 911
# Total biomass:
# Model iMM904.cmd: 4.288212801348383E-5
# Model iJN1463.cmd: 8.949114057026749E-5
# Cycle 912
# Total biomass:
# Model iMM904.cmd: 4.2904134919164214E-5
# Model iJN1463.cmd: 8.951266810137149E-5
# Cycle 913
# Total biomass:
# Model iMM904.cmd: 4.2925170570460405E-5
# Model iJN1463.cmd: 8.953357569085389E-5
# Cycle 914
# Total biomass:
# Model iMM904.cmd: 4.294479639614479E-5
# Model iJN1463.cmd: 8.955912757535978E-5
# Cycle 915
# Total biomass:
# Model iMM904.cmd: 4.296754949828473E-5
# Model iJN1463.cmd: 8.958093975884991E-5
# Cycle 916
# Total biomass:
# Model iMM904.cmd: 4.299057596234931E-5
# Model iJN1463.cmd: 8.960232373748035E-5
# Cycle 917
# Total biomass:
# Model iMM904.cmd: 4.3013685761156644E-5
# Model iJN1463.cmd: 8.962361071035466E-5
# Cycle 918
# Total biomass:
# Model iMM904.cmd: 4.303659395352337E-5
# Model iJN1463.cmd: 8.964460686637215E-5
# Cycle 919
# Total biomass:
# Model iMM904.cmd: 4.3053671697263304E-5
# Model iJN1463.cmd: 8.966588256053296E-5
# Cycle 920
# Total biomass:
# Model iMM904.cmd: 4.307128079269737E-5
# Model iJN1463.cmd: 8.969199155303437E-5
# Cycle 921
# Total biomass:
# Model iMM904.cmd: 4.3093648120451997E-5
# Model iJN1463.cmd: 8.971351701167853E-5
# Cycle 922
# Total biomass:
# Model iMM904.cmd: 4.3109243489755556E-5
# Model iJN1463.cmd: 8.973771174935692E-5
# Cycle 923
# Total biomass:
# Model iMM904.cmd: 4.312915576082583E-5
# Model iJN1463.cmd: 8.976110131149952E-5
# Cycle 924
# Total biomass:
# Model iMM904.cmd: 4.315173025020056E-5
# Model iJN1463.cmd: 8.978240206846517E-5
# Cycle 925
# Total biomass:
# Model iMM904.cmd: 4.3166275144407786E-5
# Model iJN1463.cmd: 8.980865901787981E-5
# Cycle 926
# Total biomass:
# Model iMM904.cmd: 4.318340417675075E-5
# Model iJN1463.cmd: 8.983286062932126E-5
# Cycle 927
# Total biomass:
# Model iMM904.cmd: 4.320175433169844E-5
# Model iJN1463.cmd: 8.985442208037701E-5
# Cycle 928
# Total biomass:
# Model iMM904.cmd: 4.322059711943239E-5
# Model iJN1463.cmd: 8.987788534213183E-5
# Cycle 929
# Total biomass:
# Model iMM904.cmd: 4.323458382502869E-5
# Model iJN1463.cmd: 8.990552196239845E-5
# Cycle 930
# Total biomass:
# Model iMM904.cmd: 4.32484169623637E-5
# Model iJN1463.cmd: 8.993439453632883E-5
# Cycle 931
# Total biomass:
# Model iMM904.cmd: 4.326860580226088E-5
# Model iJN1463.cmd: 8.995672312066128E-5
# Cycle 932
# Total biomass:
# Model iMM904.cmd: 4.328826229566472E-5
# Model iJN1463.cmd: 8.998041153076075E-5
# Cycle 933
# Total biomass:
# Model iMM904.cmd: 4.330981009839176E-5
# Model iJN1463.cmd: 9.000161830942816E-5
# Cycle 934
# Total biomass:
# Model iMM904.cmd: 4.3329917189905003E-5
# Model iJN1463.cmd: 9.002454126270759E-5
# Cycle 935
# Total biomass:
# Model iMM904.cmd: 4.3351749036589094E-5
# Model iJN1463.cmd: 9.004510458109881E-5
# Cycle 936
# Total biomass:
# Model iMM904.cmd: 4.33680911200358E-5
# Model iJN1463.cmd: 9.006736660396775E-5
# Cycle 937
# Total biomass:
# Model iMM904.cmd: 4.3383583395082265E-5
# Model iJN1463.cmd: 9.009337319963877E-5
# Cycle 938
# Total biomass:
# Model iMM904.cmd: 4.3404682407914376E-5
# Model iJN1463.cmd: 9.01130394485684E-5
# Cycle 939
# Total biomass:
# Model iMM904.cmd: 4.3425859509054145E-5
# Model iJN1463.cmd: 9.013232114563668E-5
# Cycle 940
# Total biomass:
# Model iMM904.cmd: 4.3447018456719666E-5
# Model iJN1463.cmd: 9.015146219316231E-5
# Cycle 941
# Total biomass:
# Model iMM904.cmd: 4.346753346582005E-5
# Model iJN1463.cmd: 9.017163838854487E-5
# Cycle 942
# Total biomass:
# Model iMM904.cmd: 4.347798904232417E-5
# Model iJN1463.cmd: 9.020017779849272E-5
# Cycle 943
# Total biomass:
# Model iMM904.cmd: 4.3495382678724425E-5
# Model iJN1463.cmd: 9.022098646587741E-5
# Cycle 944
# Total biomass:
# Model iMM904.cmd: 4.35118816959318E-5
# Model iJN1463.cmd: 9.02382504408244E-5
# Cycle 945
# Total biomass:
# Model iMM904.cmd: 4.352561525810768E-5
# Model iJN1463.cmd: 9.025736565772693E-5
# Cycle 946
# Total biomass:
# Model iMM904.cmd: 4.353585139724669E-5
# Model iJN1463.cmd: 9.028315637274665E-5
# Cycle 947
# Total biomass:
# Model iMM904.cmd: 4.355358290833252E-5
# Model iJN1463.cmd: 9.03040284991291E-5
# Cycle 948
# Total biomass:
# Model iMM904.cmd: 4.35733992760926E-5
# Model iJN1463.cmd: 9.03233981043972E-5
# Cycle 949
# Total biomass:
# Model iMM904.cmd: 4.3593561688642884E-5
# Model iJN1463.cmd: 9.034259303503363E-5
# Cycle 950
# Total biomass:
# Model iMM904.cmd: 4.360904605768734E-5
# Model iJN1463.cmd: 9.036689129662027E-5
# Cycle 951
# Total biomass:
# Model iMM904.cmd: 4.362743414279619E-5
# Model iJN1463.cmd: 9.038793134148015E-5
# Cycle 952
# Total biomass:
# Model iMM904.cmd: 4.3647288671241476E-5
# Model iJN1463.cmd: 9.040727977709495E-5
# Cycle 953
# Total biomass:
# Model iMM904.cmd: 4.366689845513649E-5
# Model iJN1463.cmd: 9.042753502530624E-5
# Cycle 954
# Total biomass:
# Model iMM904.cmd: 4.36866825121529E-5
# Model iJN1463.cmd: 9.044598557949722E-5
# Cycle 955
# Total biomass:
# Model iMM904.cmd: 4.370785447918682E-5
# Model iJN1463.cmd: 9.046569234813257E-5
# Cycle 956
# Total biomass:
# Model iMM904.cmd: 4.372832219857944E-5
# Model iJN1463.cmd: 9.048667975801465E-5
# Cycle 957
# Total biomass:
# Model iMM904.cmd: 4.3745987491007146E-5
# Model iJN1463.cmd: 9.050441643744209E-5
# Cycle 958
# Total biomass:
# Model iMM904.cmd: 4.3766490971196134E-5
# Model iJN1463.cmd: 9.052351081341354E-5
# Cycle 959
# Total biomass:
# Model iMM904.cmd: 4.3783435071957584E-5
# Model iJN1463.cmd: 9.05476742320952E-5
# Cycle 960
# Total biomass:
# Model iMM904.cmd: 4.380256705597297E-5
# Model iJN1463.cmd: 9.056971458683997E-5
# Cycle 961
# Total biomass:
# Model iMM904.cmd: 4.3820597436184546E-5
# Model iJN1463.cmd: 9.059279720224988E-5
# Cycle 962
# Total biomass:
# Model iMM904.cmd: 4.38368133616486E-5
# Model iJN1463.cmd: 9.061557897206013E-5
# Cycle 963
# Total biomass:
# Model iMM904.cmd: 4.3854884638288524E-5
# Model iJN1463.cmd: 9.063740797740588E-5
# Cycle 964
# Total biomass:
# Model iMM904.cmd: 4.387440939335464E-5
# Model iJN1463.cmd: 9.065723761332292E-5
# Cycle 965
# Total biomass:
# Model iMM904.cmd: 4.3894953010611226E-5
# Model iJN1463.cmd: 9.067661075335829E-5
# Cycle 966
# Total biomass:
# Model iMM904.cmd: 4.3915661275595915E-5
# Model iJN1463.cmd: 9.069574255877804E-5
# Cycle 967
# Total biomass:
# Model iMM904.cmd: 4.393734263183327E-5
# Model iJN1463.cmd: 9.071724192019197E-5
# Cycle 968
# Total biomass:
# Model iMM904.cmd: 4.395767447928097E-5
# Model iJN1463.cmd: 9.07371475264966E-5
# Cycle 969
# Total biomass:
# Model iMM904.cmd: 4.397824927633876E-5
# Model iJN1463.cmd: 9.075616744712128E-5
# Cycle 970
# Total biomass:
# Model iMM904.cmd: 4.399396126402899E-5
# Model iJN1463.cmd: 9.077731152814497E-5
# Cycle 971
# Total biomass:
# Model iMM904.cmd: 4.4012641402577065E-5
# Model iJN1463.cmd: 9.079712079239664E-5
# Cycle 972
# Total biomass:
# Model iMM904.cmd: 4.4032861196109015E-5
# Model iJN1463.cmd: 9.081605689431874E-5
# Cycle 973
# Total biomass:
# Model iMM904.cmd: 4.4053232528936854E-5
# Model iJN1463.cmd: 9.083465036344056E-5
# Cycle 974
# Total biomass:
# Model iMM904.cmd: 4.407059512384821E-5
# Model iJN1463.cmd: 9.085133478386738E-5
# Cycle 975
# Total biomass:
# Model iMM904.cmd: 4.4086472019434746E-5
# Model iJN1463.cmd: 9.087256724301733E-5
# Cycle 976
# Total biomass:
# Model iMM904.cmd: 4.4105605119654165E-5
# Model iJN1463.cmd: 9.089153289631426E-5
# Cycle 977
# Total biomass:
# Model iMM904.cmd: 4.412183215181479E-5
# Model iJN1463.cmd: 9.091268607647384E-5
# Cycle 978
# Total biomass:
# Model iMM904.cmd: 4.414093570501072E-5
# Model iJN1463.cmd: 9.093239856203123E-5
# Cycle 979
# Total biomass:
# Model iMM904.cmd: 4.416084813237002E-5
# Model iJN1463.cmd: 9.095097355838582E-5
# Cycle 980
# Total biomass:
# Model iMM904.cmd: 4.418098478765889E-5
# Model iJN1463.cmd: 9.096939783268599E-5
# Cycle 981
# Total biomass:
# Model iMM904.cmd: 4.4197910610858586E-5
# Model iJN1463.cmd: 9.098660796611201E-5
# Cycle 982
# Total biomass:
# Model iMM904.cmd: 4.421132405776511E-5
# Model iJN1463.cmd: 9.101133796714141E-5
# Cycle 983
# Total biomass:
# Model iMM904.cmd: 4.422831528626707E-5
# Model iJN1463.cmd: 9.102868751545606E-5
# Cycle 984
# Total biomass:
# Model iMM904.cmd: 4.424757080650629E-5
# Model iJN1463.cmd: 9.10467714116806E-5
# Cycle 985
# Total biomass:
# Model iMM904.cmd: 4.4262286175367716E-5
# Model iJN1463.cmd: 9.107052258200334E-5
# Cycle 986
# Total biomass:
# Model iMM904.cmd: 4.427922282082391E-5
# Model iJN1463.cmd: 9.109027800933072E-5
# Cycle 987
# Total biomass:
# Model iMM904.cmd: 4.429858299154901E-5
# Model iJN1463.cmd: 9.110866726183028E-5
# Cycle 988
# Total biomass:
# Model iMM904.cmd: 4.431809998724293E-5
# Model iJN1463.cmd: 9.11266200219878E-5
# Cycle 989
# Total biomass:
# Model iMM904.cmd: 4.433777104071447E-5
# Model iJN1463.cmd: 9.114447391500711E-5
# Cycle 990
# Total biomass:
# Model iMM904.cmd: 4.435368215703457E-5
# Model iJN1463.cmd: 9.116010227038627E-5
# Cycle 991
# Total biomass:
# Model iMM904.cmd: 4.437267779169014E-5
# Model iJN1463.cmd: 9.117739499662533E-5
# Cycle 992
# Total biomass:
# Model iMM904.cmd: 4.43883086367772E-5
# Model iJN1463.cmd: 9.119655124999262E-5
# Cycle 993
# Total biomass:
# Model iMM904.cmd: 4.440590028937304E-5
# Model iJN1463.cmd: 9.121394018589558E-5
# Cycle 994
# Total biomass:
# Model iMM904.cmd: 4.441159555643157E-5
# Model iJN1463.cmd: 9.12228647851689E-5
# Cycle 995
# Total biomass:
# Model iMM904.cmd: 4.442430526815439E-5
# Model iJN1463.cmd: 9.12347928465614E-5
# Cycle 996
# Total biomass:
# Model iMM904.cmd: 4.443927529989809E-5
# Model iJN1463.cmd: 9.125379917355551E-5
# Cycle 997
# Total biomass:
# Model iMM904.cmd: 4.445790606489345E-5
# Model iJN1463.cmd: 9.12710020252256E-5
# Cycle 998
# Total biomass:
# Model iMM904.cmd: 4.447699874616696E-5
# Model iJN1463.cmd: 9.128835637450467E-5
# Cycle 999
# Total biomass:
# Model iMM904.cmd: 4.4492868142748993E-5
# Model iJN1463.cmd: 9.130931738513002E-5
# Cycle 1000
# Total biomass:
# Model iMM904.cmd: 4.451166560367883E-5
# Model iJN1463.cmd: 9.132629503133905E-5
# Cycle 1001
# End of simulation
# Total time = 20543.019s
#
# STDERR empty.

# %% [markdown]
# Para revisar la biomasa total

# %%
sim.total_biomass.plot(x = "cycle")
# Out:
# <AxesSubplot:xlabel='cycle'>

# %% [markdown]
# Graficamos los resultados de biomasa y demás metabolitos interesantes en el grid:

# %%
im = sim.get_biomass_image('iMM904', params.all_params['maxCycles'])
im2 = sim.get_biomass_image('iJN1463',params.all_params['maxCycles'])

final = np.zeros((grid_size,grid_size,3))
final[:,:,0] = im / np.max(im)
final[:,:,1] = im2 / np.max(im2)
for rock in rock_locs:
    final[rock[0],rock[1],0:3] = 0.4 
from matplotlib import pyplot as plt
ﬁg, ax = plt.subplots(ﬁgsize = (3.1, 3.1))
ax.imshow(ﬁnal)
plt.imshow(final)

# %%
plt.imshow(sim.get_metabolite_image("succ_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("ac_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("nh4_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("o2_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("catechol_e",params.all_params['maxCycles']))
