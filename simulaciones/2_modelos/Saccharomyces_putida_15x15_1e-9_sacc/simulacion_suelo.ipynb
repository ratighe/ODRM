# %% [markdown]
# **Soil-air interface.**
#
# Using the functionality of COMETS, one can design simulations which go beyond in silico corollaries of lab experiments to make predictions for environments mimicking natural ecosystems, which is a necessary step for understanding natural ecology from first principles. In this example, we consider a simulation of a soil environment. We use source-and-sink functions to model how a root provides organic acids to the environment while removing ammonia (Huang et al 2014 Botany). While we restrict the root functionality to a source/sink, one could use functionality demonstrated above, for example extracellular enzymes, to generate feedback loops between microbe-produced metabolites and root exudation. We use fixed metabolite concentrations to mimic the largely unchanging air interface above a root, which generates an oxygen gradient. Additionally, since soil is characterized by strong spatial structure with many impenetrable barriers that localized interactions (Nunan 2017), we place “rock” barriers throughout the simulation area. A more complex simulation could use varying diffusion constants for metabolites, as described in a previous protocol (Virtual Petri Dish). Similarly, we use standard diffusion of biomass, but this could be changed to use pushing force or non-linear diffusion for a potentially increased realism.

# %%
import cobra 
import sys 
import copy 
import numpy as np 
from matplotlib import pyplot as plt 
import cometspy as c

# %% [markdown]
# Para nuestro proyecto, utilizaremos Escherichia coli (modelo iAF1260), Pseudomonas putida (modelo iJN1463) y Saccharomyces Cerevisiae (modelo iMM904), recuperados de la base de datos BIGG.
#
# Cambiamos los bounds de las funciones objetivo de los modelos:

# %%
model_dir = "./modelos" # model location
iMM = cobra.io.read_sbml_model(model_dir + '/iMM904.xml')
iJN = cobra.io.read_sbml_model(model_dir + '/iJN1463.xml')

iMM.reactions.get_by_id('BIOMASS_SC5_notrace').lower_bound = 0
iMM.reactions.get_by_id('BIOMASS_SC5_notrace').upper_bound = 1000

iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').lower_bound = 0
iJN.reactions.get_by_id('BIOMASS_KT2440_WT3').upper_bound = 1000

# %% [markdown]
# Luego se convierten estos modelos al formato de COMETS. Se utilizan funciones helper para dos cosas: a) Asegurar que el modelo en COMETS no confunda las reacciones de "sink" con las de exchange, ya que en COBRA están desbalanceadas y por tanto se parecen a las de exchange, y b) abrir todos los bounds de las reacciones de exchange, para que COMETS controle la composición del medio.

# %%
iMM_comets = c.model(iMM)
iMM_comets.ensure_sinks_are_not_exchanges()
iMM_comets.open_exchanges()

iJN_comets = c.model(iJN)
iJN_comets.ensure_sinks_are_not_exchanges()
iJN_comets.open_exchanges()

# %% [markdown]
# El mundo que se simulará tendrá dimensiones de 30x30. El eje de la izquierda (x = 0) corresponde a la raíz, y el eje superior (y = 0) corresponde al aire. La biomasa y las rocas se distribuyen en el resto del grid. Donde hayan rocas no puede haber ni biomasa ni metabolitos, así que seleccionamos esos lugares primero. Para esta simulación, se generarán 3 rocas con un un tamaño medio de 1 cuadraditos. Para generar las piedras se utiliza la función helper grow_rocks.

# %%
from cometspy.utils import grow_rocks, pick_random_locations

grid_size = 15 # 100
n_rocks = 27 # 70
rock_locs = grow_rocks(n = n_rocks, xrange = [1,grid_size-1],yrange = [1,grid_size-1],mean_size = 1)

# %% [markdown]
# Cada especie será plantada en 20 lugares sin sobreponerse. Para esto se utiliza la función helper pick_random_locations, la cual toma como argumento una tupla generada anteriormente que marca lugares "prohibidos", como los cuadrados donde se encuentran las rocas.
#
# Generamos una copia de rock_locs para no cambiarla accidentalmente, y la llamamos forbbiden_locs:

# %%
import copy
forbidden_locs = copy.deepcopy(rock_locs)

# %% [markdown]
# Ahora elegimos al azar los lugares para cada especie, y los vamos añadiendo a la lista forbidden locs para que no se sobrepongan:

# %%
founders_per_species = 15 # 60
iMM_locs = pick_random_locations(n = founders_per_species, 
                                   xrange = [1,grid_size], yrange = [1,grid_size], 
                                   forbidden_locs = forbidden_locs)
forbidden_locs.extend(iMM_locs)
iJN_locs = pick_random_locations(founders_per_species, [1,grid_size],[1,grid_size], forbidden_locs)

# %% [markdown]
# Para graficar los lugares utilizamos matplotlib:

# %%
from matplotlib import pyplot as plt
initial_image = np.zeros((grid_size,grid_size,3))
for rock in rock_locs:
    initial_image[rock[0],rock[1],0:3] = 0.5 
for loc in iMM_locs:
    initial_image[loc[0],loc[1],1] = 1
for loc in iJN_locs:
    initial_image[loc[0],loc[1],2] = 1
plt.imshow(initial_image)

# %% [markdown]
# Generamos el layout y agregamos las rocas:

# %%
# iMM
iMM_initial_pop = [] 
for loc in iJN_locs: 
    iMM_initial_pop.append([loc[0], loc[1], 1.e-9]) 
iMM_comets.initial_pop = iMM_initial_pop 
# iJN
iJN_initial_pop = [] 
for loc in iJN_locs: 
    iJN_initial_pop.append([loc[0], loc[1], 1.e-8]) 
iJN_comets.initial_pop = iJN_initial_pop

# %% [markdown]
# Setteamos las poblaciones iniciales para cada especie, con esto los modelos están listos y los añadimos al layout:

# %%
layout = c.layout([iMM_comets, iJN_comets])
layout.grid = [grid_size,grid_size]
layout.add_barriers(rock_locs)

# %% [markdown]
# Añadimos los metabolitos que estarán inicialmente disponibles en el ambiente. Usamos la función helper add_typical_trace_metabolites() para las trazas típicas. Bajamos el valor del oxígeno dado que la idea es que el que esté disponible difunda desde la atmósfera. Añadimos algunos metabolitos que no se añadieron con la función helper:

# %%
layout.add_typical_trace_metabolites()
layout.set_specific_metabolite('o2_e',0.000001)
layout.set_specific_metabolite('hco3_e',1000)
layout.set_specific_metabolite('co2_e',1000)
#layout.set_specific_metabolite('h2_e',1000)
layout.set_specific_metabolite('so3_e',1000)
layout.set_specific_metabolite('nh4_e',0.0000001)

layout.set_specific_metabolite('glc__D_e',0.0000001)
layout.set_specific_metabolite('meoh_e',0.00000001)
layout.set_specific_metabolite('cys__L_e',0.0000001)
layout.set_specific_metabolite('catechol_e',0.0000001)

# %% [markdown]
# Para la capa de aire, dejamos el oxígeno en un valor constante. Al fondo también dejamos al oxígeno en un valor fijo e igual a 0, para simular el efecto de difusión. De manera similar, hacemos lo mismo con el amoniaco y la raíz en la parte izquierda:

# %%
# set static media of O2 and CO2 at the top and bottom-- the "air" and continuous loss of O2 downwards
for x in range(grid_size):
    layout.set_specific_static_at_location('o2_e', (x,0), .0001) # top
    layout.set_specific_static_at_location('o2_e', (x,grid_size-1), 0.) # bottom
    layout.set_specific_static_at_location('co2_e', (x,0), .0001)
    
for x in range(grid_size):
    layout.set_specific_static_at_location('nh4_e', (0,x), 0.0)

# %% [markdown]
# La raíz consume todo el amoniaco, pero es una fuente de acidos orgánicos y metanol para el ambiente. Asumiendo una tasa fija:

# %%
for x in range(grid_size):
    layout.set_specific_refresh_at_location('cit_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('meoh_e', (0,x), .000001)
    layout.set_specific_refresh_at_location('succ_e', (0,x), .000001)

# %% [markdown]
# El layout y los modelos están listos, ahora setteamos los parámetros de la simulación:

# %%
params = c.params()
params.set_param('timeStep', 0.1)
params.set_param('maxCycles', 1000)
params.set_param('maxSpaceBiomass', 10)
params.set_param('deathRate', 0.0001) # die at rate of 1/10000 per hour
params.set_param('writeBiomassLog', True)
params.set_param('BiomassLogRate', 500)
params.set_param('writeMediaLog', True)
params.set_param('MediaLogRate', 500)
params.set_param("writeFluxLog", True)
params.set_param("FluxLogRate", 500)
params.set_param('numRunThreads', 3)
params.set_param('defaultKm', 0.000001)

# %% [markdown]
# Ahora creamos el objeto de la simulación y la corremos. Ojito que se demora y el pc empieza a despegar.

# %%
sim = c.comets(layout, params)
sim.run(False)
# Out:
# Running COMETS simulation ...
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3357: DtypeWarning: Columns (11,13,20,23,24,27,28,31,32,35,39,46,48,62,68,69,70,80,82,85,105,123,130,150,152,169,175,185,187,199,214,225,230,255,256,257,258,274,287,292,296,297,298,324,325,333,334,335,338,339,348,374,375,378,392,396,418,419,420,421,423,425,438,440,450,452,455,463,485,489,492,509,511,512,513,520,525,526,527,533,537,538,548,554,558,560,567,576,582,590,606,614,617,628,631,633,634,648,651,653,657,658,674,678,680,691,692,693,698,701,705,706,708,711,719,726,729,732,739,740,741,744,756,773,778,779,780,788,803,810,842,847,867,868,869,870,879,883,884,913,925,929,932,939,953,954,958,967,978,984,1008,1018,1022,1026,1050,1080,1085,1091,1097,1098,1126,1127,1149,1159,1165,1176,1181,1182,1183,1184,1185,1188,1204,1206,1208,1209,1210,1216,1217,1218,1237,1261,1262,1264,1266,1284,1288,1294,1316,1331,1333,1334,1336,1340,1344,1346,1348,1351,1365,1369,1375,1396,1405,1412,1416,1420,1424,1429,1439,1442,1447,1453,1464,1467,1470,1472,1481,1487,1490,1503,1505,1507,1514,1516,1525,1530,1531,1533,1534,1535,1536,1544,1546,1548,1552,1553,1554,1555,1556,1557,1562,1565,1567,1570,1571,1572,1578,1587,1599,1601,1617,1621,1622,1624,1625,1629,1631,1641,1643,1740,1741,1764,1767,1768,1769,1771,1772,1774,1776,1778,1784,1785,1791,1808,1812,1813,1814,1815,1855,1871,1873,1874,1875,1877,1878,1895,1896,1920,1921,1926,1986,2043,2055,2071,2072,2087,2125,2127,2133,2134,2135,2140,2160,2168,2169,2170,2204,2206,2212,2227,2244,2254,2257,2264,2322,2373,2374,2382,2390,2391,2393,2394,2423,2424,2436,2439,2472,2474,2476,2477,2479,2480,2489,2531,2535,2558,2594,2639,2673,2682,2704,2712,2713,2714,2716,2719,2720,2729,2731,2733,2762,2763,2764,2765,2766,2790,2833,2841,2852,2857,2859,2862,2884,2888,2900,2908,2911,2916,2917) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Done!

# %%
print(sim.run_output)
print(sim.run_errors)
# Out:
# -script
# running script file: C:\Users\ronal\Desktop\Proyecto ODRM\ODRM\simulaciones\2_modelos\Saccharomyces_putida_15x15_1e-9_sacc/.current_script_0x1bdf21d7a60
# Current Java version: 17.0.1
# Parameters file .current_global_0x1bdf21d7a60 loaded.
# Parameters file .current_package_0x1bdf21d7a60 loaded.
# Loading layout file '.current_layout_0x1bdf21d7a60'...
# null\COMETS_manifest.txt (El sistema no puede encontrar la ruta especificada)
# Unable to initialize manifest file.
# Continuing without writing manifest file.
# Found 2 model files!
# Loading '.\iMM904.cmd' ...
# Academic license - for non-commercial use only - expires 2022-02-10
# Academic license - for non-commercial use only - expires 2022-02-10
# Done!
#  Testing default parameters...
# Done!
# Optimizer status code = 5 (looks ok!)
# objective solution =
# Academic license - for non-commercial use only - expires 2022-02-10
# Academic license - for non-commercial use only - expires 2022-02-10
# Academic license - for non-commercial use only - expires 2022-02-10
# Academic license - for non-commercial use only - expires 2022-02-10
# Academic license - for non-commercial use only - expires 2022-02-10
# Academic license - for non-commercial use only - expires 2022-02-10
# Academic license - for non-commercial use only - expires 2022-02-10
# Academic license - for non-commercial use only - expires 2022-02-10
# Academic license - for non-commercial use only - expires 2022-02-10
# Academic license - for non-commercial use only - expires 2022-02-10
# Academic license - for non-commercial use only - expires 2022-02-10
# Academic license - for non-commercial use only - expires 2022-02-10
# FBARunThread-0 starting up.
# FBARunThread-1 starting up.
# FBARunThread-2 starting up.
# Total biomass:
# Model iMM904.cmd: 1.5634903661963865E-8
# Model iJN1463.cmd: 1.5745832779161727E-7
# Cycle 2
# Total biomass:
# Model iMM904.cmd: 1.629928621116342E-8
# Model iJN1463.cmd: 1.6530848241140826E-7
# Cycle 3
# Total biomass:
# Model iMM904.cmd: 1.708421735181795E-8
# Model iJN1463.cmd: 1.7416009995686605E-7
# Cycle 4
# Total biomass:
# Model iMM904.cmd: 1.794881469149731E-8
# Model iJN1463.cmd: 1.8371455892911058E-7
# Cycle 5
# Total biomass:
# Model iMM904.cmd: 1.8884491388414353E-8
# Model iJN1463.cmd: 1.9401600673586533E-7
# Cycle 6
# Total biomass:
# Model iMM904.cmd: 1.9883384039327303E-8
# Model iJN1463.cmd: 2.0512525242160704E-7
# Cycle 7
# Total biomass:
# Model iMM904.cmd: 2.094398061836455E-8
# Model iJN1463.cmd: 2.1704807385275868E-7
# Cycle 8
# Total biomass:
# Model iMM904.cmd: 2.2069820139960807E-8
# Model iJN1463.cmd: 2.2980661936753724E-7
# Cycle 9
# Total biomass:
# Model iMM904.cmd: 2.3261883108539155E-8
# Model iJN1463.cmd: 2.4338915214002376E-7
# Cycle 10
# Total biomass:
# Model iMM904.cmd: 2.452560891096683E-8
# Model iJN1463.cmd: 2.578305242472E-7
# Cycle 11
# Total biomass:
# Model iMM904.cmd: 2.5861529477320492E-8
# Model iJN1463.cmd: 2.731568762063107E-7
# Cycle 12
# Total biomass:
# Model iMM904.cmd: 2.727374739457269E-8
# Model iJN1463.cmd: 2.8942200333958156E-7
# Cycle 13
# Total biomass:
# Model iMM904.cmd: 2.8766598678161762E-8
# Model iJN1463.cmd: 3.0668295554765367E-7
# Cycle 14
# Total biomass:
# Model iMM904.cmd: 3.034466600454739E-8
# Model iJN1463.cmd: 3.2500023299938067E-7
# Cycle 15
# Total biomass:
# Model iMM904.cmd: 3.201279276994014E-8
# Model iJN1463.cmd: 3.4443799377289004E-7
# Cycle 16
# Total biomass:
# Model iMM904.cmd: 3.377609797654845E-8
# Model iJN1463.cmd: 3.650642741267811E-7
# Cycle 17
# Total biomass:
# Model iMM904.cmd: 3.5639991972057896E-8
# Model iJN1463.cmd: 3.869512220818571E-7
# Cycle 18
# Total biomass:
# Model iMM904.cmd: 3.761019308334499E-8
# Model iJN1463.cmd: 4.10175345068175E-7
# Cycle 19
# Total biomass:
# Model iMM904.cmd: 3.9692745192115673E-8
# Model iJN1463.cmd: 4.34817772459914E-7
# Cycle 20
# Total biomass:
# Model iMM904.cmd: 4.189403630440994E-8
# Model iJN1463.cmd: 4.6096453387156985E-7
# Cycle 21
# Total biomass:
# Model iMM904.cmd: 4.4220818168618635E-8
# Model iJN1463.cmd: 4.887068541612802E-7
# Cycle 22
# Total biomass:
# Model iMM904.cmd: 4.668022699991465E-8
# Model iJN1463.cmd: 5.181414661228108E-7
# Model iMM904.cmd: 8.205788985964973E-6
# Model iJN1463.cmd: 5.41255870304223E-5
# Cycle 283
# Total biomass:
# Model iMM904.cmd: 8.259595173283157E-6
# Model iJN1463.cmd: 5.423987431932525E-5
# Cycle 284
# Total biomass:
# Model iMM904.cmd: 8.321943310142715E-6
# Model iJN1463.cmd: 5.434243180256239E-5
# Cycle 285
# Total biomass:
# Model iMM904.cmd: 8.37443273418496E-6
# Model iJN1463.cmd: 5.445549632781482E-5
# Cycle 286
# Total biomass:
# Model iMM904.cmd: 8.435513941662041E-6
# Model iJN1463.cmd: 5.456292559331656E-5
# Cycle 287
# Total biomass:
# Model iMM904.cmd: 8.493260611628501E-6
# Model iJN1463.cmd: 5.467024674264354E-5
# Cycle 288
# Total biomass:
# Model iMM904.cmd: 8.545861019260026E-6
# Model iJN1463.cmd: 5.4783130218706864E-5
# Cycle 289
# Total biomass:
# Model iMM904.cmd: 8.605665744591621E-6
# Model iJN1463.cmd: 5.4888259367278564E-5
# Cycle 290
# Total biomass:
# Model iMM904.cmd: 8.669124525074166E-6
# Model iJN1463.cmd: 5.498889357283979E-5
# Cycle 291
# Total biomass:
# Model iMM904.cmd: 8.731845373724109E-6
# Model iJN1463.cmd: 5.509277400739092E-5
# Cycle 292
# Total biomass:
# Model iMM904.cmd: 8.788379764135821E-6
# Model iJN1463.cmd: 5.520081006985344E-5
# Cycle 293
# Total biomass:
# Model iMM904.cmd: 8.842769647565817E-6
# Model iJN1463.cmd: 5.5310593109403866E-5
# Cycle 294
# Total biomass:
# Model iMM904.cmd: 8.904657380908196E-6
# Model iJN1463.cmd: 5.541041329856439E-5
# Cycle 295
# Total biomass:
# Model iMM904.cmd: 8.959920198758758E-6
# Model iJN1463.cmd: 5.5518281960706925E-5
# Cycle 296
# Total biomass:
# Model iMM904.cmd: 9.018372991101867E-6
# Model iJN1463.cmd: 5.562175885456954E-5
# Cycle 297
# Total biomass:
# Model iMM904.cmd: 9.080453552999363E-6
# Model iJN1463.cmd: 5.57216657721647E-5
# Cycle 298
# Total biomass:
# Model iMM904.cmd: 9.13753571352581E-6
# Model iJN1463.cmd: 5.582687844314533E-5
# Cycle 299
# Total biomass:
# Model iMM904.cmd: 9.196772586077363E-6
# Model iJN1463.cmd: 5.593149577023536E-5
# Cycle 300
# Total biomass:
# Model iMM904.cmd: 9.252358732572033E-6
# Model iJN1463.cmd: 5.6038610372685095E-5
# Cycle 301
# Total biomass:
# Model iMM904.cmd: 9.309549357451536E-6
# Model iJN1463.cmd: 5.614214886208057E-5
# Cycle 302
# Total biomass:
# Model iMM904.cmd: 9.368964842828006E-6
# Model iJN1463.cmd: 5.624229194751243E-5
# Cycle 303
# Total biomass:
# Model iMM904.cmd: 9.429366728646005E-6
# Model iJN1463.cmd: 5.634070090591642E-5
# Cycle 304
# Total biomass:
# Model iMM904.cmd: 9.490769952543899E-6
# Model iJN1463.cmd: 5.6437920715113765E-5
# Cycle 305
# Total biomass:
# Model iMM904.cmd: 9.551555163388572E-6
# Model iJN1463.cmd: 5.65341824629163E-5
# Cycle 306
# Total biomass:
# Model iMM904.cmd: 9.607942101993605E-6
# Model iJN1463.cmd: 5.66351654873471E-5
# Cycle 307
# Total biomass:
# Model iMM904.cmd: 9.665365444104573E-6
# Model iJN1463.cmd: 5.67364124655292E-5
# Cycle 308
# Total biomass:
# Model iMM904.cmd: 9.72627501924307E-6
# Model iJN1463.cmd: 5.683238955746335E-5
# Cycle 309
# Total biomass:
# Model iMM904.cmd: 9.780424003496174E-6
# Model iJN1463.cmd: 5.693412947440649E-5
# Cycle 310
# Total biomass:
# Model iMM904.cmd: 9.832714622660392E-6
# Model iJN1463.cmd: 5.703804496066118E-5
# Cycle 311
# Total biomass:
# Model iMM904.cmd: 9.890976053490288E-6
# Model iJN1463.cmd: 5.713400859606447E-5
# Cycle 312
# Total biomass:
# Model iMM904.cmd: 9.949959072659458E-6
# Model iJN1463.cmd: 5.723068285415304E-5
# Cycle 313
# Total biomass:
# Model iMM904.cmd: 1.0008652796757852E-5
# Model iJN1463.cmd: 5.7327330511921503E-5
# Cycle 314
# Total biomass:
# Model iMM904.cmd: 1.0070131950099793E-5
# Model iJN1463.cmd: 5.742104298263311E-5
# Cycle 315
# Total biomass:
# Model iMM904.cmd: 1.0129686651347788E-5
# Model iJN1463.cmd: 5.751416903823336E-5
# Cycle 316
# Total biomass:
# Model iMM904.cmd: 1.0189412798751994E-5
# Model iJN1463.cmd: 5.7606789342322425E-5
# Cycle 317
# Total biomass:
# Model iMM904.cmd: 1.0242371331470785E-5
# Model iJN1463.cmd: 5.7706710031682334E-5
# Cycle 318
# Total biomass:
# Model iMM904.cmd: 1.0298550221123761E-5
# Model iJN1463.cmd: 5.7804014113514886E-5
# Cycle 319
# Total biomass:
# Model iMM904.cmd: 1.0354624818700322E-5
# Model iJN1463.cmd: 5.7901164135972765E-5
# Cycle 320
# Total biomass:
# Model iMM904.cmd: 1.0417160266942026E-5
# Model iJN1463.cmd: 5.7992831095827266E-5
# Cycle 321
# Total biomass:
# Model iMM904.cmd: 1.047434308080339E-5
# Model iJN1463.cmd: 5.808875961739274E-5
# Cycle 322
# Total biomass:
# Model iMM904.cmd: 1.0533388063063236E-5
# Model iJN1463.cmd: 5.8180035406277704E-5
# Cycle 323
# Total biomass:
# Model iMM904.cmd: 1.0587662756275283E-5
# Model iJN1463.cmd: 5.827642675144029E-5
# Cycle 324
# Total biomass:
# Model iMM904.cmd: 1.0643432403459192E-5
# Model iJN1463.cmd: 5.836997329886279E-5
# Cycle 325
# Total biomass:
# Model iMM904.cmd: 1.0699922827616525E-5
# Model iJN1463.cmd: 5.846446056373545E-5
# Cycle 326
# Total biomass:
# Model iMM904.cmd: 1.075696537020405E-5
# Model iJN1463.cmd: 5.8556876158177016E-5
# Cycle 327
# Total biomass:
# Model iMM904.cmd: 1.0807717176102635E-5
# Model iJN1463.cmd: 5.86593516459749E-5
# Cycle 328
# Total biomass:
# Model iMM904.cmd: 1.086644256314239E-5
# Model iJN1463.cmd: 5.8751551652527844E-5
# Cycle 329
# Total biomass:
# Model iMM904.cmd: 1.0925394400133085E-5
# Model iJN1463.cmd: 5.8841186620143534E-5
# Cycle 330
# Total biomass:
# Model iMM904.cmd: 1.0984360330186247E-5
# Model iJN1463.cmd: 5.892937580983843E-5
# Cycle 331
# Total biomass:
# Model iMM904.cmd: 1.1039973430004098E-5
# Model iJN1463.cmd: 5.901999873509289E-5
# Cycle 332
# Total biomass:
# Model iMM904.cmd: 1.1093068450499269E-5
# Model iJN1463.cmd: 5.9112582418837766E-5
# Cycle 333
# Total biomass:
# Model iMM904.cmd: 1.1149228374930457E-5
# Model iJN1463.cmd: 5.920349416497182E-5
# Cycle 334
# Total biomass:
# Model iMM904.cmd: 1.1203146153358461E-5
# Model iJN1463.cmd: 5.9295056981822954E-5
# Cycle 335
# Total biomass:
# Model iMM904.cmd: 1.1261406029489879E-5
# Model iJN1463.cmd: 5.938165154639554E-5
# Cycle 336
# Total biomass:
# Model iMM904.cmd: 1.1322930846305615E-5
# Model iJN1463.cmd: 5.9466038852285785E-5
# Cycle 337
# Total biomass:
# Model iMM904.cmd: 1.1378082226084989E-5
# Model iJN1463.cmd: 5.9567661622960175E-5
# Cycle 338
# Total biomass:
# Model iMM904.cmd: 1.1436973029275527E-5
# Model iJN1463.cmd: 5.96570204131653E-5
# Cycle 339
# Total biomass:
# Model iMM904.cmd: 1.149515270682142E-5
# Model iJN1463.cmd: 5.974556881074816E-5
# Cycle 340
# Total biomass:
# Model iMM904.cmd: 1.1551021667158478E-5
# Model iJN1463.cmd: 5.983555250226596E-5
# Cycle 341
# Total biomass:
# Model iMM904.cmd: 1.1605767856735469E-5
# Model iJN1463.cmd: 5.992593056992816E-5
# Cycle 342
# Total biomass:
# Model iMM904.cmd: 1.1660080519340925E-5
# Model iJN1463.cmd: 6.00162047210438E-5
# Cycle 343
# Total biomass:
# Model iMM904.cmd: 1.1713303143752347E-5
# Model iJN1463.cmd: 6.010768498118225E-5
# Cycle 344
# Total biomass:
# Model iMM904.cmd: 1.1768452729025794E-5
# Model iJN1463.cmd: 6.0196624550160006E-5
# Cycle 345
# Total biomass:
# Model iMM904.cmd: 1.1824220411860061E-5
# Model iJN1463.cmd: 6.0285116074210136E-5
# Cycle 346
# Total biomass:
# Model iMM904.cmd: 1.1881242638161328E-5
# Model iJN1463.cmd: 6.0372645848471814E-5
# Cycle 347
# Total biomass:
# Model iMM904.cmd: 1.1937957144742358E-5
# Model iJN1463.cmd: 6.046061346970795E-5
# Cycle 348
# Total biomass:
# Model iMM904.cmd: 1.1994517998741347E-5
# Model iJN1463.cmd: 6.054894204991414E-5
# Cycle 349
# Total biomass:
# Model iMM904.cmd: 1.2052051785492548E-5
# Model iJN1463.cmd: 6.063533973641937E-5
# Cycle 350
# Total biomass:
# Model iMM904.cmd: 1.2108780228969975E-5
# Model iJN1463.cmd: 6.072216851355213E-5
# Cycle 351
# Total biomass:
# Model iMM904.cmd: 1.2165670714894578E-5
# Model iJN1463.cmd: 6.080882021041019E-5
# Cycle 352
# Total biomass:
# Model iMM904.cmd: 1.2225902029436541E-5
# Model iJN1463.cmd: 6.089118539101541E-5
# Cycle 353
# Total biomass:
# Model iMM904.cmd: 1.2286050291019381E-5
# Model iJN1463.cmd: 6.097303551054641E-5
# Cycle 354
# Total biomass:
# Model iMM904.cmd: 1.2347658679437786E-5
# Model iJN1463.cmd: 6.10534784860197E-5
# Cycle 355
# Total biomass:
# Model iMM904.cmd: 1.2405421393713266E-5
# Model iJN1463.cmd: 6.113817825191371E-5
# Cycle 356
# Total biomass:
# Model iMM904.cmd: 1.2469471010093657E-5
# Model iJN1463.cmd: 6.122284992419365E-5
# Cycle 357
# Total biomass:
# Model iMM904.cmd: 1.2524597606795056E-5
# Model iJN1463.cmd: 6.131017915247342E-5
# Cycle 358
# Total biomass:
# Model iMM904.cmd: 1.257863481038606E-5
# Model iJN1463.cmd: 6.139648222901592E-5
# Cycle 359
# Total biomass:
# Model iMM904.cmd: 1.2638327971737008E-5
# Model iJN1463.cmd: 6.147598074365586E-5
# Cycle 360
# Total biomass:
# Model iMM904.cmd: 1.2692173614316394E-5
# Model iJN1463.cmd: 6.156095037485466E-5
# Cycle 361
# Total biomass:
# Model iMM904.cmd: 1.2746844870093655E-5
# Model iJN1463.cmd: 6.164450465105404E-5
# Cycle 362
# Total biomass:
# Model iMM904.cmd: 1.2801724284221132E-5
# Model iJN1463.cmd: 6.172563923273E-5
# Cycle 363
# Total biomass:
# Model iMM904.cmd: 1.2858682658351637E-5
# Model iJN1463.cmd: 6.180608351831841E-5
# Cycle 364
# Total biomass:
# Model iMM904.cmd: 1.2912520841086436E-5
# Model iJN1463.cmd: 6.18893337661981E-5
# Cycle 365
# Total biomass:
# Model iMM904.cmd: 1.2968932673551079E-5
# Model iJN1463.cmd: 6.19700793872707E-5
# Cycle 366
# Total biomass:
# Model iMM904.cmd: 1.302231544299928E-5
# Model iJN1463.cmd: 6.205384187665848E-5
# Cycle 367
# Total biomass:
# Model iMM904.cmd: 1.3080859648854202E-5
# Model iJN1463.cmd: 6.213217201551496E-5
# Cycle 368
# Total biomass:
# Model iMM904.cmd: 1.3131185524481108E-5
# Model iJN1463.cmd: 6.221920185163507E-5
# Cycle 369
# Total biomass:
# Model iMM904.cmd: 1.3188658987135156E-5
# Model iJN1463.cmd: 6.229570800385274E-5
# Cycle 370
# Total biomass:
# Model iMM904.cmd: 1.3248378940773372E-5
# Model iJN1463.cmd: 6.237224170212505E-5
# Cycle 371
# Total biomass:
# Model iMM904.cmd: 1.330556407726009E-5
# Model iJN1463.cmd: 6.24506212185557E-5
# Cycle 372
# Total biomass:
# Model iMM904.cmd: 1.3360495047253112E-5
# Model iJN1463.cmd: 6.25308717659897E-5
# Cycle 373
# Total biomass:
# Model iMM904.cmd: 1.3414810997530622E-5
# Model iJN1463.cmd: 6.260714183092962E-5
# Cycle 374
# Total biomass:
# Model iMM904.cmd: 1.3469483522175807E-5
# Model iJN1463.cmd: 6.267751708256602E-5
# Cycle 375
# Total biomass:
# Model iMM904.cmd: 1.3529498161984017E-5
# Model iJN1463.cmd: 6.274698396240885E-5
# Cycle 376
# Total biomass:
# Model iMM904.cmd: 1.3585179776357122E-5
# Model iJN1463.cmd: 6.282207139121957E-5
# Cycle 377
# Total biomass:
# Model iMM904.cmd: 1.364164906759304E-5
# Model iJN1463.cmd: 6.289413909828191E-5
# Cycle 378
# Total biomass:
# Model iMM904.cmd: 1.3699140038457083E-5
# Model iJN1463.cmd: 6.296739241812547E-5
# Cycle 379
# Total biomass:
# Model iMM904.cmd: 1.3757243065756154E-5
# Model iJN1463.cmd: 6.304296478762566E-5
# Cycle 380
# Total biomass:
# Model iMM904.cmd: 1.3811445814790085E-5
# Model iJN1463.cmd: 6.312089135509555E-5
# Cycle 381
# Total biomass:
# Model iMM904.cmd: 1.3861341685401901E-5
# Model iJN1463.cmd: 6.319547135635477E-5
# Cycle 382
# Total biomass:
# Model iMM904.cmd: 1.3914586960595202E-5
# Model iJN1463.cmd: 6.326620589300924E-5
# Cycle 383
# Total biomass:
# Model iMM904.cmd: 1.3970377716593244E-5
# Model iJN1463.cmd: 6.333874058283167E-5
# Cycle 384
# Total biomass:
# Model iMM904.cmd: 1.4027498593494241E-5
# Model iJN1463.cmd: 6.341136518273408E-5
# Cycle 385
# Total biomass:
# Model iMM904.cmd: 1.4084739354665822E-5
# Model iJN1463.cmd: 6.348555307751982E-5
# Cycle 386
# Total biomass:
# Model iMM904.cmd: 1.4142235492373053E-5
# Model iJN1463.cmd: 6.356058196413789E-5
# Cycle 387
# Total biomass:
# Model iMM904.cmd: 1.419689634270047E-5
# Model iJN1463.cmd: 6.363548220091828E-5
# Cycle 388
# Total biomass:
# Model iMM904.cmd: 1.4248881170801525E-5
# Model iJN1463.cmd: 6.370570994632672E-5
# Cycle 389
# Total biomass:
# Model iMM904.cmd: 1.430207971566845E-5
# Model iJN1463.cmd: 6.377468421458797E-5
# Cycle 390
# Total biomass:
# Model iMM904.cmd: 1.4358078315394165E-5
# Model iJN1463.cmd: 6.384435291047845E-5
# Cycle 391
# Total biomass:
# Model iMM904.cmd: 1.4415009011996024E-5
# Model iJN1463.cmd: 6.391483331589078E-5
# Cycle 392
# Total biomass:
# Model iMM904.cmd: 1.4469514073191498E-5
# Model iJN1463.cmd: 6.398744881855862E-5
# Cycle 393
# Total biomass:
# Model iMM904.cmd: 1.452312481018142E-5
# Model iJN1463.cmd: 6.406101654515486E-5
# Cycle 394
# Total biomass:
# Model iMM904.cmd: 1.4576310219866335E-5
# Model iJN1463.cmd: 6.413437431827902E-5
# Cycle 395
# Total biomass:
# Model iMM904.cmd: 1.4632354394883783E-5
# Model iJN1463.cmd: 6.420381355570996E-5
# Cycle 396
# Total biomass:
# Model iMM904.cmd: 1.4689025275275584E-5
# Model iJN1463.cmd: 6.427332612322429E-5
# Cycle 397
# Total biomass:
# Model iMM904.cmd: 1.4745115164713468E-5
# Model iJN1463.cmd: 6.434329872879644E-5
# Cycle 398
# Total biomass:
# Model iMM904.cmd: 1.4800662149623266E-5
# Model iJN1463.cmd: 6.44140082970289E-5
# Cycle 399
# Total biomass:
# Model iMM904.cmd: 1.4855865077610292E-5
# Model iJN1463.cmd: 6.448299717932812E-5
# Cycle 400
# Total biomass:
# Model iMM904.cmd: 1.4910809850576797E-5
# Model iJN1463.cmd: 6.455148539510071E-5
# Cycle 401
# Total biomass:
# Model iMM904.cmd: 1.4965516970202437E-5
# Model iJN1463.cmd: 6.461963041628207E-5
# Cycle 402
# Total biomass:
# Model iMM904.cmd: 1.5019944794081764E-5
# Model iJN1463.cmd: 6.46873885349723E-5
# Cycle 403
# Total biomass:
# Model iMM904.cmd: 1.5074243213731745E-5
# Model iJN1463.cmd: 6.475484116608389E-5
# Cycle 404
# Total biomass:
# Model iMM904.cmd: 1.5128572789317675E-5
# Model iJN1463.cmd: 6.482202672525445E-5
# Cycle 405
# Total biomass:
# Model iMM904.cmd: 1.5182583035003506E-5
# Model iJN1463.cmd: 6.488951668291883E-5
# Cycle 406
# Total biomass:
# ...
# Cycle 849
# Total biomass:
# Model iMM904.cmd: 2.7576311738484193E-5
# Model iJN1463.cmd: 8.362654021988173E-5
# Cycle 850
# Total biomass:
# Model iMM904.cmd: 2.7592393860131737E-5
# Model iJN1463.cmd: 8.364379910453038E-5
# Cycle 851
# Total biomass:
# Model iMM904.cmd: 2.7608445138509292E-5
# Model iJN1463.cmd: 8.366104008596345E-5
# Cycle 852
# Total biomass:
# Model iMM904.cmd: 2.762446561218895E-5
# Model iJN1463.cmd: 8.36782629916772E-5
# Cycle 853
# Total biomass:
# Model iMM904.cmd: 2.7640455284272928E-5
# Model iJN1463.cmd: 8.369546790988767E-5
# Cycle 854
# Total biomass:
# Model iMM904.cmd: 2.765641421699945E-5
# Model iJN1463.cmd: 8.371265486584734E-5
# Cycle 855
# Total biomass:
# Model iMM904.cmd: 2.767234241892081E-5
# Model iJN1463.cmd: 8.372982378465927E-5
# Cycle 856
# Total biomass:
# Model iMM904.cmd: 2.768823991171293E-5
# Model iJN1463.cmd: 8.374697471347461E-5
# Cycle 857
# Total biomass:
# Model iMM904.cmd: 2.7704106707534452E-5
# Model iJN1463.cmd: 8.376410761886543E-5
# Cycle 858
# Total biomass:
# Model iMM904.cmd: 2.7719942850253773E-5
# Model iJN1463.cmd: 8.378122252928764E-5
# Cycle 859
# Total biomass:
# Model iMM904.cmd: 2.773574839309455E-5
# Model iJN1463.cmd: 8.379831948136373E-5
# Cycle 860
# Total biomass:
# Model iMM904.cmd: 2.775156444980111E-5
# Model iJN1463.cmd: 8.381539850370432E-5
# Cycle 861
# Total biomass:
# Model iMM904.cmd: 2.7767308793823296E-5
# Model iJN1463.cmd: 8.383246278692263E-5
# Cycle 862
# Total biomass:
# Model iMM904.cmd: 2.7783063673940847E-5
# Model iJN1463.cmd: 8.384950666373705E-5
# Cycle 863
# Total biomass:
# Model iMM904.cmd: 2.7798787928778664E-5
# Model iJN1463.cmd: 8.386653552214304E-5
# Cycle 864
# Total biomass:
# Model iMM904.cmd: 2.7814481615591726E-5
# Model iJN1463.cmd: 8.388354722159948E-5
# Cycle 865
# Total biomass:
# Model iMM904.cmd: 2.7830144765433852E-5
# Model iJN1463.cmd: 8.390054138485836E-5
# Cycle 866
# Total biomass:
# Model iMM904.cmd: 2.7845777432675384E-5
# Model iJN1463.cmd: 8.391751800318774E-5
# Cycle 867
# Total biomass:
# Model iMM904.cmd: 2.786137964404471E-5
# Model iJN1463.cmd: 8.393447694735403E-5
# Cycle 868
# Total biomass:
# Model iMM904.cmd: 2.78769514459875E-5
# Model iJN1463.cmd: 8.395141825588016E-5
# Cycle 869
# Total biomass:
# Model iMM904.cmd: 2.78924928906318E-5
# Model iJN1463.cmd: 8.396834187546206E-5
# Cycle 870
# Total biomass:
# Model iMM904.cmd: 2.7908016540009625E-5
# Model iJN1463.cmd: 8.398524785601745E-5
# Cycle 871
# Total biomass:
# Model iMM904.cmd: 2.7923497437046117E-5
# Model iJN1463.cmd: 8.400213687624691E-5
# Cycle 872
# Total biomass:
# Model iMM904.cmd: 2.793896055811332E-5
# Model iJN1463.cmd: 8.401900803168257E-5
# Cycle 873
# Total biomass:
# Model iMM904.cmd: 2.7954380922251743E-5
# Model iJN1463.cmd: 8.403586219189326E-5
# Cycle 874
# Total biomass:
# Model iMM904.cmd: 2.7969783486495163E-5
# Model iJN1463.cmd: 8.405269844489669E-5
# Cycle 875
# Total biomass:
# Model iMM904.cmd: 2.7985155843816683E-5
# Model iJN1463.cmd: 8.406951755512943E-5
# Cycle 876
# Total biomass:
# Model iMM904.cmd: 2.8000485654362076E-5
# Model iJN1463.cmd: 8.40863195039299E-5
# Cycle 877
# Total biomass:
# Model iMM904.cmd: 2.8015797771315604E-5
# Model iJN1463.cmd: 8.41031033769053E-5
# Cycle 878
# Total biomass:
# Model iMM904.cmd: 2.8031079852204557E-5
# Model iJN1463.cmd: 8.411987012428752E-5
# Cycle 879
# Total biomass:
# Model iMM904.cmd: 2.8046334398161595E-5
# Model iJN1463.cmd: 8.413662216341929E-5
# Cycle 880
# Total biomass:
# Model iMM904.cmd: 2.8062455443997684E-5
# Model iJN1463.cmd: 8.415253455361248E-5
# Cycle 881
# Total biomass:
# Model iMM904.cmd: 2.8078582144517024E-5
# Model iJN1463.cmd: 8.416843220080786E-5
# Cycle 882
# Total biomass:
# Model iMM904.cmd: 2.809468719646869E-5
# Model iJN1463.cmd: 8.418431936613039E-5
# Cycle 883
# Total biomass:
# Model iMM904.cmd: 2.8110770205573453E-5
# Model iJN1463.cmd: 8.420019634456014E-5
# Cycle 884
# Total biomass:
# Model iMM904.cmd: 2.8126831088477505E-5
# Model iJN1463.cmd: 8.421606336915927E-5
# Cycle 885
# Total biomass:
# Model iMM904.cmd: 2.8142869824430395E-5
# Model iJN1463.cmd: 8.423192066429426E-5
# Cycle 886
# Total biomass:
# Model iMM904.cmd: 2.815888645210331E-5
# Model iJN1463.cmd: 8.424776842151817E-5
# Cycle 887
# Total biomass:
# Model iMM904.cmd: 2.8174880971681844E-5
# Model iJN1463.cmd: 8.426360677369717E-5
# Cycle 888
# Total biomass:
# Model iMM904.cmd: 2.819085336117331E-5
# Model iJN1463.cmd: 8.427943578766921E-5
# Cycle 889
# Total biomass:
# Model iMM904.cmd: 2.8206803617847394E-5
# Model iJN1463.cmd: 8.429525558094307E-5
# Cycle 890
# Total biomass:
# Model iMM904.cmd: 2.822273168363681E-5
# Model iJN1463.cmd: 8.431106634089805E-5
# Cycle 891
# Total biomass:
# Model iMM904.cmd: 2.8238640044983982E-5
# Model iJN1463.cmd: 8.432687039810565E-5
# Cycle 892
# Total biomass:
# Model iMM904.cmd: 2.8255309436976774E-5
# Model iJN1463.cmd: 8.434190359542653E-5
# Cycle 893
# Total biomass:
# Model iMM904.cmd: 2.8272154859656487E-5
# Model iJN1463.cmd: 8.435679678172587E-5
# Cycle 894
# Total biomass:
# Model iMM904.cmd: 2.8289022079504657E-5
# Model iJN1463.cmd: 8.4371663980773E-5
# Cycle 895
# Total biomass:
# Model iMM904.cmd: 2.8305888244164345E-5
# Model iJN1463.cmd: 8.438652797513277E-5
# Cycle 896
# Total biomass:
# Model iMM904.cmd: 2.8322747678843535E-5
# Model iJN1463.cmd: 8.440139378407305E-5
# Cycle 897
# Total biomass:
# Model iMM904.cmd: 2.8339598965321624E-5
# Model iJN1463.cmd: 8.441626283894681E-5
# Cycle 898
# Total biomass:
# Model iMM904.cmd: 2.8356441747336872E-5
# Model iJN1463.cmd: 8.443113564676465E-5
# Cycle 899
# Total biomass:
# Model iMM904.cmd: 2.8373275920309273E-5
# Model iJN1463.cmd: 8.444601250416487E-5
# Cycle 900
# Total biomass:
# Model iMM904.cmd: 2.8390101446769877E-5
# Model iJN1463.cmd: 8.446089356156262E-5
# Cycle 901
# Total biomass:
# Model iMM904.cmd: 2.8406922568788012E-5
# Model iJN1463.cmd: 8.447578297932937E-5
# Cycle 902
# Total biomass:
# Model iMM904.cmd: 2.8423740279517145E-5
# Model iJN1463.cmd: 8.449068171566712E-5
# Cycle 903
# Total biomass:
# Model iMM904.cmd: 2.8440554764796295E-5
# Model iJN1463.cmd: 8.450559001899723E-5
# Cycle 904
# Total biomass:
# Model iMM904.cmd: 2.845736605929709E-5
# Model iJN1463.cmd: 8.452050795503446E-5
# Cycle 905
# Total biomass:
# Model iMM904.cmd: 2.8474174179215276E-5
# Model iJN1463.cmd: 8.453543554773026E-5
# Cycle 906
# Total biomass:
# Model iMM904.cmd: 2.8490979128886036E-5
# Model iJN1463.cmd: 8.455037280382664E-5
# Cycle 907
# Total biomass:
# Model iMM904.cmd: 2.8507740871282814E-5
# Model iJN1463.cmd: 8.456531972180184E-5
# Cycle 908
# Total biomass:
# Model iMM904.cmd: 2.8524564506059675E-5
# Model iJN1463.cmd: 8.45802750919195E-5
# Cycle 909
# Total biomass:
# Model iMM904.cmd: 2.8541345617802525E-5
# Model iJN1463.cmd: 8.459524105453274E-5
# Cycle 910
# Total biomass:
# Model iMM904.cmd: 2.8558123779309797E-5
# Model iJN1463.cmd: 8.461021575084036E-5
# Cycle 911
# Total biomass:
# Model iMM904.cmd: 2.857489874524166E-5
# Model iJN1463.cmd: 8.462520244272981E-5
# Cycle 912
# Total biomass:
# Model iMM904.cmd: 2.859167043035749E-5
# Model iJN1463.cmd: 8.464019866516534E-5
# Cycle 913
# Total biomass:
# Model iMM904.cmd: 2.8608438829365896E-5
# Model iJN1463.cmd: 8.465520432992258E-5
# Cycle 914
# Total biomass:
# Model iMM904.cmd: 2.862520401171721E-5
# Model iJN1463.cmd: 8.467021873672395E-5
# Cycle 915
# Total biomass:
# Model iMM904.cmd: 2.864431235785967E-5
# Model iJN1463.cmd: 8.468555677022219E-5
# Cycle 916
# Total biomass:
# Model iMM904.cmd: 2.8662793010524195E-5
# Model iJN1463.cmd: 8.469727263403267E-5
# Cycle 917
# Total biomass:
# Model iMM904.cmd: 2.8679765964875878E-5
# Model iJN1463.cmd: 8.470786029654894E-5
# Cycle 918
# Total biomass:
# Model iMM904.cmd: 2.8696441265025737E-5
# Model iJN1463.cmd: 8.471804617010509E-5
# Cycle 919
# Total biomass:
# Model iMM904.cmd: 2.8713058316371586E-5
# Model iJN1463.cmd: 8.472812433885282E-5
# Cycle 920
# Total biomass:
# Model iMM904.cmd: 2.872961229796964E-5
# Model iJN1463.cmd: 8.473815525366047E-5
# Cycle 921
# Total biomass:
# Model iMM904.cmd: 2.874611749876121E-5
# Model iJN1463.cmd: 8.474815176364695E-5
# Cycle 922
# Total biomass:
# Model iMM904.cmd: 2.876261002633358E-5
# Model iJN1463.cmd: 8.475812212383183E-5
# Cycle 923
# Total biomass:
# Model iMM904.cmd: 2.8779146148521067E-5
# Model iJN1463.cmd: 8.476809393291753E-5
# Cycle 924
# Total biomass:
# Model iMM904.cmd: 2.8795704476787403E-5
# Model iJN1463.cmd: 8.477805418550173E-5
# Cycle 925
# Total biomass:
# Model iMM904.cmd: 2.8812352878088523E-5
# Model iJN1463.cmd: 8.478799416588239E-5
# Cycle 926
# Total biomass:
# Model iMM904.cmd: 2.882897623941928E-5
# Model iJN1463.cmd: 8.479790779092058E-5
# Cycle 927
# Total biomass:
# Model iMM904.cmd: 2.8845586090453106E-5
# Model iJN1463.cmd: 8.48077939249283E-5
# Cycle 928
# Total biomass:
# Model iMM904.cmd: 2.886215958660252E-5
# Model iJN1463.cmd: 8.481765201171342E-5
# Cycle 929
# Total biomass:
# Model iMM904.cmd: 2.8878686563168446E-5
# Model iJN1463.cmd: 8.482748120175412E-5
# Cycle 930
# Total biomass:
# Model iMM904.cmd: 2.8895176303651332E-5
# Model iJN1463.cmd: 8.483728190231277E-5
# Cycle 931
# Total biomass:
# Model iMM904.cmd: 2.8911619436891268E-5
# Model iJN1463.cmd: 8.484705386496312E-5
# Cycle 932
# Total biomass:
# Model iMM904.cmd: 2.8928025412741286E-5
# Model iJN1463.cmd: 8.48567976968491E-5
# Cycle 933
# Total biomass:
# Model iMM904.cmd: 2.8944384958669484E-5
# Model iJN1463.cmd: 8.486651261070249E-5
# Cycle 934
# Total biomass:
# Model iMM904.cmd: 2.896070752523788E-5
# Model iJN1463.cmd: 8.487619913665244E-5
# Cycle 935
# Total biomass:
# Model iMM904.cmd: 2.8976983941975963E-5
# Model iJN1463.cmd: 8.488585678653999E-5
# Cycle 936
# Total biomass:
# Model iMM904.cmd: 2.8993223557970145E-5
# Model iJN1463.cmd: 8.489548606516967E-5
# Cycle 937
# Total biomass:
# Model iMM904.cmd: 2.9009417284136623E-5
# Model iJN1463.cmd: 8.490508661621117E-5
# Cycle 938
# Total biomass:
# Model iMM904.cmd: 2.9025574410623047E-5
# Model iJN1463.cmd: 8.491465909433745E-5
# Cycle 939
# Total biomass:
# Model iMM904.cmd: 2.904169174252165E-5
# Model iJN1463.cmd: 8.492420365021091E-5
# Cycle 940
# Total biomass:
# Model iMM904.cmd: 2.9057768525290658E-5
# Model iJN1463.cmd: 8.49337200548456E-5
# Cycle 941
# Total biomass:
# Model iMM904.cmd: 2.9073804586805168E-5
# Model iJN1463.cmd: 8.494320834909083E-5
# Cycle 942
# Total biomass:
# Model iMM904.cmd: 2.9089799942335512E-5
# Model iJN1463.cmd: 8.495266859493564E-5
# Cycle 943
# Total biomass:
# Model iMM904.cmd: 2.9105754675464458E-5
# Model iJN1463.cmd: 8.496210125520237E-5
# Cycle 944
# Total biomass:
# Model iMM904.cmd: 2.9121668878239337E-5
# Model iJN1463.cmd: 8.497150690425308E-5
# Cycle 945
# Total biomass:
# Model iMM904.cmd: 2.9137542651644437E-5
# Model iJN1463.cmd: 8.498088562088787E-5
# Cycle 946
# Total biomass:
# Model iMM904.cmd: 2.9153376102737858E-5
# Model iJN1463.cmd: 8.499023748369591E-5
# Cycle 947
# Total biomass:
# Model iMM904.cmd: 2.9169169348487044E-5
# Model iJN1463.cmd: 8.499956263288176E-5
# Cycle 948
# Total biomass:
# Model iMM904.cmd: 2.918492250810077E-5
# Model iJN1463.cmd: 8.500886122235078E-5
# Cycle 949
# Total biomass:
# Model iMM904.cmd: 2.9200593498190726E-5
# Model iJN1463.cmd: 8.501810838056714E-5
# Cycle 950
# Total biomass:
# Model iMM904.cmd: 2.9216010892965186E-5
# Model iJN1463.cmd: 8.502730364765434E-5
# Cycle 951
# Total biomass:
# Model iMM904.cmd: 2.9231378591735427E-5
# Model iJN1463.cmd: 8.503646121119297E-5
# Cycle 952
# Total biomass:
# Model iMM904.cmd: 2.924670240801312E-5
# Model iJN1463.cmd: 8.504558889012733E-5
# Cycle 953
# Total biomass:
# Model iMM904.cmd: 2.9262034083559975E-5
# Model iJN1463.cmd: 8.50547018467765E-5
# Cycle 954
# Total biomass:
# Model iMM904.cmd: 2.9277272684479717E-5
# Model iJN1463.cmd: 8.506377248062425E-5
# Cycle 955
# Total biomass:
# Model iMM904.cmd: 2.9292601462882354E-5
# Model iJN1463.cmd: 8.507285487011556E-5
# Cycle 956
# Total biomass:
# Model iMM904.cmd: 2.9307951567744698E-5
# Model iJN1463.cmd: 8.508192791954099E-5
# Cycle 957
# Total biomass:
# Model iMM904.cmd: 2.932334215719626E-5
# Model iJN1463.cmd: 8.509098727816868E-5
# Cycle 958
# Total biomass:
# Model iMM904.cmd: 2.933839774735388E-5
# Model iJN1463.cmd: 8.509988073942466E-5
# Cycle 959
# Total biomass:
# Model iMM904.cmd: 2.9353716167988687E-5
# Model iJN1463.cmd: 8.510890242932437E-5
# Cycle 960
# Total biomass:
# Model iMM904.cmd: 2.9368778590291287E-5
# Model iJN1463.cmd: 8.511785389138407E-5
# Cycle 961
# Total biomass:
# Model iMM904.cmd: 2.9383760325236395E-5
# Model iJN1463.cmd: 8.512675354756877E-5
# Cycle 962
# Total biomass:
# Model iMM904.cmd: 2.939869254789266E-5
# Model iJN1463.cmd: 8.513562091338366E-5
# Cycle 963
# Total biomass:
# Model iMM904.cmd: 2.9413598300496837E-5
# Model iJN1463.cmd: 8.514446307681436E-5
# Cycle 964
# Total biomass:
# Model iMM904.cmd: 2.9428496692729986E-5
# Model iJN1463.cmd: 8.515326754658674E-5
# Cycle 965
# Total biomass:
# Model iMM904.cmd: 2.9443479481222378E-5
# Model iJN1463.cmd: 8.516209935605924E-5
# Cycle 966
# Total biomass:
# Model iMM904.cmd: 2.945849940720147E-5
# Model iJN1463.cmd: 8.51709225165606E-5
# Cycle 967
# Total biomass:
# Model iMM904.cmd: 2.947355061299073E-5
# Model iJN1463.cmd: 8.517972486166085E-5
# Cycle 968
# Total biomass:
# Model iMM904.cmd: 2.948855182090222E-5
# Model iJN1463.cmd: 8.518850484059874E-5
# Cycle 969
# Total biomass:
# Model iMM904.cmd: 2.950353401181801E-5
# Model iJN1463.cmd: 8.519726058836071E-5
# Cycle 970
# Total biomass:
# Model iMM904.cmd: 2.9518468034538454E-5
# Model iJN1463.cmd: 8.52059923804968E-5
# Cycle 971
# Total biomass:
# Model iMM904.cmd: 2.953337672697934E-5
# Model iJN1463.cmd: 8.521469927741253E-5
# Cycle 972
# Total biomass:
# Model iMM904.cmd: 2.954817927980564E-5
# Model iJN1463.cmd: 8.522335294220483E-5
# Cycle 973
# Total biomass:
# Model iMM904.cmd: 2.9563008076460102E-5
# Model iJN1463.cmd: 8.523200567853924E-5
# Cycle 974
# Total biomass:
# Model iMM904.cmd: 2.95778022044638E-5
# Model iJN1463.cmd: 8.524063879138493E-5
# Cycle 975
# Total biomass:
# Model iMM904.cmd: 2.9592566464623432E-5
# Model iJN1463.cmd: 8.524924993383125E-5
# Cycle 976
# Total biomass:
# Model iMM904.cmd: 2.9607291190673617E-5
# Model iJN1463.cmd: 8.525783936343654E-5
# Cycle 977
# Total biomass:
# Model iMM904.cmd: 2.9621987105800422E-5
# Model iJN1463.cmd: 8.526640812975164E-5
# Cycle 978
# Total biomass:
# Model iMM904.cmd: 2.9636643966240472E-5
# Model iJN1463.cmd: 8.527495583657306E-5
# Cycle 979
# Total biomass:
# Model iMM904.cmd: 2.9651278419673097E-5
# Model iJN1463.cmd: 8.528348246624097E-5
# Cycle 980
# Total biomass:
# Model iMM904.cmd: 2.9665869463224957E-5
# Model iJN1463.cmd: 8.529198726794432E-5
# Cycle 981
# Total biomass:
# Model iMM904.cmd: 2.9680437193059702E-5
# Model iJN1463.cmd: 8.530047128304728E-5
# Cycle 982
# Total biomass:
# Model iMM904.cmd: 2.9694981741862725E-5
# Model iJN1463.cmd: 8.530893344349278E-5
# Cycle 983
# Total biomass:
# Model iMM904.cmd: 2.9709482522262726E-5
# Model iJN1463.cmd: 8.531737538846304E-5
# Cycle 984
# Total biomass:
# Model iMM904.cmd: 2.972396027902875E-5
# Model iJN1463.cmd: 8.532579556069617E-5
# Cycle 985
# Total biomass:
# Model iMM904.cmd: 2.9738394409257623E-5
# Model iJN1463.cmd: 8.533419536880161E-5
# Cycle 986
# Total biomass:
# Model iMM904.cmd: 2.9752805751577428E-5
# Model iJN1463.cmd: 8.534257355474752E-5
# Cycle 987
# Total biomass:
# Model iMM904.cmd: 2.9767200689672073E-5
# Model iJN1463.cmd: 8.535093173815187E-5
# Cycle 988
# Total biomass:
# Model iMM904.cmd: 2.978154746001021E-5
# Model iJN1463.cmd: 8.535926842308222E-5
# Cycle 989
# Total biomass:
# Model iMM904.cmd: 2.979587692911331E-5
# Model iJN1463.cmd: 8.536758491842904E-5
# Cycle 990
# Total biomass:
# Model iMM904.cmd: 2.981015808446281E-5
# Model iJN1463.cmd: 8.53758800119751E-5
# Cycle 991
# Total biomass:
# Model iMM904.cmd: 2.9824421861512456E-5
# Model iJN1463.cmd: 8.538415490174107E-5
# Cycle 992
# Total biomass:
# Model iMM904.cmd: 2.983863755554202E-5
# Model iJN1463.cmd: 8.539240832964062E-5
# Cycle 993
# Total biomass:
# Model iMM904.cmd: 2.985283589400643E-5
# Model iJN1463.cmd: 8.540064161153848E-5
# Cycle 994
# Total biomass:
# Model iMM904.cmd: 2.9867038074631935E-5
# Model iJN1463.cmd: 8.540885368087858E-5
# Cycle 995
# Total biomass:
# Model iMM904.cmd: 2.9881171257045163E-5
# Model iJN1463.cmd: 8.541704696357825E-5
# Cycle 996
# Total biomass:
# Model iMM904.cmd: 2.9895308485127875E-5
# Model iJN1463.cmd: 8.542521819488717E-5
# Cycle 997
# Total biomass:
# Model iMM904.cmd: 2.990942846671197E-5
# Model iJN1463.cmd: 8.54333705369285E-5
# Cycle 998
# Total biomass:
# Model iMM904.cmd: 2.9923501025315296E-5
# Model iJN1463.cmd: 8.544150193604436E-5
# Cycle 999
# Total biomass:
# Model iMM904.cmd: 2.993755875713452E-5
# Model iJN1463.cmd: 8.544961357736745E-5
# Cycle 1000
# Total biomass:
# Model iMM904.cmd: 2.99515676937171E-5
# Model iJN1463.cmd: 8.545770416205107E-5
# Cycle 1001
# End of simulation
# Total time = 6497.373s
#
# STDERR empty.

# %% [markdown]
# Para revisar la biomasa total

# %%
sim.total_biomass.plot(x = "cycle")
# Out:
# <AxesSubplot:xlabel='cycle'>

# %% [markdown]
# Graficamos los resultados de biomasa y demás metabolitos interesantes en el grid:

# %%
im = sim.get_biomass_image('iMM904', params.all_params['maxCycles'])
im2 = sim.get_biomass_image('iJN1463',params.all_params['maxCycles'])

final = np.zeros((grid_size,grid_size,3))
final[:,:,0] = im / np.max(im)
final[:,:,1] = im2 / np.max(im2)
for rock in rock_locs:
    final[rock[0],rock[1],0:3] = 0.4 
from matplotlib import pyplot as plt
ﬁg, ax = plt.subplots(ﬁgsize = (3.1, 3.1))
ax.imshow(ﬁnal)
plt.imshow(final)

# %%
plt.imshow(sim.get_metabolite_image("succ_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("ac_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("nh4_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("o2_e",params.all_params['maxCycles']))

# %%
plt.imshow(sim.get_metabolite_image("catechol_e",params.all_params['maxCycles']))
